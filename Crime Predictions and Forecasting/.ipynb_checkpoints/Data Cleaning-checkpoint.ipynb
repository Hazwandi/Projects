# %%
# Ref(install conda in google colab): https://medium.com/data-professor/how-to-install-conda-on-google-colab-e7bbf9036f76
# Ref(to install conda packages in google colab): https://towardsdatascience.com/conda-google-colab-75f7c867a522

# %%
#!pip install geopandas
#!pip install rtree

# %% [markdown]
# # **Crime Prediction & Forecasting towards 2022**
#
# ## **Business Case**
# Chicago State Police recently participated in the annual State Defense and Security Summit 2021 and have identified the need for a change in their policies on a city level. To increase the prevention effort for high crimes in the city and equipping proper skillsets and resources for their fellow officers moving forward.
#
# As the first phase of revolutionizing policing work, they decided to set up a new department called PreCrime Task Force (PCTF) as representative of the force, informing and geared frontline officers towards potential crimes.
#
# *‘Prevent, deter and detect crime’*
#
#
# ## **Problem Statement**
# - To achieve success, we, Data Forensic Scientists, have been engaged by the state police to be the brains of the unit in predicting and forecasting different types of crimes and measured based on accuracy of the predictions.
#
#
# ## **Objectives**
#  - Determine how a combination of machine learning algorithm can be used by Chicago State Police to detect, prevent, and solve crimes accurately and at a faster rate
#  - Develop a model to predict and forecast crime rates per month to antipate the allocation of resources and equipments
#
#
# ### **Project Approach**
# Our task is to identify known crimes and develop a model to predict crimes rates to help inform state police officers for their preparation.
#
# Approached to this project are as follows:
# 1. Data acquisition from [Chicago Data Portal](https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-Present/ijzp-q8t2)
# 2. Preliminary Analysis
# 3. Data Cleaning
# 4. Exploratory Data Analysis (EDA)
# 5. Data Pre-processing
# 6. Modelling - Times Series & ML Regression
# 7. Conclusions & Recommendations
#
#
#
#
#
#
# ### Reference
# - https://www.bestplaces.net/health/city/illinois/chicago
# - https://www.nytimes.com/2021/06/16/upshot/murder-crime-trends-chicago.html
# - https://en.wikipedia.org/wiki/Crime_in_Chicago#References

# %% [markdown]
# ## **Preliminary Research**
# Chicago City crime rate far exceeds the average of its country, United States and state, Illinois on every aspect from violent crime such as murder, rape to simple crime such as theft and assault.
#
# Notably, in the past decade, Chicago's crime rates have seen a gradual decreased in trend but the reasons why are not known to the government nor the state police.
#
# While Chicago is known for series of violent and property crimes mentioned in the media, the percentage difference was measure based on individual crime. Other types of crime not mention may be greater in numbers and magnitude.
#
# ## **Summary Observations**
# - Data contains a surface level information of crimes based on type and description, location and mapping area which it was reported
# - Contains a high number of null values mainly from location
#
# ### **Cleaning:**
#
# As each crime is an important information, instead of removing, we dealt with null values accordingly
# - Latitude and longtiude using block address
# - District, ward and community area by using Chicago Data Portal
# - Location description values assign to others

# %%
# Import libraries and packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import re
import geopandas as gpd

from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

pd.set_option('display.max_columns', None)

# %%
# Load crime data
df = pd.read_csv('drive/MyDrive/Colab Notebooks/capstone/assets/all_crimes.csv')
df.head()
# Out:
#          ID Case Number                    Date                  Block  IUCR  \
# 0  10224738    HY411648  09/05/2015 01:30:00 PM        043XX S WOOD ST  0486
# 1  10224739    HY411615  09/04/2015 11:30:00 AM    008XX N CENTRAL AVE  0870
# 2  11646166    JC213529  09/01/2018 12:01:00 AM  082XX S INGLESIDE AVE  0810
# 3  10224740    HY411595  09/05/2015 12:45:00 PM      035XX W BARRY AVE  2023
# 4  10224741    HY411610  09/05/2015 01:00:00 PM    0000X N LARAMIE AVE  0560
#
#   Primary Type              Description Location Description  Arrest  \
# 0      BATTERY  DOMESTIC BATTERY SIMPLE            RESIDENCE   False
# 1        THEFT           POCKET-PICKING              CTA BUS   False
# 2        THEFT                OVER $500            RESIDENCE   False
# 3    NARCOTICS    POSS: HEROIN(BRN/TAN)             SIDEWALK    True
# 4      ASSAULT                   SIMPLE            APARTMENT   False
#
#    Domestic  Beat  District  Ward  Community Area FBI Code  X Coordinate  \
# 0      True   924       9.0  12.0            61.0      08B     1165074.0
# 1     False  1511      15.0  29.0            25.0       06     1138875.0
# 2      True   631       6.0   8.0            44.0       06           NaN
# 3     False  1412      14.0  35.0            21.0       18     1152037.0
# 4      True  1522      15.0  28.0            25.0      08A     1141706.0
#
#    Y Coordinate  Year              Updated On   Latitude  Longitude  \
# 0     1875917.0  2015  02/10/2018 03:50:01 PM  41.815117 -87.670000
# 1     1904869.0  2015  02/10/2018 03:50:01 PM  41.895080 -87.765400
# 2           NaN  2018  04/06/2019 04:04:43 PM        NaN        NaN
# 3     1920384.0  2015  02/10/2018 03:50:01 PM  41.937406 -87.716650
# 4     1900086.0  2015  02/10/2018 03:50:01 PM  41.881903 -87.755121
#
#                         Location
# 0  (41.815117282, -87.669999562)
# 1  (41.895080471, -87.765400451)
# 2                            NaN
# 3  (41.937405765, -87.716649687)
# 4  (41.881903443, -87.755121152)

# %% [markdown]
# ---

# %% [markdown]
# # Data Dictionary

# %% [markdown]
# |S/N|Feature|Type|Dataset|Description|
# |:---:|:---|:---|:---:|:---|
# |1|ID|Object|df|Unique identifier for records|
# |2|Case Number|Object|df|The Chicago Police Department RD Number (Records Division Number), which is unique to the incident|
# |3|Date|Datetime|df|Date when the incident occurred(sometimes a best estimate)|
# |4|Block|Object|df|The partially redacted address where the incident occurred, placing it on the same block as the actual address|
# |5|IUCR|Object|df|The Illinois Unifrom Crime Reporting code. This is directly linked to the Primary Type and Description. See the list of IUCR codes at https://data.cityofchicago.org/d/c7ck-438e|
# |6|Primary Type|Object|df|The primary description of the ICUR code|
# |7|Description|Object|df|The secondary description of the IUCR code, a subcategory of the primary description|
# |8|Location Description|Object|df|Description of the location where the incident occurred|
# |9|Arrest|Boolean|df|Indicates whether the arrest was made|
# |10|Domestic|Boolean|df|Indicates whether the incident was domestic-related as defined by the Illinois Domestic Violence Act|
# |11|Beat|Int|df|Indicates the beat where the incident occurred. A beat is the smallest police geographic area – each beat has a dedicated police beat car. Three to five beats make up a police sector, and three sectors make up a police district. The Chicago Police Department has 22 police districts. See the beats at https://data.cityofchicago.org/d/aerh-rz74|
# |12|District|Float|df|Indicates the police district where the incident occurred. See the districts at https://data.cityofchicago.org/d/fthy-xz3r|
# |13|Ward|Float|df|The ward (City Council district) where the incident occurred. See the wards at https://data.cityofchicago.org/d/sp34-6z76|
# |14|Community Area|Float|df|Indicates the community area where the incident occurred. Chicago has 77 community areas. See the community areas at https://data.cityofchicago.org/d/cauq-8yn6|
# |15|FBI Code|Object|df|Indicates the crime classification as outlined in the FBI's National Incident-Based Reporting System (NIBRS). See the Chicago Police Department listing of these classifications at http://gis.chicagopolice.org/clearmap_crime_sums/crime_types.html|
# |16|X Coordinate|Float|df|The x coordinate of the location where the incident occurred in State Plane Illinois East NAD 1983 projection. This location is shifted from the actual location for partial redaction but falls on the same block.|
# |17|Y Coordinate|Float|df|The y coordinate of the location where the incident occurred in State Plane Illinois East NAD 1983 projection. This location is shifted from the actual location for partial redaction but falls on the same block.|
# |18|Year|datetime|df|Year the incident occured|
# |19|Updated On|Object|Df|Date and time the record was last updated|
# |20|Latitude|Float|df|The latitude of the location where the incident occurred. This location is shifted from the actual location for partial redaction but falls on the same block|
# |21|Longitude|Float|df|The longitude of the location where the incident occurred. This location is shifted from the actual location for partial redaction but falls on the same block|
# |22|Location|Object|df|The location where the incident occurred in a format that allows for creation of maps and other geographic operations on this data portal. This location is shifted from the actual location for partial redaction but falls on the same block|

# %% [markdown]
# # Data Summary

# %%
# Data rows and columns
df.shape
# Out:
# (7369258, 22)

# %%
# df summary
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7369258 entries, 0 to 7369257
# Data columns (total 22 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   ID                    int64
#  1   Case Number           object
#  2   Date                  object
#  3   Block                 object
#  4   IUCR                  object
#  5   Primary Type          object
#  6   Description           object
#  7   Location Description  object
#  8   Arrest                bool
#  9   Domestic              bool
#  10  Beat                  int64
#  11  District              float64
#  12  Ward                  float64
#  13  Community Area        float64
#  14  FBI Code              object
#  15  X Coordinate          float64
#  16  Y Coordinate          float64
#  17  Year                  int64
#  18  Updated On            object
#  19  Latitude              float64
#  20  Longitude             float64
#  21  Location              object
# dtypes: bool(2), float64(7), int64(3), object(10)
# memory usage: 1.1+ GB

# %%
# Check for null values
df.isnull().sum()
# Out:
# ID                           0
# Case Number                  4
# Date                         0
# Block                        0
# IUCR                         0
# Primary Type                 0
# Description                  0
# Location Description      8410
# Arrest                       0
# Domestic                     0
# Beat                         0
# District                    47
# Ward                    614837
# Community Area          613481
# FBI Code                     0
# X Coordinate             73441
# Y Coordinate             73441
# Year                         0
# Updated On                   0
# Latitude                 73441
# Longitude                73441
# Location                 73441
# dtype: int64

# %%
df.describe()
# Out:
#                  ID          Beat      District          Ward  Community Area  \
# count  7.369258e+06  7.369258e+06  7.369211e+06  6.754421e+06    6.755777e+06
# mean   6.706293e+06  1.187754e+03  1.129414e+01  2.271887e+01    3.755121e+01
# std    3.318089e+06  7.028956e+02  6.946204e+00  1.383099e+01    2.153817e+01
# min    6.340000e+02  1.110000e+02  1.000000e+00  1.000000e+00    0.000000e+00
# 25%    3.633551e+06  6.220000e+02  6.000000e+00  1.000000e+01    2.300000e+01
# 50%    6.697120e+06  1.034000e+03  1.000000e+01  2.200000e+01    3.200000e+01
# 75%    9.606108e+06  1.731000e+03  1.700000e+01  3.400000e+01    5.700000e+01
# max    1.243720e+07  2.535000e+03  3.100000e+01  5.000000e+01    7.700000e+01
#
#        X Coordinate  Y Coordinate          Year      Latitude     Longitude
# count  7.295817e+06  7.295817e+06  7.369258e+06  7.295817e+06  7.295817e+06
# mean   1.164558e+06  1.885726e+06  2.009271e+03  4.184203e+01 -8.767165e+01
# std    1.685735e+04  3.228476e+04  5.732384e+00  8.882348e-02  6.111225e-02
# min    0.000000e+00  0.000000e+00  2.001000e+03  3.661945e+01 -9.168657e+01
# 25%    1.152942e+06  1.859074e+06  2.004000e+03  4.176871e+01 -8.771382e+01
# 50%    1.166045e+06  1.890643e+06  2.009000e+03  4.185572e+01 -8.766600e+01
# 75%    1.176363e+06  1.909222e+06  2.014000e+03  4.190668e+01 -8.762828e+01
# max    1.205119e+06  1.951622e+06  2.021000e+03  4.202291e+01 -8.752453e+01

# %%
# Change column names to lower and replace whitespace with _
df.columns = df.columns.str.lower().str.replace(' ', '_')
df.columns
# Out:
# Index(['id', 'case_number', 'date', 'block', 'iucr', 'primary_type',
#        'description', 'location_description', 'arrest', 'domestic', 'beat',
#        'district', 'ward', 'community_area', 'fbi_code', 'x_coordinate',
#        'y_coordinate', 'year', 'updated_on', 'latitude', 'longitude',
#        'location'],
#       dtype='object')

# %% [markdown]
# # Understanding Crime Data

# %% [markdown]
# ## Missing Values

# %%
sorted(df1.year.unique())
# Out:
# [2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019,
#  2020,
#  2021]

# %%
# Check % of missing values (dataset)
def per_missing_values(df):
    for cols in df.columns:
        total_missing = df[cols].isnull().sum()
        if total_missing == 0:
            continue
        else:
            percentage = round((total_missing / df.shape[0]) * 100, 4)
            print (f'{cols} - {percentage}%')

# Check % of missing values (year)          
def per_missing_values_years(df):
    for year in sorted(df['year'].unique()):
        print (year)
        
        df_year = df[df['year'] == year]
        for cols in df_year.columns:
            total_missing = df_year[cols].isnull().sum()
            if total_missing == 0:
                continue
            else:
                percentage = round((total_missing / df.shape[0]) * 100, 4)
                print (f'{cols} - {percentage}%')
        print ('')

# Check total count of missing values (year)          
def count_missing_values_years(df):
    for year in sorted(df['year'].unique()):
        print (year)
        
        count_year = df[df['year'] == year]
        count_missing = count_year.isnull().sum()
        print (count_missing)
        print ('')

# %%
# Null values based on whole dataset
per_missing_values(df1)
# Out:
# case_number - 0.0001%
# location_description - 0.1141%
# district - 0.0006%
# ward - 8.3433%
# community_area - 8.3249%
# x_coordinate - 0.9966%
# y_coordinate - 0.9966%
# latitude - 0.9966%
# longitude - 0.9966%
# location - 0.9966%

# %%
# Null values based on years
per_missing_values_years(df1)
# Out:
# 2001
# location_description - 0.0001%
# ward - 6.5351%
# community_area - 6.5082%
# x_coordinate - 0.0398%
# y_coordinate - 0.0398%
# latitude - 0.0398%
# longitude - 0.0398%
# location - 0.0398%
#
# 2002
# location_description - 0.0001%
# ward - 1.8063%
# community_area - 1.7999%
# x_coordinate - 0.2068%
# y_coordinate - 0.2068%
# latitude - 0.2068%
# longitude - 0.2068%
# location - 0.2068%
#
# 2003
# location_description - 0.0001%
# ward - 0.0003%
# community_area - 0.0007%
# x_coordinate - 0.0533%
# y_coordinate - 0.0533%
# latitude - 0.0533%
# longitude - 0.0533%
# location - 0.0533%
#
# 2004
# location_description - 0.0002%
# district - 0.0%
# ward - 0.0003%
# community_area - 0.0009%
# x_coordinate - 0.0299%
# y_coordinate - 0.0299%
# latitude - 0.0299%
# longitude - 0.0299%
# location - 0.0299%
#
# 2005
# location_description - 0.0002%
# district - 0.0%
# ward - 0.0%
# community_area - 0.0007%
# x_coordinate - 0.052%
# y_coordinate - 0.052%
# latitude - 0.052%
# longitude - 0.052%
# location - 0.052%
#
# 2006
# location_description - 0.0002%
# district - 0.0%
# ward - 0.0%
# community_area - 0.0007%
# x_coordinate - 0.0353%
# y_coordinate - 0.0353%
# latitude - 0.0353%
# longitude - 0.0353%
# location - 0.0353%
#
# 2007
# location_description - 0.0002%
# district - 0.0%
# ward - 0.0001%
# community_area - 0.0021%
# x_coordinate - 0.0186%
# y_coordinate - 0.0186%
# latitude - 0.0186%
# longitude - 0.0186%
# location - 0.0186%
#
# 2008
# location_description - 0.0005%
# district - 0.0005%
# ward - 0.0001%
# community_area - 0.0033%
# x_coordinate - 0.0962%
# y_coordinate - 0.0962%
# latitude - 0.0962%
# longitude - 0.0962%
# location - 0.0962%
#
# 2009
# case_number - 0.0%
# location_description - 0.0007%
# ward - 0.0%
# community_area - 0.003%
# x_coordinate - 0.0915%
# y_coordinate - 0.0915%
# latitude - 0.0915%
# longitude - 0.0915%
# location - 0.0915%
#
# 2010
# case_number - 0.0%
# location_description - 0.0009%
# ward - 0.0002%
# community_area - 0.0025%
# x_coordinate - 0.0058%
# y_coordinate - 0.0058%
# latitude - 0.0058%
# longitude - 0.0058%
# location - 0.0058%
#
# 2011
# location_description - 0.004%
# ward - 0.0002%
# community_area - 0.0025%
# x_coordinate - 0.0081%
# y_coordinate - 0.0081%
# latitude - 0.0081%
# longitude - 0.0081%
# location - 0.0081%
#
# 2012
# case_number - 0.0%
# location_description - 0.0061%
# ward - 0.0001%
# community_area - 0.0004%
# x_coordinate - 0.0099%
# y_coordinate - 0.0099%
# latitude - 0.0099%
# longitude - 0.0099%
# location - 0.0099%
#
# 2013
# location_description - 0.0028%
# ward - 0.0%
# community_area - 0.0001%
# x_coordinate - 0.0137%
# y_coordinate - 0.0137%
# latitude - 0.0137%
# longitude - 0.0137%
# location - 0.0137%
#
# 2014
# location_description - 0.0051%
# ward - 0.0%
# x_coordinate - 0.0258%
# y_coordinate - 0.0258%
# latitude - 0.0258%
# longitude - 0.0258%
# location - 0.0258%
#
# 2015
# location_description - 0.0076%
# ward - 0.0%
# x_coordinate - 0.0902%
# y_coordinate - 0.0902%
# latitude - 0.0902%
# longitude - 0.0902%
# location - 0.0902%
#
# 2016
# location_description - 0.017%
# x_coordinate - 0.0319%
# y_coordinate - 0.0319%
# latitude - 0.0319%
# longitude - 0.0319%
# location - 0.0319%
#
# 2017
# location_description - 0.017%
# district - 0.0%
# ward - 0.0%
# x_coordinate - 0.0529%
# y_coordinate - 0.0529%
# latitude - 0.0529%
# longitude - 0.0529%
# location - 0.0529%
#
# 2018
# location_description - 0.0139%
# ward - 0.0001%
# x_coordinate - 0.0675%
# y_coordinate - 0.0675%
# latitude - 0.0675%
# longitude - 0.0675%
# location - 0.0675%
#
# 2019
# location_description - 0.0159%
# ward - 0.0002%
# x_coordinate - 0.022%
# y_coordinate - 0.022%
# latitude - 0.022%
# longitude - 0.022%
# location - 0.022%
#
# 2020
# location_description - 0.0164%
# ward - 0.0001%
# community_area - 0.0%
# x_coordinate - 0.0361%
# y_coordinate - 0.0361%
# latitude - 0.0361%
# longitude - 0.0361%
# location - 0.0361%
#
# 2021
# location_description - 0.0053%
# ward - 0.0001%
# x_coordinate - 0.0094%
# y_coordinate - 0.0094%
# latitude - 0.0094%
# longitude - 0.0094%
# location - 0.0094%

# %%
# Total count of null values
count_missing_values_years(df)
# Out:
# 2001
# id                           0
# case_number                  0
# date                         0
# block                        0
# iucr                         0
# primary_type                 0
# description                  0
# location_description         4
# arrest                       0
# domestic                     0
# beat                         0
# district                     0
# ward                    481586
# community_area          479607
# fbi_code                     0
# x_coordinate              2932
# y_coordinate              2932
# year                         0
# updated_on                   0
# latitude                  2932
# longitude                 2932
# location                  2932
# day                          0
# month                        0
# day_of_week                  0
# time                         0
# dtype: int64
#
# 2002
# id                           0
# case_number                  0
# date                         0
# block                        0
# iucr                         0
# primary_type                 0
# description                  0
# location_description         5
# arrest                       0
# domestic                     0
# beat                         0
# district                     0
# ward                    133112
# community_area          132639
# fbi_code                     0
# x_coordinate             15243
# y_coordinate             15243
# year                         0
# updated_on                   0
# latitude                 15243
# longitude                15243
# location                 15243
# day                          0
# month                        0
# day_of_week                  0
# time                         0
# dtype: int64
#
# 2003
# id                         0
# case_number                0
# date                       0
# block                      0
# iucr                       0
# primary_type               0
# description                0
# location_description       4
# arrest                     0
# domestic                   0
# beat                       0
# district                   0
# ward                      19
# community_area            48
# fbi_code                   0
# x_coordinate            3928
# y_coordinate            3928
# year                       0
# updated_on                 0
# latitude                3928
# longitude               3928
# location                3928
# day                        0
# month                      0
# day_of_week                0
# time                       0
# dtype: int64
#
# 2004
# id                         0
# case_number                0
# date                       0
# block                      0
# iucr                       0
# primary_type               0
# description                0
# location_description      14
# arrest                     0
# domestic                   0
# beat                       0
# district                   2
# ward                      22
# community_area            66
# fbi_code                   0
# x_coordinate            2205
# y_coordinate            2205
# year                       0
# updated_on                 0
# latitude                2205
# longitude               2205
# location                2205
# day                        0
# month                      0
# day_of_week                0
# time                       0
# dtype: int64
#
# 2005
# id                         0
# case_number                0
# date                       0
# block                      0
# iucr                       0
# primary_type               0
# description                0
# location_description      17
# arrest                     0
# domestic                   0
# beat                       0
# district                   1
# ward                       1
# community_area            54
# fbi_code                   0
# x_coordinate            3830
# y_coordinate            3830
# year                       0
# updated_on                 0
# latitude                3830
# longitude               3830
# location                3830
# day                        0
# month                      0
# day_of_week                0
# time                       0
# dtype: int64
#
# 2006
# id                         0
# case_number                0
# date                       0
# block                      0
# iucr                       0
# primary_type               0
# description                0
# location_description      15
# arrest                     0
# domestic                   0
# beat                       0
# district                   1
# ward                       3
# community_area            49
# fbi_code                   0
# x_coordinate            2600
# y_coordinate            2600
# year                       0
# updated_on                 0
# latitude                2600
# longitude               2600
# location                2600
# day                        0
# month                      0
# day_of_week                0
# time                       0
# dtype: int64
#
# 2007
# id                         0
# case_number                0
# date                       0
# block                      0
# iucr                       0
# primary_type               0
# description                0
# location_description      18
# arrest                     0
# domestic                   0
# beat                       0
# district                   2
# ward                       5
# community_area           158
# fbi_code                   0
# x_coordinate            1368
# y_coordinate            1368
# year                       0
# updated_on                 0
# latitude                1368
# longitude               1368
# location                1368
# day                        0
# month                      0
# day_of_week                0
# time                       0
# dtype: int64
#
# 2008
# id                         0
# case_number                0
# date                       0
# block                      0
# iucr                       0
# primary_type               0
# description                0
# location_description      36
# arrest                     0
# domestic                   0
# beat                       0
# district                  40
# ward                       4
# community_area           243
# fbi_code                   0
# x_coordinate            7092
# y_coordinate            7092
# year                       0
# updated_on                 0
# latitude                7092
# longitude               7092
# location                7092
# day                        0
# month                      0
# day_of_week                0
# time                       0
# dtype: int64
#
# 2009
# id                         0
# case_number                2
# date                       0
# block                      0
# iucr                       0
# primary_type               0
# description                0
# location_description      48
# arrest                     0
# domestic                   0
# beat                       0
# district                   0
# ward                       3
# community_area           219
# fbi_code                   0
# x_coordinate            6740
# y_coordinate            6740
# year                       0
# updated_on                 0
# latitude                6740
# longitude               6740
# location                6740
# day                        0
# month                      0
# day_of_week                0
# time                       0
# dtype: int64
#
# 2010
# id                        0
# case_number               1
# date                      0
# block                     0
# iucr                      0
# primary_type              0
# description               0
# location_description     68
# arrest                    0
# domestic                  0
# beat                      0
# district                  0
# ward                     18
# community_area          186
# fbi_code                  0
# x_coordinate            427
# y_coordinate            427
# year                      0
# updated_on                0
# latitude                427
# longitude               427
# location                427
# day                       0
# month                     0
# day_of_week               0
# time                      0
# dtype: int64
#
# 2011
# id                        0
# case_number               0
# date                      0
# block                     0
# iucr                      0
# primary_type              0
# description               0
# location_description    296
# arrest                    0
# domestic                  0
# beat                      0
# district                  0
# ward                     14
# community_area          181
# fbi_code                  0
# x_coordinate            600
# y_coordinate            600
# year                      0
# updated_on                0
# latitude                600
# longitude               600
# location                600
# day                       0
# month                     0
# day_of_week               0
# time                      0
# dtype: int64
#
# 2012
# id                        0
# case_number               1
# date                      0
# block                     0
# iucr                      0
# primary_type              0
# description               0
# location_description    453
# arrest                    0
# domestic                  0
# beat                      0
# district                  0
# ward                      7
# community_area           26
# fbi_code                  0
# x_coordinate            731
# y_coordinate            731
# year                      0
# updated_on                0
# latitude                731
# longitude               731
# location                731
# day                       0
# month                     0
# day_of_week               0
# time                      0
# dtype: int64
#
# 2013
# id                         0
# case_number                0
# date                       0
# block                      0
# iucr                       0
# primary_type               0
# description                0
# location_description     204
# arrest                     0
# domestic                   0
# beat                       0
# district                   0
# ward                       3
# community_area             4
# fbi_code                   0
# x_coordinate            1006
# y_coordinate            1006
# year                       0
# updated_on                 0
# latitude                1006
# longitude               1006
# location                1006
# day                        0
# month                      0
# day_of_week                0
# time                       0
# dtype: int64
#
# 2014
# id                         0
# case_number                0
# date                       0
# block                      0
# iucr                       0
# primary_type               0
# description                0
# location_description     376
# arrest                     0
# domestic                   0
# beat                       0
# district                   0
# ward                       2
# community_area             0
# fbi_code                   0
# x_coordinate            1902
# y_coordinate            1902
# year                       0
# updated_on                 0
# latitude                1902
# longitude               1902
# location                1902
# day                        0
# month                      0
# day_of_week                0
# time                       0
# dtype: int64
#
# 2015
# id                         0
# case_number                0
# date                       0
# block                      0
# iucr                       0
# primary_type               0
# description                0
# location_description     561
# arrest                     0
# domestic                   0
# beat                       0
# district                   0
# ward                       2
# community_area             0
# fbi_code                   0
# x_coordinate            6649
# y_coordinate            6649
# year                       0
# updated_on                 0
# latitude                6649
# longitude               6649
# location                6649
# day                        0
# month                      0
# day_of_week                0
# time                       0
# dtype: int64
#
# 2016
# id                         0
# case_number                0
# date                       0
# block                      0
# iucr                       0
# primary_type               0
# description                0
# location_description    1252
# arrest                     0
# domestic                   0
# beat                       0
# district                   0
# ward                       0
# community_area             0
# fbi_code                   0
# x_coordinate            2348
# y_coordinate            2348
# year                       0
# updated_on                 0
# latitude                2348
# longitude               2348
# location                2348
# day                        0
# month                      0
# day_of_week                0
# time                       0
# dtype: int64
#
# 2017
# id                         0
# case_number                0
# date                       0
# block                      0
# iucr                       0
# primary_type               0
# description                0
# location_description    1252
# arrest                     0
# domestic                   0
# beat                       0
# district                   1
# ward                       1
# community_area             0
# fbi_code                   0
# x_coordinate            3896
# y_coordinate            3896
# year                       0
# updated_on                 0
# latitude                3896
# longitude               3896
# location                3896
# day                        0
# month                      0
# day_of_week                0
# time                       0
# dtype: int64
#
# 2018
# id                         0
# case_number                0
# date                       0
# block                      0
# iucr                       0
# primary_type               0
# description                0
# location_description    1022
# arrest                     0
# domestic                   0
# beat                       0
# district                   0
# ward                       4
# community_area             0
# fbi_code                   0
# x_coordinate            4972
# y_coordinate            4972
# year                       0
# updated_on                 0
# latitude                4972
# longitude               4972
# location                4972
# day                        0
# month                      0
# day_of_week                0
# time                       0
# dtype: int64
#
# 2019
# id                         0
# case_number                0
# date                       0
# block                      0
# iucr                       0
# primary_type               0
# description                0
# location_description    1172
# arrest                     0
# domestic                   0
# beat                       0
# district                   0
# ward                      15
# community_area             0
# fbi_code                   0
# x_coordinate            1618
# y_coordinate            1618
# year                       0
# updated_on                 0
# latitude                1618
# longitude               1618
# location                1618
# day                        0
# month                      0
# day_of_week                0
# time                       0
# dtype: int64
#
# 2020
# id                         0
# case_number                0
# date                       0
# block                      0
# iucr                       0
# primary_type               0
# description                0
# location_description    1206
# arrest                     0
# domestic                   0
# beat                       0
# district                   0
# ward                       9
# community_area             1
# fbi_code                   0
# x_coordinate            2659
# y_coordinate            2659
# year                       0
# updated_on                 0
# latitude                2659
# longitude               2659
# location                2659
# day                        0
# month                      0
# day_of_week                0
# time                       0
# dtype: int64
#
# 2021
# id                        0
# case_number               0
# date                      0
# block                     0
# iucr                      0
# primary_type              0
# description               0
# location_description    387
# arrest                    0
# domestic                  0
# beat                      0
# district                  0
# ward                      7
# community_area            0
# fbi_code                  0
# x_coordinate            695
# y_coordinate            695
# year                      0
# updated_on                0
# latitude                695
# longitude               695
# location                695
# day                       0
# month                     0
# day_of_week               0
# time                      0
# dtype: int64

# %%
df1[['x_coordinate', 'y_coordinate', 'latitude', 'longitude', 'block', 'location']].head()
# Out:
#    x_coordinate  y_coordinate   latitude  longitude                  block  \
# 0     1165074.0     1875917.0  41.815117 -87.670000        043XX S WOOD ST
# 1     1138875.0     1904869.0  41.895080 -87.765400    008XX N CENTRAL AVE
# 2           NaN           NaN        NaN        NaN  082XX S INGLESIDE AVE
# 3     1152037.0     1920384.0  41.937406 -87.716650      035XX W BARRY AVE
# 4     1141706.0     1900086.0  41.881903 -87.755121    0000X N LARAMIE AVE
#
#                         location
# 0  (41.815117282, -87.669999562)
# 1  (41.895080471, -87.765400451)
# 2                            NaN
# 3  (41.937405765, -87.716649687)
# 4  (41.881903443, -87.755121152)

# %%
df1['location_description'].unique()
# Out:
# array(['RESIDENCE', 'CTA BUS', 'SIDEWALK', 'APARTMENT',
#        'RESIDENCE-GARAGE', 'GROCERY FOOD STORE', 'STREET', nan,
#        'PARKING LOT/GARAGE(NON.RESID.)', 'SMALL RETAIL STORE', 'OTHER',
#        'VEHICLE NON-COMMERCIAL', 'RESTAURANT', 'RESIDENCE PORCH/HALLWAY',
#        'ALLEY', 'POLICE FACILITY/VEH PARKING LOT', 'LIBRARY',
#        'ATHLETIC CLUB', 'DRUG STORE', 'PARK PROPERTY',
#        'CHA PARKING LOT/GROUNDS', 'NURSING HOME/RETIREMENT HOME',
#        'DRIVEWAY - RESIDENTIAL', 'RESIDENTIAL YARD (FRONT/BACK)',
#        'COMMERCIAL / BUSINESS OFFICE', 'DEPARTMENT STORE', 'HOTEL/MOTEL',
#        'GAS STATION', 'BAR OR TAVERN',
#        'CHURCH/SYNAGOGUE/PLACE OF WORSHIP', 'SPORTS ARENA/STADIUM',
#        'CONSTRUCTION SITE', 'HOSPITAL BUILDING/GROUNDS', 'CTA STATION',
#        'TAVERN/LIQUOR STORE', 'CHA HALLWAY/STAIRWELL/ELEVATOR',
#        'CONVENIENCE STORE', 'WAREHOUSE', 'VACANT LOT/LAND',
#        'CTA BUS STOP', 'CHA APARTMENT', 'TAXICAB', 'CTA TRAIN',
#        'APPLIANCE STORE', 'BARBERSHOP', 'BANK', 'SCHOOL, PUBLIC, GROUNDS',
#        'FACTORY/MANUFACTURING BUILDING', 'CAR WASH',
#        'CTA GARAGE / OTHER PROPERTY', 'OTHER (SPECIFY)',
#        'DAY CARE CENTER', 'SCHOOL, PUBLIC, BUILDING',
#        'AIRPORT TERMINAL UPPER LEVEL - SECURE AREA',
#        'JAIL / LOCK-UP FACILITY', 'SCHOOL, PRIVATE, BUILDING',
#        'AIRPORT BUILDING NON-TERMINAL - SECURE AREA',
#        'VEHICLE-COMMERCIAL', 'ABANDONED BUILDING',
#        'GOVERNMENT BUILDING/PROPERTY',
#        'AIRPORT TERMINAL UPPER LEVEL - NON-SECURE AREA',
#        'COLLEGE/UNIVERSITY GROUNDS', 'CTA PLATFORM',
#        'AIRPORT TERMINAL LOWER LEVEL - NON-SECURE AREA',
#        'ANIMAL HOSPITAL', 'AUTO / BOAT / RV DEALERSHIP',
#        'OTHER RAILROAD PROP / TRAIN DEPOT', 'POOL ROOM',
#        'VEHICLE - OTHER RIDE SERVICE',
#        'AIRPORT TERMINAL LOWER LEVEL - SECURE AREA',
#        'AIRPORT VENDING ESTABLISHMENT', 'BOAT/WATERCRAFT',
#        'AIRPORT EXTERIOR - SECURE AREA', 'ATM (AUTOMATIC TELLER MACHINE)',
#        'AIRCRAFT', 'OTHER COMMERCIAL TRANSPORTATION',
#        'MEDICAL/DENTAL OFFICE', 'CURRENCY EXCHANGE',
#        'AIRPORT PARKING LOT', 'AIRPORT EXTERIOR - NON-SECURE AREA',
#        'AIRPORT/AIRCRAFT',
#        'VEHICLE - OTHER RIDE SHARE SERVICE (E.G., UBER, LYFT)',
#        'AIRPORT BUILDING NON-TERMINAL - NON-SECURE AREA',
#        'CLEANING STORE', 'AIRPORT TERMINAL MEZZANINE - NON-SECURE AREA',
#        'FIRE STATION', 'SCHOOL, PRIVATE, GROUNDS', 'FOREST PRESERVE',
#        'AIRPORT TRANSPORTATION SYSTEM (ATS)', 'PAWN SHOP', 'CREDIT UNION',
#        'PARKING LOT / GARAGE (NON RESIDENTIAL)', 'MOVIE HOUSE/THEATER',
#        'SAVINGS AND LOAN', 'POLICE FACILITY / VEHICLE PARKING LOT',
#        'VACANT LOT', 'COLLEGE/UNIVERSITY RESIDENCE HALL',
#        'HIGHWAY/EXPRESSWAY', 'CTA TRACKS - RIGHT OF WAY',
#        'VEHICLE - COMMERCIAL', 'BRIDGE', 'HOUSE',
#        'LAKEFRONT/WATERFRONT/RIVERBANK', 'VEHICLE - DELIVERY TRUCK',
#        'COIN OPERATED MACHINE', 'FEDERAL BUILDING', 'BOWLING ALLEY',
#        'NEWSSTAND', 'RESIDENCE - GARAGE', 'HOSPITAL BUILDING / GROUNDS',
#        'RESIDENCE - PORCH / HALLWAY',
#        'CHA HALLWAY / STAIRWELL / ELEVATOR',
#        'VEHICLE - OTHER RIDE SHARE SERVICE (LYFT, UBER, ETC.)',
#        'VACANT LOT / LAND', 'RESIDENCE - YARD (FRONT / BACK)',
#        'FACTORY / MANUFACTURING BUILDING', 'SCHOOL - PUBLIC BUILDING',
#        'MOVIE HOUSE / THEATER', 'CHA PARKING LOT / GROUNDS',
#        'HOTEL / MOTEL', 'AUTO', 'NURSING / RETIREMENT HOME', 'CEMETARY',
#        'GOVERNMENT BUILDING / PROPERTY', 'CHA HALLWAY',
#        'SCHOOL - PRIVATE BUILDING', 'CHA GROUNDS', 'PARKING LOT', 'YARD',
#        'COUNTY JAIL', 'PORCH', 'CHURCH / SYNAGOGUE / PLACE OF WORSHIP',
#        'OTHER RAILROAD PROPERTY / TRAIN DEPOT', 'TAVERN / LIQUOR STORE',
#        'GANGWAY', 'LAKEFRONT / WATERFRONT / RIVERBANK', 'STAIRWELL',
#        'TAVERN', 'MEDICAL / DENTAL OFFICE', 'HALLWAY',
#        'SCHOOL - PUBLIC GROUNDS', 'COACH HOUSE',
#        'VEHICLE-COMMERCIAL - TROLLEY BUS',
#        'VEHICLE-COMMERCIAL - ENTERTAINMENT/PARTY BUS', 'HORSE STABLE',
#        'FARM', 'COLLEGE / UNIVERSITY - GROUNDS', 'DUMPSTER',
#        'SCHOOL - PRIVATE GROUNDS', 'SPORTS ARENA / STADIUM',
#        'COLLEGE / UNIVERSITY - RESIDENCE HALL', 'KENNEL', 'BASEMENT',
#        'CTA PARKING LOT / GARAGE / OTHER PROPERTY',
#        'HIGHWAY / EXPRESSWAY', 'GARAGE/AUTO REPAIR', 'DELIVERY TRUCK',
#        'CHURCH', 'CHA BREEZEWAY', 'CHA PARKING LOT', 'CHA STAIRWELL',
#        'CHURCH PROPERTY', 'CLUB', 'CHA ELEVATOR', 'SEWER',
#        'LIVERY STAND OFFICE', 'WOODED AREA', 'PRAIRIE', 'CHA LOBBY',
#        'DRIVEWAY', 'TRUCK',
#        'VEHICLE - COMMERCIAL: ENTERTAINMENT / PARTY BUS', 'RETAIL STORE',
#        'PUBLIC GRAMMAR SCHOOL', 'RIVER', 'GARAGE',
#        'JUNK YARD/GARBAGE DUMP', 'VESTIBULE', 'FUNERAL PARLOR', 'OFFICE',
#        'GAS STATION DRIVE/PROP.', 'PUBLIC HIGH SCHOOL', 'TAXI CAB',
#        'RIVER BANK', 'NURSING HOME', 'BARBER SHOP/BEAUTY SALON', 'HOTEL',
#        'RAILROAD PROPERTY', 'LIQUOR STORE', 'MOTEL', 'LAKE',
#        'CTA "L" PLATFORM', 'CHA PLAY LOT', 'SCHOOL YARD', 'ELEVATOR',
#        'POOLROOM', 'CLEANERS/LAUNDROMAT', 'EXPRESSWAY EMBANKMENT',
#        'HOSPITAL', 'CTA "L" TRAIN', 'GOVERNMENT BUILDING', 'LAGOON',
#        'TRUCKING TERMINAL', 'CTA PROPERTY', 'ROOMING HOUSE', 'FACTORY',
#        'YMCA', 'TRAILER', 'LAUNDRY ROOM', 'LIVERY AUTO', 'BANQUET HALL',
#        'LOADING DOCK', 'CTA SUBWAY STATION', 'BOAT / WATERCRAFT',
#        'VEHICLE - COMMERCIAL: TROLLEY BUS'], dtype=object)

# %% [markdown]
# ## Initial Pre-processing

# %% [markdown]
# - Feature engineered new columns based on dates

# %%
# Check duplicate data
df.duplicated().sum()
# Out:
# 0

# %%
# Check date incident occured and last updated on
df[['date', 'updated_on']].head()
# Out:
#                      date              updated_on
# 0  09/05/2015 01:30:00 PM  02/10/2018 03:50:01 PM
# 1  09/04/2015 11:30:00 AM  02/10/2018 03:50:01 PM
# 2  09/01/2018 12:01:00 AM  04/06/2019 04:04:43 PM
# 3  09/05/2015 12:45:00 PM  02/10/2018 03:50:01 PM
# 4  09/05/2015 01:00:00 PM  02/10/2018 03:50:01 PM

# %%
# Change 'date' to datetime dtype
df['date'] = pd.to_datetime(df['date'])
df['date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
# Create new columns daty, month, time
df['day'] = df['date'].apply(lambda x: x.day)
df['month'] = df['date'].apply(lambda x: x.month)
df['day_of_week'] = df['date'].apply(lambda x: x.dayofweek)
df['time'] = df['date'].apply(lambda x: x.strftime("%H"))

# %%
# Checking date breakdown 
df[['date', 'day', 'month', 'year', 'day_of_week', 'time']].head()
# Out:
#                  date  day  month  year  day_of_week time
# 0 2015-09-05 13:30:00    5      9  2015            5   13
# 1 2015-09-04 11:30:00    4      9  2015            4   11
# 2 2018-09-01 00:01:00    1      9  2018            5   00
# 3 2015-09-05 12:45:00    5      9  2015            5   12
# 4 2015-09-05 13:00:00    5      9  2015            5   13

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7369258 entries, 0 to 7369257
# Data columns (total 26 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id                    int64
#  1   case_number           object
#  2   date                  datetime64[ns]
#  3   block                 object
#  4   iucr                  object
#  5   primary_type          object
#  6   description           object
#  7   location_description  object
#  8   arrest                bool
#  9   domestic              bool
#  10  beat                  int64
#  11  district              float64
#  12  ward                  float64
#  13  community_area        float64
#  14  fbi_code              object
#  15  x_coordinate          float64
#  16  y_coordinate          float64
#  17  year                  int64
#  18  updated_on            object
#  19  latitude              float64
#  20  longitude             float64
#  21  location              object
#  22  day                   int64
#  23  month                 int64
#  24  day_of_week           int64
#  25  time                  object
# dtypes: bool(2), datetime64[ns](1), float64(7), int64(6), object(10)
# memory usage: 1.3+ GB

# %%
df1 = df.copy()

# %% [markdown]
# # Cleaning & Transform Chicago Crime Data (2021 - 2010)

# %% [markdown]
# ## Filter & Divide Data (Individual Year)

# %% [markdown]
# - Due to the large raw dataset and computationally heavy, data was separated into individual year and transform before combining it together into 1 data set

# %%
# Filter dataset  based on year >= 2010
df_ten = df1[df1['year'] >= 2010]
df_ten.reset_index()
sorted(df_ten['year'].unique())
# Out:
# [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]

# %%
df_ten.to_csv('drive/MyDrive/Colab Notebooks/capstone/assets/ten_years_crime.csv', index=False)

# %%
# Function - filter based on individual year and save as csv
def filter_data_year(year):
  df_filter_year = df1[df1['year'] == year]
  df_filter_year.reset_index()

  df_filter_year.to_csv(f'drive/MyDrive/Colab Notebooks/capstone/assets/{year}_crime.csv', index=False)

# %%
year_list = sorted(df_ten['year'].unique())

for yr in year_list:
  filter_data_year(yr)

print ('Successfully converted!')
# Out:
# Successfully converted!

# %% [markdown]
# ## Cleaning Functions

# %%
# 1) Function - replace null values to 0 for latitude, longitude and location
def replace_to_zero(df):
  df['latitude'].fillna(0, inplace=True)
  df['longitude'].fillna(0, inplace=True)
  df['location'].fillna(0, inplace=True)

# -----------------------------------------------------------------------------
# 2) Function - list of rows for missing datas (location)
def missing_row_loc(df):
  count = 0
  index_list = []

  for index, values in enumerate(df['location']):
    if values == 0:
      count += 1
      index_list.append(index)
  
  print (count)
  return index_list

# -----------------------------------------------------------------------------
# 3) Function - clean first 5 digit in block
def clean_data(text):
    text = re.sub(r'[0-9]{3}[a-zA-Z0-9]{2}[\s]{1}', '', text)
    return text

# -----------------------------------------------------------------------------
# 4) Function - impute latitude, longitude and location
def impute_data(df, index_list):
  print (index_list)
  print('')

  for index in index_list:
    processed_data = clean_data(str(df['block'].loc[index]))
    print (processed_data)

    g = geocoder.geocode(processed_data, timeout=10000)
    
    try:
      df.loc[index, 'latitude'] = g.latitude
      df.loc[index, 'longitude'] = g.longitude
      df.loc[index, 'location'] = f'({g.latitude}, {g.longitude})'

      print (df.loc[index, 'location'])
      print ('')
    except:
      df.loc[index, 'latitude'] = np.nan
      df.loc[index, 'longitude'] = np.nan
      df.loc[index, 'location'] = np.nan
  
# -----------------------------------------------------------------------------
# 5) Function - impute new values for ward

# Ref: https://stackoverflow.com/questions/61172069/extract-polygon-name-if-the-geo-point-is-inside-polygon
# Due to the update in boundaries, initial ward stated in the dataset is based on the time the crime is commited hence we will have to update the ward based on present date

def impute_ward(df):
  # Polygon Data (GeoDataFrame)
  data_poly = gpd.read_file('/content/drive/MyDrive/Colab Notebooks/capstone/assets/ward.geojson')

  # Readonly the required columns 
  # Drop NAN

  #convert dataframe to geodatframe
  gdf = gpd.GeoDataFrame(
      df, geometry=gpd.points_from_xy(df['longitude'], df['latitude']))

  #Output
  ward_gdf = gpd.sjoin(gdf, data_poly[['geometry', 'ward']], op='within')

  return ward_gdf

# -----------------------------------------------------------------------------
# 6) Function - impute new values for community_area

# Ref: https://stackoverflow.com/questions/61172069/extract-polygon-name-if-the-geo-point-is-inside-polygon
# Due to the update in boundaries, initial ward stated in the dataset is based on the time the crime is commited hence we will have to update the ward based on present date

def impute_commareas(df):
  # Polygon Data (GeoDataFrame)
  data_poly = gpd.read_file('/content/drive/MyDrive/Colab Notebooks/capstone/assets/comm_areas.geojson')

  # Readonly the required columns 
  # Drop NAN

  #convert dataframe to geodatframe
  gdf = gpd.GeoDataFrame(
      df, geometry=gpd.points_from_xy(df['longitude'], df['latitude']))

  #Output
  commarea_gdf = gpd.sjoin(gdf, data_poly[['geometry', 'area_numbe']], op='within')

  return commarea_gdf

# -----------------------------------------------------------------------------
# 7) Function - impute new values for district

# Ref: https://stackoverflow.com/questions/61172069/extract-polygon-name-if-the-geo-point-is-inside-polygon
# Due to the update in boundaries, initial ward stated in the dataset is based on the time the crime is commited hence we will have to update the ward based on present date

def impute_district(df):
  # Polygon Data (GeoDataFrame)
  data_poly = gpd.read_file('/content/drive/MyDrive/Colab Notebooks/capstone/assets/district.geojson')

  # Readonly the required columns 
  # Drop NAN

  #convert dataframe to geodatframe
  gdf = gpd.GeoDataFrame(
      df, geometry=gpd.points_from_xy(df['longitude'], df['latitude']))

  #Output
  district_gdf = gpd.sjoin(gdf, data_poly[['geometry', 'dist_num']], op='within')

  return district_gdf

# -----------------------------------------------------------------------------

# %% [markdown]
# ## Clean data (2021)

# %%
# from geopy.geocoders import Nominatim
geocoder = Nominatim(user_agent = 'crime_predictions')

# %%
df_2021 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/capstone/assets/2021_crime.csv')
df_2021.head()
# Out:
#          id case_number                 date                     block  iucr  \
# 0  12260346    JE102126  2021-01-03 13:23:00     070XX S EGGLESTON AVE  0486
# 1  12263464    JE105797  2021-01-03 06:59:00          080XX S YALE AVE  0820
# 2  12259990    JE101773  2021-01-03 00:20:00   056XX W WASHINGTON BLVD  0486
# 3  12260669    JE102509  2021-01-03 20:47:00        057XX S RACINE AVE  2022
# 4     25702    JE102438  2021-01-03 20:09:00  068XX S STONY ISLAND AVE  0110
#
#   primary_type              description location_description  arrest  \
# 0      BATTERY  DOMESTIC BATTERY SIMPLE            APARTMENT   False
# 1        THEFT           $500 AND UNDER            RESIDENCE   False
# 2      BATTERY  DOMESTIC BATTERY SIMPLE            APARTMENT   False
# 3    NARCOTICS        POSSESS - COCAINE               STREET    True
# 4     HOMICIDE      FIRST DEGREE MURDER               STREET   False
#
#    domestic  beat  district  ward  community_area fbi_code  x_coordinate  \
# 0      True   732       7.0   6.0            68.0      08B     1174496.0
# 1     False   623       6.0  17.0            44.0       06     1176011.0
# 2      True  1513      15.0  29.0            25.0      08B     1138722.0
# 3     False   713       7.0  16.0            67.0       18     1169298.0
# 4     False   332       3.0   5.0            43.0      01A     1188038.0
#
#    y_coordinate  year              updated_on   latitude  longitude  \
# 0     1858251.0  2021  01/16/2021 03:49:23 PM  41.766435 -87.635964
# 1     1851718.0  2021  01/16/2021 03:49:23 PM  41.748474 -87.630607
# 2     1900183.0  2021  01/16/2021 03:49:23 PM  41.882224 -87.766076
# 3     1866822.0  2021  01/16/2021 03:49:23 PM  41.790069 -87.654769
# 4     1860051.0  2021  01/10/2021 03:51:53 PM  41.771062 -87.586271
#
#                         location  day  month  day_of_week  time
# 0  (41.766435144, -87.635963997)    3      1            6    13
# 1  (41.748473982, -87.630606588)    3      1            6     6
# 2   (41.88222427, -87.766076162)    3      1            6     0
# 3   (41.79006908, -87.654768679)    3      1            6    20
# 4  (41.771062488, -87.586270811)    3      1            6    20

# %%
df_2021.isnull().sum()
# Out:
# id                        0
# case_number               0
# date                      0
# block                     0
# iucr                      0
# primary_type              0
# description               0
# location_description    387
# arrest                    0
# domestic                  0
# beat                      0
# district                  0
# ward                      7
# community_area            0
# fbi_code                  0
# x_coordinate            695
# y_coordinate            695
# year                      0
# updated_on                0
# latitude                695
# longitude               695
# location                695
# day                       0
# month                     0
# day_of_week               0
# time                      0
# dtype: int64

# %%
replace_to_zero(df_2021)

# %%
index_list = missing_row_loc(df_2021)
# Out:
# 695

# %%
impute_data(df_2021, index_list)
# Out:
# [9, 13, 15, 29, 31, 42, 46, 47, 62, 63, 66, 67, 68, 69, 70, 84, 85, 104, 108, 133, 140, 141, 142, 867, 868, 1300, 2972, 4483, 4569, 4946, 5023, 5188, 5241, 5373, 5486, 5497, 5572, 5704, 6067, 6138, 6216, 6247, 6431, 6640, 6740, 7059, 7656, 7866, 7990, 8182, 8237, 8279, 8468, 8526, 8564, 8581, 8726, 8820, 9018, 9230, 9231, 9487, 9543, 9628, 9695, 9790, 9806, 10027, 10195, 10238, 10627, 10764, 11182, 11238, 11350, 11564, 11844, 12069, 12151, 12190, 12237, 12238, 12266, 12357, 12372, 12444, 12485, 12535, 12789, 12969, 13082, 13127, 13478, 13514, 13860, 14039, 14505, 14572, 14644, 14656, 14733, 14766, 14822, 14852, 14882, 14917, 15254, 15264, 15846, 15850, 15951, 16033, 16538, 16711, 16738, 16751, 16847, 16851, 17462, 17826, 17859, 18062, 18075, 18119, 18149, 18286, 18288, 18289, 18297, 18306, 18614, 18744, 19819, 19928, 20235, 20370, 20680, 21135, 21312, 21941, 21945, 22225, 22255, 22304, 22341, 22494, 22649, 22679, 22820, 22958, 23508, 23675, 23844, 24181, 24407, 24747, 24972, 25116, 25207, 25626, 25764, 25800, 26002, 26045, 26099, 26279, 26416, 26441, 26487, 26530, 26567, 26592, 26924, 27037, 27594, 27601, 27753, 27900, 27982, 28029, 28047, 28301, 28408, 28671, 28958, 29123, 29207, 29417, 29627, 29705, 29794, 29933, 30276, 30345, 30373, 30474, 30779, 30847, 31006, 31304, 31537, 31896, 32230, 32419, 32453, 32615, 32620, 32947, 33182, 33432, 33433, 33885, 34280, 34311, 34368, 34478, 34588, 34932, 35048, 35280, 35355, 35411, 35482, 35592, 35687, 35907, 36736, 36788, 36897, 37305, 37440, 37506, 37569, 37589, 37624, 37679, 37710, 37785, 37846, 38040, 38069, 38175, 38336, 38612, 38635, 38737, 38769, 38814, 38888, 39064, 39414, 39465, 39708, 39752, 39977, 40441, 40456, 40789, 40948, 41073, 41525, 41643, 42045, 42200, 42511, 42539, 42947, 42957, 42958, 43265, 43350, 43416, 43425, 43426, 43534, 43607, 43637, 43742, 43915, 44091, 44187, 44401, 44492, 44799, 45158, 45554, 45955, 46196, 46368, 46437, 46668, 46998, 47162, 47171, 47618, 47987, 48188, 48349, 48918, 49470, 49544, 49733, 49843, 49993, 50017, 50059, 50282, 50359, 50491, 50532, 50567, 50591, 50620, 50732, 51122, 51565, 51618, 51651, 51665, 51686, 51728, 51875, 52266, 52286, 52564, 52777, 52778, 52867, 52887, 53286, 53647, 53675, 53748, 53760, 54012, 54076, 54134, 54167, 54546, 54561, 54578, 54770, 55012, 55069, 55181, 55338, 55565, 55673, 56242, 56715, 56800, 56876, 56981, 57017, 57090, 57150, 57188, 57497, 57727, 57786, 57925, 57939, 58360, 58406, 58801, 58988, 59044, 59135, 59858, 60134, 60179, 60321, 60371, 60614, 60729, 60797, 60843, 61401, 61588, 62013, 62230, 62418, 62495, 62505, 63274, 63356, 63476, 63644, 64137, 64227, 64242, 64281, 64305, 64538, 64567, 64627, 64670, 64741, 64831, 64848, 64911, 65010, 65046, 65198, 65227, 65356, 65436, 65491, 66550, 66995, 67314, 67605, 67724, 67762, 67977, 68064, 68155, 68272, 68325, 68561, 68630, 68725, 68801, 69167, 69216, 69277, 69295, 69429, 69544, 69784, 69881, 70521, 71045, 71168, 71393, 71478, 71740, 71892, 72245, 72479, 72504, 72551, 72615, 72676, 72896, 72909, 73065, 73161, 73196, 73201, 73376, 73413, 73430, 73485, 73503, 73539, 73541, 73542, 73675, 73915, 74029, 74216, 74339, 74397, 74414, 74614, 74663, 74674, 74764, 74840, 74923, 75180, 75244, 75250, 75258, 75644, 75687, 75884, 76304, 76325, 76379, 76400, 76586, 76641, 76721, 76769, 76908, 77338, 77397, 77407, 77540, 77648, 77779, 77813, 78022, 78023, 78054, 78508, 79900, 79971, 80085, 80087, 80094, 80424, 80430, 80483, 80541, 80566, 80746, 80838, 80873, 81013, 81052, 81440, 81480, 81831, 82031, 82043, 82193, 82232, 82435, 82656, 82684, 83189, 83344, 83378, 83530, 83607, 83656, 83670, 83811, 83925, 84055, 84294, 84479, 84562, 84563, 84574, 84577, 84582, 84792, 86040, 86095, 87034, 87067, 87068, 87425, 87442, 87590, 87649, 87791, 87897, 88122, 88252, 88340, 88515, 88812, 88825, 89113, 89137, 89469, 89735, 89828, 89882, 89954, 90049, 90073, 90103, 90354, 90714, 91059, 91492, 91566, 91635, 91716, 91782, 91952, 91955, 91976, 92221, 92420, 92480, 92545, 92615, 92642, 92785, 93355,  ...
#
# S Blackstone Ave
# (41.78726, -87.881703)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# W 14TH ST
# (40.7370431, -73.9960774)
#
# N WINTHROP AVE
# (41.9873032, -87.6581226)
#
# N NOTTINGHAM AVE
# (41.9489522, -87.8046875)
#
# S PRINCETON AVE
# (39.7884436, -75.1461365)
#
# W IOWA ST
# (43.0518372, -91.3949007)
#
# N WIELAND ST
# (41.9098507, -87.6356493)
#
# W LE MOYNE ST
# (41.9077136, -87.7331889)
#
# N BROADWAY
# (40.9696948, -73.8844801)
#
# W kinzie st
# (41.8891372, -87.6357356)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# N LEAVITT ST
# (39.531967, -87.136931)
#
# S STEWART AVE
# (28.290846, -81.4066339)
#
# N GREENVIEW AVE
# (42.2840502, -89.1311541)
#
# W Palmer St
# (35.1795946, -83.3858583)
#
# N Whipple St
# (41.9721178, -87.7049131)
#
# N RIDGE BLVD
# (38.5054097, -77.9726234)
#
# W ILLINOIS ST
# (41.862092, -88.108188)
#
# S California ave
# (34.1163848, -118.0008539)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# S BELL AVE
# (36.6728853, -120.1423994)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# N KEDZIE AVE
# (41.981245, -87.7088348)
#
# N ADA ST
# (34.536441, -96.208725)
#
# W ROSCOE ST
# (41.9417774, -87.798255)
#
# S canal st
# (42.1979758, -72.6021589)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# S CREGIER AVE
# (41.7663619, -87.5812232)
#
# E 93RD ST
# (40.7810314, -73.9454051)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# S LAKE SHORE DR SB
# W RUNWAY 1836
# (-43.5540671, 172.553635)
#
# N NOBLE ST
# (33.7944831, -117.8022079)
#
# N MC CLURG CT
# (30.332179, -82.799061)
#
# N WOLCOTT AVE
# (41.9069854, -87.6730408)
#
# W 78TH PL
# (41.4755863, -87.3774798)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# N CENTRAL PARK AVE
# (41.9751896, -87.7184185)
#
# S BEVERLY AVE
# (34.741893, -87.674971)
#
# N DRAKE AVE
# (41.9725027, -87.7171475)
#
# N ADA ST
# (34.536441, -96.208725)
#
# W WOLFRAM ST
# (41.9335036, -87.6563169)
#
# N ARTESIAN AVE
# (41.9254283, -87.6888852)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# N RICHMOND ST
# (41.9557758, -87.7019847)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# N CITY FRONT PLAZA DR
# (67.2833598, 14.3788028)
#
# W GRACE ST
# (37.5509972, -77.4531109)
#
# E 98TH ST
# (41.5353058, -87.4524707)
#
# W OHIO ST
# (40.646058, -83.609337)
#
# W SHERWIN AVE
# (42.0150507, -87.7786003)
#
# N CENTRAL AVE
# (35.7718102, -91.6557941)
#
# N CALIFORNIA AVE
# (33.9287659, -116.9813763)
#
# N HERMITAGE AVE
# (40.232782, -74.780752)
#
# W PRATT BLVD
# (42.0054657, -87.6658226)
#
# N HUMBOLDT BLVD
# (43.0638817, -87.8978425)
#
# N Talman Ave
# (41.9139404, -87.6934262)
#
# S LOCK ST
# (41.8412437, -87.6622108)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# W 21ST ST
# (44.961758, -93.306244)
#
# S CARPENTER ST
# (35.240268, -81.338339)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# N FREMONT ST
# (40.768691, -95.3850426)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# N BURLING ST
# (41.9148697, -87.6471899)
#
# N OAKLEY AVE
# (41.664195, -86.124499)
#
# S MUSEUM CAMPUS DR
# (41.8662155, -87.6137248)
#
# W FOSTER AVE
# (41.975528, -87.7281106)
#
# S GILES AVE
# (41.8310918, -87.6193367)
#
# W THORNDALE AVE
# (41.9885001, -87.7104758)
#
# N Milwaukee Ave
# (42.451391, -88.091261)
#
# N LOCKWOOD AVE
# (41.6979589, -83.5699941)
#
# N LINCOLN AVE
# (45.660956, -122.6824777)
#
# W ARDMORE AVE
# (41.9866299, -87.7144901)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# S KENNETH AVE
# (41.6814466, -87.7302028)
#
# N MARINE DR
# (33.8164549, -117.8300018)
#
# N Francisco Ave
# (26.2217801, -98.3199932)
#
# W BRADLEY PL
# (41.9501056, -87.6501801)
#
# E HURON ST
# (42.281291, -83.7369982)
#
# W HOMER ST
# (38.613178, -86.101403)
#
# W AUGUSTA BLVD
# (41.4210887, -87.732417)
#
# N KOLMAR AVE
# (41.9710894, -87.7440319)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# N PONTIAC AVE
# (31.233103, -85.4146803)
#
# W ALTGELD ST
# (41.9262007, -87.8075454)
#
# W ROSCOE ST
# (41.9417774, -87.798255)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# W CARMEN AVE
# (41.9736044, -87.7374367)
#
# W SWANN ST
# (41.8099363, -87.6295772)
#
# N OAK PARK AVE
# (41.9071844, -87.7950033)
#
# N FAIRFIELD AVE
# (40.417653, -120.640311)
#
# N WOLCOTT AVE
# (41.9069854, -87.6730408)
#
# W HARRISON ST
# (47.453523, -116.785825)
#
# N Winchester Ave
# (46.4110364, -105.830487)
#
# N WHIPPLE ST
# (41.9721178, -87.7049131)
#
# N ST LOUIS AVE
# (41.9727203, -87.7159449)
#
# S EUCLID AVE
# (43.5904697, -83.9155365)
#
# W GEORGE ST
# (55.8634318, -4.2657255)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# N Spaulding Ave
# (41.9543894, -87.7104772)
#
# W BARRY AVE
# (36.8175627, -93.9243727)
#
# N Greenview Ave
# (42.2840502, -89.1311541)
#
# N BEACON ST
# (41.4586084, -74.4140133)
#
# N OAKLEY AVE
# (41.664195, -86.124499)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# N ARTESIAN AVE
# (41.9254283, -87.6888852)
#
# S ST LAWRENCE AVE
# (41.7682281, -87.6104913)
#
# W DIVISION ST
# (38.2597099, -87.9979169)
#
# W ARTHINGTON ST
# (41.8700106, -87.7112288)
#
# N DAYTON ST
# (43.1198845, -85.5544939)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# N ROCKWELL ST
# (33.3744844, -111.7302071)
#
# N May St
# (35.6016763, -77.5898474)
#
# W 15TH ST
# (44.9689141, -93.2867103)
#
# W BEACH AVE
# (49.0253429, -122.8165082)
#
# W MELROSE ST
# (40.667262, -73.698695)
#
# N SPAULDING AVE
# (41.9543894, -87.7104772)
#
# W GRAND AVE
# (44.89992, -89.6139466)
#
# N WINTHROP AVE
# (41.9873032, -87.6581226)
#
# W THORNDALE AVE
# (41.9885001, -87.7104758)
#
# W 56TH PL
# (25.8734227, -80.3063357)
#
# W JARVIS AVE
# (42.0153543, -87.8050829)
#
# W FARWELL AVE
# (42.0067765, -87.6605207)
#
# N Humboldt Blvd
# (43.0638817, -87.8978425)
#
# W DIVERSEY PKWY
# (41.9323951, -87.6687745)
#
# N HOYNE AVE
# (41.9550717, -87.6812061)
#
# W CONGRESS PKWY
# (41.8750866, -87.6539866)
#
# W DAKIN ST
# (41.9516187, -87.7912726)
#
# W HARRISON ST
# (47.453523, -116.785825)
#
# S LOREL AVE
# (41.8037894, -87.7564931)
#
# S EMERALD AVE
# (33.3965996, -111.8035831)
#
# S BISHOP ST
# (39.5665983, -76.9892851)
#
# W FRY ST
# (41.8970425, -87.6643434)
#
# W TAYLOR ST
# (41.3837633, -75.7166377)
#
# W ADDISON ST
# (42.226415, -84.406033)
#
# W MELROSE ST
# (40.667262, -73.698695)
#
# N SPAULDING AVE
# (41.9543894, -87.7104772)
#
# W MONTROSE AVE
# (41.9607197, -87.7466474)
#
# N WINTHROP AVE
# (41.9873032, -87.6581226)
#
# N WAYNE AVE
# (40.055678, -75.393487)
#
# W IRVING PARK RD
# (41.953826, -87.7116755)
#
# N SPAULDING AVE
# (41.9543894, -87.7104772)
#
# N WHIPPLE ST
# (41.9721178, -87.7049131)
#
# N PEORIA
# (40.7175374, -89.5842635)
#
# N DAMEN AVE
# (41.9744669, -87.6793492)
#
# N LAVERGNE AVE
# (41.9090105, -87.9045527)
#
# W BERWYN AVE
# (41.9775394, -87.712376)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# N DAMEN AVE
# (41.9744669, -87.6793492)
#
# N STATE ST
# (44.619052, -75.408869)
#
# S HYDE PARK BLVD
# (41.7978073, -87.5840054)
#
# N Central Park Ave
# (41.9751896, -87.7184185)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# N MOHAWK ST
# (42.790293, -73.712513)
#
# N MC VICKER AVE
# (41.7720642, -87.7721541)
#
# N STATE ST
# (44.619052, -75.408869)
#
# N STATE ST
# (44.619052, -75.408869)
#
# N NEVA AVE
# (41.9100895, -87.8039791)
#
# W ROSEMONT AVE
# (38.8094493, -77.0631869)
#
# N NORTHCOTT AVE
# (41.9914919, -87.8022804)
#
# N SANDBURG TER
# (41.9110839, -87.6324747)
#
# S BALTIMORE AVE
# (40.083482, -74.040895)
#
# W CARMEN AVE
# (41.9736044, -87.7374367)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# W SUPERIOR ST
# (40.857308, -96.805534)
#
# W CONGRESS PKWY
# (41.8750866, -87.6539866)
#
# N MONITOR AVE
# (41.9791477, -87.7744717)
#
# W EASTWOOD AVE
# (41.9656467, -87.7297858)
#
# W LE MOYNE ST
# (41.9077136, -87.7331889)
#
# W FLETCHER ST
# (28.324413, -81.40576)
#
# E OAK ST
# (33.4730024, -111.9327122)
#
# N NASHVILLE AVE
# (33.172839, -86.245134)
#
# S RICHMOND ST
# (44.8899249, -88.3024977)
#
# N Natoma Ave
# (43.6443386, -116.4245855)
#
# W ROSCOE ST
# (41.9417774, -87.798255)
#
# N LAKEWOOD AVE
# (31.856847, -102.514627)
#
# W CORTEZ ST
# (33.5897649, -112.4664308)
#
# N WINTHROP AVE
# (41.9873032, -87.6581226)
#
# N LA SALLE DR
# (32.459967, -99.781336)
#
# N ALBANY AVE
# (40.7076835, -73.465108)
#
# S Dorchester Ave
# (41.861114, -88.126156)
#
# W Lake St
# (41.8877192, -87.7651226)
#
# W DIVERSEY PKWY
# (41.9323951, -87.6687745)
#
# N DAYTON ST
# (43.1198845, -85.5544939)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# W Grand Ave
# (44.89992, -89.6139466)
#
# W AINSLIE ST
# (41.9701978, -87.7164722)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# S LA SALLE ST
# (41.742861, -88.3242315)
#
# E 56TH ST
# (44.9015711, -93.2646052)
#
# W TERMINAL ST
# (38.3711643, -88.065751)
#
# W 83RD ST
# (41.7432634, -87.6499076)
#
# S ELIZABETH ST
# (40.727094, -84.106756)
#
# N BROADWAY
# (40.9696948, -73.8844801)
#
# W TERMINAL ST
# (38.3711643, -88.065751)
#
# W OHIO ST
# (40.646058, -83.609337)
#
# S Carpenter St
# (35.240268, -81.338339)
#
# W ROSCOE ST
# (41.9417774, -87.798255)
#
# N WOOD ST
# (32.3586259, -97.3959405)
#
# W LELAND AVE
# (41.9666512, -87.7370944)
#
# W SUPERIOR ST
# (40.857308, -96.805534)
#
# N ELSTON AVE
# (41.9624991, -87.731967)
#
# N STATE ST
# (44.619052, -75.408869)
#
# W WABANSIA AVE
# (41.9107882, -87.7995001)
#
# N PEORIA
# (40.7175374, -89.5842635)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# E DELAWARE PL
# (41.8992723, -87.6202196)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# S DREXEL AVE
# (33.369843, -111.623825)
#
# N Pulaski RD
# (41.9640877, -87.7278964)
#
# N WOLCOTT AVE
# (41.9069854, -87.6730408)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# S YATES BLVD
# (41.7408204, -87.5660877)
#
# S MUSEUM CAMPUS DR
# (41.8662155, -87.6137248)
#
# N DAMEN AVE
# (41.9744669, -87.6793492)
#
# N LAKEWOOD AVE
# (31.856847, -102.514627)
#
# S PULASKI RD
# (41.6803208, -87.7198931)
#
# S Constance Ave
# (39.1322267, -86.4965916)
#
# S MUSEUM CAMPUS DR
# (41.8662155, -87.6137248)
#
# E OHIO ST
# (40.601786, -84.084445)
#
# S PERRY AVE
# (27.74589, -81.794657)
#
# E OHIO ST
# (40.601786, -84.084445)
#
# S HARDING AVE
# (36.6834759, -119.7343476)
#
# S SHORE DR
# (38.721756, -82.978089)
#
# W SCHILLER ST
# (40.004778, -75.145108)
#
# W WOLFRAM ST
# (41.9335036, -87.6563169)
#
# W HOLLYWOOD AVE
# (40.664973, -73.381541)
#
# W MONTANA ST
# (45.6644428, -110.568881)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# S COLFAX AVE
# (30.853988, -96.9914143)
#
# N Morgan St
# (33.8042077, -117.8198522)
#
# N TROY ST
# (41.9593759, -87.70697)
#
# W LAWRENCE AVE
# (41.9683042, -87.7231431)
#
# S MAY ST
# (35.5997263, -77.5918349)
#
# S DORCHESTER AVE
# (41.861114, -88.126156)
#
# N WINCHESTER AVE
# (46.4110364, -105.830487)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# S BISHOP ST
# (39.5665983, -76.9892851)
#
# S EVANS AVE
# (35.509722, -97.9558699)
#
# W CATALPA AVE
# (41.9812028, -87.7124733)
#
# W WAVELAND AVE
# (41.9466715, -87.8113037)
#
# W Madison St
# (41.44819, -82.7183141)
#
# N ADA ST
# (34.536441, -96.208725)
#
# W Lawrence Ave
# (41.9683042, -87.7231431)
#
# W JARVIS AVE
# (42.0153543, -87.8050829)
#
# W LE MOYNE ST
# (41.9077136, -87.7331889)
#
# E 70TH PL
# (39.8821985, -86.1446465)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# S CORNELL AVE
# (42.119526, -87.95127)
#
# E RANDOLPH ST
# (39.430644, -96.7584772)
#
# N LA SALLE DR
# (32.459967, -99.781336)
#
# N LEAVITT ST
# (39.531967, -87.136931)
#
# S BLACKSTONE AVE
# (41.78726, -87.881703)
#
# N PEORIA
# (40.7175374, -89.5842635)
#
# N LINCOLN AVE
# (45.660956, -122.6824777)
#
# N SPAULDING AVE
# (41.9543894, -87.7104772)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# S CENTRAL PARK AVE
# (41.7169517, -87.7114806)
#
# N WINTHROP AVE
# (41.9873032, -87.6581226)
#
# N CENTRAL AVE
# (35.7718102, -91.6557941)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# N HOYNE AVE
# (41.9550717, -87.6812061)
#
# E ST
# (50.4738724, 4.2358174)
#
# N WAYNE AVE
# (40.055678, -75.393487)
#
# W CONGRESS PKWY
# (41.8750866, -87.6539866)
#
# W LAWRENCE AVE
# (41.9683042, -87.7231431)
#
# S DAUPHIN AVE
# (27.8698258, -82.4986097)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# S EUCLID AVE
# (43.5904697, -83.9155365)
#
# W CRYSTAL ST
# (28.899691, -82.574754)
#
# N LINCOLN AVE
# (45.660956, -122.6824777)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# N MARSHFIELD AVE
# (41.9258863, -87.669388)
#
# W 87TH ST
# (38.970993, -94.7161832)
#
# W FLETCHER ST
# (28.324413, -81.40576)
#
# S HAMLIN AVE
# (42.0088243, -87.8504392)
#
# W ARMITAGE AVE
# (43.1023086, -87.9910021)
#
# N WACKER DR
# (40.759348, -89.6577155)
#
# N Whipple ST
# (41.9721178, -87.7049131)
#
# S KEDZIE AVE
# (41.7315967, -87.7021544)
#
# N SEELEY AVE
# (43.5619333, -94.7747364)
#
# W CONGRESS PKWY
# (41.8750866, -87.6539866)
#
# N KEELER AVE
# (31.890888, -102.393391)
#
# E ROOSEVELT RD
# (41.858902, -88.097724)
#
# W 68TH ST
# (36.065546, -95.9981956)
#
# W Schubert Ave
# (41.921548, -88.096436)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# S Wabash Ave
# (34.1314901, -117.8625756)
#
# W ADDISON ST
# (42.226415, -84.406033)
#
# N PEORIA
# (40.7175374, -89.5842635)
#
# W COLUMBIA AVE
# (47.7106286, -117.421456)
#
# N NASHVILLE AVE
# (33.172839, -86.245134)
#
# N Racine Ave
# (43.003319, -88.216859)
#
# N WINTHROP AVE
# (41.9873032, -87.6581226)
#
# N Lake Shore Dr
# (28.905135, -81.763013)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# W OAKDALE AVE
# (29.0407755, -81.3169917)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# N RIDGE AVE
# (35.5045339, -80.6185371)
#
# N STATE ST
# (44.619052, -75.408869)
#
# W BERTEAU AVE
# (41.9561908, -87.8158422)
#
# N NEWGARD AVE
# (42.0017777, -87.666857)
#
# N STATE ST
# (44.619052, -75.408869)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# S MARSHFIELD AVE
# (41.8093553, -87.6662057)
#
# S eggleston ave
# (35.407396, -97.5137083)
#
# N PEORIA
# (40.7175374, -89.5842635)
#
# W Fullerton Ave
# (41.923398, -87.9104238)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# W WABANSIA AVE
# (41.9107882, -87.7995001)
#
# N PEORIA
# (40.7175374, -89.5842635)
#
# W JONQUIL TER
# (42.0211554, -87.6706138)
#
# S SPAULDING AVE
# (34.0288086, -118.3700242)
#
# N MAGNOLIA AVE
# (29.1969846, -82.1365046)
#
# N SAWYER AVE
# (41.9610885, -87.7094607)
#
# W CORTEZ ST
# (33.5897649, -112.4664308)
#
# N HAMLIN AVE
# (41.9737701, -87.7232845)
#
# N Broadway
# (40.9696948, -73.8844801)
#
# S WOOD ST
# (41.343196, -83.119849)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# W LAWRENCE AVE
# (41.9683042, -87.7231431)
#
# S MASSASOIT AVE
# (41.6640139, -87.7618901)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# W Blackhawk St
# (43.567624, -96.737549)
#
# E 38TH PL
# (41.5597753, -90.5463908)
#
# N ADA ST
# (34.536441, -96.208725)
#
# N Peoria
# (40.7175374, -89.5842635)
#
# N STATE ST
# (44.619052, -75.408869)
#
# N STATE ST
# (44.619052, -75.408869)
#
# N AVERS AVE
# (41.9628652, -87.724203)
#
# N STATE ST
# (44.619052, -75.408869)
#
# E 71ST ST
# (41.5110354, -81.6395881)
#
# S DORCHESTER AVE
# (41.861114, -88.126156)
#
# N STATE ST
# (44.619052, -75.408869)
#
# N STATE ST
# (44.619052, -75.408869)
#
# E 33RD ST
# (40.5305942, -85.6462995)
#
# N LAKEWOOD AVE
# (31.856847, -102.514627)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# S DREXEL BLVD
# (35.4636206, -97.5703073)
#
# W NEWPORT AVE
# (42.681683, -83.313192)
#
# W CONGRESS PKWY
# (41.8750866, -87.6539866)
#
# N WINTHROP AVE
# (41.9873032, -87.6581226)
#
# W CONGRESS PKWY
# (41.8750866, -87.6539866)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# N ORCHARD ST
# (43.0517216, -77.093211)
#
# S KEDZIE AVE
# (41.7315967, -87.7021544)
#
# W ROSCOE ST
# (41.9417774, -87.798255)
#
# N WELLS ST
# (30.831592, -83.286031)
#
# N STATE PKWY
# (41.9077301, -87.6287875)
#
# N CUMBERLAND AVE
# (28.5746976, -81.5453944)
#
# W TERMINAL ST
# (38.3711643, -88.065751)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# N WHIPPLE ST
# (41.9721178, -87.7049131)
#
# N SOUTHPORT AVE
# (41.9507055, -87.6641098)
#
# W LELAND AVE
# (41.9666512, -87.7370944)
#
# S SANGAMON ST
# (39.5902655, -89.7359101)
#
# W RANDOLPH ST
# (36.2743344, -90.9816148)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# N LOTUS AVE
# (35.4704582, -97.3553818)
#
# W 14TH ST
# (40.7370431, -73.9960774)
#
# W RASCHER AVE
# (41.9804019, -87.6966348)
#
# N Hoyne Ave
# (41.9550717, -87.6812061)
#
# S TROY ST
# (42.4897468, -83.1419423)
#
# N DRAKE AVE
# (41.9725027, -87.7171475)
#
# N WOOD ST
# (32.3586259, -97.3959405)
#
# S DRAKE AVE
# (41.8498569, -87.713702)
#
# W RASCHER AVE
# (41.9804019, -87.6966348)
#
# E 36TH ST
# (44.9378251, -93.2191089)
#
# N Commonwealth Ave
# (41.7632702, -88.3435098)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# S HYDE PARK BLVD
# (41.7978073, -87.5840054)
#
# W CERMAK RD
# (41.8495374, -87.849713)
#
# N Southport Ave
# (41.9507055, -87.6641098)
#
# W DIVISION ST
# (38.2597099, -87.9979169)
#
# W GREGORY ST
# (42.0735492, -87.9441124)
#
# W FOSTER AVE
# (41.975528, -87.7281106)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# W Argyle st
# (57.8956842, -5.1630045)
#
# N HARBOR DR
# (38.7256772, -89.2919982)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# S Cottage Grove Ave
# (41.6856412, -87.6114137)
#
# N RICHMOND ST
# (41.9557758, -87.7019847)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# S CALIFORNIA AVE
# (34.1163848, -118.0008539)
#
# N CALIFORNIA AVE
# (33.9287659, -116.9813763)
#
# N KEDZIE BLVD
# (41.9245939, -87.7072256)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# W GEORGE ST
# (55.8634318, -4.2657255)
#
# W TERMINAL ST
# (38.3711643, -88.065751)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# W Sunnyside Ave
# (41.9635312, -87.6603099)
#
# N LEAMINGTON AVE
# (41.8986064, -87.7544655)
#
# E 53RD ST
# (40.7580248, -73.9701634)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# N PEORIA
# (40.7175374, -89.5842635)
#
# S DREXEL AVE
# (33.369843, -111.623825)
#
# W DIVISION ST
# (38.2597099, -87.9979169)
#
# N ROCKWELL ST
# (33.3744844, -111.7302071)
#
# N Michigan Ave
# (43.4553256, -83.9500328)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# W AINSLIE ST
# (41.9701978, -87.7164722)
#
# S SAWYER AVE
# (47.2288772, -122.4540806)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# N PEORIA
# (40.7175374, -89.5842635)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# W TERMINAL ST
# (38.3711643, -88.065751)
#
# W CUYLER AVE
# (41.9551763, -87.6742845)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# W FLETCHER ST
# (28.324413, -81.40576)
#
# W Agatite Ave
# (41.9619564, -87.7205109)
#
# E JACKSON BLVD
# (37.3767724, -89.6668247)
#
# E 11TH ST
# (36.1479355, -95.9060913)
#
# S MUSEUM CAMPUS DR
# (41.8662155, -87.6137248)
#
# W Fullerton Ave
# (41.923398, -87.9104238)
#
# N CLEVELAND AVE
# (30.344444, -95.0913629)
#
# E ROOSEVELT RD
# (41.858902, -88.097724)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# N BERNARD ST
# (41.9720734, -87.7146943)
#
# N WACKER DR
# (40.759348, -89.6577155)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# E WACKER DR
# (41.8878388, -87.6190596)
#
# N Central Park Ave
# (41.9751896, -87.7184185)
#
# W CONGRESS PKWY
# (41.8750866, -87.6539866)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# N MEDFORD AVE
# (42.0078045, -87.7835576)
#
# N HIAWATHA AVE
# (41.992145, -87.7464613)
#
# S KENWOOD AVE
# (41.8060326, -87.5935411)
#
# S INGLESIDE AVE
# (41.7403543, -87.601287)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# N ADA ST
# (34.536441, -96.208725)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# N LOOMIS ST
# (42.080628, -72.815831)
#
# N CLARENDON AVE
# (39.3347411, -74.4980139)
#
# W HENDERSON ST
# (35.6845746, -80.4331586)
#
# N PAULINA ST
# (41.9902949, -87.6714344)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# S GREENWOOD AVE
# (37.6199047, -96.228166)
#
# N CALIFORNIA AVE
# (33.9287659, -116.9813763)
#
# N ADA ST
# (34.536441, -96.208725)
#
# S KARLOV AVE
# (41.7139045, -87.7235728)
#
# N PEORIA
# (40.7175374, -89.5842635)
#
# N FREMONT ST
# (40.768691, -95.3850426)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# N LEAMINGTON AVE
# (41.8986064, -87.7544655)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# N PAULINA ST
# (41.9902949, -87.6714344)
#
# N Latrobe Ave
# (41.9852199, -87.7604579)
#
# N DELPHIA AVE
# (36.7559217, -119.7939473)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# W FLOURNOY ST
# (28.406267, -97.7593919)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# N Broadway
# (40.9696948, -73.8844801)
#
# S Blackstone Ave
# (41.78726, -87.881703)
#
# W North Ave
# (39.3102943, -76.6372005)
#
# N ADA ST
# (34.536441, -96.208725)
#
# N Glenwood Ave
# (42.650887, -83.284998)
#
# W OHIO ST
# (40.646058, -83.609337)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# N PARKSIDE AVE
# (34.082432, -117.6296776)
#
# W CONGRESS PKWY
# (41.8750866, -87.6539866)
#
# N PEORIA
# (40.7175374, -89.5842635)
#
# N NASHVILLE AVE
# (33.172839, -86.245134)
#
# N NASHVILLE AVE
# (33.172839, -86.245134)
#
# W CONGRESS PKWY
# (41.8750866, -87.6539866)
#
# N WINTHROP AVE
# (41.9873032, -87.6581226)
#
# W CONGRESS PKWY
# (41.8750866, -87.6539866)
#
# N Sheridan RD
# (40.3578419, -76.2273206)
#
# W AINSLIE ST
# (41.9701978, -87.7164722)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# W Schiller ST
# (40.004778, -75.145108)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# W WINNEMAC AVE
# (41.9733819, -87.667451)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# W ARMITAGE AVE
# (43.1023086, -87.9910021)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# W Monroe St
# (41.9561258, -83.658253)
#
# N ADA ST
# (34.536441, -96.208725)
#
# E WACKER DR
# (41.8878388, -87.6190596)
#
# N WINTHROP AVE
# (41.9873032, -87.6581226)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# W DEMING PL
# (41.9292488, -87.6406316)
#
# S LOOMIS BLVD
# (41.7570599, -87.6587609)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# S MUSEUM CAMPUS DR
# (41.8662155, -87.6137248)
#
# W POLK ST
# (30.7116929, -94.9383233)
#
# W COLUMBIA AVE
# (47.7106286, -117.421456)
#
# W TOUHY AVE
# (42.0118322, -87.7491207)
#
# N NEWLAND AVE
# (41.9223472, -87.7988731)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# E 59TH ST
# (40.7639662, -73.9722705)
#
# W WRIGHTWOOD AVE
# (41.9247283, -87.9553717)
#
# N Sawyer Ave
# (41.9610885, -87.7094607)
#
# S HYDE PARK BLVD
# (41.7978073, -87.5840054)
#
# S PARNELL AVE
# (41.6335259, -87.6353874)
#
# N KEDZIE AVE
# (41.981245, -87.7088348)
#
# E WALTON ST
# (33.0918832, -83.2257331)
#
# N CALIFORNIA AVE
# (33.9287659, -116.9813763)
#
# W Gunnison St
# (41.969023, -87.7398109)
#
# N CLAREMONT AVE
# (36.106832, -80.228788)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# N WOOD ST
# (32.3586259, -97.3959405)
#
# N STATE ST
# (44.619052, -75.408869)
#
# N SACRAMENTO AVE
# (39.341244, -74.483242)
#
# E CONGRESS PKWY
# (41.8757455, -87.6251804)
#
# S TROY ST
# (42.4897468, -83.1419423)
#
# N HONORE ST
# (41.9765479, -87.6754559)
#
# N SOUTHPORT AVE
# (41.9507055, -87.6641098)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# N SOUTHPORT AVE
# (41.9507055, -87.6641098)
#
# N ARTESIAN AVE
# (41.9254283, -87.6888852)
#
# E OHIO ST
# (40.601786, -84.084445)
#
# N PAULINA ST
# (41.9902949, -87.6714344)
#
# N OKETO AVE
# (41.952203, -87.8122027)
#
# W WILCOX ST
# (39.7729655, -86.2196271)
#
# W TERMINAL ST
# (38.3711643, -88.065751)
#
# E WATERSIDE DR
# (44.836475, -85.738503)
#
# W CATALPA AVE
# (41.9812028, -87.7124733)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# N ADA ST
# (34.536441, -96.208725)
#
# S PAULINA ST
# (41.878849, -87.6692204)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# W 51ST ST
# (40.7597316, -73.9780866)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# N Western Ave
# (35.5293143, -97.5298153)
#
# N SOUTHPORT AVE
# (41.9507055, -87.6641098)
#
# W Haddon Ave
# (41.9025006, -87.6659391)
#
# N Clark St
# (42.076021, -78.402981)
#
# N SOUTHPORT AVE
# (41.9507055, -87.6641098)
#
# S RACINE AVE
# (42.9427005, -88.1582854)
#
# W WARNER AVE
# (36.8356029, -119.8173025)
#
# W ST PAUL AVE
# (43.0347877, -87.9278248)
#
# N NASHVILLE AVE
# (33.172839, -86.245134)
#
# N PEORIA
# (40.7175374, -89.5842635)
#
# W EDDY ST
# (33.6448338, -97.3810902)
#
# N NATOMA AVE
# (43.6443386, -116.4245855)
#
# N SEMINARY AVE
# (29.50448, -82.288453)
#
# W BRADLEY PL
# (41.9501056, -87.6501801)
#
# E 61ST ST
# (44.892517, -93.260414)
#
# N FRANCISCO AVE
# (26.2217801, -98.3199932)
#
# N PEORIA
# (40.7175374, -89.5842635)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# S EAST END AVE
# (40.7774069, -73.943042)
#
# S LUELLA AVE
# (41.7589872, -87.5700366)
#
# W GRAND AVE
# (44.89992, -89.6139466)
#
# S WOODLAWN AVE
# (41.7812374, -87.5962214)
#
# E RANDOLPH ST
# (39.430644, -96.7584772)
#
# N CALIFORNIA AVE
# (33.9287659, -116.9813763)
#
# S ELIZABETH ST
# (40.727094, -84.106756)
#
# E RANDOLPH ST
# (39.430644, -96.7584772)
#
# N WESTERN AVE
# (35.5293143, -97.5298153)
#
# S SHORE DR
# (38.721756, -82.978089)
#
# S UNIVERSITY AVE
# (40.2215138, -111.658881)
#
# N BELL AVE
# (32.2464153, -110.8940884)
#
# N Wolcott Ave
# (41.9069854, -87.6730408)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# N Clark St
# (42.076021, -78.402981)
#
# E RANDOLPH ST
# (39.430644, -96.7584772)
#
# S MAPLEWOOD AVE
# (36.0250954, -95.9064784)
#
# N HOMAN AVE
# (41.8919714, -87.711335)
#
# S OAKLEY AVE
# (41.6631708, -86.1244023)
#
# N HOYNE AVE
# (41.9550717, -87.6812061)
#
# N PEORIA
# (40.7175374, -89.5842635)
#
# N KEDZIE AVE
# (41.981245, -87.7088348)
#
# W 37TH ST
# (43.6239944, -116.244005)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# E MONROE DR
# (35.3490004, -96.9065622)
#
# N WELLS ST
# (30.831592, -83.286031)
#
# N Broadway
# (40.9696948, -73.8844801)
#
# W CONGRESS PKWY
# (41.8750866, -87.6539866)
#
# S Drexel Blvd
# (35.4636206, -97.5703073)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# N MALDEN ST
# (41.9687299, -87.6628804)
#
# W TERMINAL ST
# (38.3711643, -88.065751)
#
# N KEYSTONE AVE
# (42.0001236, -76.5351751)
#
# S MUSEUM CAMPUS DR
# (41.8662155, -87.6137248)
#
# N Massasoit ave
# (41.896595, -87.7691028)
#
# N Winchester Ave
# (46.4110364, -105.830487)
#
# N DESPLAINES ST
# (41.8890494, -87.6443381)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# W CONGRESS PKWY
# (41.8750866, -87.6539866)
#
# N MORGAN ST
# (33.8042077, -117.8198522)
#
# N MOHAWK ST
# (42.790293, -73.712513)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# N Elston Ave
# (41.9624991, -87.731967)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# E CONGRESS PKWY
# (41.8757455, -87.6251804)
#
# N NEWGARD AVE
# (42.0017777, -87.666857)
#
# W BELLE PLAINE AVE
# (41.955062, -87.7887068)
#
# N PEORIA
# (40.7175374, -89.5842635)
#
# S MC VICKER AVE
# (41.7720642, -87.7721541)
#
# N PEORIA
# (40.7175374, -89.5842635)
#
# N RUSH ST
# (43.7828197, -86.4281776)
#
# N PEORIA
# (40.7175374, -89.5842635)
#
# W 35TH ST
# (41.881364, -103.6683128)
#
# N PONTIAC AVE
# (31.233103, -85.4146803)
#
# N PEORIA
# (40.7175374, -89.5842635)
#
# S LA SALLE ST
# (41.742861, -88.3242315)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# S CLAREMONT AVE
# (39.096728, -94.442776)
#
# W DICKENS AVE
# (26.2215137, -98.1842927)
#
# W WEBSTER AVE
# (42.4488715, -83.1273708)
#
# W CULLERTON ST
# (41.8556603, -87.641803)
#
# W DICKENS AVE
# (26.2215137, -98.1842927)
#
# S MERRION AVE
# (41.7163154, -87.569825)
#
# W WABANSIA AVE
# (41.9107882, -87.7995001)
#
# N PEORIA
# (40.7175374, -89.5842635)
#
# N KILDARE AVE
# (41.9718061, -87.7355466)
#
# N HERMITAGE AVE
# (40.232782, -74.780752)
#
# S Archer Ave
# (41.6335223, -88.0133585)
#
# W ADDISON ST
# (42.226415, -84.406033)
#
# N LA SALLE ST
# (30.398997, -96.0961872)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# N RUSH ST
# (43.7828197, -86.4281776)
#
# W RACE AVE
# (35.2508634, -91.74748)
#
# S KEDZIE AVE
# (41.7315967, -87.7021544)
#
# W POTOMAC AVE
# (43.0958445, -88.0105462)
#
# E PEARSON ST
# (43.053739, -87.900774)
#
# S KEDZIE AVE
# (41.7315967, -87.7021544)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# S KEDZIE AVE
# (41.7315967, -87.7021544)
#
# W HOLLYWOOD AVE
# (40.664973, -73.381541)
#
# W HUTCHINSON ST
# (28.4107445, -97.7590378)
#
# W Pratt Blvd
# (42.0054657, -87.6658226)
#
# S university ave
# (40.2215138, -111.658881)
#
# S CICERO AVE
# (41.8545413, -87.7443874)
#
# N WELLS ST
# (30.831592, -83.286031)
#
# N PEORIA
# (40.7175374, -89.5842635)
#
# W WACKER DR
# (30.4717592, -84.349793)
#
# W AINSLIE ST
# (41.9701978, -87.7164722)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# S KENNETH AVE
# (41.6814466, -87.7302028)
#
# W 24TH ST
# (39.8009909, -86.170301)
#
# W LOGAN BLVD
# (41.9310979, -87.6846333)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# N OAK PARK AVE
# (41.9071844, -87.7950033)
#
# E 63RD ST
# (30.384898, -81.6447918)
#
# N WELLS ST
# (30.831592, -83.286031)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# W WEBSTER AVE
# (42.4488715, -83.1273708)
#
# S WOLCOTT AVE
# (41.8741687, -87.6740297)
#
# E ST
# (50.4738724, 4.2358174)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# N GREENVIEW AVE
# (42.2840502, -89.1311541)
#
# N Clifton Ave
# (37.2360894, -93.3271958)
#
# N BROADWAY
# (40.9696948, -73.8844801)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# W SUMMERDALE AVE
# (41.9789237, -87.6696222)
#
# S JUSTINE ST
# (41.6714397, -87.6599691)
#
# N LARAMIE AVE
# (41.8954167, -87.7556069)
#
# N SPOKANE AVE
# (48.1840456, -117.0454431)
#
# N ST LOUIS AVE
# (41.9727203, -87.7159449)
#
# S CHAMPLAIN AVE
# (32.1827548, -110.8194486)
#
# W 40TH ST
# (30.3041337, -97.7342249)
#
# W 55TH ST
# (40.7692044, -73.9927944)
#
# S FAIRFIELD AVE
# (41.8828928, -88.0058916)
#
# S WOOD ST
# (41.343196, -83.119849)
#
# S PARNELL AVE
# (41.6335259, -87.6353874)
#
# S MAPLEWOOD AVE
# (36.0250954, -95.9064784)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# W 66TH ST
# (40.7733596, -73.9809918)
#
# S UNIVERSITY AVE
# (40.2215138, -111.658881)
#
# W 18TH ST
# (39.041594, -96.8333437)
#
# S EGGLESTON AVE
# (35.407396, -97.5137083)
#
# S WASHTENAW AVE
# (41.8244476, -87.6922106)
#
# N BROADWAY
# (40.9696948, -73.8844801)
#
# E WACKER DR
# (41.8878388, -87.6190596)

# %%
# Save Checkpoint 
df2021_geo = df_2021.copy()

# %%
# Filter location that is not null
df2021_geo = df2021_geo[df2021_geo['location'].notna()]

# %%
df2021_geo = impute_district(df2021_geo)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:113: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326

# %%
# Drop columns
df2021_geo.drop(['district', 'index_right'], axis=1, inplace=True)

# Rename columns
df2021_geo.rename(columns={'dist_num':'district'}, inplace=True)

# %%
# Impute updated ward values
df2021_geo = impute_ward(df2021_geo)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:69: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326

# %%
# Drop columns
df2021_geo.drop(['ward_left', 'index_right'], axis=1, inplace=True)

# Rename columns
df2021_geo.rename(columns={'ward_right':'ward'}, inplace=True)

# %%
# Impute updated district values
df2021_geo = impute_commareas(df2021_geo)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:91: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326

# %%
# Drop columns
df2021_geo.drop(['community_area', 'index_right'], axis=1, inplace=True)

# Rename columns
df2021_geo.rename(columns={'area_numbe':'community_area'}, inplace=True)

# %%
# Balance clean up of dataset after transformation
# Drop columns
df2021_geo.drop(['x_coordinate', 'y_coordinate'], axis=1, inplace=True)

# Assign null values in location description to 'OTHER (Specify)'
df2021_geo['location_description'].fillna('OTHER (SPECIFY)', inplace = True)

# %%
df2021_geo.to_csv('/content/drive/MyDrive/Colab Notebooks/capstone/assets/clean_data/2021_crime_clean.csv', index=False)

# %%
df2021_geo.isnull().sum()
# Out:
# id                        0
# case_number               0
# date                      0
# block                     0
# iucr                      0
# primary_type              0
# description               0
# location_description    361
# arrest                    0
# domestic                  0
# beat                      0
# fbi_code                  0
# x_coordinate            211
# y_coordinate            211
# year                      0
# updated_on                0
# latitude                  0
# longitude                 0
# location                  0
# day                       0
# month                     0
# day_of_week               0
# time                      0
# geometry                  0
# district                  0
# ward                      0
# community_area            0
# dtype: int64

# %% [markdown]
# ## Clean data (2020)

# %%
# from geopy.geocoders import Nominatim
geocoder = Nominatim(user_agent = 'crime_predictions')

# %%
df_2020 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/capstone/assets/2020_crime.csv')
df_2020.head()
# Out:
#          id case_number                 date                 block  iucr  \
# 0  12014684    JD189901  2020-03-17 21:30:00  039XX N LECLAIRE AVE  0820
# 1  12012127    JD189186  2020-03-18 02:03:00  039XX W JACKSON BLVD  0910
# 2  12012330    JD189367  2020-03-18 08:50:00    023XX N KEELER AVE  0560
# 3  12014760    JD192130  2020-03-18 13:00:00     047XX W MONROE ST  1150
# 4  12012667    JD189808  2020-03-18 17:35:00    003XX S CICERO AVE  2017
#
#           primary_type                    description location_description  \
# 0                THEFT                 $500 AND UNDER               STREET
# 1  MOTOR VEHICLE THEFT                     AUTOMOBILE            APARTMENT
# 2              ASSAULT                         SIMPLE            RESIDENCE
# 3   DECEPTIVE PRACTICE              CREDIT CARD FRAUD      OTHER (SPECIFY)
# 4            NARCOTICS  MANUFACTURE / DELIVER - CRACK             SIDEWALK
#
#    arrest  domestic  beat  district  ward  community_area fbi_code  \
# 0   False     False  1634      16.0  45.0            15.0       06
# 1   False      True  1132      11.0  28.0            26.0       07
# 2   False     False  2525      25.0  35.0            20.0      08A
# 3   False     False  1113      11.0  28.0            25.0       11
# 4    True     False  1533      15.0  28.0            25.0       18
#
#    x_coordinate  y_coordinate  year              updated_on   latitude  \
# 0     1141659.0     1925649.0  2020  03/25/2020 03:45:43 PM  41.952052
# 1     1150196.0     1898398.0  2020  03/25/2020 03:47:29 PM  41.877110
# 2     1147996.0     1915240.0  2020  03/25/2020 03:47:29 PM  41.923369
# 3     1144749.0     1899145.0  2020  03/25/2020 03:47:29 PM  41.879264
# 4     1144446.0     1898000.0  2020  03/25/2020 03:47:29 PM  41.876128
#
#    longitude                       location  day  month  day_of_week  time
# 0 -87.754660  (41.952051946, -87.754660372)   17      3            1    21
# 1 -87.723990  (41.877110187, -87.723989719)   18      3            2     2
# 2 -87.731634  (41.923368973, -87.731633833)   18      3            2     8
# 3 -87.743971  (41.879264422, -87.743970898)   18      3            2    13
# 4 -87.745112  (41.876128106, -87.745112291)   18      3            2    17

# %%
df_2020.isnull().sum()
# Out:
# id                         0
# case_number                0
# date                       0
# block                      0
# iucr                       0
# primary_type               0
# description                0
# location_description    1206
# arrest                     0
# domestic                   0
# beat                       0
# district                   0
# ward                       9
# community_area             1
# fbi_code                   0
# x_coordinate            2659
# y_coordinate            2659
# year                       0
# updated_on                 0
# latitude                2659
# longitude               2659
# location                2659
# day                        0
# month                      0
# day_of_week                0
# time                       0
# dtype: int64

# %%
replace_to_zero(df_2020)

# %%
index_list = missing_row_loc(df_2020)
# Out:
# 2659

# %%
impute_data(df_2020, index_list)
# Out:
# Streaming output truncated to the last 5000 lines.
# (32.3874438, -80.5764049)
#
# W NORTH SHORE AVE
# (42.0027093, -87.744558)
#
# E 56TH ST
# (44.9015711, -93.2646052)
#
# S KENWOOD AVE
# (41.8060326, -87.5935411)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# W ADDISON ST
# (42.226415, -84.406033)
#
# W Foster Ave
# (41.975528, -87.7281106)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# W BELDEN AVE
# (41.9187168, -87.9610749)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# S CICERO AVE
# (41.8545413, -87.7443874)
#
# N CAMPBELL AVE
# (32.2527259, -110.9439424)
#
# E 54TH PL
# (39.851389, -86.050353)
#
# S WENTWORTH AVE
# (42.9981308, -87.8894434)
#
# N MAGNOLIA AVE
# (29.1969846, -82.1365046)
#
# S FAIRFIELD AVE
# (41.8828928, -88.0058916)
#
# N MC CLURG CT
# (30.332179, -82.799061)
#
# N HOYNE AVE
# (41.9550717, -87.6812061)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# N MALDEN ST
# (41.9687299, -87.6628804)
#
# S COTTAGE GROVE AVE
# (41.6856412, -87.6114137)
#
# N WINTHROP AVE
# (41.9873032, -87.6581226)
#
# N JANSSEN AVE
# (41.9725741, -87.6667373)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# N OCONTO AVE
# (41.9452423, -87.8081992)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# S KEATING AVE
# (33.3664683, -111.8640276)
#
# S ARTESIAN AVE
# (34.0977413, -117.3182866)
#
# W LUNT AVE
# (42.0077782, -87.8200486)
#
# N PAULINA ST
# (41.9902949, -87.6714344)
#
# S SEELEY AVE
# (42.2886768, -89.633005)
#
# S NEVA AVE
# (41.791771, -87.8002439)
#
# N MAGNOLIA AVE
# (29.1969846, -82.1365046)
#
# W OLIVE AVE
# (36.9528135, -120.0566053)
#
# N SEELEY AVE
# (43.5619333, -94.7747364)
#
# E ST
# (50.4738724, 4.2358174)
#
# S WESTERN AVE
# (43.5185145, -96.751124)
#
# N MARINE DR
# (33.8164549, -117.8300018)
#
# N WOOD ST
# (32.3586259, -97.3959405)
#
# N SPAULDING AVE
# (41.9543894, -87.7104772)
#
# S EVANS AVE
# (35.509722, -97.9558699)
#
# N AVERS AVE
# (41.9628652, -87.724203)
#
# W SURF ST
# (41.9343518, -87.638939)
#
# N Leavitt St
# (39.531967, -87.136931)
#
# N SOUTHPORT AVE
# (41.9507055, -87.6641098)
#
# S Michigan Ave
# (42.59934, -83.9336293)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# N Kenmore Ave
# (34.0845852, -117.6542025)
#
# W 69TH ST
# (44.8780766, -93.2858204)
#
# N SAWYER AVE
# (41.9610885, -87.7094607)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# N Dearborn St
# (39.865547, -86.111152)
#
# N CUMBERLAND AVE
# (28.5746976, -81.5453944)
#
# E 51ST ST
# (40.754497, -73.9656924)
#
# W LOYOLA AVE
# (26.2877836, -98.2438166)
#
# N ROGERS AVE
# (42.118891, -76.046551)
#
# E Hyde Park Blvd
# (41.8024947, -87.5867897)
#
# S AVALON AVE
# (34.244157, -116.386354)
#
# S OAKLEY AVE
# (41.6631708, -86.1244023)
#
# N SAUGANASH AVE
# (41.994039, -87.7412704)
#
# N KIMBALL AVE
# (32.948407, -97.1167804)
#
# N CUMBERLAND AVE
# (28.5746976, -81.5453944)
#
# W LILL AVE
# (41.9277607, -87.6590552)
#
# W CULLOM AVE
# (41.9590228, -87.7389563)
#
# S KILBOURN AVE
# (41.8591487, -87.737185)
#
# N PINE GROVE AVE
# (41.9529308, -87.6478914)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# W ARLINGTON PL
# (28.8134399, -82.5451972)
#
# W WAVELAND AVE
# (41.9466715, -87.8113037)
#
# N STATE PKWY
# (41.9077301, -87.6287875)
#
# N KARLOV AVE
# (41.9677725, -87.7304613)
#
# W Hirsch St
# (41.9062185, -87.7313087)
#
# N PINE GROVE AVE
# (41.9529308, -87.6478914)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# W Evergreen Ave
# (34.1350555, -118.0011499)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# W BAGGAGE ALY
# (33.237615, 131.6064313)
#
# N RICHMOND ST
# (41.9557758, -87.7019847)
#
# S DOBSON AVE
# (41.764125, -87.5994316)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# N LEAVITT ST
# (39.531967, -87.136931)
#
# W AINSLIE ST
# (41.9701978, -87.7164722)
#
# N MANGO AVE
# (41.9608929, -87.7709224)
#
# N PEORIA ST
# (40.935557, -89.537819)
#
# N WINTHROP AVE
# (41.9873032, -87.6581226)
#
# W DEMING PL
# (41.9292488, -87.6406316)
#
# E 61ST ST
# (44.892517, -93.260414)
#
# W DICKENS AVE
# (26.2215137, -98.1842927)
#
# S PULASKI RD
# (41.6803208, -87.7198931)
#
# N KEDZIE BLVD
# (41.9245939, -87.7072256)
#
# N STATE ST
# (44.619052, -75.408869)
#
# S Rhodes Ave
# (41.180979, -80.736336)
#
# S MAY ST
# (35.5997263, -77.5918349)
#
# W SUNNYSIDE AVE
# (41.9635312, -87.6603099)
#
# W Fullerton Ave
# (41.923398, -87.9104238)
#
# W BARRY AVE
# (36.8175627, -93.9243727)
#
# N WOLCOTT AVE
# (41.9069854, -87.6730408)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# N Michigan Ave
# (43.4553256, -83.9500328)
#
# W 33RD ST
# (43.5221332, -96.7399599)
#
# N Mayfield Ave
# (34.1105096, -117.2902727)
#
# N PEORIA
# (40.7175374, -89.5842635)
#
# W SCHOOL ST
# (33.3044468, -96.4028596)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# S HALSTED ST
# (41.5420844, -87.6359687)
#
# W st
# (55.8497133, -4.2656724)
#
# S UNION AVE
# (47.2491253, -122.4836389)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W ESTES AVE
# (32.008665, -102.081306)
#
# N HERMITAGE AVE
# (40.232782, -74.780752)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# S ARCHER AVE
# (41.6335223, -88.0133585)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# S PAULINA ST
# (41.878849, -87.6692204)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# W 55TH ST
# (40.7692044, -73.9927944)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# W CONCORD PL
# (40.3981522, -111.9271298)
#
# N EAST CIRCLE AVE
# (34.211008, -90.580597)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# S BLACKSTONE AVE
# (41.78726, -87.881703)
#
# S EBERHART AVE
# (43.822127, -84.748397)
#
# W 31ST ST
# (44.9466054, -93.2862078)
#
# W 37TH PL
# (41.5500355, -87.2771904)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# W 55TH ST
# (40.7692044, -73.9927944)
#
# N LEADER AVE
# (41.9945512, -87.7516463)
#
# S BURLEY AVE
# (41.7376517, -87.5453086)
#
# S WOOD ST
# (41.343196, -83.119849)
#
# N Winchester Ave
# (46.4110364, -105.830487)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# S ST LAWRENCE AVE
# (41.7682281, -87.6104913)
#
# N Francisco Ave
# (26.2217801, -98.3199932)
#
# W 61ST ST
# (44.89257, -93.315002)
#
# S MARQUETTE AVE
# (41.6317592, -87.5567079)
#
# W CATALPA AVE
# (41.9812028, -87.7124733)
#
# W 55TH ST
# (40.7692044, -73.9927944)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# S KIMBARK AVE
# (41.7673136, -87.5941382)
#
# W BERWYN AVE
# (41.9775394, -87.712376)
#
# W ZEMKE RD
# (41.9959191, -87.8870393)
#
# S RACINE AVE
# (42.9427005, -88.1582854)
#
# N KEDVALE AVE
# (41.9640717, -87.7315451)
#
# W 55TH ST
# (40.7692044, -73.9927944)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# S OAKLEY AVE
# (41.6631708, -86.1244023)
#
# S CAMPBELL AVE
# (37.1712552, -93.2953919)
#
# S EMERALD AVE
# (33.3965996, -111.8035831)
#
# S MOZART ST
# (41.726308, -87.6933241)
#
# S HOMAN AVE
# (41.6622485, -87.7046222)
#
# W FOSTER AVE
# (41.975528, -87.7281106)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# S HARVARD AVE
# (40.613458, -98.098577)
#
# S PEORIA ST
# (39.5974063, -104.8480467)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# N SPAULDING AVE
# (41.9543894, -87.7104772)
#
# W GRANVILLE AVE
# (40.245255, -96.754104)
#
# S ROCKWELL ST
# (33.3290958, -111.7293356)
#
# W MONTROSE AVE
# (41.9607197, -87.7466474)
#
# W LAKE ST
# (41.8877192, -87.7651226)
#
# W 64TH PL
# (25.881035, -80.3378206)
#
# S RUTHERFORD AVE
# (41.7189853, -87.78843)
#
# W Hubbard St
# (41.7159012, -89.3389805)
#
# N PARK DR
# (33.529842, -90.205781)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S WESTERN AVE
# (43.5185145, -96.751124)
#
# S HALSTED ST
# (41.5420844, -87.6359687)
#
# S YATES BLVD
# (41.7408204, -87.5660877)
#
# W FITCH AVE
# (42.0110557, -87.7865783)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# W LAKE ST
# (41.8877192, -87.7651226)
#
# E 61ST ST
# (44.892517, -93.260414)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# N Aberdeen St
# (35.732977, -95.350542)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# W CORNELIA AVE
# (33.9618136, -98.6777071)
#
# S SACRAMENTO AVE
# (39.3373525, -74.4801189)
#
# W BEACH AVE
# (49.0253429, -122.8165082)
#
# W 37TH PL
# (41.5500355, -87.2771904)
#
# W Briar Pl
# (41.9391149, -87.6468032)
#
# W HARRISON ST
# (47.453523, -116.785825)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# S ARCHER AVE
# (41.6335223, -88.0133585)
#
# W PL
# (39.0445999, -94.6029041)
#
# W HADDON AVE
# (41.9025006, -87.6659391)
#
# N NOTTINGHAM AVE
# (41.9489522, -87.8046875)
#
# S JEFFERY BLVD
# (41.7479785, -87.5759176)
#
# S NORDICA AVE
# (41.7211247, -87.7956381)
#
# N LEAVITT ST
# (39.531967, -87.136931)
#
# S University Ave
# (40.2215138, -111.658881)
#
# S DREXEL AVE
# (33.369843, -111.623825)
#
# S MARSHFIELD AVE
# (41.8093553, -87.6662057)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# E 89TH PL
# (36.0340257, -95.9045251)
#
# S KINGSTON AVE
# (36.044406, -95.9074742)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# S AVENUE C
# (38.7785529, -97.6063)
#
# W ADDISON ST
# (42.226415, -84.406033)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# N LOCKWOOD AVE
# (41.6979589, -83.5699941)
#
# N HAMILTON AVE
# (40.696537, -73.368294)
#
# W 59TH ST
# (40.7646364, -73.9737661)
#
# W ARMITAGE AVE
# (43.1023086, -87.9910021)
#
# E MONROE ST
# (38.305137, -89.992146)
#
# W 48TH ST
# (44.915947, -93.294662)
#
# S PULASKI RD
# (41.6803208, -87.7198931)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# S SPAULDING AVE
# (34.0288086, -118.3700242)
#
# W DIVISION ST
# (38.2597099, -87.9979169)
#
# W 83RD PL
# (41.4664124, -87.3859098)
#
# N RAVENSWOOD AVE
# (41.9688187, -87.6741627)
#
# S KIMBARK AVE
# (41.7673136, -87.5941382)
#
# W SHAKESPEARE AVE
# (44.1405017, -93.981392)
#
# S EMERALD AVE
# (33.3965996, -111.8035831)
#
# W CULLOM AVE
# (41.9590228, -87.7389563)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# S SANGAMON ST
# (39.5902655, -89.7359101)
#
# S EDBROOKE AVE
# (41.6980924, -87.6196287)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# E LAKE ST
# (44.9483802, -93.2053802)
#
# S BISHOP ST
# (39.5665983, -76.9892851)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# N RICHMOND ST
# (41.9557758, -87.7019847)
#
# W 64TH ST
# (39.0130173, -94.802986)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# N WINTHROP AVE
# (41.9873032, -87.6581226)
#
# E 72ND PL
# (39.886358, -86.078593)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# S AVERS AVE
# (41.6734757, -87.7157121)
#
# E 14TH ST
# (40.7321878, -73.9845578)
#
# N STATE PKWY
# (41.9077301, -87.6287875)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# N PAULINA ST
# (41.9902949, -87.6714344)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# N MASSASOIT AVE
# (41.896595, -87.7691028)
#
# W ARTHUR AVE
# (42.9994824, -87.9518008)
#
# S CORLISS AVE
# (41.6899396, -87.6012166)
#
# S FAIRFIELD AVE
# (41.8828928, -88.0058916)
#
# N MARMORA AVE
# (41.9567321, -87.7744508)
#
# S ELLIS AVE
# (35.309552, -78.616879)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# W HIGGINS AVE
# (41.9820571, -87.8112681)
#
# W 73RD ST
# (41.7589455, -87.8049929)
#
# S BLUE ISLAND AVE
# (41.8541923, -87.6641634)
#
# W Cortez St
# (33.5897649, -112.4664308)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# S OAK PARK AVE
# (41.8815808, -87.7943023)
#
# S SANGAMON ST
# (39.5902655, -89.7359101)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# N MARSHFIELD AVE
# (41.9258863, -87.669388)
#
# N SPAULDING AVE
# (41.9543894, -87.7104772)
#
# W CORTEZ ST
# (33.5897649, -112.4664308)
#
# N LARAMIE AVE
# (41.8954167, -87.7556069)
#
# E ILLINOIS ST
# (41.862286, -88.09637)
#
# S COMMERCIAL AVE
# (41.7141047, -89.3341986)
#
# N SEELEY AVE
# (43.5619333, -94.7747364)
#
# S PAULINA ST
# (41.878849, -87.6692204)
#
# S CALUMET AVE
# (41.7034033, -86.871671)
#
# N LAKEVIEW AVE
# (42.691734, -73.629981)
#
# N TRUMBULL AVE
# (45.5965005, -122.7536356)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# W 26TH ST
# (41.8444628, -87.7092909)
#
# W DIVERSEY AVE
# (41.9263942, -88.0053438)
#
# W POTOMAC AVE
# (43.0958445, -88.0105462)
#
# W 78TH PL
# (41.4755863, -87.3774798)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# S DANTE AVE
# (41.5394098, -87.5855724)
#
# W IRVING PARK RD
# (41.953826, -87.7116755)
#
# N LOWELL AVE
# (43.051309, -76.184402)
#
# N WOLCOTT AVE
# (41.9069854, -87.6730408)
#
# S SAGINAW AVE
# (41.6427026, -87.5580689)
#
# N OGALLAH AVE
# (42.0003892, -87.8132126)
#
# S UNION AVE
# (47.2491253, -122.4836389)
#
# W MELROSE ST
# (40.667262, -73.698695)
#
# N KIMBALL AVE
# (32.948407, -97.1167804)
#
# N KILBOURN AVE
# (41.9717611, -87.7405534)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# N WOOD ST
# (32.3586259, -97.3959405)
#
# S Lockwood Ave
# (41.7615119, -87.7536073)
#
# S ELLIS AVE
# (35.309552, -78.616879)
#
# S CLARK ST
# (44.955584, -90.795919)
#
# S Cornell Ave
# (42.119526, -87.95127)
#
# W 79TH ST
# (40.7849838, -73.9826637)
#
# S ST LAWRENCE AVE
# (41.7682281, -87.6104913)
#
# S KENWOOD AVE
# (41.8060326, -87.5935411)
#
# N ALBANY AVE
# (40.7076835, -73.465108)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# S STONY ISLAND AVE
# (41.772423, -87.5862745)
#
# W ST
# (55.8497133, -4.2656724)
#
# E 82ND ST
# (41.5041895, -81.6308342)
#
# W RANDOLPH ST
# (36.2743344, -90.9816148)
#
# S CLAREMONT AVE
# (39.096728, -94.442776)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# W 35TH ST
# (41.881364, -103.6683128)
#
# S RIDGEWAY AVE
# (35.61739, -82.3173401)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# W 58TH ST
# (44.8978415, -93.2888067)
#
# S OAKLEY AVE
# (41.6631708, -86.1244023)
#
# W 99TH ST
# (39.9322467, -86.2334767)
#
# E RANDOLPH ST
# (39.430644, -96.7584772)
#
# E 62ND ST
# (44.890728, -93.259847)
#
# S WALLACE ST
# (38.6625346, -87.3019057)
#
# W ZEMKE RD
# (41.9959191, -87.8870393)
#
# W 86TH PL
# (41.4598471, -87.34753)
#
# S CHAPPEL AVE
# (41.7588966, -87.5749062)
#
# S ARCHER AVE
# (41.6335223, -88.0133585)
#
# S PEORIA ST
# (39.5974063, -104.8480467)
#
# N WINTHROP AVE
# (41.9873032, -87.6581226)
#
# W 18TH PL
# (30.230237, -85.651847)
#
# S COTTAGE GROVE AVE
# (41.6856412, -87.6114137)
#
# W CULLOM AVE
# (41.9590228, -87.7389563)
#
# E 32ND ST
# (44.94472, -93.2368469)
#
# S EBERHART AVE
# (43.822127, -84.748397)
#
# W WOLFRAM ST
# (41.9335036, -87.6563169)
#
# W ALTGELD ST
# (41.9262007, -87.8075454)
#
# N RUSH ST
# (43.7828197, -86.4281776)
#
# N OLCOTT AVE
# (41.9414041, -87.8141994)
#
# W BERWYN AVE
# (41.9775394, -87.712376)
#
# W 74TH ST
# (40.780251, -73.9814398)
#
# N KEDZIE AVE
# (41.981245, -87.7088348)
#
# N KINGSBURY ST
# (41.8986511, -87.6438839)
#
# N WHIPPLE ST
# (41.9721178, -87.7049131)
#
# N LINCOLN AVE
# (45.660956, -122.6824777)
#
# N ST LOUIS AVE
# (41.9727203, -87.7159449)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# S BISHOP ST
# (39.5665983, -76.9892851)
#
# W WILCOX ST
# (39.7729655, -86.2196271)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# N MAPLEWOOD AVE
# (36.1771957, -95.9078851)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# S JEFFERY BLVD
# (41.7479785, -87.5759176)
#
# N CLYBOURN AVE
# (41.9273774, -87.6724654)
#
# N ST LOUIS AVE
# (41.9727203, -87.7159449)
#
# W GARFIELD BLVD
# (41.7944433, -87.6378706)
#
# S ESCANABA AVE
# (41.7482723, -87.55405)
#
# N Richmond St
# (41.9557758, -87.7019847)
#
# S DOBSON AVE
# (41.764125, -87.5994316)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# S MUSKEGON AVE
# (41.6308631, -87.5542799)
#
# N KEDVALE AVE
# (41.9640717, -87.7315451)
#
# S EGGLESTON AVE
# (35.407396, -97.5137083)
#
# S LUELLA AVE
# (41.7589872, -87.5700366)
#
# N NATOMA AVE
# (43.6443386, -116.4245855)
#
# W SUMMERDALE AVE
# (41.9789237, -87.6696222)
#
# W 39TH PL
# (41.5471943, -87.3456365)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# W HOWARD ST
# (43.4469912, -92.2854434)
#
# S FAIRFIELD AVE
# (41.8828928, -88.0058916)
#
# N STATE ST
# (44.619052, -75.408869)
#
# S WHIPPLE ST
# (42.6302929, -71.3004363)
#
# N MAPLEWOOD AVE
# (36.1771957, -95.9078851)
#
# S Kolin Ave
# (41.6804633, -87.7282162)
#
# S HAMILTON AVE
# (29.4083447, -98.5341118)
#
# S LONGWOOD DR
# (41.1158215, -87.8298037)
#
# N SOUTHPORT AVE
# (41.9507055, -87.6641098)
#
# N LARAMIE AVE
# (41.8954167, -87.7556069)
#
# W ARTHINGTON ST
# (41.8700106, -87.7112288)
#
# W ERIE ST
# (33.3076026, -111.9043792)
#
# S WOOD ST
# (41.343196, -83.119849)
#
# W FARGO AVE
# (36.3572713, -119.6489519)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# N OLEANDER AVE
# (29.253586, -81.0259372)
#
# S EMERALD AVE
# (33.3965996, -111.8035831)
#
# S COLFAX AVE
# (30.853988, -96.9914143)
#
# W 83RD ST
# (41.7432634, -87.6499076)
#
# E HYDE PARK BLVD
# (41.8024947, -87.5867897)
#
# W CHESTNUT ST
# (40.0400916, -76.3165126)
#
# S EMERALD AVE
# (33.3965996, -111.8035831)
#
# N KOLIN AVE
# (41.8840787, -87.7343473)
#
# W BERWYN AVE
# (41.9775394, -87.712376)
#
# W 64TH ST
# (39.0130173, -94.802986)
#
# N BURLING ST
# (41.9148697, -87.6471899)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W OLIVE AVE
# (36.9528135, -120.0566053)
#
# S YALE AVE
# (36.0765216, -95.9221167)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# W CRYSTAL ST
# (28.899691, -82.574754)
#
# N Kimball Ave
# (32.948407, -97.1167804)
#
# E WOODLAND PARK
# (41.832310250000006, -87.60984512475166)
#
# N KILDARE AVE
# (41.9718061, -87.7355466)
#
# S EMERALD AVE
# (33.3965996, -111.8035831)
#
# W ST
# (55.8497133, -4.2656724)
#
# W HUBBARD ST
# (41.7159012, -89.3389805)
#
# N LARAMIE AVE
# (41.8954167, -87.7556069)
#
# W 55TH ST
# (40.7692044, -73.9927944)
#
# S SCOTTSDALE AVE
# (41.7436903, -87.7351604)
#
# N ST LOUIS AVE
# (41.9727203, -87.7159449)
#
# S VERNON AVE
# (32.72251, -96.836774)
#
# W DIVISION ST
# (38.2597099, -87.9979169)
#
# S BURLEY AVE
# (41.7376517, -87.5453086)
#
# S ST LAWRENCE AVE
# (41.7682281, -87.6104913)
#
# S AVENUE F
# (40.55307, -90.047893)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# N ELSTON AVE
# (41.9624991, -87.731967)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# E HURON ST
# (42.281291, -83.7369982)
#
# N Seeley Ave
# (43.5619333, -94.7747364)
#
# N CLAREMONT AVE
# (36.106832, -80.228788)
#
# N RACINE AVE
# (43.003319, -88.216859)
#
# W ROOSEVELT RD
# (41.8568563, -88.1736282)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# S COTTAGE GROVE AVE
# (41.6856412, -87.6114137)
#
# S CLYDE AVE
# (28.2911755, -81.4131903)
#
# N KARLOV AVE
# (41.9677725, -87.7304613)
#
# E ST
# (50.4738724, 4.2358174)
#
# S CREGIER AVE
# (41.7663619, -87.5812232)
#
# S GREEN ST
# (37.8040878, -87.6368672)
#
# W ROOSEVELT RD
# (41.8568563, -88.1736282)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# W ERIE ST
# (33.3076026, -111.9043792)
#
# S STONY ISLAND AVE
# (41.772423, -87.5862745)
#
# W ERIE ST
# (33.3076026, -111.9043792)
#
# S PULASKI RD
# (41.6803208, -87.7198931)
#
# W ERIE ST
# (33.3076026, -111.9043792)
#
# N NARRAGANSETT AVE
# (41.9633701, -87.7869544)
#
# E 57TH ST
# (40.7629694, -73.9739676)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# N HAMILTON AVE
# (40.696537, -73.368294)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# W 43RD ST
# (44.9250102, -93.2909497)
#
# N BROADWAY
# (40.9696948, -73.8844801)
#
# S YATES BLVD
# (41.7408204, -87.5660877)
#
# N NARRAGANSETT AVE
# (41.9633701, -87.7869544)
#
# S CORLISS AVE
# (41.6899396, -87.6012166)
#
# N Humboldt Blvd
# (43.0638817, -87.8978425)
#
# N Kenmore Ave
# (34.0845852, -117.6542025)
#
# W ROOSEVELT RD
# (41.8568563, -88.1736282)
#
# N KASSON AVE
# (41.9643104, -87.7328104)
#
# N OLYMPIA AVE
# (41.9735158, -87.8175696)
#
# S WOOD ST
# (41.343196, -83.119849)
#
# W BERTEAU AVE
# (41.9561908, -87.8158422)
#
# S MARSHFIELD AVE
# (41.8093553, -87.6662057)
#
# N BROADWAY
# (40.9696948, -73.8844801)
#
# N LECLAIRE AVE
# (41.935091, -87.7540962)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# S PEORIA ST
# (39.5974063, -104.8480467)
#
# S TALMAN AVE
# (41.8617849, -87.692024)
#
# S KINGSTON AVE
# (36.044406, -95.9074742)
#
# S Maplewood ave
# (36.0250954, -95.9064784)
#
# S STONY ISLAND AVE
# (41.772423, -87.5862745)
#
# E ILLINOIS ST
# (41.862286, -88.09637)
#
# N MARINE DR
# (33.8164549, -117.8300018)
#
# N ARMOUR ST
# (37.701124, -97.25536)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# S PAULINA ST
# (41.878849, -87.6692204)
#
# S ST LAWRENCE AVE
# (41.7682281, -87.6104913)
#
# S KOMENSKY AVE
# (41.7242244, -87.7231031)
#
# W GIDDINGS ST
# (41.9673952, -87.723111)
#
# W 73RD ST
# (41.7589455, -87.8049929)
#
# N PEORIA
# (40.7175374, -89.5842635)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# N PITTSBURGH AVE
# (41.9448664, -87.8327386)
#
# S MAY ST
# (35.5997263, -77.5918349)
#
# W DIVERSEY PKWY
# (41.9323951, -87.6687745)
#
# W MARGATE TER
# (41.9724667, -87.6521788)
#
# S AVENUE O
# (30.567085, -98.28942)
#
# S PULASKI RD
# (41.6803208, -87.7198931)
#
# E RANDOLPH ST
# (39.430644, -96.7584772)
#
# S SEELEY AVE
# (42.2886768, -89.633005)
#
# E 79TH ST
# (40.7742888, -73.9572899)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# W 95TH ST
# (40.7954358, -73.9757202)
#
# N SOUTHPORT AVE
# (41.9507055, -87.6641098)
#
# S KILDARE AVE
# (41.6744106, -87.7275156)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# W Chestnut ST
# (40.0400916, -76.3165126)
#
# S MAY ST
# (35.5997263, -77.5918349)
#
# S DELANO CT E
# (41.8674021, -87.6325503)
#
# N SPAULDING AVE
# (41.9543894, -87.7104772)
#
# W FLETCHER ST
# (28.324413, -81.40576)
#
# E 63RD ST
# (30.384898, -81.6447918)
#
# W CHASE AVE
# (32.780398, -116.9699604)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# N CLAREMONT AVE
# (36.106832, -80.228788)
#
# S FOREST AVE
# (42.2736405, -83.7331125)
#
# S WINCHESTER AVE
# (46.406387, -105.830479)
#
# S TRUMBULL AVE
# (41.666268, -87.7067038)
#
# S HONORE ST
# (41.8267808, -87.6715176)
#
# W GRACE ST
# (37.5509972, -77.4531109)
#
# S RACINE AVE
# (42.9427005, -88.1582854)
#
# N KOSTNER AVE
# (41.9869013, -87.7382889)
#
# S PARNELL AVE
# (41.6335259, -87.6353874)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# S CICERO AVE
# (41.8545413, -87.7443874)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# W 64TH PL
# (25.881035, -80.3378206)
#
# W 51ST ST
# (40.7597316, -73.9780866)
#
# W WOLFRAM ST
# (41.9335036, -87.6563169)
#
# S WENTWORTH AVE
# (42.9981308, -87.8894434)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W ZEMKE RD
# (41.9959191, -87.8870393)
#
# S BLUE ISLAND AVE
# (41.8541923, -87.6641634)
#
# W NORTH SHORE AVE
# (42.0027093, -87.744558)
#
# W CULLERTON ST
# (41.8556603, -87.641803)
#
# S HOMAN AVE
# (41.6622485, -87.7046222)
#
# W MYRTLE AVE
# (33.540846, -112.4051658)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# S WESTERN AVE
# (43.5185145, -96.751124)
#
# N PLAINFIELD AVE
# (41.9381286, -87.8336538)
#
# N MOZART ST
# (41.963078, -87.699749)
#
# S CALIFORNIA AVE
# (34.1163848, -118.0008539)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# N ELSTON AVE
# (41.9624991, -87.731967)
#
# S WASHTENAW AVE
# (41.8244476, -87.6922106)
#
# S LAVERGNE AVE
# (41.6916676, -87.7446407)
#
# S CAMPBELL AVE
# (37.1712552, -93.2953919)
#
# S OAKLEY AVE
# (41.6631708, -86.1244023)
#
# W FARGO AVE
# (36.3572713, -119.6489519)
#
# S LA SALLE ST
# (41.742861, -88.3242315)
#
# E RANDOLPH ST
# (39.430644, -96.7584772)
#
# S MARSHFIELD AVE
# (41.8093553, -87.6662057)
#
# N CENTRAL PARK AVE
# (41.9751896, -87.7184185)
#
# S KILDARE AVE
# (41.6744106, -87.7275156)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# S DREXEL BLVD
# (35.4636206, -97.5703073)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# E MARQUETTE RD
# (41.7727745, -87.6280678)
#
# N PINE AVE
# (42.669591, -73.790953)
#
# W NELSON ST
# (39.937473, -94.841012)
#
# S SACRAMENTO AVE
# (39.3373525, -74.4801189)
#
# W 87TH ST
# (38.970993, -94.7161832)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# W LAKE ST
# (41.8877192, -87.7651226)
#
# N CLIFTON AVE
# (37.2360894, -93.3271958)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# N LA SALLE DR
# (32.459967, -99.781336)
#
# W 79TH ST
# (40.7849838, -73.9826637)
#
# S LEAVITT ST
# (41.8737714, -87.6813292)
#
# N PULASKI RD
# (41.9640877, -87.7278964)
#
# N SEDGWICK ST
# (37.693255, -97.36976)
#
# N MENARD AVE
# (41.8914776, -87.7700234)
#
# N ELSTON AVE
# (41.9624991, -87.731967)
#
# S RIDGELAND AVE
# (41.8835463, -87.7845574)
#
# S KOSTNER AVE
# (41.6651721, -87.7289951)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# N KEDZIE BLVD
# (41.9245939, -87.7072256)
#
# W SCHOOL ST
# (33.3044468, -96.4028596)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# S CALUMET AVE
# (41.7034033, -86.871671)
#
# S ST LAWRENCE AVE
# (41.7682281, -87.6104913)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# S KEDZIE AVE
# (41.7315967, -87.7021544)
#
# W LEXINGTON ST
# (39.0325997, -97.5948929)
#
# W OGDEN AVE
# (32.341146, -86.3093)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# N CICERO AVE
# (42.0121975, -87.7479383)
#
# W SUPERIOR ST
# (40.857308, -96.805534)
#
# W WARWICK AVE
# (41.695646, -71.528992)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# S SPAULDING AVE
# (34.0288086, -118.3700242)
#
# W 52ND ST
# (40.7680929, -73.9959697)
#
# S MAYFIELD AVE
# (41.8800902, -87.7713848)
#
# S ROCKWELL ST
# (33.3290958, -111.7293356)
#
# W FARRAGUT AVE
# (41.9745691, -87.829751)
#
# N MAYFIELD AVE
# (34.1105096, -117.2902727)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# E 93RD ST
# (40.7810314, -73.9454051)
#
# S SANGAMON ST
# (39.5902655, -89.7359101)
#
# S WOLCOTT AVE
# (41.8741687, -87.6740297)
#
# S LOOMIS ST
# (41.769112, -88.14147)
#
# W JEROME ST
# (42.0184138, -87.7002228)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# N MAYFIELD AVE
# (34.1105096, -117.2902727)
#
# W WINNEMAC AVE
# (41.9733819, -87.667451)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# E 82ND ST
# (41.5041895, -81.6308342)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# W 29TH ST
# (44.9507544, -93.281335)
#
# W ALTGELD ST
# (41.9262007, -87.8075454)
#
# W 87TH ST
# (38.970993, -94.7161832)
#
# S NARRAGANSETT AVE
# (41.7607125, -87.7806016)
#
# S LAFAYETTE AVE
# (39.334709, -74.489355)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# W 63RD ST
# (41.7733805, -87.9889844)
#
# S BENNETT AVE
# (39.047033, -82.645968)
#
# N LEAMINGTON AVE
# (41.8986064, -87.7544655)
#
# E 33RD PL
# (41.557712, -87.296391)
#
# N LUNA AVE
# (34.454345, -119.281645)
#
# W ROOSEVELT RD
# (41.8568563, -88.1736282)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# E 83RD ST
# (41.5024109, -81.6295886)
#
# W PIERCE AVE
# (39.485878, -88.185641)
#
# W LEXINGTON ST
# (39.0325997, -97.5948929)
#
# E 82ND ST
# (41.5041895, -81.6308342)
#
# N KOLMAR AVE
# (41.9710894, -87.7440319)
#
# S CARPENTER ST
# (35.240268, -81.338339)
#
# S MERRILL AVE
# (47.1026257, -104.715102)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# W WILCOX ST
# (39.7729655, -86.2196271)
#
# N SANGAMON ST
# (40.159132, -89.351149)
#
# N CENTRAL PARK AVE
# (41.9751896, -87.7184185)
#
# W PRATT BLVD
# (42.0054657, -87.6658226)
#
# E ST
# (50.4738724, 4.2358174)
#
# N WINTHROP AVE
# (41.9873032, -87.6581226)
#
# S DREXEL BLVD
# (35.4636206, -97.5703073)
#
# N WINTHROP AVE
# (41.9873032, -87.6581226)
#
# S MARTIN ST
# (35.851486, -79.559919)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# N WINTHROP AVE
# (41.9873032, -87.6581226)
#
# N CHRISTIANA AVE
# (41.9702394, -87.7121816)
#
# S PULASKI RD
# (41.6803208, -87.7198931)
#
# S OGLESBY AVE
# (41.7448277, -87.5673518)
#
# S SOUTH SHORE DR
# (41.7687175, -87.5665152)
#
# S PERRY AVE
# (27.74589, -81.794657)
#
# N KIMBALL AVE
# (32.948407, -97.1167804)
#
# W GRAND AVE
# (44.89992, -89.6139466)
#
# N STATE ST
# (44.619052, -75.408869)
#
# W 70TH ST
# (32.442242, -93.866732)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# N MOHAWK ST
# (42.790293, -73.712513)
#
# S INDEPENDENCE BLVD
# (36.8059, -76.116529)
#
# S ELLIS AVE
# (35.309552, -78.616879)
#
# W ST
# (55.8497133, -4.2656724)
#
# N STATE ST
# (44.619052, -75.408869)
#
# S SEELEY AVE
# (42.2886768, -89.633005)
#
# S KINGSTON AVE
# (36.044406, -95.9074742)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# W 66TH ST
# (40.7733596, -73.9809918)
#
# S PARNELL AVE
# (41.6335259, -87.6353874)
#
# N STATE ST
# (44.619052, -75.408869)
#
# N BERNARD ST
# (41.9720734, -87.7146943)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# S AVENUE O
# (30.567085, -98.28942)
#
# S PLYMOUTH CT
# (41.8740189, -87.6286848)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# N OGDEN AVE
# (41.2832412, -111.9678465)
#
# N LECLAIRE AVE
# (41.935091, -87.7540962)
#
# S MERRILL AVE
# (47.1026257, -104.715102)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# W PL
# (39.0445999, -94.6029041)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# N SEELEY AVE
# (43.5619333, -94.7747364)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# W SHERIDAN RD
# (42.490117, -79.250962)
#
# W THOMAS ST
# (43.230666, -75.469829)
#
# N OSCEOLA AVE
# (27.9762873, -82.799457)
#
# W 44TH ST
# (40.680314, -74.107708)
#
# W 26TH ST
# (41.8444628, -87.7092909)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# N WOLCOTT AVE
# (41.9069854, -87.6730408)
#
# E 88TH ST
# (31.936824, -102.398602)
#
# S ADA ST
# (44.9307182, -93.0759931)
#
# W LUNT AVE
# (42.0077782, -87.8200486)
#
# W EVERGREEN AVE
# (34.1350555, -118.0011499)
#
# S RIDGELAND AVE
# (41.8835463, -87.7845574)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# N NEWLAND AVE
# (41.9223472, -87.7988731)
#
# W 83RD ST
# (41.7432634, -87.6499076)
#
# W GRENSHAW ST
# (41.8679092, -87.6630252)
#
# W 64TH ST
# (39.0130173, -94.802986)
#
# W 13TH ST
# (40.5482226, -85.6954353)
#
# W MONTROSE AVE
# (41.9607197, -87.7466474)
#
# S BEVERLY AVE
# (34.741893, -87.674971)
#
# N RAVENSWOOD AVE
# (41.9688187, -87.6741627)
#
# W CONCORD PL
# (40.3981522, -111.9271298)
#
# S STONY ISLAND AVE
# (41.772423, -87.5862745)
#
# E 95TH ST
# (40.7835163, -73.9474639)
#
# S MARSHFIELD AVE
# (41.8093553, -87.6662057)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# W Cornelia Ave
# (33.9618136, -98.6777071)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# E 78TH ST
# (36.0516381, -95.9637058)
#
# E CHICAGO AVE
# (41.8968438, -87.6168932)
#
# N RIVERSIDE PLZ
# (41.846359750000005, -87.80588595707778)
#
# W ZEMKE RD
# (41.9959191, -87.8870393)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# N KILPATRICK AVE
# (41.9699316, -87.74405)
#
# W GRACE ST
# (37.5509972, -77.4531109)
#
# S LAKE PARK AVE
# (41.5348577, -87.2596604)
#
# S PAULINA ST
# (41.878849, -87.6692204)
#
# E 68TH ST
# (36.064123, -95.9448098)
#
# W GEORGE ST
# (55.8634318, -4.2657255)
#
# S SOUTH SHORE DR
# (41.7687175, -87.5665152)
#
# W DOUGLAS BLVD
# (41.8629927, -87.7029508)
#
# S EBERHART AVE
# (43.822127, -84.748397)
#
# E ST
# (50.4738724, 4.2358174)
#
# N DAMEN AVE
# (41.9744669, -87.6793492)
#
# S CANAL ST
# (42.1979758, -72.6021589)
#
# N RICHMOND ST
# (41.9557758, -87.7019847)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# N AVERS AVE
# (41.9628652, -87.724203)
#
# N CENTRAL PARK AVE
# (41.9751896, -87.7184185)
#
# N AVERS AVE
# (41.9628652, -87.724203)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# N ST LOUIS AVE
# (41.9727203, -87.7159449)
#
# E 54TH ST
# (40.757381, -73.966702)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# S COTTAGE GROVE AVE
# (41.6856412, -87.6114137)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# S BENNETT AVE
# (39.047033, -82.645968)
#
# S CICERO AVE
# (41.8545413, -87.7443874)
#
# W ROOSEVELT RD
# (41.8568563, -88.1736282)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W 87TH ST
# (38.970993, -94.7161832)
#
# S HALSTED ST
# (41.5420844, -87.6359687)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# S COMMERCIAL AVE
# (41.7141047, -89.3341986)
#
# S CICERO AVE
# (41.8545413, -87.7443874)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# E 92ND PL
# (38.955221, -94.487792)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# E 53RD ST
# (40.7580248, -73.9701634)
#
# W HUBBARD ST
# (41.7159012, -89.3389805)
#
# N PACIFIC AVE
# (37.8434641, -93.16689)
#
# W CONGRESS PKWY
# (41.8750866, -87.6539866)
#
# N Lincoln Park West
# (41.9192403, -87.6363854)
#
# S BURLEY AVE
# (41.7376517, -87.5453086)
#
# S CREGIER AVE
# (41.7663619, -87.5812232)
#
# S YATES BLVD
# (41.7408204, -87.5660877)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# N BEACON ST
# (41.4586084, -74.4140133)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# E 71ST ST
# (41.5110354, -81.6395881)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# S HONORE ST
# (41.8267808, -87.6715176)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# S CONSTANCE AVE
# (39.1322267, -86.4965916)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# S LOTUS AVE
# (36.7105116, -119.7874097)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# S MARSHFIELD AVE
# (41.8093553, -87.6662057)
#
# W DIVISION ST
# (38.2597099, -87.9979169)
#
# S VERNON AVE
# (32.72251, -96.836774)
#
# W ZEMKE RD
# (41.9959191, -87.8870393)
#
# S HERMITAGE AVE
# (41.7685166, -87.6675589)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# S SHORE DR
# (38.721756, -82.978089)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# W 87TH ST
# (38.970993, -94.7161832)
#
# S OAKLEY AVE
# (41.6631708, -86.1244023)
#
# S RUSSELL DR
# (37.364505, -87.492931)
#
# N KIMBALL AVE
# (32.948407, -97.1167804)
#
# W SHAKESPEARE AVE
# (44.1405017, -93.981392)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# W 78TH ST
# (44.8646695, -93.5812403)
#
# S ADA ST
# (44.9307182, -93.0759931)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W POTOMAC AVE
# (43.0958445, -88.0105462)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# S LAWLER AVE
# (41.6735388, -87.7455584)
#
# N LAKEWOOD AVE
# (31.856847, -102.514627)
#
# S JUSTINE ST
# (41.6714397, -87.6599691)
#
# S EDBROOKE AVE
# (41.6980924, -87.6196287)
#
# N LECLAIRE AVE
# (41.935091, -87.7540962)
#
# N MONTICELLO AVE
# (41.9751716, -87.7196691)
#
# E ST
# (50.4738724, 4.2358174)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# N MENARD AVE
# (41.8914776, -87.7700234)
#
# W 64TH ST
# (39.0130173, -94.802986)
#
# E 25TH ST
# (44.957378, -93.219421)
#
# W 66TH ST
# (40.7733596, -73.9809918)
#
# N LECLAIRE AVE
# (41.935091, -87.7540962)
#
# N LEGETT AVE
# (41.9935033, -87.7539136)
#
# W CATALPA AVE
# (41.9812028, -87.7124733)
#
# W 29TH ST
# (44.9507544, -93.281335)
#
# N BERNARD ST
# (41.9720734, -87.7146943)
#
# S ABERDEEN ST
# (35.7300766, -95.3526173)
#
# N WICKER PARK AVE
# (41.9081219, -87.6760847)
#
# N OCTAVIA AVE
# (41.9362929, -87.8091258)
#
# W JONQUIL TER
# (42.0211554, -87.6706138)
#
# S COLFAX AVE
# (30.853988, -96.9914143)
#
# W 61ST ST
# (44.89257, -93.315002)
#
# S KENNETH AVE
# (41.6814466, -87.7302028)
#
# S TROY ST
# (42.4897468, -83.1419423)
#
# W ROOSEVELT RD
# (41.8568563, -88.1736282)
#
# S MARSHFIELD AVE
# (41.8093553, -87.6662057)
#
# E 83RD ST
# (41.5024109, -81.6295886)
#
# S CHAPPEL AVE
# (41.7588966, -87.5749062)
#
# S HARVARD AVE
# (40.613458, -98.098577)
#
# N HAMLIN AVE
# (41.9737701, -87.7232845)
#
# E 42ND ST
# (40.7486764, -73.9696502)
#
# S YATES BLVD
# (41.7408204, -87.5660877)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# S WILLIAMS AVE
# (42.0992701, -88.009511)
#
# S ELIZABETH ST
# (40.727094, -84.106756)
#
# W AINSLIE ST
# (41.9701978, -87.7164722)
#
# N WOLCOTT AVE
# (41.9069854, -87.6730408)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# S PRINCETON AVE
# (39.7884436, -75.1461365)
#
# W GLADYS AVE
# (41.915226, -87.959294)
#
# N PEORIA ST
# (40.935557, -89.537819)
#
# N SAWYER AVE
# (41.9610885, -87.7094607)
#
# W MELROSE ST
# (40.667262, -73.698695)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# W WARREN BLVD
# (41.8823807, -87.6651175)
#
# S PRINCETON AVE
# (39.7884436, -75.1461365)
#
# S SANGAMON ST
# (39.5902655, -89.7359101)
#
# N KEYSTONE AVE
# (42.0001236, -76.5351751)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# W DICKENS AVE
# (26.2215137, -98.1842927)
#
# S LA SALLE ST
# (41.742861, -88.3242315)
#
# S KENWOOD AVE
# (41.8060326, -87.5935411)
#
# N SACRAMENTO AVE
# (39.341244, -74.483242)
#
# S CLARK ST
# (44.955584, -90.795919)
#
# W CONGRESS PKWY
# (41.8750866, -87.6539866)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# N DAMEN AVE
# (41.9744669, -87.6793492)
#
# S CHRISTIANA AVE
# (28.6675036, -81.4969422)
#
# W ST
# (55.8497133, -4.2656724)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# S CANAL ST
# (42.1979758, -72.6021589)
#
# W ADDISON ST
# (42.226415, -84.406033)
#
# W 38TH PL
# (41.548344, -87.2952495)
#
# S EAST END AVE
# (40.7774069, -73.943042)
#
# S WENTWORTH AVE
# (42.9981308, -87.8894434)
#
# S STONY ISLAND AVE
# (41.772423, -87.5862745)
#
# S DANTE AVE
# (41.5394098, -87.5855724)
#
# S STONY ISLAND AVE
# (41.772423, -87.5862745)
#
# S HERMITAGE AVE
# (41.7685166, -87.6675589)
#
# E 59TH ST
# (40.7639662, -73.9722705)
#
# S SANGAMON ST
# (39.5902655, -89.7359101)
#
# W ST
# (55.8497133, -4.2656724)
#
# W 80TH ST
# (41.7486788, -87.6536729)
#
# N KEDVALE AVE
# (41.9640717, -87.7315451)
#
# N BOSWORTH AVE
# (41.9106545, -87.6665138)
#
# N RIDGE BLVD
# (38.5054097, -77.9726234)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# S OAKENWALD AVE
# (41.8176178, -87.5980256)
#
# W ARCHER AVE
# (40.5846442, -90.9722443)
#
# S KENWOOD AVE
# (41.8060326, -87.5935411)
#
# N LARRABEE ST
# (41.907027, -87.6433116)
#
# W FLETCHER ST
# (28.324413, -81.40576)
#
# E 8TH ST
# (40.7275449, -73.9851784)
#
# W 16TH ST
# (37.3052344, -120.4970248)
#
# N LATROBE AVE
# (41.9852199, -87.7604579)
#
# W 52ND ST
# (40.7680929, -73.9959697)
#
# S DREXEL AVE
# (33.369843, -111.623825)
#
# N PULASKI RD
# (41.9640877, -87.7278964)
#
# S SAGINAW AVE
# (41.6427026, -87.5580689)
#
# N OSCEOLA AVE
# (27.9762873, -82.799457)
#
# N CALIFORNIA AVE
# (33.9287659, -116.9813763)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# S SOUTH SHORE DR
# (41.7687175, -87.5665152)
#
# W ROOSEVELT RD
# (41.8568563, -88.1736282)
#
# S STONY ISLAND AVE
# (41.772423, -87.5862745)
#
# S MILLARD AVE
# (36.725905, -119.6804604)
#
# S PULASKI RD
# (41.6803208, -87.7198931)
#
# N CHRISTIANA AVE
# (41.9702394, -87.7121816)
#
# W BLOOMINGDALE AVE
# (27.8936206, -82.2946314)
#
# W ST
# (55.8497133, -4.2656724)
#
# N WESTERN AVE
# (35.5293143, -97.5298153)
#
# W FARGO AVE
# (36.3572713, -119.6489519)
#
# E 60TH ST
# (44.8942722, -93.2746348)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# N WHIPPLE ST
# (41.9721178, -87.7049131)
#
# N DEWITT PL
# (41.897635, -87.6201917)
#
# W 25TH ST
# (39.802821, -86.1734111)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# S STEWART AVE
# (28.290846, -81.4066339)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# S CHAPPEL AVE
# (41.7588966, -87.5749062)
#
# W HARRISON ST
# (47.453523, -116.785825)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W 55TH ST
# (40.7692044, -73.9927944)
#
# S ST LAWRENCE AVE
# (41.7682281, -87.6104913)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# N PAULINA ST
# (41.9902949, -87.6714344)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# S EMERALD AVE
# (33.3965996, -111.8035831)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# S DREXEL BLVD
# (35.4636206, -97.5703073)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# E HURON ST
# (42.281291, -83.7369982)
#
# S OGLESBY AVE
# (41.7448277, -87.5673518)
#
# S FOREST AVE
# (42.2736405, -83.7331125)
#
# N LUNA AVE
# (34.454345, -119.281645)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# N SHEFFIELD AVE
# (43.1085525, -87.8984732)
#
# S EBERHART AVE
# (43.822127, -84.748397)
#
# S SPAULDING AVE
# (34.0288086, -118.3700242)
#
# N NASHVILLE AVE
# (33.172839, -86.245134)
#
# S MARYLAND AVE
# (39.5941256, -75.9378606)
#
# S DOBSON AVE
# (41.764125, -87.5994316)
#
# S GREEN ST
# (37.8040878, -87.6368672)
#
# W DEVON AVE
# (41.9973572, -87.7114381)
#
# W SURF ST
# (41.9343518, -87.638939)
#
# N KOSTNER AVE
# (41.9869013, -87.7382889)
#
# S SANGAMON ST
# (39.5902655, -89.7359101)
#
# W AINSLIE ST
# (41.9701978, -87.7164722)
#
# S PULASKI RD
# (41.6803208, -87.7198931)
#
# W 71ST ST
# (39.882403, -86.227212)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# W CERMAK RD
# (41.8495374, -87.849713)
#
# S JEFFERY BLVD
# (41.7479785, -87.5759176)
#
# W BELLE PLAINE AVE
# (41.955062, -87.7887068)
#
# N MOZART ST
# (41.963078, -87.699749)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W DIVERSEY AVE
# (41.9263942, -88.0053438)
#
# W GUNNISON ST
# (41.969023, -87.7398109)
#
# N WESTERN AVE
# (35.5293143, -97.5298153)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# W RICE ST
# (35.5516747, -80.6218475)
#
# N HAMILTON AVE
# (40.696537, -73.368294)
#
# S WINCHESTER AVE
# (46.406387, -105.830479)
#
# W 33RD PL
# (39.815778, -86.262383)
#
# N KEYSTONE AVE
# (42.0001236, -76.5351751)
#
# W 64TH PL
# (25.881035, -80.3378206)
#
# S NORMAL AVE
# (37.720105, -89.21769)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# S EMERALD AVE
# (33.3965996, -111.8035831)
#
# W 26TH ST
# (41.8444628, -87.7092909)
#
# S HOLLAND RD
# (43.2411071, -85.1085324)
#
# N WABASH AVE
# (41.1450949, -87.8658414)
#
# N CAMPBELL AVE
# (32.2527259, -110.9439424)
#
# S WOOD ST
# (41.343196, -83.119849)
#
# S EUCLID AVE
# (43.5904697, -83.9155365)
#
# W WAVELAND AVE
# (41.9466715, -87.8113037)
#
# S RICHMOND ST
# (44.8899249, -88.3024977)
#
# S GREENWOOD AVE
# (37.6199047, -96.228166)
#
# S FAIRFIELD AVE
# (41.8828928, -88.0058916)
#
# S NORMAL BLVD
# (41.7792236, -87.637511)
#
# W WEST END AVE
# (41.8840066, -87.7595529)
#
# W ROOSEVELT RD
# (41.8568563, -88.1736282)
#
# W HIGGINS RD
# (42.0465268, -88.0856451)
#
# S JEFFERY BLVD
# (41.7479785, -87.5759176)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# N STATE ST
# (44.619052, -75.408869)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# S MILLARD AVE
# (36.725905, -119.6804604)
#
# S JEFFERY BLVD
# (41.7479785, -87.5759176)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# N ALBANY AVE
# (40.7076835, -73.465108)
#
# N SHEFFIELD AVE
# (43.1085525, -87.8984732)
#
# N STATE ST
# (44.619052, -75.408869)
#
# S HERMITAGE AVE
# (41.7685166, -87.6675589)
#
# S ST LOUIS AVE
# (41.0219002, -87.7208064)
#
# S STEWART AVE
# (28.290846, -81.4066339)
#
# S ELLIS AVE
# (35.309552, -78.616879)
#
# N AUSTIN AVE
# (41.912831, -87.7753338)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# S EVANS AVE
# (35.509722, -97.9558699)
#
# W AUGUSTA BLVD
# (41.4210887, -87.732417)
#
# W 85TH ST
# (40.784673, -73.9699691)
#
# S MILLARD AVE
# (36.725905, -119.6804604)
#
# W GRENSHAW ST
# (41.8679092, -87.6630252)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# S PAULINA ST
# (41.878849, -87.6692204)
#
# S SPRINGFIELD AVE
# (40.6858039, -74.3274558)
#
# S WESTERN BLVD
# (33.2059937, -97.1851139)
#
# W 22ND PL
# (30.188365, -85.710205)
#
# W 26TH ST
# (41.8444628, -87.7092909)
#
# N AVERS AVE
# (41.9628652, -87.724203)
#
# W CORNELIA AVE
# (33.9618136, -98.6777071)
#
# W RACE AVE
# (35.2508634, -91.74748)
#
# E 82ND ST
# (41.5041895, -81.6308342)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# S CALUMET AVE
# (41.7034033, -86.871671)
#
# W WACKER DR
# (30.4717592, -84.349793)
#
# W IRVING PARK RD
# (41.953826, -87.7116755)
#
# S HERMITAGE AVE
# (41.7685166, -87.6675589)
#
# N WABASH AVE
# (41.1450949, -87.8658414)
#
# E 71ST ST
# (41.5110354, -81.6395881)
#
# S RACINE AVE
# (42.9427005, -88.1582854)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W PALATINE AVE
# (41.9953953, -87.8070647)
#
# W 57TH ST
# (40.7714466, -73.9940769)
#
# S AVENUE L
# (31.5331944, -97.4407611)
#
# S GREENWOOD AVE
# (37.6199047, -96.228166)
#
# E 57TH ST
# (40.7629694, -73.9739676)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W GRAND AVE
# (44.89992, -89.6139466)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# N ELSTON AVE
# (41.9624991, -87.731967)
#
# S CICERO AVE
# (41.8545413, -87.7443874)
#
# N ELSTON AVE
# (41.9624991, -87.731967)
#
# W WELLINGTON AVE
# (38.1838186, -85.7649883)
#
# S MILLARD AVE
# (36.725905, -119.6804604)
#
# W 64TH PL
# (25.881035, -80.3378206)
#
# N LATROBE AVE
# (41.9852199, -87.7604579)
#
# S SOUTH SHORE DR
# (41.7687175, -87.5665152)
#
# W CERMAK RD
# (41.8495374, -87.849713)
#
# N MAGNOLIA AVE
# (29.1969846, -82.1365046)
#
# N HUMBOLDT BLVD
# (43.0638817, -87.8978425)
#
# S TORRENCE AVE
# (41.6397957, -87.5592843)
#
# S VERNON AVE
# (32.72251, -96.836774)
#
# S EMERALD AVE
# (33.3965996, -111.8035831)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# S NEWCASTLE AVE
# (41.7885026, -87.7926598)
#
# W CORNELIA AVE
# (33.9618136, -98.6777071)
#
# N SAWYER AVE
# (41.9610885, -87.7094607)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# W 35TH ST
# (41.881364, -103.6683128)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# E 59TH ST
# (40.7639662, -73.9722705)
#
# N MC CLURG CT
# (30.332179, -82.799061)
#
# N DAMEN AVE
# (41.9744669, -87.6793492)
#
# N BEACON ST
# (41.4586084, -74.4140133)
#
# W MARQUETTE RD
# (41.7726852, -87.6253898)
#
# N BEACON ST
# (41.4586084, -74.4140133)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# S YALE AVE
# (36.0765216, -95.9221167)
#
# S ELLIS AVE
# (35.309552, -78.616879)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# S NORMANDY AVE
# (41.7176389, -87.7871653)
#
# N MASSASOIT AVE
# (41.896595, -87.7691028)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# N LAWNDALE AVE
# (41.9592196, -87.720432)
#
# W FARRAGUT AVE
# (41.9745691, -87.829751)
#
# E 54TH ST
# (40.757381, -73.966702)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# W WARREN BLVD
# (41.8823807, -87.6651175)
#
# S GREEN ST
# (37.8040878, -87.6368672)
#
# S HALSTED ST
# (41.5420844, -87.6359687)
#
# N CLARENDON AVE
# (39.3347411, -74.4980139)
#
# S LOOMIS ST
# (41.769112, -88.14147)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# S STEWART AVE
# (28.290846, -81.4066339)
#
# S SOUTH SHORE DR
# (41.7687175, -87.5665152)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# S INGLESIDE AVE
# (41.7403543, -87.601287)
#
# W 95TH ST
# (40.7954358, -73.9757202)
#
# N AVERS AVE
# (41.9628652, -87.724203)
#
# S BLACKSTONE AVE
# (41.78726, -87.881703)
#
# W 16TH ST
# (37.3052344, -120.4970248)
#
# N RIDGEWAY AVE
# (41.9954911, -87.7227208)
#
# S BISHOP ST
# (39.5665983, -76.9892851)
#
# W COLUMBIA AVE
# (47.7106286, -117.421456)
#
# W 21ST PL
# (41.579758, -87.3761617)
#
# S ELLIS AVE
# (35.309552, -78.616879)
#
# N Racine Ave
# (43.003319, -88.216859)
#
# S RIVERSIDE PLZ
# (41.87992545, -87.63872659087485)
#
# N MOBILE AVE
# (35.2845786, -93.1181537)
#
# W ST
# (55.8497133, -4.2656724)
#
# W ST
# (55.8497133, -4.2656724)
#
# W 37TH ST
# (43.6239944, -116.244005)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# S CLARK ST
# (44.955584, -90.795919)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# N TRUMBULL AVE
# (45.5965005, -122.7536356)
#
# S PAULINA ST
# (41.878849, -87.6692204)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# N FRANCISCO AVE
# (26.2217801, -98.3199932)
#
# E 74TH ST
# (40.7710532, -73.9596512)
#
# N PINE GROVE AVE
# (41.9529308, -87.6478914)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S ABERDEEN ST
# (35.7300766, -95.3526173)
#
# S SANGAMON ST
# (39.5902655, -89.7359101)
#
# W THOMAS ST
# (43.230666, -75.469829)
#
# N CLYBOURN AVE
# (41.9273774, -87.6724654)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# W FOSTER AVE
# (41.975528, -87.7281106)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# N HARLEM AVE
# (37.093364, -94.529365)
#
# N LA SALLE DR
# (32.459967, -99.781336)
#
# W DEMING PL
# (41.9292488, -87.6406316)
#
# S MARSHFIELD AVE
# (41.8093553, -87.6662057)
#
# N NEENAH AVE
# (41.9419257, -87.7898424)
#
# S TROY ST
# (42.4897468, -83.1419423)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# N AVERS AVE
# (41.9628652, -87.724203)
#
# S KILDARE AVE
# (41.6744106, -87.7275156)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# N TALMAN AVE
# (41.9139404, -87.6934262)
#
# W LEXINGTON ST
# (39.0325997, -97.5948929)
#
# W WALTON ST
# (33.089508, -83.237513)
#
# S MARQUETTE RD
# (43.029055, -91.1288113)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# W LILL AVE
# (41.9277607, -87.6590552)
#
# W GREENLEAF AVE
# (42.010296, -87.6685965)
#
# N LINCOLN AVE
# (45.660956, -122.6824777)
#
# S CORNELL AVE
# (42.119526, -87.95127)
#
# W CULLERTON ST
# (41.8556603, -87.641803)
#
# W DICKENS AVE
# (26.2215137, -98.1842927)
#
# W 43RD ST
# (44.9250102, -93.2909497)
#
# W LAWRENCE AVE
# (41.9683042, -87.7231431)
#
# W 95TH ST
# (40.7954358, -73.9757202)
#
# E 70TH ST
# (41.4801992, -81.640323)
#
# S CICERO AVE
# (41.8545413, -87.7443874)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# N HOMAN AVE
# (41.8919714, -87.711335)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# S NORMAL AVE
# (37.720105, -89.21769)
#
# S ARTESIAN AVE
# (34.0977413, -117.3182866)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S INGLESIDE AVE
# (41.7403543, -87.601287)
#
# E 71ST ST
# (41.5110354, -81.6395881)
#
# W 49TH PL
# (25.8676564, -80.314512)
#
# W HARRISON ST
# (47.453523, -116.785825)
#
# S DEARBORN ST
# (47.5958836, -122.318572)
#
# E 41ST ST
# (44.928696, -93.2276561)
#
# W 64TH PL
# (25.881035, -80.3378206)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# E ST
# (50.4738724, 4.2358174)
#
# W 34TH ST
# (40.7569672, -74.0047906)
#
# W 25TH PL
# (41.5724621, -87.390001)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# N STATE ST
# (44.619052, -75.408869)
#
# S NASHVILLE AVE
# (41.6675831, -87.7810014)
#
# W DIVISION ST
# (38.2597099, -87.9979169)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W 51ST ST
# (40.7597316, -73.9780866)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W ADDISON ST
# (42.226415, -84.406033)
#
# W BARRY AVE
# (36.8175627, -93.9243727)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# S KEDZIE AVE
# (41.7315967, -87.7021544)
#
# S ST LAWRENCE AVE
# (41.7682281, -87.6104913)
#
# W TAYLOR ST
# ...
# (41.7625938, -87.5688755)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# N PINE AVE
# (42.669591, -73.790953)
#
# W GRAND AVE
# (44.89992, -89.6139466)
#
# S CANAL ST
# (42.1979758, -72.6021589)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W IOWA ST
# (43.0518372, -91.3949007)
#
# N PINE AVE
# (42.669591, -73.790953)
#
# W 58TH ST
# (44.8978415, -93.2888067)
#
# W 23RD ST
# (40.7442808, -73.9960773)
#
# N ST CLAIR ST
# (38.6048814, -89.8103789)
#
# W LAWRENCE AVE
# (41.9683042, -87.7231431)
#
# N BROADWAY
# (40.9696948, -73.8844801)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# N LARAMIE AVE
# (41.8954167, -87.7556069)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# N LATROBE AVE
# (41.9852199, -87.7604579)
#
# N LINDER AVE
# (43.4908412, -116.4138278)
#
# S AVENUE L
# (31.5331944, -97.4407611)
#
# N Central Park Ave
# (41.9751896, -87.7184185)
#
# E ILLINOIS ST
# (41.862286, -88.09637)
#
# W GUNNISON ST
# (41.969023, -87.7398109)
#
# S HARVARD AVE
# (40.613458, -98.098577)
#
# S CANAL ST
# (42.1979758, -72.6021589)
#
# N LOWELL AVE
# (43.051309, -76.184402)
#
# W 63RD ST
# (41.7733805, -87.9889844)
#
# N LANDERS AVE
# (41.9893325, -87.7541529)
#
# S SEELEY AVE
# (42.2886768, -89.633005)
#
# N MALDEN ST
# (41.9687299, -87.6628804)
#
# N SEDGWICK ST
# (37.693255, -97.36976)
#
# N GLENWOOD AVE
# (42.650887, -83.284998)
#
# E 64TH ST
# (25.8805547, -80.2813052)
#
# W SCOTT ST
# (41.661966, -90.591106)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# W MAPLE ST
# (37.6800483, -97.4058021)
#
# S WELLS ST
# (38.0067095, -89.2477996)
#
# W HOLLYWOOD AVE
# (40.664973, -73.381541)
#
# S KOLMAR AVE
# (41.6817099, -87.7322799)
#
# N WOLCOTT AVE
# (41.9069854, -87.6730408)
#
# N ORLEANS ST
# (34.8209213, -87.6356312)
#
# N LA SALLE DR
# (32.459967, -99.781336)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# N OAKLEY AVE
# (41.664195, -86.124499)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W 76TH ST
# (33.9707255, -118.2915697)
#
# S THROOP ST
# (41.7467867, -87.6560654)
#
# N WALLER AVE
# (41.8910824, -87.7677998)
#
# W HARRISON ST
# (47.453523, -116.785825)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# S JUSTINE ST
# (41.6714397, -87.6599691)
#
# W THOMAS ST
# (43.230666, -75.469829)
#
# N CENTRAL PARK AVE
# (41.9751896, -87.7184185)
#
# N LONG AVE
# (31.872625, -102.526908)
#
# S CARPENTER ST
# (35.240268, -81.338339)
#
# S CICERO AVE
# (41.8545413, -87.7443874)
#
# S EWING AVE
# (32.7424571, -96.8126924)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# N JEFFERSON ST
# (43.572607, -76.123675)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# W FERDINAND ST
# (42.4723744, -71.076355)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# S CALUMET AVE
# (41.7034033, -86.871671)
#
# S CHRISTIANA AVE
# (28.6675036, -81.4969422)
#
# W 76TH ST
# (33.9707255, -118.2915697)
#
# S HYDE PARK BLVD
# (41.7978073, -87.5840054)
#
# S UNION AVE
# (47.2491253, -122.4836389)
#
# N SPAULDING AVE
# (41.9543894, -87.7104772)
#
# E 47TH ST
# (40.7546125, -73.9737345)
#
# S HOMAN AVE
# (41.6622485, -87.7046222)
#
# N HOYNE AVE
# (41.9550717, -87.6812061)
#
# S BISHOP ST
# (39.5665983, -76.9892851)
#
# W LEXINGTON ST
# (39.0325997, -97.5948929)
#
# S KOMENSKY AVE
# (41.7242244, -87.7231031)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# W PL
# (39.0445999, -94.6029041)
#
# S WOODLAWN AVE
# (41.7812374, -87.5962214)
#
# S UNION AVE
# (47.2491253, -122.4836389)
#
# W RAVEN ST
# (41.9950834, -87.7834843)
#
# S LAFAYETTE AVE
# (39.334709, -74.489355)
#
# S RIDGEWAY AVE
# (35.61739, -82.3173401)
#
# W 16TH ST
# (37.3052344, -120.4970248)
#
# S ELIZABETH ST
# (40.727094, -84.106756)
#
# W FARWELL AVE
# (42.0067765, -87.6605207)
#
# N RIDGE AVE
# (35.5045339, -80.6185371)
#
# N BROADWAY
# (40.9696948, -73.8844801)
#
# N WHIPPLE ST
# (41.9721178, -87.7049131)
#
# S HERMITAGE AVE
# (41.7685166, -87.6675589)
#
# S LAKE PARK AVE
# (41.5348577, -87.2596604)
#
# S ALBANY AVE
# (27.932852, -82.480986)
#
# S CLAREMONT AVE
# (39.096728, -94.442776)
#
# S CARPENTER ST
# (35.240268, -81.338339)
#
# N WESTERN AVE
# (35.5293143, -97.5298153)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# W AUGUSTA BLVD
# (41.4210887, -87.732417)
#
# S COLFAX AVE
# (30.853988, -96.9914143)
#
# S AVENUE N
# (31.532975, -97.437499)
#
# S CARPENTER ST
# (35.240268, -81.338339)
#
# S KEDZIE AVE
# (41.7315967, -87.7021544)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# E VAN BUREN ST
# (42.3609748, -85.8729469)
#
# N LINCOLN AVE
# (45.660956, -122.6824777)
#
# W ARMITAGE AVE
# (43.1023086, -87.9910021)
#
# W BRIAR PL
# (41.9391149, -87.6468032)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# S HAMILTON AVE
# (29.4083447, -98.5341118)
#
# N RIDGE BLVD
# (38.5054097, -77.9726234)
#
# S ADA ST
# (44.9307182, -93.0759931)
#
# S FAIRFIELD AVE
# (41.8828928, -88.0058916)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# S BLACKSTONE AVE
# (41.78726, -87.881703)
#
# W MAYPOLE AVE
# (41.8835952, -87.7087902)
#
# W Grace St
# (37.5509972, -77.4531109)
#
# S COTTAGE GROVE AVE
# (41.6856412, -87.6114137)
#
# N CAMPBELL AVE
# (32.2527259, -110.9439424)
#
# W WALTON ST
# (33.089508, -83.237513)
#
# S NEW ENGLAND AVE
# (41.716629, -87.7917803)
#
# S PEORIA ST
# (39.5974063, -104.8480467)
#
# S PRINCETON AVE
# (39.7884436, -75.1461365)
#
# S CREGIER AVE
# (41.7663619, -87.5812232)
#
# W 40TH ST
# (30.3041337, -97.7342249)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# S PEORIA ST
# (39.5974063, -104.8480467)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# S CANAL ST
# (42.1979758, -72.6021589)
#
# N ALBANY AVE
# (40.7076835, -73.465108)
#
# S CICERO AVE
# (41.8545413, -87.7443874)
#
# S AVENUE K
# (30.2067336, -92.3643418)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W HIGGINS AVE
# (41.9820571, -87.8112681)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# S MEADE AVE
# (47.1055468, -104.7161105)
#
# W 13TH ST
# (40.5482226, -85.6954353)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# S CREGIER AVE
# (41.7663619, -87.5812232)
#
# W BARRY AVE
# (36.8175627, -93.9243727)
#
# S FEDERAL ST
# (38.443357, -78.870308)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# W ARTHINGTON ST
# (41.8700106, -87.7112288)
#
# N CALIFORNIA AVE
# (33.9287659, -116.9813763)
#
# E CHESTNUT ST
# (40.0418024, -76.2998169)
#
# E DELAWARE PL
# (41.8992723, -87.6202196)
#
# S HARPER AVE
# (33.3743982, -111.6339155)
#
# W GEORGE ST
# (55.8634318, -4.2657255)
#
# N PARIS AVE
# (39.2522659, -94.702998)
#
# W CRYSTAL ST
# (28.899691, -82.574754)
#
# S PRINCETON AVE
# (39.7884436, -75.1461365)
#
# W BLACKHAWK ST
# (43.567624, -96.737549)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# W DIVISION ST
# (38.2597099, -87.9979169)
#
# W 63RD ST
# (41.7733805, -87.9889844)
#
# N WELLS ST
# (30.831592, -83.286031)
#
# S SPRINGFIELD AVE
# (40.6858039, -74.3274558)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S LEAVITT ST
# (41.8737714, -87.6813292)
#
# N ODELL AVE
# (39.1214083, -93.1948712)
#
# S LA SALLE ST
# (41.742861, -88.3242315)
#
# N LINCOLN AVE
# (45.660956, -122.6824777)
#
# W 27TH ST
# (41.873811, -103.670278)
#
# S BENNETT AVE
# (39.047033, -82.645968)
#
# S KOSTNER AVE
# (41.6651721, -87.7289951)
#
# W SUPERIOR ST
# (40.857308, -96.805534)
#
# S KOSTNER AVE
# (41.6651721, -87.7289951)
#
# N LAWLER AVE
# (41.9186896, -87.7523027)
#
# W BARRY AVE
# (36.8175627, -93.9243727)
#
# S KOSTNER AVE
# (41.6651721, -87.7289951)
#
# N KEDVALE AVE
# (41.9640717, -87.7315451)
#
# N NORTHWEST HWY
# (42.0193599, -87.8423973)
#
# N KEDVALE AVE
# (41.9640717, -87.7315451)
#
# S SAWYER AVE
# (47.2288772, -122.4540806)
#
# W CUYLER AVE
# (41.9551763, -87.6742845)
#
# N AVONDALE AVE
# (41.9389804, -87.7082252)
#
# S LAVERGNE AVE
# (41.6916676, -87.7446407)
#
# S DEARBORN ST
# (47.5958836, -122.318572)
#
# N LAVERGNE AVE
# (41.9090105, -87.9045527)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# W HARRISON ST
# (47.453523, -116.785825)
#
# S LAVERGNE AVE
# (41.6916676, -87.7446407)
#
# S GREEN ST
# (37.8040878, -87.6368672)
#
# W WELLINGTON AVE
# (38.1838186, -85.7649883)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W 83RD ST
# (41.7432634, -87.6499076)
#
# E ST
# (50.4738724, 4.2358174)
#
# N DRAKE AVE
# (41.9725027, -87.7171475)
#
# S MAPLEWOOD AVE
# (36.0250954, -95.9064784)
#
# W LELAND AVE
# (41.9666512, -87.7370944)
#
# W SCHUBERT AVE
# (41.921548, -88.096436)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# W 16TH ST
# (37.3052344, -120.4970248)
#
# S CARPENTER ST
# (35.240268, -81.338339)
#
# W HENDERSON ST
# (35.6845746, -80.4331586)
#
# N DRAKE AVE
# (41.9725027, -87.7171475)
#
# N BROADWAY
# (40.9696948, -73.8844801)
#
# S LAKE SHORE DR NB
# (42.25603, -87.998784)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# S KARLOV AVE
# (41.7139045, -87.7235728)
#
# N ORANGE AVE
# (28.5712842, -81.3728175)
#
# E WALTON ST
# (33.0918832, -83.2257331)
#
# S ELLIS AVE
# (35.309552, -78.616879)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# S HARVARD AVE
# (40.613458, -98.098577)
#
# N BERNARD ST
# (41.9720734, -87.7146943)
#
# S PULASKI RD
# (41.6803208, -87.7198931)
#
# W HARRISON ST
# (47.453523, -116.785825)
#
# S WOODLAWN AVE
# (41.7812374, -87.5962214)
#
# W NORMAL PKWY
# (41.7714587, -87.6348352)
#
# S MINERVA AVE
# (42.487236, -83.118805)
#
# S KOSTNER AVE
# (41.6651721, -87.7289951)
#
# S BLUE ISLAND AVE
# (41.8541923, -87.6641634)
#
# S ESCANABA AVE
# (41.7482723, -87.55405)
#
# N KEDZIE AVE
# (41.981245, -87.7088348)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W BUCKINGHAM PL
# (43.6406037, -116.2851637)
#
# W 24TH PL
# (41.5744811, -87.3824265)
#
# S MARYLAND AVE
# (39.5941256, -75.9378606)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W 55TH ST
# (40.7692044, -73.9927944)
#
# S RACINE AVE
# (42.9427005, -88.1582854)
#
# W LAWRENCE AVE
# (41.9683042, -87.7231431)
#
# N WABASH AVE
# (41.1450949, -87.8658414)
#
# S WENTWORTH AVE
# (42.9981308, -87.8894434)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# W WARWICK AVE
# (41.695646, -71.528992)
#
# S LUELLA AVE
# (41.7589872, -87.5700366)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W TOUHY AVE
# (42.0118322, -87.7491207)
#
# W 36TH ST
# (41.8823358, -103.6756337)
#
# N LOTUS AVE
# (35.4704582, -97.3553818)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# W 39TH PL
# (41.5471943, -87.3456365)
#
# N LOTUS AVE
# (35.4704582, -97.3553818)
#
# W RANDOLPH ST
# (36.2743344, -90.9816148)
#
# N SPAULDING AVE
# (41.9543894, -87.7104772)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# S PEORIA ST
# (39.5974063, -104.8480467)
#
# W FULLERTON PKWY
# (41.9256195, -87.6390215)
#
# S CICERO AVE
# (41.8545413, -87.7443874)
#
# N DRAKE AVE
# (41.9725027, -87.7171475)
#
# S HOYNE AVE
# (41.8228899, -87.6774807)
#
# W EVERGREEN AVE
# (34.1350555, -118.0011499)
#
# W WILCOX ST
# (39.7729655, -86.2196271)
#
# W DIVISION ST
# (38.2597099, -87.9979169)
#
# S VERNON AVE
# (32.72251, -96.836774)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# S HALSTED ST
# (41.5420844, -87.6359687)
#
# E WACKER DR
# (41.8878388, -87.6190596)
#
# S RIDGEWAY AVE
# (35.61739, -82.3173401)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# W MONTROSE AVE
# (41.9607197, -87.7466474)
#
# W QUINCY ST
# (28.0541053, -81.9636599)
#
# W 21ST ST
# (44.961758, -93.306244)
#
# W LEXINGTON ST
# (39.0325997, -97.5948929)
#
# S ELIZABETH ST
# (40.727094, -84.106756)
#
# S CLARK ST
# (44.955584, -90.795919)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# N HOYNE AVE
# (41.9550717, -87.6812061)
#
# W 19TH ST
# (30.1833503, -85.7294777)
#
# N HERMITAGE AVE
# (40.232782, -74.780752)
#
# S LOOMIS BLVD
# (41.7570599, -87.6587609)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# W LAWRENCE AVE
# (41.9683042, -87.7231431)
#
# E 42ND ST
# (40.7486764, -73.9696502)
#
# S WENTWORTH AVE
# (42.9981308, -87.8894434)
#
# E ST
# (50.4738724, 4.2358174)
#
# S HALSTED ST
# (41.5420844, -87.6359687)
#
# S LA SALLE ST
# (41.742861, -88.3242315)
#
# N CENTRAL AVE
# (35.7718102, -91.6557941)
#
# W DIVERSEY AVE
# (41.9263942, -88.0053438)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# N WESTERN AVE
# (35.5293143, -97.5298153)
#
# W CARROLL AVE
# (34.1342246, -117.8674488)
#
# W GLADYS AVE
# (41.915226, -87.959294)
#
# S COLES AVE
# (41.7483376, -87.5491898)
#
# W ST
# (55.8497133, -4.2656724)
#
# N MONITOR AVE
# (41.9791477, -87.7744717)
#
# W 81ST ST
# (41.7469141, -87.6500179)
#
# W GRAND AVE
# (44.89992, -89.6139466)
#
# W WASHINGTON ST
# (40.194732, -85.391486)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# S COLES AVE
# (41.7483376, -87.5491898)
#
# W ADDISON ST
# (42.226415, -84.406033)
#
# N SHEFFIELD AVE
# (43.1085525, -87.8984732)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# S UNION AVE
# (47.2491253, -122.4836389)
#
# S GREEN ST
# (37.8040878, -87.6368672)
#
# S VINCENNES AVE
# (41.6979977, -87.6592612)
#
# N PULASKI RD
# (41.9640877, -87.7278964)
#
# W CHASE AVE
# (32.780398, -116.9699604)
#
# S TALMAN AVE
# (41.8617849, -87.692024)
#
# N OCONTO AVE
# (41.9452423, -87.8081992)
#
# W GRANVILLE AVE
# (40.245255, -96.754104)
#
# W WILSON AVE
# (47.6575559, -117.4351579)
#
# W SWANN ST
# (41.8099363, -87.6295772)
#
# S KILDARE AVE
# (41.6744106, -87.7275156)
#
# N DAMEN AVE
# (41.9744669, -87.6793492)
#
# N ELSTON AVE
# (41.9624991, -87.731967)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# W 60TH ST
# (44.89423, -93.301147)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# W 71ST ST
# (39.882403, -86.227212)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# N LECLAIRE AVE
# (41.935091, -87.7540962)
#
# W 53RD PL
# (25.87113, -80.327087)
#
# N Bell Ave
# (32.2464153, -110.8940884)
#
# W GRACE ST
# (37.5509972, -77.4531109)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# N MAJOR AVE
# (36.0352811, -114.9680661)
#
# W 60TH ST
# (44.89423, -93.301147)
#
# E 93RD ST
# (40.7810314, -73.9454051)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# N RACINE AVE
# (43.003319, -88.216859)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# W SCHOOL ST
# (33.3044468, -96.4028596)
#
# W 59TH ST
# (40.7646364, -73.9737661)
#
# W 51ST PL
# (25.8690101, -80.2988702)
#
# W 73RD ST
# (41.7589455, -87.8049929)
#
# N CENTRAL AVE
# (35.7718102, -91.6557941)
#
# W ST
# (55.8497133, -4.2656724)
#
# S KENWOOD AVE
# (41.8060326, -87.5935411)
#
# W HARRISON ST
# (47.453523, -116.785825)
#
# N LAWNDALE AVE
# (41.9592196, -87.720432)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# E 54TH PL
# (39.851389, -86.050353)
#
# S LINDER AVE
# (41.8065728, -87.760244)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# S JEFFERY AVE
# (41.6446365, -87.5754872)
#
# S DANTE AVE
# (41.5394098, -87.5855724)
#
# W GRENSHAW ST
# (41.8679092, -87.6630252)
#
# N SPAULDING AVE
# (41.9543894, -87.7104772)
#
# S DOBSON AVE
# (41.764125, -87.5994316)
#
# S PERRY AVE
# (27.74589, -81.794657)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# S HOUSTON AVE
# (29.7104805, -98.1173779)
#
# N RIDGEWAY AVE
# (41.9954911, -87.7227208)
#
# W ROSCOE ST
# (41.9417774, -87.798255)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W WILCOX ST
# (39.7729655, -86.2196271)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S LEAVITT ST
# (41.8737714, -87.6813292)
#
# N NARRAGANSETT AVE
# (41.9633701, -87.7869544)
#
# S HYDE PARK BLVD
# (41.7978073, -87.5840054)
#
# S CANAL ST
# (42.1979758, -72.6021589)
#
# W PALMER ST
# (35.1795946, -83.3858583)
#
# W Jarvis Ave
# (42.0153543, -87.8050829)
#
# W IRVING PARK RD
# (41.953826, -87.7116755)
#
# S HILLOCK AVE
# (41.8421125, -87.6629531)
#
# W THORNDALE AVE
# (41.9885001, -87.7104758)
#
# S CHICAGO BEACH DR
# (41.8059766, -87.5853623)
#
# S KOMENSKY AVE
# (41.7242244, -87.7231031)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# S CRANDON AVE
# (41.7625938, -87.5688755)
#
# S LUELLA AVE
# (41.7589872, -87.5700366)
#
# N HAMLIN AVE
# (41.9737701, -87.7232845)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# W DIVISION ST
# (38.2597099, -87.9979169)
#
# S WASHTENAW AVE
# (41.8244476, -87.6922106)
#
# S EXCHANGE AVE
# (35.0704184, -92.4212449)
#
# S KEATING AVE
# (33.3664683, -111.8640276)
#
# N MENARD AVE
# (41.8914776, -87.7700234)
#
# W WAVELAND AVE
# (41.9466715, -87.8113037)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# E 93RD ST
# (40.7810314, -73.9454051)
#
# W EVERGREEN AVE
# (34.1350555, -118.0011499)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# S KIMBARK AVE
# (41.7673136, -87.5941382)
#
# S BENSLEY AVE
# (41.6390654, -87.5628808)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W 25TH ST
# (39.802821, -86.1734111)
#
# N KOSTNER AVE
# (41.9869013, -87.7382889)
#
# S NEENAH AVE
# (44.820963, -87.382074)
#
# W 21ST PL
# (41.579758, -87.3761617)
#
# S PEORIA ST
# (39.5974063, -104.8480467)
#
# N ORCHARD ST
# (43.0517216, -77.093211)
#
# N LATROBE AVE
# (41.9852199, -87.7604579)
#
# W MONTROSE AVE
# (41.9607197, -87.7466474)
#
# S CALUMET AVE
# (41.7034033, -86.871671)

# %%
# Save Checkpoint 
df2020_geo = df_2020.copy()

# %%
# Filter location that is not null
df2020_geo = df2020_geo[df2020_geo['location'].notna()]

# %%
df2020_geo = impute_district(df2020_geo)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:113: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326

# %%
# Drop columns
df2020_geo.drop(['district', 'index_right'], axis=1, inplace=True)

# Rename columns
df2020_geo.rename(columns={'dist_num':'district'}, inplace=True)

# %%
# Impute updated ward values
df2020_geo = impute_ward(df2020_geo)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:69: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326

# %%
# Drop columns
df2020_geo.drop(['ward_left', 'index_right'], axis=1, inplace=True)

# Rename columns
df2020_geo.rename(columns={'ward_right':'ward'}, inplace=True)

# %%
# Impute updated district values
df2020_geo = impute_commareas(df2020_geo)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:91: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326

# %%
# Drop columns
df2020_geo.drop(['community_area', 'index_right'], axis=1, inplace=True)

# Rename columns
df2020_geo.rename(columns={'area_numbe':'community_area'}, inplace=True)

# %%
# Balance clean up of dataset after transformation
# Drop columns
df2020_geo.drop(['x_coordinate', 'y_coordinate'], axis=1, inplace=True)

# Assign null values in location description to 'OTHER (Specify)'
df2020_geo['location_description'].fillna('OTHER (SPECIFY)', inplace = True)

# %%
df2020_geo.to_csv('/content/drive/MyDrive/Colab Notebooks/capstone/assets/2020_crime_clean.csv', index=False)

# %%
df2020_geo.isnull().sum()
# Out:
# id                      0
# case_number             0
# date                    0
# block                   0
# iucr                    0
# primary_type            0
# description             0
# location_description    0
# arrest                  0
# domestic                0
# beat                    0
# fbi_code                0
# year                    0
# updated_on              0
# latitude                0
# longitude               0
# location                0
# day                     0
# month                   0
# day_of_week             0
# time                    0
# geometry                0
# district                0
# ward                    0
# community_area          0
# dtype: int64

# %% [markdown]
# ## Clean data (2019)

# %%
# from geopy.geocoders import Nominatim
geocoder = Nominatim(user_agent = 'crime_predictions')

# %%
df_2019 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/capstone/assets/2019_crime.csv')
df_2019.head()
# Out:
#          id case_number                 date                 block  iucr  \
# 0  11864018    JC476123  2019-09-24 08:00:00  022XX S MICHIGAN AVE  1154
# 1  11859805    JC471592  2019-10-13 20:30:00   024XX W CHICAGO AVE  0860
# 2  11863808    JC476236  2019-10-05 18:30:00     0000X N LOOMIS ST  0810
# 3  11859727    JC471542  2019-10-13 19:00:00    016XX W ADDISON ST  1320
# 4  11859656    JC471240  2019-10-13 14:10:00      051XX N BROADWAY  0560
#
#          primary_type                              description  \
# 0  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 1               THEFT                             RETAIL THEFT
# 2               THEFT                                OVER $500
# 3     CRIMINAL DAMAGE                               TO VEHICLE
# 4             ASSAULT                                   SIMPLE
#
#            location_description  arrest  domestic  beat  district  ward  \
# 0  COMMERCIAL / BUSINESS OFFICE   False     False   132       1.0   3.0
# 1            GROCERY FOOD STORE   False     False  1221      12.0  26.0
# 2                     RESIDENCE   False     False  1224      12.0  27.0
# 3                        STREET   False     False  1922      19.0  47.0
# 4                   GAS STATION   False     False  2033      20.0  47.0
#
#    community_area fbi_code  x_coordinate  y_coordinate  year  \
# 0            33.0       11     1177560.0     1889548.0  2019
# 1            24.0       06     1160005.0     1905256.0  2019
# 2            28.0       06     1166986.0     1900306.0  2019
# 3             6.0       14     1164930.0     1923972.0  2019
# 4             3.0      08A     1167380.0     1934505.0  2019
#
#                updated_on   latitude  longitude  \
# 0  10/20/2019 03:56:02 PM  41.852248 -87.623786
# 1  10/20/2019 04:03:03 PM  41.895732 -87.687784
# 2  10/20/2019 03:56:02 PM  41.882002 -87.662287
# 3  10/20/2019 04:03:03 PM  41.946987 -87.669164
# 4  10/20/2019 04:03:03 PM  41.975838 -87.659854
#
#                         location  day  month  day_of_week  time
# 0  (41.852248185, -87.623786256)   24      9            1     8
# 1  (41.895732399, -87.687784384)   13     10            6    20
# 2   (41.88200224, -87.662286977)    5     10            5    18
# 3  (41.946987144, -87.669163602)   13     10            6    19
# 4  (41.975837637, -87.659853835)   13     10            6    14

# %%
df_2019.isnull().sum()
# Out:
# id                         0
# case_number                0
# date                       0
# block                      0
# iucr                       0
# primary_type               0
# description                0
# location_description    1172
# arrest                     0
# domestic                   0
# beat                       0
# district                   0
# ward                      15
# community_area             0
# fbi_code                   0
# x_coordinate            1618
# y_coordinate            1618
# year                       0
# updated_on                 0
# latitude                1618
# longitude               1618
# location                1618
# day                        0
# month                      0
# day_of_week                0
# time                       0
# dtype: int64

# %%
replace_to_zero(df_2019)

# %%
index_list = missing_row_loc(df_2019)
# Out:
# 1618

# %%
impute_data(df_2019, index_list)
# Out:
# [10, 18, 19, 23, 35, 37, 40, 43, 58, 69, 89, 92, 103, 121, 123, 125, 138, 160, 164, 188, 200, 218, 219, 224, 254, 276, 323, 336, 541, 542, 544, 545, 546, 547, 548, 549, 550, 551, 552, 553, 554, 555, 556, 557, 558, 559, 560, 561, 562, 563, 564, 565, 566, 567, 568, 569, 570, 571, 572, 573, 574, 575, 577, 578, 579, 580, 581, 582, 583, 584, 585, 586, 587, 588, 589, 590, 591, 592, 593, 594, 595, 596, 597, 603, 610, 618, 620, 622, 623, 624, 626, 627, 628, 630, 631, 632, 633, 634, 635, 636, 637, 638, 639, 640, 649, 653, 654, 658, 660, 662, 680, 729, 730, 737, 758, 779, 791, 812, 823, 1150, 1198, 1199, 1268, 1292, 1334, 1346, 1402, 1420, 1827, 1828, 1829, 1834, 1836, 1838, 1982, 2324, 2387, 2400, 2427, 2508, 2575, 2628, 2811, 2890, 2946, 2947, 3067, 3105, 3230, 3392, 3521, 3552, 3575, 3592, 3681, 3683, 3684, 3685, 3686, 3687, 3689, 3708, 3953, 4179, 4206, 4414, 4494, 4571, 4812, 4893, 5114, 5143, 5149, 5151, 5152, 5154, 5238, 5676, 5807, 5823, 5944, 5998, 6298, 13734, 24673, 25158, 29180, 29328, 29330, 29332, 29333, 29386, 29410, 29483, 29693, 29716, 29789, 33770, 38480, 41706, 66061, 68926, 69780, 74952, 80397, 88417, 96050, 96212, 96264, 96381, 96400, 96401, 96403, 96406, 96413, 96666, 96749, 96791, 96951, 97157, 97173, 97176, 97177, 97650, 97670, 97722, 97740, 97763, 97774, 97830, 98080, 98321, 98553, 98669, 98673, 98725, 99225, 99318, 99385, 99423, 99539, 99546, 99692, 100077, 100185, 100663, 100676, 101064, 101096, 101099, 101106, 101110, 101282, 101321, 101524, 101561, 101779, 101991, 102054, 102139, 102372, 102782, 103127, 103135, 103192, 103382, 103541, 103653, 103721, 103776, 103817, 103900, 104105, 104121, 104129, 104137, 104140, 104152, 104188, 104192, 104212, 104221, 104234, 104268, 104279, 104287, 104300, 104307, 104327, 104333, 104340, 104341, 104347, 104353, 104363, 104364, 104372, 104373, 104377, 104379, 104380, 104383, 104386, 104387, 104454, 104455, 104457, 104458, 104459, 104460, 104461, 104462, 104463, 104464, 104465, 104466, 104468, 104469, 104470, 104476, 104477, 104506, 104522, 104582, 104711, 104924, 104975, 104976, 104977, 104978, 104979, 104983, 104986, 104987, 104989, 104990, 105005, 105008, 105009, 105011, 105012, 105028, 105030, 105031, 105040, 105043, 105052, 105060, 105061, 105079, 105088, 105094, 105105, 105106, 105110, 105129, 105139, 105147, 105148, 105159, 105163, 105173, 105189, 105234, 105235, 105239, 105251, 105252, 105269, 105281, 105287, 105308, 105311, 105312, 105313, 105314, 105315, 105316, 105317, 105318, 105319, 105321, 105322, 105323, 105324, 105325, 105326, 105327, 105328, 105329, 105330, 105331, 105332, 105334, 105335, 105336, 105337, 105338, 105339, 105340, 105341, 105342, 105356, 105357, 105358, 105359, 105360, 105362, 105367, 105370, 105373, 105531, 106165, 106600, 106895, 107053, 107104, 107179, 107234, 108010, 110194, 126596, 127166, 131904, 132547, 133835, 133965, 134025, 134370, 134504, 134510, 135247, 135931, 135974, 136195, 136199, 136675, 136685, 136745, 136939, 136941, 137341, 138061, 138160, 138276, 138451, 139189, 139207, 139422, 139437, 139502, 139567, 139624, 139904, 139957, 140086, 140429, 140655, 140883, 141233, 141235, 141258, 141349, 141466, 141484, 141515, 141547, 141550, 141600, 141638, 141750, 141766, 141773, 141782, 141894, 142089, 142152, 142196, 142203, 142273, 142423, 142776, 142937, 143067, 143316, 143377, 143436, 143440, 143744, 143811, 143813, 143815, 144191, 144194, 144232, 144238, 144248, 144249, 144250, 144720, 144777, 144819, 144951, 145024, 145098, 145105, 145124, 145167, 145214, 145255, 145466, 145481, 145556, 145569, 145583, 145841, 145885, 145904, 146076, 146275, 146495, 146761, 146896, 146974, 147103, 147119, 147403, 147696, 148970, 149507, 149645, 149883, 149986, 153993, 154631, 159451, 159735, 159865, 160288, 160624, 160730, 160918, 161060, 161123, 161336, 161468, 161984, 162136, 162244, 162641, 162819, 162848, 163184, 163263, 163312, 163785, 163820, 163956, 163993, 164146, 164281, 164484, 165131, 165682, 165901, 166181, 166580, 166786, 166865, 1671 ...
#
# N ogden ave
# (41.2832412, -111.9678465)
#
# N WELLS ST
# (30.831592, -83.286031)
#
# E MONROE ST
# (38.305137, -89.992146)
#
# W Ogden Ave
# (32.341146, -86.3093)
#
# W ARLINGTON PL
# (28.8134399, -82.5451972)
#
# E 75TH ST
# (38.985274, -94.4306042)
#
# W Crystal St
# (28.899691, -82.574754)
#
# N DAYTON ST
# (43.1198845, -85.5544939)
#
# W LUNT AVE
# (42.0077782, -87.8200486)
#
# S KIMBARK AVE
# (41.7673136, -87.5941382)
#
# W Estes Ave
# (32.008665, -102.081306)
#
# N Racine Ave
# (43.003319, -88.216859)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# S PARNELL AVE
# (41.6335259, -87.6353874)
#
# S GREEN BAY AVE
# (41.6372553, -87.540884)
#
# W IDA B WELLS DR
# (41.8756771, -87.6325771)
#
# S EGGLESTON AVE
# (35.407396, -97.5137083)
#
# N LISTER AVE
# (39.2768708, -94.5233747)
#
# S LA SALLE ST
# (41.742861, -88.3242315)
#
# W BELDEN AVE
# (41.9187168, -87.9610749)
#
# N LA SALLE ST
# (30.398997, -96.0961872)
#
# W DIVISION ST
# (38.2597099, -87.9979169)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# N STATE ST
# (44.619052, -75.408869)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# N WESTERN AVE
# (35.5293143, -97.5298153)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# E erie st
# (33.3090107, -111.8198088)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# W HARRISON ST
# (47.453523, -116.785825)
#
# N ST LOUIS AVE
# (41.9727203, -87.7159449)
#
# E ROOSEVELT RD
# (41.858902, -88.097724)
#
# N Broadway
# (40.9696948, -73.8844801)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# W DIVISION ST
# (38.2597099, -87.9979169)
#
# W DIVERSEY PKWY
# (41.9323951, -87.6687745)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# N CENTRAL AVE
# (35.7718102, -91.6557941)
#
# S Financial Pl
# (41.8752586, -87.6330631)
#
# N WINCHESTER AVE
# (46.4110364, -105.830487)
#
# W LAKE ST
# (41.8877192, -87.7651226)
#
# W OHIO ST
# (40.646058, -83.609337)
#
# S LOOMIS BLVD
# (41.7570599, -87.6587609)
#
# N Racine Ave
# (43.003319, -88.216859)
#
# N BISSELL ST
# (39.502357, -89.763274)
#
# W HUBBARD ST
# (41.7159012, -89.3389805)
#
# N OLEANDER AVE
# (29.253586, -81.0259372)
#
# W WALTON ST
# (33.089508, -83.237513)
#
# N STATE ST
# (44.619052, -75.408869)
#
# E IDA B WELLS DR
# (41.8757455, -87.6251804)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# W CRYSTAL ST
# (28.899691, -82.574754)
#
# N KINGSBURY ST
# (41.8986511, -87.6438839)
#
# W PENSACOLA AVE
# (41.9604024, -87.6892707)
#
# W WELLINGTON AVE
# (38.1838186, -85.7649883)
#
# W RANDOLPH ST
# (36.2743344, -90.9816148)
#
# W BRIAR PL
# (41.9391149, -87.6468032)
#
# S Michigan Ave
# (42.59934, -83.9336293)
#
# N STATE ST
# (44.619052, -75.408869)
#
# W CATALPA AVE
# (41.9812028, -87.7124733)
#
# W ALTGELD ST
# (41.9262007, -87.8075454)
#
# S Parnell Ave
# (41.6335259, -87.6353874)
#
# W Montana St
# (45.6644428, -110.568881)
#
# S CICERO AVE
# (41.8545413, -87.7443874)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# W 31ST ST
# (44.9466054, -93.2862078)
#
# W Race Ave
# (35.2508634, -91.74748)
#
# E 54TH ST
# (40.757381, -73.966702)
#
# N FRANKLIN ST
# (43.053353, -76.154839)
#
# W LOYOLA AVE
# (26.2877836, -98.2438166)
#
# S LOOMIS BLVD
# (41.7570599, -87.6587609)
#
# N Western Ave
# (35.5293143, -97.5298153)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# N ST CLAIR ST
# (38.6048814, -89.8103789)
#
# N Michigan ave
# (43.4553256, -83.9500328)
#
# W Taylor St
# (41.3837633, -75.7166377)
#
# E Walton St
# (33.0918832, -83.2257331)
#
# N SACRAMENTO AVE
# (39.341244, -74.483242)
#
# N STATE ST
# (44.619052, -75.408869)
#
# W OHIO ST
# (40.646058, -83.609337)
#
# E 60TH ST
# (44.8942722, -93.2746348)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# W foster ave
# (41.975528, -87.7281106)
#
# E OHIO ST
# (40.601786, -84.084445)
#
# N Wolcott Ave
# (41.9069854, -87.6730408)
#
# N GENEVA TER
# (41.9237147, -87.643845)
#
# W TERMINAL ST
# (38.3711643, -88.065751)
#
# N WINTHROP AVE
# (41.9873032, -87.6581226)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# N LINCOLN AVE
# (45.660956, -122.6824777)
#
# N ELAINE PL
# (41.944742, -87.6477153)
#
# N halsted st
# (41.9468528, -87.649475)
#
# W LAKE ST
# (41.8877192, -87.7651226)
#
# W ERIE ST
# (33.3076026, -111.9043792)
#
# W FOSTER AVE
# (41.975528, -87.7281106)
#
# W 17TH ST
# (30.1810582, -85.7266273)
#
# N spaulding ave
# (41.9543894, -87.7104772)
#
# W PRATT BLVD
# (42.0054657, -87.6658226)
#
# W HOOD AVE
# (46.214711, -119.1458494)
#
# N MULLIGAN AVE
# (41.9602275, -87.7855735)
#
# N SACRAMENTO AVE
# (39.341244, -74.483242)
#
# N MOZART ST
# (41.963078, -87.699749)
#
# S Wabash Ave
# (34.1314901, -117.8625756)
#
# N WOOD ST
# (32.3586259, -97.3959405)
#
# N ELSTON AVE
# (41.9624991, -87.731967)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# W TERMINAL ST
# (38.3711643, -88.065751)
#
# E 89TH PL
# (36.0340257, -95.9045251)
#
# N HERMITAGE AVE
# (40.232782, -74.780752)
#
# W WRIGHTWOOD AVE
# (41.9247283, -87.9553717)
#
# N Hoyne Ave
# (41.9550717, -87.6812061)
#
# N FRANCISCO AVE
# (26.2217801, -98.3199932)
#
# N SOUTHPORT AVE
# (41.9507055, -87.6641098)
#
# W CRYSTAL ST
# (28.899691, -82.574754)
#
# W RANDOLPH ST
# (36.2743344, -90.9816148)
#
# S edbrooke ave
# (41.6980924, -87.6196287)
#
# N NARRAGANSETT AVE
# (41.9633701, -87.7869544)
#
# W 47TH ST
# (40.7580163, -73.9817975)
#
# S KENNETH AVE
# (41.6814466, -87.7302028)
#
# S DORCHESTER AVE
# (41.861114, -88.126156)
#
# N ARTESIAN AVE
# (41.9254283, -87.6888852)
#
# S RIVERSIDE PLZ
# (41.87992545, -87.63872659087485)
#
# N STATE ST
# (44.619052, -75.408869)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# W DICKENS AVE
# (26.2215137, -98.1842927)
#
# N NEWGARD AVE
# (42.0017777, -87.666857)
#
# W EASTWOOD AVE
# (41.9656467, -87.7297858)
#
# S FAIRFIELD AVE
# (41.8828928, -88.0058916)
#
# N DAMEN AVE
# (41.9744669, -87.6793492)
#
# S DANTE AVE
# (41.5394098, -87.5855724)
#
# E LAKE ST
# (44.9483802, -93.2053802)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# N Halsted St
# (41.9468528, -87.649475)
#
# E OAKWOOD BLVD
# (41.8241108, -87.6043228)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# W TERMINAL ST
# (38.3711643, -88.065751)
#
# N LA SALLE ST
# (30.398997, -96.0961872)
#
# W Augusta Blvd
# (41.4210887, -87.732417)
#
# S DEARBORN ST
# (47.5958836, -122.318572)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# E CULLERTON ST
# (41.8555004, -87.6231244)
#
# S WACKER DR
# (41.8753503, -87.6357587)
#
# S FOREST AVE
# (42.2736405, -83.7331125)
#
# S DEARBORN ST
# (47.5958836, -122.318572)
#
# S ESCANABA AVE
# (41.7482723, -87.55405)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# S DEARBORN ST
# (47.5958836, -122.318572)
#
# S WOODLAWN AVE
# (41.7812374, -87.5962214)
#
# N HAMILTON AVE
# (40.696537, -73.368294)
#
# W LE MOYNE ST
# (41.9077136, -87.7331889)
#
# E Grand Ave
# (36.7105116, -119.7874097)
#
# N STATE ST
# (44.619052, -75.408869)
#
# N RUSH ST
# (43.7828197, -86.4281776)
#
# N SEDGWICK ST
# (37.693255, -97.36976)
#
# E IDA B WELLS DR
# (41.8757455, -87.6251804)
#
# S CICERO AVE
# (41.8545413, -87.7443874)
#
# W ROSCOE ST
# (41.9417774, -87.798255)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# S DELANO CT E
# (41.8674021, -87.6325503)
#
# N LAKEWOOD AVE
# (31.856847, -102.514627)
#
# S LAKE SHORE DR SB
# E OHIO ST
# (40.601786, -84.084445)
#
# N PARK DR
# (33.529842, -90.205781)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# S LAKE PARK AVE
# (41.5348577, -87.2596604)
#
# N WELLS ST
# (30.831592, -83.286031)
#
# W WACKER DR
# (30.4717592, -84.349793)
#
# W OAKDALE AVE
# (29.0407755, -81.3169917)
#
# N HARBOR DR
# (38.7256772, -89.2919982)
#
# N Hermitage Ave
# (40.232782, -74.780752)
#
# N WELLS ST
# (30.831592, -83.286031)
#
# S DEARBORN ST
# (47.5958836, -122.318572)
#
# S EVERETT AVE
# (42.087455, -79.227396)
#
# S CHAPPEL AVE
# (41.7588966, -87.5749062)
#
# N HARLEM AVE
# (37.093364, -94.529365)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# N WIELAND ST
# (41.9098507, -87.6356493)
#
# N LINCOLN AVE
# (45.660956, -122.6824777)
#
# N CALIFORNIA AVE
# (33.9287659, -116.9813763)
#
# W AUGUSTA BLVD
# (41.4210887, -87.732417)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S SEELEY AVE
# (42.2886768, -89.633005)
#
# W DICKENS AVE
# (26.2215137, -98.1842927)
#
# W NORTH SHORE AVE
# (42.0027093, -87.744558)
#
# S BLACKSTONE AVE
# (41.78726, -87.881703)
#
# S Throop St
# (41.7467867, -87.6560654)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# N OSCEOLA AVE
# (27.9762873, -82.799457)
#
# S DEARBORN ST
# (47.5958836, -122.318572)
#
# N WHIPPLE ST
# (41.9721178, -87.7049131)
#
# S RIDGELAND AVE
# (41.8835463, -87.7845574)
#
# W GRAND AVE
# (44.89992, -89.6139466)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# N LAWLER AVE
# (41.9186896, -87.7523027)
#
# W ROSEDALE AVE
# (42.9685598, -71.4632274)
#
# S CANAL ST
# (42.1979758, -72.6021589)
#
# S BISHOP ST
# (39.5665983, -76.9892851)
#
# W 63RD ST
# (41.7733805, -87.9889844)
#
# E IDA B WELLS DR
# (41.8757455, -87.6251804)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# W Drummond PL
# (41.9315035, -87.643809)
#
# W IDA B WELLS DR
# (41.8756771, -87.6325771)
#
# W RACE AVE
# (35.2508634, -91.74748)
#
# N BISSELL ST
# (39.502357, -89.763274)
#
# N FAIRFIELD AVE
# (40.417653, -120.640311)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# W DIVERSEY AVE
# (41.9263942, -88.0053438)
#
# W Eastwood Ave
# (41.9656467, -87.7297858)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# W CORNELIA AVE
# (33.9618136, -98.6777071)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# N WABASH AVE
# (41.1450949, -87.8658414)
#
# S Ashland Ave
# (44.4802212, -88.0581457)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# N SHEFFIELD AVE
# (43.1085525, -87.8984732)
#
# N WESTERN AVE
# (35.5293143, -97.5298153)
#
# W MELROSE ST
# (40.667262, -73.698695)
#
# N ROCKWELL ST
# (33.3744844, -111.7302071)
#
# W C1 ST
# (16.8263301, 96.2703488)
#
# W NEWPORT AVE
# (42.681683, -83.313192)
#
# S CLINTON ST
# (38.5332401, -89.705132)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# W Van Buren St
# (42.3609721, -85.8840144)
#
# W IDA B WELLS DR
# (41.8756771, -87.6325771)
#
# N PONCHARTRAIN BLVD
# (42.6321183, -83.4878131)
#
# W ST
# (55.8497133, -4.2656724)
#
# S DEARBORN ST
# (47.5958836, -122.318572)
#
# W Cortez St
# (33.5897649, -112.4664308)
#
# S WELLS ST
# (38.0067095, -89.2477996)
#
# W WISCONSIN ST
# (44.511563, -88.331891)
#
# W Warwick Ave
# (41.695646, -71.528992)
#
# W 71ST ST
# (39.882403, -86.227212)
#
# S CANAL ST
# (42.1979758, -72.6021589)
#
# N OAKLEY BLVD
# (41.893065, -87.684323)
#
# N NEWGARD AVE
# (42.0017777, -87.666857)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# N TALMAN AVE
# (41.9139404, -87.6934262)
#
# S CLARK ST
# (44.955584, -90.795919)
#
# S LA SALLE ST
# (41.742861, -88.3242315)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# N ALBANY AVE
# (40.7076835, -73.465108)
#
# N WILLETTS CT
# (41.9276301, -87.703214)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# W RANDOLPH ST
# (36.2743344, -90.9816148)
#
# W FARGO AVE
# (36.3572713, -119.6489519)
#
# W C1 ST
# (16.8263301, 96.2703488)
#
# N BELL AVE
# (32.2464153, -110.8940884)
#
# N Humboldt Blvd
# (43.0638817, -87.8978425)
#
# N NEWCASTLE AVE
# (41.9223699, -87.7970239)
#
# S BAKER AVE
# (34.0434437, -117.6153537)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# S PEORIA ST
# (39.5974063, -104.8480467)
#
# W HOWARD ST
# (43.4469912, -92.2854434)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# N DAMEN AVE
# (41.9744669, -87.6793492)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# N CHRISTIANA AVE
# (41.9702394, -87.7121816)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# W 21ST ST
# (44.961758, -93.306244)
#
# N SEMINARY AVE
# (29.50448, -82.288453)
#
# N CAMPBELL AVE
# (32.2527259, -110.9439424)
#
# N GREENVIEW AVE
# (42.2840502, -89.1311541)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# N Cleveland Ave
# (30.344444, -95.0913629)
#
# N OAKLEY AVE
# (41.664195, -86.124499)
#
# S Greenwood Ave
# (37.6199047, -96.228166)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# W SUPERIOR ST
# (40.857308, -96.805534)
#
# N DAMEN AVE
# (41.9744669, -87.6793492)
#
# W Ontario St
# (35.0943283, -85.3096809)
#
# N Marion Ct
# (40.199688, -85.364927)
#
# N LINCOLN AVE
# (45.660956, -122.6824777)
#
# S COLES AVE
# (41.7483376, -87.5491898)
#
# S DAN RYAN XPRS OB
# W WALTON ST
# (33.089508, -83.237513)
#
# W Newport Ave
# (42.681683, -83.313192)
#
# W MELROSE ST
# (40.667262, -73.698695)
#
# W RUNWAY 1836
# (-43.5540671, 172.553635)
#
# N Racine Ave
# (43.003319, -88.216859)
#
# E 91ST ST
# (38.9616117, -94.5526531)
#
# S LARAMIE AVE
# (41.8447325, -87.753967)
#
# N NEWCASTLE AVE
# (41.9223699, -87.7970239)
#
# N HUMBOLDT BLVD
# (43.0638817, -87.8978425)
#
# W SUNNYSIDE AVE
# (41.9635312, -87.6603099)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# W HUBBARD ST
# (41.7159012, -89.3389805)
#
# N SHEFFIELD AVE
# (43.1085525, -87.8984732)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# S LOOMIS BLVD
# (41.7570599, -87.6587609)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# N FRANKLIN ST
# (43.053353, -76.154839)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# N ARTESIAN AVE
# (41.9254283, -87.6888852)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# W CRYSTAL ST
# (28.899691, -82.574754)
#
# W IDA B WELLS DR
# (41.8756771, -87.6325771)
#
# S ST LAWRENCE AVE
# (41.7682281, -87.6104913)
#
# W C1 ST
# (16.8263301, 96.2703488)
#
# N Lawndale Ave
# (41.9592196, -87.720432)
#
# S KIMBARK AVE
# (41.7673136, -87.5941382)
#
# W ILLINOIS ST
# (41.862092, -88.108188)
#
# N RUTHERFORD AVE
# (40.706973, -73.468891)
#
# N MAJOR AVE
# (36.0352811, -114.9680661)
#
# W ARGYLE ST
# (57.8956842, -5.1630045)
#
# W MONTROSE AVE
# (41.9607197, -87.7466474)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# S HALSTED ST
# (41.5420844, -87.6359687)
#
# W Adams St
# (40.139024, -91.24072)
#
# E MADISON ST
# (41.34629, -94.005057)
#
# W TERMINAL ST
# (38.3711643, -88.065751)
#
# W IDA B WELLS DR
# (41.8756771, -87.6325771)
#
# W IDA B WELLS DR
# (41.8756771, -87.6325771)
#
# N Aberdeen St
# (35.732977, -95.350542)
#
# N KIMBALL AVE
# (32.948407, -97.1167804)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# W GOETHE ST
# (41.9056968, -87.6365183)
#
# W ROOSEVELT RD
# (41.8568563, -88.1736282)
#
# N Michigan Ave
# (43.4553256, -83.9500328)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# W FARGO AVE
# (36.3572713, -119.6489519)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# W DICKENS AVE
# (26.2215137, -98.1842927)
#
# W 87TH ST
# (38.970993, -94.7161832)
#
# W BLOOMINGDALE AVE
# (27.8936206, -82.2946314)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# W DIVISION ST
# (38.2597099, -87.9979169)
#
# W 85TH ST
# (40.784673, -73.9699691)
#
# W WEBSTER AVE
# (42.4488715, -83.1273708)
#
# N WICKER PARK AVE
# (41.9081219, -87.6760847)
#
# W CHURCHILL ST
# (41.9146453, -87.6812723)
#
# W FARWELL AVE
# (42.0067765, -87.6605207)
#
# S ARCHER AVE
# (41.6335223, -88.0133585)
#
# W PRATT BLVD
# (42.0054657, -87.6658226)
#
# N Kenmore Ave
# (34.0845852, -117.6542025)
#
# W WALTON ST
# (33.089508, -83.237513)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# N STATE ST
# (44.619052, -75.408869)
#
# E 48th pl
# (41.5302522, -87.3271266)
#
# N WESTERN AVE
# (35.5293143, -97.5298153)
#
# W 58TH ST
# (44.8978415, -93.2888067)
#
# S NORMAL AVE
# (37.720105, -89.21769)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# W 77TH PL
# (25.892764, -80.337001)
#
# N ORCHARD ST
# (43.0517216, -77.093211)
#
# W LAKE ST
# (41.8877192, -87.7651226)
#
# S DELANO CT W
# (41.8676448, -87.6326338)
#
# N BURLING ST
# (41.9148697, -87.6471899)
#
# N ELSTON AVE
# (41.9624991, -87.731967)
#
# N LINCOLN AVE
# (45.660956, -122.6824777)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# N STATE ST
# (44.619052, -75.408869)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# W LILL AVE
# (41.9277607, -87.6590552)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# N Kenmore Ave
# (34.0845852, -117.6542025)
#
# N ST LOUIS AVE
# (41.9727203, -87.7159449)
#
# W HUBBARD ST
# (41.7159012, -89.3389805)
#
# W LAKE ST
# (41.8877192, -87.7651226)
#
# W 61ST PL
# (25.879063, -80.307356)
#
# W LAKE ST
# (41.8877192, -87.7651226)
#
# W RANDOLPH ST
# (36.2743344, -90.9816148)
#
# S DREXEL BLVD
# (35.4636206, -97.5703073)
#
# N HAMILTON AVE
# (40.696537, -73.368294)
#
# N SPRINGFIELD AVE
# (41.9646307, -87.7254887)
#
# N Kimball Ave
# (32.948407, -97.1167804)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# S SPRINGFIELD AVE
# (40.6858039, -74.3274558)
#
# S DELANO CT E
# (41.8674021, -87.6325503)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# E 89TH PL
# (36.0340257, -95.9045251)
#
# N RACINE AVE
# (43.003319, -88.216859)
#
# E Wacker Dr
# (41.8878388, -87.6190596)
#
# N WINCHESTER AVE
# (46.4110364, -105.830487)
#
# W WINNEMAC AVE
# (41.9733819, -87.667451)
#
# N ST LOUIS AVE
# (41.9727203, -87.7159449)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# S Dorchester Ave
# (41.861114, -88.126156)
#
# W ADDISON ST
# (42.226415, -84.406033)
#
# W WASHINGTON ST
# (40.194732, -85.391486)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# W Dakin St
# (41.9516187, -87.7912726)
#
# W HUBBARD ST
# (41.7159012, -89.3389805)
#
# W LAKE ST
# (41.8877192, -87.7651226)
#
# N TROY ST
# (41.9593759, -87.70697)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# N HOYNE AVE
# (41.9550717, -87.6812061)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# W Sheridan Rd
# (42.490117, -79.250962)
#
# S University Ave
# (40.2215138, -111.658881)
#
# W Belmont Ave
# (40.839392, -96.722861)
#
# S SAYRE AVE
# (41.7408716, -87.7945525)
#
# W EASTMAN ST
# (42.0855803, -87.9841194)
#
# N Hoyne Ave
# (41.9550717, -87.6812061)
#
# N Sheridan Rd
# (40.3578419, -76.2273206)
#
# W ONTARIO ST
# (35.0943283, -85.3096809)
#
# N LA SALLE ST
# (30.398997, -96.0961872)
#
# S WELLS ST
# (38.0067095, -89.2477996)
#
# N WILTON AVE
# (42.42707, -88.094391)
#
# E IDA B WELLS DR
# (41.8757455, -87.6251804)
#
# E IDA B WELLS DR
# (41.8757455, -87.6251804)
#
# E IDA B WELLS DR
# (41.8757455, -87.6251804)
#
# W LE MOYNE ST
# (41.9077136, -87.7331889)
#
# W PERSHING RD
# (39.8764731, -88.9678636)
#
# N RACINE AVE
# (43.003319, -88.216859)
#
# W RANDOLPH ST
# (36.2743344, -90.9816148)
#
# W OHIO ST
# (40.646058, -83.609337)
#
# S DREXEL AVE
# (33.369843, -111.623825)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# S HERMITAGE AVE
# (41.7685166, -87.6675589)
#
# N RACINE AVE
# (43.003319, -88.216859)
#
# W COLUMBIA AVE
# (47.7106286, -117.421456)
#
# W LELAND AVE
# (41.9666512, -87.7370944)
#
# W EVERGREEN AVE
# (34.1350555, -118.0011499)
#
# N WAYNE AVE
# (40.055678, -75.393487)
#
# W EDDY ST
# (33.6448338, -97.3810902)
#
# S DREXEL BLVD
# (35.4636206, -97.5703073)
#
# W WEBSTER AVE
# (42.4488715, -83.1273708)
#
# W BRYN MAWR AVE
# (41.983045, -87.711304)
#
# N ASTOR ST
# (41.0402327, -73.8726946)
#
# N PINE GROVE AVE
# (41.9529308, -87.6478914)
#
# N STATE ST
# (44.619052, -75.408869)
#
# W EASTMAN ST
# (42.0855803, -87.9841194)
#
# W BRYN MAWR AVE
# (41.983045, -87.711304)
#
# E MONROE ST
# (38.305137, -89.992146)
#
# N MC CLURG CT
# (30.332179, -82.799061)
#
# N HOYNE AVE
# (41.9550717, -87.6812061)
#
# W BITTERSWEET PL
# (41.9543315, -87.7894585)
#
# S Green St
# (37.8040878, -87.6368672)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# N CANNON DR
# (41.9317347, -87.6377872)
#
# N NOTTINGHAM AVE
# (41.9489522, -87.8046875)
#
# N WOLCOTT AVE
# (41.9069854, -87.6730408)
#
# W DEMING PL
# (41.9292488, -87.6406316)
#
# N CLEAVER ST
# (41.90877725, -87.66409688742331)
#
# E ILLINOIS ST
# (41.862286, -88.09637)
#
# W North Ave
# (39.3102943, -76.6372005)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# W OAK ST
# (33.2135652, -92.6679021)
#
# E Ohio St
# (40.601786, -84.084445)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# W DIVERSEY PKWY
# (41.9323951, -87.6687745)
#
# S ABERDEEN ST
# (35.7300766, -95.3526173)
#
# W ELMDALE AVE
# (41.9908568, -87.6651706)
#
# W BELDEN AVE
# (41.9187168, -87.9610749)
#
# N CHRISTIANA AVE
# (41.9702394, -87.7121816)
#
# N ALLEN AVE
# (37.5531983, -77.4608904)
#
# W IDA B WELLS DR
# (41.8756771, -87.6325771)
#
# N MAGNOLIA AVE
# (29.1969846, -82.1365046)
#
# N DAMEN AVE
# (41.9744669, -87.6793492)
#
# W PL
# (39.0445999, -94.6029041)
#
# W EASTWOOD AVE
# (41.9656467, -87.7297858)
#
# W AINSLIE ST
# (41.9701978, -87.7164722)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# N BELL AVE
# (32.2464153, -110.8940884)
#
# W CORNELIA AVE
# (33.9618136, -98.6777071)
#
# N Wells St
# (30.831592, -83.286031)
#
# S CREGIER AVE
# (41.7663619, -87.5812232)
#
# N winthrop ave
# (41.9873032, -87.6581226)
#
# N Talman Ave
# (41.9139404, -87.6934262)
#
# W LEXINGTON ST
# (39.0325997, -97.5948929)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# S CLARK ST
# (44.955584, -90.795919)
#
# W ROSCOE ST
# (41.9417774, -87.798255)
#
# N PAULINA ST
# (41.9902949, -87.6714344)
#
# S SEELEY AVE
# (42.2886768, -89.633005)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# W Lawrence Ave
# (41.9683042, -87.7231431)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# N CLAREMONT AVE
# (36.106832, -80.228788)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# N SACRAMENTO AVE
# (39.341244, -74.483242)
#
# N CLAREMONT AVE
# (36.106832, -80.228788)
#
# N ELAINE PL
# (41.944742, -87.6477153)
#
# N Greenview Ave
# (42.2840502, -89.1311541)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# N GLENWOOD AVE
# (42.650887, -83.284998)
#
# S ADA ST
# (44.9307182, -93.0759931)
#
# W ONTARIO ST
# (35.0943283, -85.3096809)
#
# N KENNETH AVE
# (41.9717719, -87.7392712)
#
# W IRVING PARK RD
# (41.953826, -87.7116755)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# N Lincoln Ave
# (45.6507907, -122.6824769)
#
# W BARRY AVE
# (36.8175627, -93.9243727)
#
# N AVERS AVE
# (41.9628652, -87.724203)
#
# N STATE ST
# (44.619052, -75.408869)
#
# E 8TH ST
# (40.7275449, -73.9851784)
#
# S Drexel Ave
# (33.369843, -111.623825)
#
# N LA SALLE ST
# (30.398997, -96.0961872)
#
# W Chicago Ave
# (41.8965708, -87.6357092)
#
# E ILLINOIS ST
# (41.862286, -88.09637)
#
# N DAMEN AVE
# (41.9744669, -87.6793492)
#
# W Gordon Ter
# (41.9578365, -87.6498054)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# W RANDOLPH ST
# (36.2743344, -90.9816148)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# N CHRISTIANA AVE
# (41.9702394, -87.7121816)
#
# W IDA B WELLS DR
# (41.8756771, -87.6325771)
#
# S HYDE PARK BLVD
# (41.7978073, -87.5840054)
#
# W DICKENS AVE
# (26.2215137, -98.1842927)
#
# W ONTARIO ST
# (35.0943283, -85.3096809)
#
# E 16th St
# (39.788871, -86.0826411)
#
# W 51ST ST
# (40.7597316, -73.9780866)
#
# N HARDING AVE
# (41.9937042, -87.7276304)
#
# S Harper Ave
# (33.3743982, -111.6339155)
#
# N ST CLAIR ST
# (38.6048814, -89.8103789)
#
# N Elk Grove Ave
# (41.9093578, -87.6740675)
#
# N Avers Ave
# (41.9628652, -87.724203)
#
# W LUNT AVE
# (42.0077782, -87.8200486)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# W LAKE ST
# (41.8877192, -87.7651226)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# E WASHINGTON ST
# (48.4192112, -122.3309125)
#
# W Rascher Ave
# (41.9804019, -87.6966348)
#
# S ROCKWELL ST
# (33.3290958, -111.7293356)
#
# S RIVERSIDE PLZ
# (41.87992545, -87.63872659087485)
#
# N GREEN ST
# (42.932728, -76.570157)
#
# E 55TH ST
# (40.7560064, -73.9614975)
#
# N STATE ST
# (44.619052, -75.408869)
#
# N BURLING ST
# (41.9148697, -87.6471899)
#
# N WASHTENAW AVE
# (41.9253795, -87.6949927)
#
# E 34TH ST
# (40.7470509, -73.9812632)
#
# W LOGAN BLVD
# (41.9310979, -87.6846333)
#
# W RANDOLPH ST
# (36.2743344, -90.9816148)
#
# W FARWELL AVE
# (42.0067765, -87.6605207)
#
# E MONROE ST
# (38.305137, -89.992146)
#
# E 56th St
# (44.9015711, -93.2646052)
#
# E MONROE ST
# (38.305137, -89.992146)
#
# S GREENWOOD AVE
# (37.6199047, -96.228166)
#
# W Superior St
# (40.857308, -96.805534)
#
# W CULLERTON ST
# (41.8556603, -87.641803)
#
# S KEDZIE AVE
# (41.7315967, -87.7021544)
#
# N LECLAIRE AVE
# (41.935091, -87.7540962)
#
# N WAYNE AVE
# (40.055678, -75.393487)
#
# S CALIFORNIA AVE
# (34.1163848, -118.0008539)
#
# E 46TH ST
# (44.917865, -93.2041653)
#
# E PEARSON ST
# (43.053739, -87.900774)
#
# N CLYBOURN AVE
# (41.9273774, -87.6724654)
#
# W BEACH AVE
# (49.0253429, -122.8165082)
#
# N Sheridan RD
# (40.3578419, -76.2273206)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# W BARRY AVE
# (36.8175627, -93.9243727)
#
# S INGLESIDE AVE
# (41.7403543, -87.601287)
#
# N WAYNE AVE
# (40.055678, -75.393487)
#
# W SUMMERDALE AVE
# (41.9789237, -87.6696222)
#
# E IDA B WELLS DR
# (41.8757455, -87.6251804)
#
# W ST JAMES PL
# (42.0859345, -88.0017581)
#
# N LINCOLN AVE
# (45.660956, -122.6824777)
#
# W 56TH PL
# (25.8734227, -80.3063357)
#
# N MORGAN ST
# (33.8042077, -117.8198522)
#
# W Carmen Ave
# (41.9736044, -87.7374367)
#
# S PARNELL AVE
# (41.6335259, -87.6353874)
#
# W CONCORD PL
# (40.3981522, -111.9271298)
#
# W LELAND AVE
# (41.9666512, -87.7370944)
#
# W SCHOOL ST
# (33.3044468, -96.4028596)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# N Monticello Ave
# (41.9751716, -87.7196691)
#
# W CARROLL AVE
# (34.1342246, -117.8674488)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# N PEORIA
# (40.7175374, -89.5842635)
#
# N PEORIA
# (40.7175374, -89.5842635)
#
# N PEORIA
# (40.7175374, -89.5842635)
#
# N Sawyer Ave
# (41.9610885, -87.7094607)
#
# W DIVERSEY AVE
# (41.9263942, -88.0053438)
#
# S LAPORTE AVE
# (41.6825633, -87.7435692)
#
# S Stony Island Ave
# (41.772423, -87.5862745)
#
# N KEDZIE AVE
# (41.981245, -87.7088348)
#
# N GREENVIEW AVE
# (42.2840502, -89.1311541)
#
# W 31ST ST
# (44.9466054, -93.2862078)
#
# W 17TH PL
# (36.1369904, -95.9907598)
#
# W LAKE ST
# (41.8877192, -87.7651226)
#
# S HOMAN AVE
# (41.6622485, -87.7046222)
#
# W Higgins Rd
# (42.0465268, -88.0856451)
#
# S SEELEY AVE
# (42.2886768, -89.633005)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# W HUBBARD ST
# (41.7159012, -89.3389805)
#
# W BELLE PLAINE AVE
# (41.955062, -87.7887068)
#
# N State St
# (44.619052, -75.408869)
#
# W Palmer Blvd
# (41.9214697, -87.7067699)
#
# W WINNEMAC AVE
# (41.9733819, -87.667451)
#
# W LAWRENCE AVE
# (41.9683042, -87.7231431)
#
# N Lowell Ave
# (43.051309, -76.184402)
#
# S DORCHESTER AVE
# (41.861114, -88.126156)
#
# N WOOD ST
# (32.3586259, -97.3959405)
#
# E BENTON PL
# (41.8855211, -87.6175881)
#
# W BLACKHAWK ST
# (43.567624, -96.737549)
#
# W WINONA ST
# (46.8469244, -92.0900123)
#
# W IDA B WELLS DR
# (41.8756771, -87.6325771)
#
# W LE MOYNE ST
# (41.9077136, -87.7331889)
#
# N Noble St
# (33.7944831, -117.8022079)
#
# E BENTON PL
# (41.8855211, -87.6175881)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# W TERMINAL ST
# (38.3711643, -88.065751)
#
# N BELL AVE
# (32.2464153, -110.8940884)
#
# N Michigan Ave
# (43.4553256, -83.9500328)
#
# W FLOURNOY ST
# (28.406267, -97.7593919)
#
# W BARRY AVE
# (36.8175627, -93.9243727)
#
# N KEDZIE AVE
# (41.981245, -87.7088348)
#
# N FRANCISCO AVE
# (26.2217801, -98.3199932)
#
# W WEST END AVE
# (41.8840066, -87.7595529)
#
# W FLOURNOY ST
# (28.406267, -97.7593919)
#
# W 14TH PL
# (36.737877, -95.99234)
#
# N WELLS ST
# (30.831592, -83.286031)
#
# N Hamilton AVE
# (40.696537, -73.368294)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# W ARTHUR AVE
# (42.9994824, -87.9518008)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# W BLACKHAWK ST
# (43.567624, -96.737549)
#
# N Sheridan rd
# (40.3578419, -76.2273206)
#
# N SPRINGFIELD AVE
# (41.9646307, -87.7254887)
#
# W PRATT BLVD
# (42.0054657, -87.6658226)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# W BELLE PLAINE AVE
# (41.955062, -87.7887068)
#
# S Ewing Ave
# (32.7424571, -96.8126924)
#
# N KEELER AVE
# (31.890888, -102.393391)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# W NORWOOD ST
# (37.110794, -92.420191)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# S BISHOP ST
# (39.5665983, -76.9892851)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# W 24TH ST
# (39.8009909, -86.170301)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# W GLENLAKE AVE
# (41.9920252, -87.7164771)
#
# N LA SALLE ST
# (30.398997, -96.0961872)
#
# S ELLIS AVE
# (35.309552, -78.616879)
#
# W LUNT AVE
# (42.0077782, -87.8200486)
#
# N STATE ST
# (44.619052, -75.408869)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# W GRANVILLE AVE
# (40.245255, -96.754104)
#
# N WABASH AVE
# (41.1450949, -87.8658414)
#
# W EASTWOOD AVE
# (41.9656467, -87.7297858)
#
# W LYNDALE ST
# (41.9201267, -87.8427793)
#
# N Racine Ave
# (43.003319, -88.216859)
#
# N LINCOLN AVE
# (45.660956, -122.6824777)
#
# N WELLS ST
# (30.831592, -83.286031)
#
# N Michigan Ave
# (43.4553256, -83.9500328)
#
# W IDA B WELLS DR
# (41.8756771, -87.6325771)
#
# N MONTICELLO AVE
# (41.9751716, -87.7196691)
#
# S UNION AVE
# (47.2491253, -122.4836389)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# N WILTON AVE
# (42.42707, -88.094391)
#
# N LARRABEE ST
# (41.907027, -87.6433116)
#
# W DOUGLAS BLVD
# (41.8629927, -87.7029508)
#
# W BELDEN AVE
# (41.9187168, -87.9610749)
#
# N WOLCOTT AVE
# (41.9069854, -87.6730408)
#
# N WOLCOTT AVE
# (41.9069854, -87.6730408)
#
# N LINCOLN AVE
# (45.660956, -122.6824777)
#
# W C1 ST
# (16.8263301, 96.2703488)
#
# N KEDVALE AVE
# (41.9640717, -87.7315451)
#
# W TERMINAL ST
# (38.3711643, -88.065751)
#
# N HAZEL ST
# (40.166712, -76.395635)
#
# N Hamlin Ave
# (41.9737701, -87.7232845)
#
# N RICHMOND ST
# (41.9557758, -87.7019847)
#
# N LEAVITT ST
# (39.531967, -87.136931)
#
# W ARGYLE ST
# (57.8956842, -5.1630045)
#
# W 62ND ST
# (44.8909522, -93.3054532)
#
# N MONTICELLO AVE
# (41.9751716, -87.7196691)
#
# W CHESTNUT ST
# (40.0400916, -76.3165126)
#
# N MONTICELLO AVE
# (41.9751716, -87.7196691)
#
# W ILLINOIS ST
# (41.862092, -88.108188)
#
# N Mozart St
# (41.963078, -87.699749)
#
# E ILLINOIS ST
# (41.862286, -88.09637)
#
# N ORCHARD ST
# (43.0517216, -77.093211)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# N CLAREMONT AVE
# (36.106832, -80.228788)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# N WOLCOTT AVE
# (41.9069854, -87.6730408)
#
# S CANAL ST
# (42.1979758, -72.6021589)
#
# W 18th st
# (39.041594, -96.8333437)
#
# W Jackson BLVD
# (37.377182, -89.6682716)
#
# E GRAND AVE
# (36.7105116, -119.7874097)
#
# W ALDINE AVE
# (41.9418061, -87.6487849)
#
# E OHIO ST
# (40.601786, -84.084445)
#
# N WELLS ST
# (30.831592, -83.286031)
#
# N DEARBORN PKWY
# (41.9077182, -87.630106)
#
# S AVENUE L
# (31.5331944, -97.4407611)
#
# N CLAREMONT AVE
# (36.106832, -80.228788)
#
# W ARMITAGE AVE
# (43.1023086, -87.9910021)
#
# N LA SALLE DR
# (32.459967, -99.781336)
#
# E IDA B WELLS DR
# (41.8757455, -87.6251804)
#
# S CHRISTIANA AVE
# (28.6675036, -81.4969422)
#
# W HIRSCH ST
# (41.9062185, -87.7313087)
#
# N CLIFTON AVE
# (37.2360894, -93.3271958)
#
# W 17TH ST
# (30.1810582, -85.7266273)
#
# E 33RD ST
# (40.5305942, -85.6462995)
#
# W EASTMAN ST
# (42.0855803, -87.9841194)
#
# W BELLE PLAINE AVE
# (41.955062, -87.7887068)
#
# N SPAULDING AVE
# (41.9543894, -87.7104772)
#
# E 53RD ST
# (40.7580248, -73.9701634)
#
# W BARRY AVE
# (36.8175627, -93.9243727)
#
# S Blackstone Ave
# (41.78726, -87.881703)
#
# N Hermitage Ave
# (40.232782, -74.780752)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S MARSHFIELD AVE
# (41.8093553, -87.6662057)
#
# N Jefferson St
# (43.572607, -76.123675)
#
# W Farwell Ave
# (42.0067765, -87.6605207)
#
# N TALMAN AVE
# (41.9139404, -87.6934262)
#
# S DELANO CT W
# (41.8676448, -87.6326338)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# N LAWNDALE AVE
# (41.9592196, -87.720432)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# W EASTMAN ST
# (42.0855803, -87.9841194)
#
# W EASTMAN ST
# (42.0855803, -87.9841194)
#
# N LINCOLN AVE
# (45.660956, -122.6824777)
#
# W IRVING PARK RD
# (41.953826, -87.7116755)
#
# N PAULINA ST
# (41.9902949, -87.6714344)
#
# W C1 ST
# (16.8263301, 96.2703488)
#
# W Carmen AVe
# (41.9736044, -87.7374367)
#
# W DIVERSEY PKWY
# (41.9323951, -87.6687745)
#
# N ELIZABETH ST
# (38.0310475, -84.5126509)
#
# W SUNNYSIDE AVE
# (41.9635312, -87.6603099)
#
# W MELROSE ST
# (40.667262, -73.698695)
#
# N LATROBE AVE
# (41.9852199, -87.7604579)
#
# W IDA B WELLS DR
# (41.8756771, -87.6325771)
#
# W IDA B WELLS DR
# (41.8756771, -87.6325771)
#
# E ILLINOIS ST
# (41.862286, -88.09637)
#
# W DIVISION ST
# (38.2597099, -87.9979169)
#
# S KENWOOD AVE
# (41.8060326, -87.5935411)
#
# W Estes Ave
# (32.008665, -102.081306)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# S Calumet Ave
# (41.7034033, -86.871671)
#
# N RICHMOND ST
# (41.9557758, -87.7019847)
#
# W GARFIELD BLVD
# (41.7944433, -87.6378706)
#
# W LYNDALE ST
# (41.9201267, -87.8427793)
#
# N KINGSBURY ST
# (41.8986511, -87.6438839)
#
# S CALUMET AVE
# (41.7034033, -86.871671)
#
# N CHRISTIANA AVE
# (41.9702394, -87.7121816)
#
# W HARRISON ST
# (47.453523, -116.785825)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# S KOMENSKY AVE
# (41.7242244, -87.7231031)
#
# S WENTWORTH AVE
# (42.9981308, -87.8894434)
#
# N STATE ST
# (44.619052, -75.408869)
#
# E IDA B WELLS DR
# (41.8757455, -87.6251804)
#
# S KILBOURN AVE
# (41.8591487, -87.737185)
#
# N KOLMAR AVE
# (41.9710894, -87.7440319)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# W WILLOW ST
# (42.7487589, -84.5619189)
#
# N PAULINA ST
# (41.9902949, -87.6714344)
#
# S HARPER AVE
# (33.3743982, -111.6339155)
#
# N RAVENSWOOD AVE
# (41.9688187, -87.6741627)
#
# W AGATITE AVE
# (41.9619564, -87.7205109)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# N BOSWORTH AVE
# (41.9106545, -87.6665138)
#
# N STATE ST
# (44.619052, -75.408869)
#
# E 46TH ST
# (44.917865, -93.2041653)
#
# N STATE ST
# (44.619052, -75.408869)
#
# W Fullerton Ave
# (41.923398, -87.9104238)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# W ARMITAGE AVE
# (43.1023086, -87.9910021)
#
# W MELROSE ST
# (40.667262, -73.698695)
#
# W RANDOLPH ST
# (36.2743344, -90.9816148)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# W POLK ST
# (30.7116929, -94.9383233)
#
# N KEDZIE AVE
# (41.981245, -87.7088348)
#
# E IDA B WELLS DR
# (41.8757455, -87.6251804)
#
# W ROSCOE ST
# (41.9417774, -87.798255)
#
# E MADISON ST
# (41.34629, -94.005057)
#
# S UNIVERSITY AVE
# (40.2215138, -111.658881)
#
# N RIDGEWAY AVE
# (41.9954911, -87.7227208)
#
# W LAWRENCE AVE
# (41.9683042, -87.7231431)
#
# N ORLEANS ST
# (34.8209213, -87.6356312)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# W WABANSIA AVE
# (41.9107882, -87.7995001)
#
# W ERIE ST
# (33.3076026, -111.9043792)
#
# W DIVERSEY PKWY
# (41.9323951, -87.6687745)
#
# S KIMBARK AVE
# (41.7673136, -87.5941382)
#
# W GORDON TER
# (41.9578365, -87.6498054)
#
# S Ingleside Ave
# (41.7403543, -87.601287)
#
# W FRY ST
# (41.8970425, -87.6643434)
#
# N ASHLAND BLVD
# (42.0066203, -87.6699972)
#
# N CHRISTIANA AVE
# (41.9702394, -87.7121816)
#
# E NORTH WATER ST
# (44.1892786, -88.4550657)
#
# S OAKLEY AVE
# (41.6631708, -86.1244023)
#
# W OGDEN AVE
# (32.341146, -86.3093)
#
# N WACKER DR
# (40.759348, -89.6577155)
#
# W OHIO ST
# (40.646058, -83.609337)
#
# E CONGRESS PKWY
# (41.8757455, -87.6251804)
#
# W ILLINOIS ST
# (41.862092, -88.108188)
#
# W LELAND AVE
# (41.9666512, -87.7370944)
#
# S PAXTON AVE
# (41.7316571, -87.5707162)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# N Wells St
# (30.831592, -83.286031)
#
# W LAWRENCE AVE
# (41.9683042, -87.7231431)
#
# S LITUANICA AVE
# (41.8276171, -87.6476628)
#
# W KINZIE ST
# (41.8891372, -87.6357356)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# N STATE ST
# (44.619052, -75.408869)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# N WESTERN AVE
# (35.5293143, -97.5298153)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# W Belmont Ave
# (40.839392, -96.722861)
#
# W Hubbard st
# (41.7159012, -89.3389805)
#
# N PEORIA ST
# (40.935557, -89.537819)
#
# W MORSE AVE
# (42.0072486, -87.6859808)
#
# S WOOD ST
# (41.343196, -83.119849)
#
# S ST LAWRENCE AVE
# (41.7682281, -87.6104913)
#
# W TAYLOR ST
# (41.3837633, -75.7166377)
#
# N KENNETH AVE
# (41.9717719, -87.7392712)
#
# S BUFFALO AVE
# (31.4608364, -96.0651776)
#
# N WOLCOTT AVE
# (41.9069854, -87.6730408)
#
# N WACKER DR
# (40.759348, -89.6577155)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# W WINNEMAC AVE
# (41.9733819, -87.667451)
#
# N SHEFFIELD AVE
# (43.1085525, -87.8984732)
#
# S FRANKLIN ST
# (36.675438, -76.922075)
#
# N GLENWOOD AVE
# (42.650887, -83.284998)
#
# W LUNT AVE
# (42.0077782, -87.8200486)
#
# N State Pkwy
# (41.9077301, -87.6287875)
#
# S KOSTNER AVE
# (41.6651721, -87.7289951)
#
# W Arlington Pl
# (28.8134399, -82.5451972)
#
# W ERIE ST
# (33.3076026, -111.9043792)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# N MOORMAN ST
# (41.9049392, -87.6704848)
#
# N JEFFERSON ST
# (43.572607, -76.123675)
#
# E IDA B WELLS DR
# (41.8757455, -87.6251804)
#
# N MOBILE AVE
# (35.2845786, -93.1181537)
#
# S YATES AVE
# (41.1127251, -87.8911556)
#
# W DEVON AVE
# (41.9973572, -87.7114381)
#
# N GREENVIEW AVE
# (42.2840502, -89.1311541)
#
# E JACKSON DR
# (39.0427286, -94.3401464)
#
# N CLINTON ST
# (43.0516907, -76.1535027)
#
# S COLUMBUS DR
# (33.3465843, -111.7432952)
#
# E RANDOLPH ST
# (39.430644, -96.7584772)
#
# W CUYLER AVE
# (41.9551763, -87.6742845)
#
# S CHURCH ST
# (41.2952576, -82.9712879)
#
# N MAPLEWOOD AVE
# (36.1771957, -95.9078851)
#
# E WALTON ST
# (33.0918832, -83.2257331)
#
# N ELIZABETH ST
# (38.0310475, -84.5126509)
#
# S HONORE ST
# (41.8267808, -87.6715176)
#
# E BALBO AVE
# (41.8731287, -87.6256509)
#
# N Franklin St
# (43.053353, -76.154839)
#
# N Clybourn Ave
# (41.9273774, -87.6724654)
#
# W TERMINAL ST
# (38.3711643, -88.065751)
#
# N CANAL ST
# (42.442134, -75.597522)
#
# E RANDOLPH ST
# (39.430644, -96.7584772)
#
# S SANGAMON ST
# (39.5902655, -89.7359101)
#
# W RASCHER AVE
# (41.9804019, -87.6966348)
#
# E RANDOLPH ST
# (39.430644, -96.7584772)
#
# S COLUMBUS DR
# (33.3465843, -111.7432952)
#
# E HUBBARD ST
# (32.5163243, -95.4024822)
#
# E RANDOLPH ST
# (39.430644, -96.7584772)
#
# E RANDOLPH ST
# (39.430644, -96.7584772)
#
# W WAYMAN ST
# (41.8873865, -87.6476434)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# N CICERO AVE
# (42.0121975, -87.7479383)
#
# S COLUMBUS DR
# (33.3465843, -111.7432952)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# E ROOSEVELT RD
# (41.858902, -88.097724)
#
# E Randolph St
# (39.430644, -96.7584772)
#
# N RACINE AVE
# (43.003319, -88.216859)
#
# E 52ND ST
# (40.7542669, -73.9631956)
#
# W ONTARIO ST
# (35.0943283, -85.3096809)
#
# W IDA B WELLS DR
# (41.8756771, -87.6325771)
#
# W LELAND AVE
# (41.9666512, -87.7370944)
#
# N WELLS ST
# (30.831592, -83.286031)
#
# W Montrose Ave
# (41.9607197, -87.7466474)
#
# N STATE ST
# (44.619052, -75.408869)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# E 47TH ST
# (40.7546125, -73.9737345)
#
# E WACKER DR
# (41.8878388, -87.6190596)
#
# S CALIFORNIA AVE
# (34.1163848, -118.0008539)
#
# N RUSH ST
# (43.7828197, -86.4281776)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# W WILSON AVE
# (47.6575559, -117.4351579)
#
# N Leamington Ave
# (41.8986064, -87.7544655)
#
# N STATE ST
# (44.619052, -75.408869)
#
# N Claremont Ave
# (36.106832, -80.228788)
#
# N RIDGE AVE
# (35.5045339, -80.6185371)
#
# N MARSHFIELD AVE
# (41.9258863, -87.669388)
#
# N LOTUS AVE
# (35.4704582, -97.3553818)
#
# W EUGENIE ST
# (41.9128325, -87.6422919)
#
# W MC LEAN AVE
# (41.9181539, -87.720491)
#
# E HURON ST
# (42.281291, -83.7369982)
#
# W IDA B WELLS DR
# (41.8756771, -87.6325771)
#
# N CALIFORNIA AVE
# (33.9287659, -116.9813763)
#
# W ROSCOE ST
# (41.9417774, -87.798255)
#
# N Ashland Blvd
# (42.0066203, -87.6699972)
#
# W 18th st
# (39.041594, -96.8333437)
#
# W ST
# (55.8497133, -4.2656724)
#
# W Barry Ave
# (36.8175627, -93.9243727)
#
# S HARPER AVE
# (33.3743982, -111.6339155)
#
# N WAYNE AVE
# (40.055678, -75.393487)
#
# W EASTMAN ST
# (42.0855803, -87.9841194)
#
# W CORTEZ ST
# (33.5897649, -112.4664308)
#
# W HUBBARD ST
# (41.7159012, -89.3389805)
#
# S EUCLID AVE
# (43.5904697, -83.9155365)
#
# W PERSHING RD
# (39.8764731, -88.9678636)
#
# S YALE AVE
# (36.0765216, -95.9221167)
#
# S CANAL ST
# (42.1979758, -72.6021589)
#
# N LA SALLE ST
# (30.398997, -96.0961872)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# S INDEPENDENCE BLVD
# (36.8059, -76.116529)
#
# N WELLS ST
# (30.831592, -83.286031)
#
# W Kinzie St
# (41.8891372, -87.6357356)
#
# S PARNELL AVE
# (41.6335259, -87.6353874)
#
# W HENDERSON ST
# (35.6845746, -80.4331586)
#
# W TERMINAL ST
# (38.3711643, -88.065751)
#
# N TAHOMA AVE
# (41.9991758, -87.7637514)
#
# W EASTMAN ST
# (42.0855803, -87.9841194)
#
# W Eastwood ave
# (41.9656467, -87.7297858)
#
# W SUMMERDALE AVE
# (41.9789237, -87.6696222)
#
# E PERSHING RD
# (39.8772063, -88.9358125)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W DEVON AVE
# (41.9973572, -87.7114381)
#
# S Green Bay Ave
# (41.6372553, -87.540884)
#
# E IDA B WELLS DR
# (41.8757455, -87.6251804)
#
# W SCHUBERT AVE
# (41.921548, -88.096436)
#
# W IDA B WELLS DR
# (41.8756771, -87.6325771)
#
# W DIVISION ST
# (38.2597099, -87.9979169)
#
# W 25TH PL
# (41.5724621, -87.390001)
#
# W 19TH ST
# (30.1833503, -85.7294777)
#
# N SPRINGFIELD AVE
# (41.9646307, -87.7254887)
#
# N CENTRAL AVE
# (35.7718102, -91.6557941)
#
# W GEORGE ST
# (55.8634318, -4.2657255)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# E 31ST ST
# (44.9466342, -93.276554)
#
# N NATCHEZ AVE
# (41.9548213, -87.7893155)
#
# S JEFFERY BLVD
# (41.7479785, -87.5759176)
#
# N ARTESIAN AVE
# (41.9254283, -87.6888852)
#
# W Wellington Ave
# (38.1838186, -85.7649883)
#
# N ARTESIAN AVE
# (41.9254283, -87.6888852)
#
# W HASTINGS ST
# (34.482251, -91.5564269)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# S GREENWOOD AVE
# (37.6199047, -96.228166)
#
# N RUSH ST
# (43.7828197, -86.4281776)
#
# W 74TH ST
# (40.780251, -73.9814398)
#
# W IRVING PARK RD
# (41.953826, -87.7116755)
#
# N WOOD ST
# (32.3586259, -97.3959405)
#
# S MAY ST
# (35.5997263, -77.5918349)
#
# W COULTER ST
# (40.0260654, -75.1778327)
#
# W LILL AVE
# (41.9277607, -87.6590552)
#
# W PARKER AVE
# (42.1332826, -72.7503617)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# W WILLOW ST
# (42.7487589, -84.5619189)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# E ST
# (50.4738724, 4.2358174)
#
# W MORSE AVE
# (42.0072486, -87.6859808)
#
# N WELLS ST
# (30.831592, -83.286031)
#
# N LINCOLN AVE
# (45.660956, -122.6824777)
#
# W GREENLEAF AVE
# (42.010296, -87.6685965)
#
# S Spaulding Ave
# (34.0288086, -118.3700242)
#
# N RACINE AVE
# (43.003319, -88.216859)
#
# N PAULINA ST
# (41.9902949, -87.6714344)
#
# W IDA B WELLS DR
# (41.8756771, -87.6325771)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# S LA SALLE ST
# (41.742861, -88.3242315)
#
# E MONROE ST
# (38.305137, -89.992146)
#
# N HUDSON AVE
# (37.691596, -83.95988)
#
# S UNION AVE
# (47.2491253, -122.4836389)
#
# W Pratt blvd
# (42.0054657, -87.6658226)
#
# W AINSLIE ST
# (41.9701978, -87.7164722)
#
# W IDA B WELLS DR
# (41.8756771, -87.6325771)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# W CONGRESS PKWY
# (41.8750866, -87.6539866)
#
# N La Salle Dr
# (32.459967, -99.781336)
#
# N CHRISTIANA AVE
# (41.9702394, -87.7121816)
#
# N CROSBY ST
# (41.431494, -96.510016)
#
# W CORTEZ ST
# (33.5897649, -112.4664308)
#
# S HAMLIN AVE
# (42.0088243, -87.8504392)
#
# S EMERALD AVE
# (33.3965996, -111.8035831)
#
# N CHRISTIANA AVE
# (41.9702394, -87.7121816)
#
# W SUPERIOR ST
# (40.857308, -96.805534)
#
# W WILLOW ST
# (42.7487589, -84.5619189)
#
# W Addison St
# (42.226415, -84.406033)
#
# N DAMEN AVE
# (41.9744669, -87.6793492)
#
# W BLACKHAWK ST
# (43.567624, -96.737549)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# N Halsted St
# (41.9468528, -87.649475)
#
# N STATE ST
# (44.619052, -75.408869)
#
# S CALUMET AVE
# (41.7034033, -86.871671)
#
# S WOOD ST
# (41.343196, -83.119849)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# W AUGUSTA BLVD
# (41.4210887, -87.732417)
#
# E Grand Ave
# (36.7105116, -119.7874097)
#
# N Ashland ave
# (37.99278, -84.165192)
#
# W CARMEN AVE
# (41.9736044, -87.7374367)
#
# S STONY ISLAND AVE
# (41.772423, -87.5862745)
#
# N PEORIA
# (40.7175374, -89.5842635)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# N PEORIA
# (40.7175374, -89.5842635)
#
# W AUGUSTA BLVD
# (41.4210887, -87.732417)
#
# S PLYMOUTH CT
# (41.8740189, -87.6286848)
#
# W ANCONA ST
# (41.8938657, -87.6501028)
#
# W THOMAS ST
# (43.230666, -75.469829)
#
# N CAMPBELL AVE
# (32.2527259, -110.9439424)
#
# E 32ND ST
# (44.94472, -93.2368469)
#
# E RANDOLPH ST
# (39.430644, -96.7584772)
#
# N WALLER AVE
# (41.8910824, -87.7677998)
#
# W Fulton Market
# (41.8867067, -87.6544987)
#
# N Mason Ave
# (42.354338, -85.244316)
#
# N WAYNE AVE
# (40.055678, -75.393487)
#
# N Troy St
# (41.9593759, -87.70697)
#
# E BALBO AVE
# (41.8731287, -87.6256509)
#
# N LINCOLN AVE
# (45.660956, -122.6824777)
#
# W SURF ST
# (41.9343518, -87.638939)
#
# W ILLINOIS ST
# (41.862092, -88.108188)
#
# N KOLMAR AVE
# (41.9710894, -87.7440319)
#
# N FRANKLIN ST
# (43.053353, -76.154839)
#
# W MORSE AVE
# (42.0072486, -87.6859808)
#
# W Morse Ave
# (42.0072486, -87.6859808)
#
# S CICERO AVE
# (41.8545413, -87.7443874)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# N Clarendon Ave
# (39.3347411, -74.4980139)
#
# W JARLATH ST
# (42.012664, -87.7262732)
#
# N WAYNE AVE
# (40.055678, -75.393487)
#
# W GREGORY ST
# (42.0735492, -87.9441124)
#
# S SOUTH SHORE DR
# (41.7687175, -87.5665152)
#
# S ST LOUIS AVE
# (41.0219002, -87.7208064)
#
# S SEELEY AVE
# (42.2886768, -89.633005)
#
# S DAN RYAN XPRS OB
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# S DREXEL AVE
# (33.369843, -111.623825)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W George St
# (55.8634318, -4.2657255)
#
# S DRAKE AVE
# (41.8498569, -87.713702)
#
# W 81ST ST
# (41.7469141, -87.6500179)
#
# S HOYNE AVE
# (41.8228899, -87.6774807)
#
# S JEFFERY BLVD
# (41.7479785, -87.5759176)
#
# N ORCHARD ST
# (43.0517216, -77.093211)
#
# W ERIE ST
# (33.3076026, -111.9043792)
#
# N DAYTON ST
# (43.1198845, -85.5544939)
#
# N ORLEANS ST
# (34.8209213, -87.6356312)
#
# W BRADLEY PL
# (41.9501056, -87.6501801)
#
# W WRIGHTWOOD AVE
# (41.9247283, -87.9553717)
#
# N Damen ave
# (41.9744669, -87.6793492)
#
# W PL
# (39.0445999, -94.6029041)
#
# W WELLINGTON AVE
# (38.1838186, -85.7649883)
#
# W MONTROSE AVE
# (41.9607197, -87.7466474)
#
# W WARREN BLVD
# (41.8823807, -87.6651175)
#
# N NOBLE ST
# (33.7944831, -117.8022079)
#
# W WINDSOR AVE
# (33.4760021, -112.3092496)
#
# N MASON AVE
# (42.354338, -85.244316)
#
# S CARPENTER ST
# (35.240268, -81.338339)
#
# N Bell AVe
# (32.2464153, -110.8940884)
#
# N Hoyne Ave
# (41.9550717, -87.6812061)
#
# S CANAL ST
# (42.1979758, -72.6021589)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# W 35TH ST
# (41.881364, -103.6683128)
#
# S CALIFORNIA AVE
# (34.1163848, -118.0008539)
#
# N Orchard St
# (43.0517216, -77.093211)
#
# W 24TH PL
# (41.5744811, -87.3824265)
#
# S VERNON AVE
# (32.72251, -96.836774)
#
# W OGDEN AVE
# (32.341146, -86.3093)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# S CANAL ST
# (42.1979758, -72.6021589)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# S CICERO AVE
# (41.8545413, -87.7443874)
#
# N ORCHARD ST
# (43.0517216, -77.093211)
#
# S CALIFORNIA AVE
# (34.1163848, -118.0008539)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# W 79TH ST
# (40.7849838, -73.9826637)
#
# S DRAKE AVE
# (41.8498569, -87.713702)
#
# N KILPATRICK AVE
# (41.9699316, -87.74405)
#
# N ST LOUIS AVE
# (41.9727203, -87.7159449)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# N Frontier Ave
# (41.9544884, -87.6466486)
#
# N CLARENDON AVE
# (39.3347411, -74.4980139)
#
# E 77TH ST
# (36.0529109, -95.8831572)
#
# E BELLEVUE PL
# (41.901579, -87.6272014)
#
# W THOMAS ST
# (43.230666, -75.469829)
#
# S ALBANY AVE
# (27.932852, -82.480986)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# E 89TH PL
# (36.0340257, -95.9045251)
#
# S LA SALLE ST
# (41.742861, -88.3242315)
#
# S Michigan Ave
# (42.59934, -83.9336293)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# S SPRINGFIELD AVE
# (40.6858039, -74.3274558)
#
# W DIVERSEY AVE
# (41.9263942, -88.0053438)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# S CICERO AVE
# (41.8545413, -87.7443874)
#
# E PERSHING RD
# (39.8772063, -88.9358125)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# S WESTERN AVE
# (43.5185145, -96.751124)
#
# S CANAL ST
# (42.1979758, -72.6021589)
#
# S KEELER AVE
# (36.7501253, -95.9789915)
#
# N Richmond st
# (41.9557758, -87.7019847)
#
# S SACRAMENTO AVE
# (39.3373525, -74.4801189)
#
# S THROOP ST
# ...
#
# N KEDZIE AVE
# (41.981245, -87.7088348)
#
# S EMERALD AVE
# (33.3965996, -111.8035831)
#
# W WAVELAND AVE
# (41.9466715, -87.8113037)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# W SCHOOL ST
# (33.3044468, -96.4028596)
#
# E 90TH ST
# (39.9181982, -86.0387202)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# W 43RD ST
# (44.9250102, -93.2909497)
#
# S SPRINGFIELD AVE
# (40.6858039, -74.3274558)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# N NEWLAND AVE
# (41.9223472, -87.7988731)
#
# W BERWYN AVE
# (41.9775394, -87.712376)
#
# N NEWLAND AVE
# (41.9223472, -87.7988731)
#
# W ARMITAGE AVE
# (43.1023086, -87.9910021)
#
# E 62ND ST
# (44.890728, -93.259847)
#
# N MASON AVE
# (42.354338, -85.244316)
#
# S NEENAH AVE
# (44.820963, -87.382074)
#
# W 55TH ST
# (40.7692044, -73.9927944)
#
# S WALLACE ST
# (38.6625346, -87.3019057)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# S OAKLEY AVE
# (41.6631708, -86.1244023)
#
# W ALBION AVE
# (42.0009577, -87.7179087)
#
# W ARMITAGE AVE
# (43.1023086, -87.9910021)
#
# W GRACE ST
# (37.5509972, -77.4531109)
#
# W HIGGINS AVE
# (41.9820571, -87.8112681)
#
# W 83RD PL
# (41.4664124, -87.3859098)
#
# S DREXEL AVE
# (33.369843, -111.623825)
#
# W ALTGELD ST
# (41.9262007, -87.8075454)
#
# S COTTAGE GROVE AVE
# (41.6856412, -87.6114137)
#
# S ADA ST
# (44.9307182, -93.0759931)
#
# S CREGIER AVE
# (41.7663619, -87.5812232)
#
# W FARWELL AVE
# (42.0067765, -87.6605207)
#
# N BEACON ST
# (41.4586084, -74.4140133)
#
# E PEARSON ST
# (43.053739, -87.900774)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# S KOMENSKY AVE
# (41.7242244, -87.7231031)
#
# S SACRAMENTO AVE
# (39.3373525, -74.4801189)
#
# S WOLCOTT AVE
# (41.8741687, -87.6740297)
#
# E 89TH PL
# (36.0340257, -95.9045251)
#
# N LAKEVIEW AVE
# (42.691734, -73.629981)
#
# W EVERGREEN AVE
# (34.1350555, -118.0011499)
#
# W 70TH PL
# (25.886576, -80.29765)
#
# W GRAND AVE
# (44.89992, -89.6139466)
#
# E 21ST ST
# (44.9618246, -93.259672)
#
# W 47TH PL
# (41.568397, -90.623596)
#
# E 44TH ST
# (44.9233272, -93.2683053)
#
# W DIVISION ST
# (38.2597099, -87.9979169)
#
# W OHIO ST
# (40.646058, -83.609337)
#
# N RICHMOND ST
# (41.9557758, -87.7019847)
#
# N LAPORTE AVE
# (41.9754723, -87.751858)
#
# N CUMBERLAND AVE
# (28.5746976, -81.5453944)
#
# S KEDZIE AVE
# (41.7315967, -87.7021544)
#
# E 69TH ST
# (39.001852, -94.5613311)
#
# S SEELEY AVE
# (42.2886768, -89.633005)
#
# S Lake Park Ave
# (41.5348577, -87.2596604)
#
# S OAKLEY AVE
# (41.6631708, -86.1244023)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# W GREENLEAF AVE
# (42.010296, -87.6685965)
#
# N CROSBY ST
# (41.431494, -96.510016)
#
# W 73RD ST
# (41.7589455, -87.8049929)
#
# E KINZIE ST
# (41.8892706, -87.6274916)
#
# S MAPLEWOOD AVE
# (36.0250954, -95.9064784)
#
# N LAVERGNE AVE
# (41.9090105, -87.9045527)
#
# W OAKDALE AVE
# (29.0407755, -81.3169917)
#
# N LEADER AVE
# (41.9945512, -87.7516463)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# S BISHOP ST
# (39.5665983, -76.9892851)
#
# S THROOP ST
# (41.7467867, -87.6560654)
#
# S PRINCETON AVE
# (39.7884436, -75.1461365)
#
# N LARAMIE AVE
# (41.8954167, -87.7556069)
#
# W TALCOTT AVE
# (41.9845749, -87.8041302)
#
# W GLADYS AVE
# (41.915226, -87.959294)
#
# W JEROME ST
# (42.0184138, -87.7002228)
#
# S CAMPBELL AVE
# (37.1712552, -93.2953919)
#
# N OAK PARK AVE
# (41.9071844, -87.7950033)
#
# W PL
# (39.0445999, -94.6029041)
#
# S CHICAGO BEACH DR
# (41.8059766, -87.5853623)
#
# W 67TH PL
# (25.8836759, -80.3255296)
#
# N LARAMIE AVE
# (41.8954167, -87.7556069)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# S MILLARD AVE
# (36.725905, -119.6804604)
#
# N MARINE DR
# (33.8164549, -117.8300018)
#
# S PULASKI RD
# (41.6803208, -87.7198931)
#
# W ST
# (55.8497133, -4.2656724)
#
# S PHILLIPS AVE
# (43.513078, -96.7262166)
#
# N LATROBE AVE
# (41.9852199, -87.7604579)
#
# W HOMER ST
# (38.613178, -86.101403)
#
# S SPAULDING AVE
# (34.0288086, -118.3700242)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# W 58TH ST
# (44.8978415, -93.2888067)
#
# W RACE AVE
# (35.2508634, -91.74748)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# W LAKE ST
# (41.8877192, -87.7651226)
#
# S HAMILTON AVE
# (29.4083447, -98.5341118)
#
# W 77TH ST
# (39.7052739, -74.134883)
#
# E 62ND ST
# (44.890728, -93.259847)
#
# W DIVERSEY AVE
# (41.9263942, -88.0053438)
#
# S EBERHART AVE
# (43.822127, -84.748397)
#
# S VERNON AVE
# (32.72251, -96.836774)
#
# S CONSTANCE AVE
# (39.1322267, -86.4965916)
#
# W OAKDALE AVE
# (29.0407755, -81.3169917)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# W CRYSTAL ST
# (28.899691, -82.574754)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# S VINCENNES AVE
# (41.6979977, -87.6592612)
#
# W ST
# (55.8497133, -4.2656724)
#
# W SUPERIOR ST
# (40.857308, -96.805534)
#
# W 79TH PL
# (25.89498, -80.294083)
#
# W CONGRESS PKWY
# (41.8750866, -87.6539866)
#
# W 47TH ST
# (40.7580163, -73.9817975)
#
# N SPAULDING AVE
# (41.9543894, -87.7104772)
#
# W GOETHE ST
# (41.9056968, -87.6365183)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# W 73RD ST
# (41.7589455, -87.8049929)
#
# S SOUTH SHORE DR
# (41.7687175, -87.5665152)
#
# E 60TH ST
# (44.8942722, -93.2746348)
#
# W DICKENS AVE
# (26.2215137, -98.1842927)
#
# S KERFOOT AVE
# (41.7414221, -87.6404092)
#
# N MAPLEWOOD AVE
# (36.1771957, -95.9078851)
#
# W GRANVILLE AVE
# (40.245255, -96.754104)
#
# W 26TH ST
# (41.8444628, -87.7092909)
#
# E ST
# (50.4738724, 4.2358174)
#
# W IMLAY ST
# (41.9969101, -87.8037106)
#
# N MULLIGAN AVE
# (41.9602275, -87.7855735)
#
# N GRESHAM AVE
# (41.9348173, -87.7158431)
#
# W 26TH ST
# (41.8444628, -87.7092909)
#
# W GRACE ST
# (37.5509972, -77.4531109)
#
# S MAY ST
# (35.5997263, -77.5918349)
#
# S FAIRFIELD AVE
# (41.8828928, -88.0058916)
#
# S BLUE ISLAND AVE
# (41.8541923, -87.6641634)
#
# E 76TH ST
# (39.704568, -74.135229)
#
# N CLARENDON AVE
# (39.3347411, -74.4980139)
#
# W HIRSCH ST
# (41.9062185, -87.7313087)
#
# N LAVERGNE AVE
# (41.9090105, -87.9045527)
#
# N GLENWOOD AVE
# (42.650887, -83.284998)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# S WOODLAWN AVE
# (41.7812374, -87.5962214)
#
# S MANISTEE AVE
# (41.6390183, -87.5555637)
#
# W 65TH ST
# (34.6902193, -92.3298401)
#
# S PAULINA ST
# (41.878849, -87.6692204)
#
# E 91ST ST
# (38.9616117, -94.5526531)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# S CICERO AVE
# (41.8545413, -87.7443874)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# N ELSTON AVE
# (41.9624991, -87.731967)
#
# W C1 ST
# (16.8263301, 96.2703488)
#
# S CANAL ST
# (42.1979758, -72.6021589)
#
# S PAULINA ST
# (41.878849, -87.6692204)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# N WELLS ST
# (30.831592, -83.286031)
#
# W 87TH ST
# (38.970993, -94.7161832)
#
# W PETERSON AVE
# (41.9903163, -87.7190017)
#
# N WACKER DR
# (40.759348, -89.6577155)
#
# N STATE ST
# (44.619052, -75.408869)
#
# N PAULINA ST
# (41.9902949, -87.6714344)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# W IDA B WELLS DR
# (41.8756771, -87.6325771)
#
# W SCHOOL ST
# (33.3044468, -96.4028596)
#
# S Wentworth Ave
# (42.9981308, -87.8894434)
#
# N MONTICELLO AVE
# (41.9751716, -87.7196691)
#
# W POLK ST
# (30.7116929, -94.9383233)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W BRIAR PL
# (41.9391149, -87.6468032)
#
# N PAULINA ST
# (41.9902949, -87.6714344)
#
# W IOWA ST
# (43.0518372, -91.3949007)
#
# W SUNNYSIDE AVE
# (41.9635312, -87.6603099)
#
# N GREENVIEW AVE
# (42.2840502, -89.1311541)
#
# S Michigan Ave
# (42.59934, -83.9336293)
#
# S DEARBORN ST
# (47.5958836, -122.318572)
#
# W PALMER ST
# (35.1795946, -83.3858583)
#
# E IDA B WELLS DR
# (41.8757455, -87.6251804)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# N ALBANY AVE
# (40.7076835, -73.465108)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# W Belmont Ave
# (40.839392, -96.722861)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# N WINCHESTER AVE
# (46.4110364, -105.830487)
#
# E 9TH ST
# (37.0034535, -121.5606568)
#
# N KILPATRICK AVE
# (41.9699316, -87.74405)
#
# N JANSSEN AVE
# (41.9725741, -87.6667373)
#
# N LAKEWOOD AVE
# (31.856847, -102.514627)
#
# W AINSLIE ST
# (41.9701978, -87.7164722)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# S Burley Ave
# (41.7376517, -87.5453086)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# N DAYTON ST
# (43.1198845, -85.5544939)
#
# W EDDY ST
# (33.6448338, -97.3810902)
#
# S STEWART AVE
# (28.290846, -81.4066339)
#
# S RIDGELAND AVE
# (41.8835463, -87.7845574)
#
# W BITTERSWEET PL
# (41.9543315, -87.7894585)
#
# W CORTEZ st
# (33.5897649, -112.4664308)
#
# E Ohio St
# (40.601786, -84.084445)
#
# W THOMAS ST
# (43.230666, -75.469829)
#
# S HARPER AVE
# (33.3743982, -111.6339155)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# W HUBBARD ST
# (41.7159012, -89.3389805)
#
# N Elston Ave
# (41.9624991, -87.731967)
#
# N SPAULDING AVE
# (41.9543894, -87.7104772)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# W CORTLAND ST
# (42.591483, -76.371899)
#
# W 38TH PL
# (41.548344, -87.2952495)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# N ELSTON AVE
# (41.9624991, -87.731967)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# S WOOD ST
# (41.343196, -83.119849)
#
# S KENWOOD AVE
# (41.8060326, -87.5935411)
#
# S BENNETT AVE
# (39.047033, -82.645968)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# N WINCHESTER AVE
# (46.4110364, -105.830487)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# N CLARENDON AVE
# (39.3347411, -74.4980139)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# N WOLCOTT AVE
# (41.9069854, -87.6730408)
#
# W 16TH ST
# (37.3052344, -120.4970248)
#
# N Glenwood Ave
# (42.650887, -83.284998)
#
# W ERIE ST
# (33.3076026, -111.9043792)
#
# W C1 ST
# (16.8263301, 96.2703488)
#
# W ELM ST
# (31.7998495, -97.0960399)
#
# S DEARBORN ST
# (47.5958836, -122.318572)
#
# N Sheffield ave
# (43.1085525, -87.8984732)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# N CLINTON ST
# (43.0516907, -76.1535027)
#
# W GRACE ST
# (37.5509972, -77.4531109)
#
# S state st
# (43.964385, -88.9429077)
#
# W Montrose Ave
# (41.9607197, -87.7466474)
#
# S KEDVALE AVE
# (41.6474182, -87.7222793)
#
# W CHARLESTON ST
# (36.007004, -95.8607771)
#
# N WIELAND ST
# (41.9098507, -87.6356493)
#
# N NORTHWEST HWY
# (42.0193599, -87.8423973)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# E RANDOLPH ST
# (39.430644, -96.7584772)
#
# W IDA B WELLS DR
# (41.8756771, -87.6325771)
#
# N Lotus Ave
# (35.4704582, -97.3553818)
#
# N TROY ST
# (41.9593759, -87.70697)
#
# W margate ter
# (41.9724667, -87.6521788)
#
# N WINCHESTER AVE
# (46.4110364, -105.830487)
#
# N WOOD ST
# (32.3586259, -97.3959405)
#
# W WINNEMAC AVE
# (41.9733819, -87.667451)
#
# W IDA B WELLS DR
# (41.8756771, -87.6325771)
#
# S HYDE PARK BLVD
# (41.7978073, -87.5840054)
#
# W GUNNISON ST
# (41.969023, -87.7398109)
#
# N HOWE ST
# (33.9374828, -78.0259086)
#
# E CHICAGO AVE
# (41.8968438, -87.6168932)
#
# W ALDINE AVE
# (41.9418061, -87.6487849)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# N FRANCISCO AVE
# (26.2217801, -98.3199932)
#
# N broadway
# (40.9696948, -73.8844801)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# W SUPERIOR ST
# (40.857308, -96.805534)
#
# W LAKE ST
# (41.8877192, -87.7651226)
#
# W PRATT BLVD
# (42.0054657, -87.6658226)
#
# W BERENICE AVE
# (41.9494861, -87.7950096)
#
# W TERMINAL ST
# (38.3711643, -88.065751)
#
# N ELSTON AVE
# (41.9624991, -87.731967)
#
# E WASHINGTON ST
# (48.4192112, -122.3309125)
#
# E 47TH DR
# (32.6426596, -114.3973967)
#
# S EVANS AVE
# (35.509722, -97.9558699)
#
# S EGGLESTON AVE
# (35.407396, -97.5137083)
#
# N SAWYER AVE
# (41.9610885, -87.7094607)
#
# S ELLIS AVE
# (35.309552, -78.616879)
#
# S VERNON AVE
# (32.72251, -96.836774)
#
# N FAIRFIELD AVE
# (40.417653, -120.640311)
#
# E 89TH PL
# (36.0340257, -95.9045251)
#
# S SOUTH SHORE DR
# (41.7687175, -87.5665152)
#
# S CALUMET AVE
# (41.7034033, -86.871671)
#
# N WESTERN AVE
# (35.5293143, -97.5298153)
#
# S EBERHART AVE
# (43.822127, -84.748397)
#
# W ROOSEVELT RD
# (41.8568563, -88.1736282)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# S KILBOURN AVE
# (41.8591487, -87.737185)
#
# N STATE ST
# (44.619052, -75.408869)
#
# S Halsted St
# (41.5420844, -87.6359687)
#
# W 91ST ST
# (41.7265995, -87.7948245)
#
# N TRUMBULL AVE
# (45.5965005, -122.7536356)
#
# W GOODMAN ST
# (31.3445752, -110.9482013)
#
# N KEDZIE AVE
# (41.981245, -87.7088348)
#
# W SUPERIOR ST
# (40.857308, -96.805534)
#
# W 66TH PL
# (25.883077, -80.317394)
#
# W OHIO ST
# (40.646058, -83.609337)
#
# S HARDING AVE
# (36.6834759, -119.7343476)
#
# W BERWYN AVE
# (41.9775394, -87.712376)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# N WALLER AVE
# (41.8910824, -87.7677998)
#
# N PULASKI RD
# (41.9640877, -87.7278964)
#
# N BROADWAY
# (40.9696948, -73.8844801)
#
# S MUSKEGON AVE
# (41.6308631, -87.5542799)
#
# W AGATITE AVE
# (41.9619564, -87.7205109)
#
# N KEDZIE AVE
# (41.981245, -87.7088348)
#
# S LOOMIS BLVD
# (41.7570599, -87.6587609)
#
# S COTTAGE GROVE AVE
# (41.6856412, -87.6114137)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# N NEW ENGLAND AVE
# (41.9380328, -87.7981462)
#
# S PEORIA ST
# (39.5974063, -104.8480467)
#
# S DREXEL AVE
# (33.369843, -111.623825)
#
# S PERRY AVE
# (27.74589, -81.794657)
#
# S COTTAGE GROVE AVE
# (41.6856412, -87.6114137)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# W 59TH ST
# (40.7646364, -73.9737661)
#
# W 84TH ST
# (38.9742141, -94.857781)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# S CENTRAL PARK AVE
# (41.7169517, -87.7114806)
#
# N FAIRFIELD AVE
# (40.417653, -120.640311)
#
# S FORRESTVILLE AVE
# (41.6913991, -87.6091965)
#
# E 75TH ST
# (38.985274, -94.4306042)
#
# W FARWELL AVE
# (42.0067765, -87.6605207)
#
# S HAMILTON AVE
# (29.4083447, -98.5341118)
#
# W HOWARD ST
# (43.4469912, -92.2854434)
#
# N KIMBALL AVE
# (32.948407, -97.1167804)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# S SEELEY AVE
# (42.2886768, -89.633005)
#
# W WALTON ST
# (33.089508, -83.237513)
#
# S DREXEL AVE
# (33.369843, -111.623825)
#
# W 86TH ST
# (40.7861728, -73.9714247)
#
# S MASON AVE
# (47.1898123, -122.4941429)
#
# W ARGYLE ST
# (57.8956842, -5.1630045)
#
# N KEDVALE AVE
# (41.9640717, -87.7315451)
#
# N ROCKWELL ST
# (33.3744844, -111.7302071)
#
# W ROOSEVELT RD
# (41.8568563, -88.1736282)
#
# S DANTE AVE
# (41.5394098, -87.5855724)
#
# E 59TH ST
# (40.7639662, -73.9722705)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# W TAYLOR ST
# (41.3837633, -75.7166377)
#
# W FOSTER AVE
# (41.975528, -87.7281106)
#
# N SAYRE AVE
# (41.9628625, -87.8025486)
#
# S CANAL ST
# (42.1979758, -72.6021589)
#
# W 35TH ST
# (41.881364, -103.6683128)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# W POLK ST
# (30.7116929, -94.9383233)
#
# S TRIPP AVE
# (41.663533, -87.72595)
#
# S TROY ST
# (42.4897468, -83.1419423)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# S GREEN ST
# (37.8040878, -87.6368672)
#
# S KIMBARK AVE
# (41.7673136, -87.5941382)
#
# N LINCOLN AVE
# (45.660956, -122.6824777)
#
# S SPRINGFIELD AVE
# (40.6858039, -74.3274558)
#
# S KILDARE AVE
# (41.6744106, -87.7275156)
#
# S FRANCISCO AVE
# (37.6847697, -122.4009224)
#
# N LAMON AVE
# (41.9242164, -87.7487482)
#
# W GRACE ST
# (37.5509972, -77.4531109)
#
# S ST LOUIS AVE
# (41.0219002, -87.7208064)
#
# S MARYLAND AVE
# (39.5941256, -75.9378606)
#
# E 72ND ST
# (40.7710212, -73.9636252)
#
# N SAUGANASH AVE
# (41.994039, -87.7412704)
#
# S DRAKE AVE
# (41.8498569, -87.713702)
#
# N NAGLE AVE
# (41.9200303, -87.7865552)
#
# N OSCEOLA AVE
# (27.9762873, -82.799457)
#
# N TRIPP AVE
# (41.9848527, -87.7341352)
#
# W GRAND AVE
# (44.89992, -89.6139466)
#
# S LA SALLE ST
# (41.742861, -88.3242315)
#
# N HAMLIN AVE
# (41.9737701, -87.7232845)
#
# S HARPER AVE
# (33.3743982, -111.6339155)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# N MASON AVE
# (42.354338, -85.244316)
#
# W GRANVILLE AVE
# (40.245255, -96.754104)
#
# N Hazel St
# (40.166712, -76.395635)
#
# S CHAMPLAIN AVE
# (32.1827548, -110.8194486)
#
# S DREXEL AVE
# (33.369843, -111.623825)
#
# W GLADYS AVE
# (41.915226, -87.959294)
#
# S FRANCISCO AVE
# (37.6847697, -122.4009224)
#
# W CORNELIA AVE
# (33.9618136, -98.6777071)
#
# W IRVING PARK RD
# (41.953826, -87.7116755)
#
# N KEELER AVE
# (31.890888, -102.393391)
#
# N MC VICKER AVE
# (41.7720642, -87.7721541)
#
# S RIVERSIDE PLZ
# (41.87992545, -87.63872659087485)
#
# E OHIO ST
# (40.601786, -84.084445)
#
# N Kedzie Ave
# (41.981245, -87.7088348)
#
# W CHASE AVE
# (32.780398, -116.9699604)
#
# S SPAULDING AVE
# (34.0288086, -118.3700242)
#
# S CALIFORNIA AVE
# (34.1163848, -118.0008539)
#
# W 61ST ST
# (44.89257, -93.315002)
#
# W ROOSEVELT RD
# (41.8568563, -88.1736282)
#
# W MONTROSE AVE
# (41.9607197, -87.7466474)
#
# N NEENAH AVE
# (41.9419257, -87.7898424)
#
# S WOLCOTT AVE
# (41.8741687, -87.6740297)
#
# S KNOX AVE
# (31.7922502, -102.4986994)
#
# S MOZART ST
# (41.726308, -87.6933241)
#
# W 61ST ST
# (44.89257, -93.315002)
#
# N Hamilton Ave
# (40.696537, -73.368294)
#
# E DREXEL SQUARE DR
# (41.8013879, -87.6063821)
#
# S LAKE PARK AVE
# (41.5348577, -87.2596604)
#
# N LARAMIE AVE
# (41.8954167, -87.7556069)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# W ILLINOIS ST
# (41.862092, -88.108188)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# N COLUMBUS DR
# (30.5692605, -85.1366536)

# %%
# Save Checkpoint 
df2019_geo = df_2019.copy()

# %%
# Filter location that is not null
df2019_geo = df2019_geo[df2019_geo['location'].notna()]

# %%
df2019_geo = impute_district(df2019_geo)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:113: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326

# %%
# Drop columns
df2019_geo.drop(['district', 'index_right'], axis=1, inplace=True)

# Rename columns
df2019_geo.rename(columns={'dist_num':'district'}, inplace=True)

# %%
# Impute updated ward values
df2019_geo = impute_ward(df2019_geo)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:69: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326

# %%
# Drop columns
df2019_geo.drop(['ward_left', 'index_right'], axis=1, inplace=True)

# Rename columns
df2019_geo.rename(columns={'ward_right':'ward'}, inplace=True)

# %%
# Impute updated district values
df2019_geo = impute_commareas(df2019_geo)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:91: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326

# %%
# Drop columns
df2019_geo.drop(['community_area', 'index_right'], axis=1, inplace=True)

# Rename columns
df2019_geo.rename(columns={'area_numbe':'community_area'}, inplace=True)

# %%
# Balance clean up of dataset after transformation
# Drop columns
df2019_geo.drop(['x_coordinate', 'y_coordinate'], axis=1, inplace=True)

# Assign null values in location description to 'OTHER (Specify)'
df2019_geo['location_description'].fillna('OTHER (SPECIFY)', inplace = True)

# %%
df2019_geo.to_csv('/content/drive/MyDrive/Colab Notebooks/capstone/assets/2019_crime_clean.csv', index=False)

# %%
df2019_geo.isnull().sum()
# Out:
# id                      0
# case_number             0
# date                    0
# block                   0
# iucr                    0
# primary_type            0
# description             0
# location_description    0
# arrest                  0
# domestic                0
# beat                    0
# fbi_code                0
# year                    0
# updated_on              0
# latitude                0
# longitude               0
# location                0
# day                     0
# month                   0
# day_of_week             0
# time                    0
# geometry                0
# district                0
# ward                    0
# community_area          0
# dtype: int64

# %% [markdown]
# ## Clean data (2018)

# %%
# from geopy.geocoders import Nominatim
geocoder = Nominatim(user_agent = 'crime_predictions')

# %%
df_2018 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/capstone/assets/2018_crime.csv')
df_2018.head()
# Out:
#          id case_number                 date                  block  iucr  \
# 0  11646166    JC213529  2018-09-01 00:01:00  082XX S INGLESIDE AVE  0810
# 1  11645648    JC212959  2018-01-01 08:00:00    024XX N MONITOR AVE  1153
# 2  11645959    JC211511  2018-12-20 16:00:00     045XX N ALBANY AVE  2820
# 3  11645557    JC212685  2018-04-01 00:01:00     080XX S VERNON AVE  1153
# 4  11646293    JC213749  2018-12-20 15:00:00   023XX N LOCKWOOD AVE  1154
#
#          primary_type                              description  \
# 0               THEFT                                OVER $500
# 1  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 2       OTHER OFFENSE                         TELEPHONE THREAT
# 3  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 4  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
#
#   location_description  arrest  domestic  beat  district  ward  \
# 0            RESIDENCE   False      True   631       6.0   8.0
# 1            RESIDENCE   False     False  2515      25.0  30.0
# 2            RESIDENCE   False     False  1724      17.0  33.0
# 3            RESIDENCE   False     False   631       6.0   6.0
# 4            APARTMENT   False     False  2515      25.0  36.0
#
#    community_area fbi_code  x_coordinate  y_coordinate  year  \
# 0            44.0       06           NaN           NaN  2018
# 1            19.0       11           NaN           NaN  2018
# 2            14.0      08A           NaN           NaN  2018
# 3            44.0       11           NaN           NaN  2018
# 4            19.0       11           NaN           NaN  2018
#
#                updated_on  latitude  longitude location  day  month  \
# 0  04/06/2019 04:04:43 PM       NaN        NaN      NaN    1      9
# 1  04/06/2019 04:04:43 PM       NaN        NaN      NaN    1      1
# 2  04/06/2019 04:04:43 PM       NaN        NaN      NaN   20     12
# 3  04/06/2019 04:04:43 PM       NaN        NaN      NaN    1      4
# 4  04/06/2019 04:04:43 PM       NaN        NaN      NaN   20     12
#
#    day_of_week  time
# 0            5     0
# 1            0     8
# 2            3    16
# 3            6     0
# 4            3    15

# %%
df_2018.isnull().sum()
# Out:
# id                         0
# case_number                0
# date                       0
# block                      0
# iucr                       0
# primary_type               0
# description                0
# location_description    1022
# arrest                     0
# domestic                   0
# beat                       0
# district                   0
# ward                       4
# community_area             0
# fbi_code                   0
# x_coordinate            4972
# y_coordinate            4972
# year                       0
# updated_on                 0
# latitude                4972
# longitude               4972
# location                4972
# day                        0
# month                      0
# day_of_week                0
# time                       0
# dtype: int64

# %%
replace_to_zero(df_2018)

# %%
index_list = missing_row_loc(df_2018)
# Out:
# 4972

# %%
impute_data(df_2018, index_list)
# Out:
# Streaming output truncated to the last 5000 lines.
#
# W MORSE AVE
# (42.0072486, -87.6859808)
#
# S BURLEY AVE
# (41.7376517, -87.5453086)
#
# W SCHOOL ST
# (33.3044468, -96.4028596)
#
# W DRUMMOND PL
# (41.9315035, -87.643809)
#
# W DIVERSEY AVE
# (41.9263942, -88.0053438)
#
# N MARINE DR
# (33.8164549, -117.8300018)
#
# W MARQUETTE RD
# (41.7726852, -87.6253898)
#
# S ESCANABA AVE
# (41.7482723, -87.55405)
#
# S PULASKI RD
# (41.6803208, -87.7198931)
#
# N NORMANDY AVE
# (32.3607574, -95.2956254)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# E PEARSON ST
# (43.053739, -87.900774)
#
# W GRENSHAW ST
# (41.8679092, -87.6630252)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# N OGDEN AVE
# (41.2832412, -111.9678465)
#
# S NORMAL AVE
# (37.720105, -89.21769)
#
# N DELPHIA AVE
# (36.7559217, -119.7939473)
#
# W DIVISION ST
# (38.2597099, -87.9979169)
#
# E 13TH ST
# (40.1774606, -85.347364)
#
# W 82ND PL
# (41.4683852, -87.3613672)
#
# W 47TH PL
# (41.568397, -90.623596)
#
# W ST
# (55.8497133, -4.2656724)
#
# N SACRAMENTO AVE
# (39.341244, -74.483242)
#
# W ST
# (55.8497133, -4.2656724)
#
# E WALTON ST
# (33.0918832, -83.2257331)
#
# S DREXEL AVE
# (33.369843, -111.623825)
#
# N LAPORTE AVE
# (41.9754723, -87.751858)
#
# W WILSON AVE
# (47.6575559, -117.4351579)
#
# N HOYNE AVE
# (41.9550717, -87.6812061)
#
# N LA SALLE ST
# (30.398997, -96.0961872)
#
# S Cicero Ave
# (41.8545413, -87.7443874)
#
# E ONTARIO ST
# (42.9988209, -87.8882358)
#
# W PATTERSON AVE
# (35.847964, -79.574575)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# N LATROBE AVE
# (41.9852199, -87.7604579)
#
# N LA SALLE ST
# (30.398997, -96.0961872)
#
# W M17 ST
# (34.6916371, 135.5009538)
#
# S WESTERN AVE
# (43.5185145, -96.751124)
#
# N Columbus Dr
# (30.5692605, -85.1366536)
#
# S CLAREMONT AVE
# (39.096728, -94.442776)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# N ROCKWELL ST
# (33.3744844, -111.7302071)
#
# N CLYBOURN AVE
# (41.9273774, -87.6724654)
#
# S HALSTED ST
# (41.5420844, -87.6359687)
#
# N MOHAWK ST
# (42.790293, -73.712513)
#
# N PEORIA ST
# (40.935557, -89.537819)
#
# W LAWRENCE AVE
# (41.9683042, -87.7231431)
#
# N BROADWAY
# (40.9696948, -73.8844801)
#
# W cortland st
# (42.591483, -76.371899)
#
# W AINSLIE ST
# (41.9701978, -87.7164722)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# N LA SALLE DR
# (32.459967, -99.781336)
#
# N KOSTNER AVE
# (41.9869013, -87.7382889)
#
# N PULASKI RD
# (41.9640877, -87.7278964)
#
# W BLOOMINGDALE AVE
# (27.8936206, -82.2946314)
#
# N STATE ST
# (44.619052, -75.408869)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# E Illinois St
# (41.862286, -88.09637)
#
# N WHIPPLE ST
# (41.9721178, -87.7049131)
#
# W 38TH ST
# (39.7635758, -75.5276556)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# W GRACE ST
# (37.5509972, -77.4531109)
#
# S WELLS ST
# (38.0067095, -89.2477996)
#
# S CALUMET AVE
# (41.7034033, -86.871671)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# N LA SALLE DR
# (32.459967, -99.781336)
#
# W RWY 27R
# (49.3870867, 8.2020301)
#
# W ILLINOIS ST
# (41.862092, -88.108188)
#
# S FRANKLIN ST
# (36.675438, -76.922075)
#
# N LINCOLN AVE
# (45.660956, -122.6824777)
#
# N HERMITAGE AVE
# (40.232782, -74.780752)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# W C1 ST
# (16.8263301, 96.2703488)
#
# W FULLERTON PKWY
# (41.9256195, -87.6390215)
#
# N CLEAVER ST
# (41.90877725, -87.66409688742331)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# E 38TH PL
# (41.5597753, -90.5463908)
#
# W WINONA ST
# (46.8469244, -92.0900123)
#
# S CLINTON ST
# (38.5332401, -89.705132)
#
# S GREEN ST
# (37.8040878, -87.6368672)
#
# S STONY ISLAND AVE
# (41.772423, -87.5862745)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# S BLACKSTONE AVE
# (41.78726, -87.881703)
#
# W ENGLEWOOD AVE
# (40.895974, -73.983219)
#
# E OAK ST
# (33.4730024, -111.9327122)
#
# N HUMBOLDT BLVD
# (43.0638817, -87.8978425)
#
# S NATOMA AVE
# (41.715834, -87.7859084)
#
# N MONTICELLO AVE
# (41.9751716, -87.7196691)
#
# S GREEN ST
# (37.8040878, -87.6368672)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S HAMLIN BLVD
# (41.8778539, -87.7205673)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# N SEDGWICK ST
# (37.693255, -97.36976)
#
# S LOOMIS BLVD
# (41.7570599, -87.6587609)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S EGGLESTON AVE
# (35.407396, -97.5137083)
#
# N ORIOLE AVE
# (41.9361388, -87.8164565)
#
# S CORNELL AVE
# (42.119526, -87.95127)
#
# N FREMONT ST
# (40.768691, -95.3850426)
#
# N KILBOURN AVE
# (41.9717611, -87.7405534)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# W 71ST ST
# (39.882403, -86.227212)
#
# E 46TH ST
# (44.917865, -93.2041653)
#
# W CONGRESS PKWY
# (41.8750866, -87.6539866)
#
# W 95TH ST
# (40.7954358, -73.9757202)
#
# S PARNELL AVE
# (41.6335259, -87.6353874)
#
# W FOSTER AVE
# (41.975528, -87.7281106)
#
# E 56TH ST
# (44.9015711, -93.2646052)
#
# S MAY ST
# (35.5997263, -77.5918349)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# W FOSTER AVE
# (41.975528, -87.7281106)
#
# N CENTRAL AVE
# (35.7718102, -91.6557941)
#
# N AUSTIN AVE
# (41.912831, -87.7753338)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# E 41ST ST
# (44.928696, -93.2276561)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# N MARMORA AVE
# (41.9567321, -87.7744508)
#
# W GLENLAKE AVE
# (41.9920252, -87.7164771)
#
# W 37TH ST
# (43.6239944, -116.244005)
#
# N MASON AVE
# (42.354338, -85.244316)
#
# N NAGLE AVE
# (41.9200303, -87.7865552)
#
# E 32ND ST
# (44.94472, -93.2368469)
#
# W GIDDINGS ST
# (41.9673952, -87.723111)
#
# E PL
# (14.8370417, -89.14104361631954)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# N MARMORA AVE
# (41.9567321, -87.7744508)
#
# W MONTROSE AVE
# (41.9607197, -87.7466474)
#
# S DOBSON AVE
# (41.764125, -87.5994316)
#
# N ALBANY AVE
# (40.7076835, -73.465108)
#
# W GARFIELD BLVD
# (41.7944433, -87.6378706)
#
# N SHEFFIELD AVE
# (43.1085525, -87.8984732)
#
# S SANGAMON ST
# (39.5902655, -89.7359101)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# W ST
# (55.8497133, -4.2656724)
#
# W ST
# (55.8497133, -4.2656724)
#
# S ST LAWRENCE AVE
# (41.7682281, -87.6104913)
#
# N ST LOUIS AVE
# (41.9727203, -87.7159449)
#
# S WASHTENAW AVE
# (41.8244476, -87.6922106)
#
# N KEELER AVE
# (31.890888, -102.393391)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# E 79TH ST
# (40.7742888, -73.9572899)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# S WALLACE ST
# (38.6625346, -87.3019057)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# W WARREN BLVD
# (41.8823807, -87.6651175)
#
# N NASHVILLE AVE
# (33.172839, -86.245134)
#
# E 79TH ST
# (40.7742888, -73.9572899)
#
# S RICHMOND ST
# (44.8899249, -88.3024977)
#
# W KAMERLING AVE
# (41.9048703, -87.7639163)
#
# E 37TH ST
# (39.825431, -85.980762)
#
# S SAWYER AVE
# (47.2288772, -122.4540806)
#
# W 51ST ST
# (40.7597316, -73.9780866)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# S WOLCOTT AVE
# (41.8741687, -87.6740297)
#
# N MELVINA AVE
# (42.0121329, -87.7817803)
#
# S TALMAN AVE
# (41.8617849, -87.692024)
#
# N WELLS ST
# (30.831592, -83.286031)
#
# S LAKE PARK AVE
# (41.5348577, -87.2596604)
#
# S EMERALD AVE
# (33.3965996, -111.8035831)
#
# S WENTWORTH AVE
# (42.9981308, -87.8894434)
#
# S KILDARE AVE
# (41.6744106, -87.7275156)
#
# S SOUTH SHORE DR
# (41.7687175, -87.5665152)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# S BLUE ISLAND AVE
# (41.8541923, -87.6641634)
#
# W IRVING PARK RD
# (41.953826, -87.7116755)
#
# W WRIGHTWOOD AVE
# (41.9247283, -87.9553717)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# S DOTY AVE W
# (41.6562186, -87.5905125)
#
# W SHERWIN AVE
# (42.0150507, -87.7786003)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# W POLK ST
# (30.7116929, -94.9383233)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# N WABASH AVE
# (41.1450949, -87.8658414)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# E 59TH ST
# (40.7639662, -73.9722705)
#
# N ODELL AVE
# (39.1214083, -93.1948712)
#
# S JEFFERSON ST
# (45.8680078, -112.0965554)
#
# S JEFFERY BLVD
# (41.7479785, -87.5759176)
#
# W DIVERSEY AVE
# (41.9263942, -88.0053438)
#
# E PL
# (14.8370417, -89.14104361631954)
#
# E 79TH PL
# (36.0493276, -95.9658572)
#
# W ST
# (55.8497133, -4.2656724)
#
# W WILSON AVE
# (47.6575559, -117.4351579)
#
# W LAKESIDE PL
# (42.0625044, -88.0999232)
#
# W 61ST ST
# (44.89257, -93.315002)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# S CALUMET AVE
# (41.7034033, -86.871671)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# S HARPER CT
# (41.5483868, -93.8356768)
#
# W NEWPORT AVE
# (42.681683, -83.313192)
#
# S EWING AVE
# (32.7424571, -96.8126924)
#
# S COMMERCIAL AVE
# (41.7141047, -89.3341986)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# N CENTRAL AVE
# (35.7718102, -91.6557941)
#
# S ELIZABETH ST
# (40.727094, -84.106756)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# N STAVE ST
# (41.9193467, -87.6942569)
#
# W CUYLER AVE
# (41.9551763, -87.6742845)
#
# W DIVERSEY PKWY
# (41.9323951, -87.6687745)
#
# S RICHMOND ST
# (44.8899249, -88.3024977)
#
# W MORSE AVE
# (42.0072486, -87.6859808)
#
# S CONSTANCE AVE
# (39.1322267, -86.4965916)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# S WOLCOTT AVE
# (41.8741687, -87.6740297)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# S AUSTIN AVE
# (39.3448149, -74.4685932)
#
# W QUINCY ST
# (28.0541053, -81.9636599)
#
# N WINCHESTER AVE
# (46.4110364, -105.830487)
#
# N HARDING AVE
# (41.9937042, -87.7276304)
#
# W ST
# (55.8497133, -4.2656724)
#
# W WILSON AVE
# (47.6575559, -117.4351579)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# S SPRINGFIELD AVE
# (40.6858039, -74.3274558)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# W HARRISON ST
# (47.453523, -116.785825)
#
# S CICERO AVE
# (41.8545413, -87.7443874)
#
# S PULASKI RD
# (41.6803208, -87.7198931)
#
# W 74TH ST
# (40.780251, -73.9814398)
#
# S WHIPPLE ST
# (42.6302929, -71.3004363)
#
# S SPAULDING AVE
# (34.0288086, -118.3700242)
#
# E 78TH ST
# (36.0516381, -95.9637058)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# W WILCOX ST
# (39.7729655, -86.2196271)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# S FRANCISCO AVE
# (37.6847697, -122.4009224)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# W GARFIELD BLVD
# (41.7944433, -87.6378706)
#
# W WILCOX ST
# (39.7729655, -86.2196271)
#
# E ST
# (50.4738724, 4.2358174)
#
# W GLADYS AVE
# (41.915226, -87.959294)
#
# S DREXEL AVE
# (33.369843, -111.623825)
#
# N DRAKE AVE
# (41.9725027, -87.7171475)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# E ST
# (50.4738724, 4.2358174)
#
# S TROY ST
# (42.4897468, -83.1419423)
#
# W 79TH ST
# (40.7849838, -73.9826637)
#
# N LAVERGNE AVE
# (41.9090105, -87.9045527)
#
# W ST
# (55.8497133, -4.2656724)
#
# W EASTWOOD AVE
# (41.9656467, -87.7297858)
#
# E 25TH PL
# (30.194051, -85.645576)
#
# N RIDGE AVE
# (35.5045339, -80.6185371)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# N LECLAIRE AVE
# (41.935091, -87.7540962)
#
# S VERNON AVE
# (32.72251, -96.836774)
#
# W MONTANA ST
# (45.6644428, -110.568881)
#
# S PARNELL AVE
# (41.6335259, -87.6353874)
#
# S UNION AVE
# (47.2491253, -122.4836389)
#
# E 77TH ST
# (36.0529109, -95.8831572)
#
# E DELAWARE PL
# (41.8992723, -87.6202196)
#
# W FIFTH AVE
# (42.6509145, -71.3368917)
#
# W OHIO ST
# (40.646058, -83.609337)
#
# S NORMAL AVE
# (37.720105, -89.21769)
#
# S MC DOWELL AVE
# (31.220963, -81.473986)
#
# N NATCHEZ AVE
# (41.9548213, -87.7893155)
#
# N KEYSTONE AVE
# (42.0001236, -76.5351751)
#
# N MAJOR AVE
# (36.0352811, -114.9680661)
#
# N AVERS AVE
# (41.9628652, -87.724203)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# S WELLS ST
# (38.0067095, -89.2477996)
#
# N LEAVITT ST
# (39.531967, -87.136931)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W DIVISION ST
# (38.2597099, -87.9979169)
#
# W NELSON ST
# (39.937473, -94.841012)
#
# W SURF ST
# (41.9343518, -87.638939)
#
# S WESTERN AVE
# (43.5185145, -96.751124)
#
# S BENNETT AVE
# (39.047033, -82.645968)
#
# S KILBOURN AVE
# (41.8591487, -87.737185)
#
# N KIMBALL AVE
# (32.948407, -97.1167804)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# E ST
# (50.4738724, 4.2358174)
#
# W CLARENCE AVE
# (41.9945038, -87.8125473)
#
# E 82ND ST
# (41.5041895, -81.6308342)
#
# S ELLIS AVE
# (35.309552, -78.616879)
#
# S HOYNE AVE
# (41.8228899, -87.6774807)
#
# W ROOSEVELT RD
# (41.8568563, -88.1736282)
#
# S KENNETH AVE
# (41.6814466, -87.7302028)
#
# S VINCENNES AVE
# (41.6979977, -87.6592612)
#
# S NEENAH AVE
# (44.820963, -87.382074)
#
# W WILSON AVE
# (47.6575559, -117.4351579)
#
# S BENNETT AVE
# (39.047033, -82.645968)
#
# W CARMEN AVE
# (41.9736044, -87.7374367)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# W GRAND AVE
# (44.89992, -89.6139466)
#
# W HUBBARD ST
# (41.7159012, -89.3389805)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# E SOUTH WATER ST
# (41.8867796, -87.6225047)
#
# N DAMEN AVE
# (41.9744669, -87.6793492)
#
# W 23RD ST
# (40.7442808, -73.9960773)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# N KEYSTONE AVE
# (42.0001236, -76.5351751)
#
# N DAMEN AVE
# (41.9744669, -87.6793492)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# W 66TH ST
# (40.7733596, -73.9809918)
#
# N KEDZIE AVE
# (41.981245, -87.7088348)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# S RACINE AVE
# (42.9427005, -88.1582854)
#
# N PARKSIDE AVE
# (34.082432, -117.6296776)
#
# S COTTAGE GROVE AVE
# (41.6856412, -87.6114137)
#
# E 50TH PL
# (39.845682, -86.057732)
#
# N CENTRAL AVE
# (35.7718102, -91.6557941)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# S BISHOP ST
# (39.5665983, -76.9892851)
#
# S MARSHFIELD AVE
# (41.8093553, -87.6662057)
#
# N RIDGE BLVD
# (38.5054097, -77.9726234)
#
# N RUSH ST
# (43.7828197, -86.4281776)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# S ESSEX AVE
# (39.3133874, -76.4565138)
#
# W ST
# (55.8497133, -4.2656724)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# S PEORIA ST
# (39.5974063, -104.8480467)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# S CALUMET AVE
# (41.7034033, -86.871671)
#
# W GREGORY ST
# (42.0735492, -87.9441124)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# E 73RD ST
# (32.0274706, -81.1097986)
#
# N COLUMBUS DR
# (30.5692605, -85.1366536)
#
# N HARLEM AVE
# (37.093364, -94.529365)
#
# W 60TH ST
# (44.89423, -93.301147)
#
# S EVANS AVE
# (35.509722, -97.9558699)
#
# W LELAND AVE
# (41.9666512, -87.7370944)
#
# N OAK PARK AVE
# (41.9071844, -87.7950033)
#
# S KEDVALE AVE
# (41.6474182, -87.7222793)
#
# S SOUTH SHORE DR
# (41.7687175, -87.5665152)
#
# W 61ST PL
# (25.879063, -80.307356)
#
# N DESPLAINES ST
# (41.8890494, -87.6443381)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# S MAPLEWOOD AVE
# (36.0250954, -95.9064784)
#
# W 12TH PL
# (25.832919, -80.291466)
#
# S PAULINA ST
# (41.878849, -87.6692204)
#
# S ADA ST
# (44.9307182, -93.0759931)
#
# W ST
# (55.8497133, -4.2656724)
#
# E WACKER DR
# (41.8878388, -87.6190596)
#
# S SHORE DR
# (38.721756, -82.978089)
#
# W 95TH ST
# (40.7954358, -73.9757202)
#
# W DEVON AVE
# (41.9973572, -87.7114381)
#
# N WAYNE AVE
# (40.055678, -75.393487)
#
# N LOWER WABASH AVE
# (41.890088, -87.6266553)
#
# W DEVON AVE
# (41.9973572, -87.7114381)
#
# S VERNON AVE
# (32.72251, -96.836774)
#
# N MOZART ST
# (41.963078, -87.699749)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# N MILTIMORE AVE
# (41.9873262, -87.7727911)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# N PULASKI RD
# (41.9640877, -87.7278964)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S MARYLAND AVE
# (39.5941256, -75.9378606)
#
# N LAMON AVE
# (41.9242164, -87.7487482)
#
# W MELROSE ST
# (40.667262, -73.698695)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# S KOMENSKY AVE
# (41.7242244, -87.7231031)
#
# S PULASKI RD
# (41.6803208, -87.7198931)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# N SEELEY AVE
# (43.5619333, -94.7747364)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# S RACINE AVE
# (42.9427005, -88.1582854)
#
# W 55TH ST
# (40.7692044, -73.9927944)
#
# W CORNELIA AVE
# (33.9618136, -98.6777071)
#
# W CORCORAN PL
# (41.8871682, -87.7678871)
#
# S PARKSIDE AVE
# (34.0213373, -117.6290334)
#
# S KOLMAR AVE
# (41.6817099, -87.7322799)
#
# W CORTEZ ST
# (33.5897649, -112.4664308)
#
# N LONG AVE
# (31.872625, -102.526908)
#
# N ROCKWELL ST
# (33.3744844, -111.7302071)
#
# W ST
# (55.8497133, -4.2656724)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# S CLYDE AVE
# (28.2911755, -81.4131903)
#
# N BOSWORTH AVE
# (41.9106545, -87.6665138)
#
# W 55TH ST
# (40.7692044, -73.9927944)
#
# S CARPENTER ST
# (35.240268, -81.338339)
#
# N LOWELL AVE
# (43.051309, -76.184402)
#
# W CRYSTAL ST
# (28.899691, -82.574754)
#
# N CICERO AVE
# (42.0121975, -87.7479383)
#
# N LAWNDALE AVE
# (41.9592196, -87.720432)
#
# S EMERALD AVE
# (33.3965996, -111.8035831)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# S MUSKEGON AVE
# (41.6308631, -87.5542799)
#
# S HALE AVE
# (27.9444192, -82.5109327)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# S COMMERCIAL AVE
# (41.7141047, -89.3341986)
#
# W DAKIN ST
# (41.9516187, -87.7912726)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# S LOOMIS ST
# (41.769112, -88.14147)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# S KEDZIE AVE
# (41.7315967, -87.7021544)
#
# S ESSEX AVE
# (39.3133874, -76.4565138)
#
# S EAST END AVE
# (40.7774069, -73.943042)
#
# S WALDEN PKWY
# (41.7166332, -87.6677208)
#
# W 65TH ST
# (34.6902193, -92.3298401)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W AUGUSTA BLVD
# (41.4210887, -87.732417)
#
# S CALIFORNIA AVE
# (34.1163848, -118.0008539)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# S STEWART AVE
# (28.290846, -81.4066339)
#
# W Iowa ST
# (43.0518372, -91.3949007)
#
# S MARSHFIELD AVE
# (41.8093553, -87.6662057)
#
# W WILSON AVE
# (47.6575559, -117.4351579)
#
# S BLACKSTONE AVE
# (41.78726, -87.881703)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W 87TH ST
# (38.970993, -94.7161832)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# W CONGRESS PKWY
# (41.8750866, -87.6539866)
#
# N CLYBOURN AVE
# (41.9273774, -87.6724654)
#
# S PAULINA ST
# (41.878849, -87.6692204)
#
# N ST CLAIR ST
# (38.6048814, -89.8103789)
#
# W 16TH ST
# (37.3052344, -120.4970248)
#
# S MILLARD AVE
# (36.725905, -119.6804604)
#
# N ST CLAIR ST
# (38.6048814, -89.8103789)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# W CERMAK RD
# (41.8495374, -87.849713)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# S BENSLEY AVE
# (41.6390654, -87.5628808)
#
# W ADDISON ST
# (42.226415, -84.406033)
#
# E 71ST ST
# (41.5110354, -81.6395881)
#
# S KEDZIE AVE
# (41.7315967, -87.7021544)
#
# W DEVON AVE
# (41.9973572, -87.7114381)
#
# E 89TH PL
# (36.0340257, -95.9045251)
#
# W GRENSHAW ST
# (41.8679092, -87.6630252)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# S EVANS AVE
# (35.509722, -97.9558699)
#
# S FAIRFIELD AVE
# (41.8828928, -88.0058916)
#
# S CLAREMONT AVE
# (39.096728, -94.442776)
#
# W GRAND AVE
# (44.89992, -89.6139466)
#
# N ROGERS AVE
# (42.118891, -76.046551)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# W 92ND PL
# (41.4500313, -87.3867959)
#
# N MONTICELLO AVE
# (41.9751716, -87.7196691)
#
# S RICHMOND ST
# (44.8899249, -88.3024977)
#
# W DIVERSEY PKWY
# (41.9323951, -87.6687745)
#
# S CICERO AVE
# (41.8545413, -87.7443874)
#
# N Kolin Ave
# (41.8840787, -87.7343473)
#
# W SUNNYSIDE AVE
# (41.9635312, -87.6603099)
#
# N WHIPPLE ST
# (41.9721178, -87.7049131)
#
# W ERIE ST
# (33.3076026, -111.9043792)
#
# W WEST END AVE
# (41.8840066, -87.7595529)
#
# S WENTWORTH AVE
# (42.9981308, -87.8894434)
#
# N SHEFFIELD AVE
# (43.1085525, -87.8984732)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# S MAJOR AVE
# (41.664039, -87.760687)
#
# N ARTESIAN AVE
# (41.9254283, -87.6888852)
#
# N LA CROSSE AVE
# (38.2701926, -104.5890357)
#
# E 67TH ST
# (31.9089805, -102.3842858)
#
# S KIMBARK AVE
# (41.7673136, -87.5941382)
#
# E 95TH ST
# (40.7835163, -73.9474639)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# S VINCENNES AVE
# (41.6979977, -87.6592612)
#
# S COLES AVE
# (41.7483376, -87.5491898)
#
# S VINCENNES AVE
# (41.6979977, -87.6592612)
#
# S ALBANY AVE
# (27.932852, -82.480986)
#
# S DAUPHIN AVE
# (27.8698258, -82.4986097)
#
# W 43RD ST
# (44.9250102, -93.2909497)
#
# N MARINE DR
# (33.8164549, -117.8300018)
#
# S ALBANY AVE
# (27.932852, -82.480986)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# W COLUMBUS AVE
# (39.3034047, -85.2267268)
#
# N LA SALLE ST
# (30.398997, -96.0961872)
#
# S SAWYER AVE
# (47.2288772, -122.4540806)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# W 60TH ST
# (44.89423, -93.301147)
#
# S ADA ST
# (44.9307182, -93.0759931)
#
# S MAY ST
# (35.5997263, -77.5918349)
#
# S LAFAYETTE AVE
# (39.334709, -74.489355)
#
# N ALBANY AVE
# (40.7076835, -73.465108)
#
# S BLUE ISLAND AVE
# (41.8541923, -87.6641634)
#
# N LA SALLE ST
# (30.398997, -96.0961872)
#
# S BISHOP ST
# (39.5665983, -76.9892851)
#
# E 36TH PL
# (39.822629, -86.024769)
#
# N SOUTHPORT AVE
# (41.9507055, -87.6641098)
#
# E 9TH ST
# (37.0034535, -121.5606568)
#
# E OAKWOOD BLVD
# (41.8241108, -87.6043228)
#
# S SPAULDING AVE
# (34.0288086, -118.3700242)
#
# E 14TH ST
# (40.7321878, -73.9845578)
#
# S KEDVALE AVE
# (41.6474182, -87.7222793)
#
# W GUNNISON ST
# (41.969023, -87.7398109)
#
# N SPAULDING AVE
# (41.9543894, -87.7104772)
#
# W CULLOM AVE
# (41.9590228, -87.7389563)
#
# W Wellington Ave
# (38.1838186, -85.7649883)
#
# S EAST END AVE
# (40.7774069, -73.943042)
#
# S KEELER AVE
# (36.7501253, -95.9789915)
#
# W PL
# (39.0445999, -94.6029041)
#
# S CARPENTER ST
# (35.240268, -81.338339)
#
# W GRENSHAW ST
# (41.8679092, -87.6630252)
#
# S KILBOURN AVE
# (41.8591487, -87.737185)
#
# W THORNDALE AVE
# (41.9885001, -87.7104758)
#
# E 79TH ST
# (40.7742888, -73.9572899)
#
# W HARRISON ST
# (47.453523, -116.785825)
#
# S AVERS AVE
# (41.6734757, -87.7157121)
#
# S KEDZIE AVE
# (41.7315967, -87.7021544)
#
# S PRINCETON AVE
# (39.7884436, -75.1461365)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# S FORRESTVILLE AVE
# (41.6913991, -87.6091965)
#
# W 58TH ST
# (44.8978415, -93.2888067)
#
# E 13TH ST
# (40.1774606, -85.347364)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# N SPAULDING AVE
# (41.9543894, -87.7104772)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# S ALBANY AVE
# (27.932852, -82.480986)
#
# N KOSTNER AVE
# (41.9869013, -87.7382889)
#
# W 63RD ST
# (41.7733805, -87.9889844)
#
# S CARPENTER ST
# (35.240268, -81.338339)
#
# W Jarvis Ave
# (42.0153543, -87.8050829)
#
# W BARRY AVE
# (36.8175627, -93.9243727)
#
# S ARTESIAN AVE
# (34.0977413, -117.3182866)
#
# W WEBSTER AVE
# (42.4488715, -83.1273708)
#
# S KILDARE AVE
# (41.6744106, -87.7275156)
#
# S LAKE PARK AVE
# (41.5348577, -87.2596604)
#
# S SPRINGFIELD AVE
# (40.6858039, -74.3274558)
#
# S CORLISS AVE
# (41.6899396, -87.6012166)
#
# S MERRILL AVE
# (47.1026257, -104.715102)
#
# N HOYNE AVE
# (41.9550717, -87.6812061)
#
# S MARSHFIELD AVE
# (41.8093553, -87.6662057)
#
# W 35TH ST
# (41.881364, -103.6683128)
#
# N STATE ST
# (44.619052, -75.408869)
#
# W HOWARD ST
# (43.4469912, -92.2854434)
#
# W DIVISION ST
# (38.2597099, -87.9979169)
#
# N LAWLER AVE
# (41.9186896, -87.7523027)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# S BURLEY AVE
# (41.7376517, -87.5453086)
#
# S ESSEX AVE
# (39.3133874, -76.4565138)
#
# S STEWART AVE
# (28.290846, -81.4066339)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# S MOZART ST
# (41.726308, -87.6933241)
#
# N STETSON AVE
# (41.8876872, -87.6223174)
#
# N LAPORTE AVE
# (41.9754723, -87.751858)
#
# S HOMAN AVE
# (41.6622485, -87.7046222)
#
# S VINCENNES AVE
# (41.6979977, -87.6592612)
#
# W SEIPP ST
# (41.7380126, -87.6947059)
#
# W 87TH ST
# (38.970993, -94.7161832)
#
# S PAULINA ST
# (41.878849, -87.6692204)
#
# N MONTICELLO AVE
# (41.9751716, -87.7196691)
#
# S NORMAL AVE
# (37.720105, -89.21769)
#
# S PEORIA ST
# (39.5974063, -104.8480467)
#
# N NARRAGANSETT AVE
# (41.9633701, -87.7869544)
#
# S HERMITAGE AVE
# (41.7685166, -87.6675589)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# S LAFAYETTE AVE
# (39.334709, -74.489355)
#
# W 23RD ST
# (40.7442808, -73.9960773)
#
# S RACINE AVE
# (42.9427005, -88.1582854)
#
# S ST LAWRENCE AVE
# (41.7682281, -87.6104913)
#
# N HAUSSEN CT
# (41.9360784, -87.7239374)
#
# S SPRINGFIELD AVE
# (40.6858039, -74.3274558)
#
# S DREXEL BLVD
# (35.4636206, -97.5703073)
#
# S HERMITAGE AVE
# (41.7685166, -87.6675589)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# S Michigan Ave
# (42.59934, -83.9336293)
#
# W HARRISON ST
# (47.453523, -116.785825)
#
# W KAMERLING AVE
# (41.9048703, -87.7639163)
#
# N ASHLAND BLVD
# (42.0066203, -87.6699972)
#
# W 17TH ST
# (30.1810582, -85.7266273)
#
# N ST LOUIS AVE
# (41.9727203, -87.7159449)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# S SANGAMON ST
# (39.5902655, -89.7359101)
#
# S CANAL ST
# (42.1979758, -72.6021589)
#
# W FARGO AVE
# (36.3572713, -119.6489519)
#
# S ELLIS AVE
# (35.309552, -78.616879)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# S CANAL ST
# (42.1979758, -72.6021589)
#
# S ELLIS AVE
# (35.309552, -78.616879)
#
# S HALSTED ST
# (41.5420844, -87.6359687)
#
# N WESTERN AVE
# (35.5293143, -97.5298153)
#
# N NARRAGANSETT AVE
# (41.9633701, -87.7869544)
#
# E 56TH ST
# (44.9015711, -93.2646052)
#
# S COTTAGE GROVE AVE
# (41.6856412, -87.6114137)
#
# S SANGAMON ST
# (39.5902655, -89.7359101)
#
# S MERRILL AVE
# (47.1026257, -104.715102)
#
# S KIMBARK AVE
# (41.7673136, -87.5941382)
#
# S BLACKSTONE AVE
# (41.78726, -87.881703)
#
# N MONITOR AVE
# (41.9791477, -87.7744717)
#
# N HOYNE AVE
# (41.9550717, -87.6812061)
#
# W SUPERIOR ST
# (40.857308, -96.805534)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# S LAKE PARK AVE
# (41.5348577, -87.2596604)
#
# S EDBROOKE AVE
# (41.6980924, -87.6196287)
#
# S BURNSIDE AVE
# (30.2022661, -90.9203336)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# W ADDISON ST
# (42.226415, -84.406033)
#
# N MAY ST
# (35.6016763, -77.5898474)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W TAYLOR ST
# (41.3837633, -75.7166377)
#
# W CHASE AVE
# (32.780398, -116.9699604)
#
# W ROOSEVELT RD
# (41.8568563, -88.1736282)
#
# S ADA ST
# (44.9307182, -93.0759931)
#
# N NORMANDY AVE
# (32.3607574, -95.2956254)
#
# W BALMORAL AVE
# (41.9798396, -87.6688623)
#
# E 77TH ST
# (36.0529109, -95.8831572)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# S ARTESIAN AVE
# (34.0977413, -117.3182866)
#
# N ALBANY AVE
# (40.7076835, -73.465108)
#
# W BARRY AVE
# (36.8175627, -93.9243727)
#
# W 27TH ST
# (41.873811, -103.670278)
#
# S HERMOSA AVE
# (33.9126479, -116.8692547)
#
# W ADDISON ST
# (42.226415, -84.406033)
#
# N CENTRAL PARK AVE
# (41.9751896, -87.7184185)
#
# N CLARENDON AVE
# (39.3347411, -74.4980139)
#
# S UNION AVE
# (47.2491253, -122.4836389)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# W ST
# (55.8497133, -4.2656724)
#
# W 63RD ST
# (41.7733805, -87.9889844)
#
# N NEVA AVE
# (41.9100895, -87.8039791)
#
# N KEDZIE AVE
# (41.981245, -87.7088348)
#
# S MARSHFIELD AVE
# (41.8093553, -87.6662057)
#
# W WALNUT ST
# (31.8085297, -97.0935238)
#
# S HAMILTON AVE
# (29.4083447, -98.5341118)
#
# S COMMERCIAL AVE
# (41.7141047, -89.3341986)
#
# W BYRON ST
# (41.9503382, -87.7955338)
#
# N LOVEJOY AVE
# (41.9752196, -87.7658729)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# S DANIEL DR
# (40.9296114, -90.4079592)
#
# S HARPER AVE
# (33.3743982, -111.6339155)
#
# N AVERS AVE
# (41.9628652, -87.724203)
#
# S Michigan Ave
# (42.59934, -83.9336293)
#
# N MARINE DR
# (33.8164549, -117.8300018)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# S PAULINA ST
# (41.878849, -87.6692204)
#
# N KENTON AVE
# (41.9747987, -87.7430818)
#
# W 83RD ST
# (41.7432634, -87.6499076)
#
# S PERRY AVE
# (27.74589, -81.794657)
#
# S SPAULDING AVE
# (34.0288086, -118.3700242)
#
# W ST
# (55.8497133, -4.2656724)
#
# W ARGYLE ST
# (57.8956842, -5.1630045)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# S MARYLAND AVE
# (39.5941256, -75.9378606)
#
# S EVANS AVE
# (35.509722, -97.9558699)
#
# W 83RD ST
# (41.7432634, -87.6499076)
#
# W MELROSE ST
# (40.667262, -73.698695)
#
# W ARTHINGTON ST
# (41.8700106, -87.7112288)
#
# S TROY ST
# (42.4897468, -83.1419423)
#
# N KOSTNER AVE
# (41.9869013, -87.7382889)
#
# S CARPENTER ST
# (35.240268, -81.338339)
#
# N LEAVITT ST
# (39.531967, -87.136931)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# E CHICAGO AVE
# (41.8968438, -87.6168932)
#
# E CHICAGO AVE
# (41.8968438, -87.6168932)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S PERRY AVE
# (27.74589, -81.794657)
#
# S RICHMOND ST
# (44.8899249, -88.3024977)
#
# W HENDERSON ST
# (35.6845746, -80.4331586)
#
# N WALLER AVE
# (41.8910824, -87.7677998)
#
# N NATCHEZ AVE
# (41.9548213, -87.7893155)
#
# N SHEFFIELD AVE
# (43.1085525, -87.8984732)
#
# E 56TH ST
# (44.9015711, -93.2646052)
#
# W ROOSEVELT RD
# (41.8568563, -88.1736282)
#
# W ROOSEVELT RD
# (41.8568563, -88.1736282)
#
# W ROOSEVELT RD
# (41.8568563, -88.1736282)
#
# W ROOSEVELT RD
# (41.8568563, -88.1736282)
#
# N SEELEY AVE
# (43.5619333, -94.7747364)
#
# W ROOSEVELT RD
# (41.8568563, -88.1736282)
#
# N CLARENDON AVE
# (39.3347411, -74.4980139)
#
# N MOODY AVE
# (27.9453048, -82.484032)
#
# S OAKLEY BLVD
# (41.8761349, -87.6838294)
#
# S CALUMET AVE
# (41.7034033, -86.871671)
#
# N BERNARD ST
# (41.9720734, -87.7146943)
#
# W CHESTNUT ST
# (40.0400916, -76.3165126)
#
# N KOSTNER AVE
# (41.9869013, -87.7382889)
#
# N RIDGEWAY AVE
# (41.9954911, -87.7227208)
#
# S RACINE AVE
# (42.9427005, -88.1582854)
#
# W FARWELL AVE
# (42.0067765, -87.6605207)
#
# N RIDGEWAY AVE
# (41.9954911, -87.7227208)
#
# W 21ST ST
# (44.961758, -93.306244)
#
# E RANDOLPH ST
# (39.430644, -96.7584772)
#
# W 21ST ST
# (44.961758, -93.306244)
#
# W 21ST ST
# (44.961758, -93.306244)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# N WINTHROP AVE
# (41.9873032, -87.6581226)
#
# S CALIFORNIA AVE
# (34.1163848, -118.0008539)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# S SANGAMON ST
# (39.5902655, -89.7359101)
#
# N ROGERS AVE
# (42.118891, -76.046551)
#
# W 46TH ST
# (43.5105458, -96.7570732)
#
# S LAKE PARK AVE
# (41.5348577, -87.2596604)
#
# S DREXEL BLVD
# (35.4636206, -97.5703073)
#
# W POLK ST
# (30.7116929, -94.9383233)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# N TRUMBULL AVE
# (45.5965005, -122.7536356)
#
# N LAWNDALE AVE
# (41.9592196, -87.720432)
#
# S PEORIA ST
# (39.5974063, -104.8480467)
#
# W RICE ST
# (35.5516747, -80.6218475)
#
# S SHIELDS AVE
# (37.5470522, -77.4700211)
#
# S HONORE ST
# (41.8267808, -87.6715176)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# S KEELER AVE
# (36.7501253, -95.9789915)
#
# N RIDGEWAY AVE
# (41.9954911, -87.7227208)
#
# N LONG AVE
# (31.872625, -102.526908)
#
# N SACRAMENTO BLVD
# (41.889664, -87.7013745)
#
# E 47TH ST
# (40.7546125, -73.9737345)
#
# W LAKE ST
# (41.8877192, -87.7651226)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# S KEELER AVE
# (36.7501253, -95.9789915)
#
# S CARPENTER ST
# (35.240268, -81.338339)
#
# N NATCHEZ AVE
# (41.9548213, -87.7893155)
#
# E 71ST PL
# (36.0595852, -95.9162265)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# W LAKE ST
# (41.8877192, -87.7651226)
#
# W CERMAK RD
# (41.8495374, -87.849713)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W 95TH ST
# (40.7954358, -73.9757202)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# S RIDGELAND AVE
# (41.8835463, -87.7845574)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# S WELLS ST
# (38.0067095, -89.2477996)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# S WASHTENAW AVE
# (41.8244476, -87.6922106)
#
# S PRINCETON AVE
# (39.7884436, -75.1461365)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# E ST
# (50.4738724, 4.2358174)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W 79TH ST
# (40.7849838, -73.9826637)
#
# W LAKE ST
# (41.8877192, -87.7651226)
#
# S DREXEL AVE
# (33.369843, -111.623825)
#
# S ST LOUIS AVE
# (41.0219002, -87.7208064)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# S CHICAGO SKYWAY OB
# W WILCOX ST
# (39.7729655, -86.2196271)
#
# N KEDZIE BLVD
# (41.9245939, -87.7072256)
#
# W AUGUSTA BLVD
# (41.4210887, -87.732417)
#
# S HONORE ST
# (41.8267808, -87.6715176)
#
# E RANDOLPH ST
# (39.430644, -96.7584772)
#
# W ROOSEVELT RD
# (41.8568563, -88.1736282)
#
# N NARRAGANSETT AVE
# (41.9633701, -87.7869544)
#
# W 15TH ST
# (44.9689141, -93.2867103)
#
# N RIDGEWAY AVE
# (41.9954911, -87.7227208)
#
# S WESTERN AVE
# (43.5185145, -96.751124)
#
# S LOOMIS BLVD
# (41.7570599, -87.6587609)
#
# S SOUTH SHORE DR
# (41.7687175, -87.5665152)
#
# S ST LOUIS AVE
# (41.0219002, -87.7208064)
#
# N JEFFERSON ST
# (43.572607, -76.123675)
#
# S ELLIS AVE
# (35.309552, -78.616879)
#
# S CLAREMONT AVE
# (39.096728, -94.442776)
#
# N AUSTIN BLVD
# (41.8969924, -87.7752014)
#
# S INGLESIDE AVE
# (41.7403543, -87.601287)
#
# W ST
# (55.8497133, -4.2656724)
#
# S COLUMBUS DR
# (33.3465843, -111.7432952)
#
# W ST
# (55.8497133, -4.2656724)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# N LOCKWOOD AVE
# (41.6979589, -83.5699941)
#
# W 87TH ST
# (38.970993, -94.7161832)
#
# W AUGUSTA BLVD
# (41.4210887, -87.732417)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# S SHIELDS AVE
# (37.5470522, -77.4700211)
#
# S RIDGELAND AVE
# (41.8835463, -87.7845574)
#
# W CONGRESS PKWY
# (41.8750866, -87.6539866)
#
# W BLACKHAWK ST
# (43.567624, -96.737549)
#
# W OHIO ST
# (40.646058, -83.609337)
#
# W 83RD ST
# (41.7432634, -87.6499076)
#
# W DEMING PL
# (41.9292488, -87.6406316)
#
# S ST LAWRENCE AVE
# (41.7682281, -87.6104913)
#
# W GARFIELD BLVD
# (41.7944433, -87.6378706)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# W WOLFRAM ST
# (41.9335036, -87.6563169)
#
# E 45TH ST
# (44.9215266, -93.2683374)
#
# E 77TH ST
# (36.0529109, -95.8831572)
#
# S ST LAWRENCE AVE
# (41.7682281, -87.6104913)
#
# S PULASKI RD
# (41.6803208, -87.7198931)
#
# E 36TH ST
# (44.9378251, -93.2191089)
#
# S CANAL ST
# (42.1979758, -72.6021589)
#
# S BISHOP ST
# (39.5665983, -76.9892851)
#
# S WESTERN AVE
# (43.5185145, -96.751124)
#
# W THOMAS ST
# (43.230666, -75.469829)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# E 98TH ST
# (41.5353058, -87.4524707)
#
# N LAWLER AVE
# (41.9186896, -87.7523027)
#
# S LAKE PARK AVE
# (41.5348577, -87.2596604)
#
# W MAPLE ST
# (37.6800483, -97.4058021)
#
# N WESTERN AVE
# (35.5293143, -97.5298153)
#
# W ARMITAGE AVE
# (43.1023086, -87.9910021)
#
# E 72ND ST
# (40.7710212, -73.9636252)
#
# W 43RD ST
# (44.9250102, -93.2909497)
#
# E 74TH PL
# (39.8892699, -86.0747405)
#
# S LAKE PARK AVE
# (41.5348577, -87.2596604)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# W 62ND ST
# (44.8909522, -93.3054532)
#
# S CHICAGO BEACH DR
# (41.8059766, -87.5853623)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# N HAMLIN AVE
# (41.9737701, -87.7232845)
#
# S CREGIER AVE
# (41.7663619, -87.5812232)
#
# N LARAMIE AVE
# (41.8954167, -87.7556069)
#
# E GRAND AVE
# (36.7105116, -119.7874097)
#
# N STETSON AVE
# (41.8876872, -87.6223174)
#
# S PAULINA ST
# (41.878849, -87.6692204)
#
# S TRIPP AVE
# (41.663533, -87.72595)
#
# N OPAL AVE
# (41.9378193, -87.8226158)
#
# N TROY ST
# (41.9593759, -87.70697)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# S AVENUE M
# (31.773624, -97.579064)
#
# S SOUTH SHORE DR
# (41.7687175, -87.5665152)
#
# S EMERALD AVE
# (33.3965996, -111.8035831)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# S BISHOP ST
# (39.5665983, -76.9892851)
#
# S KINGSTON AVE
# (36.044406, -95.9074742)
#
# W CULLERTON ST
# (41.8556603, -87.641803)
#
# S EMERALD AVE
# (33.3965996, -111.8035831)
#
# S EVANS AVE
# (35.509722, -97.9558699)
#
# S KEELER AVE
# (36.7501253, -95.9789915)
#
# S HALSTED ST
# (41.5420844, -87.6359687)
#
# S COTTAGE GROVE AVE
# (41.6856412, -87.6114137)
#
# W PATTERSON AVE
# (35.847964, -79.574575)
#
# W 84TH ST
# (38.9742141, -94.857781)
#
# S PEORIA ST
# (39.5974063, -104.8480467)
#
# N NEVA AVE
# (41.9100895, -87.8039791)
#
# N NORA AVE
# (34.0813562, -117.9385738)
#
# S CICERO AVE
# (41.8545413, -87.7443874)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# E PL
# (14.8370417, -89.14104361631954)
#
# N LAVERGNE AVE
# (41.9090105, -87.9045527)
#
# S HAMLIN AVE
# (42.0088243, -87.8504392)
#
# E 73RD ST
# (32.0274706, -81.1097986)
#
# S KARLOV AVE
# (41.7139045, -87.7235728)
#
# N PARKSIDE AVE
# (34.082432, -117.6296776)
#
# N LEAMINGTON AVE
# (41.8986064, -87.7544655)
#
# N MONTCLARE AVE
# (41.9271534, -87.8039141)
#
# W DEVON AVE
# (41.9973572, -87.7114381)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W WAVELAND AVE
# (41.9466715, -87.8113037)
#
# S CRANDON AVE
# (41.7625938, -87.5688755)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# E HURON ST
# (42.281291, -83.7369982)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# N KILBOURN AVE
# (41.9717611, -87.7405534)
#
# S YATES BLVD
# (41.7408204, -87.5660877)
#
# W 92ND ST
# (38.9630308, -94.6160841)
#
# S PARNELL AVE
# (41.6335259, -87.6353874)
#
# S WOODLAWN AVE
# (41.7812374, -87.5962214)
#
# N OAKLEY AVE
# (41.664195, -86.124499)
#
# W SUPERIOR ST
# (40.857308, -96.805534)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# W SUPERIOR ST
# (40.857308, -96.805534)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# W LAKE ST
# (41.8877192, -87.7651226)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# E PL
# (14.8370417, -89.14104361631954)
#
# N HARDING AVE
# (41.9937042, -87.7276304)
#
# E 83RD ST
# (41.5024109, -81.6295886)
#
# W HUBBARD ST
# (41.7159012, -89.3389805)
#
# W 23RD ST
# (40.7442808, -73.9960773)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# W EVERGREEN AVE
# (34.1350555, -118.0011499)
#
# S DREXEL AVE
# (33.369843, -111.623825)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# S HOMAN AVE
# (41.6622485, -87.7046222)
#
# W HUTCHINSON ST
# (28.4107445, -97.7590378)
#
# N CAMPBELL AVE
# (32.2527259, -110.9439424)
#
# S MANISTEE AVE
# (41.6390183, -87.5555637)
#
# N LINCOLN PARK WEST
# (41.9192403, -87.6363854)
#
# W 25TH PL
# (41.5724621, -87.390001)
#
# W BYRON ST
# (41.9503382, -87.7955338)
#
# S CALUMET AVE
# (41.7034033, -86.871671)
#
# E 77TH ST
# (36.0529109, -95.8831572)
#
# N DAMEN AVE
# (41.9744669, -87.6793492)
#
# N Lamon Ave
# (41.9242164, -87.7487482)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# N PAULINA ST
# (41.9902949, -87.6714344)
#
# N LAWNDALE AVE
# (41.9592196, -87.720432)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# S KILDARE AVE
# (41.6744106, -87.7275156)
#
# S LUNA AVE
# (41.8018752, -87.761324)
#
# W POLK ST
# (30.7116929, -94.9383233)
#
# N MOZART ST
# (41.963078, -87.699749)
#
# N CLINTON ST
# (43.0516907, -76.1535027)
#
# S SPAULDING AVE
# (34.0288086, -118.3700242)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# S Rhodes AVE
# (41.180979, -80.736336)
#
# S ADA ST
# (44.9307182, -93.0759931)
#
# S CAMPBELL AVE
# (37.1712552, -93.2953919)
#
# S FAIRFIELD AVE
# (41.8828928, -88.0058916)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# W 75TH PL
# (25.8910332, -80.2897868)
#
# N KEYSTONE AVE
# (42.0001236, -76.5351751)
#
# S YALE AVE
# (36.0765216, -95.9221167)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# E 72ND ST
# (40.7710212, -73.9636252)
#
# W PL
# (39.0445999, -94.6029041)
#
# S SPRINGFIELD AVE
# (40.6858039, -74.3274558)
#
# N MOZART ST
# (41.963078, -87.699749)
#
# S PRINCETON AVE
# (39.7884436, -75.1461365)
#
# S KEDVALE AVE
# (41.6474182, -87.7222793)
#
# W PL
# (39.0445999, -94.6029041)
#
# W ADDISON ST
# (42.226415, -84.406033)
#
# S TALMAN AVE
# (41.8617849, -87.692024)
#
# W MONTANA ST
# (45.6644428, -110.568881)
#
# E 83RD ST
# (41.5024109, -81.6295886)
#
# S SEELEY AVE
# (42.2886768, -89.633005)
#
# W WALTON ST
# (33.089508, -83.237513)
#
# S PRINCETON AVE
# (39.7884436, -75.1461365)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# S BURLEY AVE
# (41.7376517, -87.5453086)
#
# N LAKEVIEW AVE
# (42.691734, -73.629981)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# W JARVIS AVE
# (42.0153543, -87.8050829)
#
# W 75TH ST
# (44.8673118, -93.306107)
#
# S SPRINGFIELD AVE
# (40.6858039, -74.3274558)
#
# N MARINE DR
# (33.8164549, -117.8300018)
#
# N ST LOUIS AVE
# (41.9727203, -87.7159449)
#
# S INGLESIDE AVE
# (41.7403543, -87.601287)
#
# E PL
# (14.8370417, -89.14104361631954)
#
# S RACINE AVE
# (42.9427005, -88.1582854)
#
# W AUGUSTA BLVD
# (41.4210887, -87.732417)
#
# S HONORE ST
# (41.8267808, -87.6715176)
#
# S SANGAMON ST
# (39.5902655, -89.7359101)
#
# S CALUMET AVE
# (41.7034033, -86.871671)
#
# N MARSHFIELD AVE
# (41.9258863, -87.669388)
#
# W SUPERIOR ST
# (40.857308, -96.805534)
#
# W MAYPOLE AVE
# (41.8835952, -87.7087902)
#
# E 84TH ST
# (40.6411761, -73.914588)
#
# E 48TH ST
# (31.890308, -102.382918)
#
# N WESTERN AVE
# (35.5293143, -97.5298153)
#
# W HIGHLAND AVE
# (32.4336541, -87.0567983)
#
# S PARNELL AVE
# (41.6335259, -87.6353874)
#
# S PERRY AVE
# (27.74589, -81.794657)
#
# W SCHOOL ST
# (33.3044468, -96.4028596)
#
# S LOOMIS BLVD
# (41.7570599, -87.6587609)
#
# S PHILLIPS AVE
# (43.513078, -96.7262166)
#
# W GLADYS AVE
# (41.915226, -87.959294)
#
# S CYRIL AVE
# (41.7648349, -87.5769415)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# W 63RD ST
# (41.7733805, -87.9889844)
#
# S PARNELL AVE
# (41.6335259, -87.6353874)
#
# S HERMITAGE AVE
# (41.7685166, -87.6675589)
#
# N WACKER DR
# (40.759348, -89.6577155)
#
# S LAKE PARK AVE
# (41.5348577, -87.2596604)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# W 31ST ST
# (44.9466054, -93.2862078)
#
# E 77TH ST
# (36.0529109, -95.8831572)
#
# E ONTARIO ST
# (42.9988209, -87.8882358)
#
# N ST LOUIS AVE
# (41.9727203, -87.7159449)
#
# N LAVERGNE AVE
# (41.9090105, -87.9045527)
#
# W 18TH PL
# (30.230237, -85.651847)
#
# E 89TH PL
# (36.0340257, -95.9045251)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# W CERMAK RD
# (41.8495374, -87.849713)
#
# S COTTAGE GROVE AVE
# (41.6856412, -87.6114137)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# E PL
# (14.8370417, -89.14104361631954)
#
# S CANAL ST
# (42.1979758, -72.6021589)
#
# S CANAL ST
# (42.1979758, -72.6021589)
#
# W ERIE ST
# (33.3076026, -111.9043792)
#
# N TRUMBULL AVE
# (45.5965005, -122.7536356)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# S WASHTENAW AVE
# (41.8244476, -87.6922106)
#
# S DOBSON AVE
# (41.764125, -87.5994316)
#
# W 87TH ST
# (38.970993, -94.7161832)
#
# S HYDE PARK BLVD
# (41.7978073, -87.5840054)
#
# N SAWYER AVE
# (41.9610885, -87.7094607)
#
# S ALBANY AVE
# (27.932852, -82.480986)
#
# N HUMBOLDT BLVD
# (43.0638817, -87.8978425)
#
# S ABERDEEN ST
# (35.7300766, -95.3526173)
#
# S ESCANABA AVE
# (41.7482723, -87.55405)
#
# N MONITOR AVE
# (41.9791477, -87.7744717)
#
# S LEAVITT ST
# (41.8737714, -87.6813292)
#
# S KOLIN AVE
# (41.6804633, -87.7282162)
#
# S UNION AVE
# (47.2491253, -122.4836389)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# N COLUMBUS DR
# (30.5692605, -85.1366536)
#
# W 62ND ST
# (44.8909522, -93.3054532)
#
# W GRANVILLE AVE
# (40.245255, -96.754104)
#
# N RICHMOND ST
# (41.9557758, -87.7019847)
#
# N MARSHFIELD AVE
# (41.9258863, -87.669388)
#
# W 50TH ST
# (40.7591258, -73.978595)
#
# N LAWLER AVE
# (41.9186896, -87.7523027)
#
# E MONROE DR
# (35.3490004, -96.9065622)
#
# W BARRY AVE
# (36.8175627, -93.9243727)
#
# S VERNON AVE
# (32.72251, -96.836774)
#
# N LEAVITT ST
# (39.531967, -87.136931)
#
# W PL
# (39.0445999, -94.6029041)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# S CARPENTER ST
# (35.240268, -81.338339)
#
# S RICHMOND ST
# (44.8899249, -88.3024977)
#
# S CANAL ST
# (42.1979758, -72.6021589)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# S WENTWORTH AVE
# (42.9981308, -87.8894434)
#
# S ABERDEEN ST
# (35.7300766, -95.3526173)
#
# N LINDER AVE
# (43.4908412, -116.4138278)
#
# E PL
# (14.8370417, -89.14104361631954)
#
# S THROOP ST
# (41.7467867, -87.6560654)
#
# S WENTWORTH AVE
# (42.9981308, -87.8894434)
#
# W POLK ST
# (30.7116929, -94.9383233)
#
# S COTTAGE GROVE AVE
# (41.6856412, -87.6114137)
#
# W GARFIELD BLVD
# (41.7944433, -87.6378706)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S EGGLESTON AVE
# (35.407396, -97.5137083)
#
# S HOMAN AVE
# (41.6622485, -87.7046222)
#
# S KOMENSKY AVE
# (41.7242244, -87.7231031)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# E 65TH PL
# (39.876728, -86.063538)
#
# E 81ST ST
# (41.4803912, -81.6310758)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# N DRAKE AVE
# (41.9725027, -87.7171475)
#
# W OHIO ST
# (40.646058, -83.609337)
#
# W 64TH ST
# (39.0130173, -94.802986)
#
# N WHIPPLE ST
# (41.9721178, -87.7049131)
#
# N SACRAMENTO BLVD
# (41.889664, -87.7013745)
#
# S UNION AVE
# (47.2491253, -122.4836389)
#
# S EBERHART AVE
# (43.822127, -84.748397)
#
# N MASON AVE
# (42.354338, -85.244316)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# S INGLESIDE AVE
# (41.7403543, -87.601287)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# N LAVERGNE AVE
# (41.9090105, -87.9045527)
#
# N LAWNDALE AVE
# (41.9592196, -87.720432)
#
# S JUSTINE ST
# (41.6714397, -87.6599691)
#
# S SPAULDING AVE
# (34.0288086, -118.3700242)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# N HAMLIN AVE
# (41.9737701, -87.7232845)
#
# N MONITOR AVE
# (41.9791477, -87.7744717)
#
# S KEELER AVE
# (36.7501253, -95.9789915)
#
# S KILBOURN AVE
# (41.8591487, -87.737185)
#
# N LEAMINGTON AVE
# (41.8986064, -87.7544655)
#
# N LOCKWOOD AVE
# (41.6979589, -83.5699941)
#
# W ROOSEVELT RD
# (41.8568563, -88.1736282)
#
# S NORMAL AVE
# (37.720105, -89.21769)
#
# S INGLESIDE AVE
# (41.7403543, -87.601287)
#
# N HAMLIN AVE
# (41.9737701, -87.7232845)
#
# N CHESTER AVE
# (39.987598, -75.81039)
#
# N KEYSTONE AVE
# (42.0001236, -76.5351751)
#
# S WOODLAWN AVE
# (41.7812374, -87.5962214)
#
# W ERIE ST
# (33.3076026, -111.9043792)
#
# E GARFIELD BLVD
# (41.794447, -87.6149514)
#
# N LUNA AVE
# (34.454345, -119.281645)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# W 80TH PL
# (25.8957384, -80.300054)
#
# E 83RD ST
# (41.5024109, -81.6295886)
#
# N CLEAVER ST
# (41.90877725, -87.66409688742331)
#
# W 50TH ST
# (40.7591258, -73.978595)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# N GLENWOOD AVE
# (42.650887, -83.284998)
#
# W 61ST ST
# (44.89257, -93.315002)
#
# S ABERDEEN ST
# (35.7300766, -95.3526173)
#
# S WOLCOTT AVE
# (41.8741687, -87.6740297)
#
# N WELLS ST
# (30.831592, -83.286031)
#
# S RACINE AVE
# (42.9427005, -88.1582854)
#
# S BLACKSTONE AVE
# (41.78726, -87.881703)
#
# S BENSLEY AVE
# (41.6390654, -87.5628808)
#
# W BYRON ST
# (41.9503382, -87.7955338)
#
# N LA SALLE DR
# (32.459967, -99.781336)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# S CARPENTER ST
# (35.240268, -81.338339)
#
# S LAKE PARK AVE
# (41.5348577, -87.2596604)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# W 48TH PL
# (41.530619, -87.3628539)
#
# S WENTWORTH AVE
# (42.9981308, -87.8894434)
#
# W LUNT AVE
# (42.0077782, -87.8200486)
#
# S MUSKEGON AVE
# (41.6308631, -87.5542799)
#
# S WALLACE ST
# (38.6625346, -87.3019057)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# S PHILLIPS AVE
# (43.513078, -96.7262166)
#
# E 63RD ST
# (30.384898, -81.6447918)
#
# S DRAKE AVE
# (41.8498569, -87.713702)
#
# S PAULINA ST
# (41.878849, -87.6692204)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# N PAULINA ST
# (41.9902949, -87.6714344)
#
# S CLARK ST
# (44.955584, -90.795919)
#
# S HAMILTON AVE
# (29.4083447, -98.5341118)
#
# W farwell ave
# (42.0067765, -87.6605207)
#
# W ARMITAGE AVE
# (43.1023086, -87.9910021)
#
# S PHILLIPS AVE
# (43.513078, -96.7262166)
#
# N EAST RIVER RD
# (42.09628, -83.15081)
#
# S CALUMET AVE
# (41.7034033, -86.871671)
#
# S PARNELL AVE
# (41.6335259, -87.6353874)
#
# E ST
# (50.4738724, 4.2358174)
#
# S FAIRFIELD AVE
# (41.8828928, -88.0058916)
#
# N ST LOUIS AVE
# (41.9727203, -87.7159449)
#
# S TRIPP AVE
# (41.663533, -87.72595)
#
# S DREXEL BLVD
# (35.4636206, -97.5703073)
#
# W 64TH ST
# (39.0130173, -94.802986)
#
# E ERIE ST
# (33.3090107, -111.8198088)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# S NORMAL AVE
# (37.720105, -89.21769)
#
# W 86TH ST
# (40.7861728, -73.9714247)
#
# W MORSE AVE
# (42.0072486, -87.6859808)
#
# S KOMENSKY AVE
# (41.7242244, -87.7231031)
#
# S COLFAX AVE
# (30.853988, -96.9914143)
#
# W RICE ST
# (35.5516747, -80.6218475)
#
# N ST LOUIS AVE
# (41.9727203, -87.7159449)
#
# N MAPLEWOOD AVE
# (36.1771957, -95.9078851)
#
# W 14TH PL
# (36.737877, -95.99234)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# N RIDGEWAY AVE
# (41.9954911, -87.7227208)
#
# W GLADYS AVE
# (41.915226, -87.959294)
#
# N RIDGEWAY AVE
# (41.9954911, -87.7227208)
#
# S KENWOOD AVE
# (41.8060326, -87.5935411)
#
# W PL
# (39.0445999, -94.6029041)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# S WOLCOTT AVE
# (41.8741687, -87.6740297)
#
# W 71ST ST
# (39.882403, -86.227212)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# N rockwell st
# (33.3744844, -111.7302071)
#
# N KENNETH AVE
# (41.9717719, -87.7392712)
#
# S WOLCOTT AVE
# (41.8741687, -87.6740297)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# S COLFAX AVE
# (30.853988, -96.9914143)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# W Argyle St
# (57.8956842, -5.1630045)
#
# E 84th Pl
# (41.4637197, -87.3359496)
#
# S KEDZIE AVE
# (41.7315967, -87.7021544)
#
# E PL
# (14.8370417, -89.14104361631954)
#
# N TROY ST
# (41.9593759, -87.70697)
#
# W PERSHING RD
# (39.8764731, -88.9678636)
#
# N MONTICELLO AVE
# (41.9751716, -87.7196691)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# W MONTROSE AVE
# (41.9607197, -87.7466474)
#
# W LEXINGTON ST
# (39.0325997, -97.5948929)
#
# W WRIGHTWOOD AVE
# (41.9247283, -87.9553717)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# N WINTHROP AVE
# (41.9873032, -87.6581226)
#
# N COMMONWEALTH AVE
# (41.7632702, -88.3435098)
#
# E NORTH WATER ST
# (44.1892786, -88.4550657)
#
# S WHIPPLE ST
# (42.6302929, -71.3004363)
#
# S ABERDEEN ST
# (35.7300766, -95.3526173)
#
# S HALSTED ST
# (41.5420844, -87.6359687)
#
# W LE MOYNE ST
# (41.9077136, -87.7331889)
#
# S UNION AVE
# (47.2491253, -122.4836389)
#
# E 59TH ST
# (40.7639662, -73.9722705)
#
# S LAMON AVE
# (41.678126, -87.741686)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# S CAMPBELL AVE
# (37.1712552, -93.2953919)
#
# W WRIGHTWOOD AVE
# (41.9247283, -87.9553717)
#
# N KOSTNER AVE
# (41.9869013, -87.7382889)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# N MC VICKER AVE
# (41.7720642, -87.7721541)
#
# W 64TH ST
# (39.0130173, -94.802986)
#
# W FARRAGUT AVE
# (41.9745691, -87.829751)
#
# S TRUMBULL AVE
# (41.666268, -87.7067038)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W ST
# (55.8497133, -4.2656724)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W EVERGREEN AVE
# (34.1350555, -118.0011499)
#
# N SACRAMENTO BLVD
# (41.889664, -87.7013745)
#
# S VERNON AVE
# (32.72251, -96.836774)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# S SPAULDING AVE
# (34.0288086, -118.3700242)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# W 85TH ST
# (40.784673, -73.9699691)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# S KILPATRICK AVE
# (41.8149584, -87.7409068)
#
# S KARLOV AVE
# (41.7139045, -87.7235728)
#
# W ST
# (55.8497133, -4.2656724)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# N LA SALLE ST
# (30.398997, -96.0961872)
#
# S TRUMBULL AVE
# (41.666268, -87.7067038)
#
# W OGDEN AVE
# (32.341146, -86.3093)
#
# S COTTAGE GROVE AVE
# (41.6856412, -87.6114137)
#
# S JUSTINE ST
# (41.6714397, -87.6599691)
#
# S Michigan Ave
# (42.59934, -83.9336293)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# S KEDZIE AVE
# (41.7315967, -87.7021544)
#
# S INGLESIDE AVE
# (41.7403543, -87.601287)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# E ST
# (50.4738724, 4.2358174)
#
# N KEELER AVE
# (31.890888, -102.393391)
#
# S MOZART ST
# (41.726308, -87.6933241)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# N HOMAN AVE
# (41.8919714, -87.711335)
#
# S FRANCISCO AVE
# (37.6847697, -122.4009224)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# S WOLCOTT AVE
# (41.8741687, -87.6740297)
#
# W WELLINGTON AVE
# (38.1838186, -85.7649883)
#
# W OHIO ST
# ...
#
# W PL
# (39.0445999, -94.6029041)
#
# S SACRAMENTO DR
# (41.8592648, -87.7017057)
#
# W 95TH ST
# (40.7954358, -73.9757202)
#
# W 95TH ST
# (40.7954358, -73.9757202)
#
# S CANAL ST
# (42.1979758, -72.6021589)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# N MOBILE AVE
# (35.2845786, -93.1181537)
#
# N SPRINGFIELD AVE
# (41.9646307, -87.7254887)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# S EMERALD AVE
# (33.3965996, -111.8035831)
#
# S ELIZABETH ST
# (40.727094, -84.106756)
#
# S KENWOOD AVE
# (41.8060326, -87.5935411)
#
# S WELLS ST
# (38.0067095, -89.2477996)
#
# W MARQUETTE RD
# (41.7726852, -87.6253898)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# E 77TH ST
# (36.0529109, -95.8831572)
#
# S CHAMPLAIN AVE
# (32.1827548, -110.8194486)
#
# S YALE AVE
# (36.0765216, -95.9221167)
#
# S WESTERN AVE
# (43.5185145, -96.751124)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# N Lake Shore DR
# (28.905135, -81.763013)
#
# W ST
# (55.8497133, -4.2656724)
#
# S LOOMIS BLVD
# (41.7570599, -87.6587609)
#
# S SPAULDING AVE
# (34.0288086, -118.3700242)
#
# S CALIFORNIA AVE
# (34.1163848, -118.0008539)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# N LARAMIE AVE
# (41.8954167, -87.7556069)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# S AVENUE L
# (31.5331944, -97.4407611)
#
# W 21ST PL
# (41.579758, -87.3761617)
#
# S SAGINAW AVE
# (41.6427026, -87.5580689)
#
# S CICERO AVE
# (41.8545413, -87.7443874)
#
# S LAWLER AVE
# (41.6735388, -87.7455584)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# S PULASKI RD
# (41.6803208, -87.7198931)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# S BISHOP ST
# (39.5665983, -76.9892851)
#
# N RIDGE BLVD
# (38.5054097, -77.9726234)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# W ST
# (55.8497133, -4.2656724)
#
# W PETERSON AVE
# (41.9903163, -87.7190017)
#
# S LA SALLE ST
# (41.742861, -88.3242315)
#
# S CICERO AVE
# (41.8545413, -87.7443874)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# N TRIPP AVE
# (41.9848527, -87.7341352)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# S SAWYER AVE
# (47.2288772, -122.4540806)
#
# S SHIELDS AVE
# (37.5470522, -77.4700211)
#
# W 60TH ST
# (44.89423, -93.301147)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# S MILLARD AVE
# (36.725905, -119.6804604)
#
# N RICHMOND ST
# (41.9557758, -87.7019847)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# S ARTESIAN AVE
# (34.0977413, -117.3182866)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# S MAY ST
# (35.5997263, -77.5918349)
#
# W 60TH ST
# (44.89423, -93.301147)
#
# W THOME AVE
# (41.9955841, -87.6734358)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# W 54TH ST
# (40.7692528, -73.9948535)
#
# W 43RD ST
# (44.9250102, -93.2909497)
#
# W EVERGREEN AVE
# (34.1350555, -118.0011499)
#
# S CICERO AVE
# (41.8545413, -87.7443874)
#
# S VERNON AVE
# (32.72251, -96.836774)
#
# W 21ST PL
# (41.579758, -87.3761617)
#
# W 14TH PL
# (36.737877, -95.99234)
#
# W BRYN MAWR AVE
# (41.983045, -87.711304)
#
# S WOLCOTT AVE
# (41.8741687, -87.6740297)
#
# S VINCENNES AVE
# (41.6979977, -87.6592612)
#
# N LA SALLE ST
# (30.398997, -96.0961872)
#
# E 72ND ST
# (40.7710212, -73.9636252)
#
# S LOOMIS BLVD
# (41.7570599, -87.6587609)
#
# N HARLEM AVE
# (37.093364, -94.529365)
#
# N NEWCASTLE AVE
# (41.9223699, -87.7970239)
#
# S LAWNDALE AVE
# (41.8425259, -87.7171839)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# N LOREL AVE
# (41.8840101, -87.7588689)
#
# W ARGYLE ST
# (57.8956842, -5.1630045)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# S SANGAMON ST
# (39.5902655, -89.7359101)
#
# S HAMLIN AVE
# (42.0088243, -87.8504392)
#
# S FORRESTVILLE AVE
# (41.6913991, -87.6091965)
#
# W FOSTER AVE
# (41.975528, -87.7281106)
#
# N RIDGE BLVD
# (38.5054097, -77.9726234)
#
# W PRYOR AVE
# (36.3095106, -119.3585237)
#
# S EAST END AVE
# (40.7774069, -73.943042)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# S TALMAN AVE
# (41.8617849, -87.692024)
#
# W TAYLOR ST
# (41.3837633, -75.7166377)
#
# N ELSTON AVE
# (41.9624991, -87.731967)
#
# N KILBOURN AVE
# (41.9717611, -87.7405534)
#
# E 71ST PL
# (36.0595852, -95.9162265)
#
# S PERRY AVE
# (27.74589, -81.794657)
#
# S CICERO AVE
# (41.8545413, -87.7443874)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# W RICE ST
# (35.5516747, -80.6218475)
#
# S LA SALLE ST
# (41.742861, -88.3242315)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# S KARLOV AVE
# (41.7139045, -87.7235728)
#
# W 31ST ST
# (44.9466054, -93.2862078)
#
# N LEAMINGTON AVE
# (41.8986064, -87.7544655)
#
# E MONROE ST
# (38.305137, -89.992146)
#
# W ADDISON ST
# (42.226415, -84.406033)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# N STATE ST
# (44.619052, -75.408869)
#
# E JACKSON BLVD
# (37.3767724, -89.6668247)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# S PULASKI RD
# (41.6803208, -87.7198931)
#
# S PULASKI RD
# (41.6803208, -87.7198931)
#
# S WINCHESTER AVE
# (46.406387, -105.830479)
#
# S TROY ST
# (42.4897468, -83.1419423)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# W 87TH ST
# (38.970993, -94.7161832)
#
# N PARKSIDE AVE
# (34.082432, -117.6296776)
#
# W ST
# (55.8497133, -4.2656724)
#
# W ST
# (55.8497133, -4.2656724)
#
# S CHAMPLAIN AVE
# (32.1827548, -110.8194486)
#
# N BEACON ST
# (41.4586084, -74.4140133)
#
# S GREEN ST
# (37.8040878, -87.6368672)
#
# S ST LAWRENCE AVE
# (41.7682281, -87.6104913)
#
# W FLETCHER ST
# (28.324413, -81.40576)
#
# N MONTICELLO AVE
# (41.9751716, -87.7196691)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# N WOLCOTT AVE
# (41.9069854, -87.6730408)
#
# S LAKE PARK AVE
# (41.5348577, -87.2596604)
#
# S Evans Ave
# (35.509722, -97.9558699)
#
# N BEACON ST
# (41.4586084, -74.4140133)
#
# S FRANCISCO AVE
# (37.6847697, -122.4009224)
#
# S RIDGELAND AVE
# (41.8835463, -87.7845574)
#
# N LECLAIRE AVE
# (41.935091, -87.7540962)
#
# S THROOP ST
# (41.7467867, -87.6560654)
#
# W 69TH PL
# (25.8853991, -80.3477838)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# W ALBION AVE
# (42.0009577, -87.7179087)
#
# W 76TH ST
# (33.9707255, -118.2915697)
#
# W 61ST PL
# (25.879063, -80.307356)
#
# E 79TH ST
# (40.7742888, -73.9572899)
#
# S THROOP ST
# (41.7467867, -87.6560654)
#
# S WESTERN AVE
# (43.5185145, -96.751124)
#
# S SACRAMENTO AVE
# (39.3373525, -74.4801189)
#
# S ROCKWELL ST
# (33.3290958, -111.7293356)
#
# N LAVERGNE AVE
# (41.9090105, -87.9045527)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# N LA SALLE DR
# (32.459967, -99.781336)
#
# W HUNTINGTON ST
# (40.554783, -85.282949)
#
# E ST
# (50.4738724, 4.2358174)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# S MAJOR AVE
# (41.664039, -87.760687)
#
# S BISHOP ST
# (39.5665983, -76.9892851)
#
# S SACRAMENTO AVE
# (39.3373525, -74.4801189)
#
# S FAIRFIELD AVE
# (41.8828928, -88.0058916)
#
# S KILPATRICK AVE
# (41.8149584, -87.7409068)
#
# S ADA ST
# (44.9307182, -93.0759931)
#
# S HARDING AVE
# (36.6834759, -119.7343476)
#
# N MARMORA AVE
# (41.9567321, -87.7744508)
#
# S UNION AVE
# (47.2491253, -122.4836389)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# E 63RD ST
# (30.384898, -81.6447918)
#
# W 80TH ST
# (41.7486788, -87.6536729)
#
# N JANSSEN AVE
# (41.9725741, -87.6667373)
#
# N FRANCISCO AVE
# (26.2217801, -98.3199932)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# S CENTRAL AVE
# (40.8950402, -74.0839635)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# W MORSE AVE
# (42.0072486, -87.6859808)
#
# S SAGINAW AVE
# (41.6427026, -87.5580689)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# S ARCHER AVE
# (41.6335223, -88.0133585)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# N PULASKI RD
# (41.9640877, -87.7278964)
#
# W WELLINGTON AVE
# (38.1838186, -85.7649883)
#
# S VERNON AVE
# (32.72251, -96.836774)
#
# W FOSTER AVE
# (41.975528, -87.7281106)
#
# W LELAND AVE
# (41.9666512, -87.7370944)
#
# N LA CROSSE AVE
# (38.2701926, -104.5890357)
#
# W HARRISON ST
# (47.453523, -116.785825)
#
# W TAYLOR ST
# (41.3837633, -75.7166377)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# S CICERO AVE
# (41.8545413, -87.7443874)
#
# S SACRAMENTO BLVD
# (41.877103, -87.7011017)
#
# W 70TH ST
# (32.442242, -93.866732)
#
# S PAULINA ST
# (41.878849, -87.6692204)
#
# E 62ND ST
# (44.890728, -93.259847)
#
# S SEELEY AVE
# (42.2886768, -89.633005)
#
# N SAWYER AVE
# (41.9610885, -87.7094607)
#
# S KIMBARK AVE
# (41.7673136, -87.5941382)
#
# N MARINE DR
# (33.8164549, -117.8300018)
#
# N MASON AVE
# (42.354338, -85.244316)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# N CENTRAL AVE
# (35.7718102, -91.6557941)
#
# S WASHTENAW AVE
# (41.8244476, -87.6922106)
#
# W 87TH ST
# (38.970993, -94.7161832)
#
# S CAMPBELL AVE
# (37.1712552, -93.2953919)
#
# S VINCENNES AVE
# (41.6979977, -87.6592612)
#
# N DAMEN AVE
# (41.9744669, -87.6793492)
#
# W RANDOLPH ST
# (36.2743344, -90.9816148)
#
# W 69TH PL
# (25.8853991, -80.3477838)
#
# S HOYNE AVE
# (41.8228899, -87.6774807)
#
# S DREXEL AVE
# (33.369843, -111.623825)
#
# W 35TH ST
# (41.881364, -103.6683128)
#
# N CENTRAL PARK AVE
# (41.9751896, -87.7184185)
#
# S DORCHESTER AVE
# (41.861114, -88.126156)
#
# W BIRCHWOOD AVE
# (42.9399265, -87.9627232)
#
# W 37TH ST
# (43.6239944, -116.244005)
#
# N Clifton Ave
# (37.2360894, -93.3271958)
#
# E 79TH ST
# (40.7742888, -73.9572899)
#
# S LA SALLE ST
# (41.742861, -88.3242315)
#
# N WINTHROP AVE
# (41.9873032, -87.6581226)
#
# S CANAL ST
# (42.1979758, -72.6021589)
#
# S CANAL ST
# (42.1979758, -72.6021589)
#
# S COTTAGE GROVE AVE
# (41.6856412, -87.6114137)
#
# S PAULINA ST
# (41.878849, -87.6692204)
#
# W 85TH ST
# (40.784673, -73.9699691)
#
# S CALUMET AVE
# (41.7034033, -86.871671)
#
# S PEORIA ST
# (39.5974063, -104.8480467)
#
# N HAMLIN AVE
# (41.9737701, -87.7232845)
#
# W 26TH ST
# (41.8444628, -87.7092909)
#
# E 79TH ST
# (40.7742888, -73.9572899)
#
# W OGDEN AVE
# (32.341146, -86.3093)
#
# W 64TH PL
# (25.881035, -80.3378206)
#
# E 72ND ST
# (40.7710212, -73.9636252)
#
# S WOOD ST
# (41.343196, -83.119849)
#
# W CORTLAND ST
# (42.591483, -76.371899)
#
# W DOUGLAS BLVD
# (41.8629927, -87.7029508)
#
# W NORTH SHORE AVE
# (42.0027093, -87.744558)
#
# N BROADWAY
# (40.9696948, -73.8844801)
#
# S CLAREMONT AVE
# (39.096728, -94.442776)
#
# S KEDZIE AVE
# (41.7315967, -87.7021544)
#
# E KENSINGTON AVE
# (41.6839578, -87.6167641)
#
# W WEBSTER AVE
# (42.4488715, -83.1273708)
#
# N ARTESIAN AVE
# (41.9254283, -87.6888852)
#
# S SPRINGFIELD AVE
# (40.6858039, -74.3274558)
#
# N ST LOUIS AVE
# (41.9727203, -87.7159449)
#
# S WINCHESTER AVE
# (46.406387, -105.830479)
#
# W ARGYLE ST
# (57.8956842, -5.1630045)
#
# N TROY ST
# (41.9593759, -87.70697)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# N WESTERN AVE
# (35.5293143, -97.5298153)
#
# S ELIZABETH ST
# (40.727094, -84.106756)
#
# E ILLINOIS ST
# (41.862286, -88.09637)
#
# S KOMENSKY AVE
# (41.7242244, -87.7231031)
#
# S EVANS AVE
# (35.509722, -97.9558699)
#
# N LOTUS AVE
# (35.4704582, -97.3553818)
#
# N MONTCLARE AVE
# (41.9271534, -87.8039141)
#
# S CHURCH ST
# (41.2952576, -82.9712879)
#
# W TOUHY AVE
# (42.0118322, -87.7491207)
#
# S YALE AVE
# (36.0765216, -95.9221167)
#
# E 77TH ST
# (36.0529109, -95.8831572)
#
# E 32ND ST
# (44.94472, -93.2368469)
#
# N KEDZIE AVE
# (41.981245, -87.7088348)
#
# E 67TH PL
# (36.0649253, -95.9371847)
#
# S KOSTNER AVE
# (41.6651721, -87.7289951)
#
# S WOLCOTT AVE
# (41.8741687, -87.6740297)
#
# S WOOD ST
# (41.343196, -83.119849)
#
# S EVANS AVE
# (35.509722, -97.9558699)
#
# W UNIVERSITY LN
# (41.8635579, -87.6473253)
#
# N PARKSIDE AVE
# (34.082432, -117.6296776)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# S JUSTINE ST
# (41.6714397, -87.6599691)
#
# S CHAMPLAIN AVE
# (32.1827548, -110.8194486)
#
# N PULASKI RD
# (41.9640877, -87.7278964)
#
# S WOLCOTT AVE
# (41.8741687, -87.6740297)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# S YATES BLVD
# (41.7408204, -87.5660877)
#
# N SOUTHPORT AVE
# (41.9507055, -87.6641098)
#
# E ILLINOIS ST
# (41.862286, -88.09637)
#
# W DEVON AVE
# (41.9973572, -87.7114381)
#
# S WOOD ST
# (41.343196, -83.119849)
#
# E ERIE ST
# (33.3090107, -111.8198088)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# N ROCKWELL ST
# (33.3744844, -111.7302071)
#
# W ARMITAGE AVE
# (43.1023086, -87.9910021)
#
# S MARSHFIELD AVE
# (41.8093553, -87.6662057)
#
# N HARLEM AVE
# (37.093364, -94.529365)
#
# N WACKER DR
# (40.759348, -89.6577155)
#
# W HUBBARD ST
# (41.7159012, -89.3389805)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# S HAMLIN AVE
# (42.0088243, -87.8504392)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# N KEELER AVE
# (31.890888, -102.393391)
#
# W OAKDALE AVE
# (29.0407755, -81.3169917)
#
# W FARGO AVE
# (36.3572713, -119.6489519)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# N NORTH BRANCH ST
# (41.9031391, -87.6551326)
#
# N RUSH ST
# (43.7828197, -86.4281776)
#
# S HOLLAND RD
# (43.2411071, -85.1085324)
#
# W 95TH ST
# (40.7954358, -73.9757202)
#
# S JUSTINE ST
# (41.6714397, -87.6599691)
#
# S KOMENSKY AVE
# (41.7242244, -87.7231031)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# W MONTROSE AVE
# (41.9607197, -87.7466474)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# S TRIPP AVE
# (41.663533, -87.72595)
#
# S EBERHART AVE
# (43.822127, -84.748397)
#
# N WILTON AVE
# (42.42707, -88.094391)
#
# S TRUMBULL AVE
# (41.666268, -87.7067038)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# W GARFIELD BLVD
# (41.7944433, -87.6378706)
#
# E 79TH ST
# (40.7742888, -73.9572899)
#
# N CICERO AVE
# (42.0121975, -87.7479383)
#
# S FOREST AVE
# (42.2736405, -83.7331125)
#
# N PAULINA ST
# (41.9902949, -87.6714344)
#
# W 83RD ST
# (41.7432634, -87.6499076)
#
# S DRAKE AVE
# (41.8498569, -87.713702)
#
# S INGLESIDE AVE
# (41.7403543, -87.601287)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# W 47TH ST
# (40.7580163, -73.9817975)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# W CERMAK RD
# (41.8495374, -87.849713)
#
# N DAMEN AVE
# (41.9744669, -87.6793492)
#
# S NORMAL BLVD
# (41.7792236, -87.637511)
#
# N SPAULDING AVE
# (41.9543894, -87.7104772)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# N WINTHROP AVE
# (41.9873032, -87.6581226)
#
# N FRANCISCO AVE
# (26.2217801, -98.3199932)
#
# S EMERALD AVE
# (33.3965996, -111.8035831)
#
# S DRAKE AVE
# (41.8498569, -87.713702)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W WEST END AVE
# (41.8840066, -87.7595529)
#
# W 21ST PL
# (41.579758, -87.3761617)
#
# W MELROSE ST
# (40.667262, -73.698695)
#
# S PULASKI RD
# (41.6803208, -87.7198931)
#
# S ELIZABETH ST
# (40.727094, -84.106756)
#
# W 70TH PL
# (25.886576, -80.29765)
#
# S RIDGEWAY AVE
# (35.61739, -82.3173401)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# S CLAREMONT AVE
# (39.096728, -94.442776)
#
# N HERMITAGE AVE
# (40.232782, -74.780752)
#
# W CERMAK RD
# (41.8495374, -87.849713)
#
# N KEELER AVE
# (31.890888, -102.393391)
#
# N WASHTENAW AVE
# (41.9253795, -87.6949927)
#
# N MOODY AVE
# (27.9453048, -82.484032)
#
# N TRUMBULL AVE
# (45.5965005, -122.7536356)
#
# W 47TH ST
# (40.7580163, -73.9817975)
#
# S MARYLAND AVE
# (39.5941256, -75.9378606)
#
# S WASHTENAW AVE
# (41.8244476, -87.6922106)
#
# W PL
# (39.0445999, -94.6029041)
#
# S PHILLIPS AVE
# (43.513078, -96.7262166)
#
# N KEYSTONE AVE
# (42.0001236, -76.5351751)
#
# N CENTRAL PARK AVE
# (41.9751896, -87.7184185)
#
# N KIMBALL AVE
# (32.948407, -97.1167804)
#
# S MAPLEWOOD AVE
# (36.0250954, -95.9064784)
#
# W HOOD AVE
# (46.214711, -119.1458494)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# N LOWELL AVE
# (43.051309, -76.184402)
#
# S EGGLESTON AVE
# (35.407396, -97.5137083)
#
# W MC LEAN AVE
# (41.9181539, -87.720491)
#
# S SOUTH SHORE DR
# (41.7687175, -87.5665152)
#
# S MAYFIELD AVE
# (41.8800902, -87.7713848)
#
# S KENTON AVE
# (41.6814568, -87.7334309)
#
# W ARMITAGE AVE
# (43.1023086, -87.9910021)
#
# S WALLACE ST
# (38.6625346, -87.3019057)
#
# E ST
# (50.4738724, 4.2358174)
#
# S EVANS AVE
# (35.509722, -97.9558699)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S KEDZIE AVE
# (41.7315967, -87.7021544)
#
# W FLETCHER ST
# (28.324413, -81.40576)
#
# N SPAULDING AVE
# (41.9543894, -87.7104772)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# W 98TH ST
# (39.9294661, -86.2288934)
#
# S MERRILL AVE
# (47.1026257, -104.715102)
#
# S HAMILTON AVE
# (29.4083447, -98.5341118)
#
# N LAVERGNE AVE
# (41.9090105, -87.9045527)
#
# S LEAVITT ST
# (41.8737714, -87.6813292)
#
# W DIVERSEY AVE
# (41.9263942, -88.0053438)
#
# W CULLERTON ST
# (41.8556603, -87.641803)
#
# E 46TH ST
# (44.917865, -93.2041653)
#
# S MAYFIELD AVE
# (41.8800902, -87.7713848)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# W ERIE ST
# (33.3076026, -111.9043792)
#
# S MARSHFIELD AVE
# (41.8093553, -87.6662057)
#
# S FAIRFIELD AVE
# (41.8828928, -88.0058916)
#
# S CRANDON AVE
# (41.7625938, -87.5688755)
#
# W MORSE AVE
# (42.0072486, -87.6859808)
#
# W 63RD ST
# (41.7733805, -87.9889844)
#
# N LONG AVE
# (31.872625, -102.526908)
#
# W CORTEZ ST
# (33.5897649, -112.4664308)
#
# W CERMAK RD
# (41.8495374, -87.849713)
#
# E 84TH ST
# (40.6411761, -73.914588)
#
# S VANDERPOEL AVE
# (41.7202873, -87.6664219)
#
# N CENTRAL AVE
# (35.7718102, -91.6557941)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# S DREXEL BLVD
# (35.4636206, -97.5703073)
#
# N NEENAH AVE
# (41.9419257, -87.7898424)
#
# W SUNNYSIDE AVE
# (41.9635312, -87.6603099)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# E ST
# (50.4738724, 4.2358174)
#
# S VERNON AVE
# (32.72251, -96.836774)
#
# E 79TH ST
# (40.7742888, -73.9572899)
#
# S SANGAMON ST
# (39.5902655, -89.7359101)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)

# %%
# Save Checkpoint 
df2018_geo = df_2018.copy()

# %%
# Filter location that is not null
df2018_geo = df2018_geo[df2018_geo['location'].notna()]

# %%
df2018_geo = impute_district(df2018_geo)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:113: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326

# %%
# Drop columns
df2018_geo.drop(['district', 'index_right'], axis=1, inplace=True)

# Rename columns
df2018_geo.rename(columns={'dist_num':'district'}, inplace=True)

# %%
# Impute updated ward values
df2018_geo = impute_ward(df2018_geo)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:69: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326

# %%
# Drop columns
df2018_geo.drop(['ward_left', 'index_right'], axis=1, inplace=True)

# Rename columns
df2018_geo.rename(columns={'ward_right':'ward'}, inplace=True)

# %%
# Impute updated district values
df2018_geo = impute_commareas(df2018_geo)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:91: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326

# %%
# Drop columns
df2018_geo.drop(['community_area', 'index_right'], axis=1, inplace=True)

# Rename columns
df2018_geo.rename(columns={'area_numbe':'community_area'}, inplace=True)

# %%
# Balance clean up of dataset after transformation
# Drop columns
df2018_geo.drop(['x_coordinate', 'y_coordinate'], axis=1, inplace=True)

# Assign null values in location description to 'OTHER (Specify)'
df2018_geo['location_description'].fillna('OTHER (SPECIFY)', inplace = True)

# %%
df2018_geo.to_csv('/content/drive/MyDrive/Colab Notebooks/capstone/assets/2018_crime_clean.csv', index=False)

# %%
df2018_geo.isnull().sum()
# Out:
# id                      0
# case_number             0
# date                    0
# block                   0
# iucr                    0
# primary_type            0
# description             0
# location_description    0
# arrest                  0
# domestic                0
# beat                    0
# fbi_code                0
# year                    0
# updated_on              0
# latitude                0
# longitude               0
# location                0
# day                     0
# month                   0
# day_of_week             0
# time                    0
# geometry                0
# district                0
# ward                    0
# community_area          0
# dtype: int64

# %% [markdown]
# ## Clean data (2017)

# %%
# from geopy.geocoders import Nominatim
geocoder = Nominatim(user_agent = 'crime_predictions')

# %%
df_2017 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/capstone/assets/2017_crime.csv')
df_2017.head()
# Out:
#          id case_number                 date                 block  iucr  \
# 0  11227287    JB147188  2017-10-08 03:00:00    092XX S RACINE AVE  0281
# 1  11227583    JB147595  2017-03-28 14:00:00       026XX W 79TH ST  0620
# 2  11227293    JB147230  2017-09-09 20:17:00  060XX S EBERHART AVE  0810
# 3  11227634    JB147599  2017-08-26 10:00:00   001XX W RANDOLPH ST  0281
# 4  11227508    JB146365  2017-01-01 00:01:00    027XX S WHIPPLE ST  1754
#
#                  primary_type                     description  \
# 0         CRIM SEXUAL ASSAULT                  NON-AGGRAVATED
# 1                    BURGLARY                  UNLAWFUL ENTRY
# 2                       THEFT                       OVER $500
# 3         CRIM SEXUAL ASSAULT                  NON-AGGRAVATED
# 4  OFFENSE INVOLVING CHILDREN  AGG SEX ASSLT OF CHILD FAM MBR
#
#   location_description  arrest  domestic  beat  district  ward  \
# 0            RESIDENCE   False     False  2222      22.0  21.0
# 1                OTHER   False     False   835       8.0  18.0
# 2            RESIDENCE   False     False   313       3.0  20.0
# 3          HOTEL/MOTEL   False     False   122       1.0  42.0
# 4            RESIDENCE   False     False  1033      10.0  12.0
#
#    community_area fbi_code  x_coordinate  y_coordinate  year  \
# 0            73.0       02           NaN           NaN  2017
# 1            70.0       05           NaN           NaN  2017
# 2            42.0       06           NaN           NaN  2017
# 3            32.0       02           NaN           NaN  2017
# 4            30.0       02           NaN           NaN  2017
#
#                updated_on  latitude  longitude location  day  month  \
# 0  02/11/2018 03:57:41 PM       NaN        NaN      NaN    8     10
# 1  02/11/2018 03:57:41 PM       NaN        NaN      NaN   28      3
# 2  02/11/2018 03:57:41 PM       NaN        NaN      NaN    9      9
# 3  02/11/2018 03:57:41 PM       NaN        NaN      NaN   26      8
# 4  02/11/2018 03:57:41 PM       NaN        NaN      NaN    1      1
#
#    day_of_week  time
# 0            6     3
# 1            1    14
# 2            5    20
# 3            5    10
# 4            6     0

# %%
df_2017.isnull().sum()
# Out:
# id                         0
# case_number                0
# date                       0
# block                      0
# iucr                       0
# primary_type               0
# description                0
# location_description    1252
# arrest                     0
# domestic                   0
# beat                       0
# district                   1
# ward                       1
# community_area             0
# fbi_code                   0
# x_coordinate            3896
# y_coordinate            3896
# year                       0
# updated_on                 0
# latitude                3896
# longitude               3896
# location                3896
# day                        0
# month                      0
# day_of_week                0
# time                       0
# dtype: int64

# %%
replace_to_zero(df_2017)

# %%
index_list = missing_row_loc(df_2017)
# Out:
# 3896

# %%
impute_data(df_2017, index_list)
# Out:
# Streaming output truncated to the last 5000 lines.
#
# N SPRINGFIELD AVE
# (41.9646307, -87.7254887)
#
# S KEELER AVE
# (36.7501253, -95.9789915)
#
# E ST
# (50.4738724, 4.2358174)
#
# N AVERS AVE
# (41.9628652, -87.724203)
#
# W 65TH PL
# (39.876, -86.192027)
#
# S COLFAX AVE
# (30.853988, -96.9914143)
#
# N ROCKWELL ST
# (33.3744844, -111.7302071)
#
# S KARLOV AVE
# (41.7139045, -87.7235728)
#
# S COLFAX AVE
# (30.853988, -96.9914143)
#
# S DEARBORN ST
# (47.5957569, -122.3197611)
#
# S Stewart Ave
# (28.290846, -81.4066339)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# N WASHTENAW AVE
# (41.9253795, -87.6949927)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W Jackson Blvd
# (37.377182, -89.6682716)
#
# E MARQUETTE RD
# (41.7727745, -87.6280678)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# E PL
# (14.8370417, -89.14104361631954)
#
# E 67TH PL
# (36.0649253, -95.9371847)
#
# S SPAULDING AVE
# (34.0288086, -118.3700242)
#
# W ST
# (55.8497133, -4.2656724)
#
# N LAWNDALE AVE
# (41.9592196, -87.720432)
#
# S KEDVALE AVE
# (41.6474182, -87.7222793)
#
# W POTOMAC AVE
# (43.0958445, -88.0105462)
#
# W 96TH ST
# (40.7928721, -73.967548)
#
# N SPRINGFIELD AVE
# (41.9646307, -87.7254887)
#
# E 67TH ST
# (31.9089805, -102.3842858)
#
# W ESTES AVE
# (32.008665, -102.081306)
#
# S CORNELL AVE
# (42.119526, -87.95127)
#
# S MERRIMAC AVE
# (43.57647, -116.306088)
#
# W ADDISON ST
# (42.226415, -84.406033)
#
# S MARYLAND AVE
# (39.5941256, -75.9378606)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# N ORIOLE AVE
# (41.9361388, -87.8164565)
#
# S MAPLEWOOD AVE
# (36.0250954, -95.9064784)
#
# S Loomis St
# (41.769112, -88.14147)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# N PARKSIDE AVE
# (34.082432, -117.6296776)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# W Irving Park Rd
# (41.9536094, -87.7322066)
#
# N MELVINA AVE
# (42.0121329, -87.7817803)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# W 21ST PL
# (41.579758, -87.3761617)
#
# N HAMLIN AVE
# (41.9737701, -87.7232845)
#
# S TALMAN AVE
# (41.8617849, -87.692024)
#
# S CHRISTIANA AVE
# (28.6675036, -81.4969422)
#
# N MAYFIELD AVE
# (34.1105096, -117.2902727)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# S KEDVALE AVE
# (41.6474182, -87.7222793)
#
# E 75TH ST
# (38.985274, -94.4306042)
#
# S HARPER AVE
# (33.3743982, -111.6339155)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# S ALLPORT ST
# (41.8549455, -87.6575679)
#
# W 47TH ST
# (40.7580163, -73.9817975)
#
# S KINGSTON AVE
# (36.044406, -95.9074742)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# E 77TH ST
# (36.0529109, -95.8831572)
#
# W POPE JOHN PAUL II DR
# (41.815443, -87.7017808)
#
# S PARK SHORE EAST CT
# (41.7837478, -87.5878863)
#
# S LOOMIS ST
# (41.769112, -88.14147)
#
# W POPE JOHN PAUL II DR
# (41.815443, -87.7017808)
#
# W 94TH ST
# (39.9223608, -86.2310595)
#
# W WELLINGTON AVE
# (38.1838186, -85.7649883)
#
# S DREXEL AVE
# (33.369843, -111.623825)
#
# S SACRAMENTO AVE
# (39.3373525, -74.4801189)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# W 63RD PKWY
# (41.7821426, -87.6460823)
#
# S EUCLID AVE
# (43.5904697, -83.9155365)
#
# S MERRILL AVE
# (47.1026257, -104.715102)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# S WINCHESTER AVE
# (46.406387, -105.830479)
#
# S EMERALD AVE
# (33.3965996, -111.8035831)
#
# W ROSCOE ST
# (41.9417774, -87.798255)
#
# E 45TH ST
# (44.9215266, -93.2683374)
#
# E 90TH ST
# (39.9181982, -86.0387202)
#
# S ELLIS AVE
# (35.309552, -78.616879)
#
# W POLK ST
# (30.7116929, -94.9383233)
#
# S LAKE PARK AVE
# (41.5348577, -87.2596604)
#
# S ABERDEEN ST
# (35.7300766, -95.3526173)
#
# W MAPLE ST
# (37.6800483, -97.4058021)
#
# E BELLEVUE PL
# (41.901579, -87.6272014)
#
# S LAKE PARK AVE
# (41.5348577, -87.2596604)
#
# S KEDZIE AVE
# (41.7315967, -87.7021544)
#
# E WACKER DR
# (41.8878388, -87.6190596)
#
# W WELLINGTON AVE
# (38.1838186, -85.7649883)
#
# W WELLINGTON AVE
# (38.1838186, -85.7649883)
#
# S HONORE ST
# (41.8267808, -87.6715176)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# S ESSEX AVE
# (39.3133874, -76.4565138)
#
# E 87TH ST
# (41.4677098, -81.6272505)
#
# S HARDING AVE
# (36.6834759, -119.7343476)
#
# W THOMAS ST
# (43.230666, -75.469829)
#
# N CLIFTON AVE
# (37.2360894, -93.3271958)
#
# S ARCHER AVE
# (41.6335223, -88.0133585)
#
# W MARQUETTE RD
# (41.7726852, -87.6253898)
#
# W LEXINGTON ST
# (39.0325997, -97.5948929)
#
# N OCONTO AVE
# (41.9452423, -87.8081992)
#
# W ELMDALE AVE
# (41.9908568, -87.6651706)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# E 53RD ST
# (40.7580248, -73.9701634)
#
# S PRINCETON AVE
# (39.7884436, -75.1461365)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# W ALTGELD ST
# (41.9262007, -87.8075454)
#
# N LUNA AVE
# (34.454345, -119.281645)
#
# S HERMITAGE AVE
# (41.7685166, -87.6675589)
#
# N ORLEANS ST
# (34.8209213, -87.6356312)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# S SACRAMENTO AVE
# (39.3373525, -74.4801189)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# S KEDVALE AVE
# (41.6474182, -87.7222793)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# S CARPENTER ST
# (35.240268, -81.338339)
#
# S KENNETH AVE
# (41.6814466, -87.7302028)
#
# S KENWOOD AVE
# (41.8060326, -87.5935411)
#
# S MARQUETTE AVE
# (41.6317592, -87.5567079)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# W DEMING PL
# (41.9292488, -87.6406316)
#
# S YATES BLVD
# (41.7408204, -87.5660877)
#
# S PARNELL AVE
# (41.6335259, -87.6353874)
#
# N CHRISTIANA AVE
# (41.9702394, -87.7121816)
#
# S KOMENSKY AVE
# (41.7242244, -87.7231031)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# N PARKSIDE AVE
# (34.082432, -117.6296776)
#
# W STRONG ST
# (41.971, -87.7262917)
#
# S FAIRFIELD AVE
# (41.8828928, -88.0058916)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# S SANGAMON ST
# (39.5902655, -89.7359101)
#
# W LEXINGTON ST
# (39.0325997, -97.5948929)
#
# W 57TH ST
# (40.7714466, -73.9940769)
#
# W QUINCY ST
# (28.0541053, -81.9636599)
#
# S CLYDE AVE
# (28.2911755, -81.4131903)
#
# N DAMEN AVE
# (41.9649901, -87.6790702)
#
# W EASTWOOD AVE
# (41.9656467, -87.7297858)
#
# E 72ND ST
# (40.7710212, -73.9636252)
#
# W PETERSON AVE
# (41.9903163, -87.7190017)
#
# W 71ST ST
# (39.882403, -86.227212)
#
# E 87TH ST
# (41.4677098, -81.6272505)
#
# S SEELEY AVE
# (42.2886768, -89.633005)
#
# S TRUMBULL AVE
# (41.666268, -87.7067038)
#
# S ELLIS AVE
# (35.309552, -78.616879)
#
# S BENSLEY AVE
# (41.6390654, -87.5628808)
#
# S HERMITAGE AVE
# (41.7685166, -87.6675589)
#
# N KEDZIE AVE
# (41.981245, -87.7088348)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# S VERNON AVE
# (32.72251, -96.836774)
#
# W TERMINAL ST
# (38.3711643, -88.065751)
#
# S WOLCOTT AVE
# (41.8741687, -87.6740297)
#
# E 90TH ST
# (39.9181982, -86.0387202)
#
# N LARAMIE AVE
# (41.8954167, -87.7556069)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S KILBOURN AVE
# (41.8591487, -87.737185)
#
# N LARAMIE AVE
# (41.8954167, -87.7556069)
#
# S CHICAGO BEACH DR
# (41.8059766, -87.5853623)
#
# N CHRISTIANA AVE
# (41.9702394, -87.7121816)
#
# W 87TH ST
# (38.970993, -94.7161832)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# S SANGAMON ST
# (39.5902655, -89.7359101)
#
# S LOOMIS ST
# (41.769112, -88.14147)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# W CONCORD PL
# (40.3981522, -111.9271298)
#
# S WESTERN AVE
# (43.5185145, -96.751124)
#
# S Normal Ave
# (37.720105, -89.21769)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# S KEDVALE AVE
# (41.6474182, -87.7222793)
#
# S CONSTANCE AVE
# (36.6111889, -119.5428517)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# S KIMBARK AVE
# (41.7673136, -87.5941382)
#
# S EBERHART AVE
# (43.822127, -84.748397)
#
# S LAKE PARK AVE
# (41.5348577, -87.2596604)
#
# S DOBSON AVE
# (41.764125, -87.5994316)
#
# N CENTRAL AVE
# (35.7718102, -91.6557941)
#
# S ABERDEEN ST
# (35.7300766, -95.3526173)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W IRVING PARK RD
# (41.9536094, -87.7322066)
#
# N CAMPBELL AVE
# (32.2876934, -110.9438319)
#
# N CAMPBELL AVE
# (32.2876934, -110.9438319)
#
# S TRIPP AVE
# (41.663533, -87.72595)
#
# S EAST END AVE
# (40.7774069, -73.943042)
#
# W WELLINGTON AVE
# (38.1838186, -85.7649883)
#
# N WELLS ST
# (30.831592, -83.286031)
#
# W OHIO ST
# (40.646058, -83.609337)
#
# W TOUHY AVE
# (42.0118322, -87.7491207)
#
# N KEATING AVE
# (41.9746791, -87.7467834)
#
# W 61ST ST
# (44.89257, -93.315002)
#
# S HYDE PARK BLVD
# (41.7978073, -87.5840054)
#
# N LARAMIE AVE
# (41.8954167, -87.7556069)
#
# W 95TH ST
# (40.7954358, -73.9757202)
#
# N JEFFERSON ST
# (43.572607, -76.123675)
#
# W FULTON BLVD
# (41.8864528, -87.7038266)
#
# W ST PAUL AVE
# (43.0347877, -87.9278248)
#
# S Michigan Ave
# (42.59934, -83.9336293)
#
# N NORA AVE
# (34.0813562, -117.9385738)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# S HAMLIN AVE
# (41.8315296, -87.7192675)
#
# W GLADYS AVE
# (41.915226, -87.959294)
#
# S CAMPBELL AVE
# (37.1712552, -93.2953919)
#
# N NATCHEZ AVE
# (41.9548213, -87.7893155)
#
# W 87TH ST
# (38.970993, -94.7161832)
#
# S DOBSON AVE
# (41.764125, -87.5994316)
#
# N RIDGE BLVD
# (38.5054097, -77.9726234)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# S LUELLA AVE
# (41.7589872, -87.5700366)
#
# W MARQUETTE RD
# (41.7726852, -87.6253898)
#
# S RIDGEWAY AVE
# (35.61739, -82.3173401)
#
# W BALMORAL AVE
# (41.9798396, -87.6688623)
#
# N LA SALLE DR
# (32.459967, -99.781336)
#
# W BLOOMINGDALE AVE
# (27.8936206, -82.2946314)
#
# E 50TH PL
# (39.845682, -86.057732)
#
# S COTTAGE GROVE AVE
# (41.6856412, -87.6114137)
#
# W THOMAS ST
# (43.230666, -75.469829)
#
# S EUCLID AVE
# (43.5904697, -83.9155365)
#
# S UNION AVE
# (47.2491253, -122.4836389)
#
# S BELL AVE
# (36.6728853, -120.1423994)
#
# W GLADYS AVE
# (41.915226, -87.959294)
#
# N MOZART ST
# (41.963078, -87.699749)
#
# S HALSTED ST
# (41.5420844, -87.6359687)
#
# N TROY ST
# (41.9593759, -87.70697)
#
# E 81ST PL
# (36.045795, -95.8938498)
#
# S KILDARE AVE
# (41.6744106, -87.7275156)
#
# W 51ST ST
# (40.7597316, -73.9780866)
#
# S CHAPPEL AVE
# (41.7588966, -87.5749062)
#
# N MARSHFIELD AVE
# (41.9258863, -87.669388)
#
# W HOMER ST
# (38.613178, -86.101403)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# E 93RD ST
# (40.7810314, -73.9454051)
#
# S TRUMBULL AVE
# (41.666268, -87.7067038)
#
# N HONORE ST
# (41.9765479, -87.6754559)
#
# S LUELLA AVE
# (41.7589872, -87.5700366)
#
# S LOOMIS BLVD
# (41.7570599, -87.6587609)
#
# N WOLCOTT AVE
# (41.9069854, -87.6730408)
#
# E 51ST ST
# (40.754497, -73.9656924)
#
# N ST LOUIS AVE
# (41.9727203, -87.7159449)
#
# S WALLACE ST
# (38.6625346, -87.3019057)
#
# N FRANKLIN ST
# (43.053353, -76.154839)
#
# N WESTERN AVE
# (35.5293143, -97.5298153)
#
# W LELAND AVE
# (41.9666512, -87.7370944)
#
# N NOBLE ST
# (33.7944831, -117.8022079)
#
# N DAMEN AVE
# (41.9649901, -87.6790702)
#
# N KINGSBURY ST
# (41.8986511, -87.6438839)
#
# S CICERO AVE
# (41.8545413, -87.7443874)
#
# N Eastlake Ter
# (42.019648, -87.664686)
#
# N LA SALLE DR
# (32.459967, -99.781336)
#
# W 55TH ST
# (40.7692044, -73.9927944)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# N WELLS ST
# (30.831592, -83.286031)
#
# W HADDON AVE
# (41.9025006, -87.6659391)
#
# W Lawrence Ave
# (41.9683042, -87.7231431)
#
# N WOLCOTT AVE
# (41.9069854, -87.6730408)
#
# S FOREST AVE
# (42.2736405, -83.7331125)
#
# N BELL AVE
# (32.2464153, -110.8940884)
#
# N DAMEN AVE
# (41.9649901, -87.6790702)
#
# S UNION AVE
# (47.2491253, -122.4836389)
#
# N STATE PKWY
# (41.9077301, -87.6287875)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# N KIMBALL AVE
# (32.948407, -97.1167804)
#
# N AVERS AVE
# (41.9628652, -87.724203)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# S CANAL ST
# (42.1979758, -72.6021589)
#
# E WACKER DR
# (41.8878388, -87.6190596)
#
# N WABASH AVE
# (41.1450949, -87.8658414)
#
# N CLEAVER ST
# (41.90877725, -87.66409688742331)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# E CHICAGO AVE
# (41.8968438, -87.6168932)
#
# S SPRINGFIELD AVE
# (40.6858039, -74.3274558)
#
# N PINE GROVE AVE
# (41.9529308, -87.6478914)
#
# N PIONEER AVE
# (38.349852, -98.205988)
#
# S ELLIS AVE
# (35.309552, -78.616879)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# W LAKE ST
# (41.8877192, -87.7651226)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# W WILCOX ST
# (39.7729655, -86.2196271)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# W MOFFAT ST
# (41.9147199, -87.6873358)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# E 50th St
# (40.7584119, -73.9769016)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# N Milwaukee Ave
# (42.451391, -88.091261)
#
# W RANDOLPH ST
# (36.2743344, -90.9816148)
#
# W OHIO ST
# (40.646058, -83.609337)
#
# S SAGINAW AVE
# (41.6427026, -87.5580689)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# W OHIO ST
# (40.646058, -83.609337)
#
# W PIERCE AVE
# (39.485878, -88.185641)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# N PAULINA ST
# (41.9902949, -87.6714344)
#
# S DEARBORN ST
# (47.5957569, -122.3197611)
#
# N INDIAN RD
# (37.4090741, -98.6027787)
#
# W ROOSEVELT RD
# (41.8568563, -88.1736282)
#
# E LOWER WACKER DR
# (41.8875576, -87.6174627)
#
# E JACKSON BLVD
# (37.3767724, -89.6668247)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# N Clark St
# (42.076021, -78.402981)
#
# S LA SALLE ST
# (41.742861, -88.3242315)
#
# W ST
# (55.8497133, -4.2656724)
#
# W DIVISION ST
# (38.2597099, -87.9979169)
#
# W THOMAS ST
# (43.230666, -75.469829)
#
# N STATE ST
# (44.619052, -75.408869)
#
# W POLK ST
# (30.7116929, -94.9383233)
#
# N ST LOUIS AVE
# (41.9727203, -87.7159449)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# N WINTHROP AVE
# (41.9873032, -87.6581226)
#
# W 16th St
# (37.3052344, -120.4970248)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# E LAKE ST
# (44.9483802, -93.2053802)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# E 59TH ST
# (40.7639662, -73.9722705)
#
# N ST CLAIR ST
# (38.6048814, -89.8103789)
#
# W ST PAUL AVE
# (43.0347877, -87.9278248)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# N ASTOR ST
# (41.0402327, -73.8726946)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# S LA SALLE ST
# (41.742861, -88.3242315)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# W RANDOLPH ST
# (36.2743344, -90.9816148)
#
# N HUDSON AVE
# (37.691596, -83.95988)
#
# W WACKER DR
# (30.4717592, -84.349793)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# S ESSEX AVE
# (39.3133874, -76.4565138)
#
# N SEDGWICK ST
# (37.693255, -97.36976)
#
# N WELLS ST
# (30.831592, -83.286031)
#
# S FORRESTVILLE AVE
# (41.6913991, -87.6091965)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# E WACKER DR
# (41.8878388, -87.6190596)
#
# N MANKATO AVE
# (42.010632, -87.7793399)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# E RANDOLPH ST
# (39.430644, -96.7584772)
#
# W 32ND ST
# (44.9447377, -93.2874525)
#
# W CRYSTAL ST
# (28.899691, -82.574754)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# W IRVING PARK RD
# (41.9536094, -87.7322066)
#
# N STATE ST
# (44.619052, -75.408869)
#
# E ILLINOIS ST
# (41.862286, -88.09637)
#
# W NORTH SHORE AVE
# (42.0027093, -87.744558)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# W IRVING PARK RD
# (41.9536094, -87.7322066)
#
# N RACINE AVE
# (43.003319, -88.216859)
#
# S DEARBORN ST
# (47.5957569, -122.3197611)
#
# W RANDOLPH ST
# (36.2743344, -90.9816148)
#
# S LAKE SHORE DR
# (42.25603, -87.998784)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# N FOREST VIEW AVE
# (42.6504327, -71.3050375)
#
# W Fullerton Ave
# (41.923398, -87.9104238)
#
# S EUCLID PKWY
# (41.7589319, -87.5781852)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# W COLUMBIA AVE
# (47.7106286, -117.421456)
#
# W JARVIS AVE
# (42.0153543, -87.8050829)
#
# N ST CLAIR ST
# (38.6048814, -89.8103789)
#
# W WILLOW ST
# (42.7487589, -84.5619189)
#
# W MONTROSE AVE
# (41.9607197, -87.7466474)
#
# E 8TH ST
# (40.7275449, -73.9851784)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# W TAYLOR ST
# (41.3837633, -75.7166377)
#
# W ROSCOE ST
# (41.9417774, -87.798255)
#
# S HONORE ST
# (41.8267808, -87.6715176)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# W ROSCOE ST
# (41.9417774, -87.798255)
#
# W WASHINGTON ST
# (40.194732, -85.391486)
#
# N NEW ENGLAND AVE
# (41.9380328, -87.7981462)
#
# W WOLFRAM ST
# (41.9335036, -87.6563169)
#
# W BERTEAU AVE
# (41.9561908, -87.8158422)
#
# W WINNEMAC AVE
# (41.9733819, -87.667451)
#
# N ST CLAIR ST
# (38.6048814, -89.8103789)
#
# W ERIE ST
# (33.3076026, -111.9043792)
#
# S PERRY AVE
# (27.74589, -81.794657)
#
# N HOYNE AVE
# (41.9550717, -87.6812061)
#
# N DRAKE AVE
# (41.9725027, -87.7171475)
#
# N BURLING ST
# (41.9148697, -87.6471899)
#
# W ADDISON ST
# (42.226415, -84.406033)
#
# N ADA ST
# (34.536441, -96.208725)
#
# N CICERO AVE
# (42.0121975, -87.7479383)
#
# S VERNON AVE
# (32.72251, -96.836774)
#
# N LARRABEE ST
# (41.8987673, -87.643014)
#
# N LEAVITT ST
# (39.531967, -87.136931)
#
# S AUSTIN AVE
# (39.3448149, -74.4685932)
#
# N BURLING ST
# (41.9148697, -87.6471899)
#
# E OAK ST
# (33.4730024, -111.9327122)
#
# E 90TH ST
# (39.9181982, -86.0387202)
#
# S CICERO AVE
# (41.8545413, -87.7443874)
#
# N WASHTENAW AVE
# (41.9253795, -87.6949927)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# N WACKER DR
# (40.759348, -89.6577155)
#
# N STATE ST
# (44.619052, -75.408869)
#
# W HUBBARD ST
# (41.7159012, -89.3389805)
#
# N MAY ST
# (35.6016763, -77.5898474)
#
# S SACRAMENTO AVE
# (39.3373525, -74.4801189)
#
# N GREEN ST
# (42.932728, -76.570157)
#
# S THROOP ST
# (41.7467867, -87.6560654)
#
# W 31ST ST
# (44.9466054, -93.2862078)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W HUBBARD ST
# (41.7159012, -89.3389805)
#
# N WASHTENAW AVE
# (41.9253795, -87.6949927)
#
# W RWY 27R
# (49.3870867, 8.2020301)
#
# N MOZART ST
# (41.963078, -87.699749)
#
# N WOLCOTT AVE
# (41.9069854, -87.6730408)
#
# S CORLISS AVE
# (41.6899396, -87.6012166)
#
# N STATE ST
# (44.619052, -75.408869)
#
# N LEAVITT ST
# (39.531967, -87.136931)
#
# E 67TH ST
# (31.9089805, -102.3842858)
#
# S ELIZABETH ST
# (40.727094, -84.106756)
#
# S CICERO AVE
# (41.8545413, -87.7443874)
#
# S CENTRAL AVE
# (40.8950402, -74.0839635)
#
# W PETERSON AVE
# (41.9903163, -87.7190017)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# E CHICAGO AVE
# (41.8968438, -87.6168932)
#
# S WOODLAWN AVE
# (41.7812374, -87.5962214)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# W WELLINGTON AVE
# (38.1838186, -85.7649883)
#
# N LA SALLE ST
# (30.398997, -96.0961872)
#
# W MEDILL AVE
# (41.9211428, -87.8794266)
#
# S CLAREMONT AVE
# (39.096728, -94.442776)
#
# S ESSEX AVE
# (39.3133874, -76.4565138)
#
# S WACKER DR
# (41.8753503, -87.6357587)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# N HERMITAGE AVE
# (40.232782, -74.780752)
#
# W SCHUBERT AVE
# (41.921548, -88.096436)
#
# W HUBBARD ST
# (41.7159012, -89.3389805)
#
# S PERRY AVE
# (27.74589, -81.794657)
#
# N NEWGARD AVE
# (42.0017777, -87.666857)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# S DEARBORN ST
# (47.5957569, -122.3197611)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# S ARTESIAN AVE
# (34.0977413, -117.3182866)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# S TALMAN AVE
# (41.8617849, -87.692024)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# E OAK ST
# (33.4730024, -111.9327122)
#
# W TERMINAL ST
# (38.3711643, -88.065751)
#
# W GEORGE ST
# (33.9307626, -116.8894562)
#
# N STATE ST
# (44.619052, -75.408869)
#
# W LAKE ST
# (41.8877192, -87.7651226)
#
# W HUBBARD ST
# (41.7159012, -89.3389805)
#
# S LAKE PARK AVE
# (41.5348577, -87.2596604)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# W M14 ST
# (35.6745485, 139.7455534)
#
# E 53RD ST
# (40.7580248, -73.9701634)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# N MARIA CT
# (41.9622999, -87.8397331)
#
# N OKETO AVE
# (41.952203, -87.8122027)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# W Irving Park Rd
# (41.9536094, -87.7322066)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# N Ravenswood Ave
# (41.9688187, -87.6741627)
#
# N LOWELL AVE
# (43.051309, -76.184402)
#
# W POTOMAC AVE
# (43.0958445, -88.0105462)
#
# W PL
# (39.0445999, -94.6029041)
#
# W DIVISION ST
# (38.2597099, -87.9979169)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# W ILLINOIS ST
# (41.862092, -88.108188)
#
# S INGLESIDE AVE
# (41.7403543, -87.601287)
#
# S Avenue G
# (31.724859, -97.549034)
#
# S LA SALLE ST
# (41.742861, -88.3242315)
#
# W CRESTLINE ST
# (41.7442705, -87.7258555)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# S GREEN ST
# (37.8040878, -87.6368672)
#
# N WELLS ST
# (30.831592, -83.286031)
#
# S LOOMIS BLVD
# (41.7570599, -87.6587609)
#
# S STEWART AVE
# (28.290846, -81.4066339)
#
# N HAMPDEN CT
# (41.9327766, -87.6424927)
#
# W MARQUETTE RD
# (41.7726852, -87.6253898)
#
# W ADDISON ST
# (42.226415, -84.406033)
#
# N KILBOURN AVE
# (41.9717611, -87.7405534)
#
# N MAJOR AVE
# (36.0352811, -114.9680661)
#
# S PROSPECT AVE
# (33.8413909, -118.3763438)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# S AVENUE N
# (31.532975, -97.437499)
#
# S MERRION AVE
# (41.7163154, -87.569825)
#
# W PRATT BLVD
# (42.0054657, -87.6658226)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# E 77TH ST
# (36.0529109, -95.8831572)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# N MOODY AVE
# (27.9453048, -82.484032)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S EVANS AVE
# (35.509722, -97.9558699)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# W POTOMAC AVE
# (43.0958445, -88.0105462)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# S TROY ST
# (42.4897468, -83.1419423)
#
# N MOODY AVE
# (27.9453048, -82.484032)
#
# E HYDE PARK BLVD
# (41.8024947, -87.5867897)
#
# N CICERO AVE
# (42.0121975, -87.7479383)
#
# S COTTAGE GROVE AVE
# (41.6856412, -87.6114137)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# W SUMMERDALE AVE
# (41.9789237, -87.6696222)
#
# N LATROBE AVE
# (41.9852199, -87.7604579)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# N BROADWAY
# (40.9696948, -73.8844801)
#
# W IRVING PARK RD
# (41.9536094, -87.7322066)
#
# S HYDE PARK BLVD
# (41.7978073, -87.5840054)
#
# E ST
# (50.4738724, 4.2358174)
#
# S FAIRFIELD AVE
# (41.8828928, -88.0058916)
#
# S DESPLAINES ST
# (41.5186497, -88.0855583)
#
# W WALNUT ST
# (31.8085297, -97.0935238)
#
# N BOSWORTH AVE
# (41.9106545, -87.6665138)
#
# N DESPLAINES ST
# (41.8890494, -87.6443381)
#
# S WELLS ST
# (38.0067095, -89.2477996)
#
# N STATE ST
# (44.619052, -75.408869)
#
# W FARWELL AVE
# (42.0067765, -87.6605207)
#
# S ST LAWRENCE AVE
# (41.7682281, -87.6104913)
#
# W MONTROSE AVE
# (41.9607197, -87.7466474)
#
# S UNION AVE
# (47.2491253, -122.4836389)
#
# E OHIO ST
# (40.601786, -84.084445)
#
# S PAXTON AVE
# (41.7316571, -87.5707162)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# N KEDZIE AVE
# (41.981245, -87.7088348)
#
# N MAPLEWOOD AVE
# (36.1771957, -95.9078851)
#
# S RIDGEWAY AVE
# (35.61739, -82.3173401)
#
# W WINNEMAC AVE
# (41.9733819, -87.667451)
#
# S STEWART AVE
# (28.290846, -81.4066339)
#
# S DREXEL AVE
# (33.369843, -111.623825)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# S CAMPBELL AVE
# (37.1712552, -93.2953919)
#
# W WEST END AVE
# (41.8840066, -87.7595529)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# W MAYPOLE AVE
# (41.8835952, -87.7087902)
#
# S CLYDE AVE
# (28.2911755, -81.4131903)
#
# S CAMPBELL AVE
# (37.1712552, -93.2953919)
#
# S MAPLEWOOD AVE
# (36.0250954, -95.9064784)
#
# S ELIZABETH ST
# (40.727094, -84.106756)
#
# E 50TH ST
# (40.7584119, -73.9769016)
#
# N MEADE AVE
# (38.8379256, -104.7960056)
#
# W WASHBURNE AVE
# (41.8661181, -87.6581942)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# E 33RD PL
# (41.557712, -87.296391)
#
# W CARMEN AVE
# (41.9736044, -87.7374367)
#
# S DOBSON AVE
# (41.764125, -87.5994316)
#
# W RASCHER AVE
# (41.9804019, -87.6966348)
#
# N RUTHERFORD AVE
# (40.706973, -73.468891)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# S PAULINA ST
# (41.878849, -87.6692204)
#
# S HOUSTON AVE
# (29.7104805, -98.1173779)
#
# W GOETHE ST
# (41.9057582, -87.6331726)
#
# S WINCHESTER AVE
# (46.406387, -105.830479)
#
# S FAIRFIELD AVE
# (41.8828928, -88.0058916)
#
# S WENTWORTH AVE
# (42.9981308, -87.8894434)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# S PHILLIPS AVE
# (43.513078, -96.7262166)
#
# E PL
# (14.8370417, -89.14104361631954)
#
# N HUMBOLDT BLVD
# (43.0638817, -87.8978425)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# W DIVERSEY PKWY
# (41.9322809, -87.6779319)
#
# W GARFIELD BLVD
# (41.7944433, -87.6378706)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# E 53RD ST
# (40.7580248, -73.9701634)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# N MAPLEWOOD AVE
# (36.1771957, -95.9078851)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# W 65TH ST
# (34.690303, -92.3334514)
#
# W EDGEWATER AVE
# (41.9859428, -87.6699435)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# N BELL AVE
# (32.2464153, -110.8940884)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# W ROOT ST
# (41.8190508, -87.6360402)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# N ELSTON AVE
# (41.9624991, -87.731967)
#
# W 55TH ST
# (40.7692044, -73.9927944)
#
# W GETTYSBURG ST
# (43.58047, -116.191094)
#
# W TAYLOR ST
# (41.3837633, -75.7166377)
#
# N MALDEN ST
# (41.9687299, -87.6628804)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# S EBERHART AVE
# (43.822127, -84.748397)
#
# W CULLOM AVE
# (41.9590228, -87.7389563)
#
# W 47TH ST
# (40.7580163, -73.9817975)
#
# S HALSTED ST
# (41.5420844, -87.6359687)
#
# N SOUTHPORT AVE
# (41.9288439, -87.6634384)
#
# W 63RD PL
# (25.8801129, -80.3380563)
#
# S TALMAN AVE
# (41.8617849, -87.692024)
#
# N LARAMIE AVE
# (41.8954167, -87.7556069)
#
# N ASHLAND BLVD
# (42.0066203, -87.6699972)
#
# S KOMENSKY AVE
# (41.7242244, -87.7231031)
#
# S CLAREMONT AVE
# (39.096728, -94.442776)
#
# N PAULINA ST
# (41.9902949, -87.6714344)
#
# N MOZART ST
# (41.963078, -87.699749)
#
# N LARRABEE ST
# (41.8987673, -87.643014)
#
# S CAMPBELL AVE
# (37.1712552, -93.2953919)
#
# S LEAVITT ST
# (41.8737714, -87.6813292)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# W IOWA ST
# (43.0518372, -91.3949007)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# E 59TH ST
# (40.7639662, -73.9722705)
#
# W WOLFRAM ST
# (41.9335036, -87.6563169)
#
# N MONTICELLO AVE
# (41.9751716, -87.7196691)
#
# S JEFFERY BLVD
# (41.7479785, -87.5759176)
#
# S SACRAMENTO AVE
# (39.3373525, -74.4801189)
#
# W SHERIDAN RD
# (42.490117, -79.250962)
#
# W 79TH PL
# (25.8947274, -80.2894612)
#
# W ALTGELD ST
# (41.9262007, -87.8075454)
#
# S KENWOOD AVE
# (41.8060326, -87.5935411)
#
# N RAVENSWOOD AVE
# (41.9688187, -87.6741627)
#
# S EXCHANGE AVE
# (35.0704184, -92.4212449)
#
# S DRAKE AVE
# (41.8498569, -87.713702)
#
# S ST LOUIS AVE
# (41.0219002, -87.7208064)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# W 84TH PL
# (41.4643866, -87.3478885)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# S CENTRAL PARK AVE
# (41.7169517, -87.7114806)
#
# N PULASKI RD
# (41.9640877, -87.7278964)
#
# S MARYLAND AVE
# (39.5941256, -75.9378606)
#
# N ASHLAND BLVD
# (42.0066203, -87.6699972)
#
# W 35TH PL
# (39.818328, -86.271661)
#
# W NEWPORT AVE
# (42.681683, -83.313192)
#
# N WALLER AVE
# (41.8910824, -87.7677998)
#
# W MONTANA ST
# (45.6644428, -110.568881)
#
# N ASHLAND BLVD
# (42.0066203, -87.6699972)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# W LEXINGTON ST
# (39.0325997, -97.5948929)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# W WALNUT ST
# (31.8085297, -97.0935238)
#
# E 71ST ST
# (41.5110354, -81.6395881)
#
# W POLK ST
# (30.7116929, -94.9383233)
#
# S FARRELL ST
# (41.8406963, -87.6529906)
#
# W Chestnut St
# (40.0400916, -76.3165126)
#
# S CAMPBELL AVE
# (37.1712552, -93.2953919)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# S EDBROOKE AVE
# (41.6980924, -87.6196287)
#
# W GRENSHAW ST
# (41.8679092, -87.6630252)
#
# N WESTERN AVE
# (35.5293143, -97.5298153)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# S MOODY AVE
# (27.9372334, -82.4840243)
#
# W ROSCOE ST
# (41.9417774, -87.798255)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# N LA SALLE DR
# (32.459967, -99.781336)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# W 66TH PL
# (25.883077, -80.317394)
#
# N CENTRAL AVE
# (35.7718102, -91.6557941)
#
# W AINSLIE ST
# (41.9701978, -87.7164722)
#
# S ST LAWRENCE AVE
# (41.7682281, -87.6104913)
#
# N CENTRAL AVE
# (35.7718102, -91.6557941)
#
# S INGLESIDE AVE
# (41.7403543, -87.601287)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# S DOTY AVE E
# (41.6512027, -87.5806882)
#
# N OLCOTT AVE
# (41.9414041, -87.8141994)
#
# W BALMORAL AVE
# (41.9798396, -87.6688623)
#
# E CHESTNUT ST
# (40.0418024, -76.2998169)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# S CICERO AVE
# (41.8545413, -87.7443874)
#
# W MAXWELL ST
# (41.078907, -100.5275514)
#
# N KILPATRICK AVE
# (41.9699316, -87.74405)
#
# N LUNA AVE
# (34.454345, -119.281645)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# E 84TH PL
# (41.4637197, -87.3359496)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# N SHEFFIELD AVE
# (43.1085525, -87.8984732)
#
# S WOOD ST
# (41.343196, -83.119849)
#
# N NORA AVE
# (34.0813562, -117.9385738)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# N MENARD AVE
# (41.8914776, -87.7700234)
#
# S CANAL ST
# (42.1979758, -72.6021589)
#
# N kingsbury st
# (41.8986511, -87.6438839)
#
# S RACINE AVE
# (42.9427005, -88.1582854)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W 83RD ST
# (41.7432634, -87.6499076)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# E 32ND ST
# (44.94472, -93.2368469)
#
# E 47TH ST
# (40.7546125, -73.9737345)
#
# S ST LOUIS AVE
# (41.0219002, -87.7208064)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# S CANAL ST
# (42.1979758, -72.6021589)
#
# W HOWARD ST
# (43.4469912, -92.2854434)
#
# E CERMAK RD
# (41.8529064, -87.6261499)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# N ALBANY AVE
# (40.7076835, -73.465108)
#
# E 60TH ST
# (44.8942722, -93.2746348)
#
# W 63RD ST
# (41.7733805, -87.9889844)
#
# S TRUMBULL AVE
# (41.666268, -87.7067038)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# N WABASH AVE
# (41.1450949, -87.8658414)
#
# S MARSHFIELD AVE
# (41.8093553, -87.6662057)
#
# N KEDZIE BLVD
# (41.9245939, -87.7072256)
#
# N MAYFIELD AVE
# (34.1105096, -117.2902727)
#
# W BYRON ST
# (41.9503382, -87.7955338)
#
# S HERMITAGE AVE
# (41.7685166, -87.6675589)
#
# N CUMBERLAND AVE
# (28.5746976, -81.5453944)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# N MENARD AVE
# (41.8914776, -87.7700234)
#
# W ARMITAGE AVE
# (43.1023086, -87.9910021)
#
# S ARCHER AVE
# (41.6335223, -88.0133585)
#
# S DEARBORN ST
# (47.5957569, -122.3197611)
#
# S CANAL ST
# (42.1979758, -72.6021589)
#
# W 50TH ST
# (40.7591258, -73.978595)
#
# S LOOMIS BLVD
# (41.7570599, -87.6587609)
#
# N LA CROSSE AVE
# (38.2701926, -104.5890357)
#
# S VINCENNES AVE
# (41.6979977, -87.6592612)
#
# S SAGINAW AVE
# (41.6427026, -87.5580689)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W GUNNISON ST
# (41.969023, -87.7398109)
#
# S ELIZABETH ST
# (40.727094, -84.106756)
#
# N TRUMBULL AVE
# (45.5965005, -122.7536356)
#
# W 92ND ST
# (38.9630308, -94.6160841)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# S VINCENNES AVE
# (41.6979977, -87.6592612)
#
# N LONG AVE
# (31.872625, -102.526908)
#
# W ST
# (55.8497133, -4.2656724)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# E 53RD ST
# (40.7580248, -73.9701634)
#
# W RANDOLPH ST
# (36.2743344, -90.9816148)
#
# N LINCOLN AVE
# (45.660956, -122.6824777)
#
# N LEAVITT ST
# (39.531967, -87.136931)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# S LARAMIE AVE
# (41.8447325, -87.753967)
#
# S PHILLIPS AVE
# (43.513078, -96.7262166)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# N SPRINGFIELD AVE
# (41.9646307, -87.7254887)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# S KEDVALE AVE
# (41.6474182, -87.7222793)
#
# S KEATING AVE
# (33.3664683, -111.8640276)
#
# W IRVING PARK RD
# (41.9536094, -87.7322066)
#
# W PENSACOLA AVE
# (41.9604024, -87.6892707)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# W GRAND AVE
# (44.89992, -89.6139466)
#
# W CORNELIA AVE
# (33.9618136, -98.6777071)
#
# E 69TH PL
# (41.4913223, -87.3304402)
#
# S SAGINAW AVE
# (41.6427026, -87.5580689)
#
# E 71ST ST
# (41.5110354, -81.6395881)
#
# N LAWNDALE AVE
# (41.9592196, -87.720432)
#
# S DREXEL AVE
# (33.369843, -111.623825)
#
# S DEARBORN ST
# (47.5957569, -122.3197611)
#
# S GILES AVE
# (41.8310918, -87.6193367)
#
# W 31ST ST
# (44.9466054, -93.2862078)
#
# W BARRY AVE
# (36.8175627, -93.9243727)
#
# S THROOP ST
# (41.7467867, -87.6560654)
#
# S SAWYER AVE
# (47.2288772, -122.4540806)
#
# N TALMAN AVE
# (41.9139404, -87.6934262)
#
# W FULLERTON PKWY
# (41.9256195, -87.6390215)
#
# S VERNON AVE
# (32.72251, -96.836774)
#
# W CONGRESS PKWY
# (41.8750866, -87.6539866)
#
# W GRACE ST
# (37.5509972, -77.4531109)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# S HOYNE AVE
# (41.8228899, -87.6774807)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# S FEDERAL ST
# (38.443357, -78.870308)
#
# S HALSTED ST
# (41.5420844, -87.6359687)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# S HALE AVE
# (27.9444192, -82.5109327)
#
# N ARTESIAN AVE
# (41.9254283, -87.6888852)
#
# S KILDARE AVE
# (41.6744106, -87.7275156)
#
# S RICHMOND ST
# (44.8899249, -88.3024977)
#
# N MEADE AVE
# (38.8379256, -104.7960056)
#
# S BLACKSTONE AVE
# (41.78726, -87.881703)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# W MEDILL AVE
# (41.9211428, -87.8794266)
#
# S WASHTENAW AVE
# (41.8244476, -87.6922106)
#
# W VERMONT ST
# (39.772338, -86.257635)
#
# S HAMILTON AVE
# (29.4083447, -98.5341118)
#
# W 31ST ST
# (44.9466054, -93.2862078)
#
# S HAMILTON AVE
# (29.4083447, -98.5341118)
#
# N PARKSIDE AVE
# (34.082432, -117.6296776)
#
# W POTOMAC AVE
# (43.0958445, -88.0105462)
#
# S FORRESTVILLE AVE
# (41.6913991, -87.6091965)
#
# W gladys ave
# (41.915226, -87.959294)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# S TRIPP AVE
# (41.663533, -87.72595)
#
# S DANTE AVE
# (41.5394098, -87.5855724)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# S WENTWORTH AVE
# (42.9981308, -87.8894434)
#
# E 51ST ST
# (40.754497, -73.9656924)
#
# N DEARBORN PKWY
# (41.9077182, -87.630106)
#
# S NORMAL AVE
# (37.720105, -89.21769)
#
# E 76TH ST
# (39.704568, -74.135229)
#
# N MELVINA AVE
# (42.0121329, -87.7817803)
#
# S EGGLESTON AVE
# (35.407396, -97.5137083)
#
# S TROY ST
# (42.4897468, -83.1419423)
#
# N PARKSIDE AVE
# (34.082432, -117.6296776)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# S EVANS AVE
# (35.509722, -97.9558699)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# N HAZEL ST
# (40.166712, -76.395635)
#
# E ILLINOIS ST
# (41.862286, -88.09637)
#
# E 41ST ST
# (44.928696, -93.2276561)
#
# S BLUE ISLAND AVE
# (41.8541923, -87.6641634)
#
# S FAIRFIELD AVE
# (41.8828928, -88.0058916)
#
# S KEDZIE AVE
# (41.7315967, -87.7021544)
#
# N WINNEBAGO AVE
# (41.9143693, -87.6852148)
#
# W TAYLOR ST
# (41.3837633, -75.7166377)
#
# N BESSIE COLEMAN DR
# (37.7186984, -122.2033434)
#
# S WENTWORTH AVE
# (42.9981308, -87.8894434)
#
# N AVERS AVE
# (41.9628652, -87.724203)
#
# S WENTWORTH AVE
# (42.9981308, -87.8894434)
#
# W WINNEMAC AVE
# (41.9733819, -87.667451)
#
# S MERRILL AVE
# (47.1026257, -104.715102)
#
# W MELROSE ST
# (40.667262, -73.698695)
#
# S DEARBORN ST
# (47.5957569, -122.3197611)
#
# N SEDGWICK ST
# (37.693255, -97.36976)
#
# S WOLCOTT AVE
# (41.8741687, -87.6740297)
#
# W DIVISION ST
# (38.2597099, -87.9979169)
#
# N RACINE AVE
# (43.003319, -88.216859)
#
# E 80TH ST
# (39.706875, -74.132378)
#
# W CONGRESS PKWY
# (41.8750866, -87.6539866)
#
# S ARCHER AVE
# (41.6335223, -88.0133585)
#
# S MAY ST
# (35.5997263, -77.5918349)
#
# N LA SALLE DR
# (32.459967, -99.781336)
#
# S SAWYER AVE
# (47.2288772, -122.4540806)
#
# E 81ST ST
# (41.4803912, -81.6310758)
#
# N CENTRAL AVE
# (35.7718102, -91.6557941)
#
# W CRYSTAL ST
# (28.899691, -82.574754)
#
# S DRAKE AVE
# (41.8498569, -87.713702)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# S KINGSTON AVE
# (36.044406, -95.9074742)
#
# E ST
# (50.4738724, 4.2358174)
#
# N LINCOLN AVE
# (45.660956, -122.6824777)
#
# S HARVARD AVE
# (40.613458, -98.098577)
#
# S WENTWORTH AVE
# (42.9981308, -87.8894434)
#
# S EWING AVE
# (32.7424571, -96.8126924)
#
# S SPAULDING AVE
# (34.0288086, -118.3700242)
#
# N LAWLER AVE
# (41.9186896, -87.7523027)
#
# N SANDBURG TER
# (41.9110839, -87.6324747)
#
# S SOUTH SHORE DR
# (41.7687175, -87.5665152)
#
# W ST
# (55.8497133, -4.2656724)
#
# N KIMBALL AVE
# (32.948407, -97.1167804)
#
# N FRANKLIN ST
# (43.053353, -76.154839)
#
# W 75TH ST
# (44.8673118, -93.306107)
#
# S ADA ST
# (44.9307182, -93.0759931)
#
# S KOLIN AVE
# (41.6804633, -87.7282162)
#
# S CENTRAL PARK AVE
# (41.7169517, -87.7114806)
#
# S CALIFORNIA AVE
# (34.1163848, -118.0008539)
#
# W WILCOX ST
# (39.7729655, -86.2196271)
#
# W PATTERSON AVE
# (35.847964, -79.574575)
#
# S RUTHERFORD AVE
# (41.7189853, -87.78843)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# S KOMENSKY AVE
# (41.7242244, -87.7231031)
#
# S WHIPPLE ST
# (42.6302929, -71.3004363)
#
# S WESTERN AVE
# (43.5185145, -96.751124)
#
# S CENTRAL PARK AVE
# (41.7169517, -87.7114806)
#
# S KOSTNER AVE
# (41.6651721, -87.7289951)
#
# S AVENUE N
# (31.532975, -97.437499)
#
# W GRACE ST
# (37.5509972, -77.4531109)
#
# W CORNELIA AVE
# (33.9618136, -98.6777071)
#
# N LECLAIRE AVE
# (41.935091, -87.7540962)
#
# W 74TH ST
# (40.780251, -73.9814398)
#
# N KILDARE AVE
# (41.9718061, -87.7355466)
#
# W 19TH ST
# (41.452886, -82.190809)
#
# N AUSTIN AVE
# (41.912831, -87.7753338)
#
# S HALSTED ST
# (41.5420844, -87.6359687)
#
# E 40TH ST
# (44.9305097, -93.2276849)
#
# S INDEPENDENCE BLVD
# (36.8059, -76.116529)
#
# S JUSTINE ST
# (41.6714397, -87.6599691)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# N HOYNE AVE
# (41.9550717, -87.6812061)
#
# E 90TH ST
# (39.9181982, -86.0387202)
#
# W WELLINGTON AVE
# (38.1838186, -85.7649883)
#
# S MARYLAND AVE
# (39.5941256, -75.9378606)
#
# N CENTRAL AVE
# (35.7718102, -91.6557941)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# W LEXINGTON ST
# (39.0325997, -97.5948929)
#
# S INDEPENDENCE BLVD
# (36.8059, -76.116529)
#
# N MOODY AVE
# (27.9453048, -82.484032)
#
# W LEXINGTON ST
# (39.0325997, -97.5948929)
#
# N CICERO AVE
# (42.0121975, -87.7479383)
#
# N MOZART ST
# (41.963078, -87.699749)
#
# S MARQUETTE AVE
# (41.6317592, -87.5567079)
#
# E 79TH ST
# (40.7742888, -73.9572899)
#
# S MAY ST
# (35.5997263, -77.5918349)
#
# N CLIFTON AVE
# (37.2360894, -93.3271958)
#
# E ST
# (50.4738724, 4.2358174)
#
# N MONTICELLO AVE
# (41.9751716, -87.7196691)
#
# W HARRISON ST
# (47.453523, -116.785825)
#
# W 97TH ST
# (44.828127, -93.2981407)
#
# S SANGAMON ST
# (39.5902655, -89.7359101)
#
# E 95TH ST
# (40.7835163, -73.9474639)
#
# S PERRY AVE
# (27.74589, -81.794657)
#
# W MEDILL AVE
# (41.9211428, -87.8794266)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S WOODLAWN AVE
# (41.7812374, -87.5962214)
#
# S ST LAWRENCE AVE
# (41.7682281, -87.6104913)
#
# N KENNETH AVE
# (41.9717719, -87.7392712)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# W 66TH ST
# (40.7733596, -73.9809918)
#
# S ELLIS AVE
# (35.309552, -78.616879)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# S ARTESIAN AVE
# (34.0977413, -117.3182866)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# S CHAMPLAIN AVE
# (32.1827548, -110.8194486)
#
# E Ohio St
# (40.601786, -84.084445)
#
# N MARMORA AVE
# (41.9567321, -87.7744508)
#
# N PULASKI RD
# (41.9640877, -87.7278964)
#
# W ADDISON ST
# (42.226415, -84.406033)
#
# W 51ST ST
# (40.7597316, -73.9780866)
#
# S MERRILL AVE
# (47.1026257, -104.715102)
#
# W MONTANA ST
# (45.6644428, -110.568881)
#
# N HUDSON AVE
# (37.691596, -83.95988)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# S INDEPENDENCE BLVD
# (36.8059, -76.116529)
#
# N LONG AVE
# (31.872625, -102.526908)
#
# N MANGO AVE
# (41.9608929, -87.7709224)
#
# N LINCOLN AVE
# (45.660956, -122.6824777)
#
# S CENTRAL AVE
# (40.8950402, -74.0839635)
#
# W 43RD ST
# (44.9250102, -93.2909497)
#
# S HONORE ST
# (41.8267808, -87.6715176)
#
# W CONCORD PL
# (40.3981522, -111.9271298)
#
# E 76TH ST
# (39.704568, -74.135229)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# W DIVISION ST
# (38.2597099, -87.9979169)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# N KIMBALL AVE
# (32.948407, -97.1167804)
#
# S PEORIA ST
# (39.5974063, -104.8480467)
#
# N WABASH AVE
# (41.1450949, -87.8658414)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# N KEDVALE AVE
# (41.9640717, -87.7315451)
#
# S CORNELL AVE
# (42.119526, -87.95127)
#
# S CORNELL AVE
# (42.119526, -87.95127)
#
# W POTOMAC AVE
# (43.0958445, -88.0105462)
#
# W OAKDALE AVE
# (29.0407755, -81.3169917)
#
# W HUBBARD ST
# (41.7159012, -89.3389805)
#
# S CRANDON AVE
# (41.7625938, -87.5688755)
#
# N SAYRE AVE
# (41.9628625, -87.8025486)
#
# S HAMILTON AVE
# (29.4083447, -98.5341118)
#
# W 87TH ST
# (38.970993, -94.7161832)
#
# S HOMAN AVE
# (41.6622485, -87.7046222)
#
# S PAULINA ST
# (41.878849, -87.6692204)
#
# N SPAULDING AVE
# (41.9543894, -87.7104772)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# S KINGSTON AVE
# (36.044406, -95.9074742)
#
# W DEVON AVE
# (41.9973572, -87.7114381)
#
# N KILBOURN AVE
# (41.9717611, -87.7405534)
#
# S COLES AVE
# (41.7483376, -87.5491898)
#
# S LAKE PARK AVE
# (41.5348577, -87.2596604)
#
# N GREENVIEW AVE
# (42.2840502, -89.1311541)
#
# S SOUTH SHORE DR
# (41.7687175, -87.5665152)
#
# S LOOMIS ST
# (41.769112, -88.14147)
#
# S MAY ST
# (35.5997263, -77.5918349)
#
# S AVERS AVE
# (41.6734757, -87.7157121)
#
# S JUSTINE ST
# (41.6714397, -87.6599691)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# W WARREN BLVD
# (41.8823807, -87.6651175)
#
# W ROOSEVELT RD
# (41.8568563, -88.1736282)
#
# N MARINE DR
# (33.8164549, -117.8300018)
#
# W AUGUSTA BLVD
# (41.4210887, -87.732417)
#
# E 50TH PL
# (39.845682, -86.057732)
#
# S HONORE ST
# (41.8267808, -87.6715176)
#
# E 92ND ST
# (40.636327, -73.898929)
#
# S EAST END AVE
# (40.7774069, -73.943042)
#
# W SHERWIN AVE
# (42.0150507, -87.7786003)
#
# S KINGSTON AVE
# (36.044406, -95.9074742)
#
# N RACINE AVE
# (43.003319, -88.216859)
#
# S KILDARE AVE
# (41.6744106, -87.7275156)
#
# N LECLAIRE AVE
# (41.935091, -87.7540962)
#
# W JUNIOR TER
# (41.9603724, -87.6498768)
#
# W SUNNYSIDE AVE
# (41.9635312, -87.6603099)
#
# W POTOMAC AVE
# (43.0958445, -88.0105462)
#
# S KEDVALE AVE
# (41.6474182, -87.7222793)
#
# S ARCHER AVE
# (41.6335223, -88.0133585)
#
# W WINNEMAC AVE
# (41.9733819, -87.667451)
#
# W CHESTNUT ST
# (40.0400916, -76.3165126)
#
# E ST
# (50.4738724, 4.2358174)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# S COLES AVE
# (41.7483376, -87.5491898)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# W DIVERSEY AVE
# (41.9263942, -88.0053438)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# S CHARLES ST
# (39.4041707, -88.8020472)
#
# N RICHMOND ST
# (41.9557758, -87.7019847)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# N RIDGEWAY AVE
# (41.9954911, -87.7227208)
#
# E 50TH ST
# (40.7584119, -73.9769016)
#
# W FLOURNOY ST
# (28.406267, -97.7593919)
#
# S COTTAGE GROVE AVE
# (41.6856412, -87.6114137)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# S LAKE PARK AVE
# (41.5348577, -87.2596604)
#
# W MAYPOLE AVE
# (41.8835952, -87.7087902)
#
# S CRANDON AVE
# (41.7625938, -87.5688755)
#
# S FAIRFIELD AVE
# (41.8828928, -88.0058916)
#
# S KILBOURN AVE
# (41.8591487, -87.737185)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# E 69TH PL
# (41.4913223, -87.3304402)
#
# S WOOD ST
# (41.343196, -83.119849)
#
# S LAKE PARK AVE
# (41.5348577, -87.2596604)
#
# S ELLIS AVE
# (35.309552, -78.616879)
#
# S LAFAYETTE AVE
# (39.334709, -74.489355)
#
# N WALLER AVE
# (41.8910824, -87.7677998)
#
# S OAKENWALD AVE
# (41.8176178, -87.5980256)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# W 64TH ST
# (39.0130173, -94.802986)
#
# S WALLACE ST
# (38.6625346, -87.3019057)
#
# W SUNNYSIDE AVE
# (41.9635312, -87.6603099)
#
# W 78TH PL
# (41.4755863, -87.3774798)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# N KEATING AVE
# (41.9746791, -87.7467834)
#
# N Lamon Ave
# (41.9242164, -87.7487482)
#
# S SAWYER AVE
# (47.2288772, -122.4540806)
#
# W JARVIS AVE
# (42.0153543, -87.8050829)
#
# W PL
# (39.0445999, -94.6029041)
#
# S EBERHART AVE
# (43.822127, -84.748397)
#
# S PEORIA ST
# (39.5974063, -104.8480467)
#
# S HALSTED ST
# (41.5420844, -87.6359687)
#
# S DORCHESTER AVE
# (41.861114, -88.126156)
#
# N WESTERN AVE
# (35.5293143, -97.5298153)
#
# N KEDZIE AVE
# (41.981245, -87.7088348)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# N NEWCASTLE AVE
# (41.9223699, -87.7970239)
#
# N WALLER AVE
# (41.8910824, -87.7677998)
#
# S SPRINGFIELD AVE
# (40.6858039, -74.3274558)
#
# W WALTON ST
# (33.089508, -83.237513)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# S HALE AVE
# (27.9444192, -82.5109327)
#
# W FLETCHER ST
# (28.324413, -81.40576)
#
# E 68TH ST
# (36.064123, -95.9448098)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# N KEYSTONE AVE
# (42.0001236, -76.5351751)
#
# S COTTAGE GROVE AVE
# (41.6856412, -87.6114137)
#
# N SACRAMENTO BLVD
# (41.889664, -87.7013745)
#
# S WASHTENAW AVE
# (41.8244476, -87.6922106)
#
# W ADDISON ST
# (42.226415, -84.406033)
#
# W WAVELAND AVE
# (41.9466715, -87.8113037)
#
# W CONCORD PL
# (40.3981522, -111.9271298)
#
# W BIRCHWOOD AVE
# (42.9399265, -87.9627232)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S MAPLEWOOD AVE
# (36.0250954, -95.9064784)
#
# N LINCOLN AVE
# (45.660956, -122.6824777)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# N WASHTENAW AVE
# (41.9253795, -87.6949927)
#
# W COYLE AVE
# (42.0076556, -87.6949713)
#
# S CLYDE AVE
# (28.2911755, -81.4131903)
#
# W 51ST ST
# (40.7597316, -73.9780866)
#
# S EAST END AVE
# (40.7774069, -73.943042)
#
# S BENNETT AVE
# (39.047033, -82.645968)
#
# N MC VICKER AVE
# (41.7720642, -87.7721541)
#
# W KINZIE ST
# (41.8891372, -87.6357356)
#
# S GREENWOOD AVE
# (37.6199047, -96.228166)
#
# N KEDZIE AVE
# (41.981245, -87.7088348)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# S DORCHESTER AVE
# (41.861114, -88.126156)
#
# N LYNCH AVE
# (35.2230001, -111.5864205)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# W 19TH ST
# (41.452886, -82.190809)
#
# E 57TH ST
# (40.7629694, -73.9739676)
#
# S LAWNDALE AVE
# (41.8425259, -87.7171839)
#
# S INDEPENDENCE BLVD
# (36.8059, -76.116529)
#
# W SUMMERDALE AVE
# (41.9789237, -87.6696222)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# S CORNELL AVE
# (42.119526, -87.95127)
#
# S TORRENCE AVE
# (41.6397957, -87.5592843)
#
# N KEATING AVE
# (41.9746791, -87.7467834)
#
# S BELL AVE
# (36.6728853, -120.1423994)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W FLETCHER ST
# (28.324413, -81.40576)
#
# N WACKER DR
# (40.759348, -89.6577155)
#
# W 26TH ST
# (41.8444628, -87.7092909)
#
# S EVANS AVE
# (35.509722, -97.9558699)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# W ST
# (55.8497133, -4.2656724)
#
# S PLEASANT AVE
# (40.9629751, -74.1033557)
#
# S VERNON AVE
# (32.72251, -96.836774)
#
# S SPAULDING AVE
# (34.0288086, -118.3700242)
#
# W 22nd PL
# (30.188365, -85.710205)
#
# W MAYPOLE AVE
# (41.8835952, -87.7087902)
#
# W ADDISON ST
# (42.226415, -84.406033)
#
# S MAY ST
# (35.5997263, -77.5918349)
#
# N Sheridan Rd
# (40.3578419, -76.2273206)
#
# S ESSEX AVE
# (39.3133874, -76.4565138)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# E GARFIELD BLVD
# (41.794447, -87.6149514)
#
# W 28TH ST
# (44.9524575, -93.3005243)
#
# W BARRY AVE
# (36.8175627, -93.9243727)
#
# S AVENUE C
# (38.7785529, -97.6063)
#
# N SAWYER AVE
# (41.9610885, -87.7094607)
#
# E ST
# (50.4738724, 4.2358174)
#
# S CHAPPEL AVE
# (41.7588966, -87.5749062)
#
# S CHAMPLAIN AVE
# (32.1827548, -110.8194486)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# W KINZIE ST
# (41.8891372, -87.6357356)
#
# S MAY ST
# (35.5997263, -77.5918349)
#
# S THROOP ST
# (41.7467867, -87.6560654)
#
# W DIVERSEY AVE
# (41.9263942, -88.0053438)
#
# S EWING AVE
# (32.7424571, -96.8126924)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# W 94TH PL
# (41.4469275, -87.3368917)
#
# N LEAMINGTON AVE
# (41.8986064, -87.7544655)
#
# N WASHTENAW AVE
# (41.9253795, -87.6949927)
#
# N STATE ST
# (44.619052, -75.408869)
#
# W FERDINAND ST
# (42.4723744, -71.076355)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# S UNION AVE
# (47.2491253, -122.4836389)
#
# W BEVERLY GLEN PKWY
# (41.7129081, -87.6630153)
#
# W GUNNISON ST
# (41.969023, -87.7398109)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# N GLENWOOD AVE
# (42.650887, -83.284998)
#
# S EAST END AVE
# (40.7774069, -73.943042)
#
# S BAKER AVE
# (34.0434437, -117.6153537)
#
# W AGATITE AVE
# (41.9619564, -87.7205109)
#
# W CONGRESS PKWY
# (41.8750866, -87.6539866)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# W EDDY ST
# (33.6448338, -97.3810902)
#
# S STONY ISLAND AVE
# (41.772423, -87.5862745)
#
# S KILBOURN AVE
# (41.8591487, -87.737185)
#
# W POLK ST
# (30.7116929, -94.9383233)
#
# W NELSON ST
# (39.937473, -94.841012)
#
# S CARONDOLET AVE
# (41.6687429, -87.5495644)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# N LARAMIE AVE
# (41.8954167, -87.7556069)
#
# S Michigan Ave
# (42.59934, -83.9336293)
#
# W HARRISON ST
# (47.453523, -116.785825)
#
# N PULASKI RD
# (41.9640877, -87.7278964)
#
# W WEBSTER AVE
# (42.4488715, -83.1273708)
#
# W DIVISION ST
# (38.2597099, -87.9979169)
#
# W 47TH ST
# (40.7580163, -73.9817975)
#
# S EMERALD AVE
# (33.3965996, -111.8035831)
#
# S ALBANY AVE
# (27.932852, -82.480986)
#
# N SAWYER AVE
# (41.9610885, -87.7094607)
#
# S KINGSTON AVE
# (36.044406, -95.9074742)
#
# W MARQUETTE RD
# (41.7726852, -87.6253898)
#
# W KAMERLING AVE
# (41.9048703, -87.7639163)
#
# W BALMORAL AVE
# (41.9798396, -87.6688623)
#
# S TROY ST
# (42.4897468, -83.1419423)
#
# E OHIO ST
# (40.601786, -84.084445)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# E ST
# (50.4738724, 4.2358174)
#
# S PAULINA ST
# (41.878849, -87.6692204)
#
# N FRANCISCO AVE
# (26.2217801, -98.3199932)
#
# E OAKWOOD BLVD
# (41.8241108, -87.6043228)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# N ARTESIAN AVE
# (41.9254283, -87.6888852)
#
# W 13TH PL
# (32.8861934, -111.7616046)
#
# N FRANCISCO AVE
# (26.2217801, -98.3199932)
#
# S MARSHFIELD AVE
# (41.8093553, -87.6662057)
#
# S PULASKI RD
# (41.6803208, -87.7198931)
#
# W DOUGLAS BLVD
# (41.8629927, -87.7029508)
#
# S WELLS ST
# (38.0067095, -89.2477996)
#
# S HOMAN AVE
# (41.6622485, -87.7046222)
#
# S TRUMBULL AVE
# (41.666268, -87.7067038)
#
# S DANTE AVE
# (41.5394098, -87.5855724)
#
# S MARSHFIELD AVE
# (41.8093553, -87.6662057)
#
# S INGLESIDE AVE
# (41.7403543, -87.601287)
#
# W 21ST ST
# (44.961758, -93.306244)
#
# N RIDGE BLVD
# (38.5054097, -77.9726234)
#
# S LAWNDALE AVE
# (41.8425259, -87.7171839)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# W DIVISION ST
# (38.2597099, -87.9979169)
#
# S FAIRFIELD AVE
# (41.8828928, -88.0058916)
#
# W GRACE ST
# (37.5509972, -77.4531109)
#
# N PULASKI RD
# (41.9640877, -87.7278964)
#
# S HOMAN AVE
# (41.6622485, -87.7046222)
#
# N SACRAMENTO AVE
# (39.341244, -74.483242)
#
# E 51ST ST
# (40.754497, -73.9656924)
#
# W LUNT AVE
# (42.0077782, -87.8200486)
#
# S MARSHALL BLVD
# (41.8527744, -87.6991201)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# W CATALPA AVE
# (41.9812028, -87.7124733)
#
# N NAGLE AVE
# (41.9200303, -87.7865552)
#
# S CALUMET AVE
# (41.7034033, -86.871671)
#
# W CORTEZ ST
# (33.5897649, -112.4664308)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# W POTOMAC AVE
# (43.0958445, -88.0105462)
#
# S EVANS AVE
# (35.509722, -97.9558699)
#
# N KEDVALE AVE
# (41.9640717, -87.7315451)
#
# N WINCHESTER AVE
# (46.4110364, -105.830487)
#
# W JONQUIL TER
# (42.0211554, -87.6706138)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# S EBERHART AVE
# (43.822127, -84.748397)
#
# S ELLIS AVE
# (35.309552, -78.616879)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# S BLUE ISLAND AVE
# (41.8541923, -87.6641634)
#
# S MASON AVE
# (47.1898123, -122.4941429)
#
# S DORCHESTER AVE
# (41.861114, -88.126156)
#
# N LARAMIE AVE
# (41.8954167, -87.7556069)
#
# S AVENUE M
# (31.773624, -97.579064)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# S ELLIS AVE
# (35.309552, -78.616879)
#
# S SANGAMON ST
# (39.5902655, -89.7359101)
#
# W LUNT AVE
# (42.0077782, -87.8200486)
#
# N LEAMINGTON AVE
# (41.8986064, -87.7544655)
#
# W FULTON ST
# (40.6996535, -90.0114673)
#
# W POTOMAC AVE
# (43.0958445, -88.0105462)
#
# W IOWA ST
# (43.0518372, -91.3949007)
#
# W 47TH PL
# (41.568397, -90.623596)
#
# S WOLCOTT AVE
# (41.8741687, -87.6740297)
#
# N LONG AVE
# ...
#
# S Cicero Ave
# (41.8545413, -87.7443874)
#
# S CANAL ST
# (42.1979758, -72.6021589)
#
# N Elizabeth St
# (38.0310475, -84.5126509)
#
# N WHIPPLE ST
# (41.9721178, -87.7049131)
#
# W POTOMAC AVE
# (43.0958445, -88.0105462)
#
# E 73RD PL
# (36.0577139, -95.9568994)
#
# W CORTLAND ST
# (42.591483, -76.371899)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# W TERMINAL ST
# (38.3711643, -88.065751)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# W HIRSCH ST
# (41.9062185, -87.7313087)
#
# W SCHOOL ST
# (33.3044468, -96.4028596)
#
# N ELSTON AVE
# (41.9624991, -87.731967)
#
# S SAGINAW AVE
# (41.6427026, -87.5580689)
#
# S THROOP ST
# (41.7467867, -87.6560654)
#
# S KARLOV AVE
# (41.7139045, -87.7235728)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# N CITY FRONT PLAZA DR
# (67.2833598, 14.3788028)
#
# N SAWYER AVE
# (41.9610885, -87.7094607)
#
# N CLARENDON AVE
# (39.3347411, -74.4980139)
#
# E 81ST ST
# (41.4803912, -81.6310758)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# N LYNCH AVE
# (35.2230001, -111.5864205)
#
# E 59TH ST
# (40.7639662, -73.9722705)
#
# N ELSTON AVE
# (41.9624991, -87.731967)
#
# S HARDING AVE
# (36.6834759, -119.7343476)
#
# N PARKSIDE AVE
# (34.082432, -117.6296776)
#
# S EBERHART AVE
# (43.822127, -84.748397)
#
# N HARLEM AVE
# (37.093364, -94.529365)
#
# S PULASKI RD
# (41.6803208, -87.7198931)
#
# W 36TH ST
# (41.8823358, -103.6756337)
#
# N ELSTON AVE
# (41.9624991, -87.731967)
#
# N ELSTON AVE
# (41.9624991, -87.731967)
#
# N ELSTON AVE
# (41.9624991, -87.731967)
#
# N ELSTON AVE
# (41.9624991, -87.731967)
#
# E MIDWAY PLAISANCE
# (41.7871183, -87.6065381)
#
# E 67TH ST
# (31.9089805, -102.3842858)
#
# N WAYNE AVE
# (40.055678, -75.393487)
#
# W PIERCE AVE
# (39.485878, -88.185641)
#
# W EASTWOOD AVE
# (41.9656467, -87.7297858)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# N LINCOLN PARK WEST
# (41.9192403, -87.6363854)
#
# S INGLESIDE AVE
# (41.7403543, -87.601287)
#
# N MALDEN ST
# (41.9687299, -87.6628804)
#
# N WINTHROP AVE
# (41.9873032, -87.6581226)
#
# N CITY FRONT PLAZA DR
# (67.2833598, 14.3788028)
#
# N HOYNE AVE
# (41.9550717, -87.6812061)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# N KINGSBURY ST
# (41.8986511, -87.6438839)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# W FLOURNOY ST
# (28.406267, -97.7593919)
#
# W FARWELL AVE
# (42.0067765, -87.6605207)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# W SCHILLER ST
# (41.9078231, -87.6301106)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# W KINZIE ST
# (41.8891372, -87.6357356)
#
# N OAKLEY BLVD
# (41.893065, -87.684323)
#
# N OGDEN AVE
# (41.2832412, -111.9678465)
#
# S RACINE AVE
# (42.9427005, -88.1582854)
#
# N KEYSTONE AVE
# (42.0001236, -76.5351751)
#
# S HARVARD AVE
# (40.613458, -98.098577)
#
# N MANGO AVE
# (41.9608929, -87.7709224)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# W B12 ST
# (25.0519776, 55.1499542)
#
# S GREENWOOD AVE
# (37.6199047, -96.228166)
#
# S ARCHER AVE
# (41.6335223, -88.0133585)
#
# N TALMAN AVE
# (41.9139404, -87.6934262)
#
# S RUTHERFORD AVE
# (41.7189853, -87.78843)
#
# S MAPLEWOOD AVE
# (36.0250954, -95.9064784)
#
# S CRANDON AVE
# (41.7625938, -87.5688755)
#
# N HUMBOLDT BLVD
# (43.0638817, -87.8978425)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# N WINTHROP AVE
# (41.9873032, -87.6581226)
#
# S ALBANY AVE
# (27.932852, -82.480986)
#
# N LOWELL AVE
# (43.051309, -76.184402)
#
# N WICKER PARK AVE
# (41.9081219, -87.6760847)
#
# E WACKER DR
# (41.8878388, -87.6190596)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# N RIDGE AVE
# (35.5045339, -80.6185371)
#
# W ROSCOE ST
# (41.9417774, -87.798255)
#
# N KEDVALE AVE
# (41.9640717, -87.7315451)
#
# W WAVELAND AVE
# (41.9466715, -87.8113037)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# W AINSLIE ST
# (41.9701978, -87.7164722)
#
# S MARTIN ST
# (35.851486, -79.559919)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# W THOMAS ST
# (43.230666, -75.469829)
#
# W POTOMAC AVE
# (43.0958445, -88.0105462)
#
# N DAYTON ST
# (43.1198845, -85.5544939)
#
# S DEARBORN ST
# (47.5957569, -122.3197611)
#
# N Paulina St
# (41.9902949, -87.6714344)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# S CICERO AVE
# (41.8545413, -87.7443874)
#
# S LAWNDALE AVE
# (41.8425259, -87.7171839)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# N RUSH ST
# (43.7828197, -86.4281776)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# N ELSTON AVE
# (41.9624991, -87.731967)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# E WALTON ST
# (33.0918832, -83.2257331)
#
# N HAMILTON AVE
# (40.696537, -73.368294)
#
# W TERMINAL ST
# (38.3711643, -88.065751)
#
# W ADDISON ST
# (42.226415, -84.406033)
#
# W LAKE ST
# (41.8877192, -87.7651226)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# N STATE ST
# (44.619052, -75.408869)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# N LAKE SHORE DR SB
# (41.9022379, -87.6245502)
#
# W LAKE ST
# (41.8877192, -87.7651226)
#
# S CALIFORNIA AVE
# (34.1163848, -118.0008539)
#
# S MERRILL AVE
# (47.1026257, -104.715102)
#
# S ST LAWRENCE AVE
# (41.7682281, -87.6104913)
#
# W 64TH ST
# (39.0130173, -94.802986)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# N STATE ST
# (44.619052, -75.408869)
#
# S FRANCISCO AVE
# (37.6847697, -122.4009224)
#
# S CALIFORNIA BLVD
# (37.8959724, -122.0627491)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# E WACKER DR
# (41.8878388, -87.6190596)
#
# W ALDINE AVE
# (41.9418061, -87.6487849)
#
# S WACKER DR
# (41.8753503, -87.6357587)
#
# W LOGAN BLVD
# (41.9310979, -87.6846333)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# N SEMINARY AVE
# (29.50448, -82.288453)
#
# W KINZIE ST
# (41.8891372, -87.6357356)
#
# W CHESTNUT ST
# (40.0400916, -76.3165126)
#
# N DAYTON ST
# (43.1198845, -85.5544939)
#
# N SPAULDING AVE
# (41.9543894, -87.7104772)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# W HARRISON ST
# (47.453523, -116.785825)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# E PERSHING RD
# (39.8772063, -88.9358125)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# N WELLS ST
# (30.831592, -83.286031)
#
# W ST PAUL AVE
# (43.0347877, -87.9278248)
#
# W LAWRENCE AVE
# (41.9683042, -87.7231431)
#
# N RIDGEWAY AVE
# (41.9954911, -87.7227208)
#
# N ELSTON AVE
# (41.9624991, -87.731967)
#
# S LAKE SHORE DR E
# (41.151578, -85.747808)
#
# W IOWA ST
# (43.0518372, -91.3949007)
#
# W WRIGHTWOOD AVE
# (41.9247283, -87.9553717)
#
# N LINCOLN AVE
# (45.660956, -122.6824777)
#
# W WOLFRAM ST
# (41.9335036, -87.6563169)
#
# W LUNT AVE
# (42.0077782, -87.8200486)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# E 60TH ST
# (44.8942722, -93.2746348)
#
# W WABANSIA AVE
# (41.9107882, -87.7995001)
#
# N HOWE ST
# (33.9374828, -78.0259086)
#
# W 56TH ST
# (44.901509, -93.2991292)
#
# W WILSON AVE
# (47.6575559, -117.4351579)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# S LOOMIS ST
# (41.769112, -88.14147)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# W OAK ST
# (33.2135652, -92.6679021)
#
# S LAKE SHORE DR
# (42.25603, -87.998784)
#
# N CENTRAL AVE
# (35.7718102, -91.6557941)
#
# N RACINE AVE
# (43.003319, -88.216859)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# W LUNT AVE
# (42.0077782, -87.8200486)
#
# N MC CLURG CT
# (30.332179, -82.799061)
#
# W ERIE ST
# (33.3076026, -111.9043792)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# N GREEN ST
# (42.932728, -76.570157)
#
# S ST LAWRENCE AVE
# (41.7682281, -87.6104913)
#
# S LAKE SHORE DR E
# (41.151578, -85.747808)
#
# E RANDOLPH ST
# (39.430644, -96.7584772)
#
# W CHARLESTON ST
# (36.007004, -95.8607771)
#
# W HUBBARD ST
# (41.7159012, -89.3389805)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# W 14TH ST
# (40.7370431, -73.9960774)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# E ERIE ST
# (33.3090107, -111.8198088)
#
# W TERMINAL ST
# (38.3711643, -88.065751)
#
# N OKETO AVE
# (41.952203, -87.8122027)
#
# S Springfield Ave
# (40.6858039, -74.3274558)
#
# N FREMONT ST
# (40.768691, -95.3850426)
#
# W LAWRENCE AVE
# (41.9683042, -87.7231431)
#
# E 55TH PL
# (39.853822, -86.056486)
#
# S THROOP ST
# (41.7467867, -87.6560654)
#
# W C5 ST
# (16.8253267, 96.2700502)
#
# N JANSSEN AVE
# (41.9725741, -87.6667373)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# W CHARLESTON ST
# (36.007004, -95.8607771)
#
# N WINCHESTER AVE
# (46.4110364, -105.830487)
#
# W WASHINGTON ST
# (40.194732, -85.391486)
#
# W LELAND AVE
# (41.9666512, -87.7370944)
#
# E ERIE ST
# (33.3090107, -111.8198088)
#
# W FARWELL AVE
# (42.0067765, -87.6605207)
#
# N KEYSTONE AVE
# (42.0001236, -76.5351751)
#
# W ALTGELD ST
# (41.9262007, -87.8075454)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# E MONROE DR
# (35.3490004, -96.9065622)
#
# N DAMEN AVE
# (41.9649901, -87.6790702)
#
# W ONTARIO ST
# (35.0943283, -85.3096809)
#
# N WOLCOTT AVE
# (41.9069854, -87.6730408)
#
# S CANAL ST
# (42.1979758, -72.6021589)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# W 26TH ST
# (41.8444628, -87.7092909)
#
# S CLARK ST
# (44.955584, -90.795919)
#
# N MALDEN ST
# (41.9687299, -87.6628804)
#
# W IRVING PARK RD
# (41.9536094, -87.7322066)
#
# E GRAND AVE
# (36.7105116, -119.7874097)
#
# N STATE ST
# (44.619052, -75.408869)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# N OAKLEY AVE
# (41.664195, -86.124499)
#
# W LAKE ST
# (41.8877192, -87.7651226)
#
# S LA SALLE ST
# (41.742861, -88.3242315)
#
# S PRINCETON AVE
# (39.7884436, -75.1461365)
#
# W SCHOOL ST
# (33.3044468, -96.4028596)
#
# S MACKINAW AVE
# (41.6390757, -87.5420386)
#
# S DESPLAINES ST
# (41.5186497, -88.0855583)
#
# W 47TH ST
# (40.7580163, -73.9817975)
#
# W FOSTER AVE
# (41.975528, -87.7281106)
#
# N CALIFORNIA AVE
# (33.9287659, -116.9813763)
#
# N HUDSON AVE
# (37.691596, -83.95988)
#
# W PALMER BLVD
# (41.9214697, -87.7067699)
#
# E SCOTT ST
# (43.79134, -88.4223071)
#
# S WOLCOTT AVE
# (41.8741687, -87.6740297)
#
# S DORCHESTER AVE
# (41.861114, -88.126156)
#
# S HONORE ST
# (41.8267808, -87.6715176)
#
# S PERRY AVE
# (27.74589, -81.794657)
#
# N MELVINA AVE
# (42.0121329, -87.7817803)
#
# S ST LAWRENCE AVE
# (41.7682281, -87.6104913)
#
# N MAGNOLIA AVE
# (29.1969846, -82.1365046)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# N CICERO AVE
# (42.0121975, -87.7479383)
#
# S PHILLIPS AVE
# (43.513078, -96.7262166)
#
# W GRENSHAW ST
# (41.8679092, -87.6630252)
#
# W 65TH PL
# (39.876, -86.192027)
#
# W DIVERSEY AVE
# (41.9263942, -88.0053438)
#
# W 25TH ST
# (39.802821, -86.1734111)
#
# N CANNON DR
# (41.9317347, -87.6377872)
#
# W 55TH ST
# (40.7692044, -73.9927944)
#
# S HARPER AVE
# (33.3743982, -111.6339155)
#
# S RIDGEWAY AVE
# (35.61739, -82.3173401)
#
# W DICKENS AVE
# (26.2215137, -98.1842927)
#
# W ERIE ST
# (33.3076026, -111.9043792)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# S NORMAL AVE
# (37.720105, -89.21769)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# S VANDERPOEL AVE
# (41.7202873, -87.6664219)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S LAKE PARK AVE
# (41.5348577, -87.2596604)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W RAVEN ST
# (41.9950834, -87.7834843)
#
# N ALBANY AVE
# (40.7076835, -73.465108)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# N ELSTON AVE
# (41.9624991, -87.731967)
#
# S CHAPPEL AVE
# (41.7588966, -87.5749062)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# S EVANS AVE
# (35.509722, -97.9558699)
#
# N LA SALLE DR
# (32.459967, -99.781336)
#
# N WASHTENAW AVE
# (41.9253795, -87.6949927)
#
# S THROOP ST
# (41.7467867, -87.6560654)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# S BLACKSTONE AVE
# (41.78726, -87.881703)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# S SACRAMENTO AVE
# (39.3373525, -74.4801189)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# W CULLERTON ST
# (41.8556603, -87.641803)
#
# W HARRISON ST
# (47.453523, -116.785825)
#
# W HARRISON ST
# (47.453523, -116.785825)
#
# W WARREN BLVD
# (41.8823807, -87.6651175)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# S UNIVERSITY AVE
# (40.2215138, -111.658881)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# E 33RD ST
# (40.5305942, -85.6462995)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S JUSTINE ST
# (41.6714397, -87.6599691)
#
# E 86TH ST
# (40.7801372, -73.9570904)
#
# S PEORIA ST
# (39.5974063, -104.8480467)
#
# S CARONDOLET AVE
# (41.6687429, -87.5495644)
#
# S AVERS AVE
# (41.6734757, -87.7157121)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# S ST LAWRENCE AVE
# (41.7682281, -87.6104913)
#
# N KARLOV AVE
# (41.9677725, -87.7304613)
#
# S CHRISTIANA AVE
# (28.6675036, -81.4969422)
#
# E 61ST ST
# (44.892517, -93.260414)
#
# N OLEANDER AVE
# (29.253586, -81.0259372)
#
# W POTOMAC AVE
# (43.0958445, -88.0105462)
#
# W GRANVILLE AVE
# (40.245255, -96.754104)
#
# N ARTESIAN AVE
# (41.9254283, -87.6888852)
#
# N LECLAIRE AVE
# (41.935091, -87.7540962)
#
# W Newport Ave
# (42.681683, -83.313192)
#
# W LAKE ST
# (41.8877192, -87.7651226)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# S INGLESIDE AVE
# (41.7403543, -87.601287)
#
# N TALMAN AVE
# (41.9139404, -87.6934262)
#
# S DORCHESTER AVE
# (41.861114, -88.126156)
#
# S ST LAWRENCE AVE
# (41.7682281, -87.6104913)
#
# W MONTROSE AVE
# (41.9607197, -87.7466474)
#
# W RANDOLPH ST
# (36.2743344, -90.9816148)
#
# W LEXINGTON ST
# (39.0325997, -97.5948929)
#
# S KOSTNER AVE
# (41.6651721, -87.7289951)
#
# W MONTANA ST
# (45.6644428, -110.568881)
#
# S HALSTED ST
# (41.5420844, -87.6359687)
#
# W OAKDALE AVE
# (29.0407755, -81.3169917)
#
# S SEELEY AVE
# (42.2886768, -89.633005)
#
# N WHIPPLE ST
# (41.9721178, -87.7049131)
#
# W 86TH PL
# (41.4598471, -87.34753)
#
# W CARROLL AVE
# (34.1342246, -117.8674488)
#
# N WASHTENAW AVE
# (41.9253795, -87.6949927)
#
# W WILCOX ST
# (39.7729655, -86.2196271)
#
# N CENTRAL AVE
# (35.7718102, -91.6557941)
#
# E 47TH ST
# (40.7546125, -73.9737345)
#
# N CLARENDON AVE
# (39.3347411, -74.4980139)
#
# N SOUTHPORT AVE
# (41.9288439, -87.6634384)
#
# W 87TH ST
# (38.970993, -94.7161832)
#
# N ROCKWELL ST
# (33.3744844, -111.7302071)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# W NELSON ST
# (39.937473, -94.841012)
#
# S LAKE SHORE DR SB
# N WELLS ST
# (30.831592, -83.286031)
#
# W 87TH ST
# (38.970993, -94.7161832)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S CORNELL AVE
# (42.119526, -87.95127)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# N ORLEANS ST
# (34.8209213, -87.6356312)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# S DORCHESTER AVE
# (41.861114, -88.126156)
#
# W BIRCHWOOD AVE
# (42.9399265, -87.9627232)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# S ARTESIAN AVE
# (34.0977413, -117.3182866)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# N LECLAIRE AVE
# (41.935091, -87.7540962)
#
# W VERMONT ST
# (39.772338, -86.257635)
#
# N RIDGEWAY AVE
# (41.9954911, -87.7227208)
#
# W WRIGHTWOOD AVE
# (41.9247283, -87.9553717)
#
# E 79TH ST
# (40.7742888, -73.9572899)
#
# W 99TH ST
# (39.9322467, -86.2334767)
#
# S UNION AVE
# (47.2491253, -122.4836389)
#
# N ROCKWELL ST
# (33.3744844, -111.7302071)
#
# N KOLMAR AVE
# (41.9710894, -87.7440319)
#
# S KOSTNER AVE
# (41.6651721, -87.7289951)
#
# S CALIFORNIA AVE
# (34.1163848, -118.0008539)
#
# S KINGSTON AVE
# (36.044406, -95.9074742)
#
# W MELROSE ST
# (40.667262, -73.698695)
#
# S BUFFALO AVE
# (31.4608364, -96.0651776)
#
# S WHIPPLE ST
# (42.6302929, -71.3004363)
#
# S WHIPPLE ST
# (42.6302929, -71.3004363)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# S GREEN ST
# (37.8040878, -87.6368672)
#
# S WHIPPLE ST
# (42.6302929, -71.3004363)
#
# W 66TH ST
# (40.7733596, -73.9809918)
#
# W CARROLL AVE
# (34.1342246, -117.8674488)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W 43RD PL
# (25.861802, -80.297849)
#
# N WASHTENAW AVE
# (41.9253795, -87.6949927)
#
# S PULASKI RD
# (41.6803208, -87.7198931)
#
# W QUINCY ST
# (28.0541053, -81.9636599)
#
# S HOMAN AVE
# (41.6622485, -87.7046222)
#
# W DEMING PL
# (41.9292488, -87.6406316)
#
# W CONCORD PL
# (40.3981522, -111.9271298)
#
# N ROCKWELL ST
# (33.3744844, -111.7302071)
#
# N MOZART ST
# (41.963078, -87.699749)
#
# N SAYRE AVE
# (41.9628625, -87.8025486)
#
# N KIMBALL AVE
# (32.948407, -97.1167804)
#
# N LOREL AVE
# (41.8840101, -87.7588689)
#
# N SAWYER AVE
# (41.9610885, -87.7094607)
#
# S JUSTINE ST
# (41.6714397, -87.6599691)
#
# S CLYDE AVE
# (28.2911755, -81.4131903)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# W 21ST PL
# (41.579758, -87.3761617)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# S SAGINAW AVE
# (41.6427026, -87.5580689)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# W CARROLL AVE
# (34.1342246, -117.8674488)
#
# E 59TH ST
# (40.7639662, -73.9722705)
#
# W HIRSCH ST
# (41.9062185, -87.7313087)
#
# W MARQUETTE RD
# (41.7726852, -87.6253898)
#
# N ELSTON AVE
# (41.9624991, -87.731967)
#
# W CORCORAN PL
# (41.8871682, -87.7678871)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# N LA SALLE DR
# (32.459967, -99.781336)
#
# W EASTWOOD AVE
# (41.9656467, -87.7297858)
#
# N ARTESIAN AVE
# (41.9254283, -87.6888852)
#
# N LAKEWOOD AVE
# (31.856847, -102.514627)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# N MONTICELLO AVE
# (41.9751716, -87.7196691)
#
# S HOMAN AVE
# (41.6622485, -87.7046222)
#
# S BLUE ISLAND AVE
# (41.8541923, -87.6641634)
#
# N SPRINGFIELD AVE
# (41.9646307, -87.7254887)
#
# S CENTRAL AVE
# (40.8950402, -74.0839635)
#
# S MINERVA AVE
# (42.487236, -83.118805)
#
# N LOWELL AVE
# (43.051309, -76.184402)
#
# S KOSTNER AVE
# (41.6651721, -87.7289951)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# N ELBRIDGE AVE
# (41.9363334, -87.7157425)
#
# W 21ST PL
# (41.579758, -87.3761617)
#
# S SPRINGFIELD AVE
# (40.6858039, -74.3274558)
#
# W LYNDALE ST
# (41.9201267, -87.8427793)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)

# %%
# Save Checkpoint 
df2017_geo = df_2017.copy()

# %%
# Filter location that is not null
df2017_geo = df2017_geo[df2017_geo['location'].notna()]

# %%
df2017_geo = impute_district(df2017_geo)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:113: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326

# %%
# Drop columns
df2017_geo.drop(['district', 'index_right'], axis=1, inplace=True)

# Rename columns
df2017_geo.rename(columns={'dist_num':'district'}, inplace=True)

# %%
# Impute updated ward values
df2017_geo = impute_ward(df2017_geo)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:69: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326

# %%
# Drop columns
df2017_geo.drop(['ward_left', 'index_right'], axis=1, inplace=True)

# Rename columns
df2017_geo.rename(columns={'ward_right':'ward'}, inplace=True)

# %%
# Impute updated district values
df2017_geo = impute_commareas(df2017_geo)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:91: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326

# %%
# Drop columns
df2017_geo.drop(['community_area', 'index_right'], axis=1, inplace=True)

# Rename columns
df2017_geo.rename(columns={'area_numbe':'community_area'}, inplace=True)

# %%
# Balance clean up of dataset after transformation
# Drop columns
df2017_geo.drop(['x_coordinate', 'y_coordinate'], axis=1, inplace=True)

# Assign null values in location description to 'OTHER (Specify)'
df2017_geo['location_description'].fillna('OTHER (SPECIFY)', inplace = True)

# %%
df2017_geo.to_csv('/content/drive/MyDrive/Colab Notebooks/capstone/assets/2017_crime_clean.csv', index=False)

# %%
df2017_geo.isnull().sum()
# Out:
# id                      0
# case_number             0
# date                    0
# block                   0
# iucr                    0
# primary_type            0
# description             0
# location_description    0
# arrest                  0
# domestic                0
# beat                    0
# fbi_code                0
# year                    0
# updated_on              0
# latitude                0
# longitude               0
# location                0
# day                     0
# month                   0
# day_of_week             0
# time                    0
# geometry                0
# district                0
# ward                    0
# community_area          0
# dtype: int64

# %%
df2017_geo['year'].head()
# Out:
# 5       2017
# 172     2017
# 459     2017
# 2752    2017
# 8449    2017
# Name: year, dtype: int64

# %% [markdown]
# ## Clean data (2016)

# %%
# from geopy.geocoders import Nominatim
geocoder = Nominatim(user_agent = 'crime_predictions')

# %%
df_2016 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/capstone/assets/2016_crime.csv')
df_2016.head()
# Out:
#          id case_number                 date                  block  iucr  \
# 0  11645836    JC212333  2016-05-01 00:25:00    055XX S ROCKWELL ST  1153
# 1  11043021    JA367631  2016-10-19 19:00:00     075XX S YATES BLVD  0610
# 2  11243066    JB168427  2016-03-29 07:00:00  067XX S RIDGELAND AVE  1153
# 3  11243020    HZ184094  2016-03-11 23:00:00   052XX N ST LOUIS AVE  0281
# 4  11227940    JB148122  2016-01-01 11:00:00    108XX S CALUMET AVE  1154
#
#           primary_type                              description  \
# 0   DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 1             BURGLARY                           FORCIBLE ENTRY
# 2   DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 3  CRIM SEXUAL ASSAULT                           NON-AGGRAVATED
# 4   DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
#
#       location_description  arrest  domestic  beat  district  ward  \
# 0                      NaN   False     False   824       8.0  15.0
# 1               RESTAURANT   False     False   421       4.0   7.0
# 2                    OTHER   False     False   332       3.0   5.0
# 3  RESIDENCE PORCH/HALLWAY   False     False  1712      17.0  39.0
# 4                RESIDENCE   False     False   513       5.0   9.0
#
#    community_area fbi_code  x_coordinate  y_coordinate  year  \
# 0            63.0       11           NaN           NaN  2016
# 1            43.0       05           NaN           NaN  2016
# 2            43.0       11           NaN           NaN  2016
# 3            13.0       02           NaN           NaN  2016
# 4            49.0       11           NaN           NaN  2016
#
#                updated_on  latitude  longitude location  day  month  \
# 0  04/06/2019 04:04:43 PM       NaN        NaN      NaN    1      5
# 1  08/05/2017 03:50:08 PM       NaN        NaN      NaN   19     10
# 2  03/01/2018 03:54:55 PM       NaN        NaN      NaN   29      3
# 3  03/01/2018 03:54:55 PM       NaN        NaN      NaN   11      3
# 4  02/12/2018 03:49:14 PM       NaN        NaN      NaN    1      1
#
#    day_of_week  time
# 0            6     0
# 1            2    19
# 2            1     7
# 3            4    23
# 4            4    11

# %%
df_2016.isnull().sum()
# Out:
# id                         0
# case_number                0
# date                       0
# block                      0
# iucr                       0
# primary_type               0
# description                0
# location_description    1252
# arrest                     0
# domestic                   0
# beat                       0
# district                   0
# ward                       0
# community_area             0
# fbi_code                   0
# x_coordinate            2348
# y_coordinate            2348
# year                       0
# updated_on                 0
# latitude                2348
# longitude               2348
# location                2348
# day                        0
# month                      0
# day_of_week                0
# time                       0
# dtype: int64

# %%
replace_to_zero(df_2016)

# %%
index_list = missing_row_loc(df_2016)
# Out:
# 2348

# %%
impute_data(df_2016, index_list)
# Out:
# Streaming output truncated to the last 5000 lines.
# W MONTROSE AVE
# (41.9607197, -87.7466474)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# S SPAULDING AVE
# (34.0288086, -118.3700242)
#
# E 85TH PL
# (36.0395364, -95.9347648)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W GLADYS AVE
# (41.915226, -87.959294)
#
# N KILDARE AVE
# (41.9718061, -87.7355466)
#
# N LAVERGNE AVE
# (41.9090105, -87.9045527)
#
# S KOLIN AVE
# (41.6804633, -87.7282162)
#
# N HOMAN AVE
# (41.8919714, -87.711335)
#
# S ROCKWELL ST
# (33.3290958, -111.7293356)
#
# W FULTON BLVD
# (41.8864528, -87.7038266)
#
# S BENNETT AVE
# (39.047033, -82.645968)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# W ST
# (55.8497133, -4.2656724)
#
# W ST
# (55.8497133, -4.2656724)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# S HOYNE AVE
# (41.8228899, -87.6774807)
#
# S FAIRFIELD AVE
# (41.8828928, -88.0058916)
#
# W 91ST ST
# (41.7265995, -87.7948245)
#
# W MARQUETTE RD
# (41.7726852, -87.6253898)
#
# E 53RD ST
# (40.7580248, -73.9701634)
#
# W GORDON TER
# (41.9578365, -87.6498054)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# S KEELER AVE
# (36.7501253, -95.9789915)
#
# S DREXEL AVE
# (33.369843, -111.623825)
#
# W GEORGE ST
# (55.8634318, -4.2657255)
#
# S MARSHFIELD AVE
# (41.8093553, -87.6662057)
#
# S EMERALD AVE
# (33.3965996, -111.8035831)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# S MARSHFIELD AVE
# (41.8093553, -87.6662057)
#
# W LE MOYNE ST
# (41.9077136, -87.7331889)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# N MENARD AVE
# (41.8914776, -87.7700234)
#
# E PERSHING RD
# (39.8772063, -88.9358125)
#
# N LONG AVE
# (31.872625, -102.526908)
#
# S EGGLESTON AVE
# (35.407396, -97.5137083)
#
# S GREEN ST
# (37.8040878, -87.6368672)
#
# S CAMPBELL AVE
# (37.1712552, -93.2953919)
#
# N WELLS ST
# (30.831592, -83.286031)
#
# S WESTERN AVE
# (43.5185145, -96.751124)
#
# S DORCHESTER AVE
# (41.861114, -88.126156)
#
# S NORMAL AVE
# (37.720105, -89.21769)
#
# S ST LAWRENCE AVE
# (41.7682281, -87.6104913)
#
# S EMERALD AVE
# (33.3965996, -111.8035831)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# S SPAULDING AVE
# (34.0288086, -118.3700242)
#
# W CULLERTON ST
# (41.8556603, -87.641803)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# S CANAL ST
# (42.1979758, -72.6021589)
#
# W LEXINGTON ST
# (39.0325997, -97.5948929)
#
# W HENDERSON ST
# (35.6845746, -80.4331586)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# W TAYLOR ST
# (41.3837633, -75.7166377)
#
# N NEW ENGLAND AVE
# (41.9380328, -87.7981462)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# W ST
# (55.8497133, -4.2656724)
#
# S RIDGELAND AVE
# (41.8835463, -87.7845574)
#
# W ST
# (55.8497133, -4.2656724)
#
# S UNION AVE
# (47.2491253, -122.4836389)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# W WALTON ST
# (33.089508, -83.237513)
#
# N CENTRAL AVE
# (35.7718102, -91.6557941)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W ALTGELD ST
# (41.9262007, -87.8075454)
#
# N CLAREMONT AVE
# (36.106832, -80.228788)
#
# N PULASKI RD
# (41.9640877, -87.7278964)
#
# W HAWTHORNE PL
# (28.816361, -82.5664011)
#
# S FAIRFIELD AVE
# (41.8828928, -88.0058916)
#
# S DOBSON AVE
# (41.764125, -87.5994316)
#
# S CARPENTER ST
# (35.240268, -81.338339)
#
# E 72ND ST
# (40.7710212, -73.9636252)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# W FULTON ST
# (40.6996535, -90.0114673)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# W 75TH PL
# (25.8910332, -80.2897868)
#
# S WASHTENAW AVE
# (41.8244476, -87.6922106)
#
# W ERIE ST
# (33.3076026, -111.9043792)
#
# S PAULINA ST
# (41.878849, -87.6692204)
#
# S BISHOP ST
# (39.5665983, -76.9892851)
#
# W POLK ST
# (30.7116929, -94.9383233)
#
# N FAIRFIELD AVE
# (40.417653, -120.640311)
#
# E ST
# (50.4738724, 4.2358174)
#
# S PHILLIPS AVE
# (43.513078, -96.7262166)
#
# N AVERS AVE
# (41.9628652, -87.724203)
#
# S JUSTINE ST
# (41.6714397, -87.6599691)
#
# N LAPORTE AVE
# (41.9754723, -87.751858)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# W 18TH ST
# (39.041594, -96.8333437)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# W GREENLEAF AVE
# (42.010296, -87.6685965)
#
# N LARAMIE AVE
# (41.8954167, -87.7556069)
#
# W FLOURNOY ST
# (28.406267, -97.7593919)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# S KEDZIE AVE
# (41.7315967, -87.7021544)
#
# S JUSTINE ST
# (41.6714397, -87.6599691)
#
# N MOBILE AVE
# (35.2845786, -93.1181537)
#
# W GEORGE ST
# (55.8634318, -4.2657255)
#
# N LARAMIE AVE
# (41.8954167, -87.7556069)
#
# N MENARD AVE
# (41.8914776, -87.7700234)
#
# W QUINCY ST
# (28.0541053, -81.9636599)
#
# E MARQUETTE RD
# (41.7727745, -87.6280678)
#
# S CALUMET AVE
# (41.7034033, -86.871671)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# W GLADYS AVE
# (41.915226, -87.959294)
#
# S PRINCETON AVE
# (39.7884436, -75.1461365)
#
# W EASTWOOD AVE
# (41.9656467, -87.7297858)
#
# S KOSTNER AVE
# (41.6651721, -87.7289951)
#
# S BURNHAM AVE
# (41.6423104, -87.5396238)
#
# S ROCKWELL ST
# (33.3290958, -111.7293356)
#
# S JUSTINE ST
# (41.6714397, -87.6599691)
#
# S GREEN ST
# (37.8040878, -87.6368672)
#
# W 21ST ST
# (44.961758, -93.306244)
#
# S THROOP ST
# (41.7467867, -87.6560654)
#
# N LOTUS AVE
# (35.4704582, -97.3553818)
#
# S KENWOOD AVE
# (41.8060326, -87.5935411)
#
# S CHAMPLAIN AVE
# (32.1827548, -110.8194486)
#
# N LEAMINGTON AVE
# (41.8986064, -87.7544655)
#
# S CORLISS AVE
# (41.6899396, -87.6012166)
#
# N LECLAIRE AVE
# (41.935091, -87.7540962)
#
# S KILBOURN AVE
# (41.8591487, -87.737185)
#
# S IRON ST
# (37.597239, -90.6307718)
#
# E 40TH ST
# (44.9305097, -93.2276849)
#
# S EMERALD AVE
# (33.3965996, -111.8035831)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# S OGLESBY AVE
# (41.7448277, -87.5673518)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# E CHELTENHAM PL
# (41.7531429, -87.5502168)
#
# S VERNON AVE
# (32.72251, -96.836774)
#
# N WESTERN AVE
# (35.5293143, -97.5298153)
#
# N KEDZIE AVE
# (41.981245, -87.7088348)
#
# S PEORIA ST
# (39.5974063, -104.8480467)
#
# E PL
# (14.8370417, -89.14104361631954)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# W IRVING PARK RD
# (41.953826, -87.7116755)
#
# N WALLER AVE
# (41.8910824, -87.7677998)
#
# W HIRSCH ST
# (41.9062185, -87.7313087)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W CERMAK RD
# (41.8495374, -87.849713)
#
# S GREEN ST
# (37.8040878, -87.6368672)
#
# S COTTAGE GROVE AVE
# (41.6856412, -87.6114137)
#
# S JEFFERY BLVD
# (41.7479785, -87.5759176)
#
# S BRANDON AVE
# (40.8875742, -92.8209286)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# N LECLAIRE AVE
# (41.935091, -87.7540962)
#
# W 70TH PL
# (25.886576, -80.29765)
#
# S UNIVERSITY AVE
# (40.2215138, -111.658881)
#
# S CARPENTER ST
# (35.240268, -81.338339)
#
# E 50TH ST
# (40.7584119, -73.9769016)
#
# W 70TH PL
# (25.886576, -80.29765)
#
# S EAST END AVE
# (40.7774069, -73.943042)
#
# W CRYSTAL ST
# (28.899691, -82.574754)
#
# S HAMILTON AVE
# (29.4083447, -98.5341118)
#
# S PAXTON AVE
# (41.7316571, -87.5707162)
#
# S HARPER AVE
# (33.3743982, -111.6339155)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# S DORCHESTER AVE
# (41.861114, -88.126156)
#
# S PAULINA ST
# (41.878849, -87.6692204)
#
# S KENWOOD AVE
# (41.8060326, -87.5935411)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# S ABERDEEN ST
# (35.7300766, -95.3526173)
#
# S CARPENTER ST
# (35.240268, -81.338339)
#
# S PULASKI RD
# (41.6803208, -87.7198931)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S CORNELL AVE
# (42.119526, -87.95127)
#
# N ROCKWELL ST
# (33.3744844, -111.7302071)
#
# W PL
# (39.0445999, -94.6029041)
#
# W ROSCOE ST
# (41.9417774, -87.798255)
#
# E 95TH ST
# (40.7835163, -73.9474639)
#
# N LA SALLE DR
# (32.459967, -99.781336)
#
# S MARYLAND AVE
# (39.5941256, -75.9378606)
#
# S LA SALLE ST
# (41.742861, -88.3242315)
#
# N WAYNE AVE
# (40.055678, -75.393487)
#
# W ELM ST
# (31.7998495, -97.0960399)
#
# N ST CLAIR ST
# (38.6048814, -89.8103789)
#
# E WACKER DR
# (41.8878388, -87.6190596)
#
# N PAULINA ST
# (41.9902949, -87.6714344)
#
# E BOWEN AVE
# (46.8021128, -100.7877832)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# N ADA ST
# (34.536441, -96.208725)
#
# S DREXEL BLVD
# (35.4636206, -97.5703073)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# W 14TH ST
# (40.7370431, -73.9960774)
#
# S PEORIA ST
# (39.5974063, -104.8480467)
#
# E 60TH ST
# (44.8942722, -93.2746348)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# E BOWEN AVE
# (46.8021128, -100.7877832)
#
# N LEAVITT ST
# (39.531967, -87.136931)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# E RANDOLPH ST
# (39.430644, -96.7584772)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# W RWY 27R
# (49.3870867, 8.2020301)
#
# S DEARBORN ST
# (47.5958836, -122.318572)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# W THOMAS ST
# (43.230666, -75.469829)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# S SOUTH CHICAGO AVE
# (41.7362005, -87.5643049)
#
# W LUNT AVE
# (42.0077782, -87.8200486)
#
# W ALDINE AVE
# (41.9418061, -87.6487849)
#
# W 95TH ST
# (40.7954358, -73.9757202)
#
# S MAY ST
# (35.5997263, -77.5918349)
#
# W 21ST ST
# (44.961758, -93.306244)
#
# N ADA ST
# (34.536441, -96.208725)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# W FARGO AVE
# (36.3572713, -119.6489519)
#
# N KINGSBURY ST
# (41.8986511, -87.6438839)
#
# W EASTWOOD AVE
# (41.9656467, -87.7297858)
#
# W TERMINAL ST
# (38.3711643, -88.065751)
#
# E WALTON ST
# (33.0918832, -83.2257331)
#
# N HERMITAGE AVE
# (40.232782, -74.780752)
#
# N Milwaukee Ave
# (42.451391, -88.091261)
#
# S MARSHFIELD AVE
# (41.8093553, -87.6662057)
#
# W HOOD AVE
# (46.214711, -119.1458494)
#
# W ILLINOIS ST
# (41.862092, -88.108188)
#
# S HALSTED ST
# (41.5420844, -87.6359687)
#
# E 44TH PL
# (39.836145, -86.056552)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# W CORTEZ ST
# (33.5897649, -112.4664308)
#
# W TERMINAL ST
# (38.3711643, -88.065751)
#
# N WESTERN AVE
# (35.5293143, -97.5298153)
#
# W GRAND AVE
# (44.89992, -89.6139466)
#
# W DIVERSEY PKWY
# (41.9323951, -87.6687745)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# E BOWEN AVE
# (46.8021128, -100.7877832)
#
# S BISHOP ST
# (39.5665983, -76.9892851)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# W Aldine Ave
# (41.9418061, -87.6487849)
#
# S WACKER DR
# (41.8753503, -87.6357587)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W 64TH ST
# (39.0130173, -94.802986)
#
# S CICERO AVE
# (41.8545413, -87.7443874)
#
# S STONY ISLAND AVE
# (41.772423, -87.5862745)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# N MARSHFIELD AVE
# (41.9258863, -87.669388)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# N RAVENSWOOD AVE
# (41.9688187, -87.6741627)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# N TROY ST
# (41.9593759, -87.70697)
#
# W WABANSIA AVE
# (41.9107882, -87.7995001)
#
# W 76TH ST
# (33.9707255, -118.2915697)
#
# W TERMINAL ST
# (38.3711643, -88.065751)
#
# W TERMINAL ST
# (38.3711643, -88.065751)
#
# W IRVING PARK RD
# (41.953826, -87.7116755)
#
# N WELLS ST
# (30.831592, -83.286031)
#
# N STATE ST
# (44.619052, -75.408869)
#
# S CLYDE AVE
# (28.2911755, -81.4131903)
#
# N FRANKLIN ST
# (43.053353, -76.154839)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# S DEARBORN ST
# (47.5958836, -122.318572)
#
# S MENARD AVE
# (41.6600662, -87.7628355)
#
# N BELL AVE
# (32.2464153, -110.8940884)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# E Randolph St
# (39.430644, -96.7584772)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W ERIE ST
# (33.3076026, -111.9043792)
#
# N LA SALLE DR
# (32.459967, -99.781336)
#
# W DIVERSEY PKWY
# (41.9323951, -87.6687745)
#
# W RWY 27R
# (49.3870867, 8.2020301)
#
# W GRAND AVE
# (44.89992, -89.6139466)
#
# W KENNEDY EXPY IB
# (41.8769483, -87.6457872)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# E DELAWARE PL
# (41.8992723, -87.6202196)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# N OAKLEY BLVD
# (41.893065, -87.684323)
#
# W DIVERSEY AVE
# (41.9263942, -88.0053438)
#
# N LINCOLN AVE
# (45.660956, -122.6824777)
#
# W WOLF POINT PLZ
# (41.8879777, -87.637308)
#
# W 19TH ST
# (30.1833503, -85.7294777)
#
# W FULTON MARKET
# (41.8867067, -87.6544987)
#
# N PAULINA ST
# (41.9902949, -87.6714344)
#
# N WESTERN AVE
# (35.5293143, -97.5298153)
#
# S DEARBORN ST
# (47.5958836, -122.318572)
#
# W 33RD ST
# (43.5221332, -96.7399599)
#
# N WELLS ST
# (30.831592, -83.286031)
#
# N SPRINGFIELD AVE
# (41.9646307, -87.7254887)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# W HUTCHINSON ST
# (28.4107445, -97.7590378)
#
# E 57TH ST
# (40.7629694, -73.9739676)
#
# E 95TH ST
# (40.7835163, -73.9474639)
#
# W TERMINAL ST
# (38.3711643, -88.065751)
#
# W ARLINGTON PL
# (28.8134399, -82.5451972)
#
# N HAMLIN AVE
# (41.9737701, -87.7232845)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# W 32ND ST
# (44.9447377, -93.2874525)
#
# N RACINE AVE
# (43.003319, -88.216859)
#
# S DEARBORN ST
# (47.5958836, -122.318572)
#
# W ARTHINGTON ST
# (41.8700106, -87.7112288)
#
# N KEYSTONE AVE
# (42.0001236, -76.5351751)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# N WESTERN AVE
# (35.5293143, -97.5298153)
#
# S JEFFERY BLVD
# (41.7479785, -87.5759176)
#
# W ARMITAGE AVE
# (43.1023086, -87.9910021)
#
# N SANDBURG TER
# (41.9110839, -87.6324747)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# W ILLINOIS ST
# (41.862092, -88.108188)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# W WINNEMAC AVE
# (41.9733819, -87.667451)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# S LAVERGNE AVE
# (41.6916676, -87.7446407)
#
# W FLOURNOY ST
# (28.406267, -97.7593919)
#
# N Broadway
# (40.9696948, -73.8844801)
#
# W 47TH ST
# (40.7580163, -73.9817975)
#
# N CLEVELAND AVE
# (30.344444, -95.0913629)
#
# N CICERO AVE
# (42.0121975, -87.7479383)
#
# S CARPENTER ST
# (35.240268, -81.338339)
#
# W 14TH ST
# (40.7370431, -73.9960774)
#
# N STATE ST
# (44.619052, -75.408869)
#
# N HERMITAGE AVE
# (40.232782, -74.780752)
#
# S VINCENNES AVE
# (41.6979977, -87.6592612)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# N LINCOLN AVE
# (45.660956, -122.6824777)
#
# N ARTESIAN AVE
# (41.9254283, -87.6888852)
#
# S KEDZIE AVE
# (41.7315967, -87.7021544)
#
# W 14TH ST
# (40.7370431, -73.9960774)
#
# W ONTARIO ST
# (35.0943283, -85.3096809)
#
# W DICKENS AVE
# (26.2215137, -98.1842927)
#
# E 80TH ST
# (39.706875, -74.132378)
#
# N TROY ST
# (41.9593759, -87.70697)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# N STATE ST
# (44.619052, -75.408869)
#
# E MADISON ST
# (41.34629, -94.005057)
#
# S AVENUE H
# (40.552806, -90.05225)
#
# S SPAULDING AVE
# (34.0288086, -118.3700242)
#
# S CARPENTER ST
# (35.240268, -81.338339)
#
# W NELSON ST
# (39.937473, -94.841012)
#
# S ESCANABA AVE
# (41.7482723, -87.55405)
#
# N FRANKLIN ST
# (43.053353, -76.154839)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# N LAKEVIEW AVE
# (42.691734, -73.629981)
#
# W FARWELL AVE
# (42.0067765, -87.6605207)
#
# S WASHTENAW AVE
# (41.8244476, -87.6922106)
#
# W 69TH PL
# (25.8853991, -80.3477838)
#
# N LA SALLE ST
# (30.398997, -96.0961872)
#
# N LA SALLE ST
# (30.398997, -96.0961872)
#
# N LARRABEE ST
# (41.907027, -87.6433116)
#
# N ODELL AVE
# (39.1214083, -93.1948712)
#
# S BLACKSTONE AVE
# (41.78726, -87.881703)
#
# N PAULINA ST
# (41.9902949, -87.6714344)
#
# W TERMINAL ST
# (38.3711643, -88.065751)
#
# N KENNETH AVE
# (41.9717719, -87.7392712)
#
# W DIVISION ST
# (38.2597099, -87.9979169)
#
# S GREEN ST
# (37.8040878, -87.6368672)
#
# N LONG AVE
# (31.872625, -102.526908)
#
# W JUNIOR TER
# (41.9603724, -87.6498768)
#
# N SPRINGFIELD AVE
# (41.9646307, -87.7254887)
#
# W ERIE ST
# (33.3076026, -111.9043792)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# W CERMAK RD
# (41.8495374, -87.849713)
#
# W TERMINAL ST
# (38.3711643, -88.065751)
#
# N PARKSIDE AVE
# (34.082432, -117.6296776)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W WOLF POINT PLZ
# (41.8879777, -87.637308)
#
# S BONFIELD ST
# (41.8400709, -87.65428)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# W HUBBARD ST
# (41.7159012, -89.3389805)
#
# N KEDVALE AVE
# (41.9640717, -87.7315451)
#
# S COTTAGE GROVE AVE
# (41.6856412, -87.6114137)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# S RIVERSIDE PLZ
# (41.87992545, -87.63872659087485)
#
# S KILBOURN AVE
# (41.8591487, -87.737185)
#
# W ADDISON ST
# (42.226415, -84.406033)
#
# S DEARBORN ST
# (47.5958836, -122.318572)
#
# S DEARBORN ST
# (47.5958836, -122.318572)
#
# N HAMLIN AVE
# (41.9737701, -87.7232845)
#
# N HERMITAGE AVE
# (40.232782, -74.780752)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# W 44TH ST
# (40.680314, -74.107708)
#
# W PALMER ST
# (35.1795946, -83.3858583)
#
# S VERNON AVE
# (32.72251, -96.836774)
#
# N WABASH AVE
# (41.1450949, -87.8658414)
#
# S SPAULDING AVE
# (34.0288086, -118.3700242)
#
# S ESSEX AVE
# (39.3133874, -76.4565138)
#
# E GRAND AVE
# (36.7105116, -119.7874097)
#
# E LAKE ST
# (44.9483802, -93.2053802)
#
# N STATE ST
# (44.619052, -75.408869)
#
# S HALSTED ST
# (41.5420844, -87.6359687)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# W 71ST ST
# (39.882403, -86.227212)
#
# E 95TH ST
# (40.7835163, -73.9474639)
#
# W LAWRENCE AVE
# (41.9683042, -87.7231431)
#
# W IRVING PARK RD
# (41.953826, -87.7116755)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# S HALSTED ST
# (41.5420844, -87.6359687)
#
# N Milwaukee Ave
# (42.451391, -88.091261)
#
# W NELSON ST
# (39.937473, -94.841012)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# S OAKLEY AVE
# (41.6631708, -86.1244023)
#
# W 16TH ST
# (37.3052344, -120.4970248)
#
# W WILSON AVE
# (47.6575559, -117.4351579)
#
# N CALIFORNIA AVE
# (33.9287659, -116.9813763)
#
# W IOWA ST
# (43.0518372, -91.3949007)
#
# W LUNT AVE
# (42.0077782, -87.8200486)
#
# W 33RD ST
# (43.5221332, -96.7399599)
#
# E MADISON ST
# (41.34629, -94.005057)
#
# N SANDBURG TER
# (41.9110839, -87.6324747)
#
# S COLUMBUS DR
# (33.3465843, -111.7432952)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# S CHRISTIANA AVE
# (28.6675036, -81.4969422)
#
# S WHIPPLE ST
# (42.6302929, -71.3004363)
#
# W WOLFRAM ST
# (41.9335036, -87.6563169)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# W ARMITAGE AVE
# (43.1023086, -87.9910021)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# E 71ST ST
# (41.5110354, -81.6395881)
#
# S LAKE SHORE DR SB
# S LAKE SHORE DR SB
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# S LAKE SHORE DR NB
# (42.25603, -87.998784)
#
# W ELM ST
# (31.7998495, -97.0960399)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# E RANDOLPH ST
# (39.430644, -96.7584772)
#
# W BALMORAL AVE
# (41.9798396, -87.6688623)
#
# N NOKOMIS AVE
# (42.0027918, -87.7566892)
#
# W OHIO ST
# (40.646058, -83.609337)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# W ST PAUL AVE
# (43.0347877, -87.9278248)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# S SANGAMON ST
# (39.5902655, -89.7359101)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# E OAK ST
# (33.4730024, -111.9327122)
#
# N BISSELL ST
# (39.502357, -89.763274)
#
# N LARAMIE AVE
# (41.8954167, -87.7556069)
#
# S COLUMBUS DR
# (33.3465843, -111.7432952)
#
# S EMERALD AVE
# (33.3965996, -111.8035831)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# W CHASE AVE
# (32.780398, -116.9699604)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# N KINGSBURY ST
# (41.8986511, -87.6438839)
#
# E 95TH ST
# (40.7835163, -73.9474639)
#
# W ERIE ST
# (33.3076026, -111.9043792)
#
# S CANAL ST
# (42.1979758, -72.6021589)
#
# N HOYNE AVE
# (41.9550717, -87.6812061)
#
# N THROOP ST
# (41.9034499, -87.6606648)
#
# S ABERDEEN ST
# (35.7300766, -95.3526173)
#
# S STONY ISLAND AVE
# (41.772423, -87.5862745)
#
# S MAY ST
# (35.5997263, -77.5918349)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# S DAN RYAN EXPY OB
# (41.8313616, -87.6310856)
#
# N CLYBOURN AVE
# (41.9273774, -87.6724654)
#
# E 71ST ST
# (41.5110354, -81.6395881)
#
# W CONGRESS PKWY
# (41.8750866, -87.6539866)
#
# W ARTHUR AVE
# (42.9994824, -87.9518008)
#
# S CALUMET AVE
# (41.7034033, -86.871671)
#
# N SANDBURG TER
# (41.9110839, -87.6324747)
#
# W RANDOLPH ST
# (36.2743344, -90.9816148)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# W ROSEMONT AVE
# (38.8094493, -77.0631869)
#
# S WOOD ST
# (41.343196, -83.119849)
#
# S SEELEY AVE
# (42.2886768, -89.633005)
#
# W DIVISION ST
# (38.2597099, -87.9979169)
#
# E BOWEN AVE
# (46.8021128, -100.7877832)
#
# S SPRINGFIELD AVE
# (40.6858039, -74.3274558)
#
# S VINCENNES AVE
# (41.6979977, -87.6592612)
#
# E 71ST PL
# (36.0595852, -95.9162265)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# S CLARK ST
# (44.955584, -90.795919)
#
# W 19TH ST
# (30.1833503, -85.7294777)
#
# W 69TH ST
# (44.8780766, -93.2858204)
#
# S KIMBARK AVE
# (41.7673136, -87.5941382)
#
# N SHEFFIELD AVE
# (43.1085525, -87.8984732)
#
# W HUBBARD ST
# (41.7159012, -89.3389805)
#
# W 55TH ST
# (40.7692044, -73.9927944)
#
# E 68TH ST
# (36.064123, -95.9448098)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# S VINCENNES AVE
# (41.6979977, -87.6592612)
#
# S STATE LINE RD
# (41.056499, -84.803287)
#
# W ARMITAGE AVE
# (43.1023086, -87.9910021)
#
# N WESTERN AVE
# (35.5293143, -97.5298153)
#
# S ESSEX AVE
# (39.3133874, -76.4565138)
#
# W BARRY AVE
# (36.8175627, -93.9243727)
#
# N MOZART ST
# (41.963078, -87.699749)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# N BROADWAY
# (40.9696948, -73.8844801)
#
# N ELSTON AVE
# (41.9624991, -87.731967)
#
# W HOWARD ST
# (43.4469912, -92.2854434)
#
# E GRAND AVE
# (36.7105116, -119.7874097)
#
# S PAULINA ST
# (41.878849, -87.6692204)
#
# N LONG AVE
# (31.872625, -102.526908)
#
# N HOYNE AVE
# (41.9550717, -87.6812061)
#
# S GREENWOOD AVE
# (37.6199047, -96.228166)
#
# N HAZEL ST
# (40.166712, -76.395635)
#
# N CICERO AVE
# (42.0121975, -87.7479383)
#
# W DIVISION ST
# (38.2597099, -87.9979169)
#
# E ILLINOIS ST
# (41.862286, -88.09637)
#
# N FRANKLIN ST
# (43.053353, -76.154839)
#
# N CLYBOURN AVE
# (41.9273774, -87.6724654)
#
# E ILLINOIS ST
# (41.862286, -88.09637)
#
# S COTTAGE GROVE AVE
# (41.6856412, -87.6114137)
#
# N CANAL ST
# (42.442134, -75.597522)
#
# S EMERALD AVE
# (33.3965996, -111.8035831)
#
# N MARCEY ST
# (41.9145583, -87.6560273)
#
# N Racine Ave
# (43.003319, -88.216859)
#
# E ERIE ST
# (33.3090107, -111.8198088)
#
# E 71ST ST
# (41.5110354, -81.6395881)
#
# E GRAND AVE
# (36.7105116, -119.7874097)
#
# W GEORGE ST
# (55.8634318, -4.2657255)
#
# N LINCOLN PARK WEST
# (41.9192403, -87.6363854)
#
# W ERIE ST
# (33.3076026, -111.9043792)
#
# W WARWICK AVE
# (41.695646, -71.528992)
#
# E JACKSON DR
# (39.0427286, -94.3401464)
#
# W 23RD ST
# (40.7442808, -73.9960773)
#
# N PARK DR
# (33.529842, -90.205781)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# N RAVENSWOOD AVE
# (41.9688187, -87.6741627)
#
# S WACKER DR
# (41.8753503, -87.6357587)
#
# W ST
# (55.8497133, -4.2656724)
#
# E RANDOLPH ST
# (39.430644, -96.7584772)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# N CLYBOURN AVE
# (41.9273774, -87.6724654)
#
# E CHICAGO AVE
# (41.8968438, -87.6168932)
#
# E RANDOLPH ST
# (39.430644, -96.7584772)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# W DIVISION ST
# (38.2597099, -87.9979169)
#
# W HUBBARD ST
# (41.7159012, -89.3389805)
#
# W HUBBARD ST
# (41.7159012, -89.3389805)
#
# E JACKSON DR
# (39.0427286, -94.3401464)
#
# W WEBSTER AVE
# (42.4488715, -83.1273708)
#
# S COLUMBUS DR
# (33.3465843, -111.7432952)
#
# W THOMAS ST
# (43.230666, -75.469829)
#
# E RANDOLPH ST
# (39.430644, -96.7584772)
#
# W EASTMAN ST
# (42.0855803, -87.9841194)
#
# E RANDOLPH ST
# (39.430644, -96.7584772)
#
# E RANDOLPH ST
# (39.430644, -96.7584772)
#
# N BROADWAY
# (40.9696948, -73.8844801)
#
# N FRANCISCO AVE
# (26.2217801, -98.3199932)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S CRANDON AVE
# (41.7625938, -87.5688755)
#
# S DEARBORN ST
# (47.5958836, -122.318572)
#
# N LONG AVE
# (31.872625, -102.526908)
#
# W ST
# (55.8497133, -4.2656724)
#
# S CICERO AVE
# (41.8545413, -87.7443874)
#
# S DORCHESTER AVE
# (41.861114, -88.126156)
#
# N BESSIE COLEMAN DR
# (37.7186984, -122.2033434)
#
# W HUBBARD ST
# (41.7159012, -89.3389805)
#
# S LA SALLE ST
# (41.742861, -88.3242315)
#
# S WOLCOTT AVE
# (41.8741687, -87.6740297)
#
# N WESTERN AVE
# (35.5293143, -97.5298153)
#
# W WALTON ST
# (33.089508, -83.237513)
#
# W 24TH PL
# (41.5744811, -87.3824265)
#
# N PAULINA ST
# (41.9902949, -87.6714344)
#
# N STOCKTON DR
# (39.6703588, -75.5803918)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# N KIMBALL AVE
# (32.948407, -97.1167804)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# N WALLER AVE
# (41.8910824, -87.7677998)
#
# S CALUMET AVE
# (41.7034033, -86.871671)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# S PEORIA ST
# (39.5974063, -104.8480467)
#
# S YATES BLVD
# (41.7408204, -87.5660877)
#
# E BOWEN AVE
# (46.8021128, -100.7877832)
#
# S CANAL ST
# (42.1979758, -72.6021589)
#
# S SOUTH SHORE DR
# (41.7687175, -87.5665152)
#
# N NEW ENGLAND AVE
# (41.9380328, -87.7981462)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# N NEW ENGLAND AVE
# (41.9380328, -87.7981462)
#
# N WASHTENAW AVE
# (41.9253795, -87.6949927)
#
# N MC CLURG CT
# (30.332179, -82.799061)
#
# W RANDOLPH ST
# (36.2743344, -90.9816148)
#
# W BRIAR PL
# (41.9391149, -87.6468032)
#
# S CENTRAL AVE
# (40.8950402, -74.0839635)
#
# S HAMLIN AVE
# (42.0088243, -87.8504392)
#
# N RICHMOND ST
# (41.9557758, -87.7019847)
#
# S CANAL ST
# (42.1979758, -72.6021589)
#
# N LINCOLN PARK WEST
# (41.9192403, -87.6363854)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# W MELROSE ST
# (40.667262, -73.698695)
#
# S CALHOUN AVE
# (41.6390695, -87.5616751)
#
# N STATE ST
# (44.619052, -75.408869)
#
# S EVANS AVE
# (35.509722, -97.9558699)
#
# S VINCENNES AVE
# (41.6979977, -87.6592612)
#
# W 35TH ST
# (41.881364, -103.6683128)
#
# S DEARBORN ST
# (47.5958836, -122.318572)
#
# S HONORE ST
# (41.8267808, -87.6715176)
#
# N SPAULDING AVE
# (41.9543894, -87.7104772)
#
# S MAPLEWOOD AVE
# (36.0250954, -95.9064784)
#
# N PAULINA ST
# (41.9902949, -87.6714344)
#
# N CLYBOURN AVE
# (41.9273774, -87.6724654)
#
# W C12 ST
# (16.8223087, 96.2703822)
#
# N ST MICHAELS CT
# (41.912953, -87.6403654)
#
# W 63RD ST
# (41.7733805, -87.9889844)
#
# N CENTRAL PARK AVE
# (41.9751896, -87.7184185)
#
# S CHAMPLAIN AVE
# (32.1827548, -110.8194486)
#
# N MARINE DR
# (33.8164549, -117.8300018)
#
# W Cermak Rd
# (41.8495374, -87.849713)
#
# W 79TH ST
# (40.7849838, -73.9826637)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# S WELLS ST
# (38.0067095, -89.2477996)
#
# S LYNN WHITE DR
# (52.7495459, 0.3871241)
#
# W C12 ST
# (16.8223087, 96.2703822)
#
# W DRUMMOND PL
# (41.9315035, -87.643809)
#
# W TERMINAL ST
# (38.3711643, -88.065751)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# W 26TH ST
# (41.8444628, -87.7092909)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# W B10 ST
# (25.0562875, 55.1445349)
#
# W FOSTER AVE
# (41.975528, -87.7281106)
#
# N Kimball Ave
# (32.948407, -97.1167804)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# S DEARBORN ST
# (47.5958836, -122.318572)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# E CHICAGO AVE
# (41.8968438, -87.6168932)
#
# W C12 ST
# (16.8223087, 96.2703822)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# W ADDISON ST
# (42.226415, -84.406033)
#
# N LARAMIE AVE
# (41.8954167, -87.7556069)
#
# W 54TH PL
# (25.8719155, -80.33905)
#
# W 24TH ST
# (39.8009909, -86.170301)
#
# W HUBBARD ST
# (41.7159012, -89.3389805)
#
# E SUPERIOR ST
# (41.082802, -85.1375483)
#
# N LA SALLE DR
# (32.459967, -99.781336)
#
# E KENSINGTON AVE
# (41.6839578, -87.6167641)
#
# S EVANS AVE
# (35.509722, -97.9558699)
#
# S HONORE ST
# (41.8267808, -87.6715176)
#
# S CHAPPEL AVE
# (41.7588966, -87.5749062)
#
# N HERMITAGE AVE
# (40.232782, -74.780752)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# N LOTUS AVE
# (35.4704582, -97.3553818)
#
# N MOBILE AVE
# (35.2845786, -93.1181537)
#
# E DIVISION ST
# (32.7432903, -97.0671683)
#
# N SEELEY AVE
# (43.5619333, -94.7747364)
#
# N CLAREMONT AVE
# (36.106832, -80.228788)
#
# E 71ST ST
# (41.5110354, -81.6395881)
#
# N LOTUS AVE
# (35.4704582, -97.3553818)
#
# N LAWNDALE AVE
# (41.9592196, -87.720432)
#
# W IOWA ST
# (43.0518372, -91.3949007)
#
# E 71ST ST
# (41.5110354, -81.6395881)
#
# S GREEN ST
# (37.8040878, -87.6368672)
#
# S KILPATRICK AVE
# (41.8149584, -87.7409068)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# W LUNT AVE
# (42.0077782, -87.8200486)
#
# W 53RD ST
# (40.7608471, -73.9768541)
#
# N SACRAMENTO AVE
# (39.341244, -74.483242)
#
# E 76TH ST
# (39.704568, -74.135229)
#
# W IOWA ST
# (43.0518372, -91.3949007)
#
# W ADDISON ST
# (42.226415, -84.406033)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# W HARRISON ST
# (47.453523, -116.785825)
#
# N KOLIN AVE
# (41.8840787, -87.7343473)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# S NORMAL AVE
# (37.720105, -89.21769)
#
# W GRAND AVE
# (44.89992, -89.6139466)
#
# E RANDOLPH ST
# (39.430644, -96.7584772)
#
# W WACKER DR
# (30.4717592, -84.349793)
#
# N SEELEY AVE
# (43.5619333, -94.7747364)
#
# W RANDOLPH ST
# (36.2743344, -90.9816148)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# W FULTON ST
# (40.6996535, -90.0114673)
#
# W TERMINAL ST
# (38.3711643, -88.065751)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# S ALBANY AVE
# (27.932852, -82.480986)
#
# N DOMINICK ST
# (41.9194072, -87.664739)
#
# S PAXTON AVE
# (41.7316571, -87.5707162)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# S MARYLAND AVE
# (39.5941256, -75.9378606)
#
# S EMERALD AVE
# (33.3965996, -111.8035831)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# W OAKDALE AVE
# (29.0407755, -81.3169917)
#
# S SANGAMON ST
# (39.5902655, -89.7359101)
#
# N GREENVIEW AVE
# (42.2840502, -89.1311541)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# N COLUMBUS DR
# (30.5692605, -85.1366536)
#
# N STOCKTON DR
# (39.6703588, -75.5803918)
#
# N SOUTHPORT AVE
# (41.9507055, -87.6641098)
#
# N WABASH AVE
# (41.1450949, -87.8658414)
#
# N CLINTON ST
# (43.0516907, -76.1535027)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# N KEDZIE AVE
# (41.981245, -87.7088348)
#
# S KIMBARK AVE
# (41.7673136, -87.5941382)
#
# W CULLOM AVE
# (41.9590228, -87.7389563)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# W CORTLAND ST
# (42.591483, -76.371899)
#
# S PHILLIPS AVE
# (43.513078, -96.7262166)
#
# N TRIPP AVE
# (41.9848527, -87.7341352)
#
# S UNIVERSITY AVE
# (40.2215138, -111.658881)
#
# W GREENLEAF AVE
# (42.010296, -87.6685965)
#
# S ABERDEEN ST
# (35.7300766, -95.3526173)
#
# W MC LEAN AVE
# (41.9181539, -87.720491)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# W LAWRENCE AVE
# (41.9683042, -87.7231431)
#
# S LA SALLE ST
# (41.742861, -88.3242315)
#
# W CORTEZ ST
# (33.5897649, -112.4664308)
#
# N BISSELL ST
# (39.502357, -89.763274)
#
# W TERMINAL ST
# (38.3711643, -88.065751)
#
# W CULLERTON ST
# (41.8556603, -87.641803)
#
# S LAKE SHORE DR W
# (42.48534, -79.348034)
#
# N ARTESIAN AVE
# (41.9254283, -87.6888852)
#
# S WALLACE ST
# (38.6625346, -87.3019057)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# N HOYNE AVE
# (41.9550717, -87.6812061)
#
# S STARK ST
# (41.364612, -96.155635)
#
# W HUBBARD ST
# (41.7159012, -89.3389805)
#
# W SUPERIOR ST
# (40.857308, -96.805534)
#
# N STATE ST
# (44.619052, -75.408869)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# W CONCOURSE H ST
# W PALMER BLVD
# (41.9214697, -87.7067699)
#
# W WINONA ST
# (46.8469244, -92.0900123)
#
# N WABASH AVE
# (41.1450949, -87.8658414)
#
# N CICERO AVE
# (42.0121975, -87.7479383)
#
# N KENNEDY EXPY OB
# (28.519230999999998, -80.64317239050752)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# E BOWEN AVE
# (46.8021128, -100.7877832)
#
# N HERMITAGE AVE
# (40.232782, -74.780752)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# N KNOX AVE
# (45.0350358, -93.3021408)
#
# E ROOSEVELT RD
# (41.858902, -88.097724)
#
# N ARMOUR ST
# (37.701124, -97.25536)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# S OAKLEY BLVD
# (41.8761349, -87.6838294)
#
# W MONTANA ST
# (45.6644428, -110.568881)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# N HERMITAGE AVE
# (40.232782, -74.780752)
#
# W BARRY AVE
# (36.8175627, -93.9243727)
#
# W 38TH PL
# (41.548344, -87.2952495)
#
# W WEBSTER AVE
# (42.4488715, -83.1273708)
#
# S LAKE SHORE DR E
# (41.151578, -85.747808)
#
# W I190 EXPY
# (5.3691591, -3.954783)
#
# S KEDZIE AVE
# (41.7315967, -87.7021544)
#
# S SHIELDS AVE
# (37.5470522, -77.4700211)
#
# W GRAND AVE
# (44.89992, -89.6139466)
#
# S DREXEL BLVD
# (35.4636206, -97.5703073)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# W WELLINGTON AVE
# (38.1838186, -85.7649883)
#
# S WACKER DR
# (41.8753503, -87.6357587)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# S PLEASANT AVE
# (40.9629751, -74.1033557)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# S MARSHFIELD AVE
# (41.8093553, -87.6662057)
#
# W ONTARIO ST
# (35.0943283, -85.3096809)
#
# N WOLCOTT AVE
# (41.9069854, -87.6730408)
#
# W BERTEAU AVE
# (41.9561908, -87.8158422)
#
# W AUGUSTA BLVD
# (41.4210887, -87.732417)
#
# S Indiana Ave
# (41.5256039, -85.0627283)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# S PAXTON AVE
# (41.7316571, -87.5707162)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# S MIDWAY ST
# (31.8779051, -85.4496238)
#
# W BERTEAU AVE
# (41.9561908, -87.8158422)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# S Kilpatrick Ave
# (41.8149584, -87.7409068)
#
# S CRANDON AVE
# (41.7625938, -87.5688755)
#
# W 63RD ST
# (41.7733805, -87.9889844)
#
# N HAMILTON AVE
# (40.696537, -73.368294)
#
# N Cannon Dr
# (41.9317347, -87.6377872)
#
# N WELLS ST
# (30.831592, -83.286031)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# S CARPENTER ST
# (35.240268, -81.338339)
#
# S CLINTON ST
# (38.5332401, -89.705132)
#
# N LINCOLN PARK WEST
# (41.9192403, -87.6363854)
#
# S OAKLEY AVE
# (41.6631708, -86.1244023)
#
# W CARROLL AVE
# (34.1342246, -117.8674488)
#
# E LOWER NORTH WATER ST
# (43.0514818, -87.9059642)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# N JANSSEN AVE
# (41.9725741, -87.6667373)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# N CALIFORNIA AVE
# (33.9287659, -116.9813763)
#
# N HERMITAGE AVE
# (40.232782, -74.780752)
#
# N WINTHROP AVE
# (41.9873032, -87.6581226)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# W C12 ST
# (16.8223087, 96.2703822)
#
# N FRANKLIN ST
# (43.053353, -76.154839)
#
# W WALNUT ST
# (31.8085297, -97.0935238)
#
# E 53RD ST
# (40.7580248, -73.9701634)
#
# E CONGRESS PKWY
# (41.8757455, -87.6251804)
#
# E HURON ST
# (42.281291, -83.7369982)
#
# W 35TH ST
# (41.881364, -103.6683128)
#
# N WAYNE AVE
# (40.055678, -75.393487)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# W HUBBARD ST
# (41.7159012, -89.3389805)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# N ST LOUIS AVE
# (41.9727203, -87.7159449)
#
# N JANSSEN AVE
# (41.9725741, -87.6667373)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# W ARDMORE AVE
# (41.9866299, -87.7144901)
#
# S WELLS ST
# (38.0067095, -89.2477996)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# S LAKE SHORE DR SB
# W WARREN BLVD
# (41.8823807, -87.6651175)
#
# W ONTARIO ST
# (35.0943283, -85.3096809)
#
# S SOUTH SHORE DR
# (41.7687175, -87.5665152)
#
# S COTTAGE GROVE AVE
# (41.6856412, -87.6114137)
#
# W MELROSE ST
# (40.667262, -73.698695)
#
# N MC CLURG CT
# (30.332179, -82.799061)
#
# W 66TH ST
# (40.7733596, -73.9809918)
#
# N ARTESIAN AVE
# (41.9254283, -87.6888852)
#
# W 19TH ST
# (30.1833503, -85.7294777)
#
# W CRYSTAL ST
# (28.899691, -82.574754)
#
# N BOSWORTH AVE
# (41.9106545, -87.6665138)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# N ST CLAIR ST
# (38.6048814, -89.8103789)
#
# E 54TH ST
# (40.757381, -73.966702)
#
# W DIVISION ST
# (38.2597099, -87.9979169)
#
# W ARGYLE ST
# (57.8956842, -5.1630045)
#
# S KENWOOD AVE
# (41.8060326, -87.5935411)
#
# W TERMINAL ST
# (38.3711643, -88.065751)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S CHAMPLAIN AVE
# (32.1827548, -110.8194486)
#
# N ELSTON AVE
# (41.9624991, -87.731967)
#
# N STATE ST
# (44.619052, -75.408869)
#
# W BERTEAU AVE
# (41.9561908, -87.8158422)
#
# W SUNNYSIDE AVE
# (41.9635312, -87.6603099)
#
# E 53RD ST
# (40.7580248, -73.9701634)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# W ADDISON ST
# (42.226415, -84.406033)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# S CANAL ST
# (42.1979758, -72.6021589)
#
# W TERMINAL ST
# (38.3711643, -88.065751)
#
# E RANDOLPH ST
# (39.430644, -96.7584772)
#
# S LAKE SHORE DR E
# (41.151578, -85.747808)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# E 53RD ST
# (40.7580248, -73.9701634)
#
# S LAKE SHORE DR E
# (41.151578, -85.747808)
#
# N STATE ST
# (44.619052, -75.408869)
#
# N PAULINA ST
# (41.9902949, -87.6714344)
#
# W ONTARIO ST
# (35.0943283, -85.3096809)
#
# W 47TH ST
# (40.7580163, -73.9817975)
#
# S HONORE ST
# (41.8267808, -87.6715176)
#
# N MOHAWK ST
# (42.790293, -73.712513)
#
# S CANAL ST
# (42.1979758, -72.6021589)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# W CHESTNUT ST
# (40.0400916, -76.3165126)
#
# S SANGAMON ST
# (39.5902655, -89.7359101)
#
# N ASHLAND BLVD
# (42.0066203, -87.6699972)
#
# W GORDON TER
# (41.9578365, -87.6498054)
#
# W TERMINAL ST
# (38.3711643, -88.065751)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# W SCHOOL ST
# (33.3044468, -96.4028596)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# E MARQUETTE DR
# (33.3653183, -111.74299756216216)
#
# W LAKE ST
# (41.8877192, -87.7651226)
#
# N FREMONT ST
# (40.768691, -95.3850426)
#
# S MONTGOMERY AVE
# (39.173565, -89.646954)
#
# N STOCKTON DR
# (39.6703588, -75.5803918)
#
# N LA SALLE DR
# (32.459967, -99.781336)
#
# N MOZART ST
# (41.963078, -87.699749)
#
# N STATE ST
# (44.619052, -75.408869)
#
# W 24TH PL
# (41.5744811, -87.3824265)
#
# N TALMAN AVE
# (41.9139404, -87.6934262)
#
# W FULTON ST
# (40.6996535, -90.0114673)
#
# S LOOMIS ST
# (41.769112, -88.14147)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# N STATE ST
# (44.619052, -75.408869)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S LOOMIS BLVD
# (41.7570599, -87.6587609)
#
# S SACRAMENTO DR
# (41.8592648, -87.7017057)
#
# N WASHTENAW AVE
# (41.9253795, -87.6949927)
#
# S COTTAGE GROVE AVE
# (41.6856412, -87.6114137)
#
# N WINTHROP AVE
# (41.9873032, -87.6581226)
#
# S ADA ST
# (44.9307182, -93.0759931)
#
# S RIVERSIDE PLZ
# (41.87992545, -87.63872659087485)
#
# W WOLF POINT PLZ
# (41.8879777, -87.637308)
#
# W BARRY AVE
# (36.8175627, -93.9243727)
#
# N CENTRAL AVE
# (35.7718102, -91.6557941)
#
# N ELSTON AVE
# (41.9624991, -87.731967)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# W RANDOLPH ST
# (36.2743344, -90.9816148)
#
# W HADDON AVE
# (41.9025006, -87.6659391)
#
# N RACINE AVE
# (43.003319, -88.216859)
#
# W DIVERSEY PKWY
# (41.9323951, -87.6687745)
#
# E 71ST ST
# (41.5110354, -81.6395881)
#
# W CULLERTON ST
# (41.8556603, -87.641803)
#
# S CLINTON ST
# (38.5332401, -89.705132)
#
# E ELM ST
# (37.2052899, -93.2328025)
#
# N LEAVITT ST
# (39.531967, -87.136931)
#
# W BERTEAU AVE
# (41.9561908, -87.8158422)
#
# N CENTRAL AVE
# (35.7718102, -91.6557941)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# W 18TH ST
# (39.041594, -96.8333437)
#
# W 48TH PL
# (41.530619, -87.3628539)
#
# S WENTWORTH AVE
# (42.9981308, -87.8894434)
#
# N LA SALLE ST
# (30.398997, -96.0961872)
#
# S DEARBORN ST
# (47.5958836, -122.318572)
#
# S DEARBORN ST
# (47.5958836, -122.318572)
#
# S JUSTINE ST
# (41.6714397, -87.6599691)
#
# W RWY 27R
# (49.3870867, 8.2020301)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# W 47TH ST
# (40.7580163, -73.9817975)
#
# N CUMBERLAND AVE
# (28.5746976, -81.5453944)
#
# W 21ST ST
# (44.961758, -93.306244)
#
# N KEDZIE AVE
# (41.981245, -87.7088348)
#
# N ADA ST
# (34.536441, -96.208725)
#
# W ST
# (55.8497133, -4.2656724)
#
# W CONGRESS PKWY
# (41.8750866, -87.6539866)
#
# N CENTRAL PARK AVE
# (41.9751896, -87.7184185)
#
# S CALIFORNIA AVE
# (34.1163848, -118.0008539)
#
# N HARLEM AVE
# (37.093364, -94.529365)
#
# N RAVENSWOOD AVE
# (41.9688187, -87.6741627)
#
# N CLYBOURN AVE
# (41.9273774, -87.6724654)
#
# N MOZART ST
# (41.963078, -87.699749)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# N KEDZIE AVE
# (41.981245, -87.7088348)
#
# S HOMAN AVE
# (41.6622485, -87.7046222)
#
# W FULTON ST
# (40.6996535, -90.0114673)
#
# S KILDARE AVE
# (41.6744106, -87.7275156)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# W FULTON MARKET
# (41.8867067, -87.6544987)
#
# N KIMBALL AVE
# (32.948407, -97.1167804)
#
# E BOWEN AVE
# (46.8021128, -100.7877832)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# E BOWEN AVE
# (46.8021128, -100.7877832)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# W NORTH SHORE AVE
# (42.0027093, -87.744558)
#
# N LOWELL AVE
# (43.051309, -76.184402)
#
# S PRINCETON AVE
# (39.7884436, -75.1461365)
#
# W MAYPOLE AVE
# (41.8835952, -87.7087902)
#
# S KEDZIE AVE
# (41.7315967, -87.7021544)
#
# W ERIE ST
# (33.3076026, -111.9043792)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# S EUCLID AVE
# (43.5904697, -83.9155365)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# S EMERALD AVE
# (33.3965996, -111.8035831)
#
# W Warwick Ave
# (41.695646, -71.528992)
#
# S MUSKEGON AVE
# (41.6308631, -87.5542799)
#
# W BRIAR PL
# (41.9391149, -87.6468032)
#
# W BALMORAL AVE
# (41.9798396, -87.6688623)
#
# E ST
# (50.4738724, 4.2358174)
#
# N Olmsted Ave
# (42.0044618, -87.8211452)
#
# W ARTHUR AVE
# (42.9994824, -87.9518008)
#
# W HOLLYWOOD AVE
# (40.664973, -73.381541)
#
# N NICKERSON AVE
# (41.9895017, -87.8036989)
#
# W 34TH PL
# (39.817303, -86.251433)
#
# E 36TH PL
# (39.822629, -86.024769)
#
# E 47TH ST
# (40.7546125, -73.9737345)
#
# W TERMINAL ST
# (38.3711643, -88.065751)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# N HARDING AVE
# (41.9937042, -87.7276304)
#
# S WOOD ST
# (41.343196, -83.119849)
#
# N ST CLAIR ST
# (38.6048814, -89.8103789)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# W FLETCHER ST
# (28.324413, -81.40576)
#
# W WABANSIA AVE
# (41.9107882, -87.7995001)
#
# W ERIE ST
# (33.3076026, -111.9043792)
#
# W 69TH ST
# (44.8780766, -93.2858204)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# S CARPENTER ST
# (35.240268, -81.338339)
#
# S STEWART AVE
# (28.290846, -81.4066339)
#
# S NORMAL BLVD
# (41.7792236, -87.637511)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# W RWY 27R
# (49.3870867, 8.2020301)
#
# N RAVENSWOOD AVE
# (41.9688187, -87.6741627)
#
# W IRVING PARK RD
# (41.953826, -87.7116755)
#
# S CALUMET AVE
# (41.7034033, -86.871671)
#
# W WOLF POINT PLZ
# (41.8879777, -87.637308)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# N MC CLURG CT
# (30.332179, -82.799061)
#
# N LINCOLN AVE
# (45.660956, -122.6824777)
#
# W LILL AVE
# (41.9277607, -87.6590552)
#
# E WACKER DR
# (41.8878388, -87.6190596)
#
# S JUSTINE ST
# (41.6714397, -87.6599691)
#
# W WRIGHTWOOD AVE
# (41.9247283, -87.9553717)
#
# N BOSWORTH AVE
# (41.9106545, -87.6665138)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# E RANDOLPH ST
# (39.430644, -96.7584772)
#
# S KINGSTON AVE
# (36.044406, -95.9074742)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S DAN RYAN EXPY OB
# (41.8313616, -87.6310856)
#
# S STONY ISLAND AVE
# (41.772423, -87.5862745)
#
# W 81ST ST
# (41.7469141, -87.6500179)
#
# S SACRAMENTO BLVD
# (41.877103, -87.7011017)
#
# S ST LOUIS AVE
# (41.0219002, -87.7208064)
#
# S LAFAYETTE AVE
# (39.334709, -74.489355)
#
# N PARKSIDE AVE
# (34.082432, -117.6296776)
#
# N ADA St
# (34.536441, -96.208725)
#
# N Hoyne Ave
# (41.9550717, -87.6812061)
#
# W 18TH PL
# (30.230237, -85.651847)
#
# S MUSKEGON AVE
# (41.6308631, -87.5542799)
#
# W North Ave
# (39.3102943, -76.6372005)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# W DIVISION ST
# (38.2597099, -87.9979169)
#
# N LOOMIS ST
# (42.080628, -72.815831)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# W FOSTER AVE
# (41.975528, -87.7281106)
#
# N DESPLAINES ST
# (41.8890494, -87.6443381)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# W FLETCHER ST
# (28.324413, -81.40576)
#
# N LAVERGNE AVE
# (41.9090105, -87.9045527)
#
# W RWY 27R
# (49.3870867, 8.2020301)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# E WACKER DR
# (41.8878388, -87.6190596)
#
# W GEORGE ST
# (55.8634318, -4.2657255)
#
# W LELAND AVE
# (41.9666512, -87.7370944)
#
# N GREENVIEW AVE
# (42.2840502, -89.1311541)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# N KILDARE AVE
# (41.9718061, -87.7355466)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S LAKE SHORE DR E
# (41.151578, -85.747808)
#
# W WACKER DR
# (30.4717592, -84.349793)
#
# W 87TH ST
# (38.970993, -94.7161832)
#
# N THROOP ST
# (41.9034499, -87.6606648)
#
# N DAYTON ST
# (43.1198845, -85.5544939)
#
# W TERMINAL ST
# (38.3711643, -88.065751)
#
# N KOSTNER AVE
# (41.9869013, -87.7382889)
#
# N ST CLAIR ST
# (38.6048814, -89.8103789)
#
# N NEW ENGLAND AVE
# (41.9380328, -87.7981462)
#
# S CENTRAL PARK AVE
# (41.7169517, -87.7114806)
#
# W TILDEN ST
# (40.23459, -89.844674)
#
# N WACKER DR
# (40.759348, -89.6577155)
#
# W GRAND AVE
# (44.89992, -89.6139466)
#
# N LINCOLN AVE
# (45.660956, -122.6824777)
#
# N CANNON DR
# (41.9317347, -87.6377872)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# E 31ST ST
# (44.9466342, -93.276554)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# W DIVERSEY AVE
# (41.9263942, -88.0053438)
#
# W DIVERSEY AVE
# (41.9263942, -88.0053438)
#
# N PARKSIDE AVE
# (34.082432, -117.6296776)
#
# S CLINTON ST
# (38.5332401, -89.705132)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# W ESTES AVE
# (32.008665, -102.081306)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# N MONITOR AVE
# (41.9791477, -87.7744717)
#
# W HARRISON ST
# (47.453523, -116.785825)
#
# N KENNEDY EXPY IB
# S LA SALLE ST
# (41.742861, -88.3242315)
#
# N ELSTON AVE
# (41.9624991, -87.731967)
#
# S SAGINAW AVE
# (41.6427026, -87.5580689)
#
# S INGLESIDE AVE
# (41.7403543, -87.601287)
#
# S UNION AVE
# (47.2491253, -122.4836389)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# N MARSHFIELD AVE
# (41.9258863, -87.669388)
#
# N ORCHARD ST
# (43.0517216, -77.093211)
#
# W LAWRENCE AVE
# (41.9683042, -87.7231431)
#
# E ST
# (50.4738724, 4.2358174)
#
# W MOFFAT ST
# (41.9147199, -87.6873358)
#
# N BELL AVE
# (32.2464153, -110.8940884)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# W SCHOOL ST
# (33.3044468, -96.4028596)
#
# S ST LOUIS AVE
# (41.0219002, -87.7208064)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# S ABERDEEN ST
# (35.7300766, -95.3526173)
#
# W CHESTNUT ST
# (40.0400916, -76.3165126)
#
# S WESTERN AVE
# (43.5185145, -96.751124)
#
# W 17TH ST
# (30.1810582, -85.7266273)
#
# N SOUTHPORT AVE
# (41.9507055, -87.6641098)
#
# N DAWSON AVE
# (41.9340311, -87.7123507)
#
# S ST LAWRENCE AVE
# (41.7682281, -87.6104913)
#
# S EAST END AVE
# (40.7774069, -73.943042)
#
# N CALIFORNIA AVE
# (33.9287659, -116.9813763)
#
# W Rosemont Ave
# (38.8094493, -77.0631869)
#
# S TRIPP AVE
# (41.663533, -87.72595)
#
# S WENTWORTH AVE
# (42.9981308, -87.8894434)
#
# S ARCHER AVE
# (41.6335223, -88.0133585)
#
# N ROCKWELL ST
# (33.3744844, -111.7302071)
#
# E 49TH ST
# (44.9143071, -93.2651976)
#
# E 70TH ST
# (41.4801992, -81.640323)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# W 82ND PL
# (41.4683852, -87.3613672)
#
# W 97TH PL
# (41.4405852, -87.3425892)
#
# S HOMAN AVE
# (41.6622485, -87.7046222)
#
# W DIVERSEY AVE
# (41.9263942, -88.0053438)
#
# S NORMAL AVE
# (37.720105, -89.21769)
#
# S VERNON AVE
# (32.72251, -96.836774)
#
# W ST
# (55.8497133, -4.2656724)
#
# W PL
# (39.0445999, -94.6029041)
#
# S TROY ST
# (42.4897468, -83.1419423)
#
# S ST LOUIS AVE
# (41.0219002, -87.7208064)
#
# E MONROE ST
# (38.305137, -89.992146)
#
# S ST LOUIS AVE
# (41.0219002, -87.7208064)
#
# S TALMAN AVE
# (41.8617849, -87.692024)
#
# S GREENWOOD AVE
# (37.6199047, -96.228166)
#
# S BUFFALO AVE
# (31.4608364, -96.0651776)
#
# W AGATITE AVE
# (41.9619564, -87.7205109)
#
# N TALMAN AVE
# (41.9139404, -87.6934262)
#
# W FULTON ST
# (40.6996535, -90.0114673)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# N CICERO AVE
# (42.0121975, -87.7479383)
#
# S INDEPENDENCE BLVD
# (36.8059, -76.116529)
#
# W TERMINAL ST
# (38.3711643, -88.065751)
#
# W ROSCOE ST
# (41.9417774, -87.798255)
#
# W 69TH ST
# (44.8780766, -93.2858204)
#
# S CAMPBELL AVE
# (37.1712552, -93.2953919)
#
# W RWY 27R
# (49.3870867, 8.2020301)
#
# E NORTH WATER ST
# (44.1892786, -88.4550657)
#
# W NORWOOD ST
# (37.110794, -92.420191)
#
# W HUBBARD ST
# (41.7159012, -89.3389805)
#
# N ELSTON AVE
# (41.9624991, -87.731967)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# S WACKER DR
# (41.8753503, -87.6357587)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# E WALTON ST
# (33.0918832, -83.2257331)
#
# S HARDING AVE
# (36.6834759, -119.7343476)
#
# N HAMILTON AVE
# (40.696537, -73.368294)
#
# W KINZIE ST
# (41.8891372, -87.6357356)
#
# S WELLS ST
# (38.0067095, -89.2477996)
#
# E CHICAGO AVE
# (41.8968438, -87.6168932)
#
# W 30TH ST
# (34.1464779, -117.2966361)
#
# E RANDOLPH ST
# (39.430644, -96.7584772)
#
# N COLUMBUS DR
# (30.5692605, -85.1366536)
#
# N WESTERN AVE
# (35.5293143, -97.5298153)
#
# W GARFIELD BLVD
# (41.7944433, -87.6378706)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# N BOSWORTH AVE
# (41.9106545, -87.6665138)
#
# S PHILLIPS AVE
# (43.513078, -96.7262166)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# N LARAMIE AVE
# (41.8954167, -87.7556069)
#
# E 67TH ST
# (31.9089805, -102.3842858)
#
# S MAPLEWOOD AVE
# (36.0250954, -95.9064784)
#
# E 56TH ST
# (44.9015711, -93.2646052)
#
# S LAPORTE AVE
# (41.6825633, -87.7435692)
#
# W 31ST ST
# (44.9466054, -93.2862078)
#
# N FAIRFIELD AVE
# (40.417653, -120.640311)
#
# S COLFAX AVE
# (30.853988, -96.9914143)
#
# S STEWART AVE
# (28.290846, -81.4066339)
#
# S HOMAN AVE
# (41.6622485, -87.7046222)
#
# N HARDING AVE
# (41.9937042, -87.7276304)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# S HARVARD AVE
# (40.613458, -98.098577)
#
# S KILBOURN AVE
# (41.8591487, -87.737185)
#
# S ELIZABETH ST
# (40.727094, -84.106756)
#
# W GRENSHAW ST
# (41.8679092, -87.6630252)
#
# W 66TH ST
# (40.7733596, -73.9809918)
#
# S BISHOP ST
# (39.5665983, -76.9892851)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# W 18TH ST
# (39.041594, -96.8333437)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# S CICERO AVE
# (41.8545413, -87.7443874)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# N CLARENDON AVE
# (39.3347411, -74.4980139)
#
# E 80TH ST
# (39.706875, -74.132378)
#
# S SOUTH SHORE DR
# (41.7687175, -87.5665152)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# E 60TH ST
# (44.8942722, -93.2746348)
#
# S BENNETT AVE
# (39.047033, -82.645968)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# W 86TH ST
# (40.7861728, -73.9714247)
#
# S LAKE PARK AVE
# (41.5348577, -87.2596604)
#
# S SAWYER AVE
# (47.2288772, -122.4540806)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# W DIVISION ST
# (38.2597099, -87.9979169)
#
# N KILDARE AVE
# (41.9718061, -87.7355466)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# N RIDGE AVE
# (35.5045339, -80.6185371)
#
# W 85TH ST
# (40.784673, -73.9699691)
#
# W CULLERTON ST
# (41.8556603, -87.641803)
#
# S DRAKE AVE
# (41.8498569, -87.713702)
#
# S WINCHESTER AVE
# (46.406387, -105.830479)
#
# E 87TH ST
# (41.4677098, -81.6272505)
#
# S MARSHFIELD AVE
# (41.8093553, -87.6662057)
#
# W FLOURNOY ST
# (28.406267, -97.7593919)
#
# S WOODLAWN AVE
# (41.7812374, -87.5962214)
#
# S LOOMIS BLVD
# (41.7570599, -87.6587609)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# N ELSTON AVE
# (41.9624991, -87.731967)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# S BENNETT AVE
# (39.047033, -82.645968)
#
# S KIRKLAND AVE
# (33.1772716, -99.1742449)
#
# W ARTHUR AVE
# (42.9994824, -87.9518008)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# ...
#
# S CALIFORNIA AVE
# (34.1163848, -118.0008539)
#
# N HARDING AVE
# (41.9937042, -87.7276304)
#
# S HALSTED ST
# (41.5420844, -87.6359687)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# W WRIGHTWOOD AVE
# (41.9247283, -87.9553717)
#
# S MAY ST
# (35.5997263, -77.5918349)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# W 59TH ST
# (40.7646364, -73.9737661)
#
# S MOBILE AVE
# (41.6583825, -87.776142)
#
# S SHIELDS AVE
# (37.5470522, -77.4700211)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# W 85TH ST
# (40.784673, -73.9699691)
#
# N NEW ENGLAND AVE
# (41.9380328, -87.7981462)
#
# N KEDVALE AVE
# (41.9640717, -87.7315451)
#
# N AUSTIN AVE
# (41.912831, -87.7753338)
#
# W CONCORD PL
# (40.3981522, -111.9271298)
#
# S LA SALLE ST
# (41.742861, -88.3242315)
#
# W ARTHINGTON ST
# (41.8700106, -87.7112288)
#
# S SEELEY AVE
# (42.2886768, -89.633005)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# S HALSTED ST
# (41.5420844, -87.6359687)
#
# E ST
# (50.4738724, 4.2358174)
#
# S EBERHART AVE
# (43.822127, -84.748397)
#
# S WOOD ST
# (41.343196, -83.119849)
#
# N LUNA AVE
# (34.454345, -119.281645)
#
# W IRVING PARK RD
# (41.953826, -87.7116755)
#
# S ANTHONY AVE
# (37.149086, -98.028778)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# W ILLINOIS ST
# (41.862092, -88.108188)
#
# W DIVERSEY AVE
# (41.9263942, -88.0053438)
#
# S KERFOOT AVE
# (41.7414221, -87.6404092)
#
# S GREEN ST
# (37.8040878, -87.6368672)
#
# S DRAKE AVE
# (41.8498569, -87.713702)
#
# W HUBBARD ST
# (41.7159012, -89.3389805)
#
# W HARRISON ST
# (47.453523, -116.785825)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# W GLADYS AVE
# (41.915226, -87.959294)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# S ADA ST
# (44.9307182, -93.0759931)
#
# S CORNELL AVE
# (42.119526, -87.95127)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S HAMLIN AVE
# (42.0088243, -87.8504392)
#
# S EBERHART AVE
# (43.822127, -84.748397)
#
# S MUSKEGON AVE
# (41.6308631, -87.5542799)
#
# S KEDVALE AVE
# (41.6474182, -87.7222793)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# N PINE GROVE AVE
# (41.9529308, -87.6478914)
#
# N KARLOV AVE
# (41.9677725, -87.7304613)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# W GRANVILLE AVE
# (40.245255, -96.754104)
#
# S KIMBARK AVE
# (41.7673136, -87.5941382)
#
# S ADA ST
# (44.9307182, -93.0759931)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S WENTWORTH AVE
# (42.9981308, -87.8894434)
#
# S MAY ST
# (35.5997263, -77.5918349)
#
# S VAN VLISSINGEN RD
# (41.7150711, -87.5738714)
#
# S COTTAGE GROVE AVE
# (41.6856412, -87.6114137)
#
# S DREXEL AVE
# (33.369843, -111.623825)
#
# S OGLESBY AVE
# (41.7448277, -87.5673518)
#
# S TROY ST
# (42.4897468, -83.1419423)
#
# W ST
# (55.8497133, -4.2656724)
#
# S SPAULDING AVE
# (34.0288086, -118.3700242)
#
# W MARQUETTE RD
# (41.7726852, -87.6253898)
#
# W ARTHUR AVE
# (42.9994824, -87.9518008)
#
# N LARAMIE AVE
# (41.8954167, -87.7556069)
#
# N KOLIN AVE
# (41.8840787, -87.7343473)
#
# W MONTANA ST
# (45.6644428, -110.568881)
#
# S Michigan Ave
# (42.59934, -83.9336293)
#
# W 96TH PL
# (41.4437059, -87.3484881)
#
# S YATES BLVD
# (41.7408204, -87.5660877)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# S ANTHONY AVE
# (37.149086, -98.028778)
#
# S HERMOSA AVE
# (33.9126479, -116.8692547)
#
# N TRIPP AVE
# (41.9848527, -87.7341352)
#
# W 80TH ST
# (41.7486788, -87.6536729)
#
# S CALIFORNIA AVE
# (34.1163848, -118.0008539)
#
# N NATCHEZ AVE
# (41.9548213, -87.7893155)
#
# W LAWRENCE AVE
# (41.9683042, -87.7231431)
#
# S TALMAN AVE
# (41.8617849, -87.692024)
#
# S KOSTNER AVE
# (41.6651721, -87.7289951)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S HARDING AVE
# (36.6834759, -119.7343476)
#
# S RIDGELAND AVE
# (41.8835463, -87.7845574)
#
# S PERRY AVE
# (27.74589, -81.794657)
#
# N LOREL AVE
# (41.8840101, -87.7588689)
#
# W SUPERIOR ST
# (40.857308, -96.805534)
#
# S KILPATRICK AVE
# (41.8149584, -87.7409068)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S NATOMA AVE
# (41.715834, -87.7859084)
#
# S DORCHESTER AVE
# (41.861114, -88.126156)
#
# S WOOD ST
# (41.343196, -83.119849)
#
# S SPRINGFIELD AVE
# (40.6858039, -74.3274558)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# S CHRISTIANA AVE
# (28.6675036, -81.4969422)
#
# S EBERHART AVE
# (43.822127, -84.748397)
#
# S ARTESIAN AVE
# (34.0977413, -117.3182866)
#
# S PRINCETON AVE
# (39.7884436, -75.1461365)
#
# W CONGRESS PKWY
# (41.8750866, -87.6539866)
#
# E 89TH PL
# (36.0340257, -95.9045251)
#
# S WHIPPLE ST
# (42.6302929, -71.3004363)
#
# S RACINE AVE
# (42.9427005, -88.1582854)
#
# S FRANCISCO AVE
# (37.6847697, -122.4009224)
#
# W DIVISION ST
# (38.2597099, -87.9979169)
#
# N ST LOUIS AVE
# (41.9727203, -87.7159449)
#
# W ROSCOE ST
# (41.9417774, -87.798255)
#
# N NORTHWEST HWY
# (42.0193599, -87.8423973)
#
# N LINCOLN AVE
# (45.660956, -122.6824777)
#
# N KEATING AVE
# (41.9746791, -87.7467834)
#
# W 90TH PL
# (41.7271363, -87.8001261)
#
# W FLETCHER ST
# (28.324413, -81.40576)
#
# S HAMILTON AVE
# (29.4083447, -98.5341118)
#
# S PROSPECT AVE
# (33.8413909, -118.3763438)
#
# N NARRAGANSETT AVE
# (41.9633701, -87.7869544)
#
# S AVERS AVE
# (41.6734757, -87.7157121)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# N MASON AVE
# (42.354338, -85.244316)
#
# W WEBSTER AVE
# (42.4488715, -83.1273708)
#
# N KILDARE AVE
# (41.9718061, -87.7355466)
#
# N LOCKWOOD AVE
# (41.6979589, -83.5699941)
#
# N KOLIN AVE
# (41.8840787, -87.7343473)
#
# N KEELER AVE
# (31.890888, -102.393391)
#
# W IRVING PARK RD
# (41.953826, -87.7116755)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W LAWRENCE AVE
# (41.9683042, -87.7231431)
#
# S TRIPP AVE
# (41.663533, -87.72595)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# S OAKLEY AVE
# (41.6631708, -86.1244023)
#
# W DICKENS AVE
# (26.2215137, -98.1842927)
#
# E OHIO ST
# (40.601786, -84.084445)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# S MILLARD AVE
# (36.725905, -119.6804604)
#
# S KEDVALE AVE
# (41.6474182, -87.7222793)
#
# W WASHBURNE AVE
# (41.8661181, -87.6581942)
#
# E 77TH ST
# (36.0529109, -95.8831572)
#
# S MARSHFIELD AVE
# (41.8093553, -87.6662057)
#
# S SANGAMON ST
# (39.5902655, -89.7359101)
#
# N ST LOUIS AVE
# (41.9727203, -87.7159449)
#
# S MACKINAW AVE
# (41.6390757, -87.5420386)
#
# S MASON AVE
# (47.1898123, -122.4941429)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# W 79TH ST
# (40.7849838, -73.9826637)
#
# S LA SALLE ST
# (41.742861, -88.3242315)
#
# W FLOURNOY ST
# (28.406267, -97.7593919)
#
# S GREENWOOD AVE
# (37.6199047, -96.228166)
#
# N WESTERN AVE
# (35.5293143, -97.5298153)
#
# E 42ND ST
# (40.7486764, -73.9696502)
#
# W LEXINGTON ST
# (39.0325997, -97.5948929)
#
# S PHILLIPS AVE
# (43.513078, -96.7262166)
#
# W HUBBARD ST
# (41.7159012, -89.3389805)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S MARYLAND AVE
# (39.5941256, -75.9378606)
#
# W 15TH ST
# (44.9689141, -93.2867103)
#
# S HARPER AVE
# (33.3743982, -111.6339155)
#
# S KEDVALE AVE
# (41.6474182, -87.7222793)
#
# W WABANSIA AVE
# (41.9107882, -87.7995001)
#
# S COLFAX AVE
# (30.853988, -96.9914143)
#
# N FRANCISCO AVE
# (26.2217801, -98.3199932)
#
# S WENTWORTH AVE
# (42.9981308, -87.8894434)
#
# S RIDGELAND AVE
# (41.8835463, -87.7845574)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# W ST
# (55.8497133, -4.2656724)
#
# N DRAKE AVE
# (41.9725027, -87.7171475)
#
# W MIDWAY PARK
# (41.8889822, -87.7720806)
#
# W PATTERSON AVE
# (35.847964, -79.574575)
#
# N BOSWORTH AVE
# (41.9106545, -87.6665138)
#
# S LAPORTE AVE
# (41.6825633, -87.7435692)
#
# W 14TH ST
# (40.7370431, -73.9960774)
#
# E 83RD ST
# (41.5024109, -81.6295886)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# W 83RD ST
# (41.7432634, -87.6499076)
#
# N PINE AVE
# (42.669591, -73.790953)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# S FRANCISCO AVE
# (37.6847697, -122.4009224)
#
# W WILCOX ST
# (39.7729655, -86.2196271)
#
# W ST
# (55.8497133, -4.2656724)
#
# W LOCUST ST
# (38.442816, -90.2015914)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# N RACINE AVE
# (43.003319, -88.216859)
#
# W LEXINGTON ST
# (39.0325997, -97.5948929)
#
# W 64TH ST
# (39.0130173, -94.802986)
#
# N LAWNDALE AVE
# (41.9592196, -87.720432)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# W WEST END AVE
# (41.8840066, -87.7595529)
#
# N LARAMIE AVE
# (41.8954167, -87.7556069)
#
# S HAMLIN AVE
# (42.0088243, -87.8504392)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# E 80TH ST
# (39.706875, -74.132378)
#
# E 57TH ST
# (40.7629694, -73.9739676)
#
# N SEDGWICK ST
# (37.693255, -97.36976)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# N ALBANY AVE
# (40.7076835, -73.465108)
#
# N WALLER AVE
# (41.8910824, -87.7677998)
#
# W DRUMMOND PL
# (41.9315035, -87.643809)
#
# W HENDERSON ST
# (35.6845746, -80.4331586)
#
# S HAMLIN AVE
# (42.0088243, -87.8504392)
#
# S CHAPPEL AVE
# (41.7588966, -87.5749062)
#
# W MAYPOLE AVE
# (41.8835952, -87.7087902)
#
# S CAMPBELL AVE
# (37.1712552, -93.2953919)
#
# S AVENUE N
# (31.532975, -97.437499)
#
# S HALSTED ST
# (41.5420844, -87.6359687)
#
# N PINE AVE
# (42.669591, -73.790953)
#
# W DOUGLAS BLVD
# (41.8629927, -87.7029508)
#
# N AVERS AVE
# (41.9628652, -87.724203)
#
# W JARVIS AVE
# (42.0153543, -87.8050829)
#
# S COLES AVE
# (41.7483376, -87.5491898)
#
# S ALBANY AVE
# (27.932852, -82.480986)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# N MOODY AVE
# (27.9453048, -82.484032)
#
# W 61ST ST
# (44.89257, -93.315002)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# N LINCOLN AVE
# (45.660956, -122.6824777)
#
# S DREXEL AVE
# (33.369843, -111.623825)
#
# S ESSEX AVE
# (39.3133874, -76.4565138)
#
# N BELL AVE
# (32.2464153, -110.8940884)
#
# S LONGWOOD DR
# (41.1158215, -87.8298037)
#
# W DIVISION ST
# (38.2597099, -87.9979169)
#
# W CORNELIA AVE
# (33.9618136, -98.6777071)
#
# S ELIZABETH ST
# (40.727094, -84.106756)
#
# S ALBANY AVE
# (27.932852, -82.480986)
#
# S TAN CT
# (41.8550773, -87.6346044)
#
# W CRYSTAL ST
# (28.899691, -82.574754)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# W ARTHUR AVE
# (42.9994824, -87.9518008)
#
# W 19TH ST
# (30.1833503, -85.7294777)
#
# W MELROSE ST
# (40.667262, -73.698695)
#
# N MARINE DR
# (33.8164549, -117.8300018)
#
# W ALTGELD ST
# (41.9262007, -87.8075454)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# N DRAKE AVE
# (41.9725027, -87.7171475)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# S WINCHESTER AVE
# (46.406387, -105.830479)
#
# N NEW ENGLAND AVE
# (41.9380328, -87.7981462)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# W 48TH ST
# (44.915947, -93.294662)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# S DEARBORN ST
# (47.5958836, -122.318572)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# S KENWOOD AVE
# (41.8060326, -87.5935411)
#
# W EDDY ST
# (33.6448338, -97.3810902)
#
# S KENNETH AVE
# (41.6814466, -87.7302028)
#
# W EASTWOOD AVE
# (41.9656467, -87.7297858)
#
# N ARTESIAN AVE
# (41.9254283, -87.6888852)
#
# S ALBANY AVE
# (27.932852, -82.480986)
#
# S PROSPECT AVE
# (33.8413909, -118.3763438)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# S MAY ST
# (35.5997263, -77.5918349)
#
# N HAZEL ST
# (40.166712, -76.395635)
#
# W 19TH ST
# (30.1833503, -85.7294777)
#
# W ST
# (55.8497133, -4.2656724)
#
# W 47TH ST
# (40.7580163, -73.9817975)
#
# W EDDY ST
# (33.6448338, -97.3810902)
#
# S CANAL ST
# (42.1979758, -72.6021589)
#
# W KENNEDY EXPY IB
# (41.8769483, -87.6457872)
#
# N ODELL AVE
# (39.1214083, -93.1948712)
#
# W TAYLOR ST
# (41.3837633, -75.7166377)
#
# N STATE ST
# (44.619052, -75.408869)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# E BOWEN AVE
# (46.8021128, -100.7877832)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# N ORLEANS ST
# (34.8209213, -87.6356312)
#
# N STATE ST
# (44.619052, -75.408869)
#
# N STATE ST
# (44.619052, -75.408869)
#
# W DIVISION ST
# (38.2597099, -87.9979169)
#
# N ORLEANS ST
# (34.8209213, -87.6356312)
#
# N ST CLAIR ST
# (38.6048814, -89.8103789)
#
# N ORLEANS ST
# (34.8209213, -87.6356312)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# W ERIE ST
# (33.3076026, -111.9043792)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# N WESTERN AVE
# (35.5293143, -97.5298153)
#
# S KEDZIE AVE
# (41.7315967, -87.7021544)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# N NORTH PARK AVE
# (41.9085375, -87.6365839)
#
# N EASTLAKE TER
# (42.019648, -87.664686)
#
# S ARTESIAN AVE
# (34.0977413, -117.3182866)
#
# N ADA ST
# (34.536441, -96.208725)
#
# W SCHOOL ST
# (33.3044468, -96.4028596)
#
# E 43RD ST
# (44.9251197, -93.2396454)
#
# W IRVING PARK RD
# (41.953826, -87.7116755)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# S PAXTON AVE
# (41.7316571, -87.5707162)
#
# N ELSTON AVE
# (41.9624991, -87.731967)
#
# N ELSTON AVE
# (41.9624991, -87.731967)
#
# N ELSTON AVE
# (41.9624991, -87.731967)
#
# N ELSTON AVE
# (41.9624991, -87.731967)
#
# N ELSTON AVE
# (41.9624991, -87.731967)
#
# N ELSTON AVE
# (41.9624991, -87.731967)
#
# N ELSTON AVE
# (41.9624991, -87.731967)
#
# W superior st
# (40.857308, -96.805534)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# S KEELEY ST
# (41.8404734, -87.6534502)
#
# N CLYBOURN AVE
# (41.9273774, -87.6724654)
#
# W 71ST ST
# (39.882403, -86.227212)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# E 71ST ST
# (41.5110354, -81.6395881)
#
# S LEAVITT ST
# (41.8737714, -87.6813292)
#
# S LOOMIS ST
# (41.769112, -88.14147)
#
# N LA SALLE DR
# (32.459967, -99.781336)
#
# N ELSTON AVE
# (41.9624991, -87.731967)
#
# S ESCANABA AVE
# (41.7482723, -87.55405)
#
# W RICE ST
# (35.5516747, -80.6218475)
#
# W LEXINGTON ST
# (39.0325997, -97.5948929)
#
# S JUSTINE ST
# (41.6714397, -87.6599691)
#
# S ST LOUIS AVE
# (41.0219002, -87.7208064)
#
# S BISHOP ST
# (39.5665983, -76.9892851)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# S ESSEX AVE
# (39.3133874, -76.4565138)
#
# N AVERS AVE
# (41.9628652, -87.724203)
#
# S BISHOP ST
# (39.5665983, -76.9892851)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# S PAXTON AVE
# (41.7316571, -87.5707162)
#
# W CONGRESS PKWY
# (41.8750866, -87.6539866)
#
# S UNION AVE
# (47.2491253, -122.4836389)
#
# S DANTE AVE
# (41.5394098, -87.5855724)
#
# N BROADWAY
# (40.9696948, -73.8844801)
#
# S PEORIA ST
# (39.5974063, -104.8480467)
#
# S LOOMIS BLVD
# (41.7570599, -87.6587609)
#
# W WABANSIA AVE
# (41.9107882, -87.7995001)
#
# E 65TH ST
# (25.8818612, -80.2655861)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# E 74TH ST
# (40.7710532, -73.9596512)
#
# W ROOSEVELT RD
# (41.8568563, -88.1736282)
#
# S MILLARD AVE
# (36.725905, -119.6804604)
#
# S COTTAGE GROVE AVE
# (41.6856412, -87.6114137)
#
# S MARSHFIELD AVE
# (41.8093553, -87.6662057)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# N SPRINGFIELD AVE
# (41.9646307, -87.7254887)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# W WEST END AVE
# (41.8840066, -87.7595529)
#
# S VINCENNES AVE
# (41.6979977, -87.6592612)
#
# S CANALPORT AVE
# (41.8526148, -87.651186)
#
# S RIDGELAND AVE
# (41.8835463, -87.7845574)
#
# W SCHUBERT AVE
# (41.921548, -88.096436)
#
# N CENTRAL AVE
# (35.7718102, -91.6557941)
#
# S WHIPPLE ST
# (42.6302929, -71.3004363)
#
# S DORCHESTER AVE
# (41.861114, -88.126156)
#
# S PEORIA ST
# (39.5974063, -104.8480467)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# S WESTERN AVE
# (43.5185145, -96.751124)
#
# S UNION AVE
# (47.2491253, -122.4836389)
#
# S PEORIA ST
# (39.5974063, -104.8480467)
#
# S ST LAWRENCE AVE
# (41.7682281, -87.6104913)
#
# W HADDON AVE
# (41.9025006, -87.6659391)
#
# W SUMMERDALE AVE
# (41.9789237, -87.6696222)
#
# N KEDZIE AVE
# (41.981245, -87.7088348)
#
# E 90TH ST
# (39.9181982, -86.0387202)
#
# N MONITOR AVE
# (41.9791477, -87.7744717)
#
# W CULLERTON ST
# (41.8556603, -87.641803)
#
# S VERNON AVE
# (32.72251, -96.836774)
#
# N CLAREMONT AVE
# (36.106832, -80.228788)
#
# S INDEPENDENCE BLVD
# (36.8059, -76.116529)
#
# W HUTCHINSON ST
# (28.4107445, -97.7590378)
#
# S ALLPORT ST
# (41.8549455, -87.6575679)
#
# S TRIPP AVE
# (41.663533, -87.72595)
#
# W ALTGELD ST
# (41.9262007, -87.8075454)
#
# W ALTGELD ST
# (41.9262007, -87.8075454)
#
# E DELAWARE PL
# (41.8992723, -87.6202196)
#
# W 35TH ST
# (41.881364, -103.6683128)
#
# S HERMITAGE AVE
# (41.7685166, -87.6675589)
#
# S HERMITAGE AVE
# (41.7685166, -87.6675589)
#
# S MAJOR AVE
# (41.664039, -87.760687)
#
# S WELLS ST
# (38.0067095, -89.2477996)
#
# W NELSON ST
# (39.937473, -94.841012)
#
# N LONG AVE
# (31.872625, -102.526908)
#
# N La Salle Dr
# (32.459967, -99.781336)
#
# S HALSTED ST
# (41.5420844, -87.6359687)
#
# W POTOMAC AVE
# (43.0958445, -88.0105462)
#
# W IRVING PARK RD
# (41.953826, -87.7116755)
#
# N FRANCISCO AVE
# (26.2217801, -98.3199932)
#
# S WASHTENAW AVE
# (41.8244476, -87.6922106)
#
# S BLUE ISLAND AVE
# (41.8541923, -87.6641634)
#
# S FOREST AVE
# (42.2736405, -83.7331125)
#
# S WASHTENAW AVE
# (41.8244476, -87.6922106)
#
# N KENNETH AVE
# (41.9717719, -87.7392712)
#
# S TROY ST
# (42.4897468, -83.1419423)
#
# N LA CROSSE AVE
# (38.2701926, -104.5890357)
#
# S BELL AVE
# (36.6728853, -120.1423994)
#
# S EBERHART AVE
# (43.822127, -84.748397)
#
# W CRYSTAL ST
# (28.899691, -82.574754)
#
# N MOZART ST
# (41.963078, -87.699749)
#
# W ROSCOE ST
# (41.9417774, -87.798255)
#
# N la salle dr
# (32.459967, -99.781336)
#
# S HYDE PARK BLVD
# (41.7978073, -87.5840054)
#
# N MONITOR AVE
# (41.9791477, -87.7744717)
#
# E ST
# (50.4738724, 4.2358174)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W GREGORY ST
# (42.0735492, -87.9441124)
#
# N SPRINGFIELD AVE
# (41.9646307, -87.7254887)

# %%
# Save Checkpoint 
df2016_geo = df_2016.copy()

# %%
# Filter location that is not null
df2016_geo = df2016_geo[df2016_geo['location'].notna()]

# %%
df2016_geo = impute_district(df2016_geo)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:113: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326

# %%
# Drop columns
df2016_geo.drop(['district', 'index_right'], axis=1, inplace=True)

# Rename columns
df2016_geo.rename(columns={'dist_num':'district'}, inplace=True)

# %%
# Impute updated ward values
df2016_geo = impute_ward(df2016_geo)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:69: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326

# %%
# Drop columns
df2016_geo.drop(['ward_left', 'index_right'], axis=1, inplace=True)

# Rename columns
df2016_geo.rename(columns={'ward_right':'ward'}, inplace=True)

# %%
# Impute updated district values
df2016_geo = impute_commareas(df2016_geo)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:91: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326

# %%
# Drop columns
df2016_geo.drop(['community_area', 'index_right'], axis=1, inplace=True)

# Rename columns
df2016_geo.rename(columns={'area_numbe':'community_area'}, inplace=True)

# %%
# Balance clean up of dataset after transformation
# Drop columns
df2016_geo.drop(['x_coordinate', 'y_coordinate'], axis=1, inplace=True)

# Assign null values in location description to 'OTHER (Specify)'
df2016_geo['location_description'].fillna('OTHER (SPECIFY)', inplace = True)

# %%
df2016_geo.to_csv('/content/drive/MyDrive/Colab Notebooks/capstone/assets/2016_crime_clean.csv', index=False)

# %%
df2016_geo.isnull().sum()
# Out:
# id                      0
# case_number             0
# date                    0
# block                   0
# iucr                    0
# primary_type            0
# description             0
# location_description    0
# arrest                  0
# domestic                0
# beat                    0
# fbi_code                0
# year                    0
# updated_on              0
# latitude                0
# longitude               0
# location                0
# day                     0
# month                   0
# day_of_week             0
# time                    0
# geometry                0
# district                0
# ward                    0
# community_area          0
# dtype: int64

# %% [markdown]
# ## Clean data (2015)

# %%
# from geopy.geocoders import Nominatim
geocoder = Nominatim(user_agent = 'crime_predictions')

# %%
df_2015 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/capstone/assets/2015_crime.csv')
df_2015.head()
# Out:
#          id case_number                 date                block  iucr  \
# 0  10224738    HY411648  2015-09-05 13:30:00      043XX S WOOD ST  0486
# 1  10224739    HY411615  2015-09-04 11:30:00  008XX N CENTRAL AVE  0870
# 2  10224740    HY411595  2015-09-05 12:45:00    035XX W BARRY AVE  2023
# 3  10224741    HY411610  2015-09-05 13:00:00  0000X N LARAMIE AVE  0560
# 4  10224742    HY411435  2015-09-05 10:55:00  082XX S LOOMIS BLVD  0610
#
#   primary_type              description location_description  arrest  \
# 0      BATTERY  DOMESTIC BATTERY SIMPLE            RESIDENCE   False
# 1        THEFT           POCKET-PICKING              CTA BUS   False
# 2    NARCOTICS    POSS: HEROIN(BRN/TAN)             SIDEWALK    True
# 3      ASSAULT                   SIMPLE            APARTMENT   False
# 4     BURGLARY           FORCIBLE ENTRY            RESIDENCE   False
#
#    domestic  beat  district  ward  community_area fbi_code  x_coordinate  \
# 0      True   924       9.0  12.0            61.0      08B     1165074.0
# 1     False  1511      15.0  29.0            25.0       06     1138875.0
# 2     False  1412      14.0  35.0            21.0       18     1152037.0
# 3      True  1522      15.0  28.0            25.0      08A     1141706.0
# 4     False   614       6.0  21.0            71.0       05     1168430.0
#
#    y_coordinate  year              updated_on   latitude  longitude  \
# 0     1875917.0  2015  02/10/2018 03:50:01 PM  41.815117 -87.670000
# 1     1904869.0  2015  02/10/2018 03:50:01 PM  41.895080 -87.765400
# 2     1920384.0  2015  02/10/2018 03:50:01 PM  41.937406 -87.716650
# 3     1900086.0  2015  02/10/2018 03:50:01 PM  41.881903 -87.755121
# 4     1850165.0  2015  02/10/2018 03:50:01 PM  41.744379 -87.658431
#
#                         location  day  month  day_of_week  time
# 0  (41.815117282, -87.669999562)    5      9            5    13
# 1  (41.895080471, -87.765400451)    4      9            4    11
# 2  (41.937405765, -87.716649687)    5      9            5    12
# 3  (41.881903443, -87.755121152)    5      9            5    13
# 4  (41.744378879, -87.658430635)    5      9            5    10

# %%
df_2015.isnull().sum()
# Out:
# id                         0
# case_number                0
# date                       0
# block                      0
# iucr                       0
# primary_type               0
# description                0
# location_description     561
# arrest                     0
# domestic                   0
# beat                       0
# district                   0
# ward                       2
# community_area             0
# fbi_code                   0
# x_coordinate            6649
# y_coordinate            6649
# year                       0
# updated_on                 0
# latitude                6649
# longitude               6649
# location                6649
# day                        0
# month                      0
# day_of_week                0
# time                       0
# dtype: int64

# %%
replace_to_zero(df_2015)

# %%
index_list = missing_row_loc(df_2015)
# Out:
# 6649

# %%
impute_data(df_2015, index_list)
# Out:
# Streaming output truncated to the last 5000 lines.
#
# S HALSTED ST
# (41.5420844, -87.6359687)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# W THOMAS ST
# (43.230666, -75.469829)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# S WESTERN AVE
# (43.5185145, -96.751124)
#
# W POTOMAC AVE
# (43.0958445, -88.0105462)
#
# S CALUMET AVE
# (41.7034033, -86.871671)
#
# S TORRENCE AVE
# (41.6397957, -87.5592843)
#
# W MAYPOLE AVE
# (41.8835952, -87.7087902)
#
# W 61ST ST
# (44.89257, -93.315002)
#
# S WELLS ST
# (38.0067095, -89.2477996)
#
# N CICERO AVE
# (42.0121975, -87.7479383)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# N SACRAMENTO AVE
# (39.341244, -74.483242)
#
# W 60TH ST
# (44.89423, -93.301147)
#
# N MAYFIELD AVE
# (34.1105096, -117.2902727)
#
# E BOWEN AVE
# (46.8021128, -100.7877832)
#
# S STONY ISLAND AVE
# (41.772423, -87.5862745)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# E 82ND ST
# (41.5041895, -81.6308342)
#
# N NEWCASTLE AVE
# (41.9223699, -87.7970239)
#
# W HARRISON ST
# (47.453523, -116.785825)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# W PL
# (39.0445999, -94.6029041)
#
# S PEORIA ST
# (39.5974063, -104.8480467)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# N FAIRFIELD AVE
# (40.417653, -120.640311)
#
# W WILSON AVE
# (47.6575559, -117.4351579)
#
# N MERRIMAC AVE
# (39.2169153, -94.6287743)
#
# N LONG AVE
# (31.872625, -102.526908)
#
# E PL
# (14.8370417, -89.14104361631954)
#
# W POLK ST
# (30.7116929, -94.9383233)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# S KEDZIE AVE
# (41.7315967, -87.7021544)
#
# W 63RD ST
# (41.7733805, -87.9889844)
#
# S ROCKWELL ST
# (33.3290958, -111.7293356)
#
# S CANAL ST
# (42.1979758, -72.6021589)
#
# S MERRILL AVE
# (47.1026257, -104.715102)
#
# S COLES AVE
# (41.7483376, -87.5491898)
#
# N RIDGE BLVD
# (38.5054097, -77.9726234)
#
# N WASHTENAW AVE
# (41.9253795, -87.6949927)
#
# W LELAND AVE
# (41.9666512, -87.7370944)
#
# S LA SALLE ST
# (41.742861, -88.3242315)
#
# W PENSACOLA AVE
# (41.9604024, -87.6892707)
#
# N STAVE ST
# (41.9193467, -87.6942569)
#
# S PULASKI RD
# (41.6803208, -87.7198931)
#
# S KOLIN AVE
# (41.6804633, -87.7282162)
#
# S CICERO AVE
# (41.8545413, -87.7443874)
#
# N WALLER AVE
# (41.8910824, -87.7677998)
#
# W ROOT ST
# (41.8190508, -87.6360402)
#
# S MAPLEWOOD AVE
# (36.0250954, -95.9064784)
#
# E 64TH ST
# (25.8805547, -80.2813052)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# S KARLOV AVE
# (41.7139045, -87.7235728)
#
# W MONTVALE AVE
# (35.2007361, -111.6600613)
#
# S EVANS AVE
# (35.509722, -97.9558699)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# S HALSTED ST
# (41.5420844, -87.6359687)
#
# W ROOSEVELT RD
# (41.8568563, -88.1736282)
#
# S BISHOP ST
# (39.5665983, -76.9892851)
#
# N KEYSTONE AVE
# (42.0001236, -76.5351751)
#
# S LAKE PARK AVE
# (41.5348577, -87.2596604)
#
# S DREXEL BLVD
# (35.4636206, -97.5703073)
#
# S PULASKI RD
# (41.6803208, -87.7198931)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# E 47TH DR
# (32.6426596, -114.3973967)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# S INGLESIDE AVE
# (41.7403543, -87.601287)
#
# S YALE AVE
# (36.0765216, -95.9221167)
#
# S ARTESIAN AVE
# (34.0977413, -117.3182866)
#
# W 74TH ST
# (40.780251, -73.9814398)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# S OAKENWALD AVE
# (41.8176178, -87.5980256)
#
# S WENTWORTH AVE
# (42.9981308, -87.8894434)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# W WELLINGTON AVE
# (38.1838186, -85.7649883)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# E ST
# (50.4738724, 4.2358174)
#
# S WOLCOTT AVE
# (41.8741687, -87.6740297)
#
# S LOOMIS BLVD
# (41.7570599, -87.6587609)
#
# N HOYNE AVE
# (41.9550717, -87.6812061)
#
# N WABASH AVE
# (41.1450949, -87.8658414)
#
# N Hampden Ct
# (41.9327766, -87.6424927)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# N SACRAMENTO AVE
# (39.341244, -74.483242)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# S CICERO AVE
# (41.8545413, -87.7443874)
#
# S JEFFERY BLVD
# (41.7479785, -87.5759176)
#
# E 81ST ST
# (41.4803912, -81.6310758)
#
# W FARWELL AVE
# (42.0067765, -87.6605207)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# W DIVISION ST
# (38.2597099, -87.9979169)
#
# W FOSTER AVE
# (41.975528, -87.7281106)
#
# N CENTRAL AVE
# (35.7718102, -91.6557941)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# W ESTES AVE
# (32.008665, -102.081306)
#
# W 62ND ST
# (44.8909522, -93.3054532)
#
# W 79TH ST
# (40.7849838, -73.9826637)
#
# N MONITOR AVE
# (41.9791477, -87.7744717)
#
# N NAGLE AVE
# (41.9200303, -87.7865552)
#
# W 59TH ST
# (40.7646364, -73.9737661)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# S ALBANY AVE
# (27.932852, -82.480986)
#
# W MELROSE ST
# (40.667262, -73.698695)
#
# S CANAL ST
# (42.1979758, -72.6021589)
#
# W 31ST ST
# (44.9466054, -93.2862078)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# N SACRAMENTO AVE
# (39.341244, -74.483242)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# W 69TH PL
# (25.8853991, -80.3477838)
#
# S HALSTED ST
# (41.5420844, -87.6359687)
#
# W ADDISON ST
# (42.226415, -84.406033)
#
# W LAKE ST
# (41.8877192, -87.7651226)
#
# W ADDISON ST
# (42.226415, -84.406033)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# S KARLOV AVE
# (41.7139045, -87.7235728)
#
# W 92ND ST
# (38.9630308, -94.6160841)
#
# W ST
# (55.8497133, -4.2656724)
#
# W ADDISON ST
# (42.226415, -84.406033)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# S GREEN ST
# (37.8040878, -87.6368672)
#
# S WOLCOTT AVE
# (41.8741687, -87.6740297)
#
# S CHAMPLAIN AVE
# (32.1827548, -110.8194486)
#
# W SUPERIOR ST
# (40.857308, -96.805534)
#
# E 45TH PL
# (36.097638, -95.7848888)
#
# S LUELLA AVE
# (41.7589872, -87.5700366)
#
# W ERIE ST
# (33.3076026, -111.9043792)
#
# W 63RD PL
# (25.8801129, -80.3380563)
#
# N HONORE ST
# (41.9765479, -87.6754559)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# N CALIFORNIA AVE
# (33.9287659, -116.9813763)
#
# W 47TH ST
# (40.7580163, -73.9817975)
#
# N SACRAMENTO BLVD
# (41.889664, -87.7013745)
#
# S TRIPP AVE
# (41.663533, -87.72595)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S TROY ST
# (42.4897468, -83.1419423)
#
# W WILCOX ST
# (39.7729655, -86.2196271)
#
# N CALIFORNIA AVE
# (33.9287659, -116.9813763)
#
# N HARLEM AVE
# (37.093364, -94.529365)
#
# S LAKE PARK AVE
# (41.5348577, -87.2596604)
#
# W PL
# (39.0445999, -94.6029041)
#
# W ARCHER AVE
# (40.5846442, -90.9722443)
#
# W FULTON BLVD
# (41.8864528, -87.7038266)
#
# S SEELEY AVE
# (42.2886768, -89.633005)
#
# W ST
# (55.8497133, -4.2656724)
#
# N MOZART ST
# (41.963078, -87.699749)
#
# S CALIFORNIA AVE
# (34.1163848, -118.0008539)
#
# N LECLAIRE AVE
# (41.935091, -87.7540962)
#
# W SCHUBERT AVE
# (41.921548, -88.096436)
#
# E 52ND ST
# (40.7542669, -73.9631956)
#
# N DOVER ST
# (35.259544, -77.561226)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W HARRISON ST
# (47.453523, -116.785825)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# S CREGIER AVE
# (41.7663619, -87.5812232)
#
# N MENARD AVE
# (41.8914776, -87.7700234)
#
# W DEVON AVE
# (41.9973572, -87.7114381)
#
# W CERMAK RD
# (41.8495374, -87.849713)
#
# N LARAMIE AVE
# (41.8954167, -87.7556069)
#
# W 77TH ST
# (39.7052739, -74.134883)
#
# W CERMAK RD
# (41.8495374, -87.849713)
#
# W TOUHY AVE
# (42.0118322, -87.7491207)
#
# S CENTRAL PARK AVE
# (41.7169517, -87.7114806)
#
# N HUMBOLDT BLVD
# (43.0638817, -87.8978425)
#
# S RACINE AVE
# (42.9427005, -88.1582854)
#
# S LUNA AVE
# (41.8018752, -87.761324)
#
# S HAMLIN AVE
# (42.0088243, -87.8504392)
#
# S HALSTED ST
# (41.5420844, -87.6359687)
#
# W FLETCHER ST
# (28.324413, -81.40576)
#
# S ESCANABA AVE
# (41.7482723, -87.55405)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# S WALLACE ST
# (38.6625346, -87.3019057)
#
# W ST
# (55.8497133, -4.2656724)
#
# N AUSTIN BLVD
# (41.8969924, -87.7752014)
#
# E 53RD ST
# (40.7580248, -73.9701634)
#
# E WALTON ST
# (33.0918832, -83.2257331)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# W 99TH ST
# (39.9322467, -86.2334767)
#
# S WINCHESTER AVE
# (46.406387, -105.830479)
#
# S MERRILL AVE
# (47.1026257, -104.715102)
#
# S EAST END AVE
# (40.7774069, -73.943042)
#
# E ST
# (50.4738724, 4.2358174)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# W DEVON AVE
# (41.9973572, -87.7114381)
#
# W IRVING PARK RD
# (41.953826, -87.7116755)
#
# S WENTWORTH AVE
# (42.9981308, -87.8894434)
#
# W WINDSOR AVE
# (33.4760021, -112.3092496)
#
# N Janssen Ave
# (41.9725741, -87.6667373)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# S ARCHER AVE
# (41.6335223, -88.0133585)
#
# S THROOP ST
# (41.7467867, -87.6560654)
#
# W 47TH ST
# (40.7580163, -73.9817975)
#
# E ST
# (50.4738724, 4.2358174)
#
# N PULASKI RD
# (41.9640877, -87.7278964)
#
# S MOZART ST
# (41.726308, -87.6933241)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# S WOLCOTT AVE
# (41.8741687, -87.6740297)
#
# S PARKSIDE AVE
# (34.0213373, -117.6290334)
#
# W RANDOLPH ST
# (36.2743344, -90.9816148)
#
# N LOWELL AVE
# (43.051309, -76.184402)
#
# W 61ST ST
# (44.89257, -93.315002)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# N NATCHEZ AVE
# (41.9548213, -87.7893155)
#
# S YATES BLVD
# (41.7408204, -87.5660877)
#
# W RICE ST
# (35.5516747, -80.6218475)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# S BUFFALO AVE
# (31.4608364, -96.0651776)
#
# N KILPATRICK AVE
# (41.9699316, -87.74405)
#
# N OAK PARK AVE
# (41.9071844, -87.7950033)
#
# S EGGLESTON AVE
# (35.407396, -97.5137083)
#
# S PARNELL AVE
# (41.6335259, -87.6353874)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# N SPRINGFIELD AVE
# (41.9646307, -87.7254887)
#
# N LUNA AVE
# (34.454345, -119.281645)
#
# N CENTRAL AVE
# (35.7718102, -91.6557941)
#
# W LUNT AVE
# (42.0077782, -87.8200486)
#
# W SUPERIOR ST
# (40.857308, -96.805534)
#
# W ADDISON ST
# (42.226415, -84.406033)
#
# N FAIRFIELD AVE
# (40.417653, -120.640311)
#
# W PENSACOLA AVE
# (41.9604024, -87.6892707)
#
# W PERSHING RD
# (39.8764731, -88.9678636)
#
# N VINE ST
# (39.4096607, -88.8046073)
#
# W WARREN BLVD
# (41.8823807, -87.6651175)
#
# S BISHOP ST
# (39.5665983, -76.9892851)
#
# N SHEFFIELD AVE
# (43.1085525, -87.8984732)
#
# W 31ST ST
# (44.9466054, -93.2862078)
#
# W CONGRESS PKWY
# (41.8750866, -87.6539866)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# W WALNUT ST
# (31.8085297, -97.0935238)
#
# S MARQUETTE AVE
# (41.6317592, -87.5567079)
#
# E GOETHE ST
# (41.9058343, -87.6272838)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# N ELSTON AVE
# (41.9624991, -87.731967)
#
# W BERWYN AVE
# (41.9775394, -87.712376)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W 62ND PL
# (25.879219, -80.337529)
#
# W WARNER AVE
# (36.8356029, -119.8173025)
#
# N LOWELL AVE
# (43.051309, -76.184402)
#
# N AUSTIN AVE
# (41.912831, -87.7753338)
#
# W ST PAUL AVE
# (43.0347877, -87.9278248)
#
# N KEELER AVE
# (31.890888, -102.393391)
#
# N PINE GROVE AVE
# (41.9529308, -87.6478914)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# S LUELLA AVE
# (41.7589872, -87.5700366)
#
# N KILDARE AVE
# (41.9718061, -87.7355466)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# S ALBANY AVE
# (27.932852, -82.480986)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# E 65TH PL
# (39.876728, -86.063538)
#
# S STONY ISLAND AVE
# (41.772423, -87.5862745)
#
# N LOREL AVE
# (41.8840101, -87.7588689)
#
# W HILL ST
# (50.8300933, -0.1444975)
#
# S CORNELL AVE
# (42.119526, -87.95127)
#
# W ROOSEVELT RD
# (41.8568563, -88.1736282)
#
# N LAWLER AVE
# (41.9186896, -87.7523027)
#
# S TALMAN AVE
# (41.8617849, -87.692024)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# W ADDISON ST
# (42.226415, -84.406033)
#
# N ROGERS AVE
# (42.118891, -76.046551)
#
# N NOBLE ST
# (33.7944831, -117.8022079)
#
# S VINCENNES AVE
# (41.6979977, -87.6592612)
#
# N LARAMIE AVE
# (41.8954167, -87.7556069)
#
# W 65TH ST
# (34.6902193, -92.3298401)
#
# S DREXEL AVE
# (33.369843, -111.623825)
#
# N LOCKWOOD AVE
# (41.6979589, -83.5699941)
#
# S CALUMET AVE
# (41.7034033, -86.871671)
#
# N CICERO AVE
# (42.0121975, -87.7479383)
#
# W 40TH ST
# (30.3041337, -97.7342249)
#
# N WESTERN AVE
# (35.5293143, -97.5298153)
#
# N STATE ST
# (44.619052, -75.408869)
#
# N NOBLE ST
# (33.7944831, -117.8022079)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# S STONY ISLAND AVE
# (41.772423, -87.5862745)
#
# W POLK ST
# (30.7116929, -94.9383233)
#
# E 80TH ST
# (39.706875, -74.132378)
#
# S CLINTON ST
# (38.5332401, -89.705132)
#
# S BLUE ISLAND AVE
# (41.8541923, -87.6641634)
#
# S WOODLAWN AVE
# (41.7812374, -87.5962214)
#
# S MARSHFIELD AVE
# (41.8093553, -87.6662057)
#
# E 96TH ST
# (40.782958, -73.943852)
#
# N BERNARD ST
# (41.9720734, -87.7146943)
#
# W TAYLOR ST
# (41.3837633, -75.7166377)
#
# S PARNELL AVE
# (41.6335259, -87.6353874)
#
# W 59TH ST
# (40.7646364, -73.9737661)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# S NORMAL AVE
# (37.720105, -89.21769)
#
# E ST
# (50.4738724, 4.2358174)
#
# S ESSEX AVE
# (39.3133874, -76.4565138)
#
# N RIDGEWAY AVE
# (41.9954911, -87.7227208)
#
# W PL
# (39.0445999, -94.6029041)
#
# W 41ST ST
# (43.5148333, -96.769579)
#
# W CORTEZ ST
# (33.5897649, -112.4664308)
#
# E 73RD ST
# (32.0274706, -81.1097986)
#
# W POLK ST
# (30.7116929, -94.9383233)
#
# S ALBANY AVE
# (27.932852, -82.480986)
#
# E ST
# (50.4738724, 4.2358174)
#
# S SAGINAW AVE
# (41.6427026, -87.5580689)
#
# N CLYBOURN AVE
# (41.9273774, -87.6724654)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W 99TH ST
# (39.9322467, -86.2334767)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# S BURNHAM AVE
# (41.6423104, -87.5396238)
#
# W CUYLER AVE
# (41.9551763, -87.6742845)
#
# N LINCOLN AVE
# (45.660956, -122.6824777)
#
# N WELLS ST
# (30.831592, -83.286031)
#
# W ST
# (55.8497133, -4.2656724)
#
# W 66TH ST
# (40.7733596, -73.9809918)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# S WALLACE ST
# (38.6625346, -87.3019057)
#
# S MARQUETTE AVE
# (41.6317592, -87.5567079)
#
# N AUSTIN AVE
# (41.912831, -87.7753338)
#
# W IRVING PARK RD
# (41.953826, -87.7116755)
#
# S MARSHFIELD AVE
# (41.8093553, -87.6662057)
#
# W ADDISON ST
# (42.226415, -84.406033)
#
# N OAKLEY AVE
# (41.664195, -86.124499)
#
# N HARLEM AVE
# (37.093364, -94.529365)
#
# W QUINCY ST
# (28.0541053, -81.9636599)
#
# S MOZART ST
# (41.726308, -87.6933241)
#
# E ST
# (50.4738724, 4.2358174)
#
# S COMMERCIAL AVE
# (41.7141047, -89.3341986)
#
# W 65TH ST
# (34.6902193, -92.3298401)
#
# W COULTER ST
# (40.0260654, -75.1778327)
#
# W GLADYS AVE
# (41.915226, -87.959294)
#
# S KEDZIE AVE
# (41.7315967, -87.7021544)
#
# S STEWART AVE
# (28.290846, -81.4066339)
#
# S WASHTENAW AVE
# (41.8244476, -87.6922106)
#
# W LEXINGTON ST
# (39.0325997, -97.5948929)
#
# S HONORE ST
# (41.8267808, -87.6715176)
#
# N OZARK AVE
# (37.2286508, -93.286646)
#
# N MARMORA AVE
# (41.9567321, -87.7744508)
#
# S CONSTANCE AVE
# (39.1322267, -86.4965916)
#
# N SPAULDING AVE
# (41.9543894, -87.7104772)
#
# N CENTRAL AVE
# (35.7718102, -91.6557941)
#
# W WALNUT ST
# (31.8085297, -97.0935238)
#
# S TROY ST
# (42.4897468, -83.1419423)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# S RACINE AVE
# (42.9427005, -88.1582854)
#
# S FAIRFIELD AVE
# (41.8828928, -88.0058916)
#
# S ESSEX AVE
# (39.3133874, -76.4565138)
#
# N SPAULDING AVE
# (41.9543894, -87.7104772)
#
# S LA CROSSE AVE
# (41.659632, -87.7403304)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# S DEARBORN ST
# (47.5958836, -122.318572)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# N LAWLER AVE
# (41.9186896, -87.7523027)
#
# E 74TH ST
# (40.7710532, -73.9596512)
#
# S ABERDEEN ST
# (35.7300766, -95.3526173)
#
# W 62ND PL
# (25.879219, -80.337529)
#
# N CLYBOURN AVE
# (41.9273774, -87.6724654)
#
# E ST
# (50.4738724, 4.2358174)
#
# N KIMBALL AVE
# (32.948407, -97.1167804)
#
# S EUCLID AVE
# (43.5904697, -83.9155365)
#
# S CHAMPLAIN AVE
# (32.1827548, -110.8194486)
#
# W ILLINOIS ST
# (41.862092, -88.108188)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# E ST
# (50.4738724, 4.2358174)
#
# W 60TH ST
# (44.89423, -93.301147)
#
# N KILPATRICK AVE
# (41.9699316, -87.74405)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# S ELIZABETH ST
# (40.727094, -84.106756)
#
# S SOUTH SHORE DR
# (41.7687175, -87.5665152)
#
# W 26TH ST
# (41.8444628, -87.7092909)
#
# S OAKLEY AVE
# (41.6631708, -86.1244023)
#
# S PAULINA ST
# (41.878849, -87.6692204)
#
# S SEELEY AVE
# (42.2886768, -89.633005)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# E RANDOLPH ST
# (39.430644, -96.7584772)
#
# N ELAINE PL
# (41.944742, -87.6477153)
#
# E SUPERIOR ST
# (41.082802, -85.1375483)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# W PL
# (39.0445999, -94.6029041)
#
# W MARQUETTE RD
# (41.7726852, -87.6253898)
#
# S MERRILL AVE
# (47.1026257, -104.715102)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# N ST LOUIS AVE
# (41.9727203, -87.7159449)
#
# N KEDVALE AVE
# (41.9640717, -87.7315451)
#
# S WESTERN AVE
# (43.5185145, -96.751124)
#
# S WOOD ST
# (41.343196, -83.119849)
#
# N CLAREMONT AVE
# (36.106832, -80.228788)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# W GEORGE ST
# (55.8634318, -4.2657255)
#
# W 76TH ST
# (33.9707255, -118.2915697)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# N PULASKI RD
# (41.9640877, -87.7278964)
#
# S COTTAGE GROVE AVE
# (41.6856412, -87.6114137)
#
# S WOOD ST
# (41.343196, -83.119849)
#
# W 51ST ST
# (40.7597316, -73.9780866)
#
# S MAPLEWOOD AVE
# (36.0250954, -95.9064784)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# S HARVARD AVE
# (40.613458, -98.098577)
#
# W HARRISON ST
# (47.453523, -116.785825)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# S SPAULDING AVE
# (34.0288086, -118.3700242)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# N HERMITAGE AVE
# (40.232782, -74.780752)
#
# W Oakdale Ave
# (29.0407755, -81.3169917)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# S PHILLIPS AVE
# (43.513078, -96.7262166)
#
# S GREEN ST
# (37.8040878, -87.6368672)
#
# N LOCKWOOD AVE
# (41.6979589, -83.5699941)
#
# W PL
# (39.0445999, -94.6029041)
#
# W FULTON ST
# (40.6996535, -90.0114673)
#
# S SPAULDING AVE
# (34.0288086, -118.3700242)
#
# W GLADYS AVE
# (41.915226, -87.959294)
#
# S PEORIA ST
# (39.5974063, -104.8480467)
#
# W G6 ST
# (25.0400823, 55.1653528)
#
# N MULLIGAN AVE
# (41.9602275, -87.7855735)
#
# N WILTON AVE
# (42.42707, -88.094391)
#
# W WASHINGTON ST
# (40.194732, -85.391486)
#
# S CHAMPLAIN AVE
# (32.1827548, -110.8194486)
#
# S PRINCETON AVE
# (39.7884436, -75.1461365)
#
# W GLADYS AVE
# (41.915226, -87.959294)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# W IRVING PARK RD
# (41.953826, -87.7116755)
#
# W CERMAK RD
# (41.8495374, -87.849713)
#
# W BUENA AVE
# (41.9582205, -87.656241)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# W ST
# (55.8497133, -4.2656724)
#
# N BROADWAY
# (40.9696948, -73.8844801)
#
# W 51ST ST
# (40.7597316, -73.9780866)
#
# N EASTLAKE TER
# (42.019648, -87.664686)
#
# W GRAND AVE
# (44.89992, -89.6139466)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# W VICTORIA ST
# (34.4152919, -119.7153286)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# W GRAND AVE
# (44.89992, -89.6139466)
#
# N GREENVIEW AVE
# (42.2840502, -89.1311541)
#
# N LINCOLN AVE
# (45.660956, -122.6824777)
#
# S UNION AVE
# (47.2491253, -122.4836389)
#
# S CALUMET AVE
# (41.7034033, -86.871671)
#
# S MARSHFIELD AVE
# (41.8093553, -87.6662057)
#
# S ARCHER AVE
# (41.6335223, -88.0133585)
#
# S OGLESBY AVE
# (41.7448277, -87.5673518)
#
# E 79TH ST
# (40.7742888, -73.9572899)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# S PAULINA ST
# (41.878849, -87.6692204)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# E ONTARIO ST
# (42.9988209, -87.8882358)
#
# N BROADWAY
# (40.9696948, -73.8844801)
#
# E 89TH ST
# (40.7778572, -73.9457131)
#
# S KEATING AVE
# (33.3664683, -111.8640276)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# N COLUMBUS DR
# (30.5692605, -85.1366536)
#
# S CARPENTER ST
# (35.240268, -81.338339)
#
# S FAIRFIELD AVE
# (41.8828928, -88.0058916)
#
# W 65TH PL
# (39.876, -86.192027)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# W HUBBARD ST
# (41.7159012, -89.3389805)
#
# N ROCKWELL ST
# (33.3744844, -111.7302071)
#
# W CONGRESS PKWY
# (41.8750866, -87.6539866)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# N KEDVALE AVE
# (41.9640717, -87.7315451)
#
# W ST
# (55.8497133, -4.2656724)
#
# N RICHMOND ST
# (41.9557758, -87.7019847)
#
# W WACKER DR
# (30.4717592, -84.349793)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# W CUYLER AVE
# (41.9551763, -87.6742845)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# S SOUTH SHORE DR
# (41.7687175, -87.5665152)
#
# S JUSTINE ST
# (41.6714397, -87.6599691)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# S AVENUE J
# (34.1782421, -103.3451898)
#
# W WOLFRAM ST
# (41.9335036, -87.6563169)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# S JUSTINE ST
# (41.6714397, -87.6599691)
#
# S CAMPBELL AVE
# (37.1712552, -93.2953919)
#
# W LEXINGTON ST
# (39.0325997, -97.5948929)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# S CRANDON AVE
# (41.7625938, -87.5688755)
#
# W CORNELIA AVE
# (33.9618136, -98.6777071)
#
# S PERRY AVE
# (27.74589, -81.794657)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# N BROADWAY
# (40.9696948, -73.8844801)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# S PRINCETON AVE
# (39.7884436, -75.1461365)
#
# N MAGNOLIA AVE
# (29.1969846, -82.1365046)
#
# S DREXEL BLVD
# (35.4636206, -97.5703073)
#
# E 32ND ST
# (44.94472, -93.2368469)
#
# N LAWLER AVE
# (41.9186896, -87.7523027)
#
# W ST
# (55.8497133, -4.2656724)
#
# W BERENICE AVE
# (41.9494861, -87.7950096)
#
# S PHILLIPS AVE
# (43.513078, -96.7262166)
#
# S LOOMIS ST
# (41.769112, -88.14147)
#
# W BARRY AVE
# (36.8175627, -93.9243727)
#
# N MAGNOLIA AVE
# (29.1969846, -82.1365046)
#
# W 96TH ST
# (40.7928721, -73.967548)
#
# S WINCHESTER AVE
# (46.406387, -105.830479)
#
# N KEELER AVE
# (31.890888, -102.393391)
#
# N MAGNOLIA AVE
# (29.1969846, -82.1365046)
#
# S CAMPBELL AVE
# (37.1712552, -93.2953919)
#
# S CALUMET AVE
# (41.7034033, -86.871671)
#
# W CORTEZ ST
# (33.5897649, -112.4664308)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# S CALUMET AVE
# (41.7034033, -86.871671)
#
# S WASHTENAW AVE
# (41.8244476, -87.6922106)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# S MUSKEGON AVE
# (41.6308631, -87.5542799)
#
# W 69TH PL
# (25.8853991, -80.3477838)
#
# S PRINCETON AVE
# (39.7884436, -75.1461365)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# E ST
# (50.4738724, 4.2358174)
#
# S AVENUE O
# (30.567085, -98.28942)
#
# N DAYTON ST
# (43.1198845, -85.5544939)
#
# S KOSTNER AVE
# (41.6651721, -87.7289951)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# S YALE AVE
# (36.0765216, -95.9221167)
#
# S HOLLAND RD
# (43.2411071, -85.1085324)
#
# S DREXEL BLVD
# (35.4636206, -97.5703073)
#
# W 79TH ST
# (40.7849838, -73.9826637)
#
# S KIMBARK AVE
# (41.7673136, -87.5941382)
#
# S PRINCETON AVE
# (39.7884436, -75.1461365)
#
# E 55TH ST
# (40.7560064, -73.9614975)
#
# W 55TH ST
# (40.7692044, -73.9927944)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# S HOLLAND RD
# (43.2411071, -85.1085324)
#
# W HARRISON ST
# (47.453523, -116.785825)
#
# N MOZART ST
# (41.963078, -87.699749)
#
# W OHIO ST
# (40.646058, -83.609337)
#
# W 93RD ST
# (40.7920773, -73.9716551)
#
# S BISHOP ST
# (39.5665983, -76.9892851)
#
# S CICERO AVE
# (41.8545413, -87.7443874)
#
# N WESTERN AVE
# (35.5293143, -97.5298153)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# S NAGLE AVE
# (41.799668, -87.7829259)
#
# N KEDZIE AVE
# (41.981245, -87.7088348)
#
# E ERIE ST
# (33.3090107, -111.8198088)
#
# S HOLLAND RD
# (43.2411071, -85.1085324)
#
# N CLEVELAND AVE
# (30.344444, -95.0913629)
#
# W 13TH ST
# (40.5482226, -85.6954353)
#
# S SANGAMON ST
# (39.5902655, -89.7359101)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# N MOBILE AVE
# (35.2845786, -93.1181537)
#
# E DELAWARE PL
# (41.8992723, -87.6202196)
#
# W 78TH ST
# (44.8646695, -93.5812403)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# S HOYNE AVE
# (41.8228899, -87.6774807)
#
# W 53RD PL
# (25.87113, -80.327087)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# S EGGLESTON AVE
# (35.407396, -97.5137083)
#
# S MONITOR AVE
# (41.8023373, -87.7691002)
#
# W DOUGLAS BLVD
# (41.8629927, -87.7029508)
#
# N JEFFERSON ST
# (43.572607, -76.123675)
#
# S EMERALD AVE
# (33.3965996, -111.8035831)
#
# S ROCKWELL ST
# (33.3290958, -111.7293356)
#
# S LAVERGNE AVE
# (41.6916676, -87.7446407)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# W RANDOLPH ST
# (36.2743344, -90.9816148)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# W TAYLOR ST
# (41.3837633, -75.7166377)
#
# E ST
# (50.4738724, 4.2358174)
#
# E OHIO ST
# (40.601786, -84.084445)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# W ADDISON ST
# (42.226415, -84.406033)
#
# S WENTWORTH AVE
# (42.9981308, -87.8894434)
#
# W PENSACOLA AVE
# (41.9604024, -87.6892707)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# E 79TH ST
# (40.7742888, -73.9572899)
#
# N STATE ST
# (44.619052, -75.408869)
#
# W ST
# (55.8497133, -4.2656724)
#
# S EVANS AVE
# (35.509722, -97.9558699)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# E 84TH ST
# (40.6411761, -73.914588)
#
# N LEAMINGTON AVE
# (41.8986064, -87.7544655)
#
# S SOUTH SHORE DR
# (41.7687175, -87.5665152)
#
# N ST LOUIS AVE
# (41.9727203, -87.7159449)
#
# S OAKENWALD AVE
# (41.8176178, -87.5980256)
#
# S OAKLEY AVE
# (41.6631708, -86.1244023)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# S MAPLEWOOD AVE
# (36.0250954, -95.9064784)
#
# W 35TH PL
# (39.818328, -86.271661)
#
# N LECLAIRE AVE
# (41.935091, -87.7540962)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# W 22ND PL
# (30.188365, -85.710205)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# N LATROBE AVE
# (41.9852199, -87.7604579)
#
# S GREEN ST
# (37.8040878, -87.6368672)
#
# N FRANCISCO AVE
# (26.2217801, -98.3199932)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S MUSKEGON AVE
# (41.6308631, -87.5542799)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# S ANTHONY AVE
# (37.149086, -98.028778)
#
# S CALIFORNIA AVE
# (34.1163848, -118.0008539)
#
# N LA SALLE ST
# (30.398997, -96.0961872)
#
# W IRVING PARK RD
# (41.953826, -87.7116755)
#
# N WEST CIRCLE AVE
# (34.210465, -90.583813)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# N HERMITAGE AVE
# (40.232782, -74.780752)
#
# N NORMANDY AVE
# (32.3607574, -95.2956254)
#
# N LARAMIE AVE
# (41.8954167, -87.7556069)
#
# S WENTWORTH AVE
# (42.9981308, -87.8894434)
#
# S RACINE AVE
# (42.9427005, -88.1582854)
#
# W 91ST ST
# (41.7265995, -87.7948245)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# S CHAMPLAIN AVE
# (32.1827548, -110.8194486)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# N KEDZIE BLVD
# (41.9245939, -87.7072256)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# W POTOMAC AVE
# (43.0958445, -88.0105462)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# W ERIE ST
# (33.3076026, -111.9043792)
#
# W ROOSEVELT RD
# (41.8568563, -88.1736282)
#
# W FULTON ST
# (40.6996535, -90.0114673)
#
# W 15TH ST
# (44.9689141, -93.2867103)
#
# W 68TH ST
# (36.065546, -95.9981956)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# N ASTOR ST
# (41.0402327, -73.8726946)
#
# N CENTRAL AVE
# (35.7718102, -91.6557941)
#
# W IRVING PARK RD
# (41.953826, -87.7116755)
#
# S RICHMOND ST
# (44.8899249, -88.3024977)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# S HARDING AVE
# (36.6834759, -119.7343476)
#
# W 99TH ST
# (39.9322467, -86.2334767)
#
# N KEDVALE AVE
# (41.9640717, -87.7315451)
#
# S SEELEY AVE
# (42.2886768, -89.633005)
#
# W DEVON AVE
# (41.9973572, -87.7114381)
#
# N BROADWAY
# (40.9696948, -73.8844801)
#
# S BISHOP ST
# (39.5665983, -76.9892851)
#
# N BROADWAY
# (40.9696948, -73.8844801)
#
# S YALE AVE
# (36.0765216, -95.9221167)
#
# S FEDERAL ST
# (38.443357, -78.870308)
#
# S LAKE PARK AVE
# (41.5348577, -87.2596604)
#
# N SEDGWICK ST
# (37.693255, -97.36976)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# E MONROE ST
# (38.305137, -89.992146)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# W THOMAS ST
# (43.230666, -75.469829)
#
# S VERNON AVE
# (32.72251, -96.836774)
#
# S EBERHART AVE
# (43.822127, -84.748397)
#
# W LAKE ST
# (41.8877192, -87.7651226)
#
# W 78TH ST
# (44.8646695, -93.5812403)
#
# S VINCENNES AVE
# (41.6979977, -87.6592612)
#
# S FEDERAL ST
# (38.443357, -78.870308)
#
# S WOOD ST
# (41.343196, -83.119849)
#
# W HARRISON ST
# (47.453523, -116.785825)
#
# S PAULINA ST
# (41.878849, -87.6692204)
#
# W IRVING PARK RD
# (41.953826, -87.7116755)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# S COTTAGE GROVE AVE
# (41.6856412, -87.6114137)
#
# W CORTEZ ST
# (33.5897649, -112.4664308)
#
# S MANISTEE AVE
# (41.6390183, -87.5555637)
#
# S PERRY AVE
# (27.74589, -81.794657)
#
# E 53RD ST
# (40.7580248, -73.9701634)
#
# S PHILLIPS AVE
# (43.513078, -96.7262166)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# N HARLEM AVE
# (37.093364, -94.529365)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# W EDGEWATER AVE
# (41.9859428, -87.6699435)
#
# S STONY ISLAND AVE
# (41.772423, -87.5862745)
#
# S Harper Ave
# (33.3743982, -111.6339155)
#
# N RIDGEWAY AVE
# (41.9954911, -87.7227208)
#
# S LARAMIE AVE
# (41.8447325, -87.753967)
#
# S PAULINA ST
# (41.878849, -87.6692204)
#
# S KOLIN AVE
# (41.6804633, -87.7282162)
#
# S OGLESBY AVE
# (41.7448277, -87.5673518)
#
# N JEFFERSON ST
# (43.572607, -76.123675)
#
# S AVENUE J
# (34.1782421, -103.3451898)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# N SHEFFIELD AVE
# (43.1085525, -87.8984732)
#
# S IRON ST
# (37.597239, -90.6307718)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# S WHIPPLE ST
# (42.6302929, -71.3004363)
#
# S HARDING AVE
# (36.6834759, -119.7343476)
#
# W 39TH PL
# (41.5471943, -87.3456365)
#
# N WACKER DR
# (40.759348, -89.6577155)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# S TROY ST
# (42.4897468, -83.1419423)
#
# N OPAL AVE
# (41.9378193, -87.8226158)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# S CARPENTER ST
# (35.240268, -81.338339)
#
# S LUELLA AVE
# (41.7589872, -87.5700366)
#
# S EMERALD AVE
# (33.3965996, -111.8035831)
#
# W ERIE ST
# (33.3076026, -111.9043792)
#
# S MENARD AVE
# (41.6600662, -87.7628355)
#
# E 71ST PL
# (36.0595852, -95.9162265)
#
# N WACKER DR
# (40.759348, -89.6577155)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# W FRANCIS PL
# (39.7539027, -105.0977458)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# N KOSTNER AVE
# (41.9869013, -87.7382889)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# E SOUTH WATER ST
# (41.8867796, -87.6225047)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# W 65TH ST
# (34.6902193, -92.3298401)
#
# W HARRISON ST
# (47.453523, -116.785825)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# S STEWART AVE
# (28.290846, -81.4066339)
#
# N LOREL AVE
# (41.8840101, -87.7588689)
#
# N LATROBE AVE
# (41.9852199, -87.7604579)
#
# S GREEN ST
# (37.8040878, -87.6368672)
#
# S PHILLIPS AVE
# (43.513078, -96.7262166)
#
# W PERSHING RD
# (39.8764731, -88.9678636)
#
# S JUSTINE ST
# (41.6714397, -87.6599691)
#
# N KEYSTONE AVE
# (42.0001236, -76.5351751)
#
# N BROADWAY
# (40.9696948, -73.8844801)
#
# E MARQUETTE RD
# (41.7727745, -87.6280678)
#
# S WHIPPLE ST
# (42.6302929, -71.3004363)
#
# S MERRILL AVE
# (47.1026257, -104.715102)
#
# S SOUTH SHORE DR
# (41.7687175, -87.5665152)
#
# S PERRY AVE
# (27.74589, -81.794657)
#
# S SOUTH SHORE DR
# (41.7687175, -87.5665152)
#
# N KEDVALE AVE
# (41.9640717, -87.7315451)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# W WINNEMAC AVE
# (41.9733819, -87.667451)
#
# W HARRISON ST
# (47.453523, -116.785825)
#
# W WALLEN AVE
# (42.001795, -87.7241161)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# N PULASKI RD
# (41.9640877, -87.7278964)
#
# W WINNEMAC AVE
# (41.9733819, -87.667451)
#
# E 75TH ST
# (38.985274, -94.4306042)
#
# W 50TH ST
# (40.7591258, -73.978595)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# W POTOMAC AVE
# (43.0958445, -88.0105462)
#
# S CORNELL AVE
# (42.119526, -87.95127)
#
# N RACINE AVE
# (43.003319, -88.216859)
#
# N LARAMIE AVE
# (41.8954167, -87.7556069)
#
# N PULASKI RD
# (41.9640877, -87.7278964)
#
# W FARWELL AVE
# (42.0067765, -87.6605207)
#
# W 65TH ST
# (34.6902193, -92.3298401)
#
# E 70TH ST
# (41.4801992, -81.640323)
#
# S WHIPPLE ST
# (42.6302929, -71.3004363)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# W EASTWOOD AVE
# (41.9656467, -87.7297858)
#
# W WALNUT ST
# (31.8085297, -97.0935238)
#
# N OAKLEY BLVD
# (41.893065, -87.684323)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# S BLUE ISLAND AVE
# (41.8541923, -87.6641634)
#
# W POPE JOHN PAUL II DR
# (41.815443, -87.7017808)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# N OAKLEY BLVD
# (41.893065, -87.684323)
#
# S HALSTED ST
# (41.5420844, -87.6359687)
#
# S COMMERCIAL AVE
# (41.7141047, -89.3341986)
#
# S OGLESBY AVE
# (41.7448277, -87.5673518)
#
# W LAWRENCE AVE
# (41.9683042, -87.7231431)
#
# S MELODY CT
# (41.8568761, -87.6336107)
#
# S VERNON AVE
# (32.72251, -96.836774)
#
# W WELLINGTON AVE
# (38.1838186, -85.7649883)
#
# S FRANCISCO AVE
# (37.6847697, -122.4009224)
#
# W POLK ST
# (30.7116929, -94.9383233)
#
# S JUSTINE ST
# (41.6714397, -87.6599691)
#
# S EDBROOKE AVE
# (41.6980924, -87.6196287)
#
# S PARNELL AVE
# (41.6335259, -87.6353874)
#
# W HIRSCH ST
# (41.9062185, -87.7313087)
#
# N NORDICA AVE
# (41.9489763, -87.8034519)
#
# S WOODLAWN AVE
# (41.7812374, -87.5962214)
#
# W 71ST ST
# (39.882403, -86.227212)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# S DOBSON AVE
# (41.764125, -87.5994316)
#
# N AVERS AVE
# (41.9628652, -87.724203)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# E 70TH ST
# (41.4801992, -81.640323)
#
# N NEWCASTLE AVE
# (41.9223699, -87.7970239)
#
# N SHEFFIELD AVE
# (43.1085525, -87.8984732)
#
# W HARRISON ST
# (47.453523, -116.785825)
#
# W 80TH ST
# (41.7486788, -87.6536729)
#
# S AVENUE L
# (31.5331944, -97.4407611)
#
# S WENTWORTH AVE
# (42.9981308, -87.8894434)
#
# N MARINE DR
# (33.8164549, -117.8300018)
#
# N PARKSIDE AVE
# (34.082432, -117.6296776)
#
# E MONROE ST
# (38.305137, -89.992146)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# S CLINTON ST
# (38.5332401, -89.705132)
#
# N NORTHWEST HWY
# (42.0193599, -87.8423973)
#
# N PARKSIDE AVE
# (34.082432, -117.6296776)
#
# W HADDON AVE
# (41.9025006, -87.6659391)
#
# W MEDILL AVE
# (41.9211428, -87.8794266)
#
# W ARMITAGE AVE
# (43.1023086, -87.9910021)
#
# W BERTEAU AVE
# (41.9561908, -87.8158422)
#
# W MONTROSE AVE
# (41.9607197, -87.7466474)
#
# S MARYLAND AVE
# (39.5941256, -75.9378606)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S KEDZIE AVE
# (41.7315967, -87.7021544)
#
# N WHIPPLE ST
# (41.9721178, -87.7049131)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# W HIRSCH ST
# (41.9062185, -87.7313087)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# W SHAKESPEARE AVE
# (44.1405017, -93.981392)
#
# S LAKE SHORE DR SB
# W 47TH ST
# (40.7580163, -73.9817975)
#
# S LOOMIS ST
# (41.769112, -88.14147)
#
# N RIDGEWAY AVE
# (41.9954911, -87.7227208)
#
# N MARMORA AVE
# (41.9567321, -87.7744508)
#
# S KARLOV AVE
# (41.7139045, -87.7235728)
#
# S BUFFALO AVE
# (31.4608364, -96.0651776)
#
# N CANAL ST
# (42.442134, -75.597522)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# S SPRINGFIELD AVE
# (40.6858039, -74.3274558)
#
# N MC VICKER AVE
# (41.7720642, -87.7721541)
#
# S WALLACE ST
# (38.6625346, -87.3019057)
#
# E RANDOLPH ST
# (39.430644, -96.7584772)
#
# S JEFFERSON ST
# (45.8680078, -112.0965554)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# E EASTGATE PL
# (41.8467971, -87.6178311)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S ELLIS AVE
# (35.309552, -78.616879)
#
# W ALTGELD ST
# (41.9262007, -87.8075454)
#
# S EWING AVE
# (32.7424571, -96.8126924)
#
# W 61ST ST
# (44.89257, -93.315002)
#
# E 83RD ST
# (41.5024109, -81.6295886)
#
# W WALNUT ST
# (31.8085297, -97.0935238)
#
# S CALUMET AVE
# (41.7034033, -86.871671)
#
# W Hubbard St
# (41.7159012, -89.3389805)
#
# S LEAVITT ST
# (41.8737714, -87.6813292)
#
# N KILDARE AVE
# (41.9718061, -87.7355466)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# S SPRINGFIELD AVE
# (40.6858039, -74.3274558)
#
# S MOZART ST
# (41.726308, -87.6933241)
#
# S RIDGEWAY AVE
# (35.61739, -82.3173401)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# S CENTRAL PARK AVE
# (41.7169517, -87.7114806)
#
# W BELLE PLAINE AVE
# (41.955062, -87.7887068)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# S CENTRAL PARK AVE
# (41.7169517, -87.7114806)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# W WALTON ST
# (33.089508, -83.237513)
#
# S LOOMIS ST
# (41.769112, -88.14147)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# W 79TH ST
# (40.7849838, -73.9826637)
#
# S CARPENTER ST
# (35.240268, -81.338339)
#
# N MASON AVE
# (42.354338, -85.244316)
#
# N KENTON AVE
# (41.9747987, -87.7430818)
#
# S SANGAMON ST
# (39.5902655, -89.7359101)
#
# S YALE AVE
# (36.0765216, -95.9221167)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# W POTOMAC AVE
# (43.0958445, -88.0105462)
#
# S MASON AVE
# (47.1898123, -122.4941429)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# N LINCOLN AVE
# (45.660956, -122.6824777)
#
# S DELANO CT E
# (41.8674021, -87.6325503)
#
# S STEWART AVE
# (28.290846, -81.4066339)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# S WESTERN AVE
# (43.5185145, -96.751124)
#
# S ARCHER AVE
# (41.6335223, -88.0133585)
#
# S RACINE AVE
# (42.9427005, -88.1582854)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# W 26TH ST
# (41.8444628, -87.7092909)
#
# S EXCHANGE AVE
# (35.0704184, -92.4212449)
#
# E BELLEVUE PL
# (41.901579, -87.6272014)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# W GRENSHAW ST
# (41.8679092, -87.6630252)
#
# E 46TH ST
# (44.917865, -93.2041653)
#
# W 69TH ST
# (44.8780766, -93.2858204)
#
# E GRAND AVE
# (36.7105116, -119.7874097)
#
# N TROY ST
# (41.9593759, -87.70697)
#
# S JEFFERY BLVD
# (41.7479785, -87.5759176)
#
# N RIDGEWAY AVE
# (41.9954911, -87.7227208)
#
# S ARCHER AVE
# (41.6335223, -88.0133585)
#
# N CENTRAL AVE
# (35.7718102, -91.6557941)
#
# E 49TH ST
# (44.9143071, -93.2651976)
#
# S GREEN ST
# (37.8040878, -87.6368672)
#
# N LA SALLE ST
# (30.398997, -96.0961872)
#
# W 61ST ST
# (44.89257, -93.315002)
#
# S EUCLID AVE
# (43.5904697, -83.9155365)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# S MAY ST
# (35.5997263, -77.5918349)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# W 21ST ST
# (44.961758, -93.306244)
#
# N NEW ENGLAND AVE
# (41.9380328, -87.7981462)
#
# E 53RD ST
# (40.7580248, -73.9701634)
#
# E ERIE ST
# (33.3090107, -111.8198088)
#
# W LAKE ST
# (41.8877192, -87.7651226)
#
# N CICERO AVE
# (42.0121975, -87.7479383)
#
# N CENTRAL PARK AVE
# (41.9751896, -87.7184185)
#
# N KEYSTONE AVE
# (42.0001236, -76.5351751)
#
# E 85TH PL
# (36.0395364, -95.9347648)
#
# S EMERALD AVE
# (33.3965996, -111.8035831)
#
# E ST
# (50.4738724, 4.2358174)
#
# N RAVENSWOOD AVE
# (41.9688187, -87.6741627)
#
# S BENNETT AVE
# (39.047033, -82.645968)
#
# W 76TH ST
# (33.9707255, -118.2915697)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# W CULLOM AVE
# (41.9590228, -87.7389563)
#
# N TRIPP AVE
# (41.9848527, -87.7341352)
#
# N ALBANY AVE
# (40.7076835, -73.465108)
#
# N DAMEN AVE
# (41.9744669, -87.6793492)
#
# S KILDARE AVE
# (41.6744106, -87.7275156)
#
# S TALMAN AVE
# (41.8617849, -87.692024)
#
# N PAULINA ST
# (41.9902949, -87.6714344)
#
# N DAMEN AVE
# (41.9744669, -87.6793492)
#
# W 92ND PL
# (41.4500313, -87.3867959)
#
# S GREEN ST
# (37.8040878, -87.6368672)
#
# N KEYSTONE AVE
# (42.0001236, -76.5351751)
#
# S WINCHESTER AVE
# (46.406387, -105.830479)
#
# S CARPENTER ST
# (35.240268, -81.338339)
#
# W WELLINGTON AVE
# (38.1838186, -85.7649883)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# S LA SALLE ST
# (41.742861, -88.3242315)
#
# S LEAVITT ST
# (41.8737714, -87.6813292)
#
# N CENTRAL AVE
# (35.7718102, -91.6557941)
#
# W POTOMAC AVE
# (43.0958445, -88.0105462)
#
# N LINDER AVE
# (43.4908412, -116.4138278)
#
# N MERRIMAC AVE
# (39.2169153, -94.6287743)
#
# N RACINE AVE
# (43.003319, -88.216859)
#
# W 68TH PL
# (25.8846371, -80.3531037)
#
# W 25TH ST
# (39.802821, -86.1734111)
#
# N DOVER ST
# (35.259544, -77.561226)
#
# N LARAMIE AVE
# (41.8954167, -87.7556069)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# S HOMAN AVE
# (41.6622485, -87.7046222)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# W Fargo Ave
# (36.3572713, -119.6489519)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# N AVERS AVE
# (41.9628652, -87.724203)
#
# E ST
# (50.4738724, 4.2358174)
#
# S EVANS AVE
# (35.509722, -97.9558699)
#
# N RUTHERFORD AVE
# (40.706973, -73.468891)
#
# N CUMBERLAND AVE
# (28.5746976, -81.5453944)
#
# W 74TH ST
# (40.780251, -73.9814398)
#
# N WINTHROP AVE
# (41.9873032, -87.6581226)
#
# W JARLATH ST
# (42.012664, -87.7262732)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# S UNION AVE
# (47.2491253, -122.4836389)
#
# S STEWART AVE
# (28.290846, -81.4066339)
#
# S COTTAGE GROVE AVE
# (41.6856412, -87.6114137)
#
# S AUSTIN BLVD
# (41.8690856, -87.7742324)
#
# S TALMAN AVE
# (41.8617849, -87.692024)
#
# S TALMAN AVE
# (41.8617849, -87.692024)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# E PL
# (14.8370417, -89.14104361631954)
#
# S BENNETT AVE
# (39.047033, -82.645968)
#
# N HERMITAGE AVE
# (40.232782, -74.780752)
#
# W WASHINGTON ST
# (40.194732, -85.391486)
#
# N RICHMOND ST
# (41.9557758, -87.7019847)
#
# S HALSTED ST
# (41.5420844, -87.6359687)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# S MONITOR AVE
# (41.8023373, -87.7691002)
#
# N RIDGEWAY AVE
# (41.9954911, -87.7227208)
#
# W COLUMBUS AVE
# (39.3034047, -85.2267268)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# S VERNON AVE
# (32.72251, -96.836774)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# W 60TH ST
# (44.89423, -93.301147)
#
# W 56TH ST
# (44.901509, -93.2991292)
#
# N LOREL AVE
# (41.8840101, -87.7588689)
#
# N LAMON AVE
# (41.9242164, -87.7487482)
#
# S RIDGEWOOD CT
# (37.1541375, -93.2404554)
#
# N MOODY AVE
# (27.9453048, -82.484032)
#
# S OAKLEY AVE
# (41.6631708, -86.1244023)
#
# N PULASKI RD
# (41.9640877, -87.7278964)
#
# N BELL AVE
# (32.2464153, -110.8940884)
#
# W 63RD ST
# (41.7733805, -87.9889844)
#
# S WOOD ST
# (41.343196, -83.119849)
#
# N LARAMIE AVE
# (41.8954167, -87.7556069)
#
# N LA SALLE DR
# (32.459967, -99.781336)
#
# W 40TH ST
# (30.3041337, -97.7342249)
#
# N CHRISTIANA AVE
# (41.9702394, -87.7121816)
#
# W 58TH ST
# (44.8978415, -93.2888067)
#
# N LOWELL AVE
# (43.051309, -76.184402)
#
# W GLENLAKE AVE
# (41.9920252, -87.7164771)
#
# W BERENICE AVE
# (41.9494861, -87.7950096)
#
# E 84TH PL
# (41.4637197, -87.3359496)
#
# N KOLMAR AVE
# (41.9710894, -87.7440319)
#
# S KENWOOD AVE
# (41.8060326, -87.5935411)
#
# N AVERS AVE
# (41.9628652, -87.724203)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# W 82ND ST
# (41.7450945, -87.6499675)
#
# S FAIRFIELD AVE
# (41.8828928, -88.0058916)
#
# S TRUMBULL AVE
# (41.666268, -87.7067038)
#
# S EMERALD AVE
# (33.3965996, -111.8035831)
#
# E OAKWOOD BLVD
# (41.8241108, -87.6043228)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# S STEWART AVE
# (28.290846, -81.4066339)
#
# S MARSHFIELD AVE
# (41.8093553, -87.6662057)
#
# S DELANO CT W
# (41.8676448, -87.6326338)
#
# N RICHMOND ST
# (41.9557758, -87.7019847)
#
# W HARRISON ST
# (47.453523, -116.785825)
#
# N LARAMIE AVE
# (41.8954167, -87.7556069)
#
# N HARLEM AVE
# (37.093364, -94.529365)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# W fullerton ave
# (41.923398, -87.9104238)
#
# N WASHTENAW AVE
# (41.9253795, -87.6949927)
#
# S MARYLAND AVE
# (39.5941256, -75.9378606)
#
# S GREENWOOD AVE
# (37.6199047, -96.228166)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# S NORMAL BLVD
# (41.7792236, -87.637511)
#
# N ST LOUIS AVE
# (41.9727203, -87.7159449)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# S ADA ST
# (44.9307182, -93.0759931)
#
# W ARTHUR AVE
# (42.9994824, -87.9518008)
#
# S EMERALD AVE
# (33.3965996, -111.8035831)
#
# S KEDZIE AVE
# (41.7315967, -87.7021544)
#
# W SUNNYSIDE AVE
# (41.9635312, -87.6603099)
#
# N JEFFERSON ST
# (43.572607, -76.123675)
#
# W WINONA ST
# (46.8469244, -92.0900123)
#
# W PERSHING RD
# (39.8764731, -88.9678636)
#
# W ARGYLE ST
# (57.8956842, -5.1630045)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# N HARLEM AVE
# (37.093364, -94.529365)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# W 26TH ST
# (41.8444628, -87.7092909)
#
# S PEORIA ST
# (39.5974063, -104.8480467)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# E 41ST ST
# (44.928696, -93.2276561)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# S LAWNDALE AVE
# (41.8425259, -87.7171839)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# W ADDISON ST
# (42.226415, -84.406033)
#
# N LOREL AVE
# (41.8840101, -87.7588689)
#
# N RACINE AVE
# (43.003319, -88.216859)
#
# N CHRISTIANA AVE
# (41.9702394, -87.7121816)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# N JERSEY AVE
# (41.992891, -87.7115505)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# W OHIO ST
# (40.646058, -83.609337)
#
# S GREEN ST
# (37.8040878, -87.6368672)
#
# S TRUMBULL AVE
# (41.666268, -87.7067038)
#
# W POTOMAC AVE
# (43.0958445, -88.0105462)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# S AVENUE L
# (31.5331944, -97.4407611)
#
# W OHIO ST
# (40.646058, -83.609337)
#
# W DIVISION ST
# (38.2597099, -87.9979169)
#
# S RACINE AVE
# (42.9427005, -88.1582854)
#
# N KENNETH AVE
# (41.9717719, -87.7392712)
#
# N WESTERN AVE
# (35.5293143, -97.5298153)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# N WESTERN AVE
# (35.5293143, -97.5298153)
#
# W SEIPP ST
# (41.7380126, -87.6947059)
#
# W ARMITAGE AVE
# (43.1023086, -87.9910021)
#
# W PL
# (39.0445999, -94.6029041)
#
# W AGATITE AVE
# (41.9619564, -87.7205109)
#
# W ARMITAGE AVE
# (43.1023086, -87.9910021)
#
# S HALSTED ST
# (41.5420844, -87.6359687)
#
# W 54TH ST
# (40.7692528, -73.9948535)
#
# W ST
# (55.8497133, -4.2656724)
#
# W MONTROSE AVE
# (41.9607197, -87.7466474)
#
# N KEDZIE AVE
# (41.981245, -87.7088348)
#
# S PAXTON AVE
# (41.7316571, -87.5707162)
#
# N MC VICKER AVE
# (41.7720642, -87.7721541)
#
# W ARCHER AVE
# (40.5846442, -90.9722443)
#
# W CERMAK RD
# (41.8495374, -87.849713)
#
# N MARMORA AVE
# (41.9567321, -87.7744508)
#
# W 83RD ST
# (41.7432634, -87.6499076)
#
# S BLUE ISLAND AVE
# (41.8541923, -87.6641634)
#
# W 63RD ST
# (41.7733805, -87.9889844)
#
# N ROCKWELL ST
# (33.3744844, -111.7302071)
#
# S AVENUE N
# (31.532975, -97.437499)
#
# W GRENSHAW ST
# (41.8679092, -87.6630252)
#
# W CARMEN AVE
# (41.9736044, -87.7374367)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# N ALTA VISTA TER
# (41.9526342, -87.6565354)
#
# S ARTESIAN AVE
# (34.0977413, -117.3182866)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# N HERMITAGE AVE
# (40.232782, -74.780752)
#
# E 77TH ST
# (36.0529109, -95.8831572)
#
# S PEORIA ST
# (39.5974063, -104.8480467)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# W MELROSE ST
# (40.667262, -73.698695)
#
# E ADAMS ST
# (40.191878, -85.381801)
#
# N LINDER AVE
# (43.4908412, -116.4138278)
#
# S SAWYER AVE
# (47.2288772, -122.4540806)
#
# S KEDVALE AVE
# (41.6474182, -87.7222793)
#
# W 55TH ST
# (40.7692044, -73.9927944)
#
# W 22ND PL
# (30.188365, -85.710205)
#
# N OAK PARK AVE
# (41.9071844, -87.7950033)
#
# S SACRAMENTO BLVD
# (41.877103, -87.7011017)
#
# W FRANKLIN BLVD
# (35.2598762, -81.214961)
#
# S MELVINA AVE
# (41.6593014, -87.7726964)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# W GLADYS AVE
# (41.915226, -87.959294)
#
# E 71ST PL
# (36.0595852, -95.9162265)
#
# N KNOX AVE
# (45.0350358, -93.3021408)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# N CANFIELD AVE
# (41.9789076, -87.8240646)
#
# W 81ST ST
# (41.7469141, -87.6500179)
#
# E 31ST ST
# (44.9466342, -93.276554)
#
# S DREXEL AVE
# (33.369843, -111.623825)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# S ALBANY AVE
# (27.932852, -82.480986)
#
# W 84TH ST
# (38.9742141, -94.857781)
#
# S ROCKWELL ST
# (33.3290958, -111.7293356)
#
# N LOREL AVE
# (41.8840101, -87.7588689)
#
# W 84TH ST
# (38.9742141, -94.857781)
#
# N RICHMOND ST
# (41.9557758, -87.7019847)
#
# S AVENUE M
# (31.773624, -97.579064)
#
# E 54TH ST
# (40.757381, -73.966702)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# E 68TH ST
# (36.064123, -95.9448098)
#
# S BENSLEY AVE
# (41.6390654, -87.5628808)
#
# W BERWYN AVE
# (41.9775394, -87.712376)
#
# N LATROBE AVE
# (41.9852199, -87.7604579)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# N HAMPDEN CT
# (41.9327766, -87.6424927)
#
# W GETTYSBURG ST
# (43.58047, -116.191094)
#
# W WILSON AVE
# (47.6575559, -117.4351579)
#
# W 83RD ST
# (41.7432634, -87.6499076)
#
# S PLYMOUTH CT
# (41.8740189, -87.6286848)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# N MC CLURG CT
# (30.332179, -82.799061)
#
# W TOUHY AVE
# (42.0118322, -87.7491207)
#
# W OGDEN AVE
# (32.341146, -86.3093)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# N LOCKWOOD AVE
# (41.6979589, -83.5699941)
#
# W COLUMBIA AVE
# (47.7106286, -117.421456)
#
# N KEDZIE AVE
# (41.981245, -87.7088348)
#
# E WALTON ST
# (33.0918832, -83.2257331)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# W LELAND AVE
# (41.9666512, -87.7370944)
#
# W ESTES AVE
# (32.008665, -102.081306)
#
# S ARCHER AVE
# (41.6335223, -88.0133585)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# S KIMBARK AVE
# (41.7673136, -87.5941382)
#
# S WALLACE ST
# (38.6625346, -87.3019057)
#
# N SACRAMENTO BLVD
# (41.889664, -87.7013745)
#
# E ST
# (50.4738724, 4.2358174)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# S EWING AVE
# (32.7424571, -96.8126924)
#
# S STEWART AVE
# (28.290846, -81.4066339)
#
# W HENDERSON ST
# (35.6845746, -80.4331586)
#
# N WINTHROP AVE
# (41.9873032, -87.6581226)
#
# W WASHINGTON ST
# (40.194732, -85.391486)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# W ERIE ST
# (33.3076026, -111.9043792)
#
# N KOLIN AVE
# (41.8840787, -87.7343473)
#
# W ST
# (55.8497133, -4.2656724)
#
# W HIRSCH ST
# (41.9062185, -87.7313087)
#
# S SACRAMENTO AVE
# (39.3373525, -74.4801189)
#
# S WINCHESTER AVE
# (46.406387, -105.830479)
#
# S CALIFORNIA AVE
# (34.1163848, -118.0008539)
#
# N MARMORA AVE
# (41.9567321, -87.7744508)
#
# W POTOMAC AVE
# (43.0958445, -88.0105462)
#
# N NATOMA AVE
# (43.6443386, -116.4245855)
#
# N LOVEJOY AVE
# (41.9752196, -87.7658729)
#
# S HALSTED ST
# (41.5420844, -87.6359687)
#
# W LAWRENCE AVE
# (41.9683042, -87.7231431)
#
# N NOBLE ST
# (33.7944831, -117.8022079)
#
# N HERMITAGE AVE
# (40.232782, -74.780752)
#
# W AUGUSTA BLVD
# (41.4210887, -87.732417)
#
# N PULASKI RD
# (41.9640877, -87.7278964)
#
# W ONTARIO ST
# (35.0943283, -85.3096809)
#
# N WAYNE AVE
# (40.055678, -75.393487)
#
# N LAWNDALE AVE
# (41.9592196, -87.720432)
#
# S ALBANY AVE
# (27.932852, -82.480986)
#
# S ADA ST
# (44.9307182, -93.0759931)
#
# S SHIELDS AVE
# (37.5470522, -77.4700211)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W 71ST ST
# (39.882403, -86.227212)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# S AUSTIN BLVD
# (41.8690856, -87.7742324)
#
# N RAVENSWOOD AVE
# (41.9688187, -87.6741627)
#
# S CLAREMONT AVE
# (39.096728, -94.442776)
#
# W ARTHINGTON ST
# (41.8700106, -87.7112288)
#
# W FLOURNOY ST
# (28.406267, -97.7593919)
#
# W 77TH ST
# (39.7052739, -74.134883)
#
# N HARLEM AVE
# (37.093364, -94.529365)
#
# N MELVINA AVE
# (42.0121329, -87.7817803)
#
# S DOBSON AVE
# (41.764125, -87.5994316)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# S PLYMOUTH CT
# (41.8740189, -87.6286848)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# S GREENWOOD AVE
# (37.6199047, -96.228166)
#
# W Briar Pl
# (41.9391149, -87.6468032)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# E MONROE ST
# (38.305137, -89.992146)
#
# E 82ND ST
# (41.5041895, -81.6308342)
#
# W WASHINGTON ST
# (40.194732, -85.391486)
#
# W LAKESIDE PL
# (42.0625044, -88.0999232)
#
# S BLACKSTONE AVE
# (41.78726, -87.881703)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# W ST JAMES PL
# (42.0859345, -88.0017581)
#
# S BALTIMORE AVE
# (40.083482, -74.040895)
#
# ...
#
# N POINT ST
# (37.8055427, -122.4218698)
#
# S GREEN ST
# (37.8040878, -87.6368672)
#
# W THOMAS ST
# (43.230666, -75.469829)
#
# W MAPLE ST
# (37.6800483, -97.4058021)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# S HARDING AVE
# (36.6834759, -119.7343476)
#
# S CLYDE AVE
# (28.2911755, -81.4131903)
#
# W PETERSON AVE
# (41.9903163, -87.7190017)
#
# N TALMAN AVE
# (41.9139404, -87.6934262)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# N LATROBE AVE
# (41.9852199, -87.7604579)
#
# W ALDINE AVE
# (41.9418061, -87.6487849)
#
# W TERMINAL ST
# (38.3711643, -88.065751)
#
# S EXCHANGE AVE
# (35.0704184, -92.4212449)
#
# S MOBILE AVE
# (41.6583825, -87.776142)
#
# S WHIPPLE ST
# (42.6302929, -71.3004363)
#
# N VIRGINIA AVE
# (36.739932, -79.930829)
#
# W PIERCE AVE
# (39.485878, -88.185641)
#
# S HONORE ST
# (41.8267808, -87.6715176)
#
# S WACKER DR
# (41.8753503, -87.6357587)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# S VERNON AVE
# (32.72251, -96.836774)
#
# S RIVERSIDE PLZ
# (41.87992545, -87.63872659087485)
#
# S BISHOP ST
# (39.5665983, -76.9892851)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# N SEDGWICK ST
# (37.693255, -97.36976)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# E MARQUETTE RD
# (41.7727745, -87.6280678)
#
# W MARQUETTE RD
# (41.7726852, -87.6253898)
#
# W PETERSON AVE
# (41.9903163, -87.7190017)
#
# N ASTOR ST
# (41.0402327, -73.8726946)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# S DRAKE AVE
# (41.8498569, -87.713702)
#
# N KEDZIE AVE
# (41.981245, -87.7088348)
#
# S HEATH AVE
# (41.8636338, -87.6843448)
#
# N LAMON AVE
# (41.9242164, -87.7487482)
#
# E 89TH ST
# (40.7778572, -73.9457131)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# E 96TH ST
# (40.782958, -73.943852)
#
# N MENARD AVE
# (41.8914776, -87.7700234)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# S BELL AVE
# (36.6728853, -120.1423994)
#
# S CLARK ST
# (44.955584, -90.795919)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# S WESTERN AVE
# (43.5185145, -96.751124)
#
# N CENTRAL AVE
# (35.7718102, -91.6557941)
#
# W MARQUETTE RD
# (41.7726852, -87.6253898)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# N LA SALLE ST
# (30.398997, -96.0961872)
#
# S ST LAWRENCE AVE
# (41.7682281, -87.6104913)
#
# N KEELER AVE
# (31.890888, -102.393391)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# W 60TH ST
# (44.89423, -93.301147)
#
# S DRAKE AVE
# (41.8498569, -87.713702)
#
# N WASHTENAW AVE
# (41.9253795, -87.6949927)
#
# E OHIO ST
# (40.601786, -84.084445)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# N GREENVIEW AVE
# (42.2840502, -89.1311541)
#
# S SAWYER AVE
# (47.2288772, -122.4540806)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# N WINNEBAGO AVE
# (41.9143693, -87.6852148)
#
# N HAMLIN AVE
# (41.9737701, -87.7232845)
#
# W MERCHANDISE MART PLZ
# (41.8879633, -87.6352443)
#
# E LAKE SHORE DR
# (42.358919, -88.0764399)
#
# W ROSCOE ST
# (41.9417774, -87.798255)
#
# S EAST END AVE
# (40.7774069, -73.943042)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# W WEST END AVE
# (41.8840066, -87.7595529)
#
# W CERMAK RD
# (41.8495374, -87.849713)
#
# W GRAND AVE
# (44.89992, -89.6139466)
#
# S KILPATRICK AVE
# (41.8149584, -87.7409068)
#
# S HONORE ST
# (41.8267808, -87.6715176)
#
# S LOTUS AVE
# (36.7105116, -119.7874097)
#
# N WASHTENAW AVE
# (41.9253795, -87.6949927)
#
# E 87TH ST
# (41.4677098, -81.6272505)
#
# S KIRKLAND AVE
# (33.1772716, -99.1742449)
#
# W MAYPOLE AVE
# (41.8835952, -87.7087902)
#
# N HAMLIN BLVD
# (41.8818123, -87.7208182)
#
# S CREGIER AVE
# (41.7663619, -87.5812232)
#
# E 46TH ST
# (44.917865, -93.2041653)
#
# W HAWTHORNE PL
# (28.816361, -82.5664011)
#
# N FAIRBANKS CT
# (41.8939932, -87.620286)
#
# W BLOOMINGDALE AVE
# (27.8936206, -82.2946314)
#
# W 18TH ST
# (39.041594, -96.8333437)
#
# N AUSTIN AVE
# (41.912831, -87.7753338)
#
# W CORNELIA AVE
# (33.9618136, -98.6777071)
#
# S KARLOV AVE
# (41.7139045, -87.7235728)
#
# W 40TH PL
# (25.858926, -80.284691)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# S HOMAN AVE
# (41.6622485, -87.7046222)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# N PULASKI RD
# (41.9640877, -87.7278964)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# W DIVERSEY PKWY
# (41.9323951, -87.6687745)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# W DEVON AVE
# (41.9973572, -87.7114381)
#
# N CLARENDON AVE
# (39.3347411, -74.4980139)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# W 65TH ST
# (34.6902193, -92.3298401)
#
# W DRUMMOND PL
# (41.9315035, -87.643809)
#
# W IOWA ST
# (43.0518372, -91.3949007)
#
# S VINCENNES AVE
# (41.6979977, -87.6592612)
#
# N CAMPBELL AVE
# (32.2527259, -110.9439424)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# N ORLEANS ST
# (34.8209213, -87.6356312)
#
# S ST LOUIS AVE
# (41.0219002, -87.7208064)
#
# S LOOMIS BLVD
# (41.7570599, -87.6587609)
#
# S PRINCETON AVE
# (39.7884436, -75.1461365)
#
# S WENTWORTH AVE
# (42.9981308, -87.8894434)
#
# S LOOMIS ST
# (41.769112, -88.14147)
#
# W CORTLAND ST
# (42.591483, -76.371899)
#
# W KENNEDY EXPY OB
# (40.642947899999996, -73.7793733748521)
#
# S COMMERCIAL AVE
# (41.7141047, -89.3341986)
#
# N KENNEDY EXPY OB
# (28.519230999999998, -80.64317239050752)
#
# W BEACH AVE
# (49.0253429, -122.8165082)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# N HAMLIN AVE
# (41.9737701, -87.7232845)
#
# W BERWYN AVE
# (41.9775394, -87.712376)
#
# N PAULINA ST
# (41.9902949, -87.6714344)
#
# S JEFFERY BLVD
# (41.7479785, -87.5759176)
#
# S MUSKEGON AVE
# (41.6308631, -87.5542799)
#
# S PRINCETON AVE
# (39.7884436, -75.1461365)
#
# W HOWARD ST
# (43.4469912, -92.2854434)
#
# N ST LOUIS AVE
# (41.9727203, -87.7159449)
#
# S ELLIS AVE
# (35.309552, -78.616879)
#
# W BRYN MAWR AVE
# (41.983045, -87.711304)
#
# N LARAMIE AVE
# (41.8954167, -87.7556069)
#
# W OHIO ST
# (40.646058, -83.609337)
#
# W BIRCHWOOD AVE
# (42.9399265, -87.9627232)
#
# E LOWER WACKER DR
# (41.8875576, -87.6174627)
#
# S EGGLESTON AVE
# (35.407396, -97.5137083)
#
# W Belmont Ave
# (40.839392, -96.722861)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# S KENTON AVE
# (41.6814568, -87.7334309)
#
# S AVENUE H
# (40.552806, -90.05225)
#
# N AVERS AVE
# (41.9628652, -87.724203)
#
# N AVERS AVE
# (41.9628652, -87.724203)
#
# W FOSTER AVE
# (41.975528, -87.7281106)
#
# W MENOMONEE ST
# (41.9147183, -87.6386952)
#
# W MYRTLE AVE
# (33.540846, -112.4051658)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# N KILDARE AVE
# (41.9718061, -87.7355466)
#
# N RIDGEWAY AVE
# (41.9954911, -87.7227208)
#
# W NORWOOD ST
# (37.110794, -92.420191)
#
# N MEADE AVE
# (38.8379256, -104.7960056)
#
# S ESSEX AVE
# (39.3133874, -76.4565138)
#
# E WACKER DR
# (41.8878388, -87.6190596)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# W POLK ST
# (30.7116929, -94.9383233)
#
# N MAJOR AVE
# (36.0352811, -114.9680661)
#
# N MASON AVE
# (42.354338, -85.244316)
#
# E MONROE ST
# (38.305137, -89.992146)
#
# S HYDE PARK BLVD
# (41.7978073, -87.5840054)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W PERSHING RD
# (39.8764731, -88.9678636)
#
# S KENNETH AVE
# (41.6814466, -87.7302028)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# N LINCOLN AVE
# (45.660956, -122.6824777)
#
# S OGLESBY AVE
# (41.7448277, -87.5673518)
#
# S KINGSTON AVE
# (36.044406, -95.9074742)
#
# N AVERS AVE
# (41.9628652, -87.724203)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# S MASON AVE
# (47.1898123, -122.4941429)
#
# W WALTON ST
# (33.089508, -83.237513)
#
# N LEAMINGTON AVE
# (41.8986064, -87.7544655)
#
# W 68TH ST
# (36.065546, -95.9981956)
#
# N WIELAND ST
# (41.9098507, -87.6356493)
#
# S EUCLID AVE
# (43.5904697, -83.9155365)
#
# N KEDVALE AVE
# (41.9640717, -87.7315451)
#
# W ERIE ST
# (33.3076026, -111.9043792)
#
# N Wabash Ave
# (41.1450949, -87.8658414)
#
# W DICKENS AVE
# (26.2215137, -98.1842927)
#
# S KILDARE AVE
# (41.6744106, -87.7275156)
#
# W 18TH ST
# (39.041594, -96.8333437)
#
# S MILLARD AVE
# (36.725905, -119.6804604)
#
# W 71ST PL
# (25.8872768, -80.347878)
#
# S ST LAWRENCE AVE
# (41.7682281, -87.6104913)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# N SEDGWICK ST
# (37.693255, -97.36976)
#
# S WHIPPLE ST
# (42.6302929, -71.3004363)
#
# N FAIRBANKS CT
# (41.8939932, -87.620286)
#
# N LAWNDALE AVE
# (41.9592196, -87.720432)
#
# W IRVING PARK RD
# (41.953826, -87.7116755)
#
# W OAKDALE AVE
# (29.0407755, -81.3169917)
#
# W WILCOX ST
# (39.7729655, -86.2196271)
#
# S CRANDON AVE
# (41.7625938, -87.5688755)
#
# S CICERO AVE
# (41.8545413, -87.7443874)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# W 54TH ST
# (40.7692528, -73.9948535)
#
# S EXCHANGE AVE
# (35.0704184, -92.4212449)
#
# N LINCOLN AVE
# (45.660956, -122.6824777)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# S EMERALD AVE
# (33.3965996, -111.8035831)
#
# E ST
# (50.4738724, 4.2358174)
#
# W LE MOYNE ST
# (41.9077136, -87.7331889)
#
# S KIMBARK AVE
# (41.7673136, -87.5941382)
#
# W CUYLER AVE
# (41.9551763, -87.6742845)
#
# N COLUMBUS DR
# (30.5692605, -85.1366536)
#
# W 79TH ST
# (40.7849838, -73.9826637)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# N KEELER AVE
# (31.890888, -102.393391)
#
# S RIDGELAND AVE
# (41.8835463, -87.7845574)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# S HOXIE AVE
# (41.6318654, -87.5604201)
#
# W POPE JOHN PAUL II DR
# (41.815443, -87.7017808)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# W 87TH ST
# (38.970993, -94.7161832)
#
# N MOZART ST
# (41.963078, -87.699749)
#
# W ST
# (55.8497133, -4.2656724)
#
# N CLEVELAND AVE
# (30.344444, -95.0913629)
#
# S SOUTH SHORE DR
# (41.7687175, -87.5665152)
#
# W WELLINGTON AVE
# (38.1838186, -85.7649883)
#
# W 63RD PL
# (25.8801129, -80.3380563)
#
# S MAY ST
# (35.5997263, -77.5918349)
#
# W WALNUT ST
# (31.8085297, -97.0935238)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# S CLAREMONT AVE
# (39.096728, -94.442776)
#
# N LARRABEE ST
# (41.907027, -87.6433116)
#
# S WALLACE ST
# (38.6625346, -87.3019057)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# E HYDE PARK BLVD
# (41.8024947, -87.5867897)
#
# S MINERVA AVE
# (42.487236, -83.118805)
#
# W 72ND PL
# (25.8884828, -80.3539543)
#
# S LEAMINGTON AVE
# (41.7619164, -87.7501006)
#
# N KILDARE AVE
# (41.9718061, -87.7355466)
#
# W PENSACOLA AVE
# (41.9604024, -87.6892707)
#
# N EDGEBROOK TER
# (42.00262735, -87.77663392591357)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# W CRYSTAL ST
# (28.899691, -82.574754)
#
# S LAKE SHORE DR E
# (41.151578, -85.747808)
#
# W FLOURNOY ST
# (28.406267, -97.7593919)
#
# S BONAPARTE ST
# (41.8398404, -87.6596895)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# E 65TH ST
# (25.8818612, -80.2655861)
#
# E HYDE PARK BLVD
# (41.8024947, -87.5867897)
#
# W 19TH ST
# (30.1833503, -85.7294777)
#
# W ST
# (55.8497133, -4.2656724)
#
# N KILPATRICK AVE
# (41.9699316, -87.74405)
#
# W 80TH ST
# (41.7486788, -87.6536729)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# W CORTEZ ST
# (33.5897649, -112.4664308)
#
# W 31ST ST
# (44.9466054, -93.2862078)
#
# W 66TH ST
# (40.7733596, -73.9809918)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# S ELLIS AVE
# (35.309552, -78.616879)
#
# W 64TH PL
# (25.881035, -80.3378206)
#
# N LUNA AVE
# (34.454345, -119.281645)
#
# W 55TH ST
# (40.7692044, -73.9927944)
#
# S KEELER AVE
# (36.7501253, -95.9789915)
#
# W 31ST ST
# (44.9466054, -93.2862078)
#
# W POLK ST
# (30.7116929, -94.9383233)
#
# N LINCOLN PARK WEST
# (41.9192403, -87.6363854)
#
# N MELVINA AVE
# (42.0121329, -87.7817803)
#
# W HENDERSON ST
# (35.6845746, -80.4331586)
#
# S THROOP ST
# (41.7467867, -87.6560654)
#
# N DAMEN AVE
# (41.9744669, -87.6793492)
#
# S LAKE PARK AVE
# (41.5348577, -87.2596604)
#
# N SACRAMENTO BLVD
# (41.889664, -87.7013745)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# E 72ND PL
# (39.886358, -86.078593)
#
# W 35TH ST
# (41.881364, -103.6683128)
#
# S CENTRAL PARK AVE
# (41.7169517, -87.7114806)
#
# S WELLS ST
# (38.0067095, -89.2477996)
#
# W 18TH ST
# (39.041594, -96.8333437)
#
# S KILDARE AVE
# (41.6744106, -87.7275156)
#
# W OGDEN AVE
# (32.341146, -86.3093)
#
# N ASHLAND BLVD
# (42.0066203, -87.6699972)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# N CANAL ST
# (42.442134, -75.597522)
#
# S NEWLAND AVE
# (41.7774254, -87.7954677)
#
# S DORCHESTER AVE
# (41.861114, -88.126156)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# S DORCHESTER AVE
# (41.861114, -88.126156)
#
# E GARFIELD BLVD
# (41.794447, -87.6149514)
#
# S HAMLIN AVE
# (42.0088243, -87.8504392)
#
# W CULLERTON ST
# (41.8556603, -87.641803)
#
# S HERMITAGE AVE
# (41.7685166, -87.6675589)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# S KIMBARK AVE
# (41.7673136, -87.5941382)
#
# S SOUTH SHORE DR
# (41.7687175, -87.5665152)
#
# S CICERO AVE
# (41.8545413, -87.7443874)
#
# N LEAMINGTON AVE
# (41.8986064, -87.7544655)
#
# S CHAPPEL AVE
# (41.7588966, -87.5749062)
#
# W MIDWAY PARK
# (41.8889822, -87.7720806)
#
# E GARFIELD BLVD
# (41.794447, -87.6149514)
#
# S THROOP ST
# (41.7467867, -87.6560654)
#
# S CALIFORNIA BLVD
# (37.8959724, -122.0627491)
#
# S ROCKWELL ST
# (33.3290958, -111.7293356)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# S SACRAMENTO AVE
# (39.3373525, -74.4801189)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# W HARRISON ST
# (47.453523, -116.785825)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# W MAYPOLE AVE
# (41.8835952, -87.7087902)
#
# N FRANCISCO AVE
# (26.2217801, -98.3199932)
#
# W BUCKINGHAM PL
# (43.6406037, -116.2851637)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# W LEXINGTON ST
# (39.0325997, -97.5948929)
#
# S WOODLAWN AVE
# (41.7812374, -87.5962214)
#
# S PULASKI RD
# (41.6803208, -87.7198931)
#
# S ESSEX AVE
# (39.3133874, -76.4565138)
#
# S AVALON AVE
# (34.244157, -116.386354)
#
# N LAWLER AVE
# (41.9186896, -87.7523027)
#
# S OGLESBY AVE
# (41.7448277, -87.5673518)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# S EBERHART AVE
# (43.822127, -84.748397)
#
# S STEWART AVE
# (28.290846, -81.4066339)
#
# S WESTERN AVE
# (43.5185145, -96.751124)
#
# S BURLEY AVE
# (41.7376517, -87.5453086)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# S BRENNAN AVE
# (41.7186926, -87.5678337)
#
# W AUGUSTA BLVD
# (41.4210887, -87.732417)
#
# S BURLEY AVE
# (41.7376517, -87.5453086)
#
# S PARK SHORE EAST CT
# (41.7837478, -87.5878863)
#
# N HERMITAGE AVE
# (40.232782, -74.780752)
#
# S LEAVITT ST
# (41.8737714, -87.6813292)
#
# S RICHMOND ST
# (44.8899249, -88.3024977)
#
# S PERRY AVE
# (27.74589, -81.794657)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# W DOUGLAS BLVD
# (41.8629927, -87.7029508)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# S INDEPENDENCE BLVD
# (36.8059, -76.116529)
#
# S AVERS AVE
# (41.6734757, -87.7157121)
#
# S YALE AVE
# (36.0765216, -95.9221167)
#
# S MILLARD AVE
# (36.725905, -119.6804604)
#
# W HARRISON ST
# (47.453523, -116.785825)
#
# W LAKE ST
# (41.8877192, -87.7651226)
#
# S UNION AVE
# (47.2491253, -122.4836389)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# S RICHMOND ST
# (44.8899249, -88.3024977)
#
# E 47TH PL
# (41.5324031, -87.3313342)
#
# S BURLEY AVE
# (41.7376517, -87.5453086)
#
# S PEORIA ST
# (39.5974063, -104.8480467)
#
# W ALTGELD ST
# (41.9262007, -87.8075454)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# S MARSHFIELD AVE
# (41.8093553, -87.6662057)
#
# S EUCLID AVE
# (43.5904697, -83.9155365)
#
# W LEXINGTON ST
# (39.0325997, -97.5948929)
#
# N ELSTON AVE
# (41.9624991, -87.731967)
#
# N ELSTON AVE
# (41.9624991, -87.731967)
#
# S LAKE SHORE DR
# (42.25603, -87.998784)
#
# N ELSTON AVE
# (41.9624991, -87.731967)
#
# E 65TH ST
# (25.8818612, -80.2655861)
#
# S PULASKI RD
# (41.6803208, -87.7198931)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# W 63RD ST
# (41.7733805, -87.9889844)
#
# N MC VICKER AVE
# (41.7720642, -87.7721541)
#
# N KEDZIE BLVD
# (41.9245939, -87.7072256)
#
# S WINCHESTER AVE
# (46.406387, -105.830479)
#
# S HAMILTON AVE
# (29.4083447, -98.5341118)
#
# S PAULINA ST
# (41.878849, -87.6692204)
#
# S HAMLIN AVE
# (42.0088243, -87.8504392)
#
# W 70TH ST
# (32.442242, -93.866732)
#
# S Prairie Ave
# (38.2622876, -104.6440104)
#
# S MACKINAW AVE
# (41.6390757, -87.5420386)
#
# W DIVISION ST
# (38.2597099, -87.9979169)
#
# S DELANO CT W
# (41.8676448, -87.6326338)
#
# E 76TH ST
# (39.704568, -74.135229)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# W ST
# (55.8497133, -4.2656724)
#
# W ST
# (55.8497133, -4.2656724)
#
# W POLK ST
# (30.7116929, -94.9383233)
#
# S HOMAN AVE
# (41.6622485, -87.7046222)
#
# W PL
# (39.0445999, -94.6029041)
#
# N LINCOLN AVE
# (45.660956, -122.6824777)
#
# W 35TH PL
# (39.818328, -86.271661)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# S LA SALLE ST
# (41.742861, -88.3242315)
#
# W 19TH ST
# (30.1833503, -85.7294777)
#
# S ABERDEEN ST
# (35.7300766, -95.3526173)
#
# N HAMLIN AVE
# (41.9737701, -87.7232845)
#
# W MORSE AVE
# (42.0072486, -87.6859808)
#
# W AINSLIE ST
# (41.9701978, -87.7164722)
#
# N LESTER AVE
# (29.9788827, -90.2202247)
#
# E 89TH PL
# (36.0340257, -95.9045251)
#
# W DRUMMOND PL
# (41.9315035, -87.643809)
#
# N KOSTNER AVE
# (41.9869013, -87.7382889)
#
# S HOMAN AVE
# (41.6622485, -87.7046222)
#
# W MELROSE ST
# (40.667262, -73.698695)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W 32ND ST
# (44.9447377, -93.2874525)
#
# N WALLER AVE
# (41.8910824, -87.7677998)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# W SHERIDAN RD
# (42.490117, -79.250962)
#
# N CENTRAL AVE
# (35.7718102, -91.6557941)
#
# S JUSTINE ST
# (41.6714397, -87.6599691)
#
# W 55TH ST
# (40.7692044, -73.9927944)
#
# S GILES AVE
# (41.8310918, -87.6193367)
#
# W 72ND ST
# (40.778834, -73.982158)
#
# S LAFAYETTE AVE
# (39.334709, -74.489355)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# S PERRY AVE
# (27.74589, -81.794657)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)

# %%
# Save Checkpoint 
df2015_geo = df_2015.copy()

# %%
# Filter location that is not null
df2015_geo = df2015_geo[df2015_geo['location'].notna()]

# %%
df2015_geo = impute_district(df2015_geo)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:113: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326

# %%
# Drop columns
df2015_geo.drop(['district', 'index_right'], axis=1, inplace=True)

# Rename columns
df2015_geo.rename(columns={'dist_num':'district'}, inplace=True)

# %%
# Impute updated ward values
df2015_geo = impute_ward(df2015_geo)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:69: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326

# %%
# Drop columns
df2015_geo.drop(['ward_left', 'index_right'], axis=1, inplace=True)

# Rename columns
df2015_geo.rename(columns={'ward_right':'ward'}, inplace=True)

# %%
# Impute updated district values
df2015_geo = impute_commareas(df2015_geo)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:91: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326

# %%
# Drop columns
df2015_geo.drop(['community_area', 'index_right'], axis=1, inplace=True)

# Rename columns
df2015_geo.rename(columns={'area_numbe':'community_area'}, inplace=True)

# %%
# Balance clean up of dataset after transformation
# Drop columns
df2015_geo.drop(['x_coordinate', 'y_coordinate'], axis=1, inplace=True)

# Assign null values in location description to 'OTHER (Specify)'
df2015_geo['location_description'].fillna('OTHER (SPECIFY)', inplace = True)

# %%
df2015_geo.to_csv('/content/drive/MyDrive/Colab Notebooks/capstone/assets/2015_crime_clean.csv', index=False)

# %%
df2015_geo.isnull().sum()
# Out:
# id                      0
# case_number             0
# date                    0
# block                   0
# iucr                    0
# primary_type            0
# description             0
# location_description    0
# arrest                  0
# domestic                0
# beat                    0
# fbi_code                0
# year                    0
# updated_on              0
# latitude                0
# longitude               0
# location                0
# day                     0
# month                   0
# day_of_week             0
# time                    0
# geometry                0
# district                0
# ward                    0
# community_area          0
# dtype: int64

# %% [markdown]
# ## Clean data (2014)

# %%
# from geopy.geocoders import Nominatim
geocoder = Nominatim(user_agent = 'crime_predictions')

# %%
df_2014 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/capstone/assets/2014_crime.csv')
df_2014.head()
# Out:
#          id case_number                 date                 block  iucr  \
# 0  10224788    HY410899  2014-03-27 00:01:00  035XX S MICHIGAN AVE  5111
# 1  11645601    JC212935  2014-06-01 00:01:00   087XX S SANGAMON ST  1153
# 2  10225562    HY412692  2014-12-29 08:00:00       035XX W 58TH PL  1752
# 3  11028056    JA359834  2014-10-15 15:00:00    047XX S PULASKI RD  1153
# 4  11227495    JB147292  2014-03-20 09:00:00       003XX E ERIE ST  1154
#
#                  primary_type                              description  \
# 0               OTHER OFFENSE        GUN OFFENDER: ANNUAL REGISTRATION
# 1          DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 2  OFFENSE INVOLVING CHILDREN            AGG CRIM SEX ABUSE FAM MEMBER
# 3          DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 4          DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
#
#               location_description  arrest  domestic  beat  district  ward  \
# 0  POLICE FACILITY/VEH PARKING LOT    True     False   213       2.0   3.0
# 1                        RESIDENCE   False     False  2222      22.0  21.0
# 2                        RESIDENCE   False     False   822       8.0  14.0
# 3   PARKING LOT/GARAGE(NON.RESID.)   False     False   821       8.0  14.0
# 4                        RESIDENCE   False     False  1834      18.0  42.0
#
#    community_area fbi_code  x_coordinate  y_coordinate  year  \
# 0            35.0       26     1177772.0     1881665.0  2014
# 1            71.0       11           NaN           NaN  2014
# 2            63.0       20     1153676.0     1865593.0  2014
# 3            57.0       11           NaN           NaN  2014
# 4             8.0       11           NaN           NaN  2014
#
#                updated_on   latitude  longitude  \
# 0  02/10/2018 03:50:01 PM  41.830612 -87.623247
# 1  04/06/2019 04:04:43 PM        NaN        NaN
# 2  02/10/2018 03:50:01 PM  41.787021 -87.712083
# 3  07/24/2017 03:54:23 PM        NaN        NaN
# 4  02/11/2018 03:57:41 PM        NaN        NaN
#
#                         location  day  month  day_of_week  time
# 0  (41.830611847, -87.623247369)   27      3            3     0
# 1                            NaN    1      6            6     0
# 2  (41.787020592, -87.712083182)   29     12            0     8
# 3                            NaN   15     10            2    15
# 4                            NaN   20      3            3     9

# %%
df_2014.isnull().sum()
# Out:
# id                         0
# case_number                0
# date                       0
# block                      0
# iucr                       0
# primary_type               0
# description                0
# location_description     376
# arrest                     0
# domestic                   0
# beat                       0
# district                   0
# ward                       2
# community_area             0
# fbi_code                   0
# x_coordinate            1902
# y_coordinate            1902
# year                       0
# updated_on                 0
# latitude                1902
# longitude               1902
# location                1902
# day                        0
# month                      0
# day_of_week                0
# time                       0
# dtype: int64

# %%
replace_to_zero(df_2014)

# %%
index_list = missing_row_loc(df_2014)
# Out:
# 1902

# %%
impute_data(df_2014, index_list)
# Out:
# Streaming output truncated to the last 5000 lines.
# W 71ST ST
# (39.882403, -86.227212)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# S ELLIS AVE
# (35.309552, -78.616879)
#
# W THOMAS ST
# (43.230666, -75.469829)
#
# W OHIO ST
# (40.646058, -83.609337)
#
# S LOOMIS BLVD
# (41.7570599, -87.6587609)
#
# W 40TH ST
# (30.3041337, -97.7342249)
#
# S COTTAGE GROVE AVE
# (41.6856412, -87.6114137)
#
# W 76TH ST
# (33.9707255, -118.2915697)
#
# N FRANCISCO AVE
# (26.2217801, -98.3199932)
#
# W 61ST ST
# (44.89257, -93.315002)
#
# S ST LAWRENCE AVE
# (41.7682281, -87.6104913)
#
# N FRANCISCO AVE
# (26.2217801, -98.3199932)
#
# S BURNHAM AVE
# (41.6423104, -87.5396238)
#
# S INDEPENDENCE BLVD
# (36.8059, -76.116529)
#
# N KILBOURN AVE
# (41.9717611, -87.7405534)
#
# S UNION AVE
# (47.2491253, -122.4836389)
#
# E 73RD ST
# (32.0274706, -81.1097986)
#
# N WALLER AVE
# (41.8910824, -87.7677998)
#
# S KOSTNER AVE
# (41.6651721, -87.7289951)
#
# S DANTE AVE
# (41.5394098, -87.5855724)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W SUPERIOR ST
# (40.857308, -96.805534)
#
# W DEVON AVE
# (41.9973572, -87.7114381)
#
# E GRAND AVE
# (36.7105116, -119.7874097)
#
# E GRAND AVE
# (36.7105116, -119.7874097)
#
# E GRAND AVE
# (36.7105116, -119.7874097)
#
# S GREEN ST
# (37.8040878, -87.6368672)
#
# S CRANDON AVE
# (41.7625938, -87.5688755)
#
# N KOSTNER AVE
# (41.9869013, -87.7382889)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# W HOLLYWOOD AVE
# (40.664973, -73.381541)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# W 87TH ST
# (38.970993, -94.7161832)
#
# W CRESTLINE ST
# (41.7442705, -87.7258555)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# W 68TH PL
# (25.8846371, -80.3531037)
#
# N DAMEN AVE
# (41.9744669, -87.6793492)
#
# W DOUGLAS BLVD
# (41.8629927, -87.7029508)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# S CHAPPEL AVE
# (41.7588966, -87.5749062)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# W ST
# (55.8497133, -4.2656724)
#
# N LOREL AVE
# (41.8840101, -87.7588689)
#
# W AUGUSTA BLVD
# (41.4210887, -87.732417)
#
# N TROY ST
# (41.9593759, -87.70697)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# N KEDZIE AVE
# (41.981245, -87.7088348)
#
# W ARTHUR AVE
# (42.9994824, -87.9518008)
#
# W CORNELIA AVE
# (33.9618136, -98.6777071)
#
# S ARCHER AVE
# (41.6335223, -88.0133585)
#
# W OAK ST
# (33.2135652, -92.6679021)
#
# S HONORE ST
# (41.8267808, -87.6715176)
#
# W 23RD PL
# (36.12889, -96.0026142)
#
# W LEXINGTON ST
# (39.0325997, -97.5948929)
#
# S PERRY AVE
# (27.74589, -81.794657)
#
# S CHAMPLAIN AVE
# (32.1827548, -110.8194486)
#
# N NARRAGANSETT AVE
# (41.9633701, -87.7869544)
#
# S EBERHART AVE
# (43.822127, -84.748397)
#
# E PL
# (14.8370417, -89.14104361631954)
#
# E 72ND PL
# (39.886358, -86.078593)
#
# W CARMEN AVE
# (41.9736044, -87.7374367)
#
# E 78TH ST
# (36.0516381, -95.9637058)
#
# W WARREN BLVD
# (41.8823807, -87.6651175)
#
# S CHAMPLAIN AVE
# (32.1827548, -110.8194486)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# S EXCHANGE AVE
# (35.0704184, -92.4212449)
#
# W 15TH ST
# (44.9689141, -93.2867103)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# W 87TH ST
# (38.970993, -94.7161832)
#
# N SPRINGFIELD AVE
# (41.9646307, -87.7254887)
#
# S MASON AVE
# (47.1898123, -122.4941429)
#
# W SHAKESPEARE AVE
# (44.1405017, -93.981392)
#
# W 82ND ST
# (41.7450945, -87.6499675)
#
# N LONG AVE
# (31.872625, -102.526908)
#
# W CRYSTAL ST
# (28.899691, -82.574754)
#
# W CULLOM AVE
# (41.9590228, -87.7389563)
#
# N WHIPPLE ST
# (41.9721178, -87.7049131)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S OAK PARK AVE
# (41.8815808, -87.7943023)
#
# N MAYFIELD AVE
# (34.1105096, -117.2902727)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# W SCHOOL ST
# (33.3044468, -96.4028596)
#
# S WENTWORTH AVE
# (42.9981308, -87.8894434)
#
# N MOZART ST
# (41.963078, -87.699749)
#
# N ALBANY AVE
# (40.7076835, -73.465108)
#
# W HIRSCH ST
# (41.9062185, -87.7313087)
#
# S STONY ISLAND AVE
# (41.772423, -87.5862745)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# W 61ST ST
# (44.89257, -93.315002)
#
# S SANGAMON ST
# (39.5902655, -89.7359101)
#
# S CHRISTIANA AVE
# (28.6675036, -81.4969422)
#
# W 65TH PL
# (39.876, -86.192027)
#
# N HAZEL ST
# (40.166712, -76.395635)
#
# W CHASE AVE
# (32.780398, -116.9699604)
#
# S RICHMOND ST
# (44.8899249, -88.3024977)
#
# S ANTHONY AVE
# (37.149086, -98.028778)
#
# W 61ST ST
# (44.89257, -93.315002)
#
# S SEELEY AVE
# (42.2886768, -89.633005)
#
# W THOMAS ST
# (43.230666, -75.469829)
#
# W ST
# (55.8497133, -4.2656724)
#
# S KOSTNER AVE
# (41.6651721, -87.7289951)
#
# S DREXEL AVE
# (33.369843, -111.623825)
#
# S JUSTINE ST
# (41.6714397, -87.6599691)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# S WHIPPLE ST
# (42.6302929, -71.3004363)
#
# S KOLIN AVE
# (41.6804633, -87.7282162)
#
# W THOMAS ST
# (43.230666, -75.469829)
#
# S UNION AVE
# (47.2491253, -122.4836389)
#
# W IRVING PARK RD
# (41.953826, -87.7116755)
#
# W SHAKESPEARE AVE
# (44.1405017, -93.981392)
#
# S VERNON AVE
# (32.72251, -96.836774)
#
# W SCHOOL ST
# (33.3044468, -96.4028596)
#
# S HARPER AVE
# (33.3743982, -111.6339155)
#
# N HAMLIN AVE
# (41.9737701, -87.7232845)
#
# S LOTUS AVE
# (36.7105116, -119.7874097)
#
# W GRAND AVE
# (44.89992, -89.6139466)
#
# W GLADYS AVE
# (41.915226, -87.959294)
#
# E 53RD ST
# (40.7580248, -73.9701634)
#
# S CREGIER AVE
# (41.7663619, -87.5812232)
#
# S BISHOP ST
# (39.5665983, -76.9892851)
#
# N LOTUS AVE
# (35.4704582, -97.3553818)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# N MASON AVE
# (42.354338, -85.244316)
#
# W WEST END AVE
# (41.8840066, -87.7595529)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# N MONITOR AVE
# (41.9791477, -87.7744717)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# W PL
# (39.0445999, -94.6029041)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# S RACINE AVE
# (42.9427005, -88.1582854)
#
# W MONTROSE AVE
# (41.9607197, -87.7466474)
#
# S KOSTNER AVE
# (41.6651721, -87.7289951)
#
# W PL
# (39.0445999, -94.6029041)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# N MEADE AVE
# (38.8379256, -104.7960056)
#
# S ALBANY AVE
# (27.932852, -82.480986)
#
# W POTOMAC AVE
# (43.0958445, -88.0105462)
#
# S LOCKWOOD AVE
# (41.7615119, -87.7536073)
#
# N PINE GROVE AVE
# (41.9529308, -87.6478914)
#
# E ST
# (50.4738724, 4.2358174)
#
# S ST LAWRENCE AVE
# (41.7682281, -87.6104913)
#
# W WABANSIA AVE
# (41.9107882, -87.7995001)
#
# S KINGSTON AVE
# (36.044406, -95.9074742)
#
# W 21ST ST
# (44.961758, -93.306244)
#
# S KOMENSKY AVE
# (41.7242244, -87.7231031)
#
# S CHAMPLAIN AVE
# (32.1827548, -110.8194486)
#
# S EVANS AVE
# (35.509722, -97.9558699)
#
# W ROSCOE ST
# (41.9417774, -87.798255)
#
# N ARTESIAN AVE
# (41.9254283, -87.6888852)
#
# S EGGLESTON AVE
# (35.407396, -97.5137083)
#
# W IRVING PARK RD
# (41.953826, -87.7116755)
#
# S AVERS AVE
# (41.6734757, -87.7157121)
#
# N ST LOUIS AVE
# (41.9727203, -87.7159449)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# S LAVERGNE AVE
# (41.6916676, -87.7446407)
#
# W WALNUT ST
# (31.8085297, -97.0935238)
#
# S LAWLER AVE
# (41.6735388, -87.7455584)
#
# W THOMAS ST
# (43.230666, -75.469829)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# W CRYSTAL ST
# (28.899691, -82.574754)
#
# S COLFAX AVE
# (30.853988, -96.9914143)
#
# E 60TH ST
# (44.8942722, -93.2746348)
#
# W GLADYS AVE
# (41.915226, -87.959294)
#
# W PL
# (39.0445999, -94.6029041)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# W HARRISON ST
# (47.453523, -116.785825)
#
# W WRIGHTWOOD AVE
# (41.9247283, -87.9553717)
#
# E 74TH ST
# (40.7710532, -73.9596512)
#
# N RIDGEWAY AVE
# (41.9954911, -87.7227208)
#
# N CICERO AVE
# (42.0121975, -87.7479383)
#
# W ST
# (55.8497133, -4.2656724)
#
# W 64TH ST
# (39.0130173, -94.802986)
#
# S PERRY AVE
# (27.74589, -81.794657)
#
# E 50TH ST
# (40.7584119, -73.9769016)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# E 99TH ST
# (41.5337122, -87.4524447)
#
# W 83RD ST
# (41.7432634, -87.6499076)
#
# N HOMAN AVE
# (41.8919714, -87.711335)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# N KOLMAR AVE
# (41.9710894, -87.7440319)
#
# W 38TH ST
# (39.7635758, -75.5276556)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# W WILCOX ST
# (39.7729655, -86.2196271)
#
# W WILCOX ST
# (39.7729655, -86.2196271)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# W 18TH ST
# (39.041594, -96.8333437)
#
# S VERNON AVE
# (32.72251, -96.836774)
#
# N CENTRAL PARK AVE
# (41.9751896, -87.7184185)
#
# S MACKINAW AVE
# (41.6390757, -87.5420386)
#
# W HENDERSON ST
# (35.6845746, -80.4331586)
#
# S CHRISTIANA AVE
# (28.6675036, -81.4969422)
#
# W ST
# (55.8497133, -4.2656724)
#
# S BRENNAN AVE
# (41.7186926, -87.5678337)
#
# N LARAMIE AVE
# (41.8954167, -87.7556069)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# W 86TH ST
# (40.7861728, -73.9714247)
#
# S GREENWOOD AVE
# (37.6199047, -96.228166)
#
# S KARLOV AVE
# (41.7139045, -87.7235728)
#
# E 62ND ST
# (44.890728, -93.259847)
#
# S AVERS AVE
# (41.6734757, -87.7157121)
#
# W IRVING PARK RD
# (41.953826, -87.7116755)
#
# N CLIFTON AVE
# (37.2360894, -93.3271958)
#
# W BELDEN AVE
# (41.9187168, -87.9610749)
#
# W POLK ST
# (30.7116929, -94.9383233)
#
# W 20TH PL
# (41.5815703, -87.3803931)
#
# S KENNETH AVE
# (41.6814466, -87.7302028)
#
# W HARRISON ST
# (47.453523, -116.785825)
#
# S ANTHONY AVE
# (37.149086, -98.028778)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# S GILES AVE
# (41.8310918, -87.6193367)
#
# S LAVERGNE AVE
# (41.6916676, -87.7446407)
#
# S DORCHESTER AVE
# (41.861114, -88.126156)
#
# W FULTON BLVD
# (41.8864528, -87.7038266)
#
# S DORCHESTER AVE
# (41.861114, -88.126156)
#
# N LEAMINGTON AVE
# (41.8986064, -87.7544655)
#
# N GLENWOOD AVE
# (42.650887, -83.284998)
#
# S AUSTIN AVE
# (39.3448149, -74.4685932)
#
# S PRINCETON AVE
# (39.7884436, -75.1461365)
#
# W 53RD ST
# (40.7608471, -73.9768541)
#
# S STONY ISLAND AVE
# (41.772423, -87.5862745)
#
# N WINTHROP AVE
# (41.9873032, -87.6581226)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# S WASHTENAW AVE
# (41.8244476, -87.6922106)
#
# W PL
# (39.0445999, -94.6029041)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# N DAMEN AVE
# (41.9744669, -87.6793492)
#
# W BERTEAU AVE
# (41.9561908, -87.8158422)
#
# S WASHTENAW AVE
# (41.8244476, -87.6922106)
#
# S DOBSON AVE
# (41.764125, -87.5994316)
#
# N KEDVALE AVE
# (41.9640717, -87.7315451)
#
# S GILES AVE
# (41.8310918, -87.6193367)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# W BEACH AVE
# (49.0253429, -122.8165082)
#
# S PULASKI RD
# (41.6803208, -87.7198931)
#
# W WALNUT ST
# (31.8085297, -97.0935238)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# W GRENSHAW ST
# (41.8679092, -87.6630252)
#
# E ST
# (50.4738724, 4.2358174)
#
# S HONORE ST
# (41.8267808, -87.6715176)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S EAST END AVE
# (40.7774069, -73.943042)
#
# N CENTRAL AVE
# (35.7718102, -91.6557941)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# E 66TH PL
# (36.067636, -95.964491)
#
# S KEDVALE AVE
# (41.6474182, -87.7222793)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# E 36TH ST
# (44.9378251, -93.2191089)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# W RANDOLPH ST
# (36.2743344, -90.9816148)
#
# S INGLESIDE AVE
# (41.7403543, -87.601287)
#
# S HERMITAGE AVE
# (41.7685166, -87.6675589)
#
# E 79TH ST
# (40.7742888, -73.9572899)
#
# W WILCOX ST
# (39.7729655, -86.2196271)
#
# S RACINE AVE
# (42.9427005, -88.1582854)
#
# W ST
# (55.8497133, -4.2656724)
#
# N CENTRAL AVE
# (35.7718102, -91.6557941)
#
# N LECLAIRE AVE
# (41.935091, -87.7540962)
#
# S ABERDEEN ST
# (35.7300766, -95.3526173)
#
# N KOSTNER AVE
# (41.9869013, -87.7382889)
#
# W FLOURNOY ST
# (28.406267, -97.7593919)
#
# W PERSHING RD
# (39.8764731, -88.9678636)
#
# S CANAL ST
# (42.1979758, -72.6021589)
#
# E 87TH ST
# (41.4677098, -81.6272505)
#
# W WILCOX ST
# (39.7729655, -86.2196271)
#
# W WILCOX ST
# (39.7729655, -86.2196271)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# S CALUMET AVE
# (41.7034033, -86.871671)
#
# E 43RD ST
# (44.9251197, -93.2396454)
#
# W ERIE ST
# (33.3076026, -111.9043792)
#
# E 66TH PL
# (36.067636, -95.964491)
#
# N NARRAGANSETT AVE
# (41.9633701, -87.7869544)
#
# S HAMLIN AVE
# (42.0088243, -87.8504392)
#
# S KOMENSKY AVE
# (41.7242244, -87.7231031)
#
# N SAYRE AVE
# (41.9628625, -87.8025486)
#
# W LEXINGTON ST
# (39.0325997, -97.5948929)
#
# S RACINE AVE
# (42.9427005, -88.1582854)
#
# S CLYDE AVE
# (28.2911755, -81.4131903)
#
# S SOUTH SHORE DR
# (41.7687175, -87.5665152)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# N PINE AVE
# (42.669591, -73.790953)
#
# N PULASKI RD
# (41.9640877, -87.7278964)
#
# S DORCHESTER AVE
# (41.861114, -88.126156)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# N LOCKWOOD AVE
# (41.6979589, -83.5699941)
#
# W WELLINGTON AVE
# (38.1838186, -85.7649883)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# S KENNETH AVE
# (41.6814466, -87.7302028)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# W WILCOX ST
# (39.7729655, -86.2196271)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# W MAYPOLE AVE
# (41.8835952, -87.7087902)
#
# W 64TH PL
# (25.881035, -80.3378206)
#
# N NORDICA AVE
# (41.9489763, -87.8034519)
#
# W 18TH ST
# (39.041594, -96.8333437)
#
# N CENTRAL AVE
# (35.7718102, -91.6557941)
#
# E BOWEN AVE
# (46.8021128, -100.7877832)
#
# S PRINCETON AVE
# (39.7884436, -75.1461365)
#
# N LAWLER AVE
# (41.9186896, -87.7523027)
#
# W LELAND AVE
# (41.9666512, -87.7370944)
#
# S HOMEWOOD AVE
# (37.1390531, -93.3344851)
#
# W ARGYLE ST
# (57.8956842, -5.1630045)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# S ESSEX AVE
# (39.3133874, -76.4565138)
#
# S CENTRAL PARK AVE
# (41.7169517, -87.7114806)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# W GRAND AVE
# (44.89992, -89.6139466)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# S CHAMPLAIN AVE
# (32.1827548, -110.8194486)
#
# S MOZART ST
# (41.726308, -87.6933241)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# S LEAMINGTON AVE
# (41.7619164, -87.7501006)
#
# S JUSTINE ST
# (41.6714397, -87.6599691)
#
# W EASTWOOD AVE
# (41.9656467, -87.7297858)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# S BURNHAM AVE
# (41.6423104, -87.5396238)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# W ADDISON ST
# (42.226415, -84.406033)
#
# W 65TH ST
# (34.6902193, -92.3298401)
#
# S WINCHESTER AVE
# (46.406387, -105.830479)
#
# S CORNELL AVE
# (42.119526, -87.95127)
#
# S SPAULDING AVE
# (34.0288086, -118.3700242)
#
# S ESSEX AVE
# (39.3133874, -76.4565138)
#
# S PERRY AVE
# (27.74589, -81.794657)
#
# N KINGSBURY ST
# (41.8986511, -87.6438839)
#
# N MENARD AVE
# (41.8914776, -87.7700234)
#
# N WINTHROP AVE
# (41.9873032, -87.6581226)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# N PULASKI RD
# (41.9640877, -87.7278964)
#
# S WESTERN AVE
# (43.5185145, -96.751124)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# S CALIFORNIA AVE
# (34.1163848, -118.0008539)
#
# N CENTRAL AVE
# (35.7718102, -91.6557941)
#
# S DEARBORN ST
# (47.5958836, -122.318572)
#
# S ST LAWRENCE AVE
# (41.7682281, -87.6104913)
#
# W DRUMMOND PL
# (41.9315035, -87.643809)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# W NORTH SHORE AVE
# (42.0027093, -87.744558)
#
# S PAXTON AVE
# (41.7316571, -87.5707162)
#
# E 79TH ST
# (40.7742888, -73.9572899)
#
# N BISSELL ST
# (39.502357, -89.763274)
#
# S CLYDE AVE
# (28.2911755, -81.4131903)
#
# S CAMPBELL AVE
# (37.1712552, -93.2953919)
#
# W CARROLL AVE
# (34.1342246, -117.8674488)
#
# N HARLEM AVE
# (37.093364, -94.529365)
#
# N AUSTIN AVE
# (41.912831, -87.7753338)
#
# S CORNELL AVE
# (42.119526, -87.95127)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# N LA SALLE DR
# (32.459967, -99.781336)
#
# S STEWART AVE
# (28.290846, -81.4066339)
#
# W LEXINGTON ST
# (39.0325997, -97.5948929)
#
# S CREGIER AVE
# (41.7663619, -87.5812232)
#
# S HARVARD AVE
# (40.613458, -98.098577)
#
# W 21ST ST
# (44.961758, -93.306244)
#
# W AUGUSTA BLVD
# (41.4210887, -87.732417)
#
# N WINTHROP AVE
# (41.9873032, -87.6581226)
#
# S WENTWORTH AVE
# (42.9981308, -87.8894434)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# N PARKSIDE AVE
# (34.082432, -117.6296776)
#
# E 97TH ST
# (44.827484, -93.257759)
#
# W ST PAUL AVE
# (43.0347877, -87.9278248)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# W 18TH ST
# (39.041594, -96.8333437)
#
# S MARSHFIELD AVE
# (41.8093553, -87.6662057)
#
# S CLAREMONT AVE
# (39.096728, -94.442776)
#
# S GREEN ST
# (37.8040878, -87.6368672)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# W 19TH ST
# (30.1833503, -85.7294777)
#
# S BLUE ISLAND AVE
# (41.8541923, -87.6641634)
#
# N CHRISTIANA AVE
# (41.9702394, -87.7121816)
#
# S ABERDEEN ST
# (35.7300766, -95.3526173)
#
# N MOZART ST
# (41.963078, -87.699749)
#
# S GREEN ST
# (37.8040878, -87.6368672)
#
# S BISHOP ST
# (39.5665983, -76.9892851)
#
# N MOHAWK ST
# (42.790293, -73.712513)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# S KOLIN AVE
# (41.6804633, -87.7282162)
#
# E 88TH ST
# (31.936824, -102.398602)
#
# S GILBERT CT
# (41.6491829, -91.529802)
#
# N LAWNDALE AVE
# (41.9592196, -87.720432)
#
# W LEXINGTON ST
# (39.0325997, -97.5948929)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# N LAWNDALE AVE
# (41.9592196, -87.720432)
#
# S CLYDE AVE
# (28.2911755, -81.4131903)
#
# W ADDISON ST
# (42.226415, -84.406033)
#
# S MAY ST
# (35.5997263, -77.5918349)
#
# S Lowe Ave
# (41.8176141, -87.6421133)
#
# E 89TH PL
# (36.0340257, -95.9045251)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W IOWA ST
# (43.0518372, -91.3949007)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# E 78TH ST
# (36.0516381, -95.9637058)
#
# W GARFIELD BLVD
# (41.7944433, -87.6378706)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# N MONTICELLO AVE
# (41.9751716, -87.7196691)
#
# N SPRINGFIELD AVE
# (41.9646307, -87.7254887)
#
# S GREENWOOD AVE
# (37.6199047, -96.228166)
#
# W ADDISON ST
# (42.226415, -84.406033)
#
# S CALUMET AVE
# (41.7034033, -86.871671)
#
# S ALBANY AVE
# (27.932852, -82.480986)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# S ESSEX AVE
# (39.3133874, -76.4565138)
#
# W 51ST ST
# (40.7597316, -73.9780866)
#
# S Troy ST
# (42.4897468, -83.1419423)
#
# N SPAULDING AVE
# (41.9543894, -87.7104772)
#
# W 60TH ST
# (44.89423, -93.301147)
#
# W BELLE PLAINE AVE
# (41.955062, -87.7887068)
#
# W Rice St
# (35.5516747, -80.6218475)
#
# N CICERO AVE
# (42.0121975, -87.7479383)
#
# S WELLS ST
# (38.0067095, -89.2477996)
#
# S EGGLESTON AVE
# (35.407396, -97.5137083)
#
# N BEACON ST
# (41.4586084, -74.4140133)
#
# S SOUTH SHORE DR
# (41.7687175, -87.5665152)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# S BRANDON AVE
# (40.8875742, -92.8209286)
#
# W 25TH ST
# (39.802821, -86.1734111)
#
# N DAMEN AVE
# (41.9744669, -87.6793492)
#
# W 86TH ST
# (40.7861728, -73.9714247)
#
# S LOOMIS ST
# (41.769112, -88.14147)
#
# S HARDING AVE
# (36.6834759, -119.7343476)
#
# S WOOD ST
# (41.343196, -83.119849)
#
# N WOLCOTT AVE
# (41.9069854, -87.6730408)
#
# S HONORE ST
# (41.8267808, -87.6715176)
#
# N LEAMINGTON AVE
# (41.8986064, -87.7544655)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# N SEDGWICK ST
# (37.693255, -97.36976)
#
# S Hamilton Ave
# (29.4083447, -98.5341118)
#
# N SPAULDING AVE
# (41.9543894, -87.7104772)
#
# N CENTRAL AVE
# (35.7718102, -91.6557941)
#
# N OCONTO AVE
# (41.9452423, -87.8081992)
#
# N KENNEDY EXPY IB
# E LOWER WACKER DR
# (41.8875576, -87.6174627)
#
# W BARRY AVE
# (36.8175627, -93.9243727)
#
# N GREENVIEW AVE
# (42.2840502, -89.1311541)
#
# W GUNNISON ST
# (41.969023, -87.7398109)
#
# N DAMEN AVE
# (41.9744669, -87.6793492)
#
# W ELM ST
# (31.7998495, -97.0960399)
#
# W Hubbard St
# (41.7159012, -89.3389805)
#
# S YATES BLVD
# (41.7408204, -87.5660877)
#
# S WOLCOTT AVE
# (41.8741687, -87.6740297)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# N RUSH ST
# (43.7828197, -86.4281776)
#
# E 55TH ST
# (40.7560064, -73.9614975)
#
# W CORNELIA AVE
# (33.9618136, -98.6777071)
#
# S RICHMOND ST
# (44.8899249, -88.3024977)
#
# W GEORGE ST
# (55.8634318, -4.2657255)
#
# S MASSASOIT AVE
# (41.6640139, -87.7618901)
#
# E 79TH ST
# (40.7742888, -73.9572899)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# W LEXINGTON ST
# (39.0325997, -97.5948929)
#
# S MARSHFIELD AVE
# (41.8093553, -87.6662057)
#
# N LECLAIRE AVE
# (41.935091, -87.7540962)
#
# W MC LEAN AVE
# (41.9181539, -87.720491)
#
# S MILLARD AVE
# (36.725905, -119.6804604)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# W RICE ST
# (35.5516747, -80.6218475)
#
# N BROADWAY
# (40.9696948, -73.8844801)
#
# S BLACKSTONE AVE
# (41.78726, -87.881703)
#
# S ALBANY AVE
# (27.932852, -82.480986)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# W LE MOYNE ST
# (41.9077136, -87.7331889)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# S UNION AVE
# (47.2491253, -122.4836389)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# N KEDVALE AVE
# (41.9640717, -87.7315451)
#
# N JEFFERSON ST
# (43.572607, -76.123675)
#
# W 21ST ST
# (44.961758, -93.306244)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# S CHURCH ST
# (41.2952576, -82.9712879)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# W QUINCY ST
# (28.0541053, -81.9636599)
#
# N LEAMINGTON AVE
# (41.8986064, -87.7544655)
#
# N AVERS AVE
# (41.9628652, -87.724203)
#
# E GRAND AVE
# (36.7105116, -119.7874097)
#
# N SHEFFIELD AVE
# (43.1085525, -87.8984732)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# S EVANS AVE
# (35.509722, -97.9558699)
#
# W ROOT ST
# (41.8190508, -87.6360402)
#
# S HALSTED ST
# (41.5420844, -87.6359687)
#
# W SCHUBERT AVE
# (41.921548, -88.096436)
#
# N RIDGE AVE
# (35.5045339, -80.6185371)
#
# S LARAMIE AVE
# (41.8447325, -87.753967)
#
# S HOMAN AVE
# (41.6622485, -87.7046222)
#
# W CORNELIA AVE
# (33.9618136, -98.6777071)
#
# W SUMMERDALE AVE
# (41.9789237, -87.6696222)
#
# W 47TH ST
# (40.7580163, -73.9817975)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# N MANGO AVE
# (41.9608929, -87.7709224)
#
# S SPRINGFIELD AVE
# (40.6858039, -74.3274558)
#
# S LAWLER AVE
# (41.6735388, -87.7455584)
#
# S AVENUE J
# (34.1782421, -103.3451898)
#
# W CULLERTON ST
# (41.8556603, -87.641803)
#
# S KOMENSKY AVE
# (41.7242244, -87.7231031)
#
# W LE MOYNE ST
# (41.9077136, -87.7331889)
#
# N KOSTNER AVE
# (41.9869013, -87.7382889)
#
# S TRUMBULL AVE
# (41.666268, -87.7067038)
#
# S KILDARE AVE
# (41.6744106, -87.7275156)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# E 80TH ST
# (39.706875, -74.132378)
#
# N BOSWORTH AVE
# (41.9106545, -87.6665138)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W North Ave
# (39.3102943, -76.6372005)
#
# S EVANS AVE
# (35.509722, -97.9558699)
#
# N STATE PKWY
# (41.9077301, -87.6287875)
#
# S EBERHART AVE
# (43.822127, -84.748397)
#
# S RIDGELAND AVE
# (41.8835463, -87.7845574)
#
# W 14TH ST
# (40.7370431, -73.9960774)
#
# S KILBOURN AVE
# (41.8591487, -87.737185)
#
# W ROSCOE ST
# (41.9417774, -87.798255)
#
# N CICERO AVE
# (42.0121975, -87.7479383)
#
# W FLOURNOY ST
# (28.406267, -97.7593919)
#
# S GREENWOOD AVE
# (37.6199047, -96.228166)
#
# S LAKE PARK AVE
# (41.5348577, -87.2596604)
#
# S RICHMOND ST
# (44.8899249, -88.3024977)
#
# W ST
# (55.8497133, -4.2656724)
#
# S RACINE AVE
# (42.9427005, -88.1582854)
#
# W HADDON AVE
# (41.9025006, -87.6659391)
#
# W FLETCHER ST
# (28.324413, -81.40576)
#
# N ST LOUIS AVE
# (41.9727203, -87.7159449)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# W GRANVILLE AVE
# (40.245255, -96.754104)
#
# S CENTRAL PARK AVE
# (41.7169517, -87.7114806)
#
# N GLENWOOD AVE
# (42.650887, -83.284998)
#
# S OGLESBY AVE
# (41.7448277, -87.5673518)
#
# W 38TH ST
# (39.7635758, -75.5276556)
#
# S DRAKE AVE
# (41.8498569, -87.713702)
#
# S CARPENTER ST
# (35.240268, -81.338339)
#
# S CALUMET AVE
# (41.7034033, -86.871671)
#
# S UNIVERSITY AVE
# (40.2215138, -111.658881)
#
# E 75TH ST
# (38.985274, -94.4306042)
#
# W GARFIELD BLVD
# (41.7944433, -87.6378706)
#
# W FLOURNOY ST
# (28.406267, -97.7593919)
#
# S RACINE AVE
# (42.9427005, -88.1582854)
#
# S INGLESIDE AVE
# (41.7403543, -87.601287)
#
# S ROCKWELL ST
# (33.3290958, -111.7293356)
#
# S COLFAX AVE
# (30.853988, -96.9914143)
#
# W 40TH PL
# (25.858926, -80.284691)
#
# E 84TH ST
# (40.6411761, -73.914588)
#
# N WINCHESTER AVE
# (46.4110364, -105.830487)
#
# N GREEN ST
# (42.932728, -76.570157)
#
# W ST
# (55.8497133, -4.2656724)
#
# S MILLER ST
# (33.25877, -93.8907336)
#
# S BRANDON AVE
# (40.8875742, -92.8209286)
#
# W LAKE ST
# (41.8877192, -87.7651226)
#
# N PAULINA ST
# (41.9902949, -87.6714344)
#
# W GLADYS AVE
# (41.915226, -87.959294)
#
# S DREXEL BLVD
# (35.4636206, -97.5703073)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# E ERIE ST
# (33.3090107, -111.8198088)
#
# S OGLESBY AVE
# (41.7448277, -87.5673518)
#
# N MERRIMAC AVE
# (39.2169153, -94.6287743)
#
# S TRUMBULL AVE
# (41.666268, -87.7067038)
#
# S MAY ST
# (35.5997263, -77.5918349)
#
# N LATROBE AVE
# (41.9852199, -87.7604579)
#
# N WINCHESTER AVE
# (46.4110364, -105.830487)
#
# S BLACKSTONE AVE
# (41.78726, -87.881703)
#
# S KNOX AVE
# (31.7922502, -102.4986994)
#
# W BELDEN AVE
# (41.9187168, -87.9610749)
#
# S KINGSTON AVE
# (36.044406, -95.9074742)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# E 9TH ST
# (37.0034535, -121.5606568)
#
# S MILLARD AVE
# (36.725905, -119.6804604)
#
# S MANISTEE AVE
# (41.6390183, -87.5555637)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# S KARLOV AVE
# (41.7139045, -87.7235728)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# E PL
# (14.8370417, -89.14104361631954)
#
# N LAVERGNE AVE
# (41.9090105, -87.9045527)
#
# W ELMDALE AVE
# (41.9908568, -87.6651706)
#
# W CORTLAND ST
# (42.591483, -76.371899)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# S WALLACE ST
# (38.6625346, -87.3019057)
#
# W GLADYS AVE
# (41.915226, -87.959294)
#
# S BISHOP ST
# (39.5665983, -76.9892851)
#
# N WINTHROP AVE
# (41.9873032, -87.6581226)
#
# S SHIELDS AVE
# (37.5470522, -77.4700211)
#
# N MAYFIELD AVE
# (34.1105096, -117.2902727)
#
# W DIVERSEY AVE
# (41.9263942, -88.0053438)
#
# W FLOURNOY ST
# (28.406267, -97.7593919)
#
# W ST
# (55.8497133, -4.2656724)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# S DREXEL BLVD
# (35.4636206, -97.5703073)
#
# W 65TH ST
# (34.6902193, -92.3298401)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# S SOUTH SHORE DR
# (41.7687175, -87.5665152)
#
# W ST PAUL AVE
# (43.0347877, -87.9278248)
#
# N SPRINGFIELD AVE
# (41.9646307, -87.7254887)
#
# N WHIPPLE ST
# (41.9721178, -87.7049131)
#
# S CICERO AVE
# (41.8545413, -87.7443874)
#
# S KOMENSKY AVE
# (41.7242244, -87.7231031)
#
# S KARLOV AVE
# (41.7139045, -87.7235728)
#
# S WOOD ST
# (41.343196, -83.119849)
#
# N LARAMIE AVE
# (41.8954167, -87.7556069)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# S BENNETT AVE
# (39.047033, -82.645968)
#
# S MARYLAND AVE
# (39.5941256, -75.9378606)
#
# S MILLARD AVE
# (36.725905, -119.6804604)
#
# W WALNUT ST
# (31.8085297, -97.0935238)
#
# W AUGUSTA BLVD
# (41.4210887, -87.732417)
#
# S AVALON AVE
# (34.244157, -116.386354)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# N ARTESIAN AVE
# (41.9254283, -87.6888852)
#
# S JUSTINE ST
# (41.6714397, -87.6599691)
#
# W RACE AVE
# (35.2508634, -91.74748)
#
# W 23RD PL
# (36.12889, -96.0026142)
#
# S ARCHER AVE
# (41.6335223, -88.0133585)
#
# S ARCHER AVE
# (41.6335223, -88.0133585)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# N LARAMIE AVE
# (41.8954167, -87.7556069)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# S STONY ISLAND AVE
# (41.772423, -87.5862745)
#
# S BURLEY AVE
# (41.7376517, -87.5453086)
#
# W CONGRESS PKWY
# (41.8750866, -87.6539866)
#
# S ALBANY AVE
# (27.932852, -82.480986)
#
# W ARTHINGTON ST
# (41.8700106, -87.7112288)
#
# N HOYNE AVE
# (41.9550717, -87.6812061)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# S WHIPPLE ST
# (42.6302929, -71.3004363)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# W 35TH ST
# (41.881364, -103.6683128)
#
# S HOMAN AVE
# (41.6622485, -87.7046222)
#
# S BRENNAN AVE
# (41.7186926, -87.5678337)
#
# N CAMPBELL AVE
# (32.2527259, -110.9439424)
#
# W OHIO ST
# (40.646058, -83.609337)
#
# W THOMAS ST
# (43.230666, -75.469829)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# S ELIZABETH ST
# (40.727094, -84.106756)
#
# S RICHMOND ST
# (44.8899249, -88.3024977)
#
# W SCHUBERT AVE
# (41.921548, -88.096436)
#
# S JUSTINE ST
# (41.6714397, -87.6599691)
#
# N CLAREMONT AVE
# (36.106832, -80.228788)
#
# E 80TH ST
# (39.706875, -74.132378)
#
# N WINTHROP AVE
# (41.9873032, -87.6581226)
#
# S CENTRAL AVE
# (40.8950402, -74.0839635)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# N ROGERS AVE
# (42.118891, -76.046551)
#
# S WASHTENAW AVE
# (41.8244476, -87.6922106)
#
# N LA SALLE DR
# (32.459967, -99.781336)
#
# S ELLIS AVE
# (35.309552, -78.616879)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# W 14TH PL
# (36.737877, -95.99234)
#
# N NORMANDY AVE
# (32.3607574, -95.2956254)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# S GREEN ST
# (37.8040878, -87.6368672)
#
# N CHRISTIANA AVE
# (41.9702394, -87.7121816)
#
# W LAKE ST
# (41.8877192, -87.7651226)
#
# E 79TH ST
# (40.7742888, -73.9572899)
#
# S CLAREMONT AVE
# (39.096728, -94.442776)
#
# S CLAREMONT AVE
# (39.096728, -94.442776)
#
# S HARDING AVE
# (36.6834759, -119.7343476)
#
# W 57TH PL
# (41.5135811, -87.3693843)
#
# W DOUGLAS BLVD
# (41.8629927, -87.7029508)
#
# W 39TH PL
# (41.5471943, -87.3456365)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# N LAVERGNE AVE
# (41.9090105, -87.9045527)
#
# E 47TH ST
# (40.7546125, -73.9737345)
#
# S CLYDE AVE
# (28.2911755, -81.4131903)
#
# S UNION AVE
# (47.2491253, -122.4836389)
#
# N RICHMOND ST
# (41.9557758, -87.7019847)
#
# W GLADYS AVE
# (41.915226, -87.959294)
#
# E 61ST ST
# (44.892517, -93.260414)
#
# W 75TH ST
# (44.8673118, -93.306107)
#
# S KOLMAR AVE
# (41.6817099, -87.7322799)
#
# S SAGINAW AVE
# (41.6427026, -87.5580689)
#
# W LAWRENCE AVE
# (41.9683042, -87.7231431)
#
# S MOZART ST
# (41.726308, -87.6933241)
#
# E 49TH ST
# (44.9143071, -93.2651976)
#
# S WENTWORTH AVE
# (42.9981308, -87.8894434)
#
# S MANISTEE AVE
# (41.6390183, -87.5555637)
#
# N LOCKWOOD AVE
# (41.6979589, -83.5699941)
#
# S KENWOOD AVE
# (41.8060326, -87.5935411)
#
# N KILPATRICK AVE
# (41.9699316, -87.74405)
#
# W 32ND PL
# (39.813025, -86.268698)
#
# E 97TH PL
# (36.0227905, -95.9221473)
#
# W 61ST ST
# (44.89257, -93.315002)
#
# S LAKE PARK AVE
# (41.5348577, -87.2596604)
#
# N KEDZIE AVE
# (41.981245, -87.7088348)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# S LOOMIS ST
# (41.769112, -88.14147)
#
# S KOMENSKY AVE
# (41.7242244, -87.7231031)
#
# S BURLEY AVE
# (41.7376517, -87.5453086)
#
# S LEAVITT ST
# (41.8737714, -87.6813292)
#
# S PAULINA ST
# (41.878849, -87.6692204)
#
# E 77TH ST
# (36.0529109, -95.8831572)
#
# N CHRISTIANA AVE
# (41.9702394, -87.7121816)
#
# S SANGAMON ST
# (39.5902655, -89.7359101)
#
# N HAMLIN AVE
# (41.9737701, -87.7232845)
#
# S PULASKI RD
# (41.6803208, -87.7198931)
#
# E 69TH PL
# (41.4913223, -87.3304402)
#
# N MOBILE AVE
# (35.2845786, -93.1181537)
#
# W WRIGHTWOOD AVE
# (41.9247283, -87.9553717)
#
# W LEXINGTON ST
# (39.0325997, -97.5948929)
#
# S LAKE PARK AVE
# (41.5348577, -87.2596604)
#
# S WALLACE ST
# (38.6625346, -87.3019057)
#
# N MOZART ST
# (41.963078, -87.699749)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# S HOYNE AVE
# (41.8228899, -87.6774807)
#
# S FAIRFIELD AVE
# (41.8828928, -88.0058916)
#
# W WASHINGTON ST
# (40.194732, -85.391486)
#
# S CENTRAL AVE
# (40.8950402, -74.0839635)
#
# N MONITOR AVE
# (41.9791477, -87.7744717)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# E 72ND ST
# (40.7710212, -73.9636252)
#
# W POLK ST
# (30.7116929, -94.9383233)
#
# S UNIVERSITY AVE
# (40.2215138, -111.658881)
#
# W BRYN MAWR AVE
# (41.983045, -87.711304)
#
# N ELSTON AVE
# (41.9624991, -87.731967)
#
# W GRENSHAW ST
# (41.8679092, -87.6630252)
#
# W CERMAK RD
# (41.8495374, -87.849713)
#
# W CERMAK RD
# (41.8495374, -87.849713)
#
# W CERMAK RD
# (41.8495374, -87.849713)
#
# W CERMAK RD
# (41.8495374, -87.849713)
#
# W CERMAK RD
# (41.8495374, -87.849713)
#
# W CERMAK RD
# (41.8495374, -87.849713)
#
# W CERMAK RD
# (41.8495374, -87.849713)
#
# W CERMAK RD
# (41.8495374, -87.849713)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# W CERMAK RD
# (41.8495374, -87.849713)
#
# W CERMAK RD
# (41.8495374, -87.849713)
#
# S CALIFORNIA AVE
# (34.1163848, -118.0008539)
#
# W CERMAK RD
# (41.8495374, -87.849713)
#
# W CERMAK RD
# (41.8495374, -87.849713)
#
# N LOREL AVE
# (41.8840101, -87.7588689)
#
# N PARKSIDE AVE
# (34.082432, -117.6296776)
#
# S ELLIS AVE
# (35.309552, -78.616879)
#
# S RUTHERFORD AVE
# (41.7189853, -87.78843)
#
# S KARLOV AVE
# (41.7139045, -87.7235728)
#
# S RICHMOND ST
# (44.8899249, -88.3024977)
#
# W 78TH ST
# (44.8646695, -93.5812403)
#
# W 83RD PL
# (41.4664124, -87.3859098)
#
# S DOBSON AVE
# (41.764125, -87.5994316)
#
# S FRANCISCO AVE
# (37.6847697, -122.4009224)
#
# S KILDARE AVE
# (41.6744106, -87.7275156)
#
# S PAULINA ST
# (41.878849, -87.6692204)
#
# S DREXEL AVE
# (33.369843, -111.623825)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# N NORA AVE
# (34.0813562, -117.9385738)
#
# S KEDZIE AVE
# (41.7315967, -87.7021544)
#
# S WENTWORTH AVE
# (42.9981308, -87.8894434)
#
# N FAIRFIELD AVE
# (40.417653, -120.640311)
#
# N KIMBALL AVE
# (32.948407, -97.1167804)
#
# W GLADYS AVE
# (41.915226, -87.959294)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# S UNION AVE
# (47.2491253, -122.4836389)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# N CAMPBELL AVE
# (32.2527259, -110.9439424)
#
# W 22ND PL
# (30.188365, -85.710205)
#
# W JAMES ST
# (40.045775, -76.308196)
#
# W GLADYS AVE
# (41.915226, -87.959294)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W 23RD ST
# (40.7442808, -73.9960773)
#
# S PULASKI RD
# (41.6803208, -87.7198931)
#
# S WOODLAWN AVE
# (41.7812374, -87.5962214)
#
# W WILCOX ST
# (39.7729655, -86.2196271)
#
# N NATOMA AVE
# (43.6443386, -116.4245855)
#
# N AUSTIN AVE
# (41.912831, -87.7753338)
#
# S LA SALLE ST
# (41.742861, -88.3242315)
#
# S STONY ISLAND AVE
# (41.772423, -87.5862745)
#
# S MARSHFIELD AVE
# (41.8093553, -87.6662057)
#
# W OHIO ST
# (40.646058, -83.609337)
#
# N WINTHROP AVE
# (41.9873032, -87.6581226)
#
# N ALBANY AVE
# (40.7076835, -73.465108)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# E ST
# (50.4738724, 4.2358174)
#
# S KINGSTON AVE
# (36.044406, -95.9074742)
#
# E 44TH ST
# (44.9233272, -93.2683053)
#
# N DRAKE AVE
# (41.9725027, -87.7171475)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# S HERMOSA AVE
# (33.9126479, -116.8692547)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# S DOBSON AVE
# (41.764125, -87.5994316)
#
# S CICERO AVE
# (41.8545413, -87.7443874)
#
# W PL
# (39.0445999, -94.6029041)
#
# S CAMPBELL AVE
# (37.1712552, -93.2953919)
#
# W ST
# (55.8497133, -4.2656724)
#
# S CLYDE AVE
# (28.2911755, -81.4131903)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# W WOLFRAM ST
# (41.9335036, -87.6563169)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# S BEVERLY AVE
# (34.741893, -87.674971)
#
# N MONTICELLO AVE
# (41.9751716, -87.7196691)
#
# N PARKSIDE AVE
# (34.082432, -117.6296776)
#
# S SEELEY AVE
# (42.2886768, -89.633005)
#
# W BRADLEY PL
# (41.9501056, -87.6501801)
#
# W 21ST PL
# (41.579758, -87.3761617)
#
# S NORMAL BLVD
# (41.7792236, -87.637511)
#
# E ILLINOIS ST
# (41.862286, -88.09637)
#
# S SACRAMENTO AVE
# (39.3373525, -74.4801189)
#
# N TRIPP AVE
# (41.9848527, -87.7341352)
#
# S HOYNE AVE
# (41.8228899, -87.6774807)
#
# W LAKESIDE PL
# (42.0625044, -88.0999232)
#
# N SACRAMENTO AVE
# (39.341244, -74.483242)
#
# W ST
# (55.8497133, -4.2656724)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# S DREXEL AVE
# (33.369843, -111.623825)
#
# W WRIGHTWOOD AVE
# (41.9247283, -87.9553717)
#
# E ST
# (50.4738724, 4.2358174)
#
# W VERMONT ST
# (39.7724557, -86.2529508)
#
# S FINANCIAL PL
# (41.8752586, -87.6330631)
#
# S AVENUE N
# (31.532975, -97.437499)
#
# W DEVON AVE
# (41.9973572, -87.7114381)
#
# W POTOMAC AVE
# (43.0958445, -88.0105462)
#
# W HIRSCH ST
# (41.9062185, -87.7313087)
#
# S ARCHER AVE
# (41.6335223, -88.0133585)
#
# S HERMITAGE AVE
# (41.7685166, -87.6675589)
#
# S KOSTNER AVE
# (41.6651721, -87.7289951)
#
# S PERRY AVE
# (27.74589, -81.794657)
#
# S ADA ST
# (44.9307182, -93.0759931)
#
# S INDEPENDENCE BLVD
# (36.8059, -76.116529)
#
# N LUNA AVE
# (34.454345, -119.281645)
#
# S PLYMOUTH CT
# (41.8740189, -87.6286848)
#
# S CAMPBELL AVE
# (37.1712552, -93.2953919)
#
# W 60TH PL
# (25.877393, -80.338291)
#
# W BIRCHWOOD AVE
# (42.9399265, -87.9627232)
#
# W PL
# (39.0445999, -94.6029041)
#
# W FRANKLIN BLVD
# (35.2598762, -81.214961)
#
# S DREXEL AVE
# (33.369843, -111.623825)
#
# S SAGINAW AVE
# (41.6427026, -87.5580689)
#
# S KEDZIE AVE
# (41.7315967, -87.7021544)
#
# S ALBANY AVE
# (27.932852, -82.480986)
#
# N RIDGE AVE
# (35.5045339, -80.6185371)
#
# W 58TH ST
# (44.8978415, -93.2888067)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# N WAYNE AVE
# (40.055678, -75.393487)
#
# N OZARK AVE
# (37.2286508, -93.286646)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# N NARRAGANSETT AVE
# (41.9633701, -87.7869544)
#
# S PULASKI RD
# (41.6803208, -87.7198931)
#
# N ROCKWELL ST
# (33.3744844, -111.7302071)
#
# W FRANKLIN BLVD
# (35.2598762, -81.214961)
#
# S CALIFORNIA AVE
# (34.1163848, -118.0008539)
#
# N LA SALLE ST
# (30.398997, -96.0961872)
#
# S KIMBARK AVE
# (41.7673136, -87.5941382)
#
# S SAWYER AVE
# (47.2288772, -122.4540806)
#
# N DRAKE AVE
# (41.9725027, -87.7171475)
#
# W 43RD ST
# (44.9250102, -93.2909497)
#
# W WEBSTER AVE
# (42.4488715, -83.1273708)
#
# W ST
# (55.8497133, -4.2656724)
#
# W WASHBURNE AVE
# (41.8661181, -87.6581942)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# W PL
# (39.0445999, -94.6029041)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# W MONTEREY AVE
# (42.0026085, -88.0825745)
#
# E 64TH ST
# (25.8805547, -80.2813052)
#
# S KIMBARK AVE
# (41.7673136, -87.5941382)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# S MAYFIELD AVE
# (41.8800902, -87.7713848)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# N RUTHERFORD AVE
# (40.706973, -73.468891)
#
# N CAMPBELL AVE
# (32.2527259, -110.9439424)
#
# W GLADYS AVE
# (41.915226, -87.959294)
#
# S CALUMET AVE
# (41.7034033, -86.871671)
#
# S MOZART ST
# (41.726308, -87.6933241)
#
# W CRYSTAL ST
# (28.899691, -82.574754)
#
# W 22ND PL
# (30.188365, -85.710205)
#
# S OGLESBY AVE
# (41.7448277, -87.5673518)
#
# S KOSTNER AVE
# (41.6651721, -87.7289951)
#
# W 44TH ST
# (40.680314, -74.107708)
#
# N MOZART ST
# (41.963078, -87.699749)
#
# W WRIGHTWOOD AVE
# (41.9247283, -87.9553717)
#
# W PL
# (39.0445999, -94.6029041)
#
# N ROGERS AVE
# (42.118891, -76.046551)
#
# N KARLOV AVE
# (41.9677725, -87.7304613)
#
# N KILPATRICK AVE
# (41.9699316, -87.74405)
#
# S WHIPPLE ST
# (42.6302929, -71.3004363)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# W BLOOMINGDALE AVE
# (27.8936206, -82.2946314)
#
# N SACRAMENTO AVE
# (39.341244, -74.483242)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# W AGATITE AVE
# (41.9619564, -87.7205109)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# N MOZART ST
# (41.963078, -87.699749)
#
# S EXCHANGE AVE
# (35.0704184, -92.4212449)
#
# S DREXEL AVE
# (33.369843, -111.623825)
#
# S EDBROOKE AVE
# (41.6980924, -87.6196287)
#
# S HARDING AVE
# (36.6834759, -119.7343476)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# N BROADWAY
# (40.9696948, -73.8844801)
#
# W PENSACOLA AVE
# (41.9604024, -87.6892707)
#
# W JARVIS AVE
# (42.0153543, -87.8050829)
#
# W 32ND ST
# (44.9447377, -93.2874525)
#
# E 90TH ST
# (39.9181982, -86.0387202)
#
# S KEDVALE AVE
# (41.6474182, -87.7222793)
#
# N MALDEN ST
# (41.9687299, -87.6628804)
#
# E WACKER DR
# (41.8878388, -87.6190596)
#
# W 98TH ST
# (39.9294661, -86.2288934)
#
# S COMMERCIAL AVE
# (41.7141047, -89.3341986)
#
# N SEELEY AVE
# (43.5619333, -94.7747364)
#
# W MAPLE ST
# (37.6800483, -97.4058021)
#
# S DANTE AVE
# (41.5394098, -87.5855724)
#
# W 80TH ST
# (41.7486788, -87.6536729)
#
# W BALMORAL AVE
# (41.9798396, -87.6688623)
#
# S HALSTED ST
# (41.5420844, -87.6359687)
#
# S CLAREMONT AVE
# (39.096728, -94.442776)
#
# N BROADWAY
# (40.9696948, -73.8844801)
#
# S CALIFORNIA AVE
# (34.1163848, -118.0008539)
#
# N MENARD AVE
# (41.8914776, -87.7700234)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# S SPAULDING AVE
# (34.0288086, -118.3700242)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# W OAKDALE AVE
# (29.0407755, -81.3169917)
#
# S KINGSTON AVE
# (36.044406, -95.9074742)
#
# W TERMINAL ST
# (38.3711643, -88.065751)
#
# W ARMITAGE AVE
# (43.1023086, -87.9910021)
#
# S THROOP ST
# (41.7467867, -87.6560654)
#
# S SOUTH SHORE DR
# (41.7687175, -87.5665152)
#
# N LECLAIRE AVE
# (41.935091, -87.7540962)
#
# E 79TH ST
# (40.7742888, -73.9572899)
#
# S MAPLEWOOD AVE
# (36.0250954, -95.9064784)
#
# N CLAREMONT AVE
# (36.106832, -80.228788)
#
# S LA SALLE ST
# (41.742861, -88.3242315)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# N MOHAWK ST
# (42.790293, -73.712513)
#
# W AUGUSTA BLVD
# (41.4210887, -87.732417)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# S LOOMIS ST
# (41.769112, -88.14147)
#
# S YALE AVE
# (36.0765216, -95.9221167)
#
# S PERRY AVE
# (27.74589, -81.794657)
#
# N LOREL AVE
# (41.8840101, -87.7588689)
#
# N NEVA AVE
# (41.9100895, -87.8039791)
#
# W MAXWELL ST
# (41.078907, -100.5275514)
#
# W ROSCOE ST
# (41.9417774, -87.798255)
#
# W 95TH ST
# (40.7954358, -73.9757202)
#
# S PRINCETON AVE
# (39.7884436, -75.1461365)
#
# W MONTROSE AVE
# (41.9607197, -87.7466474)
#
# S ABERDEEN ST
# (35.7300766, -95.3526173)
#
# S CARPENTER ST
# (35.240268, -81.338339)
#
# W 86TH PL
# (41.4598471, -87.34753)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# W WRIGHTWOOD AVE
# (41.9247283, -87.9553717)
#
# W 15TH ST
# (44.9689141, -93.2867103)
#
# W PL
# (39.0445999, -94.6029041)
#
# W ST
# (55.8497133, -4.2656724)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# W 91ST PL
# (38.9619585, -94.8742813)
#
# N MAGNOLIA AVE
# (29.1969846, -82.1365046)
#
# S KIMBARK AVE
# (41.7673136, -87.5941382)
#
# W CONGRESS PKWY
# (41.8750866, -87.6539866)
#
# W OHIO ST
# (40.646058, -83.609337)
#
# W 17TH ST
# (30.1810582, -85.7266273)
#
# S HERMITAGE AVE
# (41.7685166, -87.6675589)
#
# N FREMONT ST
# (40.768691, -95.3850426)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# E PL
# (14.8370417, -89.14104361631954)
#
# S EUCLID AVE
# (43.5904697, -83.9155365)
#
# N SPRINGFIELD AVE
# (41.9646307, -87.7254887)
#
# W IRVING PARK RD
# (41.953826, -87.7116755)
#
# W DICKENS AVE
# (26.2215137, -98.1842927)
#
# S WINCHESTER AVE
# (46.406387, -105.830479)
#
# N SPAULDING AVE
# (41.9543894, -87.7104772)
#
# W GARFIELD BLVD
# (41.7944433, -87.6378706)
#
# W HOWARD ST
# (43.4469912, -92.2854434)
#
# W CONGRESS PKWY
# (41.8750866, -87.6539866)
#
# W CULLERTON ST
# (41.8556603, -87.641803)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# S WOOD ST
# (41.343196, -83.119849)
#
# E 97TH ST
# (44.827484, -93.257759)
#
# N CLEAVER ST
# (41.90877725, -87.66409688742331)
#
# S AVALON AVE
# (34.244157, -116.386354)
#
# N MANGO AVE
# (41.9608929, -87.7709224)
#
# W 79TH PL
# (25.89498, -80.294083)
#
# S KOMENSKY AVE
# (41.7242244, -87.7231031)
#
# N LINCOLN AVE
# (45.660956, -122.6824777)
#
# W 59TH ST
# (40.7646364, -73.9737661)
#
# N KILBOURN AVE
# (41.9717611, -87.7405534)
#
# W 66TH PL
# (25.883077, -80.317394)
#
# W 19TH ST
# (30.1833503, -85.7294777)
#
# W CULLERTON ST
# (41.8556603, -87.641803)
#
# S PAULINA ST
# (41.878849, -87.6692204)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# N MASON AVE
# (42.354338, -85.244316)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# S PERRY AVE
# (27.74589, -81.794657)
#
# N KEDVALE AVE
# (41.9640717, -87.7315451)
#
# E LOWER WACKER DR
# (41.8875576, -87.6174627)
#
# W HOLLYWOOD AVE
# (40.664973, -73.381541)
#
# E Grand ave
# (36.7105116, -119.7874097)
#
# S HALSTED ST
# (41.5420844, -87.6359687)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# S DANTE AVE
# (41.5394098, -87.5855724)
#
# S TRUMBULL AVE
# (41.666268, -87.7067038)
#
# N SOUTHPORT AVE
# (41.9507055, -87.6641098)
#
# S TRUMBULL AVE
# (41.666268, -87.7067038)
#
# N BREAKWATER ACCESS
# (41.8870154, -87.6137791)
#
# S WASHTENAW AVE
# (41.8244476, -87.6922106)
#
# S PHILLIPS AVE
# (43.513078, -96.7262166)
#
# W 18TH ST
# (39.041594, -96.8333437)
#
# E ST
# (50.4738724, 4.2358174)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# N Sedgwick St
# (37.693255, -97.36976)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# S PULASKI RD
# (41.6803208, -87.7198931)
#
# S CREGIER AVE
# (41.7663619, -87.5812232)
#
# S PEORIA ST
# (39.5974063, -104.8480467)
#
# W FARWELL AVE
# (42.0067765, -87.6605207)
#
# S PHILLIPS AVE
# (43.513078, -96.7262166)
#
# W GRENSHAW ST
# (41.8679092, -87.6630252)
#
# W AGATITE AVE
# (41.9619564, -87.7205109)
#
# W GLADYS AVE
# (41.915226, -87.959294)
#
# S LEAVITT ST
# (41.8737714, -87.6813292)
#
# S WOODLAWN AVE
# (41.7812374, -87.5962214)
#
# N SHEFFIELD AVE
# (43.1085525, -87.8984732)
#
# N PAULINA ST
# (41.9902949, -87.6714344)
#
# S ESSEX AVE
# (39.3133874, -76.4565138)
#
# N RIDGEWAY AVE
# (41.9954911, -87.7227208)
#
# N MAJOR AVE
# (36.0352811, -114.9680661)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# N RICHMOND ST
# (41.9557758, -87.7019847)
#
# S INDEPENDENCE BLVD
# (36.8059, -76.116529)
#
# W SHERWIN AVE
# (42.0150507, -87.7786003)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# W BERWYN AVE
# (41.9775394, -87.712376)
#
# W GLADYS AVE
# (41.915226, -87.959294)
#
# E 73RD ST
# (32.0274706, -81.1097986)
#
# E GARFIELD BLVD
# (41.794447, -87.6149514)
#
# N LINCOLN AVE
# (45.660956, -122.6824777)
#
# W 54TH ST
# (40.7692528, -73.9948535)
#
# N LONG AVE
# (31.872625, -102.526908)
#
# N HIAWATHA AVE
# (41.992145, -87.7464613)
#
# N WINCHESTER AVE
# (46.4110364, -105.830487)
#
# N HAMLIN AVE
# (41.9737701, -87.7232845)
#
# S KARLOV AVE
# (41.7139045, -87.7235728)
#
# S SACRAMENTO AVE
# (39.3373525, -74.4801189)
#
# S MENARD AVE
# (41.6600662, -87.7628355)
#
# W DIVERSEY AVE
# (41.9263942, -88.0053438)
#
# N ALBANY AVE
# (40.7076835, -73.465108)
#
# E ST
# (50.4738724, 4.2358174)
#
# N RIDGEWAY AVE
# (41.9954911, -87.7227208)
#
# W MAYPOLE AVE
# (41.8835952, -87.7087902)
#
# S CALUMET AVE
# (41.7034033, -86.871671)
#
# S CALUMET AVE
# (41.7034033, -86.871671)
#
# W ARMITAGE AVE
# (43.1023086, -87.9910021)
#
# W 87TH ST
# (38.970993, -94.7161832)
#
# W 66TH ST
# (40.7733596, -73.9809918)
#
# N KILPATRICK AVE
# (41.9699316, -87.74405)
#
# E 63RD ST
# (30.384898, -81.6447918)
#
# S PAULINA ST
# (41.878849, -87.6692204)
#
# W 18TH ST
# (39.041594, -96.8333437)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# W FLOURNOY ST
# (28.406267, -97.7593919)
#
# S KEDZIE AVE
# (41.7315967, -87.7021544)
#
# N MAPLEWOOD AVE
# (36.1771957, -95.9078851)
#
# W LEXINGTON ST
# (39.0325997, -97.5948929)
#
# S KILBOURN AVE
# (41.8591487, -87.737185)
#
# S ESSEX AVE
# (39.3133874, -76.4565138)
#
# S VINCENNES AVE
# (41.6979977, -87.6592612)
#
# S PEORIA ST
# (39.5974063, -104.8480467)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# W 72ND ST
# (40.778834, -73.982158)
#
# W GLADYS AVE
# (41.915226, -87.959294)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# S THROOP ST
# (41.7467867, -87.6560654)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# N NATCHEZ AVE
# (41.9548213, -87.7893155)
#
# N KARLOV AVE
# (41.9677725, -87.7304613)
#
# W FARWELL AVE
# (42.0067765, -87.6605207)
#
# W WINONA ST
# (46.8469244, -92.0900123)
#
# E 79TH ST
# (40.7742888, -73.9572899)
#
# N HAMLIN AVE
# (41.9737701, -87.7232845)
#
# S KEELER AVE
# (36.7501253, -95.9789915)
#
# E 60TH ST
# (44.8942722, -93.2746348)
#
# S LA SALLE ST
# (41.742861, -88.3242315)
#
# W 34TH ST
# (40.7569672, -74.0047906)
#
# S HARVARD AVE
# (40.613458, -98.098577)
#
# N TROY ST
# (41.9593759, -87.70697)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# S CHAMPLAIN AVE
# (32.1827548, -110.8194486)
#
# N MENARD AVE
# (41.8914776, -87.7700234)
#
# N ODELL AVE
# (39.1214083, -93.1948712)
#
# S HARVARD AVE
# (40.613458, -98.098577)
#
# N MAYFIELD AVE
# (34.1105096, -117.2902727)
#
# E CONGRESS PKWY
# (41.8757455, -87.6251804)
#
# S ABERDEEN ST
# (35.7300766, -95.3526173)
#
# W PETERSON AVE
# (41.9903163, -87.7190017)
#
# N ST LOUIS AVE
# (41.9727203, -87.7159449)
#
# S GREEN ST
# (37.8040878, -87.6368672)
#
# W ALTGELD ST
# (41.9262007, -87.8075454)
#
# W DICKENS AVE
# (26.2215137, -98.1842927)
#
# S HALE AVE
# (27.9444192, -82.5109327)
#
# S OAKLEY AVE
# (41.6631708, -86.1244023)
#
# S WOODLAWN AVE
# (41.7812374, -87.5962214)
#
# S STONY ISLAND AVE
# (41.772423, -87.5862745)
#
# W LAKE ST
# (41.8877192, -87.7651226)
#
# S MOZART ST
# (41.726308, -87.6933241)
#
# N NORDICA AVE
# (41.9489763, -87.8034519)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# N LINDER AVE
# (43.4908412, -116.4138278)
#
# E 82ND ST
# (41.5041895, -81.6308342)
#
# W 78TH ST
# (44.8646695, -93.5812403)
#
# W DICKENS AVE
# (26.2215137, -98.1842927)
#
# S SPAULDING AVE
# (34.0288086, -118.3700242)
#
# S OAKLEY AVE
# (41.6631708, -86.1244023)
#
# S EBERHART AVE
# (43.822127, -84.748397)
#
# W BELDEN AVE
# (41.9187168, -87.9610749)
#
# N WOOD ST
# (32.3586259, -97.3959405)
#
# N AUSTIN AVE
# (41.912831, -87.7753338)
#
# E 95TH ST
# (40.7835163, -73.9474639)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# N ST LOUIS AVE
# (41.9727203, -87.7159449)
#
# N ST LOUIS AVE
# (41.9727203, -87.7159449)
#
# S WOLCOTT AVE
# (41.8741687, -87.6740297)
#
# W TOUHY AVE
# (42.0118322, -87.7491207)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# E GARFIELD BLVD
# (41.794447, -87.6149514)
#
# N LOREL AVE
# (41.8840101, -87.7588689)
#
# S MAYFIELD AVE
# (41.8800902, -87.7713848)
#
# W KINZIE ST
# (41.8891372, -87.6357356)
#
# W LEXINGTON ST
# (39.0325997, -97.5948929)
#
# N KILBOURN AVE
# (41.9717611, -87.7405534)
#
# N KASSON AVE
# (41.9643104, -87.7328104)
#
# S HARDING AVE
# (36.6834759, -119.7343476)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# S OGLESBY AVE
# (41.7448277, -87.5673518)
#
# S BENNETT AVE
# (39.047033, -82.645968)
#
# W 13TH PL
# (32.8861934, -111.7616046)
#
# W 83RD ST
# (41.7432634, -87.6499076)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# S DREXEL BLVD
# (35.4636206, -97.5703073)
#
# S PERRY AVE
# (27.74589, -81.794657)
#
# W GREGORY ST
# (42.0735492, -87.9441124)
#
# N CLYBOURN AVE
# (41.9273774, -87.6724654)
#
# S HARPER AVE
# (33.3743982, -111.6339155)
#
# E 87TH ST
# (41.4677098, -81.6272505)
#
# S AVENUE M
# (31.773624, -97.579064)
#
# N SACRAMENTO AVE
# (39.341244, -74.483242)
#
# S LAVERGNE AVE
# (41.6916676, -87.7446407)
#
# W IRVING PARK RD
# (41.953826, -87.7116755)
#
# S KEELER AVE
# (36.7501253, -95.9789915)
#
# N WESTERN AVE
# (35.5293143, -97.5298153)
#
# S MARSHFIELD AVE
# (41.8093553, -87.6662057)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# N GLENWOOD AVE
# (42.650887, -83.284998)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# N JANSSEN AVE
# (41.9725741, -87.6667373)
#
# S PULASKI RD
# (41.6803208, -87.7198931)
#
# S BLACKSTONE AVE
# (41.78726, -87.881703)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# W LAKE ST
# (41.8877192, -87.7651226)
#
# W 85TH ST
# (40.784673, -73.9699691)
#
# S BLACKSTONE AVE
# (41.78726, -87.881703)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# N LA SALLE ST
# (30.398997, -96.0961872)
#
# N CICERO AVE
# (42.0121975, -87.7479383)
#
# W 81ST ST
# (41.7469141, -87.6500179)
#
# S EMERALD AVE
# (33.3965996, -111.8035831)
#
# S MILLARD AVE
# (36.725905, -119.6804604)
#
# N WICKER PARK AVE
# (41.9081219, -87.6760847)
#
# S FAIRFIELD AVE
# (41.8828928, -88.0058916)
#
# S MARQUETTE AVE
# (41.6317592, -87.5567079)
#
# N TALMAN AVE
# (41.9139404, -87.6934262)
#
# N RICHMOND ST
# (41.9557758, -87.7019847)
#
# W ST
# (55.8497133, -4.2656724)
#
# W PEARSON ST
# (35.3963308, -77.995187)
#
# N LINDER AVE
# (43.4908412, -116.4138278)
#
# N CALIFORNIA AVE
# (33.9287659, -116.9813763)
#
# S CALUMET AVE
# (41.7034033, -86.871671)
#
# W PARKER AVE
# (42.1332826, -72.7503617)
#
# N RUTHERFORD AVE
# (40.706973, -73.468891)
#
# S MAPLEWOOD AVE
# (36.0250954, -95.9064784)
#
# E OHIO ST
# (40.601786, -84.084445)
#
# S ELIZABETH ST
# (40.727094, -84.106756)
#
# S WESTERN AVE
# (43.5185145, -96.751124)
#
# W 38TH ST
# (39.7635758, -75.5276556)
#
# S CENTRAL PARK AVE
# (41.7169517, -87.7114806)
#
# S RICHMOND ST
# (44.8899249, -88.3024977)
#
# E GRAND AVE
# (36.7105116, -119.7874097)
#
# W 79TH ST
# (40.7849838, -73.9826637)
#
# N LUDLAM AVE
# (41.9790965, -87.7621723)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# S HOYNE AVE
# (41.8228899, -87.6774807)
#
# S LAKE PARK AVE
# (41.5348577, -87.2596604)
#
# S KENNETH AVE
# (41.6814466, -87.7302028)
#
# S HOUSTON AVE
# (29.7104805, -98.1173779)
#
# S WOLCOTT AVE
# ...
#
# N WINTHROP AVE
# (41.9873032, -87.6581226)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# W CONGRESS PKWY
# (41.8750866, -87.6539866)
#
# S EGGLESTON AVE
# (35.407396, -97.5137083)
#
# W LELAND AVE
# (41.9666512, -87.7370944)
#
# W MEDILL AVE
# (41.9211428, -87.8794266)
#
# S SEELEY AVE
# (42.2886768, -89.633005)
#
# S DREXEL AVE
# (33.369843, -111.623825)
#
# S MAY ST
# (35.5997263, -77.5918349)
#
# S MAY ST
# (35.5997263, -77.5918349)
#
# E ST
# (50.4738724, 4.2358174)
#
# S FRANCISCO AVE
# (37.6847697, -122.4009224)
#
# S CENTRAL AVE
# (40.8950402, -74.0839635)
#
# S CRANDON AVE
# (41.7625938, -87.5688755)
#
# S ELLIS AVE
# (35.309552, -78.616879)
#
# S PEORIA ST
# (39.5974063, -104.8480467)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W DIVERSEY PKWY
# (41.9323951, -87.6687745)
#
# N KEYSTONE AVE
# (42.0001236, -76.5351751)
#
# N LA SALLE DR
# (32.459967, -99.781336)
#
# W 63RD ST
# (41.7733805, -87.9889844)
#
# E MARQUETTE RD
# (41.7727745, -87.6280678)
#
# E 41ST ST
# (44.928696, -93.2276561)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# N CLIFTON AVE
# (37.2360894, -93.3271958)
#
# S PERRY AVE
# (27.74589, -81.794657)
#
# S SACRAMENTO BLVD
# (41.877103, -87.7011017)
#
# W RANDOLPH ST
# (36.2743344, -90.9816148)
#
# S BISHOP ST
# (39.5665983, -76.9892851)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S ST LAWRENCE AVE
# (41.7682281, -87.6104913)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# W SUMMERDALE AVE
# (41.9789237, -87.6696222)
#
# S KILDARE AVE
# (41.6744106, -87.7275156)
#
# S VINCENNES AVE
# (41.6979977, -87.6592612)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# N CLAREMONT AVE
# (36.106832, -80.228788)
#
# S EVANS AVE
# (35.509722, -97.9558699)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W GRACE ST
# (37.5509972, -77.4531109)
#
# S PAULINA ST
# (41.878849, -87.6692204)
#
# W 60TH PL
# (25.877393, -80.338291)
#
# S CYRIL AVE
# (41.7648349, -87.5769415)
#
# W GRENSHAW ST
# (41.8679092, -87.6630252)
#
# S HARPER AVE
# (33.3743982, -111.6339155)
#
# W MELROSE ST
# (40.667262, -73.698695)
#
# W 21ST PL
# (41.579758, -87.3761617)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# S WENTWORTH AVE
# (42.9981308, -87.8894434)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# S MAPLEWOOD AVE
# (36.0250954, -95.9064784)
#
# S AVENUE M
# (31.773624, -97.579064)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# S SANGAMON ST
# (39.5902655, -89.7359101)
#
# W WEST END AVE
# (41.8840066, -87.7595529)
#
# S KIMBARK AVE
# (41.7673136, -87.5941382)
#
# N WOLCOTT AVE
# (41.9069854, -87.6730408)
#
# S ST LOUIS AVE
# (41.0219002, -87.7208064)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# S OAKENWALD AVE
# (41.8176178, -87.5980256)
#
# S MANISTEE AVE
# (41.6390183, -87.5555637)
#
# S WOODLAWN AVE
# (41.7812374, -87.5962214)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# S CLAREMONT AVE
# (39.096728, -94.442776)
#
# W ST
# (55.8497133, -4.2656724)
#
# S ST LOUIS AVE
# (41.0219002, -87.7208064)
#
# E 59TH ST
# (40.7639662, -73.9722705)
#
# S WOOD ST
# (41.343196, -83.119849)
#
# N RACINE AVE
# (43.003319, -88.216859)
#
# N ELIZABETH ST
# (38.0310475, -84.5126509)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# N AUSTIN AVE
# (41.912831, -87.7753338)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# S JUSTINE ST
# (41.6714397, -87.6599691)
#
# W 43RD ST
# (44.9250102, -93.2909497)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# W PL
# (39.0445999, -94.6029041)
#
# N SAWYER AVE
# (41.9610885, -87.7094607)
#
# N PINE AVE
# (42.669591, -73.790953)
#
# S WOOD ST
# (41.343196, -83.119849)
#
# S DRAKE AVE
# (41.8498569, -87.713702)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W 23RD ST
# (40.7442808, -73.9960773)
#
# W 95TH ST
# (40.7954358, -73.9757202)
#
# W LEXINGTON ST
# (39.0325997, -97.5948929)
#
# S GREEN ST
# (37.8040878, -87.6368672)
#
# E 40TH ST
# (44.9305097, -93.2276849)
#
# S OAKLEY AVE
# (41.6631708, -86.1244023)
#
# W IOWA ST
# (43.0518372, -91.3949007)
#
# S CALIFORNIA AVE
# (34.1163848, -118.0008539)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W CULLERTON ST
# (41.8556603, -87.641803)
#
# N CENTRAL AVE
# (35.7718102, -91.6557941)
#
# W GLADYS AVE
# (41.915226, -87.959294)
#
# S BISHOP ST
# (39.5665983, -76.9892851)
#
# S KEELER AVE
# (36.7501253, -95.9789915)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# S JUSTINE ST
# (41.6714397, -87.6599691)
#
# S KEDZIE AVE
# (41.7315967, -87.7021544)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# S WENTWORTH AVE
# (42.9981308, -87.8894434)
#
# W FLETCHER ST
# (28.324413, -81.40576)
#
# W CARROLL AVE
# (34.1342246, -117.8674488)
#
# W PL
# (39.0445999, -94.6029041)
#
# N KEELER AVE
# (31.890888, -102.393391)
#
# S EVANS AVE
# (35.509722, -97.9558699)
#
# S LAKE PARK AVE
# (41.5348577, -87.2596604)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W 26TH ST
# (41.8444628, -87.7092909)
#
# S WOOD ST
# (41.343196, -83.119849)
#
# W ST
# (55.8497133, -4.2656724)
#
# S MAY ST
# (35.5997263, -77.5918349)
#
# S WHIPPLE ST
# (42.6302929, -71.3004363)
#
# W 63RD PL
# (25.8801129, -80.3380563)
#
# N ARTESIAN AVE
# (41.9254283, -87.6888852)
#
# W 61ST ST
# (44.89257, -93.315002)
#
# S CALIFORNIA BLVD
# (37.8959724, -122.0627491)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# N HARDING AVE
# (41.9937042, -87.7276304)
#
# S PULASKI RD
# (41.6803208, -87.7198931)
#
# S VINCENNES AVE
# (41.6979977, -87.6592612)
#
# S JUSTINE ST
# (41.6714397, -87.6599691)
#
# E 59TH ST
# (40.7639662, -73.9722705)
#
# N AVERS AVE
# (41.9628652, -87.724203)
#
# E 76TH ST
# (39.704568, -74.135229)
#
# W DIVISION ST
# (38.2597099, -87.9979169)
#
# N LEAMINGTON AVE
# (41.8986064, -87.7544655)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# W POLK ST
# (30.7116929, -94.9383233)
#
# W FOSTER AVE
# (41.975528, -87.7281106)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# S BISHOP ST
# (39.5665983, -76.9892851)
#
# W EVERGREEN AVE
# (34.1350555, -118.0011499)
#
# E ELM ST
# (37.2052899, -93.2328025)
#
# S ELIZABETH ST
# (40.727094, -84.106756)
#
# S WENTWORTH AVE
# (42.9981308, -87.8894434)
#
# W 95TH ST
# (40.7954358, -73.9757202)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# S UNIVERSITY AVE
# (40.2215138, -111.658881)
#
# W 22ND PL
# (30.188365, -85.710205)
#
# S EAST END AVE
# (40.7774069, -73.943042)
#
# S GREENWOOD AVE
# (37.6199047, -96.228166)
#
# S BENSLEY AVE
# (41.6390654, -87.5628808)
#
# N LOCKWOOD AVE
# (41.6979589, -83.5699941)
#
# W ADDISON ST
# (42.226415, -84.406033)
#
# N LARAMIE AVE
# (41.8954167, -87.7556069)
#
# S WHIPPLE ST
# (42.6302929, -71.3004363)
#
# W MAYPOLE AVE
# (41.8835952, -87.7087902)
#
# S ABERDEEN ST
# (35.7300766, -95.3526173)
#
# N MOZART ST
# (41.963078, -87.699749)
#
# S TRUMBULL AVE
# (41.666268, -87.7067038)
#
# S LAKE PARK AVE
# (41.5348577, -87.2596604)
#
# S EUCLID AVE
# (43.5904697, -83.9155365)
#
# W ARTHUR AVE
# (42.9994824, -87.9518008)
#
# W 33RD ST
# (43.5221332, -96.7399599)
#
# N PULASKI RD
# (41.9640877, -87.7278964)
#
# N LINDER AVE
# (43.4908412, -116.4138278)
#
# N SAYRE AVE
# (41.9628625, -87.8025486)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# W 86TH PL
# (41.4598471, -87.34753)
#
# S WENTWORTH AVE
# (42.9981308, -87.8894434)
#
# S WENTWORTH AVE
# (42.9981308, -87.8894434)
#
# S KEDZIE AVE
# (41.7315967, -87.7021544)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# W GRACE ST
# (37.5509972, -77.4531109)
#
# S HONORE ST
# (41.8267808, -87.6715176)
#
# S STEWART AVE
# (28.290846, -81.4066339)
#
# N LOREL AVE
# (41.8840101, -87.7588689)
#
# W IOWA ST
# (43.0518372, -91.3949007)
#
# S PERRY AVE
# (27.74589, -81.794657)
#
# S ELIZABETH ST
# (40.727094, -84.106756)
#
# W 45TH PL
# (36.0985616, -96.0301655)
#
# E 70TH PL
# (39.8821985, -86.1446465)
#
# W ARLINGTON PL
# (28.8134399, -82.5451972)
#
# N LATROBE AVE
# (41.9852199, -87.7604579)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# W ROOSEVELT RD
# (41.8568563, -88.1736282)
#
# S WHIPPLE ST
# (42.6302929, -71.3004363)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# S TALMAN AVE
# (41.8617849, -87.692024)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# S CENTRAL AVE
# (40.8950402, -74.0839635)
#
# N CHRISTIANA AVE
# (41.9702394, -87.7121816)
#
# W GRAND AVE
# (44.89992, -89.6139466)
#
# W ROOSEVELT RD
# (41.8568563, -88.1736282)
#
# N WHIPPLE ST
# (41.9721178, -87.7049131)
#
# W 64TH ST
# (39.0130173, -94.802986)
#
# S DREXEL BLVD
# (35.4636206, -97.5703073)
#
# W THOMAS ST
# (43.230666, -75.469829)
#
# N MOODY AVE
# (27.9453048, -82.484032)
#
# S INGLESIDE AVE
# (41.7403543, -87.601287)
#
# N CUMBERLAND AVE
# (28.5746976, -81.5453944)
#
# E 82ND ST
# (41.5041895, -81.6308342)
#
# S CAMPBELL AVE
# (37.1712552, -93.2953919)
#
# N WOOD ST
# (32.3586259, -97.3959405)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# E 55TH PL
# (39.853822, -86.056486)
#
# S TRUMBULL AVE
# (41.666268, -87.7067038)
#
# E 81ST ST
# (41.4803912, -81.6310758)
#
# S KOLIN AVE
# (41.6804633, -87.7282162)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# S YALE AVE
# (36.0765216, -95.9221167)
#
# S HARPER AVE
# (33.3743982, -111.6339155)
#
# S ARCHER AVE
# (41.6335223, -88.0133585)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S HAMLIN AVE
# (42.0088243, -87.8504392)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# W WEST END AVE
# (41.8840066, -87.7595529)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S KOSTNER AVE
# (41.6651721, -87.7289951)
#
# S VINCENNES AVE
# (41.6979977, -87.6592612)
#
# W HARRISON ST
# (47.453523, -116.785825)
#
# S WOODLAWN AVE
# (41.7812374, -87.5962214)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# N HAMLIN AVE
# (41.9737701, -87.7232845)
#
# W WABANSIA AVE
# (41.9107882, -87.7995001)
#
# S PULASKI RD
# (41.6803208, -87.7198931)
#
# N HERMITAGE AVE
# (40.232782, -74.780752)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# N NATCHEZ AVE
# (41.9548213, -87.7893155)
#
# N MOBILE AVE
# (35.2845786, -93.1181537)
#
# N MANGO AVE
# (41.9608929, -87.7709224)
#
# E LOWER WACKER DR
# (41.8875576, -87.6174627)
#
# E LOWER WACKER DR
# (41.8875576, -87.6174627)
#
# S HOMAN AVE
# (41.6622485, -87.7046222)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# W KINZIE ST
# (41.8891372, -87.6357356)
#
# N Milwaukee Ave
# (42.451391, -88.091261)
#
# S EBERHART AVE
# (43.822127, -84.748397)
#
# W KENNEDY EXPY IB
# (41.8769483, -87.6457872)
#
# S CHICAGO BEACH DR
# (41.8059766, -87.5853623)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# W Addison St
# (42.226415, -84.406033)
#
# W ARMITAGE AVE
# (43.1023086, -87.9910021)
#
# W HARRISON ST
# (47.453523, -116.785825)
#
# E LOWER WACKER DR
# (41.8875576, -87.6174627)
#
# W ALDINE AVE
# (41.9418061, -87.6487849)
#
# W FULTON ST
# (40.6996535, -90.0114673)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# W Sheridan Rd
# (42.490117, -79.250962)
#
# S Kedzie Ave
# (41.7315967, -87.7021544)
#
# N LECLAIRE AVE
# (41.935091, -87.7540962)
#
# S TRIPP AVE
# (41.663533, -87.72595)
#
# W 66TH ST
# (40.7733596, -73.9809918)
#
# W DEMING PL
# (41.9292488, -87.6406316)
#
# S STONY ISLAND AVE
# (41.772423, -87.5862745)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# W CUYLER AVE
# (41.9551763, -87.6742845)
#
# W FRANKLIN BLVD
# (35.2598762, -81.214961)
#
# N CENTRAL PARK AVE
# (41.9751896, -87.7184185)
#
# N BEACON ST
# (41.4586084, -74.4140133)
#
# S YATES BLVD
# (41.7408204, -87.5660877)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# E 72ND ST
# (40.7710212, -73.9636252)
#
# W 72ND PL
# (25.8884828, -80.3539543)
#
# S BISHOP ST
# (39.5665983, -76.9892851)
#
# N TROY ST
# (41.9593759, -87.70697)
#
# N BERNARD ST
# (41.9720734, -87.7146943)
#
# N DRAKE AVE
# (41.9725027, -87.7171475)
#
# N TROY ST
# (41.9593759, -87.70697)
#
# N CLAREMONT AVE
# (36.106832, -80.228788)
#
# S ALBANY AVE
# (27.932852, -82.480986)
#
# E ST
# (50.4738724, 4.2358174)
#
# S DREXEL BLVD
# (35.4636206, -97.5703073)
#
# E 72ND ST
# (40.7710212, -73.9636252)
#
# W 47TH ST
# (40.7580163, -73.9817975)
#
# S MARYLAND AVE
# (39.5941256, -75.9378606)
#
# E ST
# (50.4738724, 4.2358174)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# W 71ST PL
# (25.8872768, -80.347878)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# S AVENUE N
# (31.532975, -97.437499)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# N ALBANY AVE
# (40.7076835, -73.465108)
#
# S BISHOP ST
# (39.5665983, -76.9892851)
#
# N OAKLEY BLVD
# (41.893065, -87.684323)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# N Wabash Ave
# (41.1450949, -87.8658414)
#
# S HERMITAGE AVE
# (41.7685166, -87.6675589)
#
# S TRIPP AVE
# (41.663533, -87.72595)
#
# E 43RD ST
# (44.9251197, -93.2396454)
#
# N SEELEY AVE
# (43.5619333, -94.7747364)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S SPRINGFIELD AVE
# (40.6858039, -74.3274558)
#
# S CARPENTER ST
# (35.240268, -81.338339)
#
# E 73RD PL
# (36.0577139, -95.9568994)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# S ADA ST
# (44.9307182, -93.0759931)
#
# W 70TH ST
# (32.442242, -93.866732)
#
# E 47TH ST
# (40.7546125, -73.9737345)
#
# S CLARK ST
# (44.955584, -90.795919)
#
# W GLADYS AVE
# (41.915226, -87.959294)
#
# W 21ST ST
# (44.961758, -93.306244)
#
# S LOOMIS ST
# (41.769112, -88.14147)
#
# W GORDON TER
# (41.9578365, -87.6498054)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# S EAST END AVE
# (40.7774069, -73.943042)
#
# W OHIO ST
# (40.646058, -83.609337)
#
# S KOLMAR AVE
# (41.6817099, -87.7322799)
#
# N RICHMOND ST
# (41.9557758, -87.7019847)
#
# W LAKE ST
# (41.8877192, -87.7651226)
#
# E 74TH ST
# (40.7710532, -73.9596512)
#
# S ALBANY AVE
# (27.932852, -82.480986)
#
# E ST
# (50.4738724, 4.2358174)
#
# W MONTROSE AVE
# (41.9607197, -87.7466474)
#
# S FAIRFIELD AVE
# (41.8828928, -88.0058916)
#
# N DRAKE AVE
# (41.9725027, -87.7171475)
#
# S LONGWOOD DR
# (41.1158215, -87.8298037)
#
# W ROOSEVELT RD
# (41.8568563, -88.1736282)
#
# N LOREL AVE
# (41.8840101, -87.7588689)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# S HALSTED ST
# (41.5420844, -87.6359687)
#
# S HARDING AVE
# (36.6834759, -119.7343476)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# S WESTERN AVE
# (43.5185145, -96.751124)
#
# S SAGINAW AVE
# (41.6427026, -87.5580689)
#
# S KIMBARK AVE
# (41.7673136, -87.5941382)
#
# S CHAMPLAIN AVE
# (32.1827548, -110.8194486)
#
# S MARQUETTE AVE
# (41.6317592, -87.5567079)
#
# W ST
# (55.8497133, -4.2656724)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# N ODELL AVE
# (39.1214083, -93.1948712)
#
# W 26TH ST
# (41.8444628, -87.7092909)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# W LELAND AVE
# (41.9666512, -87.7370944)
#
# S ESCANABA AVE
# (41.7482723, -87.55405)
#
# E 41ST PL
# (39.8325, -86.020578)
#
# N CENTRAL AVE
# (35.7718102, -91.6557941)
#
# S ELIZABETH ST
# (40.727094, -84.106756)
#
# W 13TH ST
# (40.5482226, -85.6954353)
#
# S ESCANABA AVE
# (41.7482723, -87.55405)
#
# S CARPENTER ST
# (35.240268, -81.338339)
#
# S TROY ST
# (42.4897468, -83.1419423)
#
# S THROOP ST
# (41.7467867, -87.6560654)
#
# W 21ST ST
# (44.961758, -93.306244)
#
# S HALSTED ST
# (41.5420844, -87.6359687)
#
# N NATCHEZ AVE
# (41.9548213, -87.7893155)
#
# S MAY ST
# (35.5997263, -77.5918349)
#
# S UNION AVE
# (47.2491253, -122.4836389)
#
# N MONITOR AVE
# (41.9791477, -87.7744717)
#
# N LAMON AVE
# (41.9242164, -87.7487482)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# S EWING AVE
# (32.7424571, -96.8126924)
#
# S LOOMIS BLVD
# (41.7570599, -87.6587609)
#
# W 96TH ST
# (40.7928721, -73.967548)
#
# W GRAND AVE
# (44.89992, -89.6139466)
#
# S PERRY AVE
# (27.74589, -81.794657)
#
# N HUDSON AVE
# (37.691596, -83.95988)
#
# S CHARLES ST
# (39.4041707, -88.8020472)
#
# W CORNELIA AVE
# (33.9618136, -98.6777071)
#
# W WARREN BLVD
# (41.8823807, -87.6651175)
#
# W 59TH ST
# (40.7646364, -73.9737661)
#
# N HOYNE AVE
# (41.9550717, -87.6812061)
#
# N ELSTON AVE
# (41.9624991, -87.731967)
#
# S WENTWORTH AVE
# (42.9981308, -87.8894434)
#
# S NORMAL BLVD
# (41.7792236, -87.637511)
#
# S LAKE SHORE DR SB
# W ST
# (55.8497133, -4.2656724)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# W TERMINAL ST
# (38.3711643, -88.065751)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# N GLENWOOD AVE
# (42.650887, -83.284998)
#
# N RICHMOND ST
# (41.9557758, -87.7019847)
#
# N NEENAH AVE
# (41.9419257, -87.7898424)
#
# S MILLARD AVE
# (36.725905, -119.6804604)
#
# W 13TH ST
# (40.5482226, -85.6954353)
#
# N MOODY AVE
# (27.9453048, -82.484032)
#
# N KEDVALE AVE
# (41.9640717, -87.7315451)
#
# S ARTESIAN AVE
# (34.0977413, -117.3182866)
#
# W 64TH PL
# (25.881035, -80.3378206)
#
# S PEORIA ST
# (39.5974063, -104.8480467)
#
# W KAMERLING AVE
# (41.9048703, -87.7639163)
#
# W WINONA ST
# (46.8469244, -92.0900123)
#
# S TALMAN AVE
# (41.8617849, -87.692024)
#
# W 55TH PL
# (25.87268, -80.338137)
#
# S PAULINA ST
# (41.878849, -87.6692204)
#
# S PAULINA ST
# (41.878849, -87.6692204)
#
# S AVENUE F
# (40.55307, -90.047893)
#
# S AVERS AVE
# (41.6734757, -87.7157121)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S ALLPORT ST
# (41.8549455, -87.6575679)
#
# N Marine Dr
# (33.8164549, -117.8300018)
#
# W 62ND ST
# (44.8909522, -93.3054532)
#
# S WALLACE ST
# (38.6625346, -87.3019057)
#
# W ROSCOE ST
# (41.9417774, -87.798255)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# S SACRAMENTO AVE
# (39.3373525, -74.4801189)
#
# W PL
# (39.0445999, -94.6029041)
#
# S ADA ST
# (44.9307182, -93.0759931)
#
# S ADA ST
# (44.9307182, -93.0759931)
#
# S COLES AVE
# (41.7483376, -87.5491898)

# %%
# Save Checkpoint 
df2014_geo = df_2014.copy()

# %%
# Filter location that is not null
df2014_geo = df2014_geo[df2014_geo['location'].notna()]

# %%
df2014_geo = impute_district(df2014_geo)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:113: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326

# %%
# Drop columns
df2014_geo.drop(['district', 'index_right'], axis=1, inplace=True)

# Rename columns
df2014_geo.rename(columns={'dist_num':'district'}, inplace=True)

# %%
# Impute updated ward values
df2014_geo = impute_ward(df2014_geo)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:69: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326

# %%
# Drop columns
df2014_geo.drop(['ward_left', 'index_right'], axis=1, inplace=True)

# Rename columns
df2014_geo.rename(columns={'ward_right':'ward'}, inplace=True)

# %%
# Impute updated district values
df2014_geo = impute_commareas(df2014_geo)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:91: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326

# %%
# Drop columns
df2014_geo.drop(['community_area', 'index_right'], axis=1, inplace=True)

# Rename columns
df2014_geo.rename(columns={'area_numbe':'community_area'}, inplace=True)

# %%
# Balance clean up of dataset after transformation
# Drop columns
df2014_geo.drop(['x_coordinate', 'y_coordinate'], axis=1, inplace=True)

# Assign null values in location description to 'OTHER (Specify)'
df2014_geo['location_description'].fillna('OTHER (SPECIFY)', inplace = True)

# %%
df2014_geo.to_csv('/content/drive/MyDrive/Colab Notebooks/capstone/assets/2014_crime_clean.csv', index=False)

# %%
df2014_geo.isnull().sum()
# Out:
# id                      0
# case_number             0
# date                    0
# block                   0
# iucr                    0
# primary_type            0
# description             0
# location_description    0
# arrest                  0
# domestic                0
# beat                    0
# fbi_code                0
# year                    0
# updated_on              0
# latitude                0
# longitude               0
# location                0
# day                     0
# month                   0
# day_of_week             0
# time                    0
# geometry                0
# district                0
# ward                    0
# community_area          0
# dtype: int64

# %% [markdown]
# ## Clean data (2013)

# %%
# from geopy.geocoders import Nominatim
geocoder = Nominatim(user_agent = 'crime_predictions')

# %%
df_2013 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/capstone/assets/2013_crime.csv')
df_2013.head()
# Out:
#          id case_number                 date                  block  iucr  \
# 0  11227517    JB138481  2013-02-10 00:00:00  071XX S LAFAYETTE AVE  0266
# 1  11042141    JA376559  2013-05-16 00:00:00        003XX W 64TH ST  1154
# 2  11042759    JA376850  2013-07-08 16:10:00    056XX N KENMORE AVE  1153
# 3  11042911    JA376915  2013-01-01 12:00:00    034XX N WESTERN AVE  1154
# 4  11043823    JA378025  2013-08-11 17:00:00       004XX N CLARK ST  0820
#
#               primary_type                              description  \
# 0  CRIMINAL SEXUAL ASSAULT                                PREDATORY
# 1       DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 2       DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 3       DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 4                    THEFT                           $500 AND UNDER
#
#         location_description  arrest  domestic  beat  district  ward  \
# 0                  RESIDENCE   False      True   731       7.0   6.0
# 1  HOSPITAL BUILDING/GROUNDS   False     False   722       7.0  20.0
# 2                        NaN   False     False  2022      20.0  48.0
# 3                       BANK   False     False  1921      19.0  47.0
# 4                 RESTAURANT   False     False  1831      18.0  42.0
#
#    community_area fbi_code  x_coordinate  y_coordinate  year  \
# 0            69.0       02           NaN           NaN  2013
# 1            68.0       11           NaN           NaN  2013
# 2            77.0       11           NaN           NaN  2013
# 3             5.0       11           NaN           NaN  2013
# 4             8.0       06           NaN           NaN  2013
#
#                updated_on  latitude  longitude location  day  month  \
# 0  08/30/2020 03:45:17 PM       NaN        NaN      NaN   10      2
# 1  08/05/2017 03:50:08 PM       NaN        NaN      NaN   16      5
# 2  08/05/2017 03:50:08 PM       NaN        NaN      NaN    8      7
# 3  08/05/2017 03:50:08 PM       NaN        NaN      NaN    1      1
# 4  08/06/2017 03:53:31 PM       NaN        NaN      NaN   11      8
#
#    day_of_week  time
# 0            6     0
# 1            3     0
# 2            0    16
# 3            1    12
# 4            6    17

# %%
df_2013.isnull().sum()
# Out:
# id                         0
# case_number                0
# date                       0
# block                      0
# iucr                       0
# primary_type               0
# description                0
# location_description     204
# arrest                     0
# domestic                   0
# beat                       0
# district                   0
# ward                       3
# community_area             4
# fbi_code                   0
# x_coordinate            1006
# y_coordinate            1006
# year                       0
# updated_on                 0
# latitude                1006
# longitude               1006
# location                1006
# day                        0
# month                      0
# day_of_week                0
# time                       0
# dtype: int64

# %%
replace_to_zero(df_2013)

# %%
index_list = missing_row_loc(df_2013)
# Out:
# 1006

# %%
impute_data(df_2013, index_list)
# Out:
# [0, 1, 2, 3, 4, 5, 6, 9, 11, 12, 15, 16, 20, 22, 23, 24, 29, 32, 33, 34, 36, 37, 42, 46, 53, 56, 89, 114, 117, 119, 127, 148, 149, 151, 160, 162, 164, 165, 166, 168, 169, 178, 180, 184, 186, 187, 188, 189, 190, 194, 196, 198, 199, 200, 201, 202, 203, 204, 206, 207, 208, 209, 210, 212, 214, 217, 218, 222, 225, 226, 227, 232, 233, 234, 235, 243, 249, 255, 256, 259, 260, 263, 264, 265, 266, 268, 271, 274, 275, 276, 277, 278, 279, 280, 281, 282, 283, 285, 286, 287, 288, 289, 290, 291, 292, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 337, 338, 339, 342, 344, 345, 346, 349, 352, 353, 361, 362, 366, 372, 373, 374, 381, 382, 384, 389, 391, 398, 405, 411, 412, 413, 414, 415, 416, 417, 418, 419, 421, 422, 423, 424, 426, 428, 429, 430, 432, 433, 434, 435, 436, 438, 439, 440, 441, 442, 443, 444, 445, 446, 447, 448, 449, 451, 452, 454, 455, 456, 457, 458, 461, 462, 463, 465, 466, 467, 468, 469, 470, 471, 474, 475, 477, 478, 479, 480, 483, 484, 486, 487, 488, 489, 490, 491, 492, 493, 494, 495, 496, 497, 498, 499, 500, 501, 502, 503, 504, 505, 506, 513, 514, 532, 550, 774, 792, 819, 865, 869, 873, 906, 909, 922, 925, 926, 928, 929, 930, 931, 932, 933, 934, 935, 937, 938, 939, 941, 943, 944, 945, 946, 947, 948, 950, 951, 952, 953, 954, 955, 956, 957, 958, 959, 960, 961, 963, 964, 965, 966, 967, 968, 969, 970, 971, 972, 973, 974, 975, 976, 977, 978, 980, 981, 982, 983, 984, 985, 986, 988, 989, 990, 991, 992, 993, 994, 997, 999, 1000, 1001, 1002, 1003, 1004, 1005, 1006, 1009, 1010, 1011, 1012, 1013, 1014, 1015, 1018, 1022, 1066, 1078, 1080, 1085, 1088, 1099, 1101, 1112, 1114, 1116, 1119, 1120, 1125, 1129, 1130, 1137, 1138, 1139, 1140, 1141, 1142, 1143, 1144, 1145, 1146, 1147, 1148, 1149, 1150, 1151, 1152, 1153, 1154, 1155, 1156, 1157, 1158, 1159, 1160, 1161, 1162, 1163, 1164, 1165, 1166, 1167, 1168, 1169, 1171, 1172, 1173, 1174, 1175, 1176, 1177, 1178, 1179, 1180, 1181, 1182, 1183, 1184, 1185, 1186, 1187, 1188, 1189, 1190, 1191, 1192, 1193, 1194, 1195, 1196, 1197, 1198, 1199, 1200, 1201, 1202, 1203, 1204, 1205, 1206, 1207, 1208, 1209, 1210, 1211, 1212, 1213, 1214, 1215, 1216, 1217, 1218, 1219, 1220, 1221, 1222, 1223, 1224, 1225, 1226, 1227, 1228, 1229, 1230, 1232, 1233, 1234, 1235, 1236, 1237, 1238, 1240, 1241, 1242, 1243, 1244, 1245, 1246, 1247, 1248, 1249, 1250, 1251, 1252, 1253, 1254, 1255, 1256, 1257, 1258, 1259, 1260, 1261, 1262, 1263, 1264, 1265, 1266, 1268, 1269, 1270, 1271, 1272, 1273, 1274, 1275, 1276, 1277, 1278, 1279, 1280, 1281, 1282, 1283, 1284, 1285, 1286, 1287, 1288, 1289, 1290, 1291, 1292, 1293, 1294, 1295, 1296, 1297, 1298, 1299, 1300, 1301, 1302, 1303, 1305, 1306, 1307, 1308, 1309, 1310, 1311, 1312, 1313, 1314, 1315, 1316, 1317, 1318, 1319, 1320, 1321, 1322, 1323, 1324, 1325, 1326, 1327, 1328, 1329, 1330, 1331, 1332, 1333, 1334, 1335, 1336, 1337, 1338, 1339, 1340, 1341, 1342, 1343, 1344, 1345, 1346, 1347, 1927, 2209, 6926, 7355, 7412, 12359, 12531, 12616, 12863, 14117, 15345, 16556, 19466, 22937, 22976, 23516, 26832, 27637, 27851, 30170, 30995, 34737, 35945, 35989, 35995, 35998, 36316, 39579, 39580, 40753, 41135, 41391, 41405, 42651, 42837, 43291, 43342, 43358, 44046, 45455, 45478, 45805, 46167, 46172, 46177, 46185, 46202, 46726, 46854, 46982, 47399, 47652, 47940, 48114, 48435, 48673, 49298, 49320, 49321, 49613, 50726, 51014, 51170, 51235, 51266, 51272, 51675, 51676, 51677, 51678, 51679, 51680, 51681, 51683, 51684, 51685, 51686, 51687, 51688, 51689, 51690, 51691, 51692, 51693, 51694, 51695, 51696, 51697, 51698, 51699, 51700, 51702, 51703, 51704, 51705, 51706, 51707, 51708, 51709, 51710, 51711, 51712, 51713, 51714, 51715, 51716, 67812, 82749, 93951, 97614, 99545, 99676, 104729, 111141, 122209, 172412, 267729, 275948, 277239, 282433, 284804, 285049, 285477, 285541, 285595, 285601, 285606, 285609, 285610, 285614, 285616, 285878, 303973, 304007, 304008, 304009, 304010, 304 ...
#
# S LAFAYETTE AVE
# (39.334709, -74.489355)
#
# W 64TH ST
# (39.0130173, -94.802986)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# N WESTERN AVE
# (35.5293143, -97.5298153)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# N ALBANY AVE
# (40.7076835, -73.465108)
#
# N MULLIGAN AVE
# (41.9602275, -87.7855735)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# W BYRON ST
# (41.9503382, -87.7955338)
#
# N PULASKI RD
# (41.9640877, -87.7278964)
#
# N AVONDALE AVE
# (41.9389804, -87.7082252)
#
# E MARQUETTE RD
# (41.7727745, -87.6280678)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# S KEDZIE AVE
# (41.7315967, -87.7021544)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S NORMAL AVE
# (37.720105, -89.21769)
#
# S MERRILL AVE
# (47.1026257, -104.715102)
#
# E PL
# (14.8370417, -89.14104361631954)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# W 65TH ST
# (34.6902193, -92.3298401)
#
# S HOUSTON AVE
# (29.7104805, -98.1173779)
#
# S ROCKWELL ST
# (33.3290958, -111.7293356)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# N HARDING AVE
# (41.9937042, -87.7276304)
#
# W 61ST PL
# (25.879063, -80.307356)
#
# S NORMAL AVE
# (37.720105, -89.21769)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# S KENWOOD AVE
# (41.8060326, -87.5935411)
#
# N ROCKWELL ST
# (33.3744844, -111.7302071)
#
# W ST
# (55.8497133, -4.2656724)
#
# S MARSHFIELD AVE
# (41.8093553, -87.6662057)
#
# N SAYRE AVE
# (41.9628625, -87.8025486)
#
# S MAPLEWOOD AVE
# (36.0250954, -95.9064784)
#
# E 46TH ST
# (44.917865, -93.2041653)
#
# W FULTON ST
# (40.6996535, -90.0114673)
#
# W 70TH ST
# (32.442242, -93.866732)
#
# W DIVERSEY AVE
# (41.9263942, -88.0053438)
#
# S MAY ST
# (35.5997263, -77.5918349)
#
# S KILPATRICK AVE
# (41.8149584, -87.7409068)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# N LINDER AVE
# (43.4908412, -116.4138278)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# S DORCHESTER AVE
# (41.861114, -88.126156)
#
# W BERTEAU AVE
# (41.9561908, -87.8158422)
#
# S PRINCETON AVE
# (39.7884436, -75.1461365)
#
# N MONITOR AVE
# (41.9791477, -87.7744717)
#
# S WOODLAWN AVE
# (41.7812374, -87.5962214)
#
# S COTTAGE GROVE AVE
# (41.6856412, -87.6114137)
#
# S PHILLIPS AVE
# (43.513078, -96.7262166)
#
# W GLADYS AVE
# (41.915226, -87.959294)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# S PAXTON AVE
# (41.7316571, -87.5707162)
#
# S COTTAGE GROVE AVE
# (41.6856412, -87.6114137)
#
# S MAPLEWOOD AVE
# (36.0250954, -95.9064784)
#
# N HAMLIN BLVD
# (41.8818123, -87.7208182)
#
# S WOLCOTT AVE
# (41.8741687, -87.6740297)
#
# W 25TH ST
# (39.802821, -86.1734111)
#
# S MERRILL AVE
# (47.1026257, -104.715102)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# N RIDGE BLVD
# (38.5054097, -77.9726234)
#
# S YALE AVE
# (36.0765216, -95.9221167)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# W CONGRESS PKWY
# (41.8750866, -87.6539866)
#
# W WASHINGTON ST
# (40.194732, -85.391486)
#
# S CREGIER AVE
# (41.7663619, -87.5812232)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# S DEARBORN ST
# (47.5958836, -122.318572)
#
# N TROY ST
# (41.9593759, -87.70697)
#
# S LUELLA AVE
# (41.7589872, -87.5700366)
#
# N HARDING AVE
# (41.9937042, -87.7276304)
#
# S KENNETH AVE
# (41.6814466, -87.7302028)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# S PERRY AVE
# (27.74589, -81.794657)
#
# S YATES BLVD
# (41.7408204, -87.5660877)
#
# W ENGLEWOOD AVE
# (40.895974, -73.983219)
#
# S MOZART ST
# (41.726308, -87.6933241)
#
# E ST
# (50.4738724, 4.2358174)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# N MOBILE AVE
# (35.2845786, -93.1181537)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# N RICHMOND ST
# (41.9557758, -87.7019847)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# S CARPENTER ST
# (35.240268, -81.338339)
#
# S EGGLESTON AVE
# (35.407396, -97.5137083)
#
# S SOUTH SHORE DR
# (41.7687175, -87.5665152)
#
# S PRINCETON AVE
# (39.7884436, -75.1461365)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# S FRANCISCO AVE
# (37.6847697, -122.4009224)
#
# W SCHUBERT AVE
# (41.921548, -88.096436)
#
# S SACRAMENTO AVE
# (39.3373525, -74.4801189)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# N BELL AVE
# (32.2464153, -110.8940884)
#
# S DORCHESTER AVE
# (41.861114, -88.126156)
#
# W 63RD ST
# (41.7733805, -87.9889844)
#
# S GREEN ST
# (37.8040878, -87.6368672)
#
# S CENTRAL PARK AVE
# (41.7169517, -87.7114806)
#
# E 72ND ST
# (40.7710212, -73.9636252)
#
# S COLFAX AVE
# (30.853988, -96.9914143)
#
# W ROOSEVELT RD
# (41.8568563, -88.1736282)
#
# S WOLCOTT AVE
# (41.8741687, -87.6740297)
#
# S CLYDE AVE
# (28.2911755, -81.4131903)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# W ADDISON ST
# (42.226415, -84.406033)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# S HARVARD AVE
# (40.613458, -98.098577)
#
# W 18TH PL
# (30.230237, -85.651847)
#
# N ST LOUIS AVE
# (41.9727203, -87.7159449)
#
# S LA SALLE ST
# (41.742861, -88.3242315)
#
# S DELANO CT E
# (41.8674021, -87.6325503)
#
# S ELLIS AVE
# (35.309552, -78.616879)
#
# N MASON AVE
# (42.354338, -85.244316)
#
# S SOUTH SHORE DR
# (41.7687175, -87.5665152)
#
# S MARQUETTE AVE
# (41.6317592, -87.5567079)
#
# N LONG AVE
# (31.872625, -102.526908)
#
# W 35TH ST
# (41.881364, -103.6683128)
#
# W FULTON ST
# (40.6996535, -90.0114673)
#
# N NORDICA AVE
# (41.9489763, -87.8034519)
#
# N SEDGWICK ST
# (37.693255, -97.36976)
#
# E ST
# (50.4738724, 4.2358174)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# S DEARBORN ST
# (47.5958836, -122.318572)
#
# S LONGWOOD DR
# (41.1158215, -87.8298037)
#
# W 83RD ST
# (41.7432634, -87.6499076)
#
# N PINE AVE
# (42.669591, -73.790953)
#
# W WACKER DR
# (30.4717592, -84.349793)
#
# W WAVELAND AVE
# (41.9466715, -87.8113037)
#
# N WINTHROP AVE
# (41.9873032, -87.6581226)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# S DAUPHIN AVE
# (27.8698258, -82.4986097)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# N LAVERGNE AVE
# (41.9090105, -87.9045527)
#
# S TRUMBULL AVE
# (41.666268, -87.7067038)
#
# E PL
# (14.8370417, -89.14104361631954)
#
# S LOOMIS BLVD
# (41.7570599, -87.6587609)
#
# W CORTEZ ST
# (33.5897649, -112.4664308)
#
# N LEAMINGTON AVE
# (41.8986064, -87.7544655)
#
# W HUBBARD ST
# (41.7159012, -89.3389805)
#
# S HONORE ST
# (41.8267808, -87.6715176)
#
# N CLEAVER ST
# (41.90877725, -87.66409688742331)
#
# W 24TH ST
# (39.8009909, -86.170301)
#
# S HONORE ST
# (41.8267808, -87.6715176)
#
# W POLK ST
# (30.7116929, -94.9383233)
#
# E 69TH ST
# (39.001852, -94.5613311)
#
# W AUGUSTA BLVD
# (41.4210887, -87.732417)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# W HENDERSON ST
# (35.6845746, -80.4331586)
#
# W PL
# (39.0445999, -94.6029041)
#
# N PAULINA ST
# (41.9902949, -87.6714344)
#
# S WALLACE ST
# (38.6625346, -87.3019057)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# W ROOSEVELT RD
# (41.8568563, -88.1736282)
#
# W LE MOYNE ST
# (41.9077136, -87.7331889)
#
# S KOSTNER AVE
# (41.6651721, -87.7289951)
#
# S CALUMET AVE
# (41.7034033, -86.871671)
#
# S KEELER AVE
# (36.7501253, -95.9789915)
#
# E ELM ST
# (37.2052899, -93.2328025)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# W KINZIE ST
# (41.8891372, -87.6357356)
#
# W LELAND AVE
# (41.9666512, -87.7370944)
#
# W BRYN MAWR AVE
# (41.983045, -87.711304)
#
# S PARNELL AVE
# (41.6335259, -87.6353874)
#
# S Constance Ave
# (39.1322267, -86.4965916)
#
# W 14TH ST
# (40.7370431, -73.9960774)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# S OAK PARK AVE
# (41.8815808, -87.7943023)
#
# S HERMITAGE AVE
# (41.7685166, -87.6675589)
#
# W TOUHY AVE
# (42.0118322, -87.7491207)
#
# S LEAMINGTON AVE
# (41.7619164, -87.7501006)
#
# S CALHOUN AVE
# (41.6390695, -87.5616751)
#
# W DIVERSEY AVE
# (41.9263942, -88.0053438)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# W KINZIE ST
# (41.8891372, -87.6357356)
#
# N CENTRAL PARK AVE
# (41.9751896, -87.7184185)
#
# N WASHTENAW AVE
# (41.9253795, -87.6949927)
#
# S STEWART AVE
# (28.290846, -81.4066339)
#
# S THROOP ST
# (41.7467867, -87.6560654)
#
# S CARPENTER ST
# (35.240268, -81.338339)
#
# N WELLS ST
# (30.831592, -83.286031)
#
# E 53RD ST
# (40.7580248, -73.9701634)
#
# S EMERALD AVE
# (33.3965996, -111.8035831)
#
# E PL
# (14.8370417, -89.14104361631954)
#
# W M21 ST
# (35.7065151, 139.7601318)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# N WELLS ST
# (30.831592, -83.286031)
#
# W BERENICE AVE
# (41.9494861, -87.7950096)
#
# N LONG AVE
# (31.872625, -102.526908)
#
# S DREXEL BLVD
# (35.4636206, -97.5703073)
#
# S MARYLAND AVE
# (39.5941256, -75.9378606)
#
# W PRATT BLVD
# (42.0054657, -87.6658226)
#
# N LINCOLN AVE
# (45.660956, -122.6824777)
#
# N MELVINA AVE
# (42.0121329, -87.7817803)
#
# W DOUGLAS BLVD
# (41.8629927, -87.7029508)
#
# W 63RD ST
# (41.7733805, -87.9889844)
#
# W LEXINGTON ST
# (39.0325997, -97.5948929)
#
# S SOUTH SHORE DR
# (41.7687175, -87.5665152)
#
# S CICERO AVE
# (41.8545413, -87.7443874)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# S WOOD ST
# (41.343196, -83.119849)
#
# S EMERALD AVE
# (33.3965996, -111.8035831)
#
# S MAY ST
# (35.5997263, -77.5918349)
#
# N SPRINGFIELD AVE
# (41.9646307, -87.7254887)
#
# S MOZART ST
# (41.726308, -87.6933241)
#
# S WOOD ST
# (41.343196, -83.119849)
#
# S CAMPBELL AVE
# (37.1712552, -93.2953919)
#
# S HAMLIN AVE
# (42.0088243, -87.8504392)
#
# S ELIZABETH ST
# (40.727094, -84.106756)
#
# E 68TH ST
# (36.064123, -95.9448098)
#
# S ELIZABETH ST
# (40.727094, -84.106756)
#
# W 76TH PL
# (39.893339, -86.188147)
#
# S YATES BLVD
# (41.7408204, -87.5660877)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# W MAYPOLE AVE
# (41.8835952, -87.7087902)
#
# S ESSEX AVE
# (39.3133874, -76.4565138)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# S ANTHONY AVE
# (37.149086, -98.028778)
#
# N DAMEN AVE
# (41.9744669, -87.6793492)
#
# W WILSON AVE
# (47.6575559, -117.4351579)
#
# W ROOSEVELT RD
# (41.8568563, -88.1736282)
#
# W LAWRENCE AVE
# (41.9683042, -87.7231431)
#
# W GIDDINGS ST
# (41.9673952, -87.723111)
#
# N KARLOV AVE
# (41.9677725, -87.7304613)
#
# S SOUTH SHORE DR
# (41.7687175, -87.5665152)
#
# S TALMAN AVE
# (41.8617849, -87.692024)
#
# S INDEPENDENCE BLVD
# (36.8059, -76.116529)
#
# W 59TH ST
# (40.7646364, -73.9737661)
#
# E 70TH ST
# (41.4801992, -81.640323)
#
# W LEXINGTON ST
# (39.0325997, -97.5948929)
#
# W WABANSIA AVE
# (41.9107882, -87.7995001)
#
# N Sayre ave
# (41.9628625, -87.8025486)
#
# W ST
# (55.8497133, -4.2656724)
#
# W THOMAS ST
# (43.230666, -75.469829)
#
# W LEXINGTON ST
# (39.0325997, -97.5948929)
#
# E 78TH ST
# (36.0516381, -95.9637058)
#
# N LOREL AVE
# (41.8840101, -87.7588689)
#
# E 62ND ST
# (44.890728, -93.259847)
#
# S HOUSTON AVE
# (29.7104805, -98.1173779)
#
# W 50TH PL
# (25.8680845, -80.3072278)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# S SANGAMON ST
# (39.5902655, -89.7359101)
#
# S KILDARE AVE
# (41.6744106, -87.7275156)
#
# N PULASKI RD
# (41.9640877, -87.7278964)
#
# N NORTHWEST HWY
# (42.0193599, -87.8423973)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# N ORLEANS ST
# (34.8209213, -87.6356312)
#
# W HARRISON ST
# (47.453523, -116.785825)
#
# W VERMONT ST
# (39.7724557, -86.2529508)
#
# W HARRISON ST
# (47.453523, -116.785825)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W FULTON ST
# (40.6996535, -90.0114673)
#
# W 51ST ST
# (40.7597316, -73.9780866)
#
# N KEELER AVE
# (31.890888, -102.393391)
#
# W PL
# (39.0445999, -94.6029041)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# S ARCHER AVE
# (41.6335223, -88.0133585)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# W 69TH PL
# (25.8853991, -80.3477838)
#
# S EWING AVE
# (32.7424571, -96.8126924)
#
# S CREGIER AVE
# (41.7663619, -87.5812232)
#
# W 74TH ST
# (40.780251, -73.9814398)
#
# S KINGSTON AVE
# (36.044406, -95.9074742)
#
# W NELSON ST
# (39.937473, -94.841012)
#
# W WACKER DR
# (30.4717592, -84.349793)
#
# S HERMITAGE AVE
# (41.7685166, -87.6675589)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# W TOUHY AVE
# (42.0118322, -87.7491207)
#
# N MAYFIELD AVE
# (34.1105096, -117.2902727)
#
# W ROSEMONT AVE
# (38.8094493, -77.0631869)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# W ST
# (55.8497133, -4.2656724)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# W WRIGHTWOOD AVE
# (41.9247283, -87.9553717)
#
# W LEXINGTON ST
# (39.0325997, -97.5948929)
#
# W CERMAK RD
# (41.8495374, -87.849713)
#
# N PARKSIDE AVE
# (34.082432, -117.6296776)
#
# S MANISTEE AVE
# (41.6390183, -87.5555637)
#
# S KOMENSKY AVE
# (41.7242244, -87.7231031)
#
# W THOMAS ST
# (43.230666, -75.469829)
#
# W DEVON AVE
# (41.9973572, -87.7114381)
#
# S SPRINGFIELD AVE
# (40.6858039, -74.3274558)
#
# N LAKEWOOD AVE
# (31.856847, -102.514627)
#
# S SANGAMON ST
# (39.5902655, -89.7359101)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# N LEAMINGTON AVE
# (41.8986064, -87.7544655)
#
# S HAMILTON AVE
# (29.4083447, -98.5341118)
#
# E 67TH ST
# (31.9089805, -102.3842858)
#
# W 21ST PL
# (41.579758, -87.3761617)
#
# S HERMITAGE AVE
# (41.7685166, -87.6675589)
#
# W 44TH ST
# (40.680314, -74.107708)
#
# W 79TH PL
# (25.89498, -80.294083)
#
# W 38TH PL
# (41.548344, -87.2952495)
#
# S AVENUE H
# (40.552806, -90.05225)
#
# W 63RD ST
# (41.7733805, -87.9889844)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# S CLYDE AVE
# (28.2911755, -81.4131903)
#
# W 24TH ST
# (39.8009909, -86.170301)
#
# S HERMITAGE AVE
# (41.7685166, -87.6675589)
#
# W ARMITAGE AVE
# (43.1023086, -87.9910021)
#
# S UNIVERSITY AVE
# (40.2215138, -111.658881)
#
# W 57TH ST
# (40.7714466, -73.9940769)
#
# S SPRINGFIELD AVE
# (40.6858039, -74.3274558)
#
# E 53RD ST
# (40.7580248, -73.9701634)
#
# S VERNON AVE
# (32.72251, -96.836774)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# S INGLESIDE AVE
# (41.7403543, -87.601287)
#
# S WESTERN AVE
# (43.5185145, -96.751124)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# W ARGYLE ST
# (57.8956842, -5.1630045)
#
# N Southport Ave
# (41.9507055, -87.6641098)
#
# S KIMBARK AVE
# (41.7673136, -87.5941382)
#
# S PARNELL AVE
# (41.6335259, -87.6353874)
#
# N CICERO AVE
# (42.0121975, -87.7479383)
#
# W ADDISON ST
# (42.226415, -84.406033)
#
# W RANDOLPH ST
# (36.2743344, -90.9816148)
#
# N DAMEN AVE
# (41.9744669, -87.6793492)
#
# W ARTHINGTON ST
# (41.8700106, -87.7112288)
#
# E 53RD ST
# (40.7580248, -73.9701634)
#
# N PINE AVE
# (42.669591, -73.790953)
#
# S EMERALD AVE
# (33.3965996, -111.8035831)
#
# W LEXINGTON ST
# (39.0325997, -97.5948929)
#
# S TRIPP AVE
# (41.663533, -87.72595)
#
# E 71ST ST
# (41.5110354, -81.6395881)
#
# W 64TH ST
# (39.0130173, -94.802986)
#
# N AVERS AVE
# (41.9628652, -87.724203)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# S ADA ST
# (44.9307182, -93.0759931)
#
# S PRINCETON AVE
# (39.7884436, -75.1461365)
#
# S TALMAN AVE
# (41.8617849, -87.692024)
#
# S DREXEL BLVD
# (35.4636206, -97.5703073)
#
# W CORTEZ ST
# (33.5897649, -112.4664308)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# S KINGSTON AVE
# (36.044406, -95.9074742)
#
# S KINGSTON AVE
# (36.044406, -95.9074742)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# E 47TH PL
# (41.5324031, -87.3313342)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# S EAST END AVE
# (40.7774069, -73.943042)
#
# S LITUANICA AVE
# (41.8276171, -87.6476628)
#
# W 66TH ST
# (40.7733596, -73.9809918)
#
# W 75TH ST
# (44.8673118, -93.306107)
#
# S PAXTON AVE
# (41.7316571, -87.5707162)
#
# W WELLINGTON AVE
# (38.1838186, -85.7649883)
#
# W 41ST ST
# (43.5148333, -96.769579)
#
# S Princeton ave
# (39.7884436, -75.1461365)
#
# S CICERO AV
# (41.8545413, -87.7443874)
#
# N TRUMBULL AVE
# (45.5965005, -122.7536356)
#
# N MANNHEIM RD
# (41.9042609, -87.8837903)
#
# S EMERALD AVE
# (33.3965996, -111.8035831)
#
# W 60TH PL
# (25.877393, -80.338291)
#
# W WARREN BLVD
# (41.8823807, -87.6651175)
#
# W HYACINTH ST
# (41.9919789, -87.7857673)
#
# S Michigan Ave
# (42.59934, -83.9336293)
#
# N AVERS AVE
# (41.9628652, -87.724203)
#
# N MOZART ST
# (41.963078, -87.699749)
#
# N AUSTIN AVE
# (41.912831, -87.7753338)
#
# N NORMANDY AVE
# (32.3607574, -95.2956254)
#
# S WESTERN AVE
# (43.5185145, -96.751124)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# N MAYFIELD AVE
# (34.1105096, -117.2902727)
#
# S YATES AVE
# (41.1127251, -87.8911556)
#
# W DOUGLAS BLVD
# (41.8629927, -87.7029508)
#
# W 21ST ST
# (44.961758, -93.306244)
#
# S WOODLAWN AVE
# (41.7812374, -87.5962214)
#
# S MC VICKER AVE
# (41.7720642, -87.7721541)
#
# W CATALPA AVE
# (41.9812028, -87.7124733)
#
# W RAVEN ST
# (41.9950834, -87.7834843)
#
# W ontario st
# (35.0943283, -85.3096809)
#
# E 46TH ST
# (44.917865, -93.2041653)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# N WESTERN AVE
# (35.5293143, -97.5298153)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# W TERMINAL ST
# (38.3711643, -88.065751)
#
# S WOLCOTT AVE
# (41.8741687, -87.6740297)
#
# N MAGNOLIA AVE
# (29.1969846, -82.1365046)
#
# S ELIZABETH ST
# (40.727094, -84.106756)
#
# S CHAMPLAIN AVE
# (32.1827548, -110.8194486)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# S ELLIS AVE
# (35.309552, -78.616879)
#
# S MARYLAND AVE
# (39.5941256, -75.9378606)
#
# S PULASKI RD
# (41.6803208, -87.7198931)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# W WILCOX ST
# (39.7729655, -86.2196271)
#
# S RIDGEWAY AVE
# (35.61739, -82.3173401)
#
# S CLYDE AVE
# (28.2911755, -81.4131903)
#
# W DIVISION ST
# (38.2597099, -87.9979169)
#
# S SACRAMENTO AVE
# (39.3373525, -74.4801189)
#
# S RIDGELAND AVE
# (41.8835463, -87.7845574)
#
# S PRINCETON AVE
# (39.7884436, -75.1461365)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# N BEACON ST
# (41.4586084, -74.4140133)
#
# S LAVERGNE AVE
# (41.6916676, -87.7446407)
#
# S AVENUE J
# (34.1782421, -103.3451898)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# W WELLINGTON AVE
# (38.1838186, -85.7649883)
#
# S MERRILL AVE
# (47.1026257, -104.715102)
#
# S HERMITAGE AVE
# (41.7685166, -87.6675589)
#
# S WENTWORTH AVE
# (42.9981308, -87.8894434)
#
# S CHURCH ST
# (41.2952576, -82.9712879)
#
# S TROY ST
# (42.4897468, -83.1419423)
#
# S AVENUE N
# (31.532975, -97.437499)
#
# S STONY ISLAND AVE
# (41.772423, -87.5862745)
#
# S SPAULDING AVE
# (34.0288086, -118.3700242)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# S OAKLEY AVE
# (41.6631708, -86.1244023)
#
# E OHIO ST
# (40.601786, -84.084445)
#
# W GREGORY ST
# (42.0735492, -87.9441124)
#
# S WINCHESTER AVE
# (46.406387, -105.830479)
#
# S MARYLAND AVE
# (39.5941256, -75.9378606)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# S KARLOV AVE
# (41.7139045, -87.7235728)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# S LAFAYETTE AVE
# (39.334709, -74.489355)
#
# W AINSLIE ST
# (41.9701978, -87.7164722)
#
# S TRUMBULL AVE
# (41.666268, -87.7067038)
#
# S WALLACE ST
# (38.6625346, -87.3019057)
#
# S YALE AVE
# (36.0765216, -95.9221167)
#
# W PL
# (39.0445999, -94.6029041)
#
# S HARDING AVE
# (36.6834759, -119.7343476)
#
# N TROY ST
# (41.9593759, -87.70697)
#
# S EBERHART AVE
# (43.822127, -84.748397)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# S GREEN ST
# (37.8040878, -87.6368672)
#
# W HADDON AVE
# (41.9025006, -87.6659391)
#
# N LONG AVE
# (31.872625, -102.526908)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# S PEORIA ST
# (39.5974063, -104.8480467)
#
# S CHURCH ST
# (41.2952576, -82.9712879)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# S ELIZABETH ST
# (40.727094, -84.106756)
#
# N MAJOR AVE
# (36.0352811, -114.9680661)
#
# N WILTON AVE
# (42.42707, -88.094391)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# W NELSON ST
# (39.937473, -94.841012)
#
# S PERRY AVE
# (27.74589, -81.794657)
#
# N KENNETH AVE
# (41.9717719, -87.7392712)
#
# N HARLEM AVE
# (37.093364, -94.529365)
#
# W 65TH ST
# (34.6902193, -92.3298401)
#
# W 55TH ST
# (40.7692044, -73.9927944)
#
# N BROADWAY
# (40.9696948, -73.8844801)
#
# S HONORE ST
# (41.8267808, -87.6715176)
#
# N OKETO AVE
# (41.952203, -87.8122027)
#
# N KEDZIE AVE
# (41.981245, -87.7088348)
#
# S HOUSTON AVE
# (29.7104805, -98.1173779)
#
# W RACE AVE
# (35.2508634, -91.74748)
#
# W MAYPOLE AVE
# (41.8835952, -87.7087902)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# E 57TH ST
# (40.7629694, -73.9739676)
#
# N LAKEWOOD AVE
# (31.856847, -102.514627)
#
# W WILSON AVE
# (47.6575559, -117.4351579)
#
# N LAWNDALE AVE
# (41.9592196, -87.720432)
#
# W PL
# (39.0445999, -94.6029041)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# W CONGRESS PKWY
# (41.8750866, -87.6539866)
#
# S EVANS AVE
# (35.509722, -97.9558699)
#
# S DREXEL AVE
# (33.369843, -111.623825)
#
# S TRIPP AVE
# (41.663533, -87.72595)
#
# S DREXEL AVE
# (33.369843, -111.623825)
#
# E MARQUETTE RD
# (41.7727745, -87.6280678)
#
# W 83RD ST
# (41.7432634, -87.6499076)
#
# S CORNELL AVE
# (42.119526, -87.95127)
#
# N KEDZIE AVE
# (41.981245, -87.7088348)
#
# W 67TH PL
# (25.8836759, -80.3255296)
#
# S BURLEY AVE
# (41.7376517, -87.5453086)
#
# S HERMITAGE AVE
# (41.7685166, -87.6675589)
#
# S SOUTH SHORE DR
# (41.7687175, -87.5665152)
#
# S WALLACE ST
# (38.6625346, -87.3019057)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# N CLYBOURN AVE
# (41.9273774, -87.6724654)
#
# S CENTRAL AVE
# (40.8950402, -74.0839635)
#
# W DOUGLAS BLVD
# (41.8629927, -87.7029508)
#
# E 89TH PL
# (36.0340257, -95.9045251)
#
# S PEORIA ST
# (39.5974063, -104.8480467)
#
# N LEAMINGTON AVE
# (41.8986064, -87.7544655)
#
# S WOLCOTT AVE
# (41.8741687, -87.6740297)
#
# E ST
# (50.4738724, 4.2358174)
#
# W PETERSON AVE
# (41.9903163, -87.7190017)
#
# E 87TH PL
# (36.038195, -95.888076)
#
# S KOLIN AVE
# (41.6804633, -87.7282162)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# S AVENUE M
# (31.773624, -97.579064)
#
# W 21ST ST
# (44.961758, -93.306244)
#
# S PEORIA ST
# (39.5974063, -104.8480467)
#
# N ASHLAND BLVD
# (42.0066203, -87.6699972)
#
# E 83RD ST
# (41.5024109, -81.6295886)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# W 14TH ST
# (40.7370431, -73.9960774)
#
# W 15TH ST
# (44.9689141, -93.2867103)
#
# N RAVENSWOOD AVE
# (41.9688187, -87.6741627)
#
# S HONORE ST
# (41.8267808, -87.6715176)
#
# S SPRINGFIELD AVE
# (40.6858039, -74.3274558)
#
# S FAIRFIELD AVE
# (41.8828928, -88.0058916)
#
# S FOREST AVE
# (42.2736405, -83.7331125)
#
# N LECLAIRE AVE
# (41.935091, -87.7540962)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# S ST LAWRENCE AVE
# (41.7682281, -87.6104913)
#
# W ST
# (55.8497133, -4.2656724)
#
# S SOUTH SHORE DR
# (41.7687175, -87.5665152)
#
# W OHIO ST
# (40.646058, -83.609337)
#
# N KEYSTONE AVE
# (42.0001236, -76.5351751)
#
# S MC DOWELL AVE
# (31.220963, -81.473986)
#
# S ADA ST
# (44.9307182, -93.0759931)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# W ST
# (55.8497133, -4.2656724)
#
# W GLADYS AVE
# (41.915226, -87.959294)
#
# S WENTWORTH AVE
# (42.9981308, -87.8894434)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# S RIDGELAND AVE
# (41.8835463, -87.7845574)
#
# S ELIZABETH ST
# (40.727094, -84.106756)
#
# N AUSTIN AVE
# (41.912831, -87.7753338)
#
# S LA SALLE ST
# (41.742861, -88.3242315)
#
# W WARREN BLVD
# (41.8823807, -87.6651175)
#
# S COLFAX AVE
# (30.853988, -96.9914143)
#
# W FLOURNOY ST
# (28.406267, -97.7593919)
#
# N WHIPPLE ST
# (41.9721178, -87.7049131)
#
# W HIRSCH ST
# (41.9062185, -87.7313087)
#
# E 67TH ST
# (31.9089805, -102.3842858)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# W ROOSEVELT RD
# (41.8568563, -88.1736282)
#
# W SCOTT ST
# (41.661966, -90.591106)
#
# W ROOSEVELT RD
# (41.8568563, -88.1736282)
#
# S FRANCISCO AVE
# (37.6847697, -122.4009224)
#
# S CALIFORNIA AVE
# (34.1163848, -118.0008539)
#
# S CHRISTIANA AVE
# (28.6675036, -81.4969422)
#
# W 79TH ST
# (40.7849838, -73.9826637)
#
# E OHIO ST
# (40.601786, -84.084445)
#
# S KEELER AVE
# (36.7501253, -95.9789915)
#
# S RICHMOND ST
# (44.8899249, -88.3024977)
#
# N NATCHEZ AVE
# (41.9548213, -87.7893155)
#
# W HUBBARD ST
# (41.7159012, -89.3389805)
#
# S KEDVALE AVE
# (41.6474182, -87.7222793)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# S HERMITAGE AVE
# (41.7685166, -87.6675589)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# W CLARENCE AVE
# (41.9945038, -87.8125473)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# N MC VICKER AVE
# (41.7720642, -87.7721541)
#
# N LA SALLE ST
# (30.398997, -96.0961872)
#
# S SPAULDING AVE
# (34.0288086, -118.3700242)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# W DIVISION ST
# (38.2597099, -87.9979169)
#
# N CENTRAL AVE
# (35.7718102, -91.6557941)
#
# W GORDON TER
# (41.9578365, -87.6498054)
#
# S STONY ISLAND AVE
# (41.772423, -87.5862745)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# S LEAMINGTON AVE
# (41.7619164, -87.7501006)
#
# S PROSPECT AVE
# (33.8413909, -118.3763438)
#
# S South Shore Dr
# (41.7687175, -87.5665152)
#
# N CENTRAL PARK AVE
# (41.9751896, -87.7184185)
#
# W BLOOMINGDALE AVE
# (27.8936206, -82.2946314)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# S BRANDON AVE
# (40.8875742, -92.8209286)
#
# W FOSTER AVE
# (41.975528, -87.7281106)
#
# W WILCOX ST
# (39.7729655, -86.2196271)
#
# S CRANDON AVE
# (41.7625938, -87.5688755)
#
# S WINCHESTER AVE
# (46.406387, -105.830479)
#
# W RICE ST
# (35.5516747, -80.6218475)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# W ST
# (55.8497133, -4.2656724)
#
# W DIVERSEY PKWY
# (41.9323951, -87.6687745)
#
# N CHRISTIANA AVE
# (41.9702394, -87.7121816)
#
# S WASHTENAW AVE
# (41.8244476, -87.6922106)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# W ST
# (55.8497133, -4.2656724)
#
# S MAY ST
# (35.5997263, -77.5918349)
#
# S ELIZABETH ST
# (40.727094, -84.106756)
#
# N FRANCISCO AVE
# (26.2217801, -98.3199932)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# E 85TH PL
# (36.0395364, -95.9347648)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# S LAFAYETTE AVE
# (39.334709, -74.489355)
#
# N HARLEM AVE
# (37.093364, -94.529365)
#
# S OAKLEY AVE
# (41.6631708, -86.1244023)
#
# S SACRAMENTO AVE
# (39.3373525, -74.4801189)
#
# S DEARBORN ST
# (47.5958836, -122.318572)
#
# S YATES BLVD
# (41.7408204, -87.5660877)
#
# W IRVING PARK RD
# (41.953826, -87.7116755)
#
# N CLAREMONT AVE
# (36.106832, -80.228788)
#
# S CARPENTER ST
# (35.240268, -81.338339)
#
# W EUGENIE ST
# (41.9128325, -87.6422919)
#
# W MONTANA ST
# (45.6644428, -110.568881)
#
# S JUSTINE ST
# (41.6714397, -87.6599691)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# S ESCANABA AVE
# (41.7482723, -87.55405)
#
# S LOOMIS BLVD
# (41.7570599, -87.6587609)
#
# W DOUGLAS BLVD
# (41.8629927, -87.7029508)
#
# N LINCOLN AVE
# (45.660956, -122.6824777)
#
# S SEELEY AVE
# (42.2886768, -89.633005)
#
# S HALSTED ST
# (41.5420844, -87.6359687)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# S ARCHER AVE
# (41.6335223, -88.0133585)
#
# W PERSHING RD
# (39.8764731, -88.9678636)
#
# S WOODLAWN AVE
# (41.7812374, -87.5962214)
#
# S KENWOOD AVE
# (41.8060326, -87.5935411)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# S CHAPPEL AVE
# (41.7588966, -87.5749062)
#
# S HARVARD AVE
# (40.613458, -98.098577)
#
# N KARLOV AVE
# (41.9677725, -87.7304613)
#
# S NARRAGANSETT AVE
# (41.7607125, -87.7806016)
#
# W 54TH ST
# (40.7692528, -73.9948535)
#
# W OHIO ST
# (40.646058, -83.609337)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# S BLACKSTONE AVE
# (41.78726, -87.881703)
#
# W 51ST ST
# (40.7597316, -73.9780866)
#
# N LISTER AVE
# (39.2768708, -94.5233747)
#
# S PAXTON AVE
# (41.7316571, -87.5707162)
#
# S ESSEX AVE
# (39.3133874, -76.4565138)
#
# E ST
# (50.4738724, 4.2358174)
#
# N LUDLAM AVE
# (41.9790965, -87.7621723)
#
# S SAGINAW AVE
# (41.6427026, -87.5580689)
#
# W PL
# (39.0445999, -94.6029041)
#
# W OHIO ST
# (40.646058, -83.609337)
#
# S OAKLEY AVE
# (41.6631708, -86.1244023)
#
# S OAKLEY AVE
# (41.6631708, -86.1244023)
#
# W POTOMAC AVE
# (43.0958445, -88.0105462)
#
# W PALMER ST
# (35.1795946, -83.3858583)
#
# W BLOOMINGDALE AVE
# (27.8936206, -82.2946314)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# S TROY ST
# (42.4897468, -83.1419423)
#
# W WAVELAND AVE
# (41.9466715, -87.8113037)
#
# S KNOX AVE
# (31.7922502, -102.4986994)
#
# N HUMBOLDT BLVD
# (43.0638817, -87.8978425)
#
# N MASON AVE
# (42.354338, -85.244316)
#
# N WISNER AVE
# (43.582886, -85.870589)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# N ELSTON AVE
# (41.9624991, -87.731967)
#
# S KOLIN AVE
# (41.6804633, -87.7282162)
#
# N MONITOR AVE
# (41.9791477, -87.7744717)
#
# E 81ST ST
# (41.4803912, -81.6310758)
#
# S BELL AVE
# (36.6728853, -120.1423994)
#
# W 15TH ST
# (44.9689141, -93.2867103)
#
# S ELIZABETH ST
# (40.727094, -84.106756)
#
# W carmen ave
# (41.9736044, -87.7374367)
#
# W DIVERSEY AVE
# (41.9263942, -88.0053438)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# N DAMEN AVE
# (41.9744669, -87.6793492)
#
# S PRINCETON AVE
# (39.7884436, -75.1461365)
#
# S OAKLEY AVE
# (41.6631708, -86.1244023)
#
# S OAKLEY AVE
# (41.6631708, -86.1244023)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# W WRIGHTWOOD AVE
# (41.9247283, -87.9553717)
#
# N LONG AVE
# (31.872625, -102.526908)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# W MAYPOLE AVE
# (41.8835952, -87.7087902)
#
# S AVERS AVE
# (41.6734757, -87.7157121)
#
# W AUGUSTA BLVD
# (41.4210887, -87.732417)
#
# S LOOMIS ST
# (41.769112, -88.14147)
#
# S MAPLEWOOD AVE
# (36.0250954, -95.9064784)
#
# S MENARD AVE
# (41.6600662, -87.7628355)
#
# S OAKLEY BLVD
# (41.8761349, -87.6838294)
#
# S OAKLEY AVE
# (41.6631708, -86.1244023)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# W GRACE ST
# (37.5509972, -77.4531109)
#
# S HAMLIN AVE
# (42.0088243, -87.8504392)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# S KOSTNER AVE
# (41.6651721, -87.7289951)
#
# S KEDVALE AVE
# (41.6474182, -87.7222793)
#
# N PULASKI RD
# (41.9640877, -87.7278964)
#
# N CLAREMONT AVE
# (36.106832, -80.228788)
#
# S PEORIA ST
# (39.5974063, -104.8480467)
#
# E 76TH ST
# (39.704568, -74.135229)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# N HAMLIN AVE
# (41.9737701, -87.7232845)
#
# W 71ST ST
# (39.882403, -86.227212)
#
# N KARLOV AVE
# (41.9677725, -87.7304613)
#
# E 70TH ST
# (41.4801992, -81.640323)
#
# W TOUHY AVE
# (42.0118322, -87.7491207)
#
# S BELL AVE
# (36.6728853, -120.1423994)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# S SOUTH SHORE DR
# (41.7687175, -87.5665152)
#
# S HARDING AVE
# (36.6834759, -119.7343476)
#
# N SPAULDING AVE
# (41.9543894, -87.7104772)
#
# S CHICAGO BEACH DR
# (41.8059766, -87.5853623)
#
# S SPRINGFIELD AVE
# (40.6858039, -74.3274558)
#
# S COTTAGE GROVE AVE
# (41.6856412, -87.6114137)
#
# S BUFFALO AVE
# (31.4608364, -96.0651776)
#
# W ST
# (55.8497133, -4.2656724)
#
# E OHIO ST
# (40.601786, -84.084445)
#
# W WAVELAND AVE
# (41.9466715, -87.8113037)
#
# S Loomis St
# (41.769112, -88.14147)
#
# S Michigan Ave
# (42.59934, -83.9336293)
#
# S ADA ST
# (44.9307182, -93.0759931)
#
# N CLAREMONT AVE
# (36.106832, -80.228788)
#
# E 70TH ST
# (41.4801992, -81.640323)
#
# S SAWYER AVE
# (47.2288772, -122.4540806)
#
# N KINGSBURY ST
# (41.8986511, -87.6438839)
#
# E PL
# (14.8370417, -89.14104361631954)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# N RIDGEWAY AVE
# (41.9954911, -87.7227208)
#
# S CALUMET AVE
# (41.7034033, -86.871671)
#
# S ALBANY AVE
# (27.932852, -82.480986)
#
# S MARSHFIELD AVE
# (41.8093553, -87.6662057)
#
# S KARLOV AVE
# (41.7139045, -87.7235728)
#
# S MAY ST
# (35.5997263, -77.5918349)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# N CLAREMONT AVE
# (36.106832, -80.228788)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# N HERMITAGE AVE
# (40.232782, -74.780752)
#
# W CERMAK RD
# (41.8495374, -87.849713)
#
# W HUBBARD ST
# (41.7159012, -89.3389805)
#
# N AUSTIN BLVD
# (41.8969924, -87.7752014)
#
# N CENTRAL PARK AVE
# (41.9751896, -87.7184185)
#
# W ROSEDALE AVE
# (42.9685598, -71.4632274)
#
# S OGLESBY AVE
# (41.7448277, -87.5673518)
#
# N ROCKWELL ST
# (33.3744844, -111.7302071)
#
# W 41ST ST
# (43.5148333, -96.769579)
#
# W 61ST ST
# (44.89257, -93.315002)
#
# N SACRAMENTO BLVD
# (41.889664, -87.7013745)
#
# S EMERALD AVE
# (33.3965996, -111.8035831)
#
# S MARYLAND AVE
# (39.5941256, -75.9378606)
#
# N NARRAGANSETT AVE
# (41.9633701, -87.7869544)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# W WALLEN AVE
# (42.001795, -87.7241161)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# S RIVERSIDE PLZ
# (41.87992545, -87.63872659087485)
#
# S ARCHER AVE
# (41.6335223, -88.0133585)
#
# W RACE AVE
# (35.2508634, -91.74748)
#
# S RACINE AVE
# (42.9427005, -88.1582854)
#
# N TRIPP AVE
# (41.9848527, -87.7341352)
#
# S HAMILTON AVE
# (29.4083447, -98.5341118)
#
# S HAMLIN AVE
# (42.0088243, -87.8504392)
#
# W PL
# (39.0445999, -94.6029041)
#
# S DEARBORN ST
# (47.5958836, -122.318572)
#
# W 89TH ST
# (40.7895663, -73.973491)
#
# S MOZART ST
# (41.726308, -87.6933241)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# N SPRINGFIELD AVE
# (41.9646307, -87.7254887)
#
# S LA SALLE ST
# (41.742861, -88.3242315)
#
# N CLAREMONT AVE
# (36.106832, -80.228788)
#
# W 83RD ST
# (41.7432634, -87.6499076)
#
# S SOUTH SHORE DR
# (41.7687175, -87.5665152)
#
# S MERRILL AVE
# (47.1026257, -104.715102)
#
# W OHIO ST
# (40.646058, -83.609337)
#
# S DREXEL BLVD
# (35.4636206, -97.5703073)
#
# W LE MOYNE ST
# (41.9077136, -87.7331889)
#
# W 21ST ST
# (44.961758, -93.306244)
#
# W BERTEAU AVE
# (41.9561908, -87.8158422)
#
# S HOMAN AVE
# (41.6622485, -87.7046222)
#
# W HUBBARD ST
# (41.7159012, -89.3389805)
#
# N TALMAN AVE
# (41.9139404, -87.6934262)
#
# E ST
# (50.4738724, 4.2358174)
#
# W ST
# (55.8497133, -4.2656724)
#
# S RIDGELAND AVE
# (41.8835463, -87.7845574)
#
# S MARSHFIELD AVE
# (41.8093553, -87.6662057)
#
# N KEELER AVE
# (31.890888, -102.393391)
#
# N AUSTIN AVE
# (41.912831, -87.7753338)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# S PRINCETON AVE
# (39.7884436, -75.1461365)
#
# W 59TH ST
# (40.7646364, -73.9737661)
#
# S INGLESIDE AVE
# (41.7403543, -87.601287)
#
# E 69TH PL
# (41.4913223, -87.3304402)
#
# N WAYNE AVE
# (40.055678, -75.393487)
#
# S BENNETT AVE
# (39.047033, -82.645968)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# S PHILLIPS AVE
# (43.513078, -96.7262166)
#
# S KIMBARK AVE
# (41.7673136, -87.5941382)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# W HIGGINS RD
# (42.0465268, -88.0856451)
#
# S INGLESIDE AVE
# (41.7403543, -87.601287)
#
# S KILBOURN AVE
# (41.8591487, -87.737185)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# N ORCHARD ST
# (43.0517216, -77.093211)
#
# S KNOX AVE
# (31.7922502, -102.4986994)
#
# E ST
# (50.4738724, 4.2358174)
#
# S HONORE ST
# (41.8267808, -87.6715176)
#
# S BALTIMORE AVE
# (40.083482, -74.040895)
#
# W 98TH ST
# (39.9294661, -86.2288934)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# S AVENUE B
# (29.7026447, -95.4554222)
#
# N SPRINGFIELD AVE
# (41.9646307, -87.7254887)
#
# S KINGSTON AVE
# (36.044406, -95.9074742)
#
# W MARQUETTE RD
# (41.7726852, -87.6253898)
#
# S ST LOUIS AVE
# (41.0219002, -87.7208064)
#
# S MAPLEWOOD AVE
# (36.0250954, -95.9064784)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# N MC VICKER AVE
# (41.7720642, -87.7721541)
#
# N PARKVIEW TER
# (40.7689841, -89.6391437)
#
# S THROOP ST
# (41.7467867, -87.6560654)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# E 71ST PL
# (36.0595852, -95.9162265)
#
# S PULASKI RD
# (41.6803208, -87.7198931)
#
# S SOUTH SHORE DR
# (41.7687175, -87.5665152)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# W KAMERLING AVE
# (41.9048703, -87.7639163)
#
# E 51ST ST
# (40.754497, -73.9656924)
#
# S COTTAGE GROVE AVE
# (41.6856412, -87.6114137)
#
# S MARSHFIELD AVE
# (41.8093553, -87.6662057)
#
# N LARAMIE AVE
# (41.8954167, -87.7556069)
#
# S MARSHALL BLVD
# (41.8527744, -87.6991201)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# N KILPATRICK AVE
# (41.9699316, -87.74405)
#
# W 23RD ST
# (40.7442808, -73.9960773)
#
# N TROY ST
# (41.9593759, -87.70697)
#
# S AVENUE L
# (31.5331944, -97.4407611)
#
# W 53RD ST
# (40.7608471, -73.9768541)
#
# W SUNNYSIDE AVE
# (41.9635312, -87.6603099)
#
# W WILCOX ST
# (39.7729655, -86.2196271)
#
# E 71ST PL
# (36.0595852, -95.9162265)
#
# S WHIPPLE ST
# (42.6302929, -71.3004363)
#
# W SCHILLER ST
# (40.004778, -75.145108)
#
# S MINERVA AVE
# (42.487236, -83.118805)
#
# S FAIRFIELD AVE
# (41.8828928, -88.0058916)
#
# S ESCANABA AVE
# (41.7482723, -87.55405)
#
# N AUSTIN AVE
# (41.912831, -87.7753338)
#
# N MANGO AVE
# (41.9608929, -87.7709224)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# W WILCOX ST
# (39.7729655, -86.2196271)
#
# S MANISTEE AVE
# (41.6390183, -87.5555637)
#
# S SPAULDING AVE
# (34.0288086, -118.3700242)
#
# N MANGO AVE
# (41.9608929, -87.7709224)
#
# S CONSTANCE AVE
# (39.1322267, -86.4965916)
#
# S FAIRFIELD AVE
# (41.8828928, -88.0058916)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# N AUSTIN AVE
# (41.912831, -87.7753338)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# W HOOD AVE
# (46.214711, -119.1458494)
#
# S Parnell Ave
# (41.6335259, -87.6353874)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# W FOSTER AVE
# (41.975528, -87.7281106)
#
# S STEWART AVE
# (28.290846, -81.4066339)
#
# N SPAULDING AVE
# (41.9543894, -87.7104772)
#
# E 87TH PL
# (36.038195, -95.888076)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# S MEADE AVE
# (47.1055468, -104.7161105)
#
# N LOCKWOOD AVE
# (41.6979589, -83.5699941)
#
# W 13TH ST
# (40.5482226, -85.6954353)
#
# S VINCENNES AVE
# (41.6979977, -87.6592612)
#
# S SPAULDING AVE
# (34.0288086, -118.3700242)
#
# E 32ND ST
# (44.94472, -93.2368469)
#
# S VINCENNES AVE
# (41.6979977, -87.6592612)
#
# S MOZART ST
# (41.726308, -87.6933241)
#
# S MAY ST
# (35.5997263, -77.5918349)
#
# W GRACE ST
# (37.5509972, -77.4531109)
#
# S HALSTED ST
# (41.5420844, -87.6359687)
#
# W JARLATH ST
# (42.012664, -87.7262732)
#
# W 44TH ST
# (40.680314, -74.107708)
#
# S SANGAMON ST
# (39.5902655, -89.7359101)
#
# W WAVELAND AVE
# (41.9466715, -87.8113037)
#
# S KEATING AVE
# (33.3664683, -111.8640276)
#
# W MAYPOLE AVE
# (41.8835952, -87.7087902)
#
# S KOMENSKY AVE
# (41.7242244, -87.7231031)
#
# S LAWNDALE AVE
# (41.8425259, -87.7171839)
#
# W COULTER ST
# (40.0260654, -75.1778327)
#
# S SACRAMENTO AVE
# (39.3373525, -74.4801189)
#
# W HENDERSON ST
# (35.6845746, -80.4331586)
#
# E GROVELAND PARK
# (41.8334185, -87.6102751)
#
# S MOZART ST
# (41.726308, -87.6933241)
#
# W ALBION AVE
# (42.0009577, -87.7179087)
#
# S LAWNDALE AVE
# (41.8425259, -87.7171839)
#
# S DEARBORN ST
# (47.5958836, -122.318572)
#
# S KENNETH AVE
# (41.6814466, -87.7302028)
#
# N ST LOUIS AVE
# (41.9727203, -87.7159449)
#
# W LAKE ST
# (41.8877192, -87.7651226)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# S TRUMBULL AVE
# (41.666268, -87.7067038)
#
# W 14TH ST
# (40.7370431, -73.9960774)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# W 18TH PL
# (30.230237, -85.651847)
#
# N KEYSTONE AVE
# (42.0001236, -76.5351751)
#
# W PERSHING RD
# (39.8764731, -88.9678636)
#
# S WENTWORTH AVE
# (42.9981308, -87.8894434)
#
# W MONTROSE AVE
# (41.9607197, -87.7466474)
#
# N LAWLER AVE
# (41.9186896, -87.7523027)
#
# S CARPENTER ST
# (35.240268, -81.338339)
#
# S PAXTON AVE
# (41.7316571, -87.5707162)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# N ORCHARD ST
# (43.0517216, -77.093211)
#
# S BALTIMORE AVE
# (40.083482, -74.040895)
#
# S ST LAWRENCE AVE
# (41.7682281, -87.6104913)
#
# W ARGYLE ST
# (57.8956842, -5.1630045)
#
# N CHRISTIANA AVE
# (41.9702394, -87.7121816)
#
# S SAWYER AVE
# (47.2288772, -122.4540806)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# W WEST END AVE
# (41.8840066, -87.7595529)
#
# S MARYLAND AVE
# (39.5941256, -75.9378606)
#
# E SCOTT ST
# (43.79134, -88.4223071)
#
# W 14TH ST
# (40.7370431, -73.9960774)
#
# N OAK PARK AVE
# (41.9071844, -87.7950033)
#
# N SPAULDING AVE
# (41.9543894, -87.7104772)
#
# S TRUMBULL AVE
# (41.666268, -87.7067038)
#
# N KENNEDY EXPY IB
# W WILSON AVE
# (47.6575559, -117.4351579)
#
# W DEMING PL
# (41.9292488, -87.6406316)
#
# W GRAND AVE
# (44.89992, -89.6139466)
#
# E LOWER WACKER DR
# (41.8875576, -87.6174627)
#
# E LOWER WACKER DR
# (41.8875576, -87.6174627)
#
# W School St
# (33.3044468, -96.4028596)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# E 82ND ST
# (41.5041895, -81.6308342)
#
# S VERNON AVE
# (32.72251, -96.836774)
#
# S CLYDE AVE
# (28.2911755, -81.4131903)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# S PHILLIPS AVE
# (43.513078, -96.7262166)
#
# W QUINCY ST
# (28.0541053, -81.9636599)
#
# N SEDGWICK ST
# (37.693255, -97.36976)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# W MAYPOLE AVE
# (41.8835952, -87.7087902)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# S EVANS AVE
# (35.509722, -97.9558699)
#
# N SAWYER AVE
# (41.9610885, -87.7094607)
#
# N WELLS ST
# (30.831592, -83.286031)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# S clinton st
# (38.5332401, -89.705132)
#
# S EDBROOKE AVE
# (41.6980924, -87.6196287)
#
# S HALSTED ST
# (41.5420844, -87.6359687)
#
# W WASHINGTON ST
# (40.194732, -85.391486)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# N JEFFERSON ST
# (43.572607, -76.123675)
#
# W LAKE ST
# (41.8877192, -87.7651226)
#
# S WESTERN AVE
# (43.5185145, -96.751124)
#
# W GRENSHAW ST
# (41.8679092, -87.6630252)
#
# S BURNHAM AVE
# (41.6423104, -87.5396238)
#
# S HARDING AVE
# (36.6834759, -119.7343476)
#
# W IRVING PARK RD
# (41.953826, -87.7116755)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# S LEAVITT ST
# (41.8737714, -87.6813292)
#
# N WINCHESTER AVE
# (46.4110364, -105.830487)
#
# S PULASKI RD
# (41.6803208, -87.7198931)
#
# E 71ST PL
# (36.0595852, -95.9162265)
#
# N CLEVELAND AVE
# (30.344444, -95.0913629)
#
# W JUNEWAY TER
# (42.0222514, -87.6668154)
#
# W 94TH PL
# (41.4469275, -87.3368917)
#
# S SEELEY AVE
# (42.2886768, -89.633005)
#
# E ST
# (50.4738724, 4.2358174)
#
# N KILDARE AVE
# (41.9718061, -87.7355466)
#
# E 72ND ST
# (40.7710212, -73.9636252)
#
# N AUSTIN AVE
# (41.912831, -87.7753338)
#
# S GULLIKSON RD
# (41.7780051, -87.7976341)
#
# S SOUTH SHORE DR
# (41.7687175, -87.5665152)
#
# S HARVARD AVE
# (40.613458, -98.098577)
#
# N GLENWOOD AVE
# (42.650887, -83.284998)
#
# S EVANS AVE
# (35.509722, -97.9558699)
#
# N KEDVALE AVE
# (41.9640717, -87.7315451)
#
# S PHILLIPS AVE
# (43.513078, -96.7262166)
#
# S KENWOOD AVE
# (41.8060326, -87.5935411)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# S ELIZABETH ST
# (40.727094, -84.106756)
#
# W LEXINGTON ST
# (39.0325997, -97.5948929)
#
# W LUNT AVE
# (42.0077782, -87.8200486)
#
# W 89TH ST
# (40.7895663, -73.973491)
#
# S WOOD ST
# (41.343196, -83.119849)
#
# S CALUMET AVE
# (41.7034033, -86.871671)
#
# S EVANS AVE
# (35.509722, -97.9558699)
#
# N HOYNE AVE
# (41.9550717, -87.6812061)
#
# W MORSE AVE
# (42.0072486, -87.6859808)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# W ADDISON ST
# (42.226415, -84.406033)
#
# W ROOSEVELT RD
# (41.8568563, -88.1736282)
#
# W HARRISON ST
# (47.453523, -116.785825)
#
# S DRAKE AVE
# (41.8498569, -87.713702)
#
# W 63RD ST
# (41.7733805, -87.9889844)
#
# S DREXEL AVE
# (33.369843, -111.623825)
#
# W 37TH PL
# (41.5500355, -87.2771904)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# N ROGERS AVE
# (42.118891, -76.046551)
#
# S LAKE PARK AVE
# (41.5348577, -87.2596604)
#
# S CALUMET AVE
# (41.7034033, -86.871671)
#
# S HERMITAGE AVE
# (41.7685166, -87.6675589)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# N KEYSTONE AVE
# (42.0001236, -76.5351751)
#
# S TRIPP AVE
# (41.663533, -87.72595)
#
# W SCHOOL ST
# (33.3044468, -96.4028596)
#
# N RIDGEWAY AVE
# (41.9954911, -87.7227208)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# N WINTHROP AVE
# (41.9873032, -87.6581226)
#
# N KEYSTONE AVE
# (42.0001236, -76.5351751)
#
# S HOMAN AVE
# (41.6622485, -87.7046222)
#
# W WASHBURNE AVE
# (41.8661181, -87.6581942)
#
# S JUSTINE ST
# (41.6714397, -87.6599691)
#
# S OAKLEY AVE
# (41.6631708, -86.1244023)
#
# N HOMAN AVE
# (41.8919714, -87.711335)
#
# W IRVING PARK RD
# (41.953826, -87.7116755)
#
# N PANAMA AVE
# (41.9486007, -87.8292132)
#
# N SEELEY AVE
# (43.5619333, -94.7747364)
#
# S Michigan Ave
# (42.59934, -83.9336293)
#
# S LARAMIE AVE
# (41.8447325, -87.753967)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# N KEDVALE AVE
# (41.9640717, -87.7315451)
#
# N KILBOURN AVE
# (41.9717611, -87.7405534)
#
# S PAULINA ST
# (41.878849, -87.6692204)
#
# E 83RD ST
# (41.5024109, -81.6295886)
#
# W Morse Ave
# (42.0072486, -87.6859808)
#
# W 64TH PL
# (25.881035, -80.3378206)
#
# W WARWICK AVE
# (41.695646, -71.528992)
#
# S INGLESIDE AVE
# (41.7403543, -87.601287)
#
# S COLES AVE
# (41.7483376, -87.5491898)

# %%
# Save Checkpoint 
df2013_geo = df_2013.copy()

# %%
# Filter location that is not null
df2013_geo = df2013_geo[df2013_geo['location'].notna()]

# %%
df2013_geo = impute_district(df2013_geo)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:113: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326

# %%
# Drop columns
df2013_geo.drop(['district', 'index_right'], axis=1, inplace=True)

# Rename columns
df2013_geo.rename(columns={'dist_num':'district'}, inplace=True)

# %%
# Impute updated ward values
df2013_geo = impute_ward(df2013_geo)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:69: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326

# %%
# Drop columns
df2013_geo.drop(['ward_left', 'index_right'], axis=1, inplace=True)

# Rename columns
df2013_geo.rename(columns={'ward_right':'ward'}, inplace=True)

# %%
# Impute updated district values
df2013_geo = impute_commareas(df2013_geo)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:91: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326

# %%
# Drop columns
df2013_geo.drop(['community_area', 'index_right'], axis=1, inplace=True)

# Rename columns
df2013_geo.rename(columns={'area_numbe':'community_area'}, inplace=True)

# %%
# Balance clean up of dataset after transformation
# Drop columns
df2013_geo.drop(['x_coordinate', 'y_coordinate'], axis=1, inplace=True)

# Assign null values in location description to 'OTHER (Specify)'
df2013_geo['location_description'].fillna('OTHER (SPECIFY)', inplace = True)

# %%
df2013_geo.to_csv('/content/drive/MyDrive/Colab Notebooks/capstone/assets/2013_crime_clean.csv', index=False)

# %%
df2013_geo.isnull().sum()
# Out:
# id                      0
# case_number             0
# date                    0
# block                   0
# iucr                    0
# primary_type            0
# description             0
# location_description    0
# arrest                  0
# domestic                0
# beat                    0
# fbi_code                0
# year                    0
# updated_on              0
# latitude                0
# longitude               0
# location                0
# day                     0
# month                   0
# day_of_week             0
# time                    0
# geometry                0
# district                0
# ward                    0
# community_area          0
# dtype: int64

# %% [markdown]
# ## Clean data (2012)

# %%
# from geopy.geocoders import Nominatim
geocoder = Nominatim(user_agent = 'crime_predictions')

# %%
df_2012 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/capstone/assets/2012_crime.csv')
df_2012.head()
# Out:
#          id case_number                 date                     block  iucr  \
# 0  11645833    JC213044  2012-05-05 12:25:00           057XX W OHIO ST  1153
# 1  11227247    JB147078  2012-01-01 09:00:00  105XX S INDIANAPOLIS AVE  1153
# 2  10225605    HY412867  2012-07-11 09:00:00        017XX W ALBION AVE  1153
# 3  11228588    JB149037  2012-06-04 12:00:00           037XX W 85TH PL  1154
# 4  10751224    HZ513641  2012-01-01 08:00:00      010XX S MAYFIELD AVE  1752
#
#                  primary_type                              description  \
# 0          DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 1          DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 2          DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 3          DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 4  OFFENSE INVOLVING CHILDREN            AGG CRIM SEX ABUSE FAM MEMBER
#
#   location_description  arrest  domestic  beat  district  ward  \
# 0                  NaN   False     False  1511      15.0  29.0
# 1            RESIDENCE   False     False   432       4.0  10.0
# 2            APARTMENT   False     False  2432      24.0  40.0
# 3            RESIDENCE   False     False   834       8.0  18.0
# 4            RESIDENCE   False     False  1513      15.0  29.0
#
#    community_area fbi_code  x_coordinate  y_coordinate  year  \
# 0            25.0       11           NaN           NaN  2012
# 1            52.0       11           NaN           NaN  2012
# 2             1.0       11     1163498.0     1943889.0  2012
# 3            70.0       11           NaN           NaN  2012
# 4            25.0       20           NaN           NaN  2012
#
#                updated_on  latitude  longitude                      location  \
# 0  04/06/2019 04:04:43 PM       NaN        NaN                           NaN
# 1  02/11/2018 03:57:41 PM       NaN        NaN                           NaN
# 2  02/10/2018 03:50:01 PM  42.00167 -87.673864  (42.00167049, -87.673863642)
# 3  02/12/2018 03:49:14 PM       NaN        NaN                           NaN
# 4  07/27/2017 03:50:07 PM       NaN        NaN                           NaN
#
#    day  month  day_of_week  time
# 0    5      5            5    12
# 1    1      1            6     9
# 2   11      7            2     9
# 3    4      6            0    12
# 4    1      1            6     8

# %%
df_2012.isnull().sum()
# Out:
# id                        0
# case_number               1
# date                      0
# block                     0
# iucr                      0
# primary_type              0
# description               0
# location_description    453
# arrest                    0
# domestic                  0
# beat                      0
# district                  0
# ward                      7
# community_area           26
# fbi_code                  0
# x_coordinate            731
# y_coordinate            731
# year                      0
# updated_on                0
# latitude                731
# longitude               731
# location                731
# day                       0
# month                     0
# day_of_week               0
# time                      0
# dtype: int64

# %%
replace_to_zero(df_2012)

# %%
index_list = missing_row_loc(df_2012)
# Out:
# 731

# %%
impute_data(df_2012, index_list)
# Out:
# [0, 1, 3, 4, 6, 8, 9, 10, 12, 13, 14, 15, 17, 18, 22, 26, 29, 45, 59, 61, 67, 70, 76, 87, 89, 92, 93, 97, 98, 99, 100, 101, 106, 110, 114, 116, 117, 118, 119, 121, 122, 123, 124, 126, 127, 128, 129, 132, 135, 136, 139, 140, 150, 157, 162, 163, 164, 165, 166, 168, 169, 171, 172, 173, 174, 175, 176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199, 200, 201, 202, 203, 205, 206, 207, 208, 209, 210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 225, 226, 227, 228, 229, 230, 231, 232, 233, 234, 235, 236, 238, 242, 243, 248, 251, 253, 254, 255, 259, 263, 264, 265, 266, 269, 271, 272, 273, 274, 275, 277, 280, 281, 283, 284, 285, 287, 288, 289, 290, 291, 292, 296, 297, 300, 301, 302, 305, 326, 340, 345, 398, 445, 446, 447, 448, 449, 450, 451, 452, 453, 454, 455, 456, 457, 459, 460, 461, 462, 463, 464, 465, 467, 469, 470, 471, 476, 490, 493, 496, 497, 499, 502, 503, 504, 506, 507, 509, 510, 511, 687, 688, 691, 739, 830, 831, 832, 834, 836, 837, 838, 839, 840, 841, 842, 843, 844, 845, 846, 847, 849, 850, 851, 852, 853, 854, 855, 856, 857, 858, 859, 860, 862, 863, 864, 865, 867, 868, 869, 870, 871, 872, 873, 874, 907, 914, 918, 928, 930, 934, 935, 936, 939, 943, 949, 74822, 153378, 154920, 155408, 155413, 155414, 156381, 156805, 156856, 157698, 157705, 157708, 157716, 157717, 157718, 157719, 157720, 157721, 157722, 157723, 157724, 157725, 157726, 157727, 157728, 157729, 157730, 157731, 157732, 157733, 157734, 157753, 159065, 159780, 159782, 161414, 161491, 162795, 165378, 166016, 166562, 166629, 167069, 167262, 170916, 171770, 172368, 172651, 173399, 173482, 173737, 174417, 175790, 176267, 176856, 177500, 177802, 179139, 179297, 180094, 180585, 181085, 181913, 185333, 185527, 185730, 186483, 186490, 189224, 190228, 191697, 191807, 192709, 194176, 196860, 196997, 200357, 204639, 205125, 206110, 208114, 209334, 212866, 213079, 213080, 213971, 217133, 217710, 218600, 218736, 218762, 219563, 219826, 220060, 220675, 222000, 222446, 223262, 223942, 225079, 225308, 228773, 229019, 233541, 233647, 234587, 234967, 235694, 237086, 237656, 239010, 239723, 242046, 243432, 243433, 244352, 244353, 245049, 246940, 247239, 248580, 248619, 249429, 249593, 250926, 251532, 254479, 254543, 254687, 254912, 256949, 257110, 257652, 258263, 258278, 259389, 260832, 262838, 263228, 264731, 264971, 267616, 267908, 269364, 271461, 272988, 273360, 273384, 277219, 277445, 279394, 281377, 281794, 285183, 285864, 286851, 289778, 293131, 294394, 295301, 296906, 297064, 301854, 302718, 304240, 309034, 309551, 310526, 311073, 311392, 311794, 312505, 312509, 312517, 312572, 312603, 312637, 312696, 312700, 312744, 312756, 312765, 312766, 312771, 312808, 312854, 312856, 312865, 312872, 312878, 312960, 312971, 313038, 313039, 313058, 313079, 313143, 313169, 313174, 313195, 313196, 313206, 313214, 313244, 313249, 313259, 313271, 313278, 313284, 313293, 313329, 313339, 313345, 313350, 313681, 315665, 317374, 318071, 318090, 318203, 320629, 320883, 320910, 321078, 322003, 322236, 323527, 325617, 325622, 325641, 328110, 330240, 330744, 331170, 331210, 331217, 331235, 331236, 331246, 331310, 331967, 331974, 331976, 332003, 332004, 332018, 332019, 332020, 332021, 332024, 332076, 332362, 332562, 332563, 332565, 332566, 332567, 332568, 332569, 332570, 332571, 332572, 332575, 332576, 332577, 332578, 332581, 332582, 332583, 332584, 332589, 332590, 332618, 332622, 332624, 332625, 332627, 332629, 332630, 332631, 332632, 332633, 332634, 332635, 332636, 332637, 332639, 332640, 332642, 332643, 332645, 332647, 332649, 332650, 332653, 332654, 332659, 332660, 332661, 332662, 332663, 332664, 332665, 332666, 332667, 332671, 332672, 332674, 332675, 332680, 332681, 332683, 332684, 332688, 332689, 332690, 332691, 332693, 332694, 332695, 332696, 332702, 332708, 332710, 332712, 332713, 332719, 332722, 332723, 332726, 332727, 332729, 332730, 332734, 332735, 332736, 332738, 332739, 332740, 332741, 332743, 332747, 332749, 332 ...
#
# W OHIO ST
# (40.646058, -83.609337)
#
# S INDIANAPOLIS AVE
# (36.061071, -95.9392842)
#
# W 85TH PL
# (41.4632806, -87.4006556)
#
# S MAYFIELD AVE
# (41.8800902, -87.7713848)
#
# W WASHINGTON ST
# (40.194732, -85.391486)
#
# S CAMPBELL AVE
# (37.1712552, -93.2953919)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# E 60TH ST
# (44.8942722, -93.2746348)
#
# W 14TH PL
# (36.737877, -95.99234)
#
# N LA CROSSE AVE
# (38.2701926, -104.5890357)
#
# S NORDICA AVE
# (41.7211247, -87.7956381)
#
# N RIDGEWAY AVE
# (41.9954911, -87.7227208)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# S EVANS AVE
# (35.509722, -97.9558699)
#
# E 40TH ST
# (44.9305097, -93.2276849)
#
# W RANDOLPH ST
# (36.2743344, -90.9816148)
#
# E 69TH ST
# (39.001852, -94.5613311)
#
# E PL
# (14.8370417, -89.14104361631954)
#
# N MAYFIELD AVE
# (34.1105096, -117.2902727)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# N LOTUS AVE
# (35.4704582, -97.3553818)
#
# S HOYNE AVE
# (41.8228899, -87.6774807)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# E 70TH ST
# (41.4801992, -81.640323)
#
# S ABERDEEN ST
# (35.7300766, -95.3526173)
#
# W ST
# (55.8497133, -4.2656724)
#
# S KEELER AVE
# (36.7501253, -95.9789915)
#
# W DIVERSEY AVE
# (41.9263942, -88.0053438)
#
# W 47TH ST
# (40.7580163, -73.9817975)
#
# E CHICAGO AVE
# (41.8968438, -87.6168932)
#
# S MAY ST
# (35.5997263, -77.5918349)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# S DREXEL BLVD
# (35.4636206, -97.5703073)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# S ARTESIAN AVE
# (34.0977413, -117.3182866)
#
# S CHAPPEL AVE
# (41.7588966, -87.5749062)
#
# S Vernon Ave
# (32.72251, -96.836774)
#
# S EUCLID PKWY
# (41.7589319, -87.5781852)
#
# S COLFAX AVE
# (30.853988, -96.9914143)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# S WALLACE ST
# (38.6625346, -87.3019057)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# W 25TH PL
# (41.5724621, -87.390001)
#
# S MANISTEE AVE
# (41.6390183, -87.5555637)
#
# W LITHUANIAN PLAZA CT
# (41.7682602, -87.6882371)
#
# S GREENWOOD AVE
# (37.6199047, -96.228166)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# S TRUMBULL AVE
# (41.666268, -87.7067038)
#
# S ST LAWRENCE AVE
# (41.7682281, -87.6104913)
#
# S HERMITAGE AVE
# (41.7685166, -87.6675589)
#
# N MAYFIELD AVE
# (34.1105096, -117.2902727)
#
# S LAWLER AVE
# (41.6735388, -87.7455584)
#
# W 71ST ST
# (39.882403, -86.227212)
#
# N HARDING AVE
# (41.9937042, -87.7276304)
#
# W 19TH ST
# (30.1833503, -85.7294777)
#
# S DAUPHIN AVE
# (27.8698258, -82.4986097)
#
# N KENNETH AVE
# (41.9717719, -87.7392712)
#
# N MAPLEWOOD AVE
# (36.1771957, -95.9078851)
#
# W LE MOYNE ST
# (41.9077136, -87.7331889)
#
# S LOOMIS ST
# (41.769112, -88.14147)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# W FOSTER AVE
# (41.975528, -87.7281106)
#
# E PL
# (14.8370417, -89.14104361631954)
#
# S EMERALD AVE
# (33.3965996, -111.8035831)
#
# S KARLOV AVE
# (41.7139045, -87.7235728)
#
# W FERDINAND ST
# (42.4723744, -71.076355)
#
# W 48TH ST
# (44.915947, -93.294662)
#
# S CALUMET AVE
# (41.7034033, -86.871671)
#
# S RIDGELAND AVE
# (41.8835463, -87.7845574)
#
# W NORTH SHORE AVE
# (42.0027093, -87.744558)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# W 65TH ST
# (34.6902193, -92.3298401)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# E 60TH ST
# (44.8942722, -93.2746348)
#
# S KIMBARK AVE
# (41.7673136, -87.5941382)
#
# W 26TH ST
# (41.8444628, -87.7092909)
#
# S ALBANY AVE
# (27.932852, -82.480986)
#
# S MARYLAND AVE
# (39.5941256, -75.9378606)
#
# S ARTESIAN AVE
# (34.0977413, -117.3182866)
#
# W ADDISON ST
# (42.226415, -84.406033)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# S ESSEX AVE
# (39.3133874, -76.4565138)
#
# W POLK ST
# (30.7116929, -94.9383233)
#
# W 84TH PL
# (41.4643866, -87.3478885)
#
# E 89TH ST
# (40.7778572, -73.9457131)
#
# N CENTRAL PARK AVE
# (41.9751896, -87.7184185)
#
# N MONITOR AVE
# (41.9791477, -87.7744717)
#
# E 55TH PL
# (39.853822, -86.056486)
#
# E 60TH ST
# (44.8942722, -93.2746348)
#
# W PL
# (39.0445999, -94.6029041)
#
# S CHAMPLAIN AVE
# (32.1827548, -110.8194486)
#
# W 84TH ST
# (38.9742141, -94.857781)
#
# S VERNON AVE
# (32.72251, -96.836774)
#
# S PRINCETON AVE
# (39.7884436, -75.1461365)
#
# S WALLACE ST
# (38.6625346, -87.3019057)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# S chappel ave
# (41.7588966, -87.5749062)
#
# E 53RD ST
# (40.7580248, -73.9701634)
#
# S YATES AVE
# (41.1127251, -87.8911556)
#
# N LECLAIRE AVE
# (41.935091, -87.7540962)
#
# W 71ST ST
# (39.882403, -86.227212)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S LAWNDALE AVE
# (41.8425259, -87.7171839)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# N HUDSON AVE
# (37.691596, -83.95988)
#
# S KEDZIE AVE
# (41.7315967, -87.7021544)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# S JEFFERY BLVD
# (41.7479785, -87.5759176)
#
# N MENARD AVE
# (41.8914776, -87.7700234)
#
# N AVERS AVE
# (41.9628652, -87.724203)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S WENTWORTH AVE
# (42.9981308, -87.8894434)
#
# S EVANS AVE
# (35.509722, -97.9558699)
#
# W 59TH ST
# (40.7646364, -73.9737661)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# N HAMLIN AVE
# (41.9737701, -87.7232845)
#
# N MANGO AVE
# (41.9608929, -87.7709224)
#
# W BLACKHAWK ST
# (43.567624, -96.737549)
#
# W THOMAS ST
# (43.230666, -75.469829)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# S MARSHFIELD AVE
# (41.8093553, -87.6662057)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# W 54TH PL
# (25.8719155, -80.33905)
#
# S SACRAMENTO AVE
# (39.3373525, -74.4801189)
#
# N HARDING AVE
# (41.9937042, -87.7276304)
#
# S UNION AVE
# (47.2491253, -122.4836389)
#
# E 60TH ST
# (44.8942722, -93.2746348)
#
# S BLACKSTONE AVE
# (41.78726, -87.881703)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# E JACKSON BLVD
# (37.3767724, -89.6668247)
#
# W MONTANA ST
# (45.6644428, -110.568881)
#
# S Eberhart Ave
# (43.822127, -84.748397)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# W LAKE ST
# (41.8877192, -87.7651226)
#
# S UNION AVE
# (47.2491253, -122.4836389)
#
# W 21ST ST
# (44.961758, -93.306244)
#
# W CARMEN AVE
# (41.9736044, -87.7374367)
#
# W THOME AVE
# (41.9955841, -87.6734358)
#
# E 68TH ST
# (36.064123, -95.9448098)
#
# S GILES AVE
# (41.8310918, -87.6193367)
#
# S WESTERN AVE
# (43.5185145, -96.751124)
#
# W MARQUETTE RD
# (41.7726852, -87.6253898)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# W WOLFRAM ST
# (41.9335036, -87.6563169)
#
# W LEXINGTON ST
# (39.0325997, -97.5948929)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# W FLOURNOY ST
# (28.406267, -97.7593919)
#
# W 78TH PL
# (41.4755863, -87.3774798)
#
# S CONSTANCE AVE
# (39.1322267, -86.4965916)
#
# N MENARD AVE
# (41.8914776, -87.7700234)
#
# W FERDINAND ST
# (42.4723744, -71.076355)
#
# E 73RD ST
# (32.0274706, -81.1097986)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S BALTIMORE AVE
# (40.083482, -74.040895)
#
# S DEARBORN ST
# (47.5958836, -122.318572)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# S ADA ST
# (44.9307182, -93.0759931)
#
# W RACE AVE
# (35.2508634, -91.74748)
#
# N LEROY AVE
# (40.6950746, -89.6300017)
#
# S JUSTINE ST
# (41.6714397, -87.6599691)
#
# N MONTICELLO AVE
# (41.9751716, -87.7196691)
#
# W ARMITAGE AVE
# (43.1023086, -87.9910021)
#
# S DORCHESTER AVE
# (41.861114, -88.126156)
#
# N TRIPP AVE
# (41.9848527, -87.7341352)
#
# N CHRISTIANA AVE
# (41.9702394, -87.7121816)
#
# S CARPENTER ST
# (35.240268, -81.338339)
#
# N KILDARE AVE
# (41.9718061, -87.7355466)
#
# S MARYLAND AVE
# (39.5941256, -75.9378606)
#
# S SPAULDING AVE
# (34.0288086, -118.3700242)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# S DANTE AVE
# (41.5394098, -87.5855724)
#
# W WARREN BLVD
# (41.8823807, -87.6651175)
#
# S HARVARD AVE
# (40.613458, -98.098577)
#
# E 46TH PL
# (36.0964929, -95.7751581)
#
# S BELL AVE
# (36.6728853, -120.1423994)
#
# N PINE AVE
# (42.669591, -73.790953)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# N LOCKWOOD AVE
# (41.6979589, -83.5699941)
#
# N LA SALLE ST
# (30.398997, -96.0961872)
#
# E PL
# (14.8370417, -89.14104361631954)
#
# S STEWART AVE
# (28.290846, -81.4066339)
#
# W WILCOX ST
# (39.7729655, -86.2196271)
#
# S KINGSTON AVE
# (36.044406, -95.9074742)
#
# W PRATT BLVD
# (42.0054657, -87.6658226)
#
# W CHESTNUT ST
# (40.0400916, -76.3165126)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# S RIDGEWAY AVE
# (35.61739, -82.3173401)
#
# S LUELLA AVE
# (41.7589872, -87.5700366)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# W WILCOX ST
# (39.7729655, -86.2196271)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# N HAMLIN AVE
# (41.9737701, -87.7232845)
#
# S WASHTENAW AVE
# (41.8244476, -87.6922106)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# W PIERCE AVE
# (39.485878, -88.185641)
#
# E 89TH ST
# (40.7778572, -73.9457131)
#
# S PRINCETON AVE
# (39.7884436, -75.1461365)
#
# N FAIRFIELD AVE
# (40.417653, -120.640311)
#
# S DREXEL AVE
# (33.369843, -111.623825)
#
# S SOUTH SHORE DR
# (41.7687175, -87.5665152)
#
# N CENTRAL AVE
# (35.7718102, -91.6557941)
#
# E 72ND ST
# (40.7710212, -73.9636252)
#
# S SPAULDING AVE
# (34.0288086, -118.3700242)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# S WESTERN AVE
# (43.5185145, -96.751124)
#
# E 74TH ST
# (40.7710532, -73.9596512)
#
# S CENTRAL PARK AVE
# (41.7169517, -87.7114806)
#
# E 89TH PL
# (36.0340257, -95.9045251)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# S GREENWOOD AVE
# (37.6199047, -96.228166)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# N KEELER AVE
# (31.890888, -102.393391)
#
# S FEDERAL ST
# (38.443357, -78.870308)
#
# W OHIO ST
# (40.646058, -83.609337)
#
# S CARPENTER ST
# (35.240268, -81.338339)
#
# W 79TH ST
# (40.7849838, -73.9826637)
#
# N WABASH AVE
# (41.1450949, -87.8658414)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# W FARRAGUT AVE
# (41.9745691, -87.829751)
#
# S UNION AVE
# (47.2491253, -122.4836389)
#
# S CLAREMONT AVE
# (39.096728, -94.442776)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# S PAULINA ST
# (41.878849, -87.6692204)
#
# S WOOD ST
# (41.343196, -83.119849)
#
# S TRUMBULL AVE
# (41.666268, -87.7067038)
#
# S SPAULDING AVE
# (34.0288086, -118.3700242)
#
# N LA CROSSE AVE
# (38.2701926, -104.5890357)
#
# S EBERHART AVE
# (43.822127, -84.748397)
#
# W 51ST ST
# (40.7597316, -73.9780866)
#
# E 89TH ST
# (40.7778572, -73.9457131)
#
# S FAIRFIELD AVE
# (41.8828928, -88.0058916)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# S BUFFALO AVE
# (31.4608364, -96.0651776)
#
# S CARPENTER ST
# (35.240268, -81.338339)
#
# S WOOD ST
# (41.343196, -83.119849)
#
# S MERRILL AVE
# (47.1026257, -104.715102)
#
# W WALNUT ST
# (31.8085297, -97.0935238)
#
# N MAGNOLIA AVE
# (29.1969846, -82.1365046)
#
# S SPAULDING AVE
# (34.0288086, -118.3700242)
#
# N KEDZIE AVE
# (41.981245, -87.7088348)
#
# N ARTESIAN AVE
# (41.9254283, -87.6888852)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# S WESTERN AVE
# (43.5185145, -96.751124)
#
# E 51ST ST
# (40.754497, -73.9656924)
#
# S PAULINA ST
# (41.878849, -87.6692204)
#
# S EMERALD AVE
# (33.3965996, -111.8035831)
#
# S PAULINA ST
# (41.878849, -87.6692204)
#
# W POTOMAC AVE
# (43.0958445, -88.0105462)
#
# N MENARD AVE
# (41.8914776, -87.7700234)
#
# S SAWYER AVE
# (47.2288772, -122.4540806)
#
# W PL
# (39.0445999, -94.6029041)
#
# W ROSCOE ST
# (41.9417774, -87.798255)
#
# S JUSTINE ST
# (41.6714397, -87.6599691)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# S RACINE AVE
# (42.9427005, -88.1582854)
#
# S MAYFIELD AVE
# (41.8800902, -87.7713848)
#
# S MAY ST
# (35.5997263, -77.5918349)
#
# S GREEN ST
# (37.8040878, -87.6368672)
#
# N LOCKWOOD AVE
# (41.6979589, -83.5699941)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# N CLARENDON AVE
# (39.3347411, -74.4980139)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S WESTERN AVE
# (43.5185145, -96.751124)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# W FLOURNOY ST
# (28.406267, -97.7593919)
#
# S EMERALD AVE
# (33.3965996, -111.8035831)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# S ADA ST
# (44.9307182, -93.0759931)
#
# W CERMAK RD
# (41.8495374, -87.849713)
#
# N KILDARE AVE
# (41.9718061, -87.7355466)
#
# S INGLESIDE AVE
# (41.7403543, -87.601287)
#
# N ST CLAIR ST
# (38.6048814, -89.8103789)
#
# S WOOD ST
# (41.343196, -83.119849)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# E ST
# (50.4738724, 4.2358174)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# W LAKE ST
# (41.8877192, -87.7651226)
#
# S PRINCETON AVE
# (39.7884436, -75.1461365)
#
# S KIMBARK AVE
# (41.7673136, -87.5941382)
#
# N OAK PARK AVE
# (41.9071844, -87.7950033)
#
# W GARFIELD BLVD
# (41.7944433, -87.6378706)
#
# N LATROBE AVE
# (41.9852199, -87.7604579)
#
# N MARMORA AVE
# (41.9567321, -87.7744508)
#
# S SACRAMENTO BLVD
# (41.877103, -87.7011017)
#
# S DREXEL BLVD
# (35.4636206, -97.5703073)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# S CARPENTER ST
# (35.240268, -81.338339)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# N WOLCOTT AVE
# (41.9069854, -87.6730408)
#
# S WESTERN AVE
# (43.5185145, -96.751124)
#
# S CALHOUN AVE
# (41.6390695, -87.5616751)
#
# W 79TH ST
# (40.7849838, -73.9826637)
#
# S GREEN ST
# (37.8040878, -87.6368672)
#
# W GRAND AVE
# (44.89992, -89.6139466)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# E 62ND ST
# (44.890728, -93.259847)
#
# S JEFFERY BLVD
# (41.7479785, -87.5759176)
#
# W 87TH ST
# (38.970993, -94.7161832)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# W ST
# (55.8497133, -4.2656724)
#
# W AUGUSTA BLVD
# (41.4210887, -87.732417)
#
# W GRENSHAW ST
# (41.8679092, -87.6630252)
#
# N HAMPDEN CT
# (41.9327766, -87.6424927)
#
# N MC VICKER AVE
# (41.7720642, -87.7721541)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# S CHRISTIANA AVE
# (28.6675036, -81.4969422)
#
# S NATCHEZ AVE
# (41.6643374, -87.7802881)
#
# N RIDGEWAY AVE
# (41.9954911, -87.7227208)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# W 38TH ST
# (39.7635758, -75.5276556)
#
# S SPAULDING AVE
# (34.0288086, -118.3700242)
#
# W 38TH PL
# (41.548344, -87.2952495)
#
# S SANGAMON ST
# (39.5902655, -89.7359101)
#
# S CREGIER AVE
# (41.7663619, -87.5812232)
#
# S HARPER AVE
# (33.3743982, -111.6339155)
#
# S FOREST AVE
# (42.2736405, -83.7331125)
#
# S EXCHANGE AVE
# (35.0704184, -92.4212449)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# W FLOURNOY ST
# (28.406267, -97.7593919)
#
# S ROCKWELL ST
# (33.3290958, -111.7293356)
#
# E 84TH ST
# (40.6411761, -73.914588)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# N TALMAN AVE
# (41.9139404, -87.6934262)
#
# W LUTHER ST
# (41.851279, -94.010638)
#
# S ELIZABETH ST
# (40.727094, -84.106756)
#
# N KEDZIE AVE
# (41.981245, -87.7088348)
#
# N ORCHARD ST
# (43.0517216, -77.093211)
#
# S SOUTH SHORE DR
# (41.7687175, -87.5665152)
#
# W MARQUETTE RD
# (41.7726852, -87.6253898)
#
# S JUSTINE ST
# (41.6714397, -87.6599691)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# S COLFAX AVE
# (30.853988, -96.9914143)
#
# S THROOP ST
# (41.7467867, -87.6560654)
#
# W THOMAS ST
# (43.230666, -75.469829)
#
# N KEDZIE AVE
# (41.981245, -87.7088348)
#
# S HARDING AVE
# (36.6834759, -119.7343476)
#
# N RIDGEWAY AVE
# (41.9954911, -87.7227208)
#
# N HOYNE AVE
# (41.9550717, -87.6812061)
#
# W ADDISON ST
# (42.226415, -84.406033)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# W WARWICK AVE
# (41.695646, -71.528992)
#
# W BELLE PLAINE AVE
# (41.955062, -87.7887068)
#
# W DIVERSEY AVE
# (41.9263942, -88.0053438)
#
# W 21ST ST
# (44.961758, -93.306244)
#
# W FRANKLIN BLVD
# (35.2598762, -81.214961)
#
# S SACRAMENTO AVE
# (39.3373525, -74.4801189)
#
# N KOSTNER AVE
# (41.9869013, -87.7382889)
#
# W GLADYS AVE
# (41.915226, -87.959294)
#
# N HAMILTON AVE
# (40.696537, -73.368294)
#
# E 79TH ST
# (40.7742888, -73.9572899)
#
# S WHIPPLE ST
# (42.6302929, -71.3004363)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# S TALMAN AVE
# (41.8617849, -87.692024)
#
# W ST
# (55.8497133, -4.2656724)
#
# S DAUPHIN AVE
# (27.8698258, -82.4986097)
#
# N LARAMIE AVE
# (41.8954167, -87.7556069)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# S SANGAMON ST
# (39.5902655, -89.7359101)
#
# S OGLESBY AVE
# (41.7448277, -87.5673518)
#
# S KEDZIE AVE
# (41.7315967, -87.7021544)
#
# S WASHTENAW AVE
# (41.8244476, -87.6922106)
#
# W GLADYS AVE
# (41.915226, -87.959294)
#
# W GREGORY ST
# (42.0735492, -87.9441124)
#
# N CLIFTON AVE
# (37.2360894, -93.3271958)
#
# N LINCOLN AVE
# (45.660956, -122.6824777)
#
# E 9TH ST
# (37.0034535, -121.5606568)
#
# S CRANDON AVE
# (41.7625938, -87.5688755)
#
# S ABERDEEN ST
# (35.7300766, -95.3526173)
#
# S CHRISTIANA AVE
# (28.6675036, -81.4969422)
#
# W 63RD ST
# (41.7733805, -87.9889844)
#
# N PAULINA ST
# (41.9902949, -87.6714344)
#
# W FULTON BLVD
# (41.8864528, -87.7038266)
#
# W OHIO ST
# (40.646058, -83.609337)
#
# S HARVARD AVE
# (40.613458, -98.098577)
#
# N HUMBOLDT BLVD
# (43.0638817, -87.8978425)
#
# S FAIRFIELD AVE
# (41.8828928, -88.0058916)
#
# E ST
# (50.4738724, 4.2358174)
#
# S PRINCETON AVE
# (39.7884436, -75.1461365)
#
# E 42ND ST
# (40.7486764, -73.9696502)
#
# S HYDE PARK BLVD
# (41.7978073, -87.5840054)
#
# N Cleveland Ave
# (30.344444, -95.0913629)
#
# S KOMENSKY AVE
# (41.7242244, -87.7231031)
#
# S CALUMET AVE
# (41.7034033, -86.871671)
#
# S ROCKWELL ST
# (33.3290958, -111.7293356)
#
# W 61ST ST
# (44.89257, -93.315002)
#
# E PL
# (14.8370417, -89.14104361631954)
#
# W EASTWOOD AVE
# (41.9656467, -87.7297858)
#
# S CHAMPLAIN AVE
# (32.1827548, -110.8194486)
#
# S MASSASOIT AVE
# (41.6640139, -87.7618901)
#
# W GRENSHAW ST
# (41.8679092, -87.6630252)
#
# N KEDZIE AVE
# (41.981245, -87.7088348)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# N MENARD AVE
# (41.8914776, -87.7700234)
#
# S EAST END AVE
# (40.7774069, -73.943042)
#
# S RICHMOND ST
# (44.8899249, -88.3024977)
#
# N HAMLIN AVE
# (41.9737701, -87.7232845)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# W LEXINGTON ST
# (39.0325997, -97.5948929)
#
# W 55TH ST
# (40.7692044, -73.9927944)
#
# S ST LOUIS AVE
# (41.0219002, -87.7208064)
#
# N PINE AVE
# (42.669591, -73.790953)
#
# S AVENUE J
# (34.1782421, -103.3451898)
#
# S ELLIS AVE
# (35.309552, -78.616879)
#
# W 91ST ST
# (41.7265995, -87.7948245)
#
# W ST
# (55.8497133, -4.2656724)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# N DRAKE AVE
# (41.9725027, -87.7171475)
#
# W RACE AVE
# (35.2508634, -91.74748)
#
# W THOMAS ST
# (43.230666, -75.469829)
#
# W WABANSIA AVE
# (41.9107882, -87.7995001)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# E ADAMS ST
# (40.191878, -85.381801)
#
# W 47TH ST
# (40.7580163, -73.9817975)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# W CARMEN AVE
# (41.9736044, -87.7374367)
#
# N WINTHROP AVE
# (41.9873032, -87.6581226)
#
# W ST
# (55.8497133, -4.2656724)
#
# S EWING AVE
# (32.7424571, -96.8126924)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# N KILBOURN AVE
# (41.9717611, -87.7405534)
#
# S MILLARD AVE
# (36.725905, -119.6804604)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# W RACE AVE
# (35.2508634, -91.74748)
#
# E ST
# (50.4738724, 4.2358174)
#
# S CORNELL AVE
# (42.119526, -87.95127)
#
# S DOTY AVE E
# (41.6512027, -87.5806882)
#
# N HOYNE AVE
# (41.9550717, -87.6812061)
#
# S PARNELL AVE
# (41.6335259, -87.6353874)
#
# N MASON AVE
# (42.354338, -85.244316)
#
# W 22ND PL
# (30.188365, -85.710205)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# S PRINCETON AVE
# (39.7884436, -75.1461365)
#
# W BYRON ST
# (41.9503382, -87.7955338)
#
# S WASHTENAW AVE
# (41.8244476, -87.6922106)
#
# S TROY ST
# (42.4897468, -83.1419423)
#
# W GLADYS AVE
# (41.915226, -87.959294)
#
# W SUPERIOR ST
# (40.857308, -96.805534)
#
# N ELSTON AVE
# (41.9624991, -87.731967)
#
# W POLK ST
# (30.7116929, -94.9383233)
#
# N MOZART ST
# (41.963078, -87.699749)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# N WASHTENAW AVE
# (41.9253795, -87.6949927)
#
# W POLK ST
# (30.7116929, -94.9383233)
#
# W DOUGLAS BLVD
# (41.8629927, -87.7029508)
#
# S STONY ISLAND AVE
# (41.772423, -87.5862745)
#
# W CORTEZ ST
# (33.5897649, -112.4664308)
#
# S PLEASANT AVE
# (40.9629751, -74.1033557)
#
# S POPLAR AVE
# (39.9536728, -74.9960653)
#
# W ADDISON ST
# (42.226415, -84.406033)
#
# S PULASKI RD
# (41.6803208, -87.7198931)
#
# S KEDVALE AVE
# (41.6474182, -87.7222793)
#
# E 35TH ST
# (42.1073395, -80.059967)
#
# S FAIRFIELD AVE
# (41.8828928, -88.0058916)
#
# W RICE ST
# (35.5516747, -80.6218475)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# S EMERALD AVE
# (33.3965996, -111.8035831)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# E ST
# (50.4738724, 4.2358174)
#
# S MAY ST
# (35.5997263, -77.5918349)
#
# S CHAMPLAIN AVE
# (32.1827548, -110.8194486)
#
# S ROCKWELL ST
# (33.3290958, -111.7293356)
#
# E WASHINGTON ST
# (48.4192112, -122.3309125)
#
# W CORTEZ ST
# (33.5897649, -112.4664308)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# W GRAND AVE
# (44.89992, -89.6139466)
#
# W MONTANA ST
# (45.6644428, -110.568881)
#
# S COTTAGE GROVE AVE
# (41.6856412, -87.6114137)
#
# W 67TH PL
# (25.8836759, -80.3255296)
#
# N MC VICKER AVE
# (41.7720642, -87.7721541)
#
# N MEADE AVE
# (38.8379256, -104.7960056)
#
# S DREXEL AVE
# (33.369843, -111.623825)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# N DEARBORN ST
# (39.865547, -86.111152)
#
# N MEADE AVE
# (38.8379256, -104.7960056)
#
# S MANISTEE AVE
# (41.6390183, -87.5555637)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# W OHIO ST
# (40.646058, -83.609337)
#
# S LAWNDALE AVE
# (41.8425259, -87.7171839)
#
# S HOYNE AVE
# (41.8228899, -87.6774807)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# S TALMAN AVE
# (41.8617849, -87.692024)
#
# W MELROSE ST
# (40.667262, -73.698695)
#
# N LATROBE AVE
# (41.9852199, -87.7604579)
#
# S KEDZIE AVE
# (41.7315967, -87.7021544)
#
# E 50TH ST
# (40.7584119, -73.9769016)
#
# W WINDSOR AVE
# (33.4760021, -112.3092496)
#
# N HARDING AVE
# (41.9937042, -87.7276304)
#
# E 9TH ST
# (37.0034535, -121.5606568)
#
# W TAYLOR ST
# (41.3837633, -75.7166377)
#
# S PEORIA ST
# (39.5974063, -104.8480467)
#
# S DREXEL AVE
# (33.369843, -111.623825)
#
# W THOMAS ST
# (43.230666, -75.469829)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# N ORCHARD ST
# (43.0517216, -77.093211)
#
# S COTTAGE GROVE AVE
# (41.6856412, -87.6114137)
#
# W GRACE ST
# (37.5509972, -77.4531109)
#
# W 12TH PL
# (25.832919, -80.291466)
#
# W FILLMORE ST
# (43.7105602, -92.2692278)
#
# W GRANVILLE AVE
# (40.245255, -96.754104)
#
# W KAMERLING AVE
# (41.9048703, -87.7639163)
#
# N MANGO AVE
# (41.9608929, -87.7709224)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# N CLYBOURN AVE
# (41.9273774, -87.6724654)
#
# S Elizabeth st
# (40.727094, -84.106756)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# S WOOD ST
# (41.343196, -83.119849)
#
# S WOOD ST
# (41.343196, -83.119849)
#
# N HALSTED ST
# (41.9468528, -87.649475)
#
# W HAYFORD ST
# (41.7557189, -87.7184111)
#
# W 77TH ST
# (39.7052739, -74.134883)
#
# S UNIVERSITY AVE
# (40.2215138, -111.658881)
#
# S BISHOP ST
# (39.5665983, -76.9892851)
#
# S BISHOP ST
# (39.5665983, -76.9892851)
#
# N ORIOLE AVE
# (41.9361388, -87.8164565)
#
# S CHAMPLAIN AVE
# (32.1827548, -110.8194486)
#
# S COTTAGE GROVE AVE
# (41.6856412, -87.6114137)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# E ST
# (50.4738724, 4.2358174)
#
# N HOYNE AVE
# (41.9550717, -87.6812061)
#
# S KILDARE AVE
# (41.6744106, -87.7275156)
#
# N KILDARE AVE
# (41.9718061, -87.7355466)
#
# S WESTERN AVE
# (43.5185145, -96.751124)
#
# W 94TH PL
# (41.4469275, -87.3368917)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# S KARLOV AVE
# (41.7139045, -87.7235728)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# N MAYFIELD AVE
# (34.1105096, -117.2902727)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# S MILLARD AVE
# (36.725905, -119.6804604)
#
# S OGLESBY AVE
# (41.7448277, -87.5673518)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# W 42ND ST
# (40.7620687, -74.0013215)
#
# S HAMILTON AVE
# (29.4083447, -98.5341118)
#
# W 95TH ST
# (40.7954358, -73.9757202)
#
# S RACINE AVE
# (42.9427005, -88.1582854)
#
# S PERRY AVE
# (27.74589, -81.794657)
#
# N LOCKWOOD AVE
# (41.6979589, -83.5699941)
#
# W 82ND ST
# (41.7450945, -87.6499675)
#
# E ST
# (50.4738724, 4.2358174)
#
# S CALIFORNIA AVE
# (34.1163848, -118.0008539)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W FOSTER AVE
# (41.975528, -87.7281106)
#
# E 55TH ST
# (40.7560064, -73.9614975)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# N RICHMOND ST
# (41.9557758, -87.7019847)
#
# W 64TH PL
# (25.881035, -80.3378206)
#
# N HARLEM AVE
# (37.093364, -94.529365)
#
# N KILDARE AVE
# (41.9718061, -87.7355466)
#
# S DREXEL AVE
# (33.369843, -111.623825)
#
# N LAWNDALE AVE
# (41.9592196, -87.720432)
#
# N LINCOLN AVE
# (45.660956, -122.6824777)
#
# S MASON AVE
# (47.1898123, -122.4941429)
#
# W 54TH PL
# (25.8719155, -80.33905)
#
# N LARRABEE ST
# (41.907027, -87.6433116)
#
# S HOMAN AVE
# (41.6622485, -87.7046222)
#
# W 71ST ST
# (39.882403, -86.227212)
#
# S DRAKE AVE
# (41.8498569, -87.713702)
#
# S MANISTEE AVE
# (41.6390183, -87.5555637)
#
# S GREENWOOD AVE
# (37.6199047, -96.228166)
#
# N DAVLIN CT
# (41.9381612, -87.7232818)
#
# S HERMITAGE AVE
# (41.7685166, -87.6675589)
#
# W DIVERSEY AVE
# (41.9263942, -88.0053438)
#
# S KOLMAR AVE
# (41.6817099, -87.7322799)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# S YALE AVE
# (36.0765216, -95.9221167)
#
# N TALMAN AVE
# (41.9139404, -87.6934262)
#
# S MACKINAW AVE
# (41.6390757, -87.5420386)
#
# S MAPLEWOOD AVE
# (36.0250954, -95.9064784)
#
# W FARWELL AVE
# (42.0067765, -87.6605207)
#
# S EBERHART AVE
# (43.822127, -84.748397)
#
# S VANDERPOEL AVE
# (41.7202873, -87.6664219)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# N AUSTIN AVE
# (41.912831, -87.7753338)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# W LAKE ST
# (41.8877192, -87.7651226)
#
# W BIRCHWOOD AVE
# (42.9399265, -87.9627232)
#
# S MANISTEE AVE
# (41.6390183, -87.5555637)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# S ESCANABA AVE
# (41.7482723, -87.55405)
#
# N SPRINGFIELD AVE
# (41.9646307, -87.7254887)
#
# S WENTWORTH AVE
# (42.9981308, -87.8894434)
#
# E WOODLAND PARK
# (41.832310250000006, -87.60984512475166)
#
# S KILDARE AVE
# (41.6744106, -87.7275156)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# S STEWART AVE
# (28.290846, -81.4066339)
#
# S CALUMET AVE
# (41.7034033, -86.871671)
#
# S CALIFORNIA AVE
# (34.1163848, -118.0008539)
#
# S UNION AVE
# (47.2491253, -122.4836389)
#
# N WELLS ST
# (30.831592, -83.286031)
#
# W PERSHING RD
# (39.8764731, -88.9678636)
#
# N KILDARE AVE
# (41.9718061, -87.7355466)
#
# S EMERALD AVE
# (33.3965996, -111.8035831)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# S DREXEL BLVD
# (35.4636206, -97.5703073)
#
# N KILPATRICK AVE
# (41.9699316, -87.74405)
#
# W PL
# (39.0445999, -94.6029041)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# W CERMAK RD
# (41.8495374, -87.849713)
#
# N ST CLAIR ST
# (38.6048814, -89.8103789)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# W BERWYN AVE
# (41.9775394, -87.712376)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# W BELDEN AVE
# (41.9187168, -87.9610749)
#
# W POLK ST
# (30.7116929, -94.9383233)
#
# S COTTAGE GROVE AVE
# (41.6856412, -87.6114137)
#
# S PRINCETON AVE
# (39.7884436, -75.1461365)
#
# W 71ST ST
# (39.882403, -86.227212)
#
# W MELROSE ST
# (40.667262, -73.698695)
#
# N CAMPBELL AVE
# (32.2527259, -110.9439424)
#
# S EVANS AVE
# (35.509722, -97.9558699)
#
# N SEDGWICK ST
# (37.693255, -97.36976)
#
# S HERMITAGE AVE
# (41.7685166, -87.6675589)
#
# S VERNON AVE
# (32.72251, -96.836774)
#
# N WASHTENAW AVE
# (41.9253795, -87.6949927)
#
# S UNION AVE
# (47.2491253, -122.4836389)
#
# W 71ST ST
# (39.882403, -86.227212)
#
# E 91ST PL
# (36.030296, -95.893687)
#
# S BENNETT AVE
# (39.047033, -82.645968)
#
# S KOSTNER AVE
# (41.6651721, -87.7289951)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# E PL
# (14.8370417, -89.14104361631954)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# S CARPENTER ST
# (35.240268, -81.338339)
#
# S ANTHONY AVE
# (37.149086, -98.028778)
#
# S CENTRAL AVE
# (40.8950402, -74.0839635)
#
# S HALSTED ST
# (41.5420844, -87.6359687)
#
# W WASHINGTON ST
# (40.194732, -85.391486)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# N ALBANY AVE
# (40.7076835, -73.465108)
#
# E 87TH ST
# (41.4677098, -81.6272505)
#
# S WASHTENAW AVE
# (41.8244476, -87.6922106)
#
# W ST
# (55.8497133, -4.2656724)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# W ST
# (55.8497133, -4.2656724)
#
# W 69TH PL
# (25.8853991, -80.3477838)
#
# S STEWART AVE
# (28.290846, -81.4066339)
#
# E 69th pl
# (41.4913223, -87.3304402)
#
# S ELIZABETH ST
# (40.727094, -84.106756)
#
# W ILLINOIS ST
# (41.862092, -88.108188)
#
# S GILES AVE
# (41.8310918, -87.6193367)
#
# W 63RD PL
# (25.8801129, -80.3380563)
#
# N SPRINGFIELD AVE
# (41.9646307, -87.7254887)
#
# N HARLEM AVE
# (37.093364, -94.529365)
#
# E 98TH ST
# (41.5353058, -87.4524707)
#
# W KENNEDY EXPY IB
# (41.8769483, -87.6457872)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# S FRANCISCO AVE
# (37.6847697, -122.4009224)
#
# S JUSTINE ST
# (41.6714397, -87.6599691)
#
# S TALMAN AVE
# (41.8617849, -87.692024)
#
# N HAMLIN AVE
# (41.9737701, -87.7232845)
#
# W ERIE ST
# (33.3076026, -111.9043792)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# W HUBBARD ST
# (41.7159012, -89.3389805)
#
# S CLYDE AVE
# (28.2911755, -81.4131903)
#
# W ELM ST
# (31.7998495, -97.0960399)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# W MARQUETTE RD
# (41.7726852, -87.6253898)
#
# S KINGSTON AVE
# (36.044406, -95.9074742)
#
# W NORTH SHORE AVE
# (42.0027093, -87.744558)
#
# S WINCHESTER AVE
# (46.406387, -105.830479)
#
# S CHAMPLAIN AVE
# (32.1827548, -110.8194486)
#
# W RACE AVE
# (35.2508634, -91.74748)
#
# S DOBSON AVE
# (41.764125, -87.5994316)
#
# W OHIO ST
# (40.646058, -83.609337)
#
# N CICERO AVE
# (42.0121975, -87.7479383)
#
# S HARPER AVE
# (33.3743982, -111.6339155)
#
# W LUNT AVE
# (42.0077782, -87.8200486)
#
# W DOUGLAS BLVD
# (41.8629927, -87.7029508)
#
# N MICHIGAN AVE
# (43.4553256, -83.9500328)
#
# S ADA ST
# (44.9307182, -93.0759931)
#
# W HUBBARD ST
# (41.7159012, -89.3389805)
#
# S HAMLIN AVE
# (42.0088243, -87.8504392)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# W 25TH PL
# (41.5724621, -87.390001)
#
# W 25TH PL
# (41.5724621, -87.390001)
#
# W PL
# (39.0445999, -94.6029041)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# N TRUMBULL AVE
# (45.5965005, -122.7536356)
#
# E PL
# (14.8370417, -89.14104361631954)
#
# W 83RD PL
# (41.4664124, -87.3859098)
#
# W DIVERSEY AVE
# (41.9263942, -88.0053438)
#
# E CHELTENHAM PL
# (41.7531429, -87.5502168)
#
# W GLENLAKE AVE
# (41.9920252, -87.7164771)
#
# S MARQUETTE AVE
# (41.6317592, -87.5567079)
#
# N KENNETH AVE
# (41.9717719, -87.7392712)
#
# S MUSKEGON AVE
# (41.6308631, -87.5542799)
#
# S SAGINAW AVE
# (41.6427026, -87.5580689)
#
# W CULLERTON ST
# (41.8556603, -87.641803)
#
# S CONFIDENTIAL ST
# (49.686739, -123.951355)
#
# S CONFIDENTIAL ST
# (49.686739, -123.951355)
#
# S CONFIDENTIAL
# (49.686739, -123.951355)
#
# W 96TH ST
# (40.7928721, -73.967548)
#
# N KEATING AVE
# (41.9746791, -87.7467834)
#
# S ELLIS AVE
# (35.309552, -78.616879)
#
# E 46TH PL
# (36.0964929, -95.7751581)
#
# S MANISTEE AVE
# (41.6390183, -87.5555637)
#
# N RIDGE AVE
# (35.5045339, -80.6185371)
#
# S KARLOV AVE
# (41.7139045, -87.7235728)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# N BROADWAY
# (40.9696948, -73.8844801)
#
# S KERFOOT AVE
# (41.7414221, -87.6404092)
#
# E 84TH ST
# (40.6411761, -73.914588)
#
# W MELROSE ST
# (40.667262, -73.698695)
#
# S FORRESTVILLE AVE
# (41.6913991, -87.6091965)
#
# N HOYNE AVE
# (41.9550717, -87.6812061)
#
# S SPRINGFIELD AVE
# (40.6858039, -74.3274558)
#
# S MOZART ST
# (41.726308, -87.6933241)
#
# S MOZART ST
# (41.726308, -87.6933241)
#
# N ALLEN AVE
# (37.5531983, -77.4608904)
#
# S WHIPPLE ST
# (42.6302929, -71.3004363)
#
# S WHIPPLE ST
# (42.6302929, -71.3004363)
#
# W 79TH ST
# (40.7849838, -73.9826637)
#
# S LOOMIS BLVD
# (41.7570599, -87.6587609)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)

# %%
# Save Checkpoint 
df2012_geo = df_2012.copy()

# %%
# Filter location that is not null
df2012_geo = df2012_geo[df2012_geo['location'].notna()]

# %%
df2012_geo = impute_district(df2012_geo)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:113: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326

# %%
# Drop columns
df2012_geo.drop(['district', 'index_right'], axis=1, inplace=True)

# Rename columns
df2012_geo.rename(columns={'dist_num':'district'}, inplace=True)

# %%
# Impute updated ward values
df2012_geo = impute_ward(df2012_geo)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:69: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326

# %%
# Drop columns
df2012_geo.drop(['ward_left', 'index_right'], axis=1, inplace=True)

# Rename columns
df2012_geo.rename(columns={'ward_right':'ward'}, inplace=True)

# %%
# Impute updated district values
df2012_geo = impute_commareas(df2012_geo)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:91: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326

# %%
# Drop columns
df2012_geo.drop(['community_area', 'index_right'], axis=1, inplace=True)

# Rename columns
df2012_geo.rename(columns={'area_numbe':'community_area'}, inplace=True)

# %%
# Balance clean up of dataset after transformation
# Drop columns
df2012_geo.drop(['x_coordinate', 'y_coordinate'], axis=1, inplace=True)

# Assign null values in location description to 'OTHER (Specify)'
df2012_geo['location_description'].fillna('OTHER (SPECIFY)', inplace = True)

# Drop row for null case_number (1 case may not be significant)
df2012_geo = df2012_geo.dropna()

# %%
df2012_geo.to_csv('/content/drive/MyDrive/Colab Notebooks/capstone/assets/2012_crime_clean.csv', index=False)

# %%
df2012_geo.isnull().sum()
# Out:
# id                      0
# case_number             0
# date                    0
# block                   0
# iucr                    0
# primary_type            0
# description             0
# location_description    0
# arrest                  0
# domestic                0
# beat                    0
# fbi_code                0
# year                    0
# updated_on              0
# latitude                0
# longitude               0
# location                0
# day                     0
# month                   0
# day_of_week             0
# time                    0
# geometry                0
# district                0
# ward                    0
# community_area          0
# dtype: int64

# %% [markdown]
# ## Clean data (2011)

# %%
# from geopy.geocoders import Nominatim
geocoder = Nominatim(user_agent = 'crime_predictions')

# %%
df_2011 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/capstone/assets/2011_crime.csv')
df_2011.head()
# Out:
#          id case_number                 date                   block  iucr  \
# 0  10225648    HY412901  2011-08-01 08:00:00    080XX S TRUMBULL AVE  1153
# 1  11042125    JA376558  2011-12-16 00:00:00         003XX W 64TH ST  1153
# 2  11042582    JA377037  2011-01-01 00:01:00  054XX S CALIFORNIA AVE  1754
# 3  10230568    HY418187  2011-12-01 00:00:00    006XX N PARKSIDE AVE  1153
# 4  10230575    HY418177  2011-10-01 00:01:00    008XX N PARKSIDE AVE  1153
#
#                  primary_type                          description  \
# 0          DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
# 1          DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
# 2  OFFENSE INVOLVING CHILDREN       AGG SEX ASSLT OF CHILD FAM MBR
# 3          DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
# 4          DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
#
#         location_description  arrest  domestic  beat  district  ward  \
# 0                  RESIDENCE   False     False   834       8.0  18.0
# 1  HOSPITAL BUILDING/GROUNDS   False     False   722       7.0  20.0
# 2                  APARTMENT    True      True   923       9.0  14.0
# 3                  RESIDENCE   False     False  1511      15.0  29.0
# 4                  RESIDENCE   False     False  1511      15.0  29.0
#
#    community_area fbi_code  x_coordinate  y_coordinate  year  \
# 0            70.0       11     1154779.0     1851149.0  2011
# 1            68.0       11           NaN           NaN  2011
# 2            63.0       02           NaN           NaN  2011
# 3            25.0       11     1138569.0     1903659.0  2011
# 4            25.0       11     1138539.0     1904990.0  2011
#
#                updated_on   latitude  longitude  \
# 0  02/09/2018 03:44:29 PM  41.747362 -87.708424
# 1  08/05/2017 03:50:08 PM        NaN        NaN
# 2  08/13/2017 03:50:54 PM        NaN        NaN
# 3  02/09/2018 03:44:29 PM  41.891766 -87.766554
# 4  02/09/2018 03:44:29 PM  41.895419 -87.766632
#
#                         location  day  month  day_of_week  time
# 0  (41.747362057, -87.708423712)    1      8            0     8
# 1                            NaN   16     12            4     0
# 2                            NaN    1      1            5     0
# 3  (41.891765632, -87.766553683)    1     12            3     0
# 4  (41.895418606, -87.766631575)    1     10            5     0

# %%
df_2011.isnull().sum()
# Out:
# id                        0
# case_number               0
# date                      0
# block                     0
# iucr                      0
# primary_type              0
# description               0
# location_description    296
# arrest                    0
# domestic                  0
# beat                      0
# district                  0
# ward                     14
# community_area          181
# fbi_code                  0
# x_coordinate            600
# y_coordinate            600
# year                      0
# updated_on                0
# latitude                600
# longitude               600
# location                600
# day                       0
# month                     0
# day_of_week               0
# time                      0
# dtype: int64

# %%
replace_to_zero(df_2011)

# %%
index_list = missing_row_loc(df_2011)
# Out:
# 600

# %%
impute_data(df_2011, index_list)
# Out:
# [1, 2, 5, 8, 9, 10, 11, 18, 19, 22, 47, 59, 60, 69, 70, 71, 72, 73, 74, 75, 78, 80, 83, 84, 85, 86, 87, 89, 90, 91, 93, 94, 95, 97, 100, 106, 107, 109, 113, 116, 117, 118, 119, 120, 121, 122, 123, 124, 125, 126, 127, 128, 129, 130, 131, 133, 134, 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145, 146, 147, 149, 150, 151, 152, 153, 154, 157, 158, 159, 165, 167, 171, 172, 175, 177, 178, 181, 184, 185, 186, 187, 188, 189, 190, 191, 193, 194, 195, 196, 197, 198, 199, 200, 201, 213, 230, 233, 259, 261, 263, 265, 284, 289, 403, 572, 625, 626, 627, 628, 629, 630, 631, 632, 635, 636, 637, 638, 640, 641, 642, 643, 644, 645, 646, 647, 648, 650, 652, 653, 654, 655, 657, 658, 659, 660, 661, 662, 663, 664, 665, 666, 667, 668, 669, 670, 671, 672, 689, 690, 695, 696, 697, 703, 705, 708, 709, 710, 711, 712, 34381, 45452, 50261, 50263, 53287, 96592, 218872, 344239, 344241, 344386, 344387, 344388, 344389, 344393, 344396, 344397, 344398, 344399, 344400, 344401, 344403, 344404, 344405, 344406, 344407, 344408, 344409, 344410, 344411, 344412, 344413, 344414, 344415, 344416, 344417, 344418, 344419, 344420, 344421, 344422, 344423, 344424, 344425, 344426, 344427, 344428, 344429, 344430, 344432, 344437, 344438, 344441, 344453, 344455, 344456, 344460, 344461, 344462, 344463, 344465, 344466, 344467, 344468, 344469, 344470, 344472, 344478, 344479, 344480, 344485, 344488, 344490, 344499, 344506, 344512, 344513, 344514, 344515, 344516, 344517, 344519, 344521, 344526, 344527, 344529, 344530, 344535, 344536, 344542, 344544, 344556, 344557, 344568, 344569, 344571, 344575, 344576, 344590, 344595, 344599, 344610, 344613, 344620, 344633, 344654, 344660, 344662, 344667, 344671, 344676, 344678, 344692, 344694, 344698, 344704, 344707, 344715, 344717, 344728, 344735, 344741, 344742, 344745, 344747, 344749, 344753, 344754, 344755, 344756, 344760, 344762, 344764, 344771, 344774, 344775, 344780, 344783, 344789, 344803, 344804, 344806, 344821, 344822, 344823, 344825, 344832, 344841, 344852, 344853, 344855, 344860, 344863, 344864, 344867, 344874, 344885, 344892, 344897, 344898, 344900, 344902, 344911, 344920, 344928, 344934, 344947, 344950, 344967, 344969, 344981, 344989, 344997, 345001, 345002, 345005, 345023, 345030, 345031, 345034, 345036, 345058, 345063, 345064, 345071, 345077, 345083, 345090, 345091, 345092, 345093, 345094, 345096, 345098, 345107, 345113, 345131, 345136, 345137, 345139, 345141, 345142, 345145, 345146, 345147, 345148, 345149, 345150, 345151, 345152, 345153, 345159, 345160, 345162, 345166, 345171, 345172, 345173, 345174, 345177, 345181, 345185, 345191, 345192, 345197, 345198, 345201, 345204, 345211, 345212, 345217, 345218, 345219, 345222, 345224, 345226, 345235, 345247, 345286, 345308, 345316, 345317, 345394, 345408, 345532, 345539, 345540, 345542, 345543, 345551, 345854, 345856, 345857, 345858, 345859, 345861, 345864, 345865, 345867, 345871, 345882, 345885, 345886, 345887, 345888, 345890, 345891, 345892, 345893, 345894, 345895, 345896, 345897, 345898, 345899, 345900, 345902, 345905, 345908, 345909, 345910, 345911, 345912, 345913, 345914, 345915, 345916, 345917, 345918, 345919, 345922, 345924, 345925, 345926, 345927, 345928, 345929, 345930, 345932, 345933, 345934, 345935, 345936, 345938, 345939, 345944, 345953, 345954, 345955, 345957, 345958, 345959, 345960, 345961, 345963, 345968, 345969, 345970, 345971, 345974, 345979, 345983, 345986, 345989, 345991, 345992, 345993, 345994, 345995, 345996, 345999, 346001, 346002, 346004, 346006, 346009, 346010, 346012, 346013, 346015, 346016, 346017, 346018, 346019, 346020, 346021, 346022, 346031, 346032, 346033, 346034, 346035, 346036, 346037, 346038, 346039, 346040, 346041, 346042, 346043, 346044, 346045, 346046, 346047, 346048, 346049, 346050, 346051, 346052, 346053, 346054, 346055, 346056, 346057, 346058, 346059, 346060, 346061, 346062, 346063, 346064, 346065, 346066, 346067, 346068, 346069, 346070, 346071, 346072, 346073, 346074, 346075, 346076, 346077, 346078, 346079, 346080, 346081, 346082, 346083, 346084, ...
#
# W 64TH ST
# (39.0130173, -94.802986)
#
# S CALIFORNIA AVE
# (34.1163848, -118.0008539)
#
# S MARSHFIELD AVE
# (41.8093553, -87.6662057)
#
# E SOUTH WATER ST
# (41.8867796, -87.6225047)
#
# E ONTARIO ST
# (42.9988209, -87.8882358)
#
# W ST
# (55.8497133, -4.2656724)
#
# S VERNON AVE
# (32.72251, -96.836774)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# W ROSCOE ST
# (41.9417774, -87.798255)
#
# N TROY ST
# (41.9593759, -87.70697)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# S ABERDEEN ST
# (35.7300766, -95.3526173)
#
# S LA CROSSE AVE
# (41.659632, -87.7403304)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# W 51ST ST
# (40.7597316, -73.9780866)
#
# W CORTEZ ST
# (33.5897649, -112.4664308)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# N RICHMOND ST
# (41.9557758, -87.7019847)
#
# W CHICAGO AVE
# (41.8965708, -87.6357092)
#
# W IOWA ST
# (43.0518372, -91.3949007)
#
# S PERRY AVE
# (27.74589, -81.794657)
#
# N MONITOR AVE
# (41.9791477, -87.7744717)
#
# S PARNELL AVE
# (41.6335259, -87.6353874)
#
# E 80TH ST
# (39.706875, -74.132378)
#
# N DRAKE AVE
# (41.9725027, -87.7171475)
#
# S KIMBARK AVE
# (41.7673136, -87.5941382)
#
# W 95TH ST
# (40.7954358, -73.9757202)
#
# E 74TH ST
# (40.7710532, -73.9596512)
#
# S DREXEL BLVD
# (35.4636206, -97.5703073)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# S AVENUE O
# (30.567085, -98.28942)
#
# S CHURCH ST
# (41.2952576, -82.9712879)
#
# S DREXEL BLVD
# (35.4636206, -97.5703073)
#
# W ROOSEVELT RD
# (41.8568563, -88.1736282)
#
# S BISHOP ST
# (39.5665983, -76.9892851)
#
# S TALMAN AVE
# (41.8617849, -87.692024)
#
# S ARTESIAN AVE
# (34.0977413, -117.3182866)
#
# S PEORIA ST
# (39.5974063, -104.8480467)
#
# S WASHTENAW AVE
# (41.8244476, -87.6922106)
#
# S ARCHER AVE
# (41.6335223, -88.0133585)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S JUSTINE ST
# (41.6714397, -87.6599691)
#
# S RACINE AVE
# (42.9427005, -88.1582854)
#
# E 41ST ST
# (44.928696, -93.2276561)
#
# S HERMITAGE AVE
# (41.7685166, -87.6675589)
#
# N LAVERGNE AVE
# (41.9090105, -87.9045527)
#
# W 71ST ST
# (39.882403, -86.227212)
#
# E 59TH ST
# (40.7639662, -73.9722705)
#
# S HONORE ST
# (41.8267808, -87.6715176)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# S KARLOV AVE
# (41.7139045, -87.7235728)
#
# N LEGETT AVE
# (41.9935033, -87.7539136)
#
# S CARPENTER ST
# (35.240268, -81.338339)
#
# S MARQUETTE AVE
# (41.6317592, -87.5567079)
#
# S SPAULDING AVE
# (34.0288086, -118.3700242)
#
# S BUFFALO AVE
# (31.4608364, -96.0651776)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# S WESTERN AVE
# (43.5185145, -96.751124)
#
# S CALIFORNIA BLVD
# (37.8959724, -122.0627491)
#
# E DELAWARE PL
# (41.8992723, -87.6202196)
#
# N STATE ST
# (44.619052, -75.408869)
#
# E 95TH ST
# (40.7835163, -73.9474639)
#
# N ELK GROVE AVE
# (41.9093578, -87.6740675)
#
# N LONG AVE
# (31.872625, -102.526908)
#
# S PEORIA ST
# (39.5974063, -104.8480467)
#
# N OAK PARK AVE
# (41.9071844, -87.7950033)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# W MONTROSE AVE
# (41.9607197, -87.7466474)
#
# N ELK GROVE AVE
# (41.9093578, -87.6740675)
#
# S FRANCISCO AVE
# (37.6847697, -122.4009224)
#
# S EMERALD AVE
# (33.3965996, -111.8035831)
#
# N FRANCISCO AVE
# (26.2217801, -98.3199932)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# W 86TH PL
# (41.4598471, -87.34753)
#
# W SUPERIOR ST
# (40.857308, -96.805534)
#
# N TROY ST
# (41.9593759, -87.70697)
#
# S OGLESBY AVE
# (41.7448277, -87.5673518)
#
# N MASSASOIT AVE
# (41.896595, -87.7691028)
#
# N HAMLIN AVE
# (41.9737701, -87.7232845)
#
# W GARFIELD BLVD
# (41.7944433, -87.6378706)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# W 71ST ST
# (39.882403, -86.227212)
#
# S HAMLIN AVE
# (42.0088243, -87.8504392)
#
# S SANGAMON ST
# (39.5902655, -89.7359101)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# W GRACE ST
# (37.5509972, -77.4531109)
#
# W GLADYS AVE
# (41.915226, -87.959294)
#
# W BLOOMINGDALE AVE
# (27.8936206, -82.2946314)
#
# S JUSTINE ST
# (41.6714397, -87.6599691)
#
# S MILLARD AVE
# (36.725905, -119.6804604)
#
# S WALLACE ST
# (38.6625346, -87.3019057)
#
# S MAPLEWOOD AVE
# (36.0250954, -95.9064784)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# N MAPLEWOOD AVE
# (36.1771957, -95.9078851)
#
# S PULASKI RD
# (41.6803208, -87.7198931)
#
# W OHIO ST
# (40.646058, -83.609337)
#
# W IRVING PARK RD
# (41.953826, -87.7116755)
#
# N SOUTHPORT AVE
# (41.9507055, -87.6641098)
#
# W ALTGELD ST
# (41.9262007, -87.8075454)
#
# W FULLERTON AVE
# (41.923398, -87.9104238)
#
# N ORIOLE AVE
# (41.9361388, -87.8164565)
#
# S TRIPP AVE
# (41.663533, -87.72595)
#
# S SCOTTSDALE AVE
# (41.7436903, -87.7351604)
#
# W VERMONT ST
# (39.7724557, -86.2529508)
#
# W ALTGELD ST
# (41.9262007, -87.8075454)
#
# E 62ND ST
# (44.890728, -93.259847)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# E 87TH PL
# (36.038195, -95.888076)
#
# S FAIRFIELD AVE
# (41.8828928, -88.0058916)
#
# W FULTON BLVD
# (41.8864528, -87.7038266)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# S WESTERN AVE
# (43.5185145, -96.751124)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# S ABERDEEN ST
# (35.7300766, -95.3526173)
#
# N clark st
# (42.076021, -78.402981)
#
# W HIGGINS AVE
# (41.9820571, -87.8112681)
#
# W BERENICE AVE
# (41.9494861, -87.7950096)
#
# N CLEAVER ST
# (41.90877725, -87.66409688742331)
#
# N NARRAGANSETT AVE
# (41.9633701, -87.7869544)
#
# N WELLS ST
# (30.831592, -83.286031)
#
# S CENTRAL PARK AVE
# (41.7169517, -87.7114806)
#
# E 70TH PL
# (39.8821985, -86.1446465)
#
# W FLOURNOY ST
# (28.406267, -97.7593919)
#
# W 32ND ST
# (44.9447377, -93.2874525)
#
# W LEXINGTON ST
# (39.0325997, -97.5948929)
#
# S MAY ST
# (35.5997263, -77.5918349)
#
# W TAYLOR ST
# (41.3837633, -75.7166377)
#
# S WOOD ST
# (41.343196, -83.119849)
#
# S CARPENTER ST
# (35.240268, -81.338339)
#
# W WEST END AVE
# (41.8840066, -87.7595529)
#
# N DRAKE AVE
# (41.9725027, -87.7171475)
#
# W ARMITAGE AVE
# (43.1023086, -87.9910021)
#
# S CHAMPLAIN AVE
# (32.1827548, -110.8194486)
#
# S AVENUE J
# (34.1782421, -103.3451898)
#
# S KOLIN AVE
# (41.6804633, -87.7282162)
#
# W 38TH ST
# (39.7635758, -75.5276556)
#
# W SHERWIN AVE
# (42.0150507, -87.7786003)
#
# N RICHMOND ST
# (41.9557758, -87.7019847)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# E 41ST ST
# (44.928696, -93.2276561)
#
# S SAWYER AVE
# (47.2288772, -122.4540806)
#
# S ELIZABETH ST
# (40.727094, -84.106756)
#
# S GILES AVE
# (41.8310918, -87.6193367)
#
# W LAKE ST
# (41.8877192, -87.7651226)
#
# S ST LAWRENCE AVE
# (41.7682281, -87.6104913)
#
# S LAKE PARK AVE
# (41.5348577, -87.2596604)
#
# N LAWLER AVE
# (41.9186896, -87.7523027)
#
# W MONTVALE AVE
# (35.2007361, -111.6600613)
#
# S LEAMINGTON AVE
# (41.7619164, -87.7501006)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W 77TH ST
# (39.7052739, -74.134883)
#
# S FRANCISCO AVE
# (37.6847697, -122.4009224)
#
# S KEDVALE AVE
# (41.6474182, -87.7222793)
#
# E 40TH ST
# (44.9305097, -93.2276849)
#
# W WABANSIA AVE
# (41.9107882, -87.7995001)
#
# S MOZART ST
# (41.726308, -87.6933241)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# S PAULINA ST
# (41.878849, -87.6692204)
#
# S HARDING AVE
# (36.6834759, -119.7343476)
#
# S OGLESBY AVE
# (41.7448277, -87.5673518)
#
# S SACRAMENTO AVE
# (39.3373525, -74.4801189)
#
# S MUSKEGON AVE
# (41.6308631, -87.5542799)
#
# N AVERS AVE
# (41.9628652, -87.724203)
#
# W ELM ST
# (31.7998495, -97.0960399)
#
# N NORDICA AVE
# (41.9489763, -87.8034519)
#
# S DRAKE AVE
# (41.8498569, -87.713702)
#
# S CONFIDENTIAL ST
# (49.686739, -123.951355)
#
# W Briar Pl
# (41.9391149, -87.6468032)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# N OAK PARK AVE
# (41.9071844, -87.7950033)
#
# W 18TH PL
# (30.230237, -85.651847)
#
# W OHIO ST
# (40.646058, -83.609337)
#
# S LOOMIS ST
# (41.769112, -88.14147)
#
# W 61ST ST
# (44.89257, -93.315002)
#
# E BELLEVUE PL
# (41.901579, -87.6272014)
#
# S Dr Martin Luther King Jr Dr
# (32.3874438, -80.5764049)
#
# S MAPLEWOOD AVE
# (36.0250954, -95.9064784)
#
# N MAYFIELD AVE
# (34.1105096, -117.2902727)
#
# N LOREL AVE
# (41.8840101, -87.7588689)
#
# S HALSTED ST
# (41.5420844, -87.6359687)
#
# S CONFIDENTIAL ST
# (49.686739, -123.951355)
#
# N Broadway
# (40.9696948, -73.8844801)
#
# W GREENLEAF AVE
# (42.010296, -87.6685965)
#
# W GOETHE ST
# (41.9056968, -87.6365183)
#
# N TROY ST
# (41.9593759, -87.70697)
#
# S LAKE PARK AVE
# (41.5348577, -87.2596604)
#
# N LATROBE AVE
# (41.9852199, -87.7604579)
#
# N STATE ST
# (44.619052, -75.408869)
#
# E 73RD ST
# (32.0274706, -81.1097986)
#
# N SPRINGFIELD AVE
# (41.9646307, -87.7254887)
#
# W DOUGLAS BLVD
# (41.8629927, -87.7029508)
#
# E 72ND PL
# (39.886358, -86.078593)
#
# W 13TH ST
# (40.5482226, -85.6954353)
#
# S CARPENTER ST
# (35.240268, -81.338339)
#
# S WESTERN AVE
# (43.5185145, -96.751124)
#
# W 16TH ST
# (37.3052344, -120.4970248)
#
# N BROADWAY
# (40.9696948, -73.8844801)
#
# S ELLIS AVE
# (35.309552, -78.616879)
#
# W CTA 95TH ST LN
# (41.7211687, -87.6248031)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# W HASTINGS ST
# (34.482251, -91.5564269)
#
# W 59TH PL
# (25.8763307, -80.3068213)
#
# W ROOSEVELT RD
# (41.8568563, -88.1736282)
#
# S KEDZIE AVE
# (41.7315967, -87.7021544)
#
# W 59TH ST
# (40.7646364, -73.9737661)
#
# W FIFTH AVE
# (42.6509145, -71.3368917)
#
# E 58TH ST
# (44.897872, -93.2773963)
#
# N ST LOUIS AVE
# (41.9727203, -87.7159449)
#
# W GARFIELD BLVD
# (41.7944433, -87.6378706)
#
# E 79TH ST
# (40.7742888, -73.9572899)
#
# W HARRISON ST
# (47.453523, -116.785825)
#
# W GRACE ST
# (37.5509972, -77.4531109)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# W Aldine Ave
# (41.9418061, -87.6487849)
#
# W 61ST ST
# (44.89257, -93.315002)
#
# N CENTRAL PARK AVE
# (41.9751896, -87.7184185)
#
# S SOUTH SHORE DR
# (41.7687175, -87.5665152)
#
# W AUGUSTA BLVD
# (41.4210887, -87.732417)
#
# S DREXEL AVE
# (33.369843, -111.623825)
#
# E 72ND ST
# (40.7710212, -73.9636252)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# W EVERGREEN AVE
# (34.1350555, -118.0011499)
#
# W LAKE ST
# (41.8877192, -87.7651226)
#
# N LA SALLE DR
# (32.459967, -99.781336)
#
# W GRENSHAW ST
# (41.8679092, -87.6630252)
#
# W GRAND AVE
# (44.89992, -89.6139466)
#
# S WESTERN AVE
# (43.5185145, -96.751124)
#
# S COLFAX AVE
# (30.853988, -96.9914143)
#
# N SACRAMENTO BLVD
# (41.889664, -87.7013745)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# S WALDEN PKWY
# (41.7166332, -87.6677208)
#
# N LANSING AVE
# (36.1766027, -95.9807343)
#
# S CRANDON AVE
# (41.7625938, -87.5688755)
#
# N LINDER AVE
# (43.4908412, -116.4138278)
#
# S MILLARD AVE
# (36.725905, -119.6804604)
#
# W 34TH ST
# (40.7569672, -74.0047906)
#
# N DAMEN AVE
# (41.9744669, -87.6793492)
#
# N FRANCISCO AVE
# (26.2217801, -98.3199932)
#
# W PALMER ST
# (35.1795946, -83.3858583)
#
# E PL
# (14.8370417, -89.14104361631954)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# S DORCHESTER AVE
# (41.861114, -88.126156)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# S CALIFORNIA AVE
# (34.1163848, -118.0008539)
#
# N STATE ST
# (44.619052, -75.408869)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# S EWING AVE
# (32.7424571, -96.8126924)
#
# E 40TH ST
# (44.9305097, -93.2276849)
#
# W BRYN MAWR AVE
# (41.983045, -87.711304)
#
# W ST
# (55.8497133, -4.2656724)
#
# E 44TH ST
# (44.9233272, -93.2683053)
#
# W 18TH PL
# (30.230237, -85.651847)
#
# W ST
# (55.8497133, -4.2656724)
#
# N LOWELL AVE
# (43.051309, -76.184402)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# W 87TH ST
# (38.970993, -94.7161832)
#
# W LAKESIDE PL
# (42.0625044, -88.0999232)
#
# S KINGSTON AVE
# (36.044406, -95.9074742)
#
# S PAULINA ST
# (41.878849, -87.6692204)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# S HARPER AVE
# (33.3743982, -111.6339155)
#
# W POLK ST
# (30.7116929, -94.9383233)
#
# S KENNETH AVE
# (41.6814466, -87.7302028)
#
# N KIMBALL AVE
# (32.948407, -97.1167804)
#
# E 89TH ST
# (40.7778572, -73.9457131)
#
# E WALTON ST
# (33.0918832, -83.2257331)
#
# N FRANCISCO AVE
# (26.2217801, -98.3199932)
#
# E 53RD ST
# (40.7580248, -73.9701634)
#
# S CHAMPLAIN AVE
# (32.1827548, -110.8194486)
#
# N LINCOLN AVE
# (45.660956, -122.6824777)
#
# N MENARD AVE
# (41.8914776, -87.7700234)
#
# S SANGAMON ST
# (39.5902655, -89.7359101)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# S WOODLAWN AVE
# (41.7812374, -87.5962214)
#
# W GRAND AVE
# (44.89992, -89.6139466)
#
# W 74TH ST
# (40.780251, -73.9814398)
#
# W CORTLAND ST
# (42.591483, -76.371899)
#
# S AVERS AVE
# (41.6734757, -87.7157121)
#
# W WRIGHTWOOD AVE
# (41.9247283, -87.9553717)
#
# S BLACKSTONE AVE
# (41.78726, -87.881703)
#
# S INGLESIDE AVE
# (41.7403543, -87.601287)
#
# N PINE AVE
# (42.669591, -73.790953)
#
# S GREENWOOD AVE
# (37.6199047, -96.228166)
#
# S CLYDE AVE
# (28.2911755, -81.4131903)
#
# N CICERO AVE
# (42.0121975, -87.7479383)
#
# W 60TH PL
# (25.877393, -80.338291)
#
# S PEORIA ST
# (39.5974063, -104.8480467)
#
# S EAST END AVE
# (40.7774069, -73.943042)
#
# S LOOMIS BLVD
# (41.7570599, -87.6587609)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# W THORNDALE AVE
# (41.9885001, -87.7104758)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S CARPENTER ST
# (35.240268, -81.338339)
#
# E 80TH ST
# (39.706875, -74.132378)
#
# N KEDZIE AVE
# (41.981245, -87.7088348)
#
# W MARQUETTE RD
# (41.7726852, -87.6253898)
#
# W MAYPOLE AVE
# (41.8835952, -87.7087902)
#
# N GLENWOOD AVE
# (42.650887, -83.284998)
#
# E 89TH ST
# (40.7778572, -73.9457131)
#
# N LECLAIRE AVE
# (41.935091, -87.7540962)
#
# S PARNELL AVE
# (41.6335259, -87.6353874)
#
# S MONITOR AVE
# (41.8023373, -87.7691002)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# S KILBOURN AVE
# (41.8591487, -87.737185)
#
# W GRACE ST
# (37.5509972, -77.4531109)
#
# W MARQUETTE RD
# (41.7726852, -87.6253898)
#
# W MARQUETTE RD
# (41.7726852, -87.6253898)
#
# S WELLS ST
# (38.0067095, -89.2477996)
#
# S EVERETT AVE
# (42.087455, -79.227396)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# S KEDZIE AVE
# (41.7315967, -87.7021544)
#
# S DEARBORN ST
# (47.5958836, -122.318572)
#
# N RICHMOND ST
# (41.9557758, -87.7019847)
#
# N MENARD AVE
# (41.8914776, -87.7700234)
#
# S VINCENNES AVE
# (41.6979977, -87.6592612)
#
# S CALIFORNIA AVE
# (34.1163848, -118.0008539)
#
# S DREXEL AVE
# (33.369843, -111.623825)
#
# W TOUHY AVE
# (42.0118322, -87.7491207)
#
# S DEARBORN ST
# (47.5958836, -122.318572)
#
# W FLOURNOY ST
# (28.406267, -97.7593919)
#
# S GREEN BAY AVE
# (41.6372553, -87.540884)
#
# S ELIZABETH ST
# (40.727094, -84.106756)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# E 65TH ST
# (25.8818612, -80.2655861)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# N KILBOURN AVE
# (41.9717611, -87.7405534)
#
# N HOYNE AVE
# (41.9550717, -87.6812061)
#
# S PAULINA ST
# (41.878849, -87.6692204)
#
# S HALSTED ST
# (41.5420844, -87.6359687)
#
# W SCHOOL ST
# (33.3044468, -96.4028596)
#
# S CARPENTER ST
# (35.240268, -81.338339)
#
# S EDBROOKE AVE
# (41.6980924, -87.6196287)
#
# S ST LAWRENCE AVE
# (41.7682281, -87.6104913)
#
# S PEORIA ST
# (39.5974063, -104.8480467)
#
# S SACRAMENTO AVE
# (39.3373525, -74.4801189)
#
# S EWING AVE
# (32.7424571, -96.8126924)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# N LECLAIRE AVE
# (41.935091, -87.7540962)
#
# W 76TH ST
# (33.9707255, -118.2915697)
#
# W 63RD ST
# (41.7733805, -87.9889844)
#
# W 63RD ST
# (41.7733805, -87.9889844)
#
# W 60TH ST
# (44.89423, -93.301147)
#
# W 65TH PL
# (39.876, -86.192027)
#
# N ASHLAND AVE
# (37.99278, -84.165192)
#
# W PL
# (39.0445999, -94.6029041)
#
# W PL
# (39.0445999, -94.6029041)
#
# S ESCANABA AVE
# (41.7482723, -87.55405)
#
# N STATE ST
# (44.619052, -75.408869)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W 24TH ST
# (39.8009909, -86.170301)
#
# S MINERVA AVE
# (42.487236, -83.118805)
#
# S KOLIN AVE
# (41.6804633, -87.7282162)
#
# S DREXEL BLVD
# (35.4636206, -97.5703073)
#
# N MAYFIELD AVE
# (34.1105096, -117.2902727)
#
# W 63rd pl
# (25.8801129, -80.3380563)
#
# W NORTH AVE
# (39.3102943, -76.6372005)
#
# W 21ST PL
# (41.579758, -87.3761617)
#
# E 40TH ST
# (44.9305097, -93.2276849)
#
# S MORGAN ST
# (35.2789536, -81.5431898)
#
# S COTTAGE GROVE AVE
# (41.6856412, -87.6114137)
#
# W ST
# (55.8497133, -4.2656724)
#
# S CORLISS AVE
# (41.6899396, -87.6012166)
#
# W ADDISON ST
# (42.226415, -84.406033)
#
# N KILBOURN AVE
# (41.9717611, -87.7405534)
#
# N LOWER MICHIGAN AVE
# (41.888842, -87.624413)
#
# W 48TH ST
# (44.915947, -93.294662)
#
# S CONFIDENTIAL
# (49.686739, -123.951355)
#
# W LAKE ST
# (41.8877192, -87.7651226)
#
# S CONFIDENTIAL
# (49.686739, -123.951355)
#
# W 59TH ST
# (40.7646364, -73.9737661)
#
# S Parkside ave
# (34.0213373, -117.6290334)
#
# S Avenue G
# (31.724859, -97.549034)
#
# N LOREL AVE
# (41.8840101, -87.7588689)
#
# N WASHTENAW AVE
# (41.9253795, -87.6949927)
#
# S PAXTON AVE
# (41.7316571, -87.5707162)
#
# W GRACE ST
# (37.5509972, -77.4531109)
#
# S KEELER AVE
# (36.7501253, -95.9789915)
#
# W IRVING PARK RD
# (41.953826, -87.7116755)
#
# N KENMORE AVE
# (34.0845852, -117.6542025)
#
# W GRENSHAW ST
# (41.8679092, -87.6630252)
#
# N ST LOUIS AVE
# (41.9727203, -87.7159449)
#
# N BELL AVE
# (32.2464153, -110.8940884)
#
# W CORTLAND ST
# (42.591483, -76.371899)
#
# N LINDER AVE
# (43.4908412, -116.4138278)
#
# S CENTRAL PARK AVE
# (41.7169517, -87.7114806)
#
# N LOREL AVE
# (41.8840101, -87.7588689)
#
# S MOZART ST
# (41.726308, -87.6933241)
#
# S ELLIS AVE
# (35.309552, -78.616879)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W DIVERSEY AVE
# (41.9263942, -88.0053438)
#
# S AVENUE F
# (40.55307, -90.047893)
#
# W WALNUT ST
# (31.8085297, -97.0935238)
#
# N BELL AVE
# (32.2464153, -110.8940884)
#
# S MERRILL AVE
# (47.1026257, -104.715102)
#
# W 18TH ST
# (39.041594, -96.8333437)
#
# S NORMAL AVE
# (37.720105, -89.21769)
#
# N MENARD AVE
# (41.8914776, -87.7700234)
#
# S COLFAX AVE
# (30.853988, -96.9914143)
#
# N LOTUS AVE
# (35.4704582, -97.3553818)
#
# W MONTROSE AVE
# (41.9607197, -87.7466474)
#
# N KILPATRICK AVE
# (41.9699316, -87.74405)
#
# S DREXEL BLVD
# (35.4636206, -97.5703073)
#
# N KOSTNER AVE
# (41.9869013, -87.7382889)
#
# S KEDZIE AVE
# (41.7315967, -87.7021544)
#
# W TOUHY AVE
# (42.0118322, -87.7491207)
#
# W I190 EXPY
# (5.3691591, -3.954783)
#
# N SPRINGFIELD AVE
# (41.9646307, -87.7254887)
#
# N ST LOUIS AVE
# (41.9727203, -87.7159449)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W THOMAS ST
# (43.230666, -75.469829)
#
# W THOMAS ST
# (43.230666, -75.469829)
#
# E ST
# (50.4738724, 4.2358174)
#
# W ADAMS ST
# (40.139024, -91.24072)
#
# N BOSWORTH AVE
# (41.9106545, -87.6665138)
#
# S PARNELL AVE
# (41.6335259, -87.6353874)
#
# S KILDARE AVE
# (41.6744106, -87.7275156)
#
# N KEDZIE AVE
# (41.981245, -87.7088348)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# W GORDON TER
# (41.9578365, -87.6498054)
#
# E 78TH ST
# (36.0516381, -95.9637058)
#
# S EDBROOKE AVE
# (41.6980924, -87.6196287)
#
# S GREENWOOD AVE
# (37.6199047, -96.228166)
#
# S MASON AVE
# (47.1898123, -122.4941429)
#
# W LAKESIDE PL
# (42.0625044, -88.0999232)
#
# S DOBSON AVE
# (41.764125, -87.5994316)
#
# W GRENSHAW ST
# (41.8679092, -87.6630252)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# N RIDGEWAY AVE
# (41.9954911, -87.7227208)
#
# W BELDEN AVE
# (41.9187168, -87.9610749)
#
# S MARSHFIELD AVE
# (41.8093553, -87.6662057)
#
# W GREENLEAF AVE
# (42.010296, -87.6685965)
#
# N MOZART ST
# (41.963078, -87.699749)
#
# S COLFAX AVE
# (30.853988, -96.9914143)
#
# S SANGAMON ST
# (39.5902655, -89.7359101)
#
# W SHERIDAN RD
# (42.490117, -79.250962)
#
# S MARSHALL BLVD
# (41.8527744, -87.6991201)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# S AVERS AVE
# (41.6734757, -87.7157121)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# E ERIE ST
# (33.3090107, -111.8198088)
#
# S ABERDEEN ST
# (35.7300766, -95.3526173)
#
# W 24TH PL
# (41.5744811, -87.3824265)
#
# N MARMORA AVE
# (41.9567321, -87.7744508)
#
# S KINGSTON AVE
# (36.044406, -95.9074742)
#
# N MENARD AVE
# (41.8914776, -87.7700234)
#
# W WARREN BLVD
# (41.8823807, -87.6651175)
#
# S WINCHESTER AVE
# (46.406387, -105.830479)
#
# E 55TH ST
# (40.7560064, -73.9614975)
#
# N ALBANY AVE
# (40.7076835, -73.465108)
#
# S EBERHART AVE
# (43.822127, -84.748397)
#
# S ADA ST
# (44.9307182, -93.0759931)
#
# N ARTESIAN AVE
# (41.9254283, -87.6888852)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# N MEADE AVE
# (38.8379256, -104.7960056)
#
# W POLK ST
# (30.7116929, -94.9383233)
#
# S PRINCETON AVE
# (39.7884436, -75.1461365)
#
# N PARKSIDE AVE
# (34.082432, -117.6296776)
#
# E 14TH PL
# (25.835478, -80.268816)
#
# S AVALON AVE
# (34.244157, -116.386354)
#
# S ROCKWELL ST
# (33.3290958, -111.7293356)
#
# E 89TH ST
# (40.7778572, -73.9457131)
#
# N LOCKWOOD AVE
# (41.6979589, -83.5699941)
#
# W WILCOX ST
# (39.7729655, -86.2196271)
#
# W 22ND PL
# (30.188365, -85.710205)
#
# S VANDERPOEL AVE
# (41.7202873, -87.6664219)
#
# W OHARE ST
# (-25.8839318, 28.1886394)
#
# S ADA ST
# (44.9307182, -93.0759931)
#
# S UNION AVE
# (47.2491253, -122.4836389)
#
# S MULLIGAN AVE
# (41.7845739, -87.7803107)
#
# W TAYLOR ST
# (41.3837633, -75.7166377)
#
# S FRANCISCO AVE
# (37.6847697, -122.4009224)
#
# W FOSTER AVE
# (41.975528, -87.7281106)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# N PARKSIDE AVE
# (34.082432, -117.6296776)
#
# N KILDARE AVE
# (41.9718061, -87.7355466)
#
# W SUMMERDALE AVE
# (41.9789237, -87.6696222)
#
# W KAMERLING AVE
# (41.9048703, -87.7639163)
#
# W AUGUSTA BLVD
# (41.4210887, -87.732417)
#
# W 19TH ST
# (30.1833503, -85.7294777)
#
# N AVERS AVE
# (41.9628652, -87.724203)
#
# N ELBRIDGE AVE
# (41.9363334, -87.7157425)
#
# S JUSTINE ST
# (41.6714397, -87.6599691)
#
# W MARQUETTE RD
# (41.7726852, -87.6253898)
#
# N COLUMBUS DR
# (30.5692605, -85.1366536)
#
# S JEFFERY BLVD
# (41.7479785, -87.5759176)
#
# W 80TH ST
# (41.7486788, -87.6536729)
#
# N KILPATRICK AVE
# (41.9699316, -87.74405)
#
# E ST
# (50.4738724, 4.2358174)
#
# N LA CROSSE AVE
# (38.2701926, -104.5890357)
#
# W PARKER AVE
# (42.1332826, -72.7503617)
#
# S HALSTED ST
# (41.5420844, -87.6359687)
#
# S ST LOUIS AVE
# (41.0219002, -87.7208064)
#
# S CALIFORNIA AVE
# (34.1163848, -118.0008539)
#
# S KOLIN AVE
# (41.6804633, -87.7282162)
#
# S CHAMPLAIN AVE
# (32.1827548, -110.8194486)
#
# W LEXINGTON ST
# (39.0325997, -97.5948929)
#
# S KOSTNER AVE
# (41.6651721, -87.7289951)
#
# W 25TH PL
# (41.5724621, -87.390001)
#
# N HOYNE AVE
# (41.9550717, -87.6812061)
#
# N FRANCISCO AVE
# (26.2217801, -98.3199932)
#
# S KILDARE AVE
# (41.6744106, -87.7275156)
#
# N DOVER ST
# (35.259544, -77.561226)
#
# W QUINCY ST
# (28.0541053, -81.9636599)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# S GREEN ST
# (37.8040878, -87.6368672)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W 63RD ST
# (41.7733805, -87.9889844)
#
# S HALSTED ST
# (41.5420844, -87.6359687)
#
# S WHIPPLE ST
# (42.6302929, -71.3004363)
#
# W JEROME ST
# (42.0184138, -87.7002228)
#
# W MEDILL AVE
# (41.9211428, -87.8794266)
#
# E 51ST ST
# (40.754497, -73.9656924)
#
# N MULLIGAN AVE
# (41.9602275, -87.7855735)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# S CONFIDENTIAL
# (49.686739, -123.951355)
#
# S CORLISS AVE
# (41.6899396, -87.6012166)
#
# W HADDON AVE
# (41.9025006, -87.6659391)
#
# W JEROME ST
# (42.0184138, -87.7002228)
#
# N MULLIGAN AVE
# (41.9602275, -87.7855735)
#
# N STATE ST
# (44.619052, -75.408869)
#
# W IRVING PARK RD
# (41.953826, -87.7116755)
#
# W KINZIE ST
# (41.8891372, -87.6357356)
#
# N NORTHWEST HWY
# (42.0193599, -87.8423973)
#
# N PITTSBURGH AVE
# (41.9448664, -87.8327386)
#
# W GREENLEAF AVE
# (42.010296, -87.6685965)
#
# W RAVEN ST
# (41.9950834, -87.7834843)
#
# W VICTORIA ST
# (34.4152919, -119.7153286)
#
# N OAK PARK AVE
# (41.9071844, -87.7950033)
#
# S TALMAN AVE
# (41.8617849, -87.692024)
#
# S PULASKI RD
# (41.6803208, -87.7198931)
#
# N NORTHWEST HWY
# (42.0193599, -87.8423973)
#
# W JEROME ST
# (42.0184138, -87.7002228)
#
# N MAGNOLIA AVE
# (29.1969846, -82.1365046)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# W Superior St
# (40.857308, -96.805534)
#
# W 54TH PL
# (25.8719155, -80.33905)
#
# S CONFIDENTIAL ST
# (49.686739, -123.951355)
#
# S KIMBARK AVE
# (41.7673136, -87.5941382)
#
# S THROOP ST
# (41.7467867, -87.6560654)
#
# S CENTRAL PARK AVE
# (41.7169517, -87.7114806)
#
# N STATE ST
# (44.619052, -75.408869)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# N SHEFFIELD AVE
# (43.1085525, -87.8984732)
#
# S VINCENNES AVE
# (41.6979977, -87.6592612)
#
# S DAMEN AVE
# (41.8658453, -87.6761768)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# N PARKSIDE AVE
# (34.082432, -117.6296776)
#
# E 95TH ST
# (40.7835163, -73.9474639)
#
# S DANTE AVE
# (41.5394098, -87.5855724)
#
# S AVERS AVE
# (41.6734757, -87.7157121)
#
# W JUNEWAY TER
# (42.0222514, -87.6668154)
#
# S ASHLAND AVE
# (44.4802212, -88.0581457)
#
# N AUSTIN AVE
# (41.912831, -87.7753338)
#
# N MARSHFIELD AVE
# (41.9258863, -87.669388)
#
# S DANTE AVE
# (41.5394098, -87.5855724)
#
# W CERMAK RD
# (41.8495374, -87.849713)
#
# W 38TH PL
# (41.548344, -87.2952495)
#
# N TRIPP AVE
# (41.9848527, -87.7341352)
#
# S WASHTENAW AVE
# (41.8244476, -87.6922106)
#
# W 25TH ST
# (39.802821, -86.1734111)
#
# W HENDERSON ST
# (35.6845746, -80.4331586)
#
# S PEORIA ST
# (39.5974063, -104.8480467)
#
# E 87TH ST
# (41.4677098, -81.6272505)
#
# S MENARD AVE
# (41.6600662, -87.7628355)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W 66TH ST
# (40.7733596, -73.9809918)
#
# S BERKELEY AVE
# (34.0953337, -117.29685)
#
# N COMMONWEALTH AVE
# (41.7632702, -88.3435098)
#
# N BOSWORTH AVE
# (41.9106545, -87.6665138)
#
# W 58TH ST
# (44.8978415, -93.2888067)
#
# W 70TH PL
# (25.886576, -80.29765)
#
# N CLAREMONT AVE
# (36.106832, -80.228788)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# S DANTE AVE
# (41.5394098, -87.5855724)
#
# S ELLIS AVE
# (35.309552, -78.616879)
#
# S WHIPPLE ST
# (42.6302929, -71.3004363)
#
# S WHIPPLE ST
# (42.6302929, -71.3004363)
#
# S MUSKEGON AVE
# (41.6308631, -87.5542799)
#
# W WRIGHTWOOD AVE
# (41.9247283, -87.9553717)
#
# S EAST END AVE
# (40.7774069, -73.943042)
#
# N NARRAGANSETT AVE
# (41.9633701, -87.7869544)
#
# W 55TH ST
# (40.7692044, -73.9927944)
#
# N DESPLAINES ST
# (41.8890494, -87.6443381)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# W 64TH PL
# (25.881035, -80.3378206)
#
# S MAY ST
# (35.5997263, -77.5918349)
#
# W HIRSCH ST
# (41.9062185, -87.7313087)
#
# W 53RD PL
# (25.87113, -80.327087)
#
# E 84TH ST
# (40.6411761, -73.914588)
#
# S COTTAGE GROVE AVE
# (41.6856412, -87.6114137)
#
# S COTTAGE GROVE AVE
# (41.6856412, -87.6114137)
#
# S EAST END AVE
# (40.7774069, -73.943042)

# %%
# Save Checkpoint 
df2011_geo = df_2011.copy()

# %%
# Filter location that is not null
df2011_geo = df2011_geo[df2011_geo['location'].notna()]

# %%
df2011_geo = impute_district(df2011_geo)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:113: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326

# %%
# Drop columns
df2011_geo.drop(['district', 'index_right'], axis=1, inplace=True)

# Rename columns
df2011_geo.rename(columns={'dist_num':'district'}, inplace=True)

# %%
# Impute updated ward values
df2011_geo = impute_ward(df2011_geo)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:69: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326

# %%
# Drop columns
df2011_geo.drop(['ward_left', 'index_right'], axis=1, inplace=True)

# Rename columns
df2011_geo.rename(columns={'ward_right':'ward'}, inplace=True)

# %%
# Impute updated district values
df2011_geo = impute_commareas(df2011_geo)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:91: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326

# %%
# Drop columns
df2011_geo.drop(['community_area', 'index_right'], axis=1, inplace=True)

# Rename columns
df2011_geo.rename(columns={'area_numbe':'community_area'}, inplace=True)

# %%
# Balance clean up of dataset after transformation
# Drop columns
df2011_geo.drop(['x_coordinate', 'y_coordinate'], axis=1, inplace=True)

# Assign null values in location description to 'OTHER (Specify)'
df2011_geo['location_description'].fillna('OTHER (SPECIFY)', inplace = True)

# %%
df2011_geo.to_csv('/content/drive/MyDrive/Colab Notebooks/capstone/assets/2011_crime_clean.csv', index=False)

# %%
df2011_geo.isnull().sum()
# Out:
# id                      0
# case_number             0
# date                    0
# block                   0
# iucr                    0
# primary_type            0
# description             0
# location_description    0
# arrest                  0
# domestic                0
# beat                    0
# fbi_code                0
# year                    0
# updated_on              0
# latitude                0
# longitude               0
# location                0
# day                     0
# month                   0
# day_of_week             0
# time                    0
# geometry                0
# district                0
# ward                    0
# community_area          0
# dtype: int64

# %% [markdown]
# ## Clean data (2010)

# %%
# from geopy.geocoders import Nominatim
geocoder = Nominatim(user_agent = 'crime_predictions')

# %%
df_2010 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/capstone/assets/2010_crime.csv')
df_2010.head()
# Out:
#          id case_number                 date                   block  iucr  \
# 0  11042930    JA374409  2010-01-01 00:01:00  080XX S MARSHFIELD AVE  0266
# 1  10230609    HY416556  2010-09-09 20:10:00    074XX S MARYLAND AVE  1154
# 2  11033011    JA365922  2010-01-01 12:00:00      053XX S HARPER AVE  1154
# 3  11649978    JC217323  2010-04-27 09:45:00         009XX W 72ND ST  1153
# 4  11649965    JC217381  2010-11-09 03:30:00     045XX S CALUMET AVE  1153
#
#           primary_type                              description  \
# 0  CRIM SEXUAL ASSAULT                                PREDATORY
# 1   DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 2   DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 3   DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 4   DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
#
#   location_description  arrest  domestic  beat  district  ward  \
# 0            RESIDENCE   False     False   611       6.0  21.0
# 1            RESIDENCE   False     False   323       3.0   6.0
# 2            APARTMENT   False     False   234       2.0   4.0
# 3                  NaN   False     False   733       7.0   6.0
# 4                  NaN   False     False   215       2.0   3.0
#
#    community_area fbi_code  x_coordinate  y_coordinate  year  \
# 0            71.0       02           NaN           NaN  2010
# 1            69.0       11     1183191.0     1855830.0  2010
# 2            41.0       11           NaN           NaN  2010
# 3            68.0       11           NaN           NaN  2010
# 4            38.0       11           NaN           NaN  2010
#
#                updated_on   latitude  longitude  \
# 0  08/05/2017 03:50:08 PM        NaN        NaN
# 1  02/09/2018 03:44:29 PM  41.759594 -87.604169
# 2  07/28/2017 03:47:55 PM        NaN        NaN
# 3  04/10/2019 04:14:14 PM        NaN        NaN
# 4  04/10/2019 04:14:14 PM        NaN        NaN
#
#                         location  day  month  day_of_week  time
# 0                            NaN    1      1            4     0
# 1  (41.759593809, -87.604169095)    9      9            3    20
# 2                            NaN    1      1            4    12
# 3                            NaN   27      4            1     9
# 4                            NaN    9     11            1     3

# %%
df_2010.isnull().sum()
# Out:
# id                        0
# case_number               1
# date                      0
# block                     0
# iucr                      0
# primary_type              0
# description               0
# location_description     68
# arrest                    0
# domestic                  0
# beat                      0
# district                  0
# ward                     18
# community_area          186
# fbi_code                  0
# x_coordinate            427
# y_coordinate            427
# year                      0
# updated_on                0
# latitude                427
# longitude               427
# location                427
# day                       0
# month                     0
# day_of_week               0
# time                      0
# dtype: int64

# %%
replace_to_zero(df_2010)

# %%
index_list = missing_row_loc(df_2010)
# Out:
# 427

# %%
impute_data(df_2010, index_list)
# Out:
# [0, 2, 3, 4, 5, 6, 13, 14, 18, 33, 35, 38, 47, 49, 51, 52, 54, 58, 59, 60, 67, 70, 71, 72, 73, 75, 77, 80, 83, 85, 87, 88, 89, 90, 91, 92, 93, 94, 95, 96, 98, 99, 100, 101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 120, 121, 122, 123, 125, 126, 130, 134, 142, 143, 144, 148, 152, 153, 154, 155, 156, 158, 159, 160, 161, 163, 164, 166, 168, 169, 268, 285, 586, 587, 589, 590, 592, 593, 594, 595, 596, 597, 598, 599, 600, 601, 604, 607, 608, 610, 611, 612, 613, 614, 615, 616, 617, 618, 619, 620, 621, 622, 623, 624, 625, 626, 631, 632, 633, 644, 646, 43270, 352579, 362529, 363199, 363941, 364406, 364407, 364409, 364411, 364412, 364413, 364414, 364415, 364416, 364419, 364427, 364429, 364430, 364432, 364434, 364436, 364438, 364439, 364441, 364446, 364447, 364448, 364452, 364461, 364462, 364464, 364465, 364474, 364479, 364481, 364486, 364487, 364490, 364497, 364498, 364499, 364500, 364504, 364505, 364510, 364511, 364513, 364514, 364515, 364522, 364526, 364528, 364529, 364531, 364533, 364545, 364547, 364551, 364555, 364556, 364557, 364561, 364562, 364563, 364569, 364571, 364575, 364581, 364594, 364597, 364603, 364610, 364611, 364618, 364622, 364623, 364626, 364631, 364636, 364639, 364642, 364644, 364645, 364647, 364648, 364658, 364663, 364668, 364670, 364671, 364682, 364684, 364691, 364693, 364697, 364706, 364711, 364712, 364725, 364728, 364733, 364734, 364736, 364737, 364738, 364742, 364748, 364749, 364754, 364755, 364756, 364764, 364765, 364766, 364769, 364770, 364772, 364774, 364775, 364778, 364780, 364782, 364783, 364786, 364787, 364789, 364791, 364792, 364806, 364808, 364845, 364846, 364847, 364849, 364851, 364907, 365001, 365002, 365004, 365005, 365007, 365013, 365018, 365226, 365227, 365228, 365229, 365230, 365231, 365232, 365236, 365237, 365238, 365248, 365254, 365255, 365256, 365257, 365258, 365259, 365260, 365263, 365264, 365266, 365267, 365268, 365269, 365270, 365271, 365272, 365273, 365275, 365276, 365279, 365280, 365281, 365282, 365283, 365288, 365290, 365293, 365295, 365296, 365297, 365298, 365299, 365300, 365301, 365303, 365305, 365306, 365308, 365309, 365310, 365316, 365317, 365318, 365321, 365322, 365325, 365327, 365328, 365330, 365332, 365333, 365334, 365339, 365350, 365351, 365352, 365353, 365354, 365356, 365358, 365359, 365360, 365362, 365363, 365365, 365367, 365372, 365373, 365376, 365377, 365378, 365379, 365380, 365381, 365382, 365383, 365384, 365385, 365391, 365392, 365394, 365395, 365396, 365397, 365398, 365399, 365400, 365401, 365402, 365403, 365404, 365405, 365406, 365407, 365408, 365409, 365410, 365411, 365412, 365413, 365414, 365415, 365416, 365417, 365512, 365634, 365653, 365736, 366446, 366538, 366627, 366716, 366888, 366901, 367023, 367333, 367345, 367522, 367703, 367704, 367766, 367825, 367844, 367965, 367989, 368162, 368603, 368621, 368629, 369134, 369136, 369138, 369139, 369147, 369149, 370049, 370413, 370414, 370415, 370416, 370417, 370418, 370419, 370420, 370423]
#
# S MARSHFIELD AVE
# (41.8093553, -87.6662057)
#
# S HARPER AVE
# (33.3743982, -111.6339155)
#
# W 72ND ST
# (40.778834, -73.982158)
#
# S CALUMET AVE
# (41.7034033, -86.871671)
#
# W FARRAGUT AVE
# (41.9745691, -87.829751)
#
# S BISHOP ST
# (39.5665983, -76.9892851)
#
# W 63RD PL
# (25.8801129, -80.3380563)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# S VINCENNES AVE
# (41.6979977, -87.6592612)
#
# S WOOD ST
# (41.343196, -83.119849)
#
# W MADISON ST
# (41.44819, -82.7183141)
#
# E ONTARIO ST
# (42.9988209, -87.8882358)
#
# W WAVELAND AVE
# (41.9466715, -87.8113037)
#
# N SHERIDAN RD
# (40.3578419, -76.2273206)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# N CHRISTIANA AVE
# (41.9702394, -87.7121816)
#
# S HOXIE AVE
# (41.6318654, -87.5604201)
#
# S MAY ST
# (35.5997263, -77.5918349)
#
# N KARLOV AVE
# (41.9677725, -87.7304613)
#
# S TRIPP AVE
# (41.663533, -87.72595)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# S HERMOSA AVE
# (33.9126479, -116.8692547)
#
# W ST
# (55.8497133, -4.2656724)
#
# S ST LAWRENCE AVE
# (41.7682281, -87.6104913)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# S Rockwell St
# (33.3290958, -111.7293356)
#
# W DEVON AVE
# (41.9973572, -87.7114381)
#
# E ST
# (50.4738724, 4.2358174)
#
# N LATROBE AVE
# (41.9852199, -87.7604579)
#
# S GREEN ST
# (37.8040878, -87.6368672)
#
# S PAXTON AVE
# (41.7316571, -87.5707162)
#
# S FOREST AVE
# (42.2736405, -83.7331125)
#
# W GEORGE ST
# (55.8634318, -4.2657255)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# E 53RD ST
# (40.7580248, -73.9701634)
#
# N WINTHROP AVE
# (41.9873032, -87.6581226)
#
# S FRANCISCO AVE
# (37.6847697, -122.4009224)
#
# N MASON AVE
# (42.354338, -85.244316)
#
# S CORNELL AVE
# (42.119526, -87.95127)
#
# S EMERALD AVE
# (33.3965996, -111.8035831)
#
# N WOLCOTT AVE
# (41.9069854, -87.6730408)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# S ST LAWRENCE AVE
# (41.7682281, -87.6104913)
#
# N CENTRAL AVE
# (35.7718102, -91.6557941)
#
# W 25TH ST
# (39.802821, -86.1734111)
#
# E 16TH ST
# (39.788871, -86.0826411)
#
# S COTTAGE GROVE AVE
# (41.6856412, -87.6114137)
#
# W WASHINGTON BLVD
# (43.0529509, -87.9892763)
#
# W DIVERSEY AVE
# (41.9263942, -88.0053438)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# S EMERALD AVE
# (33.3965996, -111.8035831)
#
# N MONTICELLO AVE
# (41.9751716, -87.7196691)
#
# E 80TH ST
# (39.706875, -74.132378)
#
# N ROCKWELL ST
# (33.3744844, -111.7302071)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# W KINZIE ST
# (41.8891372, -87.6357356)
#
# N WASHTENAW AVE
# (41.9253795, -87.6949927)
#
# N MC CLURG CT
# (30.332179, -82.799061)
#
# W FLETCHER ST
# (28.324413, -81.40576)
#
# N CLARENDON AVE
# (39.3347411, -74.4980139)
#
# W MONROE ST
# (41.9561258, -83.658253)
#
# S CAMPBELL AVE
# (37.1712552, -93.2953919)
#
# S BEVERLY AVE
# (34.741893, -87.674971)
#
# N MAPLEWOOD AVE
# (36.1771957, -95.9078851)
#
# W BELDEN AVE
# (41.9187168, -87.9610749)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# N HOMAN AVE
# (41.8919714, -87.711335)
#
# S TRIPP AVE
# (41.663533, -87.72595)
#
# S ALBANY AVE
# (27.932852, -82.480986)
#
# W 48TH ST
# (44.915947, -93.294662)
#
# N SPAULDING AVE
# (41.9543894, -87.7104772)
#
# S RIDGEWAY AVE
# (35.61739, -82.3173401)
#
# W 15TH ST
# (44.9689141, -93.2867103)
#
# S MILLARD AVE
# (36.725905, -119.6804604)
#
# W 71ST ST
# (39.882403, -86.227212)
#
# W BELMONT AVE
# (40.839392, -96.722861)
#
# S CHAPPEL AVE
# (41.7588966, -87.5749062)
#
# S LA SALLE ST
# (41.742861, -88.3242315)
#
# S LA SALLE ST
# (41.742861, -88.3242315)
#
# S LA SALLE ST
# (41.742861, -88.3242315)
#
# N KILDARE AVE
# (41.9718061, -87.7355466)
#
# W SCHOOL ST
# (33.3044468, -96.4028596)
#
# E ST
# (50.4738724, 4.2358174)
#
# S RIDGEWAY AVE
# (35.61739, -82.3173401)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# W 65TH ST
# (34.6902193, -92.3298401)
#
# S RACINE AVE
# (42.9427005, -88.1582854)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# W ARTHINGTON ST
# (41.8700106, -87.7112288)
#
# S HARPER AVE
# (33.3743982, -111.6339155)
#
# W LEXINGTON ST
# (39.0325997, -97.5948929)
#
# W GRENSHAW ST
# (41.8679092, -87.6630252)
#
# W 21ST ST
# (44.961758, -93.306244)
#
# W OGDEN AVE
# (32.341146, -86.3093)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# S NORMAL BLVD
# (41.7792236, -87.637511)
#
# W POLK ST
# (30.7116929, -94.9383233)
#
# S WESTERN AVE
# (43.5185145, -96.751124)
#
# N LUNA AVE
# (34.454345, -119.281645)
#
# W CULLERTON ST
# (41.8556603, -87.641803)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# W LAKE ST
# (41.8877192, -87.7651226)
#
# S HOMAN AVE
# (41.6622485, -87.7046222)
#
# W ARTHUR AVE
# (42.9994824, -87.9518008)
#
# S SPAULDING AVE
# (34.0288086, -118.3700242)
#
# S STEWART AVE
# (28.290846, -81.4066339)
#
# N NOBLE ST
# (33.7944831, -117.8022079)
#
# S FEDERAL ST
# (38.443357, -78.870308)
#
# S AVENUE N
# (31.532975, -97.437499)
#
# E 98TH ST
# (41.5353058, -87.4524707)
#
# W BARRY AVE
# (36.8175627, -93.9243727)
#
# W CHASE AVE
# (32.780398, -116.9699604)
#
# N CLARENDON AVE
# (39.3347411, -74.4980139)
#
# W ST
# (55.8497133, -4.2656724)
#
# W ARGYLE ST
# (57.8956842, -5.1630045)
#
# W POTOMAC AVE
# (43.0958445, -88.0105462)
#
# N WHIPPLE ST
# (41.9721178, -87.7049131)
#
# E 32ND ST
# (44.94472, -93.2368469)
#
# W IRVING PARK RD
# (41.953826, -87.7116755)
#
# W AUGUSTA BLVD
# (41.4210887, -87.732417)
#
# N CLAREMONT AVE
# (36.106832, -80.228788)
#
# S ESCANABA AVE
# (41.7482723, -87.55405)
#
# N MERRIMAC AVE
# (39.2169153, -94.6287743)
#
# W ERIE ST
# (33.3076026, -111.9043792)
#
# W OAKDALE AVE
# (29.0407755, -81.3169917)
#
# W PRATT BLVD
# (42.0054657, -87.6658226)
#
# W DIVERSEY AVE
# (41.9263942, -88.0053438)
#
# W GREENLEAF AVE
# (42.010296, -87.6685965)
#
# S WASHTENAW AVE
# (41.8244476, -87.6922106)
#
# W CHASE AVE
# (32.780398, -116.9699604)
#
# S KEDZIE AVE
# (41.7315967, -87.7021544)
#
# W RACE AVE
# (35.2508634, -91.74748)
#
# N ROCKWELL ST
# (33.3744844, -111.7302071)
#
# S MARSHFIELD AVE
# (41.8093553, -87.6662057)
#
# W BERTEAU AVE
# (41.9561908, -87.8158422)
#
# N SPRINGFIELD AVE
# (41.9646307, -87.7254887)
#
# W 59TH ST
# (40.7646364, -73.9737661)
#
# W ELM ST
# (31.7998495, -97.0960399)
#
#  BETTY GLOYD DRIVE
# (42.0654396, -88.2362868)
#
# W 19TH ST
# (30.1833503, -85.7294777)
#
# W 61ST ST
# (44.89257, -93.315002)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# N LA SALLE ST
# (30.398997, -96.0961872)
#
# N LECLAIRE AVE
# (41.935091, -87.7540962)
#
# S ADA ST
# (44.9307182, -93.0759931)
#
# S KOSTNER AVE
# (41.6651721, -87.7289951)
#
# W PALMER ST
# (35.1795946, -83.3858583)
#
# W HURON ST
# (42.6352881, -83.3231749)
#
# W 83RD ST
# (41.7432634, -87.6499076)
#
# S SPAULDING AVE
# (34.0288086, -118.3700242)
#
# N CENTRAL AVE
# (35.7718102, -91.6557941)
#
# N SEELEY AVE
# (43.5619333, -94.7747364)
#
# N BROADWAY
# (40.9696948, -73.8844801)
#
# N LAPORTE AVE
# (41.9754723, -87.751858)
#
# S KIMBARK AVE
# (41.7673136, -87.5941382)
#
# N LAVERGNE AVE
# (41.9090105, -87.9045527)
#
# S LAKE PARK AVE
# (41.5348577, -87.2596604)
#
# N KNOX AVE
# (45.0350358, -93.3021408)
#
# N CLAREMONT AVE
# (36.106832, -80.228788)
#
# W LYNDALE ST
# (41.9201267, -87.8427793)
#
# N LAWNDALE AVE
# (41.9592196, -87.720432)
#
# W GLADYS AVE
# (41.915226, -87.959294)
#
# N KIMBALL AVE
# (32.948407, -97.1167804)
#
# S EAST END AVE
# (40.7774069, -73.943042)
#
# W GLADYS AVE
# (41.915226, -87.959294)
#
# S ST LAWRENCE AVE
# (41.7682281, -87.6104913)
#
# S WALLACE ST
# (38.6625346, -87.3019057)
#
# W 55TH ST
# (40.7692044, -73.9927944)
#
# S SACRAMENTO AVE
# (39.3373525, -74.4801189)
#
# N SAWYER AVE
# (41.9610885, -87.7094607)
#
# N KIMBALL AVE
# (32.948407, -97.1167804)
#
# W LAKE ST
# (41.8877192, -87.7651226)
#
# S RHODES AVE
# (41.180979, -80.736336)
#
# S CAMPBELL AVE
# (37.1712552, -93.2953919)
#
# N KEELER AVE
# (31.890888, -102.393391)
#
# S CHAMPLAIN AVE
# (32.1827548, -110.8194486)
#
# S MOZART ST
# (41.726308, -87.6933241)
#
# S DRAKE AVE
# (41.8498569, -87.713702)
#
# W FARGO AVE
# (36.3572713, -119.6489519)
#
# S LONGWOOD DR
# (41.1158215, -87.8298037)
#
# E 72ND ST
# (40.7710212, -73.9636252)
#
# W PERSHING RD
# (39.8764731, -88.9678636)
#
# N LONG AVE
# (31.872625, -102.526908)
#
# S LA SALLE ST
# (41.742861, -88.3242315)
#
# W 38TH ST
# (39.7635758, -75.5276556)
#
# N KARLOV AVE
# (41.9677725, -87.7304613)
#
# S LAFAYETTE AVE
# (39.334709, -74.489355)
#
# W WABANSIA AVE
# (41.9107882, -87.7995001)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# N AVERS AVE
# (41.9628652, -87.724203)
#
# S EGGLESTON AVE
# (35.407396, -97.5137083)
#
# N LOTUS AVE
# (35.4704582, -97.3553818)
#
# N CLARK ST
# (42.076021, -78.402981)
#
# S EAST END AVE
# (40.7774069, -73.943042)
#
# W BARRY AVE
# (36.8175627, -93.9243727)
#
# W HOLLYWOOD AVE
# (40.664973, -73.381541)
#
# N DRAKE AVE
# (41.9725027, -87.7171475)
#
# S EAST END AVE
# (40.7774069, -73.943042)
#
# W 71ST ST
# (39.882403, -86.227212)
#
# W IRVING PARK RD
# (41.953826, -87.7116755)
#
# S RACINE AVE
# (42.9427005, -88.1582854)
#
# S PEORIA ST
# (39.5974063, -104.8480467)
#
# N ST LOUIS AVE
# (41.9727203, -87.7159449)
#
# N LINDER AVE
# (43.4908412, -116.4138278)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# S CAMPBELL AVE
# (37.1712552, -93.2953919)
#
# S ABERDEEN ST
# (35.7300766, -95.3526173)
#
# N NASHVILLE AVE
# (33.172839, -86.245134)
#
# W WASHINGTON ST
# (40.194732, -85.391486)
#
# E GOETHE ST
# (41.9058343, -87.6272838)
#
# S CICERO AVE
# (41.8545413, -87.7443874)
#
# N PAULINA ST
# (41.9902949, -87.6714344)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# S NORMAL BLVD
# (41.7792236, -87.637511)
#
# S KARLOV AVE
# (41.7139045, -87.7235728)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# S WASHTENAW AVE
# (41.8244476, -87.6922106)
#
# S HARDING AVE
# (36.6834759, -119.7343476)
#
# W HARRISON ST
# (47.453523, -116.785825)
#
# S ABERDEEN ST
# (35.7300766, -95.3526173)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# N LUNA AVE
# (34.454345, -119.281645)
#
# S CALIFORNIA AVE
# (34.1163848, -118.0008539)
#
# S LAFLIN ST
# (41.8538083, -87.6636501)
#
# S SOUTH SHORE DR
# (41.7687175, -87.5665152)
#
# N FRANCISCO AVE
# (26.2217801, -98.3199932)
#
# S PAULINA ST
# (41.878849, -87.6692204)
#
# S RIDGELAND AVE
# (41.8835463, -87.7845574)
#
# N CENTRAL PARK AVE
# (41.9751896, -87.7184185)
#
# S NORMAL AVE
# (37.720105, -89.21769)
#
# S CENTRAL AVE
# (40.8950402, -74.0839635)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# S MARSHFIELD AVE
# (41.8093553, -87.6662057)
#
# S WACKER DR
# (41.8753503, -87.6357587)
#
# S CONFIDENTIAL
# (49.686739, -123.951355)
#
# W FLOURNOY ST
# (28.406267, -97.7593919)
#
# N KEYSTONE AVE
# (42.0001236, -76.5351751)
#
# N WINTHROP AVE
# (41.9873032, -87.6581226)
#
# E OHIO ST
# (40.601786, -84.084445)
#
# S AVENUE L
# (31.5331944, -97.4407611)
#
# S ST LAWRENCE AVE
# (41.7682281, -87.6104913)
#
# S KILDARE AVE
# (41.6744106, -87.7275156)
#
# N LAKEWOOD AVE
# (31.856847, -102.514627)
#
# W SCHUBERT AVE
# (41.921548, -88.096436)
#
# W MEDILL AVE
# (41.9211428, -87.8794266)
#
# S AVENUE L
# (31.5331944, -97.4407611)
#
# S OAKENWALD AVE
# (41.8176178, -87.5980256)
#
# W BYRON ST
# (41.9503382, -87.7955338)
#
# W HIGHLAND AVE
# (32.4336541, -87.0567983)
#
# W ILLINOIS ST
# (41.862092, -88.108188)
#
# S MAPLEWOOD AVE
# (36.0250954, -95.9064784)
#
# W AINSLIE ST
# (41.9701978, -87.7164722)
#
# S DREXEL AVE
# (33.369843, -111.623825)
#
# S PHILLIPS AVE
# (43.513078, -96.7262166)
#
# S CONSTANCE AVE
# (39.1322267, -86.4965916)
#
# E 47TH ST
# (40.7546125, -73.9737345)
#
# N WHIPPLE ST
# (41.9721178, -87.7049131)
#
# S HAMLET AVE
# (41.6889362, -87.6608953)
#
# N NOBLE ST
# (33.7944831, -117.8022079)
#
# N BROADWAY
# (40.9696948, -73.8844801)
#
# N RIDGEWAY AVE
# (41.9954911, -87.7227208)
#
# W 51ST ST
# (40.7597316, -73.9780866)
#
# S PAULINA ST
# (41.878849, -87.6692204)
#
# N MELVINA AVE
# (42.0121329, -87.7817803)
#
# W FOREST PRESERVE AVE
# (58.8130745, -136.8723522255592)
#
# S COTTAGE GROVE AVE
# (41.6856412, -87.6114137)
#
# W NORTH SHORE AVE
# (42.0027093, -87.744558)
#
# N WESTERN AVE
# (35.5293143, -97.5298153)
#
# W THOMAS ST
# (43.230666, -75.469829)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# S WOOD ST
# (41.343196, -83.119849)
#
# W LEXINGTON ST
# (39.0325997, -97.5948929)
#
# N LUNA AVE
# (34.454345, -119.281645)
#
# S FORRESTVILLE AVE
# (41.6913991, -87.6091965)
#
# S SAWYER AVE
# (47.2288772, -122.4540806)
#
# E 57TH ST
# (40.7629694, -73.9739676)
#
# S KILDARE AVE
# (41.6744106, -87.7275156)
#
# S CRANDON AVE
# (41.7625938, -87.5688755)
#
# S CALIFORNIA AVE
# (34.1163848, -118.0008539)
#
# W Bryn Mawr Ave
# (41.983045, -87.711304)
#
# E 47TH ST
# (40.7546125, -73.9737345)
#
# E 82ND ST
# (41.5041895, -81.6308342)
#
# S UNIVERSITY AVE
# (40.2215138, -111.658881)
#
# S KILDARE AVE
# (41.6744106, -87.7275156)
#
# W SUNNYSIDE AVE
# (41.9635312, -87.6603099)
#
# S Calumet Ave
# (41.7034033, -86.871671)
#
# N AUSTIN BLVD
# (41.8969924, -87.7752014)
#
# S RIDGELAND AVE
# (41.8835463, -87.7845574)
#
# S WESTERN AVE
# (43.5185145, -96.751124)
#
# S HOUSTON AVE
# (29.7104805, -98.1173779)
#
# N ROGERS AVE
# (42.118891, -76.046551)
#
# N KEDVALE AVE
# (41.9640717, -87.7315451)
#
# S VINCENNES AVE
# (41.6979977, -87.6592612)
#
# N LARAMIE AVE
# (41.8954167, -87.7556069)
#
# E 93RD ST
# (40.7810314, -73.9454051)
#
# S WOLCOTT AVE
# (41.8741687, -87.6740297)
#
# W 25TH PL
# (41.5724621, -87.390001)
#
# S MAY ST
# (35.5997263, -77.5918349)
#
# S VANDERPOEL AVE
# (41.7202873, -87.6664219)
#
# S CENTRAL PARK AVE
# (41.7169517, -87.7114806)
#
# S CARPENTER ST
# (35.240268, -81.338339)
#
# N WHIPPLE ST
# (41.9721178, -87.7049131)
#
# S HERMITAGE AVE
# (41.7685166, -87.6675589)
#
# S HOYNE AVE
# (41.8228899, -87.6774807)
#
# W POLK ST
# (30.7116929, -94.9383233)
#
# N SPRINGFIELD AVE
# (41.9646307, -87.7254887)
#
# S HARDING AVE
# (36.6834759, -119.7343476)
#
# S YALE AVE
# (36.0765216, -95.9221167)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# S TALMAN AVE
# (41.8617849, -87.692024)
#
# S LANGLEY AVE
# (32.1874315, -110.8453564)
#
# S COLFAX AVE
# (30.853988, -96.9914143)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# N LAKEVIEW AVE
# (42.691734, -73.629981)
#
# N SAUGANASH AVE
# (41.994039, -87.7412704)
#
# S HOMAN AVE
# (41.6622485, -87.7046222)
#
# S EWING AVE
# (32.7424571, -96.8126924)
#
# N KINGSBURY ST
# (41.8986511, -87.6438839)
#
# W WALTON ST
# (33.089508, -83.237513)
#
# S LAKE PARK AVE
# (41.5348577, -87.2596604)
#
# E 46th St
# (44.917865, -93.2041653)
#
# S RICHMOND ST
# (44.8899249, -88.3024977)
#
# S RACINE AVE
# (42.9427005, -88.1582854)
#
# N BROADWAY
# (40.9696948, -73.8844801)
#
# N HARDING AVE
# (41.9937042, -87.7276304)
#
# S DREXEL AVE
# (33.369843, -111.623825)
#
# S JUSTINE ST
# (41.6714397, -87.6599691)
#
# E ST
# (50.4738724, 4.2358174)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# W ARTHINGTON ST
# (41.8700106, -87.7112288)
#
# S ESSEX AVE
# (39.3133874, -76.4565138)
#
# S BUFFALO AVE
# (31.4608364, -96.0651776)
#
# N MASON AVE
# (42.354338, -85.244316)
#
# N HARDING AVE
# (41.9937042, -87.7276304)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# S FAIRFIELD AVE
# (41.8828928, -88.0058916)
#
# S FAIRFIELD AVE
# (41.8828928, -88.0058916)
#
# W 62ND PL
# (25.879219, -80.337529)
#
# N LAKE SHORE DR
# (28.905135, -81.763013)
#
# S COMMERCIAL AVE
# (41.7141047, -89.3341986)
#
# N KILPATRICK AVE
# (41.9699316, -87.74405)
#
# N MAYFIELD AVE
# (34.1105096, -117.2902727)
#
# W COULTER ST
# (40.0260654, -75.1778327)
#
# W 45TH ST
# (40.680926, -74.10719)
#
# W WARNER AVE
# (36.8356029, -119.8173025)
#
# S ELIZABETH ST
# (40.727094, -84.106756)
#
# S HARPER AVE
# (33.3743982, -111.6339155)
#
# N OAKLEY AVE
# (41.664195, -86.124499)
#
# N OAKLEY AVE
# (41.664195, -86.124499)
#
# N BURLING ST
# (41.9148697, -87.6471899)
#
# W DIVERSEY PKWY
# (41.9323951, -87.6687745)
#
# S SPRINGFIELD AVE
# (40.6858039, -74.3274558)
#
# S LOTUS AVE
# (36.7105116, -119.7874097)
#
# W POTOMAC AVE
# (43.0958445, -88.0105462)
#
# S ELIZABETH ST
# (40.727094, -84.106756)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# S ARCHER AVE
# (41.6335223, -88.0133585)
#
# W WARREN BLVD
# (41.8823807, -87.6651175)
#
# S DRAKE AVE
# (41.8498569, -87.713702)
#
# N LAWNDALE AVE
# (41.9592196, -87.720432)
#
# S LAFAYETTE AVE
# (39.334709, -74.489355)
#
# S PRAIRIE AVE
# (38.2622876, -104.6440104)
#
# W CONGRESS PKWY
# (41.8750866, -87.6539866)
#
# N NORTHWEST HWY
# (42.0193599, -87.8423973)
#
# S ALBANY AVE
# (27.932852, -82.480986)
#
# S TAN CT
# (41.8550773, -87.6346044)
#
# W 59TH ST
# (40.7646364, -73.9737661)
#
# W ELM ST
# (31.7998495, -97.0960399)
#
# W 59TH ST
# (40.7646364, -73.9737661)
#
# N LOWER MICHIGAN AVE
# (41.888842, -87.624413)
#
# W GRAND AVE
# (44.89992, -89.6139466)
#
# W MEDILL AVE
# (41.9211428, -87.8794266)
#
# W GRAND AVE
# (44.89992, -89.6139466)
#
# W GREENLEAF AVE
# (42.010296, -87.6685965)
#
# N WABASH AVE
# (41.1450949, -87.8658414)
#
# N NORTHWEST HWY
# (42.0193599, -87.8423973)
#
# W ROSEDALE AVE
# (42.9685598, -71.4632274)
#
# N NORTHWEST HWY
# (42.0193599, -87.8423973)
#
# N LEAVITT ST
# (39.531967, -87.136931)
#
# N LAPORTE AVE
# (41.9754723, -87.751858)
#
# N CALDWELL AVE
# (42.0186301, -87.7910211)
#
# S MICHIGAN AVE
# (42.59934, -83.9336293)
#
# W ERIE ST
# (33.3076026, -111.9043792)
#
# N OLIPHANT AVE
# (41.9997953, -87.8191688)
#
# S WABASH AVE
# (34.1314901, -117.8625756)
#
# N LOTUS AVE
# (35.4704582, -97.3553818)
#
# N LUNA AVE
# (34.454345, -119.281645)
#
# W ROSCOE ST
# (41.9417774, -87.798255)
#
# S INDIANA AVE
# (41.5256039, -85.0627283)
#
# S LOWE AVE
# (41.8176141, -87.6421133)
#
# N MAGNOLIA AVE
# (29.1969846, -82.1365046)
#
# W TAYLOR ST
# (41.3837633, -75.7166377)
#
# S LOOMIS BLVD
# (41.7570599, -87.6587609)
#
# W MAYPOLE AVE
# (41.8835952, -87.7087902)
#
# S SANGAMON ST
# (39.5902655, -89.7359101)
#
# S SPAULDING AVE
# (34.0288086, -118.3700242)
#
# W JACKSON BLVD
# (37.377182, -89.6682716)
#
# S HALSTED ST
# (41.5420844, -87.6359687)
#
# W 64TH PL
# (25.881035, -80.3378206)
#
# S CENTRAL PARK AVE
# (41.7169517, -87.7114806)
#
# W VAN BUREN ST
# (42.3609721, -85.8840144)
#
# N MILWAUKEE AVE
# (42.451391, -88.091261)
#
# N HUDSON AVE
# (37.691596, -83.95988)
#
# N SPAULDING AVE
# (41.9543894, -87.7104772)
#
# W CATALPA AVE
# (41.9812028, -87.7124733)
#
# S FAIRFIELD AVE
# (41.8828928, -88.0058916)
#
# S DR MARTIN LUTHER KING JR DR
# (32.3874438, -80.5764049)
#
# S TRUMBULL AVE
# (41.666268, -87.7067038)
#
# S HERMITAGE AVE
# (41.7685166, -87.6675589)
#
# S CALUMET AVE
# (41.7034033, -86.871671)
#
# S LAKE SHORE DR NB
# (42.25603, -87.998784)
#
# S BISHOP FORD EXPY IB
# S BUFFALO AVE
# (31.4608364, -96.0651776)
#
# S CLAREMONT AVE
# (39.096728, -94.442776)
#
# S STATE ST
# (43.964385, -88.9429077)
#
# S VINCENNES AVE
# (41.6979977, -87.6592612)
#
# W GRANVILLE AVE
# (40.245255, -96.754104)
#
# N KEDVALE AVE
# (41.9640717, -87.7315451)
#
# S MAPLEWOOD AVE
# (36.0250954, -95.9064784)
#
# W MELROSE ST
# (40.667262, -73.698695)
#
# S WHIPPLE ST
# (42.6302929, -71.3004363)
#
# E PERSHING RD
# (39.8772063, -88.9358125)
#
# S WALLACE ST
# (38.6625346, -87.3019057)
#
# N KEDVALE AVE
# (41.9640717, -87.7315451)
#
# S CALIFORNIA AVE
# (34.1163848, -118.0008539)
#
# S CALUMET AVE
# (41.7034033, -86.871671)

# %%
# Save Checkpoint 
df2010_geo = df_2010.copy()

# %%
# Filter location that is not null
df2010_geo = df2010_geo[df2010_geo['location'].notna()]

# %%
df2010_geo = impute_district(df2010_geo)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:113: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326

# %%
# Drop columns
df2010_geo.drop(['district', 'index_right'], axis=1, inplace=True)

# Rename columns
df2010_geo.rename(columns={'dist_num':'district'}, inplace=True)

# %%
# Impute updated ward values
df2010_geo = impute_ward(df2010_geo)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:69: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326

# %%
# Drop columns
df2010_geo.drop(['ward_left', 'index_right'], axis=1, inplace=True)

# Rename columns
df2010_geo.rename(columns={'ward_right':'ward'}, inplace=True)

# %%
# Impute updated district values
df2010_geo = impute_commareas(df2010_geo)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:91: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326

# %%
# Drop columns
df2010_geo.drop(['community_area', 'index_right'], axis=1, inplace=True)

# Rename columns
df2010_geo.rename(columns={'area_numbe':'community_area'}, inplace=True)

# %%
# Balance clean up of dataset after transformation
# Drop columns
df2010_geo.drop(['x_coordinate', 'y_coordinate'], axis=1, inplace=True)

# Assign null values in location description to 'OTHER (Specify)'
df2010_geo['location_description'].fillna('OTHER (SPECIFY)', inplace = True)

# Drop row with null case_number (1 data may not be significant)
df2010_geo = df2010_geo.dropna()

# %%
df2010_geo.to_csv('/content/drive/MyDrive/Colab Notebooks/capstone/assets/2010_crime_clean.csv', index=False)

# %%
df2010_geo.isnull().sum()
# Out:
# id                      0
# case_number             0
# date                    0
# block                   0
# iucr                    0
# primary_type            0
# description             0
# location_description    0
# arrest                  0
# domestic                0
# beat                    0
# fbi_code                0
# year                    0
# updated_on              0
# latitude                0
# longitude               0
# location                0
# day                     0
# month                   0
# day_of_week             0
# time                    0
# geometry                0
# district                0
# ward                    0
# community_area          0
# dtype: int64

# %% [markdown]
# ## Transform & Load (Combined) Data

# %%
# Load all clean dataset
df2021 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/capstone/assets/clean_data/2021_crime_clean.csv')
df2020 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/capstone/assets/clean_data/2020_crime_clean.csv')
df2019 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/capstone/assets/clean_data/2019_crime_clean.csv')
df2018 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/capstone/assets/clean_data/2018_crime_clean.csv')
df2017 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/capstone/assets/clean_data/2017_crime_clean.csv')
df2016 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/capstone/assets/clean_data/2016_crime_clean.csv')
df2015 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/capstone/assets/clean_data/2015_crime_clean.csv')
df2014 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/capstone/assets/clean_data/2014_crime_clean.csv')
df2013 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/capstone/assets/clean_data/2013_crime_clean.csv')
df2012 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/capstone/assets/clean_data/2012_crime_clean.csv')
df2011 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/capstone/assets/clean_data/2011_crime_clean.csv')
df2010 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/capstone/assets/clean_data/2010_crime_clean.csv')

# %%
df2017['year'].head()
# Out:
# 0    2017
# 1    2017
# 2    2017
# 3    2017
# 4    2017
# Name: year, dtype: int64

# %%
# Concat all dataset together (single dataset for EDA purposes)
# Ref: Concat all dataframes: https://stackoverflow.com/questions/53877687/how-can-i-concat-multiple-dataframes-in-python

crimelist = [df2021, df2020, df2019, df2018, df2017, df2016, df2015, df2014, df2013, df2012, df2011, df2010]  # List of your dataframes
df_crimes = pd.concat(crimelist)

# %%
# Reset index after joining different dataframes
df_crimes.reset_index()
# Out:
#           index        id case_number                 date  \
# 0             0  12260346    JE102126  2021-01-03 13:23:00
# 1             1  12284355    JE130457  2021-02-02 15:17:00
# 2             2  12264568    JE107021  2021-01-08 15:06:00
# 3             3  12264977    JE107479  2021-01-08 22:50:00
# 4             4  12264092    JE106496  2021-01-07 23:53:00
# ...         ...       ...         ...                  ...
# 3263316  369095   9494365    HX148399  2010-03-23 09:00:00
# 3263317  369096   7299187    HS103020  2010-01-03 11:08:00
# 3263318  369097   7461468    HS262174  2010-04-17 10:30:00
# 3263319  369098   7612740    HS417276  2010-07-18 15:00:00
# 3263320  369099   7663240    HS468160  2010-08-17 20:00:00
#
#                          block  iucr   primary_type  \
# 0        070XX S EGGLESTON AVE  0486        BATTERY
# 1          071XX S SANGAMON ST  0497        BATTERY
# 2          070XX S SANGAMON ST  501A  OTHER OFFENSE
# 3            066XX S UNION AVE  0497        BATTERY
# 4             067XX S GREEN ST  0453        BATTERY
# ...                        ...   ...            ...
# 3263316        052XX W 63RD ST  0841          THEFT
# 3263317   061XX S OAK PARK AVE  0890          THEFT
# 3263318        067XX W 64TH PL  0560        ASSAULT
# 3263319        071XX W 62ND ST  0810          THEFT
# 3263320        062XX W 64TH PL  0560        ASSAULT
#
#                                                description  \
# 0                                  DOMESTIC BATTERY SIMPLE
# 1        AGGRAVATED DOMESTIC BATTERY - OTHER DANGEROUS ...
# 2                                   ANIMAL ABUSE / NEGLECT
# 3        AGGRAVATED DOMESTIC BATTERY - OTHER DANGEROUS ...
# 4        AGGRAVATED POLICE OFFICER - OTHER DANGEROUS WE...
# ...                                                    ...
# 3263316                     FINANCIAL ID THEFT:$300 &UNDER
# 3263317                                      FROM BUILDING
# 3263318                                             SIMPLE
# 3263319                                          OVER $500
# 3263320                                             SIMPLE
#
#                 location_description  arrest  domestic  beat fbi_code  year  \
# 0                          APARTMENT   False      True   732      08B  2021
# 1                          RESIDENCE   False      True   733      04B  2021
# 2        RESIDENCE - PORCH / HALLWAY   False     False   733       26  2021
# 3                             STREET   False      True   723      04B  2021
# 4                             STREET    True     False   723      04B  2021
# ...                              ...     ...       ...   ...      ...   ...
# 3263316                         BANK   False     False   813       06  2010
# 3263317                    APARTMENT   False     False   812       06  2010
# 3263318                    RESIDENCE    True     False   812      08A  2010
# 3263319                       STREET   False     False   812       06  2010
# 3263320                    RESIDENCE   False      True   812      08A  2010
#
#                      updated_on   latitude  longitude  \
# 0        01/16/2021 03:49:23 PM  41.766435 -87.635964
# 1        02/09/2021 03:47:29 PM  41.764526 -87.648037
# 2        01/16/2021 03:49:23 PM  41.766363 -87.648087
# 3        01/16/2021 03:49:23 PM  41.773108 -87.642633
# 4        03/26/2021 04:58:11 PM  41.771796 -87.645797
# ...                         ...        ...        ...
# 3263316  02/04/2016 06:33:39 AM  41.778212 -87.753623
# 3263317  02/10/2018 03:50:01 PM  41.780645 -87.791112
# 3263318  02/10/2018 03:50:01 PM  41.774817 -87.789541
# 3263319  02/10/2018 03:50:01 PM  41.779160 -87.799135
# 3263320  02/10/2018 03:50:01 PM  41.775020 -87.777382
#
#                               location  day  month  day_of_week  time  \
# 0        (41.766435144, -87.635963997)    3      1            6    13
# 1        (41.764526407, -87.648036798)    2      2            1    15
# 2        (41.766362642, -87.648086903)    8      1            4    15
# 3         (41.773108396, -87.64263345)    8      1            4    22
# 4        (41.771796387, -87.645796537)    7      1            3    23
# ...                                ...  ...    ...          ...   ...
# 3263316  (41.778211727, -87.753622799)   23      3            1     9
# 3263317  (41.780645106, -87.791112009)    3      1            6    11
# 3263318  (41.774817017, -87.789540689)   17      4            5    10
# 3263319  (41.779159608, -87.799135466)   18      7            6    15
# 3263320  (41.775019533, -87.777382195)   17      8            1    20
#
#                                              geometry  district  ward  \
# 0                  POINT (-87.635963997 41.766435144)         7     6
# 1             POINT (-87.64803679799999 41.764526407)         7     6
# 2             POINT (-87.64808690299999 41.766362642)         7     6
# 3             POINT (-87.64263345000001 41.773108396)         7     6
# 4        POINT (-87.64579653700001 41.77179638699999)         7     6
# ...                                               ...       ...   ...
# 3263316            POINT (-87.753622799 41.778211727)         8    23
# 3263317            POINT (-87.791112009 41.780645106)         8    23
# 3263318       POINT (-87.78954068899998 41.774817017)         8    23
# 3263319       POINT (-87.79913546600002 41.779159608)         8    23
# 3263320       POINT (-87.777382195 41.77501953300001)         8    23
#
#          community_area
# 0                    68
# 1                    68
# 2                    68
# 3                    68
# 4                    68
# ...                 ...
# 3263316              64
# 3263317              64
# 3263318              64
# 3263319              64
# 3263320              64
#
# [3263321 rows x 26 columns]

# %%
df_crimes['year'].unique()
# Out:
# array([2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011,
#        2010])

# %%
df_crimes.duplicated().sum()
# Out:
# 0

# %%
df_crimes.to_csv('/content/drive/MyDrive/Colab Notebooks/capstone/assets/clean_data/2010_2021_crime_clean.csv', index=False)

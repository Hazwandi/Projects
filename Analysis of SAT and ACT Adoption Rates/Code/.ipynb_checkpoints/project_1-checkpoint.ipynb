# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Decide on your problem statement that will guide your analysis for this project. For guidelines, sample prompts, or inspiration, check out the README.
#
# **To-Do:** *Replace this cell with your problem statement.*

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# **To-Do:** *Fill out this cell (or edit the above cell) with any other background or information that is necessary for your problem statement.*

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# **To-Do:** *Fill out this cell with the datasets you will use for your analysis. Write a brief description of the contents for each dataset that you choose.*

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# **To-Do:** *Fill out this cell with outside research or any additional background information that will support your analysis.*

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Write function for mean
random_int = list(range(10))

def mu(value):
    count = 0
    for i in value:
        count += i 
    
    mean = count / (len(value))
    return mean

# %%
mu(random_int)
# Out:
# 4.5

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Standard deviation function
def st_dev(data):
    total = 0
    try:
        for x in data:
            total += (x - mu(data))**2

        stand_dev = (total/len(data))**0.5
        return stand_dev
    except:
        return 'NaN'

# %%
st_dev(random_int)
# Out:
# 2.8722813232690143

# %%
# Using numpy standard deviation function
import numpy as np

np.std(random_int)
# Out:
# 2.8722813232690143

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# Function to change string to float:
def str_to_float(string):
    try:
        return float(string)
    except:
        if string.endswith("%"):
            return float(string.strip("%").strip()) / 100

# %%
str_to_float('30.5%')
# Out:
# 0.305

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# **All libraries used should be added here**

# %%
# Imports:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
# Import csv files
sat_2017 = pd.read_csv('../Project Data/sat_2017.csv')
sat_2018 = pd.read_csv('../Project Data/sat_2018.csv')
sat_2019 = pd.read_csv('../Project Data/sat_2019.csv')
act_2017 = pd.read_csv('../Project Data/act_2017.csv')
act_2018 = pd.read_csv('../Project Data/act_2018.csv')
act_2019 = pd.read_csv('../Project Data/act_2019.csv')
sat_act_req = pd.read_csv('../Project Data/sat_act_req.csv')
state_population = pd.read_csv('../Project Data/state_population.csv')

# %% [markdown]
# ### Data cleaning - SAT records

# %%
sat_2017.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total  \
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055
#
#    Year
# 0   2017
# 1   2017
# 2   2017
# 3   2017
# 4   2017

# %%
# Check dtypes
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 6 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
#  5   Year                                51 non-null     int64
# dtypes: int64(4), object(2)
# memory usage: 2.5+ KB

# %%
# Check for any null value in dataset
sat_2017.isnull().sum()
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# Year                                  0
# dtype: int64

# %%
# Check min and max value 
a = sat_2017.min()
b = sat_2017.max()

print (a)
print (b)
# Out:
# State                                 Alabama
# Participation                             10%
# Evidence-Based Reading and Writing        482
# Math                                       52
# Total                                     950
# Year                                     2017
# dtype: object
# State                                 Wyoming
# Participation                             96%
# Evidence-Based Reading and Writing        644
# Math                                      651
# Total                                    1295
# Year                                     2017
# dtype: object

# %%
# Check size of rows & columns
sat_2017.shape
# Out:
# (51, 6)

# %% [markdown]
# #### Observations:
# - Participation column is of string value
# - The minimum value (52) may be an outlier in the whole data (min. score 200, 0 is impossible)
# - 51 rows & 6 columns
#
# #### Reference:
# - https://www.crimsoneducation.org/us/blog/test-prep/good-SAT-score/

# %%
sat_2018.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total  \
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076
#
#    Year
# 0  2018
# 1  2018
# 2  2018
# 3  2018
# 4  2018

# %%
# Check dtypes
sat_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 6 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
#  5   Year                                51 non-null     int64
# dtypes: int64(4), object(2)
# memory usage: 2.5+ KB

# %%
# Check for any null value in dataset
sat_2018.isnull().sum()
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# Year                                  0
# dtype: int64

# %%
# Check min and max value 
a = sat_2018.min()
b = sat_2018.max()

print (a)
print (b)
# Out:
# State                                 Alabama
# Participation                             10%
# Evidence-Based Reading and Writing        480
# Math                                      480
# Total                                     977
# Year                                     2018
# dtype: object
# State                                 Wyoming
# Participation                             99%
# Evidence-Based Reading and Writing        643
# Math                                      655
# Total                                    1298
# Year                                     2018
# dtype: object

# %%
# Check size of rows & columns
sat_2018.shape
# Out:
# (51, 6)

# %% [markdown]
# #### Observations:
# - Participation column is of string value
# - 51 rows & 6 columns

# %%
sat_2019.head()
# Out:
#         State Participation Rate  EBRW  Math  Total  Year
# 0     Alabama                 7%   583   560   1143  2019
# 1      Alaska                41%   556   541   1097  2019
# 2     Arizona                31%   569   565   1134  2019
# 3    Arkansas                 6%   582   559   1141  2019
# 4  California                63%   534   531   1065  2019

# %%
# Check dtypes
sat_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               53 non-null     object
#  1   Participation Rate  53 non-null     object
#  2   EBRW                53 non-null     int64
#  3   Math                53 non-null     int64
#  4   Total               53 non-null     int64
#  5   Year                53 non-null     int64
# dtypes: int64(4), object(2)
# memory usage: 2.6+ KB

# %%
# Check for any null value in dataset
sat_2019.isnull().sum()
# Out:
# State                 0
# Participation Rate    0
# EBRW                  0
# Math                  0
# Total                 0
# Year                  0
# dtype: int64

# %%
# Check min and max value 
a = sat_2019.min()
b = sat_2019.max()

print (a)
print (b)
# Out:
# State                 Alabama
# Participation Rate       100%
# EBRW                      483
# Math                      445
# Total                     935
# Year                     2019
# dtype: object
# State                 Wyoming
# Participation Rate        â€”
# EBRW                      636
# Math                      648
# Total                    1284
# Year                     2019
# dtype: object

# %%
# Check size of rows & columns
sat_2019.shape
# Out:
# (53, 6)

# %% [markdown]
# #### Observations:
# - Participation Rate column is of string value
# - Parcipation Rate column have an uknown value
# - 53 rows & 6 columns
#
# #### Others:
# - sat_2017 & sat_2018 have 51 rows while sat_2019 have 53 rows (extra data, why?)
# - sat_2017 & sat_2018 have different columns names compared to sat_2019

# %% [markdown]
# #### Change value - 52

# %%
# Check data of math score 52
sat_2017[sat_2017.Math == 52]
# Out:
#        State Participation  Evidence-Based Reading and Writing  Math  Total  \
# 20  Maryland           69%                                 536    52   1060
#
#     Year
# 20   2017

# %%
# Caculate the correct value
a = sat_2017.iloc[20]['Total']
b = sat_2017.iloc[20]['Evidence-Based Reading and Writing']

correct_value = a - b
print(correct_value)
# Out:
# 524

# %%
# Insert correct value in Maryland 
sat_2017.at[20, 'Math'] = correct_value

# %%
# Check new value set in Maryland Math score
sat_2017[sat_2017.Math == 52]
# Out:
# Empty DataFrame
# Columns: [State, Participation, Evidence-Based Reading and Writing, Math, Total, Year ]
# Index: []

# %% [markdown]
# #### Drop rows

# %%
# Compare sat_2019 to others - identify the extra values
a = sat_2019['State'].isin(sat_2017['State'])
b = sat_2019['State'].isin(sat_2018['State'])

# %%
print (a)
print (b)
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
# 30     True
# 31     True
# 32     True
# 33     True
# 34     True
# 35     True
# 36     True
# 37     True
# 38     True
# 39    False
# 40     True
# 41     True
# 42     True
# 43     True
# 44     True
# 45     True
# 46     True
# 47    False
# 48     True
# 49     True
# 50     True
# 51     True
# 52     True
# Name: State, dtype: bool
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# ...

# %% [markdown]
# #### Observations:
# - 2019 extra datas appeared in index [39] & [47]

# %%
# Using index value to point location of extra values
templist = [39, 47]

for value in templist:
    print (sat_2019.iloc[value])
# Out:
# State                 Puerto Rico
# Participation Rate            â€”
# EBRW                          483
# Math                          462
# Total                         944
# Year                         2019
# Name: 39, dtype: object
# State                 Virgin Islands
# Participation Rate               â€”
# EBRW                             490
# Math                             445
# Total                            935
# Year                            2019
# Name: 47, dtype: object

# %% [markdown]
# #### Set requirements:
# - Accepting only data with values that fulfill all 3 years

# %%
# Drop Puerto Rico and Virgin Island
for value_drop in templist:
    print (sat_2019.drop(value_drop, axis=0, inplace=True))
# Out:
# None
# None

# %%
templist = ['Puerto Rico', 'Virgin Island']

for value in templist:
    print (sat_2019[sat_2019.State == value])
# Out:
# Empty DataFrame
# Columns: [State, Participation Rate, EBRW, Math, Total, Year]
# Index: []
# Empty DataFrame
# Columns: [State, Participation Rate, EBRW, Math, Total, Year]
# Index: []

# %% [markdown]
# #### Change column datatypes

# %%
# Use apply and str_to_float function to change dtype
sat_2017['Participation'] = sat_2017['Participation'].apply(str_to_float)
sat_2018['Participation'] = sat_2018['Participation'].apply(str_to_float)
sat_2019['Participation Rate'] = sat_2019['Participation Rate'].apply(str_to_float)

# %%
sat_2017.dtypes
# Out:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# Year                                    int64
# dtype: object

# %% [markdown]
# #### Change column names

# %%
# Create new column list for df
new_columns_list = [
    'state',
    'participation_rate',
    'ebrw',
    'math',
    'total',
    'year'
]

# %%
sat_2017.columns = new_columns_list
sat_2018.columns = new_columns_list
sat_2019.columns = new_columns_list

# %%
sat_2018.columns
# Out:
# Index(['state', 'participation_rate', 'ebrw', 'math', 'total', 'year'], dtype='object')

# %% [markdown]
# #### Check for duplicates

# %%
# Check for any duplicate values
a = sat_2017.duplicated(subset='state').value_counts()
b = sat_2018.duplicated(subset='state').value_counts()
c = sat_2019.duplicated(subset='state').value_counts()

print (a)
print (b)
print (c)
# Out:
# False    51
# dtype: int64
# False    51
# dtype: int64
# False    51
# dtype: int64

# %% [markdown]
# ### Data cleaning - SAT & ACT status

# %%
sat_act_req.head()
# Out:
#         State Require SAT    Require ACT
# 0     Alabama    optional     compulsory
# 1      Alaska    optional       optional
# 2     Arizona    optional       optional
# 3    Arkansas    optional  optional_free
# 4  California    optional       optional

# %%
# Check dtypes
sat_act_req.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   State        53 non-null     object
#  1   Require SAT  53 non-null     object
#  2   Require ACT  53 non-null     object
# dtypes: object(3)
# memory usage: 1.4+ KB

# %%
# Check null values
sat_act_req.isnull().sum()
# Out:
# State          0
# Require SAT    0
# Require ACT    0
# dtype: int64

# %%
sat_act_req.shape
# Out:
# (53, 3)

# %% [markdown]
# #### Observations:
# - 53 rows & 3 columns
# - Outsourced data (refer to reference)
#
# #### Reference:
# - https://blog.prepscholar.com/which-states-require-the-act-full-list-and-advice
# - https://blog.prepscholar.com/which-states-require-the-sat

# %% [markdown]
# #### Change column names

# %%
# Create new column list for df
new_columns_list1 = [
    'state',
    'sat_required',
    'act_required',
]

# %%
# Change columns name
sat_act_req.columns = new_columns_list1

# %%
sat_act_req.columns
# Out:
# Index(['state', 'sat_required', 'act_required'], dtype='object')

# %% [markdown]
# ### Data cleaning - ACT records

# %%
act_2017.head()
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0        21
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %%
# Check dtypes
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  53 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %%
# Check min and max value 
a = act_2017.min()
b = act_2017.max()

print (a)
print (b)
# Out:
# Participation    100%
# English          16.3
# Math               18
# Reading          18.1
# Science           2.3
# dtype: object
# Participation     98%
# English          25.5
# Math             25.3
# Reading            26
# Science          24.9
# dtype: object

# %%
# Check for any null values
act_2017.isnull().sum()
# Out:
# State            1
# Participation    0
# English          1
# Math             1
# Reading          1
# Science          1
# Composite        1
# dtype: int64

# %%
# Check size of rows & columns
act_2017.shape
# Out:
# (53, 7)

# %% [markdown]
# #### Observations:
# - Participation & Composite column is of string value
# - Except Participation, rest of the columns contains 1 null value
# - 53 rows & 7 columns

# %%
act_2018.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %%
# Check dtypes
act_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  53 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.4+ KB

# %%
# Check min and max value 
a = act_2018.min()
b = act_2018.max()

print (a)
print ()
print (b)
# Out:
# Participation    100%
# Composite        17.7
# dtype: object
#
# Participation     99%
# Composite        25.6
# dtype: object

# %%
# Check for any null values
act_2018.isnull().sum()
# Out:
# State            1
# Participation    0
# Composite        1
# dtype: int64

# %%
act_2018.shape
# Out:
# (53, 3)

# %% [markdown]
# #### Observations:
# - Participation column is of string value
# - Except Participation, rest of the columns contains 1 null value
# - 53 rows & 3 columns

# %%
act_2018[act_2018.State.isnull()]
# Out:
#    State Participation  Composite
# 52   NaN           61%        NaN

# %%
act_2019.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       18.9
# 1      Alaska           38%       20.1
# 2     Arizona           73%       19.0
# 3    Arkansas          100%       19.3
# 4  California           23%       22.6

# %%
# Check dtypes
act_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  53 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.4+ KB

# %%
# Check min and max values
a = act_2019.min()
b = act_2019.max()

print (a)
print ()
print (b)
# Out:
# Participation    100%
# Composite        17.9
# dtype: object
#
# Participation     96%
# Composite        25.5
# dtype: object

# %%
act_2019.isnull().sum()
# Out:
# State            1
# Participation    0
# Composite        1
# dtype: int64

# %%
act_2019.shape
# Out:
# (53, 3)

# %% [markdown]
# #### Observations:
# - Participation column is of string value
# - Except Participation, rest of the columns contains 1 null value
# - 53 rows & 3 columns

# %% [markdown]
# #### Drop columns

# %%
# Drop rows to make all dataset similar 
act_2017.drop(['English', 'Math', 'Reading', 'Science'], axis=1, inplace=True)

# %% [markdown]
# #### Drop rows with a lot of NaN

# %%
# Check location of null value
act_2017.isnull()
# Out:
#     State  Participation  Composite
# 0   False          False      False
# 1   False          False      False
# 2   False          False      False
# 3   False          False      False
# 4   False          False      False
# 5   False          False      False
# 6   False          False      False
# 7   False          False      False
# 8   False          False      False
# 9   False          False      False
# 10  False          False      False
# 11  False          False      False
# 12  False          False      False
# 13  False          False      False
# 14  False          False      False
# 15  False          False      False
# 16  False          False      False
# 17  False          False      False
# 18  False          False      False
# 19  False          False      False
# 20  False          False      False
# 21  False          False      False
# 22  False          False      False
# 23  False          False      False
# 24  False          False      False
# ...

# %%
# Check for any null values
act_2018.isnull()
# Out:
#     State  Participation  Composite
# 0   False          False      False
# 1   False          False      False
# 2   False          False      False
# 3   False          False      False
# 4   False          False      False
# 5   False          False      False
# 6   False          False      False
# 7   False          False      False
# 8   False          False      False
# 9   False          False      False
# 10  False          False      False
# 11  False          False      False
# 12  False          False      False
# 13  False          False      False
# 14  False          False      False
# 15  False          False      False
# 16  False          False      False
# 17  False          False      False
# 18  False          False      False
# 19  False          False      False
# 20  False          False      False
# 21  False          False      False
# 22  False          False      False
# 23  False          False      False
# 24  False          False      False
# ...

# %%
# Check for any null values
act_2019.isnull()
# Out:
#     State  Participation  Composite
# 0   False          False      False
# 1   False          False      False
# 2   False          False      False
# 3   False          False      False
# 4   False          False      False
# 5   False          False      False
# 6   False          False      False
# 7   False          False      False
# 8   False          False      False
# 9   False          False      False
# 10  False          False      False
# 11  False          False      False
# 12  False          False      False
# 13  False          False      False
# 14  False          False      False
# 15  False          False      False
# 16  False          False      False
# 17  False          False      False
# 18  False          False      False
# 19  False          False      False
# 20  False          False      False
# 21  False          False      False
# 22  False          False      False
# 23  False          False      False
# 24  False          False      False
# ...

# %% [markdown]
# #### Observations:
# - All 3 years have index [52] with null values

# %%
# Check content of location with null value
a = act_2017.iloc[52]
b = act_2018.iloc[52]
c = act_2018.iloc[52]

print (a)
print (b)
print (c)
# Out:
# State            NaN
# Participation    65%
# Composite        NaN
# Name: 52, dtype: object
# State            NaN
# Participation    61%
# Composite        NaN
# Name: 52, dtype: object
# State            NaN
# Participation    61%
# Composite        NaN
# Name: 52, dtype: object

# %%
# Drop row that contains most none values - data cannot be used to draw information
act_2017.drop(act_2017.index[52], inplace=True)
act_2018.drop(act_2018.index[52], inplace=True)
act_2019.drop(act_2019.index[52], inplace=True)

# %%
# Check for any null values
templist2 = [act_2017, act_2018, act_2019]

for i in templist2:
    if i.isnull == True:
        print ('Still have NaN values')
    else:
        print ('Pass')
#act_2017.isnull() == True
# Out:
# Pass
# Pass
# Pass

# %% [markdown]
# #### Replace str value to empty (To allow changing of datatypes)

# %%
# Replace string 'x' with none
act_2017['Composite'] = act_2017['Composite'].str.replace('x', '')

# %% [markdown]
# #### Change column datatypes

# %%
# Use apply and str_to_float function to change dtype
act_2017['Participation'] = act_2017['Participation'].apply(str_to_float)
act_2018['Participation'] = act_2018['Participation'].apply(str_to_float)
act_2019['Participation'] = act_2019['Participation'].apply(str_to_float)

# %%
# Change dtypes from object to int
act_2017['Composite'] = pd.to_numeric(act_2017['Composite'])
act_2018['Composite'] = pd.to_numeric(act_2018['Composite'])
act_2019['Composite'] = pd.to_numeric(act_2019['Composite'])

# %% [markdown]
# #### Change columns name

# %%
# Create new column list for df
new_columns_list2 = [
    'state',
    'participation_rate',
    'composite'
]

# %%
act_2017.columns = new_columns_list2
act_2018.columns = new_columns_list2
act_2019.columns = new_columns_list2

# %% [markdown]
# #### Add additional column [year]

# %%
#create year column for each dataset

for i in act_2017.index:
    act_2017['year'] = 2017
    
for i in act_2018.index:
    act_2018['year'] = 2018
    
for i in act_2019.index:
    act_2019['year'] = 2019

# %% [markdown]
# #### Check duplicates

# %%
# Check duplication in data set
a = act_2017.duplicated(subset='state').value_counts()
b = act_2018.duplicated(subset='state').value_counts()
c = act_2019.duplicated(subset='state').value_counts()

print (a)
print (b)
print (c)
# Out:
# False    52
# dtype: int64
# False    51
# True      1
# dtype: int64
# False    52
# dtype: int64

# %%
# Drop duplicate data
act_2018.drop_duplicates(inplace=True)

# %% [markdown]
# ### Data cleaning - State population

# %%
state_population.head()
# Out:
#           state  population_size
# 0    California         39368078
# 1         Texas         29360759
# 2       Florida         21733312
# 3       NewYork         19336776
# 4  Pennsylvania         12783254

# %%
state_population.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   state            54 non-null     object
#  1   population_size  54 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 992.0+ bytes

# %%
state_population.shape
# Out:
# (54, 2)

# %% [markdown]
# #### Observation:
# - 54 rows & 2 columns

# %% [markdown]
# ### Combining datasets to create new dataframe

# %%
# Create new dataframe for SAT
frames = [sat_2017, sat_2018, sat_2019]
sat_temp = pd.concat(frames)

sat_temp.reset_index(inplace=True)

# %%
sat = pd.merge(sat_temp, sat_act_req, on='state', how='left')

# %%
sat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 153 entries, 0 to 152
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               153 non-null    int64
#  1   state               153 non-null    object
#  2   participation_rate  153 non-null    float64
#  3   ebrw                153 non-null    int64
#  4   math                153 non-null    int64
#  5   total               153 non-null    int64
#  6   year                153 non-null    int64
#  7   sat_required        153 non-null    object
#  8   act_required        153 non-null    object
# dtypes: float64(1), int64(5), object(3)
# memory usage: 12.0+ KB

# %%
sat.state.unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
# Create new dataframe for act
frames2 = [act_2017, act_2018, act_2019]
act = pd.concat(frames2)

act.reset_index(inplace=True)

# %%
act.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               155 non-null    int64
#  1   state               155 non-null    object
#  2   participation_rate  155 non-null    float64
#  3   composite           155 non-null    float64
#  4   year                155 non-null    int64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 6.2+ KB

# %%
act.state.unique()
# Out:
# array(['National', 'Alabama', 'Alaska', 'Arizona', 'Arkansas',
#        'California', 'Colorado', 'Connecticut', 'Delaware',
#        'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho',
#        'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana',
#        'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
#        'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
#        'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming', 'District of columbia'],
#       dtype=object)

# %% [markdown]
# #### Observations:
# - State is a unique identifier for dataframe
# - National is not part of US state but contains overall information

# %% [markdown]
# #### Drop rows

# %%
# Check index for value 'National'
act[act.state == 'National']
# Out:
#      index     state  participation_rate  composite  year
# 0        0  National                0.60       21.0  2017
# 130     27  National                0.52       20.7  2019

# %%
# Drop rows
act.drop([0, 130], axis=0, inplace=True)

# %%
act[act.state == 'National']
# Out:
# Empty DataFrame
# Columns: [index, state, participation_rate, composite, year]
# Index: []

# %% [markdown]
# #### Save dataframe to CSV

# %%
# Export new SAT dataframe as CSV
sat.to_csv(r'C:\Users\User.PF-15MGZ7\Desktop\sat.csv', index = False, header=True)

# %%
# Export new ACT datafram as CSV
act.to_csv (r'C:\Users\User.PF-15MGZ7\Desktop\act.csv', index = False, header=True)

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# **To-Do:** *Edit the table below to create your own data dictionary for the datasets you chose.*
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |column name|int/float/object|ACT/SAT|This is an example|

# %% [markdown]
# #### Dataframe - sat
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |index|int|sat_2017, sat_2018, sat_2019|Position in the list|
# |state|object|sat_2017, sat_2018, sat_2019|Name of state in US|
# |participation_rate|float|sat_2017, sat_2018, sat_2019|Percentage participation rate|
# |ebrw|int|sat_2017, sat_2018, sat_2019|Evidence-based Reading and Writing score SAT|
# |math|int|sat_2017, sat_2018, sat_2019|Math score SAT|
# |total|int|sat_2017, sat_2018, sat_2019|Sum of EBRW and Math scores for SAT|
# |year|int|sat_2017, sat_2018, sat_2019|Year of data|
# |sat_required|object|sat_act_req|Requirement status for SAT in state|
# |act_required|object|sat_act_req|Requirement status for ACT in state|

# %% [markdown]
# #### Dataframe - act
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |index|int|act_2017, act_2018, act_2019|Position in the list|
# |state|object|act_2017, act_2018, act_2019|Name of state in US|
# |participation_rate|float|act_2017, act_2018, act_2019|Percentage participation rate|
# |composite|int|act_2017, act_2018, act_2019|AVerage score for 4 test (English, Math, Reading and Science) in ACT|
# |year|int|act_2017, act_2018, act_2019|Year of data|

# %% [markdown]
# #### Temp Dataframe - participation_comb
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|sat, act|Name of state in US|
# |sat_participation_2017|float|sat_2017, sat_2018, sat_2019|Percentage participation rate for sat in 2017|
# |sat_participation_2018|float|sat_2017, sat_2018, sat_2019|Percentage participation rate for sat in 2018|
# |sat_participation_2019|float|sat_2017, sat_2018, sat_2019|Percentage participation rate for sat in 2019|
# |act_participation_2017|float|act_2017, act_2018, act_2019|Percentage participation rate for act in 2017|
# |act_participation_2018|float|act_2017, act_2018, act_2019|Percentage participation rate for act in 2018|
# |act_participation_2019|float|act_2017, act_2018, act_2019|Percentage participation rate for act in 2019|

# %% [markdown]
# #### Temp Dataframe - participation_comb
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|sat, act|Name of state in US|
# |total_2017|float|sat_2017, sat_2018, sat_2019|SAT total scores in 2017|
# |total_2018|float|sat_2017, sat_2018, sat_2019|SAT total scores in 2018|
# |total_2019|float|sat_2017, sat_2018, sat_2019|SAT total scores in 2019|
# |composite_2017|float|act_2017, act_2018, act_2019|ACT composite scores in 2017|
# |composite_2018|float|act_2017, act_2018, act_2019|ACT composite scores in 2018|
# |composite_2019|float|act_2017, act_2018, act_2019|ACT composite scores in 2019|

# %% [markdown]
# #### Datafram - state_population
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|state_population|Name of state in US|
# |population_size|float|state_population|State population size|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# ### Dict comprehension to check standard deviation for year 2017, 2081, 2019

# %%
# Using dictionary comprehensions  to apply the standard deviation function you create in part 1 to each numeric column in the dataframe. No loops
sd = {i: st_dev(sat_2017[i]) for i in sat_2017.columns}
sd
# Out:
# {'state': 'NaN',
#  'participation_rate': 0.3492907076664507,
#  'ebrw': 45.21697020437866,
#  'math': 46.65713364485503,
#  'total': 91.58351056778743,
#  'year': 0.0}

# %%
# Using dictionary comprehensions  to apply the standard deviation function you create in part 1 to each numeric column in the dataframe. No loops
sd = {i: st_dev(sat_2018[i]) for i in sat_2018.columns}
sd
# Out:
# {'state': 'NaN',
#  'participation_rate': 0.3694661922353942,
#  'ebrw': 47.03460978357609,
#  'math': 47.30194550378352,
#  'total': 93.22742384464433,
#  'year': 0.0}

# %%
sd = {i: st_dev(sat_2019[i]) for i in sat_2019.columns}
sd
# Out:
# {'state': 'NaN',
#  'participation_rate': 0.3836584048685726,
#  'ebrw': 45.792378682545134,
#  'math': 50.78521461840036,
#  'total': 96.24027185617864,
#  'year': 0.0}

# %% [markdown]
# ### Top 10 states for highest SAT participation rate

# %%
# Top 10 states for highest SAT particiption rate in 2017
sat[sat.year == 2017].sort_values(by='participation_rate', ascending=False)[['state', 'participation_rate', 'year']].head(10)
# Out:
#                    state  participation_rate  year
# 8   District of Columbia                1.00  2017
# 22              Michigan                1.00  2017
# 6            Connecticut                1.00  2017
# 7               Delaware                1.00  2017
# 29         New Hampshire                0.96  2017
# 19                 Maine                0.95  2017
# 12                 Idaho                0.93  2017
# 9                Florida                0.83  2017
# 21         Massachusetts                0.76  2017
# 39          Rhode Island                0.71  2017

# %%
# Top 10 states for highest SAT particiption rate in 2018
sat[sat.year == 2018].sort_values(by='participation_rate', ascending=False)[['state', 'participation_rate', 'year']].head(10)
# Out:
#                    state  participation_rate  year
# 56              Colorado                1.00  2018
# 57           Connecticut                1.00  2018
# 58              Delaware                1.00  2018
# 73              Michigan                1.00  2018
# 63                 Idaho                1.00  2018
# 70                 Maine                0.99  2018
# 64              Illinois                0.99  2018
# 90          Rhode Island                0.97  2018
# 80         New Hampshire                0.96  2018
# 59  District of Columbia                0.92  2018

# %%
# Top 10 states for highest SAT particiption rate in 2019
sat[sat.year == 2019].sort_values(by='participation_rate', ascending=False)[['state', 'participation_rate', 'year']].head(10)
# Out:
#              state  participation_rate  year
# 141   Rhode Island                1.00  2019
# 115       Illinois                1.00  2019
# 124       Michigan                1.00  2019
# 107       Colorado                1.00  2019
# 108    Connecticut                1.00  2019
# 109       Delaware                1.00  2019
# 111        Florida                1.00  2019
# 114          Idaho                1.00  2019
# 121          Maine                0.99  2019
# 150  West Virginia                0.99  2019

# %% [markdown]
# #### Observations:
# States with 100% Participation rate:
# 2017: District of Columbia, Michigan, Connecticut, Delaware
# 2018: Colorado, Connecticut, Delaware, Michigan, Idaho
# 2019: Rhode Island, Illinois, Michigan, Colorado, Connecticut, Delaware, Florida, Idaho
#
# - As the years goes by, there is an increasing trend of 100% participation from different states. Progressively from 4 to 5 and lastly 8.

# %% [markdown]
# ### Top 10 states for lowest SAT participation rate

# %%
# Lowest 10 states for highest SAT particiption rate in 2017
sat[sat.year == 2017].sort_values(by='participation_rate')[['state', 'participation_rate', 'year']].head(10)
# Out:
#            state  participation_rate  year
# 34  North Dakota                0.02  2017
# 24   Mississippi                0.02  2017
# 15          Iowa                0.02  2017
# 25      Missouri                0.03  2017
# 44          Utah                0.03  2017
# 41  South Dakota                0.03  2017
# 27      Nebraska                0.03  2017
# 49     Wisconsin                0.03  2017
# 23     Minnesota                0.03  2017
# 50       Wyoming                0.03  2017

# %%
# Lowest 10 states for highest SAT particiption rate in 2018
sat[sat.year == 2018].sort_values(by='participation_rate')[['state', 'participation_rate', 'year']].head(10)
# Out:
#             state  participation_rate  year
# 85   North Dakota                0.02  2018
# 101       Wyoming                0.03  2018
# 92   South Dakota                0.03  2018
# 78       Nebraska                0.03  2018
# 100     Wisconsin                0.03  2018
# 75    Mississippi                0.03  2018
# 66           Iowa                0.03  2018
# 95           Utah                0.04  2018
# 74      Minnesota                0.04  2018
# 69      Louisiana                0.04  2018

# %%
# Lowest 10 states for highest SAT particiption rate in 2019
sat[sat.year == 2019].sort_values(by='participation_rate')[['state', 'participation_rate', 'year']].head(10)
# Out:
#             state  participation_rate  year
# 136  North Dakota                0.02  2019
# 152       Wyoming                0.03  2019
# 143  South Dakota                0.03  2019
# 129      Nebraska                0.03  2019
# 151     Wisconsin                0.03  2019
# 126   Mississippi                0.03  2019
# 117          Iowa                0.03  2019
# 146          Utah                0.04  2019
# 125     Minnesota                0.04  2019
# 119      Kentucky                0.04  2019

# %% [markdown]
# #### Observation:
# - Lowest 10 states have participation rate of less than or equal to 2%. It potentially show a significant number of states with low participation rate.

# %%
sat[sat.year == 2017]['participation_rate'].mean()
# Out:
# 0.39803921568627454

# %%
sat[sat.year == 2018]['participation_rate'].mean()
# Out:
# 0.45745098039215676

# %%
sat[sat.year == 2019]['participation_rate'].mean()
# Out:
# 0.49058823529411755

# %% [markdown]
# ### Top 10 states for highest ACT participation rate

# %%
# Top 10 states for highest ACT particiption rate in 2017
act[act.year == 2017].sort_values(by='participation_rate', ascending=False)[['state', 'participation_rate', 'year']].head(20)
# Out:
#              state  participation_rate  year
# 1          Alabama                1.00  2017
# 18        Kentucky                1.00  2017
# 50       Wisconsin                1.00  2017
# 45            Utah                1.00  2017
# 43       Tennessee                1.00  2017
# 41  South Carolina                1.00  2017
# 37        Oklahoma                1.00  2017
# 34  North Carolina                1.00  2017
# 29          Nevada                1.00  2017
# 27         Montana                1.00  2017
# 25     Mississippi                1.00  2017
# 24       Minnesota                1.00  2017
# 19       Louisiana                1.00  2017
# 26        Missouri                1.00  2017
# 51         Wyoming                1.00  2017
# 6         Colorado                1.00  2017
# 4         Arkansas                1.00  2017
# 35    North Dakota                0.98  2017
# 14        Illinois                0.93  2017
# 12          Hawaii                0.90  2017

# %%
# Top 10 states for highest ACT particiption rate in 2018
act[act.year == 2018].sort_values(by='participation_rate', ascending=False)[['state', 'participation_rate', 'year']].head(20)
# Out:
#               state  participation_rate  year
# 52          Alabama                1.00  2018
# 69         Kentucky                1.00  2018
# 101       Wisconsin                1.00  2018
# 96             Utah                1.00  2018
# 94        Tennessee                1.00  2018
# 92   South Carolina                1.00  2018
# 88         Oklahoma                1.00  2018
# 87             Ohio                1.00  2018
# 85   North Carolina                1.00  2018
# 80           Nevada                1.00  2018
# 79         Nebraska                1.00  2018
# 78          Montana                1.00  2018
# 76      Mississippi                1.00  2018
# 70        Louisiana                1.00  2018
# 77         Missouri                1.00  2018
# 102         Wyoming                1.00  2018
# 55         Arkansas                1.00  2018
# 75        Minnesota                0.99  2018
# 86     North Dakota                0.98  2018
# ...

# %%
# Top 10 states for highest ACT particiption rate in 2019
act[act.year == 2019].sort_values(by='participation_rate', ascending=False)[['state', 'participation_rate', 'year']].head(20)
# Out:
#               state  participation_rate  year
# 103         Alabama                1.00  2019
# 120        Kentucky                1.00  2019
# 153       Wisconsin                1.00  2019
# 148            Utah                1.00  2019
# 146       Tennessee                1.00  2019
# 140        Oklahoma                1.00  2019
# 139            Ohio                1.00  2019
# 137  North Carolina                1.00  2019
# 132          Nevada                1.00  2019
# 131        Nebraska                1.00  2019
# 129         Montana                1.00  2019
# 127     Mississippi                1.00  2019
# 121       Louisiana                1.00  2019
# 154         Wyoming                1.00  2019
# 106        Arkansas                1.00  2019
# 138    North Dakota                0.96  2019
# 126       Minnesota                0.95  2019
# 128        Missouri                0.82  2019
# 114          Hawaii                0.80  2019
# ...

# %% [markdown]
# #### Observations:
#
# States with 100% Participation rate:
# 2017: Missouri, Kentucky, Wisconsin, Utah, Tennessee, South Carolina, Oklahoma, North Carolina, Nevada, Montana
# 2018: Alabama, Kentukcy, Wisconsin, Utah, Tennessee, South Carolina, Oklahoma, Ohio, Norht carolina, Nevada
# 2019: Alabama, Kentucky, Wisconsin, Utah, Tennessee, Oklahoma, Ohio, North Carolina, Nevada, Nebraska
#
# - Throughout the 3 years period, top 10 states hits 100% participation rate. Compare to SAT, participation rate of ACT significantly much higher.

# %% [markdown]
# ### Top 10 states for lowest ACT participation rate

# %%
# Lowest 10 states for highest ACT particiption rate in 2017
act[act.year == 2019].sort_values(by='participation_rate')[['state', 'participation_rate', 'year']].head(10)
# Out:
#              state  participation_rate  year
# 122          Maine                0.06  2019
# 143   Rhode Island                0.12  2019
# 110       Delaware                0.13  2019
# 133  New Hampshire                0.14  2019
# 142   Pennsylvania                0.17  2019
# 125       Michigan                0.19  2019
# 149        Vermont                0.20  2019
# 150       Virginia                0.21  2019
# 124  Massachusetts                0.21  2019
# 136       New York                0.22  2019

# %%
# Lowest 10 states for highest ACT particiption rate in 2018
act[act.year == 2018].sort_values(by='participation_rate')[['state', 'participation_rate', 'year']].head(10)
# Out:
#             state  participation_rate  year
# 71          Maine                0.07  2018
# 91   Rhode Island                0.15  2018
# 81  New Hampshire                0.16  2018
# 59       Delaware                0.17  2018
# 90   Pennsylvania                0.20  2018
# 74       Michigan                0.22  2018
# 99     Washington                0.24  2018
# 97        Vermont                0.24  2018
# 98       Virginia                0.24  2018
# 73  Massachusetts                0.25  2018

# %%
# Lowest 10 states for highest ACT particiption rate in 2019
act[act.year == 2019].sort_values(by='participation_rate')[['state', 'participation_rate', 'year']].head(10)
# Out:
#              state  participation_rate  year
# 122          Maine                0.06  2019
# 143   Rhode Island                0.12  2019
# 110       Delaware                0.13  2019
# 133  New Hampshire                0.14  2019
# 142   Pennsylvania                0.17  2019
# 125       Michigan                0.19  2019
# 149        Vermont                0.20  2019
# 150       Virginia                0.21  2019
# 124  Massachusetts                0.21  2019
# 136       New York                0.22  2019

# %% [markdown]
# #### Observation:
# - Lowest 10 states have participation rate of less than or equal to 25%, even the lowest score is read at 0.7 which higher than SAT lowest. It shows that ACT have a higher number of participation rate compared to ACT.

# %%
act[act.year == 2017]['participation_rate'].mean()
# Out:
# 0.6525490196078431

# %%
act[act.year == 2018]['participation_rate'].mean()
# Out:
# 0.6172549019607843

# %%
act[act.year == 2019]['participation_rate'].mean()
# Out:
# 0.5866666666666667

# %% [markdown]
# ### States with highest SAT total scores

# %%
# Top 5 states with highest SAT total scores in 2017
sat[sat.year == 2017].sort_values(by='total', ascending=False)[['state', 'total']].head()
# Out:
#         state  total
# 23  Minnesota   1295
# 49  Wisconsin   1291
# 15       Iowa   1275
# 25   Missouri   1271
# 16     Kansas   1260

# %%
# Top 5 states with highest SAT total scores in 2018
sat[sat.year == 2018].sort_values(by='total', ascending=False)[['state', 'total']].head()
# Out:
#             state  total
# 74      Minnesota   1298
# 100     Wisconsin   1294
# 85   North Dakota   1283
# 66           Iowa   1265
# 67         Kansas   1265

# %%
# Top 5 states with highest SAT total scores in 2019
sat[sat.year == 2019].sort_values(by='total', ascending=False)[['state', 'total']].head()
# Out:
#             state  total
# 125     Minnesota   1284
# 151     Wisconsin   1283
# 143  South Dakota   1268
# 136  North Dakota   1263
# 129      Nebraska   1260

# %% [markdown]
# ### States with lowest SAT total scores

# %%
# Top 5 states with lowest SAT total scores in 2017
sat[sat.year == 2017].sort_values(by='total')[['state', 'total']].head()
# Out:
#                    state  total
# 8   District of Columbia    950
# 7               Delaware    996
# 12                 Idaho   1005
# 22              Michigan   1005
# 19                 Maine   1012

# %%
# Top 5 states with lowest SAT total scores in 2018
sat[sat.year == 2018].sort_values(by='total')[['state', 'total']].head()
# Out:
#                    state  total
# 59  District of Columbia    977
# 58              Delaware    998
# 99         West Virginia    999
# 63                 Idaho   1001
# 95                  Utah   1010

# %%
# Top 5 states with lowest SAT total scores in 2019
sat[sat.year == 2019].sort_values(by='total')[['state', 'total']].head()
# Out:
#                     state  total
# 150         West Virginia    943
# 138              Oklahoma    963
# 110  District of Columbia    975
# 109              Delaware    985
# 114                 Idaho    993

# %% [markdown]
# #### Observations:
#
# SAT total scores
# - Score range: 940 to 1300
# - Average: 1126, 1120, 1113 (declining)
# - National average score: 531 EBRW | 528 Math | 1059 Total

# %%
sat[sat.year == 2017]['total'].mean()
# Out:
# 1126.0980392156862

# %%
sat[sat.year == 2018]['total'].mean()
# Out:
# 1120.0196078431372

# %%
sat[sat.year == 2019]['total'].mean()
# Out:
# 1113.078431372549

# %% [markdown]
# ### States with highest ACT composite scores

# %%
# Top 5 states with highest ACT total scores in 2017
act[act.year == 2017].sort_values(by='composite', ascending=False)[['state', 'composite']].head()
# Out:
#                    state  composite
# 30         New Hampshire       25.5
# 22         Massachusetts       25.4
# 7            Connecticut       25.2
# 20                 Maine       24.3
# 9   District of Columbia       24.2

# %%
# Top 5 states with highest ACT total scores in 2018
act[act.year == 2018].sort_values(by='composite', ascending=False)[['state', 'composite']].head()
# Out:
#             state  composite
# 58    Connecticut       25.6
# 73  Massachusetts       25.5
# 81  New Hampshire       25.1
# 84       New York       24.5
# 74       Michigan       24.2

# %%
# Top 5 states with highest ACT total scores in 2019
act[act.year == 2019].sort_values(by='composite', ascending=False)[['state', 'composite']].head()
# Out:
#              state  composite
# 124  Massachusetts       25.5
# 109    Connecticut       25.5
# 133  New Hampshire       25.0
# 143   Rhode Island       24.7
# 136       New York       24.5

# %% [markdown]
# ### States with lowest ACT composite scores

# %%
# Top 5 states with lowest ACT total scores in 2017
act[act.year == 2017].sort_values(by='composite')[['state', 'composite']].head()
# Out:
#              state  composite
# 29          Nevada       17.8
# 25     Mississippi       18.6
# 41  South Carolina       18.7
# 12          Hawaii       19.0
# 34  North Carolina       19.1

# %%
# Top 5 states with lowest ACT total scores in 2018
act[act.year == 2018].sort_values(by='composite')[['state', 'composite']].head()
# Out:
#              state  composite
# 80          Nevada       17.7
# 92  South Carolina       18.3
# 76     Mississippi       18.6
# 63          Hawaii       18.9
# 52         Alabama       19.1

# %%
# Top 5 states with lowest ACT total scores in 2019
act[act.year == 2019].sort_values(by='composite')[['state', 'composite']].head()
# Out:
#               state  composite
# 132          Nevada       17.9
# 127     Mississippi       18.4
# 144  South Carolina       18.8
# 121       Louisiana       18.8
# 103         Alabama       18.9

# %% [markdown]
# #### Observations:
#
# ACT composite scores
# - Score range: 17.7 to 25.6
# - Average: 21.5, 21.4, 21.4 (declining)
# - National average score: 20.2 Eng | 20.5 Math | 21.3 Reading | 20.7 Science | 20.7 Composite

# %%
act[act.year == 2017]['composite'].mean()
# Out:
# 21.519607843137255

# %%
act[act.year == 2018]['composite'].mean()
# Out:
# 21.49607843137255

# %%
act[act.year == 2019]['composite'].mean()
# Out:
# 21.464705882352934

# %% [markdown]
# ### Do any states with 100% participation on a given test have a rate change year-to-year?`

# %%
# Check participation rate for each year
a = sat[sat.year==2017][['state', 'participation_rate']]
b = sat[sat.year==2018][['state', 'participation_rate']]
c = sat[sat.year==2019][['state', 'participation_rate']]
d = act[act.year==2017][['state', 'participation_rate']]
e = act[act.year==2018][['state', 'participation_rate']]
f = act[act.year==2019][['state', 'participation_rate']]

# %%
# Merge into a dataframe participation_comb
temp1 = pd.merge(a, b, on='state', how='left')
temp2 = pd.merge(temp1, c, on='state', how='left')
temp3 = pd.merge(temp2, d, on='state', how='left')
temp4 = pd.merge(temp3, e, on='state', how='left')
participation_comb = pd.merge(temp4, f, on='state', how='left')

# %%
# Create new column names
new_columns_list3 = [
    'state',
    'sat_participation_2017',
    'sat_participation_2018',
    'sat_participation_2019',
    'act_participation_2017',
    'act_participation_2018',
    'act_participation_2019'
]

# %%
participation_comb.columns = new_columns_list3

# %%
participation_comb.head()
# Out:
#         state  sat_participation_2017  sat_participation_2018  \
# 0     Alabama                    0.05                    0.06
# 1      Alaska                    0.38                    0.43
# 2     Arizona                    0.30                    0.29
# 3    Arkansas                    0.03                    0.05
# 4  California                    0.53                    0.60
#
#    sat_participation_2019  act_participation_2017  act_participation_2018  \
# 0                    0.07                    1.00                    1.00
# 1                    0.41                    0.65                    0.33
# 2                    0.31                    0.62                    0.66
# 3                    0.06                    1.00                    1.00
# 4                    0.63                    0.31                    0.27
#
#    act_participation_2019
# 0                    1.00
# 1                    0.38
# 2                    0.73
# 3                    1.00
# ...

# %%
participation_comb.describe().T
# Out:
#                         count      mean       std   min     25%   50%    75%  \
# sat_participation_2017   51.0  0.398039  0.352766  0.02  0.0400  0.38  0.660
# sat_participation_2018   51.0  0.457451  0.373143  0.02  0.0450  0.52  0.775
# sat_participation_2019   51.0  0.490588  0.387476  0.02  0.0550  0.54  0.820
# act_participation_2017   51.0  0.652549  0.321408  0.08  0.3100  0.69  1.000
# act_participation_2018   50.0  0.623200  0.341141  0.07  0.2775  0.66  1.000
# act_participation_2019   51.0  0.586667  0.345159  0.06  0.2450  0.54  1.000
#
#                         max
# sat_participation_2017  1.0
# sat_participation_2018  1.0
# sat_participation_2019  1.0
# act_participation_2017  1.0
# act_participation_2018  1.0
# act_participation_2019  1.0

# %%
# Filter to get SAT participation rate
participation_comb.sort_values(by=['sat_participation_2017', 'sat_participation_2018', 'sat_participation_2019'], ascending=False)[['sat_participation_2017', 'sat_participation_2018', 'sat_participation_2019']].head()
# Out:
#     sat_participation_2017  sat_participation_2018  sat_participation_2019
# 6                     1.00                    1.00                    1.00
# 7                     1.00                    1.00                    1.00
# 22                    1.00                    1.00                    1.00
# 8                     1.00                    0.92                    0.94
# 29                    0.96                    0.96                    0.95

# %%
# Filter to get SAT participation rate
participation_comb.sort_values(by=['act_participation_2017', 'act_participation_2018', 'act_participation_2019'], ascending=False)[['state', 'act_participation_2017', 'act_participation_2018', 'act_participation_2019']].head()
# Out:
#           state  act_participation_2017  act_participation_2018  \
# 0       Alabama                     1.0                     1.0
# 3      Arkansas                     1.0                     1.0
# 17     Kentucky                     1.0                     1.0
# 18    Louisiana                     1.0                     1.0
# 24  Mississippi                     1.0                     1.0
#
#     act_participation_2019
# 0                      1.0
# 3                      1.0
# 17                     1.0
# 18                     1.0
# 24                     1.0

# %% [markdown]
# #### Observation:
# - SAT: District of Columbia with 100% participation rate in 2017 but dropped to 92% in 2018
# - ACT: None

# %% [markdown]
# ### Changes in total/composite scores from year-to-year

# %%
# Check test scores for SAT/ACT for each year
a = sat[sat.year==2017][['state', 'total']]
b = sat[sat.year==2018][['state', 'total']]
c = sat[sat.year==2019][['state', 'total']]
d = act[act.year==2017][['state', 'composite']]
e = act[act.year==2018][['state', 'composite']]
f = act[act.year==2019][['state', 'composite']]

# %%
# Merge into dataframe scores_comb
temp1 = pd.merge(a, b, on='state', how='left')
temp2 = pd.merge(temp1, c, on='state', how='left')
temp3 = pd.merge(temp2, d, on='state', how='left')
temp4 = pd.merge(temp3, e, on='state', how='left')
scores_comb = pd.merge(temp4, f, on='state', how='left')

# %%
# Create new column names
new_columns_list4 = [
    'state',
    'total_2017',
    'total_2018',
    'total_2019',
    'composite_2017',
    'composite_2018',
    'composite_2019'
]

# %%
scores_comb.columns = new_columns_list4

# %%
scores_comb.head()
# Out:
#         state  total_2017  total_2018  total_2019  composite_2017  \
# 0     Alabama        1165        1166        1143            19.2
# 1      Alaska        1080        1106        1097            19.8
# 2     Arizona        1116        1149        1134            19.7
# 3    Arkansas        1208        1169        1141            19.4
# 4  California        1055        1076        1065            22.8
#
#    composite_2018  composite_2019
# 0            19.1            18.9
# 1            20.8            20.1
# 2            19.2            19.0
# 3            19.4            19.3
# 4            22.7            22.6

# %%
scores_comb.describe()
# Out:
#         total_2017   total_2018   total_2019  composite_2017  composite_2018  \
# count    51.000000    51.000000    51.000000       51.000000       50.000000
# mean   1126.098039  1120.019608  1113.078431       21.519608       21.454000
# std      92.494812    94.155083    97.197910        2.020695        2.111312
# min     950.000000   977.000000   943.000000       17.800000       17.700000
# 25%    1055.500000  1057.500000  1038.000000       19.800000       19.925000
# 50%    1107.000000  1098.000000  1097.000000       21.400000       21.050000
# 75%    1212.000000  1204.000000  1210.000000       23.600000       23.650000
# max    1295.000000  1298.000000  1284.000000       25.500000       25.600000
#
#        composite_2019
# count       51.000000
# mean        21.464706
# std          2.194523
# min         17.900000
# 25%         19.800000
# 50%         21.100000
# 75%         23.700000
# max         25.500000

# %% [markdown]
# ### Population Size

# %%
# Population size of different states
state_population.sort_values(by='population_size', ascending=False)
# Out:
#                  state  population_size
# 0           California         39368078
# 1                Texas         29360759
# 2              Florida         21733312
# 3              NewYork         19336776
# 4         Pennsylvania         12783254
# 5             Illinois         12587530
# 6                 Ohio         11693217
# 7              Georgia         10710017
# 8        NorthCarolina         10600823
# 9             Michigan          9966555
# 10           NewJersey          8882371
# 11            Virginia          8590563
# 12          Washington          7693612
# 13             Arizona          7421401
# 14       Massachusetts          6893574
# 15           Tennessee          6886834
# 16             Indiana          6754953
# 17            Missouri          6151548
# 18            Maryland          6055802
# 19           Wisconsin          5832655
# 20            Colorado          5807719
# 21           Minnesota          5657342
# ...

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
#Create a temporary dataframe wihtout index column
final = sat[['state', 'participation_rate', 'ebrw', 'math', 'total', 'year']]

# %%
# Create heatmap
sns.heatmap(final.corr(), annot=True, cmap='coolwarm');

# %% [markdown]
# ## Correlation between SAT participation rate and total scores

# %%
sns.pairplot(final)

# %%
# Plot a scatterplot to show the relation between Participation Rate vs Total Scores
fig, ax = plt.subplots(figsize=(12,6))

# Create scatterplot
sns.scatterplot(data=sat, x=sat.participation_rate, y=sat.total)

# Design
plt.title("SAT Participation Rate vs Total Scores", fontsize=16, y=1.03)
plt.ylabel("Total")
plt.xlabel("Participation Rate")
print('Participation rate vs Total Scores <= 3 years')
# Out:
# Participation rate vs Total Scores <= 3 years

# %% [markdown]
# #### Observations:
# - There is positive relationship between total scores and evidence based reading and writing - SAT students are well versed in language
# - As the participation increases, the total scores decreases<br>

# %% [markdown]
# ### Overall participation rate

# %%
# Find mean value of participation rate in SAT
sat_mean_2017 = sat[sat['year'] == 2017]['participation_rate'].mean()
sat_mean_2018 = sat[sat['year'] == 2018]['participation_rate'].mean()
sat_mean_2019 = sat[sat['year'] == 2019]['participation_rate'].mean()

print (f'Mean for SAT participation rate (2017): {sat_mean_2017}')
print (f'Mean for SAT participation rate (2018): {sat_mean_2018}')
print (f'Mean for SAT participation rate (2019): {sat_mean_2017}')
# Out:
# Mean for SAT participation rate (2017): 0.39803921568627454
# Mean for SAT participation rate (2018): 0.45745098039215676
# Mean for SAT participation rate (2019): 0.39803921568627454

# %%
# Find mean value of participation rate in SAT
act_mean_2017 = act[act['year'] == 2017]['participation_rate'].mean()
act_mean_2018 = act[act['year'] == 2018]['participation_rate'].mean()
act_mean_2019 = act[act['year'] == 2019]['participation_rate'].mean()

print (f'Mean for ACT participation rate (2017): {act_mean_2017}')
print (f'Mean for ACT participation rate (2018): {act_mean_2018}')
print (f'Mean for ACT participation rate (2019): {act_mean_2019}')
# Out:
# Mean for ACT participation rate (2017): 0.6525490196078431
# Mean for ACT participation rate (2018): 0.6172549019607843
# Mean for ACT participation rate (2019): 0.5866666666666667

# %%
mean_sat = [sat_mean_2017, sat_mean_2018, sat_mean_2019]
mean_act = [act_mean_2017, act_mean_2018, act_mean_2019]

# %%
# Plot line chart to see relationship between SAT vs ACT participation rate
fig=plt.figure(figsize=(10,5))

# Define years for each dataframe
ys = sat['year']
ya = act['year']

# Create line chart
ax = sns.lineplot(x=ys, y=sat['participation_rate'], color='darkblue', ci=None)
ax = sns.lineplot(x=ya, y=act['participation_rate'], color='grey', ci=None)
ax.locator_params(integer=True)

# Design
plt.title("SAT & ACT Participation Rate", y=1.03)
plt.ylabel("Participation Rate")
plt.xlabel("Year")
print('Participation rate <= 3 years')
# Out:
# Participation rate <= 3 years

# %% [markdown]
# #### Observations:
# - SAT participation rate steadily increasing
# - ACT participation rate declining but participation values are higher than SAT

# %%
# Find values of participation rate for each individual year in SAT
x = sat[sat.year == 2017]['participation_rate']
y = sat[sat.year == 2018]['participation_rate']
z = sat[sat.year == 2019]['participation_rate']

# %%
# Find values of participation rate for each individual year in ACT
m = act[act.year == 2017]['participation_rate']
n = act[act.year == 2018]['participation_rate']
o = act[act.year == 2019]['participation_rate']

# %%
# Plot a histogram of participation by individual year for both SAT and ACT test
fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(15,8))
plt.tight_layout(pad=4) 

# Create histogram with design elements
sns.histplot(data=sat, x=x, ax=axs[0,0], color ='darkblue')
axs[0,0].set_title('SAT 2017 Participation')
axs[0,0].set_xlabel('Participation Rate')
axs[0,0].set_ylabel('Frequency')

sns.histplot(data=sat, x=y, ax=axs[0,1], color='darkblue')
axs[0,1].set_title('SAT 2018 Participation')
axs[0,1].set_xlabel('Participation Rate')
axs[0,1].set_ylabel('Frequency')

sns.histplot(data=sat, x=z, ax=axs[0,2], color='darkblue')
axs[0,2].set_title('SAT 2019 Participation')
axs[0,2].set_xlabel('Participation Rate')
axs[0,2].set_ylabel('Frequency')

sns.histplot(data=act, x=m, ax=axs[1,0], color='grey')
axs[1,0].set_title('ACT 2017 Participation')
axs[1,0].set_xlabel('Participation Rate')
axs[1,0].set_ylabel('Frequency')

sns.histplot(data=act, x=n, ax=axs[1,1], color='grey')
axs[1,1].set_title('ACT 2018 Participation')
axs[1,1].set_xlabel('Participation Rate')
axs[1,1].set_ylabel('Frequency')

sns.histplot(data=act, x=o, ax=axs[1,2], color='grey')
axs[1,2].set_title('ACT 2019 Participation')
axs[1,2].set_xlabel('Participation Rate')
axs[1,2].set_ylabel('Frequency')
# Out:
# Text(698.8235294117648, 0.5, 'Frequency')

# %% [markdown]
# #### Observations:
# - Participation rate distribution for SAT & ACT is similar throughout the 3 years
# - SAT test have a higher rate of low participation rate whereas ACT remains high (opposite)

# %% [markdown]
# ### Overall scores

# %%
sat_total_2017 = sat[sat['year'] == 2017]['total'].mean()
sat_total_2018 = sat[sat['year'] == 2018]['total'].mean()
sat_total_2019 = sat[sat['year'] == 2019]['total'].mean()

print (f'Mean for SAT total score (2017): {sat_total_2017}')
print (f'Mean for SAT total score (2018): {sat_total_2018}')
print (f'Mean for SAT total score (2019): {sat_total_2019}')
# Out:
# Mean for SAT total score (2017): 1126.0980392156862
# Mean for SAT total score (2018): 1120.0196078431372
# Mean for SAT total score (2019): 1113.078431372549

# %%
act_comp_2017 = act[act['year'] == 2017]['composite'].mean()
act_comp_2018 = act[act['year'] == 2018]['composite'].mean()
act_comp_2019 = act[act['year'] == 2019]['composite'].mean()

print (f'Mean for SAT total score (2017): {act_comp_2017}')
print (f'Mean for SAT total score (2018): {act_comp_2018}')
print (f'Mean for SAT total score (2019): {act_comp_2019}')
# Out:
# Mean for SAT total score (2017): 21.519607843137255
# Mean for SAT total score (2018): 21.49607843137255
# Mean for SAT total score (2019): 21.464705882352934

# %%
score_mean_sat = [sat_total_2017, sat_total_2018, sat_total_2019]
score_mean_act = [act_comp_2017, act_comp_2018, act_comp_2019]

# %%
# Plot line chart for total SAT scores throughout the years
years = ['2017', '2018', '2019']

#Create lineplot
sns.lineplot(x=years, y=score_mean_sat, marker='o', color='darkblue')

# Design
plt.suptitle('SAT Total Scores', fontsize=16, y=1.03)
plt.xlabel('Years')
plt.ylabel('Total')
print('Total Score <= 3 years')
# Out:
# Total Score <= 3 years

# %%
# Plot line chart for composite ACT total scores throughout the years
years = ['2017', '2018', '2019']

# Create lineplot
sns.lineplot(x=years, y=score_mean_act, marker='o', color='grey')

# Design
plt.suptitle('ACT Composite Scores', fontsize=16, y=1.03)
plt.xlabel('Years')
plt.ylabel('Total')
print('Composite Score <= 3 years')
# Out:
# Composite Score <= 3 years

# %% [markdown]
# #### Observations:
# - Scores for both SAT & ACT test are declining over the years
# - SAT test sees a constant drop over the years whereas ACT had a significant drop between 2018 to 2019

# %%
# Plot bar chart for total scores across all states
fig, ax = plt.subplots(figsize=(17,6))

# Create scatterplot
sns.scatterplot(data=sat, x='state', y="total", hue="year", palette="deep", ax=ax)

# Design
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='12'  
)

plt.yticks(
    fontweight='light',
    fontsize='12'  
)
plt.title("Total Scores in all states", y=1.05, fontsize=14)
plt.ylabel("Total", labelpad=15)
plt.xlabel("States")
plt.axhline(1059, ls='--', color='red')

sns.despine()
plt.legend()

# %% [markdown]
# #### Observation:
# - By end of 2019, there are about 14 states that scores below national average
#
# #### Reference:
# - https://www.washingtonpost.com/local/education/sat-scores-drop-for-2019-class-but-participation-rises-through-testing-in-schools/2019/09/23/332fc4d0-de11-11e9-8dc8-498eabc129a0_story.html

# %%
# Plot boxplot to compare total and composite scores
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(15, 10))

# Create boxplot with design
sns.boxplot(x=sat["year"], y=sat["total"], ax=axs[0])
axs[0].set_title('SAT', fontsize=14)
axs[0].set_ylabel('Total Scores')
axs[0].set_xlabel('Years')

sns.boxplot(x=act["year"], y=act["composite"], ax=axs[1])
axs[1].set_title('ACT', fontsize=14)
axs[1].set_ylabel('Composite')
axs[1].set_xlabel('Years')

plt.suptitle('SAT & ACT Total / Composite Scores', fontsize=16, y=0.95)
# Out:
# Text(0.5, 0.95, 'SAT & ACT Total / Composite Scores')

# %%
fig, ax = plt.subplots(figsize=(10, 7))
sns.boxplot( x=sat["year"], y=sat["ebrw"] );

# %%
fig, ax = plt.subplots(figsize=(10, 7))
sns.boxplot( x=sat["year"], y=sat["math"] );

# %% [markdown]
# #### Observations:
# - At least 75% of the students scores above national average total, EBRW and maths
# - Signs of majority of students scores more than average

# %% [markdown]
# ### Finding out our target states

# %%
# Filter states based on 50th percentile onwards, with optional SAT & ACT requirements
overview = sat[(sat.sat_required != 'compulsory') & (sat.act_required != 'compulsory')].sort_values(by='participation_rate')[['state', 'participation_rate', 'sat_required', 'act_required', 'year']]

# %%
# Plot a barplot to view participation rate for states with optional requirements
sns.set_context({"figure.figsize": (25, 15)})

sns.barplot(x='participation_rate',y='state',data=sat[(sat.year==2019)&(sat['state'].isin (overview['state']))] ,color='grey')
sns.barplot(x='participation_rate',y='state',data=sat[(sat.year==2018)&(sat['state'].isin (overview['state']))] ,color='darkblue')
sns.barplot(x='participation_rate',y='state',data=sat[(sat.year==2017)&(sat['state'].isin (overview['state']))] ,color='orange')

plt.title('SAT Participation for non-compulsory SAT/ACT requirement', fontsize=30, y=1.03)
sns.despine(left=True)
plt.ylabel("State", fontsize=20)
plt.yticks(fontsize=16)
plt.xlabel("Participation", fontsize=20, labelpad=30)
plt.xticks(fontsize=16)
plt.axvline(0.5, ls='--', color='red')
plt.axvline(0.76, ls='--', color='red')

topbar = plt.Rectangle((0,0),1,1,fc="grey", edgecolor = 'grey')
middlebar = plt.Rectangle((0,0),1,1,fc="darkblue", edgecolor = 'darkblue')
bottombar = plt.Rectangle((0,0),1,1,fc="orange",  edgecolor = 'orange')
plt.legend([bottombar, middlebar, topbar], ['2017', '2018','2019'], loc=1, ncol = 3, prop={'size':16})

# %% [markdown]
# #### Requirements:
# - Finding states with SAT & ACT optional within 50th to 75th percentile

# %%
# Filter states based on 50th percentile onwards, with optional SAT & ACT requirements
filter_states = sat[(sat.participation_rate > np.percentile(sat.participation_rate, 50)) & (sat.participation_rate < np.percentile(sat.participation_rate, 75)) & (sat.sat_required != 'compulsory') & (sat.act_required != 'compulsory') & (sat.sat_required != 'compulsary SA')].sort_values(by='participation_rate')[['state', 'participation_rate', 'sat_required', 'act_required', 'year']]

# %%
# Plot a scatterplot to see target states based on requirements
fig, ax = plt.subplots(figsize=(12,6))

# Create scatterplot
sns.scatterplot(data=filter_states, x=filter_states.state.sort_values(), y="participation_rate", hue="year", size="year", palette="tab10", ax=ax)

# Design
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='12'  
)

plt.yticks(
    fontweight='light',
    fontsize='12'  
)
plt.title("States participation rate above 50th and below 75th percentile", y=1.05, fontsize=14)
plt.ylabel("Participation Rate", labelpad=15)
plt.xlabel("States")

sns.despine()
plt.legend()

# %% [markdown]
# ##### Observations:
# Progressive state whose participation rate in 2019 is above 2017 based on requirements:
# 1) California
# 2) Georgia
# 3) Indiana
# 4) Pennsylvannia
# 5) Texas
# 6) Vermont
# 7) Virginia
# 8) Washington
# 9) Oregon

# %% [markdown]
# ## Finding out target states with progressive scores over the 3 years

# %%
# Filter states based on 50th percentile to 75th percentile, with optional SAT & ACT requirements - total scores
scores = sat[(sat.participation_rate > np.percentile(sat.participation_rate, 50)) & (sat.participation_rate < np.percentile(sat.participation_rate, 75)) & (sat.sat_required != 'compulsory') & (sat.sat_required != 'compulsary SA') & (sat.act_required != 'compulsory')].sort_values(by='total')[['state', 'total', 'ebrw', 'math', 'sat_required', 'act_required', 'year']]

# %%
# Plot a scatterplot to see total score for each states over the years
fig, ax = plt.subplots(figsize=(12,6))

sns.scatterplot(data=scores, x=scores.state.sort_values(), y="total", hue="year", size='year', palette="deep", ax=ax)

plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='12'  
)

plt.yticks(
    fontweight='light',
    fontsize='12'  
)
plt.title("Target States Total Score", y=1.05, fontsize=14)
plt.ylabel("Total", labelpad=15)
plt.xlabel("States")
plt.axhline(1051, ls='--', color='red')

sns.despine()
plt.legend(),
# Out:
# (<matplotlib.legend.Legend at 0x169b6297d60>,)

# %% [markdown]
# ##### Observations:
# - There is a decline in SAT scores for many states in 2019
#
# States with Total scores  that have been doing progressively well and above national average score:
# 1) California
# 2) Georgia
# 3) Indiana
# 4) Pennsylvania
# 5) Virginia
# 6) Oregon

# %%
# Plot a scatterplot to see total score for each states over the years
fig, ax = plt.subplots(figsize=(12,6))

sns.scatterplot(data=scores, x=scores.state.sort_values(), y="ebrw", hue="year", size='year', palette="deep", ax=ax)

plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='12'  
)

plt.yticks(
    fontweight='light',
    fontsize='12'  
)
plt.title("Target States Evidence Based Reading and Writing", y=1.05, fontsize=14)
plt.ylabel("EBRW", labelpad=15)
plt.xlabel("States")
plt.axhline(523, ls='--', color='red')

sns.despine()
plt.legend()

# %%
# Mean of evidence based reading and writing score
sat['ebrw'].mean()
# Out:
# 564.5359477124183

# %% [markdown]
# ##### Observations:
#
# States with EBRW scores that have been doing progressively well and above national average score:
# 1) California
# 2) Georgia
# 3) Indiana
# 4) Pennsylvania
# 5) Virginia
# 6) Oregon

# %%
# Plot a scatterplot to see total score for each states over the years
fig, ax = plt.subplots(figsize=(12,6))

sns.scatterplot(data=scores, x=scores.state.sort_values(), y="math", hue="year", palette="deep", ax=ax)

plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='12'  
)

plt.yticks(
    fontweight='light',
    fontsize='12'  
)
plt.title("Target states Math Scores", y=1.05, fontsize=14)
plt.ylabel("Math", labelpad=15)
plt.xlabel("States")
plt.axhline(523, ls='--', color='red')

sns.despine()
plt.legend()

# %%
# Mean of math score
sat['math'].mean()
# Out:
# 555.1045751633987

# %% [markdown]
# ##### Observations:
#
# States with EBRW scores that have been doing progressively well and above national average score:
# 1) California
# 2) Indiana
# 3) Pennsylvania
# 4) Virginia
# 5) Washington
# 6) Oregon

# %% [markdown]
# ### Final Target States - Individual states participation & scores

# %% [markdown]
# ##### average total score = 1051, average ebrw score = 523, average math score = 528

# %%
sat[sat.state == "California"]
# Out:
#      index       state  participation_rate  ebrw  math  total  year  \
# 4        4  California                0.53   531   524   1055  2017
# 55       4  California                0.60   540   536   1076  2018
# 106      4  California                0.63   534   531   1065  2019
#
#     sat_required act_required
# 4       optional     optional
# 55      optional     optional
# 106     optional     optional

# %%
sat[sat.state == "Indiana"]
# Out:
#      index    state  participation_rate  ebrw  math  total  year sat_required  \
# 14      14  Indiana                0.63   542   532   1074  2017     optional
# 65      14  Indiana                0.63   542   532   1074  2018     optional
# 116     14  Indiana                0.66   543   537   1080  2019     optional
#
#     act_required
# 14      optional
# 65      optional
# 116     optional

# %%
sat[sat.state == "Pennsylvania"]
# Out:
#      index         state  participation_rate  ebrw  math  total  year  \
# 38      38  Pennsylvania                0.65   540   531   1071  2017
# 89      38  Pennsylvania                0.70   547   539   1086  2018
# 140     38  Pennsylvania                0.70   545   537   1082  2019
#
#     sat_required act_required
# 38      optional     optional
# 89      optional     optional
# 140     optional     optional

# %%
sat[sat.state == "Oregon"]
# Out:
#      index   state  participation_rate  ebrw  math  total  year sat_required  \
# 37      37  Oregon                0.43   560   548   1108  2017     optional
# 88      37  Oregon                0.48   564   553   1117  2018     optional
# 139     37  Oregon                0.51   562   550   1112  2019     optional
#
#     act_required
# 37      optional
# 88      optional
# 139     optional

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# **To-Do:** *Edit this cell with your conclusions and recommendations.*
#
# ### Problem Statement
# A consultant to CollegeBoard, identify which states have the best potential to increase SAT participation in the coming years and determine if they have the potential growth.
#
# ### Conclusion
# Through observations and analysis of data, there is a constant increase in the participation rate for SAT and most students scores well above the average in respective subjects. Therefore, we should leverage on the trend and further increase participation with target states who are doing well but at the mid of the the spectrum fulfilling the following criterias:
# - States pariticipation rate between 50th to 75th percentile
# - States total scores above national average (1059) above (523) and progressive score above 2017
# - States evidence based reading and writing scores above (523) and progressive score above 2017
# - States math scores above (528) above (523) and progressive score above 2017
# - Larger population size
#
# Based on collected data, target states are as follows:
# - California (drop)
# - Pennsylvania
# - Oregon
# - Indiana
#
# After doing some outside research, we find out that state of California has a lot of underlying issues. While potentially the best to grow due to its sheer population and market in standardized test, the decision made by University of California to drop the current SAT & ACT have signal the demise of the test with other colleges following suite.
#
#
# ### Recommendations
#
# With the information of California, I am dropping the state as from the final selection.
#
# Final decision on target state:
# - Pennsylvania
# - Oregon
# - Indiana
#
# In order to achieve a higher participation, CollegeBoard can also review some recommendations to help boos their presence among the students
#
# ##### 1) Implementation of current SAT school day emphasize on target states
# Generally SAT test are conducted on saturdays which may be incovenient for some student as well as testing center who normally operates on weekdays basis. By offer SAT school days, students are allow to take exams and their covenience and comfort in their own school. At the same time helping teachers prepare,follow progress, coach and support the students before the actual test.
#
# ##### 2) Provide help to students by offering PSAT services
# While it does not count toward the final score for SAT, it is a qualifying test for National Merit scholarship and help serve as a guidepost for college admission journey with free resouces, practices and guidance counselors. It helps student build their confidence and have a sense of the preparation need to score for the test.
#
# ##### 3) Sharing of best practices
# Some schools may not have the knowledge to increase and improve SAT scores and participation. By consolidating and sharing of best practices among schools that shows significant boost, it will build a community of school badly affected to follow suit.
#
# Not all best practices are suited for individual schools but areas where it can be implement, these schools can take advantage of it.
#
# #### Reference:
# - https://www.highereddive.com/news/u-of-california-eliminates-sat-act-as-admissions-requirement/578373/
#
# - https://collegereadiness.collegeboard.org/sat/k12-educators/sat-school-day
# - https://collegereadiness.collegeboard.org/psat-nmsqt-psat-10/inside-the-test
# - https://www.forbes.com/sites/noodleeducation/2015/10/12/does-the-psat-really-matter/?sh=4681d1058585

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!

# %%
act[act.state == 'Texas']
# Out:
#      index  state  participation_rate  composite  year
# 44      44  Texas                0.45       20.7  2017
# 95      44  Texas                0.45       20.7  2018
# 147     44  Texas                0.39       20.5  2019

# %%
sat[sat.state == 'Texas']
# Out:
#      index  state  participation_rate  ebrw  math  total  year sat_required  \
# 43      43  Texas                0.62   513   507   1020  2017     optional
# 94      43  Texas                0.66   520   512   1032  2018     optional
# 145     44  Texas                0.68   515   507   1022  2019     optional
#
#     act_required
# 43      optional
# 94      optional
# 145     optional

# %%
act[act.state == 'Georgia']
# Out:
#      index    state  participation_rate  composite  year
# 11      11  Georgia                0.55       21.4  2017
# 62      10  Georgia                0.53       21.4  2018
# 113     10  Georgia                0.49       21.4  2019

# %%
sat[sat.state == 'Georgia']
# Out:
#      index    state  participation_rate  ebrw  math  total  year sat_required  \
# 10      10  Georgia                0.61   535   515   1050  2017     optional
# 61      10  Georgia                0.70   542   522   1064  2018     optional
# 112     10  Georgia                0.71   538   519   1058  2019     optional
#
#     act_required
# 10      optional
# 61      optional
# 112     optional

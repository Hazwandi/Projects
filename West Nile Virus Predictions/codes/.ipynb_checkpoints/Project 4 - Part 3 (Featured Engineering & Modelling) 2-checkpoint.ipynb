# %% [markdown]
# # Project 4 - West Nile Virus Classification

# %% [markdown]
# ## Part 3 - Featured Engineering & Modelling

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
import joblib

from sklearn.neighbors import KernelDensity

from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import confusion_matrix, plot_confusion_matrix, plot_roc_curve, roc_auc_score, f1_score, accuracy_score, auc, precision_recall_curve

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier

from imblearn.over_sampling import SMOTE

# ref: https://machinelearningmastery.com/types-of-classification-in-machine-learning/ 

pd.set_option('display.max_rows', 200)

# %%
merged_df = pd.read_csv('../assets/clean_data/mergeddf.csv')
merged_df_test = pd.read_csv('../assets/clean_data/mergeddf_test.csv')

# %% [markdown]
# ### Correlation Heatmap

# %%
# Look at the heatmap to understand correlation within the fetaures 
def plot_heatmap(dataset, size_x=8, size_y=8, title="", title_font_size=12):
    plt.figure(figsize=(size_x,size_y))

    mask = np.zeros_like(merged_df.corr(), dtype=bool)
    mask[np.triu_indices_from(mask)] = True

    hm = sns.heatmap(merged_df.corr(), mask=mask, cmap='coolwarm',vmin=-1, vmax=1,
                     square=True, linewidth=1,annot=True,annot_kws={'size':'11'},
                     cbar_kws={"shrink": 0.8}, fmt='.1g',center=0)

    hm.set_xticklabels(hm.xaxis.get_ticklabels(), fontsize=14)
    hm.set_yticklabels(hm.yaxis.get_ticklabels(), fontsize=14)

    hm.set_title(title, fontsize=title_font_size);
    
    return hm

plot_heatmap(merged_df, size_x=22, size_y=22, title='Correlation Heatmap for Merged Data', title_font_size=26);

# %% [markdown]
# ---

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ### Relative Humidity

# %% [markdown]
# Based on our EDA, high humidity is a strong factors in the spread of West Nile virus, boosting the breed of mosquitoes population in the area. As such, we will look into the percentage of amount of moisture given the weather.
#
# We use the concept of relative humidity which refers to the moisture content (i.e., water vapor) of the atmosphere, expressed as a percentage of the amount of moisture that can be retained by the atmosphere at a given temperature and pressure without condensation.

# %%
# To calculate Relative Humidity, we need to change our features from Fahrenheit to Celcius
def celsius(x):
    c = 5.0 / 9.0 * (x - 32.0)
    return float(c)

# %%
# Changing farenheit metrics to degree celsius metrics for temperature
df_list = [merged_df, merged_df_test]

for df in df_list:
    df['tavg'] = df['tavg'].apply(celsius)
    df['tmin'] = df['tmin'].apply(celsius)
    df['tmax'] = df['tmax'].apply(celsius)
    df['dewpoint'] = df['dewpoint'].apply(celsius)

# %%
# Create relative humidity features based on calculations
def r_humid(row):
    row['r_humid'] = round(100*(math.exp((17.625*row['dewpoint'])/(243.04+row['dewpoint'])) \
                          / math.exp((17.625*row['tavg'])/(243.04+row['tavg']))))
    return row

# %%
# Apply train dataset
merged_df = merged_df.apply(r_humid, axis=1)

# %%
# Apply test dataset
merged_df_test = merged_df_test.apply(r_humid, axis=1)

# %%
# Save dataset (in case require to reroll)
merged_df1 = merged_df.copy()
merged_df_test1 = merged_df_test.copy()

# %% [markdown]
# ### Polynomial Features

# %%
# Define features based on only numerica dtypes
X = merged_df1[[col for col in merged_df.columns if 'wnvpresent' not in col]]._get_numeric_data()
y = merged_df1['wnvpresent']

# %%
poly = PolynomialFeatures(include_bias=False, degree=2)
X_poly = poly.fit_transform(X)
X_poly.shape
# Out:
# (8610, 377)

# %%
# Adds appropriate feature names to all polynomial features
X_poly = pd.DataFrame(X_poly,columns=poly.get_feature_names(X.columns))

# Generates list of poly feature correlations
X_poly_corrs = X_poly.corrwith(y)

# Shows features most highly correlated (positively) with target
X_poly_corrs.sort_values(ascending=False).head(10)
# Out:
# wetbulb sunrise     0.143053
# week wetbulb        0.139108
# month wetbulb       0.136368
# week dewpoint       0.132268
# month dewpoint      0.129767
# dewpoint sunrise    0.125266
# week tmin           0.124803
# week tavg           0.123299
# month tmin          0.122222
# sunrise sunset      0.120361
# dtype: float64

# %% [markdown]
# ### Generate new features

# %%
# Choosing the top 5 features 
data_set = [merged_df1, merged_df_test1]

for df in data_set:
    df['wetbulb_sunrise'] = df['wetbulb'] * df['sunrise']
    df['week_wetbulb'] = df['week'] * df['wetbulb']
    df['month_wetbulb'] = df['month'] * df['wetbulb']
    df['week_dewpoint'] = df['week'] * df['dewpoint']
    df['month_dewPoint'] = df['month'] * df['dewpoint']

# %%
merged_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8610 entries, 0 to 8609
# Data columns (total 39 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   date                    8610 non-null   object
#  1   address                 8610 non-null   object
#  2   species                 8610 non-null   object
#  3   block                   8610 non-null   int64
#  4   street                  8610 non-null   object
#  5   trap                    8610 non-null   object
#  6   addressnumberandstreet  8610 non-null   object
#  7   latitude                8610 non-null   float64
#  8   longitude               8610 non-null   float64
#  9   addressaccuracy         8610 non-null   int64
#  10  wnvpresent              8610 non-null   int64
#  11  nummosquitos            8610 non-null   int64
#  12  year                    8610 non-null   int64
#  13  month                   8610 non-null   int64
#  14  week                    8610 non-null   int64
#  15  dayofweek               8610 non-null   int64
#  16  station                 8610 non-null   int64
#  17  tmax                    8610 non-null   float64
#  18  tmin                    8610 non-null   float64
#  19  tavg                    8610 non-null   float64
#  20  dewpoint                8610 non-null   float64
#  21  wetbulb                 8610 non-null   int64
#  22  heat                    8610 non-null   float64
#  23  cool                    8610 non-null   float64
#  24  sunrise                 8610 non-null   int64
#  25  sunset                  8610 non-null   int64
#  26  codesum                 8610 non-null   object
#  27  preciptotal             8610 non-null   float64
#  28  stnpressure             8610 non-null   float64
#  29  sealevel                8610 non-null   float64
#  30  resultspeed             8610 non-null   float64
#  31  resultdir               8610 non-null   int64
#  32  avgspeed                8610 non-null   float64
#  33  r_humid                 8610 non-null   int64
#  34  wetbulb_sunrise         8610 non-null   int64
#  35  week_wetbulb            8610 non-null   int64
#  36  month_wetbulb           8610 non-null   int64
#  37  week_dewpoint           8610 non-null   float64
#  38  month_dewPoint          8610 non-null   float64
# dtypes: float64(15), int64(17), object(7)
# memory usage: 2.6+ MB

# %% [markdown]
# ---

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# Due to the difference in dataset, there are possibility of difference in features and inputs. We will check both train and test dataset to ensure both are have similar features for modelling. Those new features created will be impute with 0 or not required will be dropped.

# %% [markdown]
# ### One-Hot Encoding for Species

# %%
# No. of mosquitoes unique values
print (len(merged_df1['species'].unique()))
print (len(merged_df_test1['species'].unique()))
# Out:
# 7
# 8

# %%
# Different species of mosquitoes in train dataset
merged_df1['species'].value_counts()
# Out:
# CULEX PIPIENS/RESTUANS    3899
# CULEX RESTUANS            2409
# CULEX PIPIENS             1996
# CULEX TERRITANS            216
# CULEX SALINARIUS            83
# CULEX TARSALIS               6
# CULEX ERRATICUS              1
# Name: species, dtype: int64

# %%
# Different species of mosquitoes in test dataset
merged_df_test1['species'].value_counts()
# Out:
# CULEX PIPIENS/RESTUANS    15359
# CULEX RESTUANS            14670
# CULEX PIPIENS             14521
# CULEX SALINARIUS          14355
# CULEX TERRITANS           14351
# CULEX TARSALIS            14347
# UNSPECIFIED CULEX         14345
# CULEX ERRATICUS           14345
# Name: species, dtype: int64

# %%
# Check missing in train dataset (test dataset have more values)
value_check = []

# Save additional features in a list
for i in merged_df_test1['species'].unique():
    if i not in merged_df1['species'].unique():
        value_check.append(i)
        
print (value_check)
# Out:
# ['UNSPECIFIED CULEX']

# %%
# Create get_dummies for 'species'
species_dummies = pd.get_dummies(merged_df1['species'])

# Change column name to str lower and replace / and whitespace with _
species_dummies.columns = species_dummies.columns.str.lower().str.replace('/', '_').str.replace(' ', '_')

# merge species_dummies with merge_df
merged_df1 = pd.concat([merged_df1, species_dummies], axis=1)

# %%
# Create get_dummies for 'species'
species_dummies2 = pd.get_dummies(merged_df_test1['species'])

# Change column name to str lower and replace / and whitespace with _
species_dummies2.columns = species_dummies2.columns.str.lower().str.replace('/', '_').str.replace(' ', '_')

# merge species_dummies with merge_df
merged_df_test1 = pd.concat([merged_df_test1, species_dummies2], axis=1)

# %%
print (merged_df1.shape)
print (merged_df_test1.shape)
# Out:
# (8610, 46)
# (116293, 46)

# %%
# Drop feature
merged_df_test1.drop('unspecified_culex', axis=1, inplace=True)

# %% [markdown]
# ### One-Hot Encoding for Trap

# %%
# Check missing in train dataset (test dataset have more values)
value_check2 = []

# Save additional features in a list
for i in merged_df_test1['trap'].unique():
    if i not in merged_df1['trap'].unique():
        value_check2.append(i)
        
print (value_check2)
# Out:
# ['T090A', 'T090B', 'T090C', 'T200A', 'T128A', 'T200B', 'T218A', 'T218C', 'T218B', 'T002A', 'T002B', 'T234', 'T065A']

# %%
# lower string for 'features'
value_check2 = [each_features.lower() for each_features in value_check2]

# Impute values for missing trap as 0
merged_df1[value_check2] = 0

# %%
print (len(merged_df1.columns))
print (len(merged_df_test1.columns))
# Out:
# 59
# 45

# %%
# Create get_dummies for 'trap'
trap_dummies = pd.get_dummies(merged_df1['trap'])

# Change column name to str lower and replace / and whitespace with _
trap_dummies.columns = trap_dummies.columns.str.lower().str.replace('/', '_').str.replace(' ', '_')

# merge species_dummies with merge_df
merged_df1 = pd.concat([merged_df1, trap_dummies], axis=1)

# %%
# Create get_dummies for 'trap'
trap_dummies = pd.get_dummies(merged_df_test1['trap'])

# Change column name to str lower and replace / and whitespace with _
trap_dummies.columns = trap_dummies.columns.str.lower().str.replace('/', '_').str.replace(' ', '_')

# merge species_dummies with merge_df
merged_df_test1 = pd.concat([merged_df_test1, trap_dummies], axis=1)

# %%
print (merged_df1.shape)
print (merged_df_test1.shape)
# Out:
# (8610, 195)
# (116293, 194)

# %% [markdown]
# ### One-Hot Encoding for CodeSum

# %%
# One hot encoding for codesum
# Split the codesum column into multiple columns by comparing to all valid codes

valid_codes = ['+FC','FC', 'TS', 'GR', 'RA', 'DZ', 'SN', 'SG', 'GS', 'PL',
         'IC', 'FG+', 'FG', 'BR', 'UP', 'HZ', 'FU', 'VA', 'DU', 'DS',
         'PO', 'SA', 'SS', 'PY', 'SQ', 'DR', 'SH', 'FZ', 'MI', 'PR',
         'BC', 'BL', 'VC']

def conver_codesum_to_col(dataset, valid_code_values):
    for col in valid_code_values:
        dataset[col] = dataset['codesum'].apply(lambda x: 1 if col in x else 0)
        if dataset[col].sum() == 0:
            dataset.drop(columns=[col], inplace=True)
    dataset.drop(columns='codesum', inplace=True)
    dataset.columns = dataset.columns.str.lower().str.replace('/', '_').str.replace(' ', '_')

# %%
conver_codesum_to_col(merged_df1, valid_codes)
conver_codesum_to_col(merged_df_test1, valid_codes)

# %%
print (merged_df1.shape)
print (merged_df_test1.shape)
# Out:
# (8610, 201)
# (116293, 202)

# %%
# Check missing in train dataset (test dataset have more values)
value_check3 = []

# Save additional features in a list
for i in merged_df_test1.columns:
    if i not in merged_df1.columns:
        value_check3.append(i)
        
print (value_check3)
# Out:
# ['id', 'fg+', 'bc']

# %%
# Drop feature
merged_df_test1.drop(['fg+', 'bc' ], axis=1, inplace=True)

# %%
print (merged_df1.shape)
print (merged_df_test1.shape)
# Out:
# (8610, 201)
# (116293, 200)

# %%
merged_df1['date']
# Out:
# 0       2007-05-29
# 1       2007-05-29
# 2       2007-05-29
# 3       2007-05-29
# 4       2007-05-29
#            ...
# 8605    2013-09-26
# 8606    2013-09-26
# 8607    2013-09-26
# 8608    2013-09-26
# 8609    2013-09-26
# Name: date, Length: 8610, dtype: object

# %% [markdown]
# ### Handling multicollinearity

# %% [markdown]
# Multicollinearity is the occurrence of high intercorrelations among two or more independent variables in the model and can lead to skewed or misleading results. Hence we are dropping features that are collinear to each other.

# %% [markdown]
# ### Numerical values

# %% [markdown]
# Feature that are multicollinearity:
# - date: 'week'
# - temperature: 'tmin', 'tmax', 'dewpoint', 'wetbulb'
# - pressure: 'sealevel'
# - speed: 'resultspeed'

# %%
# Columns drop list to handle multicollinearity
col_drop_list = ['week', 'tmin', 'tmax', 'dewpoint', 'wetbulb', 'sealevel', 'resultspeed']

for cols in col_drop_list:
    merged_df1.drop(cols, axis=1, inplace=True)
    merged_df_test1.drop(cols, axis=1, inplace=True)

# %%
print (merged_df1.shape)
print (merged_df_test1.shape)
# Out:
# (8610, 194)
# (116293, 193)

# %% [markdown]
# ### Non Numerical Data

# %% [markdown]
# Drop features that have the same meaning:
# - 'date', 'address', 'block'. 'street', 'traps', 'addressnumberandstreet', 'addressaccuracy', 'codesum'

# %%
# Columns drop list for merged_df dataset
col_drop_list2 = ['date', 'address', 'block', 'street', 'trap', 'addressnumberandstreet', 'addressaccuracy', 'species', 'nummosquitos']

# columns drop list for merged_df_test dataset - dataset does not include 'nummosquitos'
col_drop_list2_test= ['date', 'address', 'block', 'street', 'trap', 'addressnumberandstreet', 'addressaccuracy', 'species']


for cols2 in col_drop_list2:
    merged_df1.drop(cols2, axis=1, inplace=True)

for cols3 in col_drop_list2_test:
    merged_df_test1.drop(cols3, axis=1, inplace=True)

# %%
print (merged_df1.shape)
print (merged_df_test1.shape)
# Out:
# (8610, 185)
# (116293, 185)

# %%
merged_df2 = merged_df1.copy()
merged_df_test2= merged_df_test1.copy()

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ### Top 40 features

# %%
columns = abs(merged_df2.corr()['wnvpresent']).sort_values(ascending=False).head(41)

# %%
merged_df2 = merged_df2[columns.index]

# %%
#merged_df2.info()

# %% [markdown]
# ---

# %% [markdown]
# # Data Modelling

# %% [markdown]
# ### Train Test Split

# %%
# Define X and y features
X = merged_df2.drop('wnvpresent', axis=1)
y = merged_df2['wnvpresent']

# %%
# Train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

# %% [markdown]
# ### Baseline Model

# %% [markdown]
# When running the model with an imbalance dataset, our models immediately highlights the issue of using accuracy for our model. The dataset we're using is biased towards samples where WNV is absent, hence the high accuracy scores.
#
# For the baseline model, we will be using the ROC-AUC score to determine how good a model is at distinguishing between positive class and negative class.

# %%
# Baseline
y = merged_df2['wnvpresent']
y.value_counts(normalize=True)
# Out:
# 0    0.946922
# 1    0.053078
# Name: wnvpresent, dtype: float64

# %%
# Create dataframe to store result of gridsearch for baseline model
results = pd.DataFrame(columns=['model','train_score','test_score', 'precision', 
                                'recall', 'specificity', 'accuracy', 'f1', 'roc_auc'])

# %%
# List of models
models = ['logreg', 'knn', 'rf', 'ada', 'gb']

# %%
# Pipelines for different based model
list_pipes = [
    [('ss',StandardScaler()),('logreg',LogisticRegression(max_iter=5000))], 
    [('ss',StandardScaler()),('knn',KNeighborsClassifier())],
    [('ss',StandardScaler()),('rf',RandomForestClassifier())],
    [('ss',StandardScaler()),('ada',AdaBoostClassifier())],
    [('ss',StandardScaler()),('gb',GradientBoostingClassifier())]
]

# %%
# Run based model with evaluation metrics
for i in range(len(list_pipes)):
    pipe = Pipeline(steps=list_pipes[i])

    pipe.fit(X_train, y_train)

    preds = pipe.predict(X_test)
    
    # Save TN/FP/FN/TP values
    tn, fp, fn, tp = confusion_matrix(y_test, preds).ravel()

    # Storing results temporarily in loop
    temp = {}
    
    # Model metrics
    temp['model'] = models[i]
    temp['train_score'] = pipe.score(X_train, y_train)
    temp['test_score'] = pipe.score(X_test, y_test)
    temp['precision'] = tp / (tp + fp)
    temp['recall'] = tp / (tp + fn)
    temp['specificity'] = tn / (tn + fp)
    temp['accuracy'] = accuracy_score(y_test, preds)
    temp['f1'] = f1_score(y_test, preds)
    temp['roc_auc'] = roc_auc_score(y_test, pipe.predict_proba(X_test)[:,1])
    
    results = results.append(temp, ignore_index=True)
    
    # Print summary 
    
    print(f'Model: {models[i]}')
    print('')
    
    print(f'Train Score: {temp["train_score"]}')
    print(f'Test Score: {temp["test_score"]}')
    print('')

    print ("True Negatives: %s" % tn)
    print ("False Positives: %s" % fp)
    print ("False Negatives: %s" % fn)
    print ("True Positives: %s" % tp)
    print('')
    
    # Import ref: https://towardsdatascience.com/what-metrics-should-we-use-on-imbalanced-data-set-precision-recall-roc-e2e79252aeba
    
    print (f'Precision Score: {temp["precision"]}')
    print (f'Recall Score: {temp["recall"]}')
    print (f'Specificity Score: {temp["specificity"]}')
    print (f'Accuracy Score: {temp["accuracy"]}')
    print (f'F1 Score: {temp["f1"]}')
    print ('')
    
    print (f'ROC_AUC Score: {temp["roc_auc"]}')
    print('-------------------------------------------------------------------------------')
# Out:
# Model: logreg
#
# Train Score: 0.946407831425253
# Test Score: 0.9469608981804104
#
# True Negatives: 2445
# False Positives: 1
# False Negatives: 136
# True Positives: 1
#
# Precision Score: 0.5
# Recall Score: 0.0072992700729927005
# Specificity Score: 0.9995911692559281
# Accuracy Score: 0.9469608981804104
# F1 Score: 0.014388489208633093
#
# ROC_AUC Score: 0.8130375229034741
# -------------------------------------------------------------------------------
# Model: knn
#
# Train Score: 0.9500580720092915
# Test Score: 0.943476577622919
#
# True Negatives: 2432
# False Positives: 14
# False Negatives: 132
# True Positives: 5
#
# Precision Score: 0.2631578947368421
# Recall Score: 0.0364963503649635
# Specificity Score: 0.9942763695829926
# Accuracy Score: 0.943476577622919
# F1 Score: 0.0641025641025641
#
# ROC_AUC Score: 0.6987738061843856
# -------------------------------------------------------------------------------
# Model: rf
#
# Train Score: 0.9880537580886013
# Test Score: 0.9380565234223771
#
# True Negatives: 2412
# False Positives: 34
# False Negatives: 126
# True Positives: 11
#
# Precision Score: 0.24444444444444444
# Recall Score: 0.08029197080291971
# Specificity Score: 0.9860997547015535
# Accuracy Score: 0.9380565234223771
# F1 Score: 0.12087912087912088
#
# ROC_AUC Score: 0.8009337455461324
# -------------------------------------------------------------------------------
# Model: ada
#
# Train Score: 0.946407831425253
# Test Score: 0.9438637243515292
#
# True Negatives: 2435
# False Positives: 11
# False Negatives: 134
# True Positives: 3
#
# Precision Score: 0.21428571428571427
# Recall Score: 0.021897810218978103
# Specificity Score: 0.9955028618152085
# Accuracy Score: 0.9438637243515292
# F1 Score: 0.039735099337748346
#
# ROC_AUC Score: 0.8461229715131512
# -------------------------------------------------------------------------------
# Model: gb
#
# Train Score: 0.94956031192965
# Test Score: 0.9427022841656988
#
# True Negatives: 2434
# False Positives: 12
# False Negatives: 136
# True Positives: 1
#
# Precision Score: 0.07692307692307693
# Recall Score: 0.0072992700729927005
# Specificity Score: 0.9950940310711366
# Accuracy Score: 0.9427022841656988
# F1 Score: 0.013333333333333332
#
# ROC_AUC Score: 0.8726895094627904
# -------------------------------------------------------------------------------

# %%
results[['model', 'train_score', 'test_score','recall', 'accuracy', 'roc_auc']]
# Out:
#     model  train_score  test_score    recall  accuracy   roc_auc
# 0  logreg     0.946408    0.946961  0.007299  0.946961  0.813038
# 1     knn     0.950058    0.943477  0.036496  0.943477  0.698774
# 2      rf     0.988054    0.938057  0.080292  0.938057  0.800934
# 3     ada     0.946408    0.943864  0.021898  0.943864  0.846123
# 4      gb     0.949560    0.942702  0.007299  0.942702  0.872690

# %% [markdown]
# Based on results, our Boosting algorithms and Random Forest are able seemed to be performing better as compare to other models.

# %% [markdown]
# ---

# %% [markdown]
# # Best model with hyperparameters

# %% [markdown]
# ### Handling imbalance dataset

# %% [markdown]
# SMOTE (synthetic minority oversampling technique) is one of the most commonly used oversampling methods to solve the imbalance problem. It aims to balance class distribution by randomly increasing minority class examples by replicating them and synthesises new minority instances between existing minority instances.

# %%
# SMOTE
smt = SMOTE()
X_train, y_train = smt.fit_resample(X_train, y_train)

# %%
X_train.shape
# Out:
# (11414, 40)

# %%
X_test.shape
# Out:
# (2583, 40)

# %%
y_train.value_counts()
# Out:
# 1    5707
# 0    5707
# Name: wnvpresent, dtype: int64

# %% [markdown]
# ### Functions

# %%
results3 = pd.DataFrame()

# %%
# Function to calculate metrics
def eva_metrics(gs, preds, model_name):
    
    # Save TN/FP/FN/TP values
    tn, fp, fn, tp = confusion_matrix(y_test, preds).ravel()
    
    # Storing results temporarily in loop
    temp_mod = {}
    
    # Model metrics
    temp_mod['model'] = model_name
    temp_mod['best_parameters'] = gs.best_params_
    temp_mod['train_score'] = gs.score(X_train, y_train)
    temp_mod['test_score'] = gs.score(X_test, y_test)
    temp_mod['precision'] = tp / (tp + fp)
    temp_mod['recall'] = tp / (tp + fn)
    temp_mod['specificity'] = tn / (tn + fp)
    temp_mod['accuracy'] = accuracy_score(y_test, preds)
    temp_mod['f1'] = f1_score(y_test, preds)
    temp_mod['roc_auc'] = roc_auc_score(y_test, gs.predict_proba(X_test)[:,1])
    
    print(temp_mod)
    
    global results3
    results3 = results3.append(temp_mod, ignore_index=True)

    # Print summary 
    
    print(f'Model: {temp_mod["model"]}')
    print('')
    
    print(f'Best parameters are: {temp_mod["best_parameters"]}')
    print('')
    
    print(f'Train Score: {temp_mod["train_score"]}')
    print(f'Test Score: {temp_mod["test_score"]}')
    print('')

    print ("True Negatives: %s" % tn)
    print ("False Positives: %s" % fp)
    print ("False Negatives: %s" % fn)
    print ("True Positives: %s" % tp)
    print('')
    
    # Import ref: https://towardsdatascience.com/what-metrics-should-we-use-on-imbalanced-data-set-precision-recall-roc-e2e79252aeba
    
    print (f'Precision Score: {temp_mod["precision"]}')
    print (f'Recall Score: {temp_mod["precision"]}')
    print (f'Specificity Score: {temp_mod["specificity"]}')
    print (f'Accuracy Score: {temp_mod["accuracy"]}')
    print (f'F1 Score: {temp_mod["f1"]}')
    print ('')
    
    print (f'ROC_AUC Score: {temp_mod["roc_auc"]}')
    print('-------------------------------------------------------------------------------')
    print ('')
    
    plot_roc_curve(gs, X_test, y_test)
    plt.plot([0, 1], [0, 1], label='Baseline', linestyle='--')
    plt.title(model_name)

# %% [markdown]
# ---

# %% [markdown]
# ### Logistic Regression

# %%
# Create pipeline for logistic regression classification model
pipe_logreg = Pipeline([
    ('ss', StandardScaler()),
    ('logreg', LogisticRegression())
])

# Include different hyperparameters
pipe_params_logreg = [{"logreg__n_jobs": [3],
                       "logreg__penalty":['l2'],
                       "logreg__C": np.arange(1, 5, 0.1),
                       "logreg__max_iter": [5000]}]

# %%
# Instantiate GridSearchCV
gs = GridSearchCV(pipe_logreg, pipe_params_logreg, cv=5, verbose=2) 

#Fit GridSearchCV
gs.fit(X_train, y_train)

# Find predictors
preds = gs.predict(X_test)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# [CV] END logreg__C=1.0, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   2.8s
# [CV] END logreg__C=1.0, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   2.3s
# [CV] END logreg__C=1.0, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   2.2s
# [CV] END logreg__C=1.0, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.4s
# [CV] END logreg__C=1.0, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.5s
# [CV] END logreg__C=1.1, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.3s
# [CV] END logreg__C=1.1, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.2s
# [CV] END logreg__C=1.1, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.3s
# [CV] END logreg__C=1.1, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.6s
# [CV] END logreg__C=1.1, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.3s
# [CV] END logreg__C=1.2000000000000002, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.5s
# [CV] END logreg__C=1.2000000000000002, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.4s
# [CV] END logreg__C=1.2000000000000002, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.3s
# [CV] END logreg__C=1.2000000000000002, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.3s
# [CV] END logreg__C=1.2000000000000002, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.5s
# [CV] END logreg__C=1.3000000000000003, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.3s
# [CV] END logreg__C=1.3000000000000003, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.6s
# [CV] END logreg__C=1.3000000000000003, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.4s
# [CV] END logreg__C=1.3000000000000003, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.5s
# [CV] END logreg__C=1.3000000000000003, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.4s
# [CV] END logreg__C=1.4000000000000004, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.6s
# [CV] END logreg__C=1.4000000000000004, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.5s
# [CV] END logreg__C=1.4000000000000004, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.5s
# [CV] END logreg__C=1.4000000000000004, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.5s
# [CV] END logreg__C=1.4000000000000004, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.4s
# [CV] END logreg__C=1.5000000000000004, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.4s
# [CV] END logreg__C=1.5000000000000004, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.6s
# [CV] END logreg__C=1.5000000000000004, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.4s
# [CV] END logreg__C=1.5000000000000004, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.4s
# [CV] END logreg__C=1.5000000000000004, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.6s
# [CV] END logreg__C=1.6000000000000005, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.4s
# [CV] END logreg__C=1.6000000000000005, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.5s
# [CV] END logreg__C=1.6000000000000005, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.4s
# [CV] END logreg__C=1.6000000000000005, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.5s
# [CV] END logreg__C=1.6000000000000005, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.5s
# [CV] END logreg__C=1.7000000000000006, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.6s
# [CV] END logreg__C=1.7000000000000006, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.5s
# [CV] END logreg__C=1.7000000000000006, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.4s
# [CV] END logreg__C=1.7000000000000006, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.4s
# [CV] END logreg__C=1.7000000000000006, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.5s
# [CV] END logreg__C=1.8000000000000007, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.3s
# [CV] END logreg__C=1.8000000000000007, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.5s
# [CV] END logreg__C=1.8000000000000007, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.4s
# [CV] END logreg__C=1.8000000000000007, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.4s
# [CV] END logreg__C=1.8000000000000007, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.6s
# [CV] END logreg__C=1.9000000000000008, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.7s
# [CV] END logreg__C=1.9000000000000008, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.3s
# [CV] END logreg__C=1.9000000000000008, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.6s
# [CV] END logreg__C=1.9000000000000008, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.5s
# [CV] END logreg__C=1.9000000000000008, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.5s
# [CV] END logreg__C=2.000000000000001, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   2.0s
# [CV] END logreg__C=2.000000000000001, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.6s
# [CV] END logreg__C=2.000000000000001, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.7s
# [CV] END logreg__C=2.000000000000001, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.5s
# [CV] END logreg__C=2.000000000000001, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.5s
# [CV] END logreg__C=2.100000000000001, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.8s
# [CV] END logreg__C=2.100000000000001, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.7s
# [CV] END logreg__C=2.100000000000001, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.6s
# [CV] END logreg__C=2.100000000000001, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.7s
# [CV] END logreg__C=2.100000000000001, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.7s
# [CV] END logreg__C=2.200000000000001, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.7s
# [CV] END logreg__C=2.200000000000001, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.5s
# [CV] END logreg__C=2.200000000000001, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.6s
# [CV] END logreg__C=2.200000000000001, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.5s
# [CV] END logreg__C=2.200000000000001, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.7s
# [CV] END logreg__C=2.300000000000001, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.6s
# [CV] END logreg__C=2.300000000000001, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.5s
# [CV] END logreg__C=2.300000000000001, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.6s
# [CV] END logreg__C=2.300000000000001, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.3s
# [CV] END logreg__C=2.300000000000001, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.7s
# [CV] END logreg__C=2.4000000000000012, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.7s
# [CV] END logreg__C=2.4000000000000012, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.9s
# [CV] END logreg__C=2.4000000000000012, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.6s
# [CV] END logreg__C=2.4000000000000012, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.7s
# [CV] END logreg__C=2.4000000000000012, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.6s
# [CV] END logreg__C=2.5000000000000013, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.7s
# [CV] END logreg__C=2.5000000000000013, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.5s
# [CV] END logreg__C=2.5000000000000013, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   2.1s
# [CV] END logreg__C=2.5000000000000013, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.5s
# [CV] END logreg__C=2.5000000000000013, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.6s
# [CV] END logreg__C=2.6000000000000014, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.6s
# [CV] END logreg__C=2.6000000000000014, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.3s
# [CV] END logreg__C=2.6000000000000014, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.8s
# [CV] END logreg__C=2.6000000000000014, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.6s
# [CV] END logreg__C=2.6000000000000014, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.8s
# [CV] END logreg__C=2.7000000000000015, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.9s
# [CV] END logreg__C=2.7000000000000015, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.5s
# [CV] END logreg__C=2.7000000000000015, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.7s
# [CV] END logreg__C=2.7000000000000015, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   2.0s
# [CV] END logreg__C=2.7000000000000015, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.3s
# [CV] END logreg__C=2.8000000000000016, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.8s
# [CV] END logreg__C=2.8000000000000016, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.6s
# [CV] END logreg__C=2.8000000000000016, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.7s
# [CV] END logreg__C=2.8000000000000016, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.4s
# [CV] END logreg__C=2.8000000000000016, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.7s
# [CV] END logreg__C=2.9000000000000017, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.8s
# [CV] END logreg__C=2.9000000000000017, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.8s
# [CV] END logreg__C=2.9000000000000017, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.8s
# [CV] END logreg__C=2.9000000000000017, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.5s
# [CV] END logreg__C=2.9000000000000017, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.6s
# [CV] END logreg__C=3.0000000000000018, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.6s
# [CV] END logreg__C=3.0000000000000018, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.7s
# [CV] END logreg__C=3.0000000000000018, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.8s
# [CV] END logreg__C=3.0000000000000018, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.4s
# [CV] END logreg__C=3.0000000000000018, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.7s
# [CV] END logreg__C=3.100000000000002, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.9s
# [CV] END logreg__C=3.100000000000002, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.8s
# [CV] END logreg__C=3.100000000000002, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.8s
# [CV] END logreg__C=3.100000000000002, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.5s
# [CV] END logreg__C=3.100000000000002, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.4s
# [CV] END logreg__C=3.200000000000002, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.4s
# [CV] END logreg__C=3.200000000000002, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   2.0s
# [CV] END logreg__C=3.200000000000002, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.7s
# [CV] END logreg__C=3.200000000000002, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.6s
# [CV] END logreg__C=3.200000000000002, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.5s
# [CV] END logreg__C=3.300000000000002, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.6s
# [CV] END logreg__C=3.300000000000002, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.6s
# [CV] END logreg__C=3.300000000000002, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   7.0s
# [CV] END logreg__C=3.300000000000002, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   7.1s
# [CV] END logreg__C=3.300000000000002, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   7.6s
# [CV] END logreg__C=3.400000000000002, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.8s
# [CV] END logreg__C=3.400000000000002, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.5s
# [CV] END logreg__C=3.400000000000002, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.6s
# [CV] END logreg__C=3.400000000000002, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.8s
# [CV] END logreg__C=3.400000000000002, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.6s
# [CV] END logreg__C=3.500000000000002, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.7s
# [CV] END logreg__C=3.500000000000002, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.7s
# [CV] END logreg__C=3.500000000000002, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.9s
# [CV] END logreg__C=3.500000000000002, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.6s
# [CV] END logreg__C=3.500000000000002, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.4s
# [CV] END logreg__C=3.6000000000000023, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.5s
# [CV] END logreg__C=3.6000000000000023, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.6s
# [CV] END logreg__C=3.6000000000000023, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.5s
# [CV] END logreg__C=3.6000000000000023, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.5s
# [CV] END logreg__C=3.6000000000000023, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.6s
# [CV] END logreg__C=3.7000000000000024, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.6s
# [CV] END logreg__C=3.7000000000000024, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.7s
# [CV] END logreg__C=3.7000000000000024, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.6s
# [CV] END logreg__C=3.7000000000000024, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.8s
# [CV] END logreg__C=3.7000000000000024, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.9s
# [CV] END logreg__C=3.8000000000000025, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.9s
# [CV] END logreg__C=3.8000000000000025, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.9s
# [CV] END logreg__C=3.8000000000000025, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.5s
# [CV] END logreg__C=3.8000000000000025, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.5s
# [CV] END logreg__C=3.8000000000000025, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.6s
# [CV] END logreg__C=3.9000000000000026, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.8s
# [CV] END logreg__C=3.9000000000000026, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.7s
# [CV] END logreg__C=3.9000000000000026, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.7s
# [CV] END logreg__C=3.9000000000000026, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.5s
# [CV] END logreg__C=3.9000000000000026, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.5s
# [CV] END logreg__C=4.000000000000003, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.7s
# [CV] END logreg__C=4.000000000000003, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.9s
# [CV] END logreg__C=4.000000000000003, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.7s
# [CV] END logreg__C=4.000000000000003, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.7s
# [CV] END logreg__C=4.000000000000003, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.5s
# [CV] END logreg__C=4.100000000000003, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.9s
# [CV] END logreg__C=4.100000000000003, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.5s
# [CV] END logreg__C=4.100000000000003, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.7s
# [CV] END logreg__C=4.100000000000003, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.9s
# [CV] END logreg__C=4.100000000000003, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.6s
# [CV] END logreg__C=4.200000000000003, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.6s
# [CV] END logreg__C=4.200000000000003, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.7s
# [CV] END logreg__C=4.200000000000003, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.9s
# [CV] END logreg__C=4.200000000000003, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.7s
# [CV] END logreg__C=4.200000000000003, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.7s
# [CV] END logreg__C=4.3000000000000025, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   2.0s
# [CV] END logreg__C=4.3000000000000025, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.8s
# [CV] END logreg__C=4.3000000000000025, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.6s
# [CV] END logreg__C=4.3000000000000025, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.7s
# [CV] END logreg__C=4.3000000000000025, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.8s
# [CV] END logreg__C=4.400000000000003, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.7s
# [CV] END logreg__C=4.400000000000003, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.9s
# [CV] END logreg__C=4.400000000000003, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.9s
# [CV] END logreg__C=4.400000000000003, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.7s
# [CV] END logreg__C=4.400000000000003, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.7s
# [CV] END logreg__C=4.5000000000000036, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.6s
# [CV] END logreg__C=4.5000000000000036, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.6s
# [CV] END logreg__C=4.5000000000000036, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.6s
# [CV] END logreg__C=4.5000000000000036, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.5s
# [CV] END logreg__C=4.5000000000000036, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.5s
# [CV] END logreg__C=4.600000000000003, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.7s
# [CV] END logreg__C=4.600000000000003, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.8s
# [CV] END logreg__C=4.600000000000003, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   2.0s
# [CV] END logreg__C=4.600000000000003, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.8s
# [CV] END logreg__C=4.600000000000003, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.6s
# [CV] END logreg__C=4.700000000000003, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.6s
# [CV] END logreg__C=4.700000000000003, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.9s
# [CV] END logreg__C=4.700000000000003, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.8s
# [CV] END logreg__C=4.700000000000003, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.9s
# [CV] END logreg__C=4.700000000000003, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.6s
# [CV] END logreg__C=4.800000000000003, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.7s
# [CV] END logreg__C=4.800000000000003, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.8s
# [CV] END logreg__C=4.800000000000003, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.7s
# [CV] END logreg__C=4.800000000000003, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.5s
# [CV] END logreg__C=4.800000000000003, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.5s
# [CV] END logreg__C=4.900000000000004, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.7s
# [CV] END logreg__C=4.900000000000004, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   2.1s
# [CV] END logreg__C=4.900000000000004, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   2.0s
# [CV] END logreg__C=4.900000000000004, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.6s
# [CV] END logreg__C=4.900000000000004, logreg__max_iter=5000, logreg__n_jobs=3, logreg__penalty=l2; total time=   1.9s

# %%
# Evaluation metrics
eva_metrics(gs, preds, 'logreg')
# Out:
# {'model': 'logreg', 'best_parameters': {'logreg__C': 2.9000000000000017, 'logreg__max_iter': 5000, 'logreg__n_jobs': 3, 'logreg__penalty': 'l2'}, 'train_score': 0.8047135097248993, 'test_score': 0.7208672086720868, 'precision': 0.09103641456582633, 'recall': 0.4744525547445255, 'specificity': 0.7346688470973017, 'accuracy': 0.7208672086720868, 'f1': 0.15276145710928318, 'roc_auc': 0.6997705176334369}
# Model: logreg
#
# Best parameters are: {'logreg__C': 2.9000000000000017, 'logreg__max_iter': 5000, 'logreg__n_jobs': 3, 'logreg__penalty': 'l2'}
#
# Train Score: 0.8047135097248993
# Test Score: 0.7208672086720868
#
# True Negatives: 1797
# False Positives: 649
# False Negatives: 72
# True Positives: 65
#
# Precision Score: 0.09103641456582633
# Recall Score: 0.09103641456582633
# Specificity Score: 0.7346688470973017
# Accuracy Score: 0.7208672086720868
# F1 Score: 0.15276145710928318
#
# ROC_AUC Score: 0.6997705176334369
# -------------------------------------------------------------------------------

# %%
results3
# Out:
#    accuracy                                    best_parameters        f1  \
# 0  0.720867  {'logreg__C': 2.9000000000000017, 'logreg__max...  0.152761
#
#     model  precision    recall   roc_auc  specificity  test_score  train_score
# 0  logreg   0.091036  0.474453  0.699771     0.734669    0.720867     0.804714

# %% [markdown]
# ### K Nearest Neighbors

# %%
# Create pipeline for k nearest neighbors classification model
pipe_knn = Pipeline([
    ('ss', StandardScaler()),
    ('knn', KNeighborsClassifier())
])

# Ref: https://medium.datadriveninvestor.com/k-nearest-neighbors-in-python-hyperparameters-tuning-716734bc557f
# Ref: https://medium.com/swlh/the-hyperparameter-cheat-sheet-770f1fed32ff
n_neighbors = list(range(1,10))

# Include different hyperparameters
pipe_params_knn = [{"knn__n_neighbors": n_neighbors}]

# %%
# Instantiate GridSearchCV
gs2 = GridSearchCV(pipe_knn, pipe_params_knn, cv=5, verbose=2) 

#Fit GridSearchCV
gs2.fit(X_train, y_train)

# Find predictors
preds2 = gs2.predict(X_test)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] END .................................knn__n_neighbors=1; total time=   0.4s
# [CV] END .................................knn__n_neighbors=1; total time=   0.4s
# [CV] END .................................knn__n_neighbors=1; total time=   0.3s
# [CV] END .................................knn__n_neighbors=1; total time=   0.3s
# [CV] END .................................knn__n_neighbors=1; total time=   0.3s
# [CV] END .................................knn__n_neighbors=2; total time=   0.4s
# [CV] END .................................knn__n_neighbors=2; total time=   0.3s
# [CV] END .................................knn__n_neighbors=2; total time=   0.4s
# [CV] END .................................knn__n_neighbors=2; total time=   0.4s
# [CV] END .................................knn__n_neighbors=2; total time=   0.4s
# [CV] END .................................knn__n_neighbors=3; total time=   0.4s
# [CV] END .................................knn__n_neighbors=3; total time=   0.4s
# [CV] END .................................knn__n_neighbors=3; total time=   0.4s
# [CV] END .................................knn__n_neighbors=3; total time=   0.4s
# [CV] END .................................knn__n_neighbors=3; total time=   0.4s
# [CV] END .................................knn__n_neighbors=4; total time=   0.4s
# [CV] END .................................knn__n_neighbors=4; total time=   0.5s
# [CV] END .................................knn__n_neighbors=4; total time=   0.5s
# [CV] END .................................knn__n_neighbors=4; total time=   0.4s
# [CV] END .................................knn__n_neighbors=4; total time=   0.5s
# [CV] END .................................knn__n_neighbors=5; total time=   0.4s
# [CV] END .................................knn__n_neighbors=5; total time=   0.5s
# [CV] END .................................knn__n_neighbors=5; total time=   0.5s
# [CV] END .................................knn__n_neighbors=5; total time=   0.5s
# [CV] END .................................knn__n_neighbors=5; total time=   0.5s
# [CV] END .................................knn__n_neighbors=6; total time=   0.4s
# [CV] END .................................knn__n_neighbors=6; total time=   0.5s
# [CV] END .................................knn__n_neighbors=6; total time=   0.5s
# [CV] END .................................knn__n_neighbors=6; total time=   0.5s
# [CV] END .................................knn__n_neighbors=6; total time=   0.5s
# [CV] END .................................knn__n_neighbors=7; total time=   0.4s
# [CV] END .................................knn__n_neighbors=7; total time=   0.5s
# [CV] END .................................knn__n_neighbors=7; total time=   0.5s
# [CV] END .................................knn__n_neighbors=7; total time=   0.5s
# [CV] END .................................knn__n_neighbors=7; total time=   0.5s
# [CV] END .................................knn__n_neighbors=8; total time=   0.4s
# [CV] END .................................knn__n_neighbors=8; total time=   0.5s
# [CV] END .................................knn__n_neighbors=8; total time=   0.5s
# [CV] END .................................knn__n_neighbors=8; total time=   0.5s
# [CV] END .................................knn__n_neighbors=8; total time=   0.5s
# [CV] END .................................knn__n_neighbors=9; total time=   0.4s
# [CV] END .................................knn__n_neighbors=9; total time=   0.5s
# [CV] END .................................knn__n_neighbors=9; total time=   0.5s
# [CV] END .................................knn__n_neighbors=9; total time=   0.5s
# [CV] END .................................knn__n_neighbors=9; total time=   0.5s

# %%
# Evaluation metrics
eva_metrics(gs2, preds2, 'knn')
# Out:
# {'model': 'knn', 'best_parameters': {'knn__n_neighbors': 3}, 'train_score': 0.9469073068161906, 'test_score': 0.8381726674409601, 'precision': 0.14249363867684478, 'recall': 0.40875912408759124, 'specificity': 0.8622240392477515, 'accuracy': 0.8381726674409601, 'f1': 0.21132075471698114, 'roc_auc': 0.7016341293098818}
# Model: knn
#
# Best parameters are: {'knn__n_neighbors': 3}
#
# Train Score: 0.9469073068161906
# Test Score: 0.8381726674409601
#
# True Negatives: 2109
# False Positives: 337
# False Negatives: 81
# True Positives: 56
#
# Precision Score: 0.14249363867684478
# Recall Score: 0.14249363867684478
# Specificity Score: 0.8622240392477515
# Accuracy Score: 0.8381726674409601
# F1 Score: 0.21132075471698114
#
# ROC_AUC Score: 0.7016341293098818
# -------------------------------------------------------------------------------

# %%
results3
# Out:
#    accuracy                                    best_parameters        f1  \
# 0  0.720867  {'logreg__C': 2.9000000000000017, 'logreg__max...  0.152761
# 1  0.838173                            {'knn__n_neighbors': 3}  0.211321
#
#     model  precision    recall   roc_auc  specificity  test_score  train_score
# 0  logreg   0.091036  0.474453  0.699771     0.734669    0.720867     0.804714
# 1     knn   0.142494  0.408759  0.701634     0.862224    0.838173     0.946907

# %% [markdown]
# ### Random Forest

# %%
# Create pipeline for random forest classification model
pipe_rf = Pipeline([
    ('ss', StandardScaler()),
    ('rf', RandomForestClassifier())
])

# Ref: https://medium.com/swlh/the-hyperparameter-cheat-sheet-770f1fed32ff
n_estimators = np.arange(100, 200, 20)
max_depth = [None, 1, 2, 3, 4, 5]

# Include different hyperparameters
pipe_params_rf = [{"rf__n_estimators": n_estimators,
                   "rf__max_depth": max_depth}]

# %%
# Instantiate GridSearchCV
gs3 = GridSearchCV(pipe_rf, pipe_params_rf, cv=5, verbose=2) 

#Fit GridSearchCV
gs3.fit(X_train, y_train)

# Find predictors
preds3 = gs3.predict(X_test)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [CV] END ...........rf__max_depth=None, rf__n_estimators=100; total time=   0.9s
# [CV] END ...........rf__max_depth=None, rf__n_estimators=100; total time=   0.9s
# [CV] END ...........rf__max_depth=None, rf__n_estimators=100; total time=   1.0s
# [CV] END ...........rf__max_depth=None, rf__n_estimators=100; total time=   0.9s
# [CV] END ...........rf__max_depth=None, rf__n_estimators=100; total time=   0.9s
# [CV] END ...........rf__max_depth=None, rf__n_estimators=120; total time=   1.1s
# [CV] END ...........rf__max_depth=None, rf__n_estimators=120; total time=   1.2s
# [CV] END ...........rf__max_depth=None, rf__n_estimators=120; total time=   1.1s
# [CV] END ...........rf__max_depth=None, rf__n_estimators=120; total time=   1.1s
# [CV] END ...........rf__max_depth=None, rf__n_estimators=120; total time=   1.1s
# [CV] END ...........rf__max_depth=None, rf__n_estimators=140; total time=   1.4s
# [CV] END ...........rf__max_depth=None, rf__n_estimators=140; total time=   1.4s
# [CV] END ...........rf__max_depth=None, rf__n_estimators=140; total time=   1.3s
# [CV] END ...........rf__max_depth=None, rf__n_estimators=140; total time=   1.3s
# [CV] END ...........rf__max_depth=None, rf__n_estimators=140; total time=   1.4s
# [CV] END ...........rf__max_depth=None, rf__n_estimators=160; total time=   1.5s
# [CV] END ...........rf__max_depth=None, rf__n_estimators=160; total time=   1.6s
# [CV] END ...........rf__max_depth=None, rf__n_estimators=160; total time=   1.6s
# [CV] END ...........rf__max_depth=None, rf__n_estimators=160; total time=   1.6s
# [CV] END ...........rf__max_depth=None, rf__n_estimators=160; total time=   1.6s
# [CV] END ...........rf__max_depth=None, rf__n_estimators=180; total time=   1.8s
# [CV] END ...........rf__max_depth=None, rf__n_estimators=180; total time=   1.8s
# [CV] END ...........rf__max_depth=None, rf__n_estimators=180; total time=   1.8s
# [CV] END ...........rf__max_depth=None, rf__n_estimators=180; total time=   1.7s
# [CV] END ...........rf__max_depth=None, rf__n_estimators=180; total time=   1.7s
# [CV] END ..............rf__max_depth=1, rf__n_estimators=100; total time=   0.2s
# [CV] END ..............rf__max_depth=1, rf__n_estimators=100; total time=   0.2s
# [CV] END ..............rf__max_depth=1, rf__n_estimators=100; total time=   0.2s
# [CV] END ..............rf__max_depth=1, rf__n_estimators=100; total time=   0.2s
# [CV] END ..............rf__max_depth=1, rf__n_estimators=100; total time=   0.2s
# [CV] END ..............rf__max_depth=1, rf__n_estimators=120; total time=   0.2s
# [CV] END ..............rf__max_depth=1, rf__n_estimators=120; total time=   0.2s
# [CV] END ..............rf__max_depth=1, rf__n_estimators=120; total time=   0.2s
# [CV] END ..............rf__max_depth=1, rf__n_estimators=120; total time=   0.2s
# [CV] END ..............rf__max_depth=1, rf__n_estimators=120; total time=   0.2s
# [CV] END ..............rf__max_depth=1, rf__n_estimators=140; total time=   0.3s
# [CV] END ..............rf__max_depth=1, rf__n_estimators=140; total time=   0.3s
# [CV] END ..............rf__max_depth=1, rf__n_estimators=140; total time=   0.3s
# [CV] END ..............rf__max_depth=1, rf__n_estimators=140; total time=   0.3s
# [CV] END ..............rf__max_depth=1, rf__n_estimators=140; total time=   0.3s
# [CV] END ..............rf__max_depth=1, rf__n_estimators=160; total time=   0.3s
# [CV] END ..............rf__max_depth=1, rf__n_estimators=160; total time=   0.4s
# [CV] END ..............rf__max_depth=1, rf__n_estimators=160; total time=   0.4s
# [CV] END ..............rf__max_depth=1, rf__n_estimators=160; total time=   0.3s
# [CV] END ..............rf__max_depth=1, rf__n_estimators=160; total time=   0.4s
# [CV] END ..............rf__max_depth=1, rf__n_estimators=180; total time=   0.4s
# [CV] END ..............rf__max_depth=1, rf__n_estimators=180; total time=   0.4s
# [CV] END ..............rf__max_depth=1, rf__n_estimators=180; total time=   0.4s
# [CV] END ..............rf__max_depth=1, rf__n_estimators=180; total time=   0.4s
# [CV] END ..............rf__max_depth=1, rf__n_estimators=180; total time=   0.4s
# [CV] END ..............rf__max_depth=2, rf__n_estimators=100; total time=   0.2s
# [CV] END ..............rf__max_depth=2, rf__n_estimators=100; total time=   0.2s
# [CV] END ..............rf__max_depth=2, rf__n_estimators=100; total time=   0.2s
# [CV] END ..............rf__max_depth=2, rf__n_estimators=100; total time=   0.2s
# [CV] END ..............rf__max_depth=2, rf__n_estimators=100; total time=   0.3s
# [CV] END ..............rf__max_depth=2, rf__n_estimators=120; total time=   0.3s
# [CV] END ..............rf__max_depth=2, rf__n_estimators=120; total time=   0.3s
# [CV] END ..............rf__max_depth=2, rf__n_estimators=120; total time=   0.3s
# [CV] END ..............rf__max_depth=2, rf__n_estimators=120; total time=   0.3s
# [CV] END ..............rf__max_depth=2, rf__n_estimators=120; total time=   0.3s
# [CV] END ..............rf__max_depth=2, rf__n_estimators=140; total time=   0.4s
# [CV] END ..............rf__max_depth=2, rf__n_estimators=140; total time=   0.4s
# [CV] END ..............rf__max_depth=2, rf__n_estimators=140; total time=   0.4s
# [CV] END ..............rf__max_depth=2, rf__n_estimators=140; total time=   0.4s
# [CV] END ..............rf__max_depth=2, rf__n_estimators=140; total time=   0.4s
# [CV] END ..............rf__max_depth=2, rf__n_estimators=160; total time=   0.4s
# [CV] END ..............rf__max_depth=2, rf__n_estimators=160; total time=   0.4s
# [CV] END ..............rf__max_depth=2, rf__n_estimators=160; total time=   0.4s
# [CV] END ..............rf__max_depth=2, rf__n_estimators=160; total time=   0.4s
# [CV] END ..............rf__max_depth=2, rf__n_estimators=160; total time=   0.4s
# [CV] END ..............rf__max_depth=2, rf__n_estimators=180; total time=   0.5s
# [CV] END ..............rf__max_depth=2, rf__n_estimators=180; total time=   0.5s
# [CV] END ..............rf__max_depth=2, rf__n_estimators=180; total time=   0.5s
# [CV] END ..............rf__max_depth=2, rf__n_estimators=180; total time=   0.6s
# [CV] END ..............rf__max_depth=2, rf__n_estimators=180; total time=   0.6s
# [CV] END ..............rf__max_depth=3, rf__n_estimators=100; total time=   0.3s
# [CV] END ..............rf__max_depth=3, rf__n_estimators=100; total time=   0.3s
# [CV] END ..............rf__max_depth=3, rf__n_estimators=100; total time=   0.3s
# [CV] END ..............rf__max_depth=3, rf__n_estimators=100; total time=   0.3s
# [CV] END ..............rf__max_depth=3, rf__n_estimators=100; total time=   0.3s
# [CV] END ..............rf__max_depth=3, rf__n_estimators=120; total time=   0.4s
# [CV] END ..............rf__max_depth=3, rf__n_estimators=120; total time=   0.4s
# [CV] END ..............rf__max_depth=3, rf__n_estimators=120; total time=   0.4s
# [CV] END ..............rf__max_depth=3, rf__n_estimators=120; total time=   0.4s
# [CV] END ..............rf__max_depth=3, rf__n_estimators=120; total time=   0.4s
# [CV] END ..............rf__max_depth=3, rf__n_estimators=140; total time=   0.4s
# [CV] END ..............rf__max_depth=3, rf__n_estimators=140; total time=   0.5s
# [CV] END ..............rf__max_depth=3, rf__n_estimators=140; total time=   0.5s
# [CV] END ..............rf__max_depth=3, rf__n_estimators=140; total time=   0.5s
# [CV] END ..............rf__max_depth=3, rf__n_estimators=140; total time=   0.5s
# [CV] END ..............rf__max_depth=3, rf__n_estimators=160; total time=   0.5s
# [CV] END ..............rf__max_depth=3, rf__n_estimators=160; total time=   0.5s
# [CV] END ..............rf__max_depth=3, rf__n_estimators=160; total time=   0.5s
# [CV] END ..............rf__max_depth=3, rf__n_estimators=160; total time=   0.5s
# [CV] END ..............rf__max_depth=3, rf__n_estimators=160; total time=   0.5s
# [CV] END ..............rf__max_depth=3, rf__n_estimators=180; total time=   0.7s
# [CV] END ..............rf__max_depth=3, rf__n_estimators=180; total time=   0.6s
# [CV] END ..............rf__max_depth=3, rf__n_estimators=180; total time=   0.6s
# [CV] END ..............rf__max_depth=3, rf__n_estimators=180; total time=   0.6s
# [CV] END ..............rf__max_depth=3, rf__n_estimators=180; total time=   0.6s
# [CV] END ..............rf__max_depth=4, rf__n_estimators=100; total time=   0.4s
# [CV] END ..............rf__max_depth=4, rf__n_estimators=100; total time=   0.4s
# [CV] END ..............rf__max_depth=4, rf__n_estimators=100; total time=   0.4s
# [CV] END ..............rf__max_depth=4, rf__n_estimators=100; total time=   0.4s
# [CV] END ..............rf__max_depth=4, rf__n_estimators=100; total time=   0.4s
# [CV] END ..............rf__max_depth=4, rf__n_estimators=120; total time=   0.4s
# [CV] END ..............rf__max_depth=4, rf__n_estimators=120; total time=   0.5s
# [CV] END ..............rf__max_depth=4, rf__n_estimators=120; total time=   0.5s
# [CV] END ..............rf__max_depth=4, rf__n_estimators=120; total time=   0.4s
# [CV] END ..............rf__max_depth=4, rf__n_estimators=120; total time=   0.4s
# [CV] END ..............rf__max_depth=4, rf__n_estimators=140; total time=   0.5s
# [CV] END ..............rf__max_depth=4, rf__n_estimators=140; total time=   0.5s
# [CV] END ..............rf__max_depth=4, rf__n_estimators=140; total time=   0.5s
# [CV] END ..............rf__max_depth=4, rf__n_estimators=140; total time=   0.5s
# [CV] END ..............rf__max_depth=4, rf__n_estimators=140; total time=   0.5s
# [CV] END ..............rf__max_depth=4, rf__n_estimators=160; total time=   0.6s
# [CV] END ..............rf__max_depth=4, rf__n_estimators=160; total time=   0.6s
# [CV] END ..............rf__max_depth=4, rf__n_estimators=160; total time=   0.6s
# [CV] END ..............rf__max_depth=4, rf__n_estimators=160; total time=   0.6s
# [CV] END ..............rf__max_depth=4, rf__n_estimators=160; total time=   0.6s
# [CV] END ..............rf__max_depth=4, rf__n_estimators=180; total time=   0.7s
# [CV] END ..............rf__max_depth=4, rf__n_estimators=180; total time=   0.7s
# [CV] END ..............rf__max_depth=4, rf__n_estimators=180; total time=   0.7s
# [CV] END ..............rf__max_depth=4, rf__n_estimators=180; total time=   0.7s
# [CV] END ..............rf__max_depth=4, rf__n_estimators=180; total time=   0.7s
# [CV] END ..............rf__max_depth=5, rf__n_estimators=100; total time=   0.4s
# [CV] END ..............rf__max_depth=5, rf__n_estimators=100; total time=   0.4s
# [CV] END ..............rf__max_depth=5, rf__n_estimators=100; total time=   0.4s
# [CV] END ..............rf__max_depth=5, rf__n_estimators=100; total time=   0.4s
# [CV] END ..............rf__max_depth=5, rf__n_estimators=100; total time=   0.5s
# [CV] END ..............rf__max_depth=5, rf__n_estimators=120; total time=   0.6s
# [CV] END ..............rf__max_depth=5, rf__n_estimators=120; total time=   0.5s
# [CV] END ..............rf__max_depth=5, rf__n_estimators=120; total time=   0.5s
# [CV] END ..............rf__max_depth=5, rf__n_estimators=120; total time=   0.5s
# [CV] END ..............rf__max_depth=5, rf__n_estimators=120; total time=   0.5s
# [CV] END ..............rf__max_depth=5, rf__n_estimators=140; total time=   0.6s
# [CV] END ..............rf__max_depth=5, rf__n_estimators=140; total time=   0.6s
# [CV] END ..............rf__max_depth=5, rf__n_estimators=140; total time=   0.7s
# [CV] END ..............rf__max_depth=5, rf__n_estimators=140; total time=   0.7s
# [CV] END ..............rf__max_depth=5, rf__n_estimators=140; total time=   0.6s
# [CV] END ..............rf__max_depth=5, rf__n_estimators=160; total time=   0.7s
# [CV] END ..............rf__max_depth=5, rf__n_estimators=160; total time=   0.7s
# [CV] END ..............rf__max_depth=5, rf__n_estimators=160; total time=   0.7s
# [CV] END ..............rf__max_depth=5, rf__n_estimators=160; total time=   0.7s
# [CV] END ..............rf__max_depth=5, rf__n_estimators=160; total time=   0.7s
# [CV] END ..............rf__max_depth=5, rf__n_estimators=180; total time=   0.8s
# [CV] END ..............rf__max_depth=5, rf__n_estimators=180; total time=   0.8s
# [CV] END ..............rf__max_depth=5, rf__n_estimators=180; total time=   0.8s
# [CV] END ..............rf__max_depth=5, rf__n_estimators=180; total time=   0.9s
# [CV] END ..............rf__max_depth=5, rf__n_estimators=180; total time=   0.8s

# %%
# Evaluation metrics
eva_metrics(gs3, preds3, 'rf')
# Out:
# {'model': 'rf', 'best_parameters': {'rf__max_depth': None, 'rf__n_estimators': 140}, 'train_score': 0.993691957245488, 'test_score': 0.8699186991869918, 'precision': 0.15331010452961671, 'recall': 0.32116788321167883, 'specificity': 0.9006541291905151, 'accuracy': 0.8699186991869918, 'f1': 0.20754716981132074, 'roc_auc': 0.8058158411468747}
# Model: rf
#
# Best parameters are: {'rf__max_depth': None, 'rf__n_estimators': 140}
#
# Train Score: 0.993691957245488
# Test Score: 0.8699186991869918
#
# True Negatives: 2203
# False Positives: 243
# False Negatives: 93
# True Positives: 44
#
# Precision Score: 0.15331010452961671
# Recall Score: 0.15331010452961671
# Specificity Score: 0.9006541291905151
# Accuracy Score: 0.8699186991869918
# F1 Score: 0.20754716981132074
#
# ROC_AUC Score: 0.8058158411468747
# -------------------------------------------------------------------------------

# %%
results3
# Out:
#    accuracy                                    best_parameters        f1  \
# 0  0.720867  {'logreg__C': 2.9000000000000017, 'logreg__max...  0.152761
# 1  0.838173                            {'knn__n_neighbors': 3}  0.211321
# 2  0.869919   {'rf__max_depth': None, 'rf__n_estimators': 140}  0.207547
#
#     model  precision    recall   roc_auc  specificity  test_score  train_score
# 0  logreg   0.091036  0.474453  0.699771     0.734669    0.720867     0.804714
# 1     knn   0.142494  0.408759  0.701634     0.862224    0.838173     0.946907
# 2      rf   0.153310  0.321168  0.805816     0.900654    0.869919     0.993692

# %% [markdown]
# ### AdaBoost

# %%
# Create pipeline for adaboost classification model
pipe_ada = Pipeline([
    ('ss', StandardScaler()),
    ('ada', AdaBoostClassifier())
])

# Ref: https://medium.com/swlh/the-hyperparameter-cheat-sheet-770f1fed32ff
n_estimators = [100, 200]
learning_rate = [0.001, 0.01, 0.1, 0.2, 0.5]

# Include different hyperparameters
pipe_params_ada = [{"ada__n_estimators": n_estimators,
                   "ada__learning_rate": learning_rate}]

# %%
# Instantiate GridSearchCV
gs4 = GridSearchCV(pipe_ada, pipe_params_ada, cv=5, verbose=2) 

#Fit GridSearchCV
gs4.fit(X_train, y_train)

# Find predictors
preds4 = gs4.predict(X_test)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END ....ada__learning_rate=0.001, ada__n_estimators=100; total time=   1.3s
# [CV] END ....ada__learning_rate=0.001, ada__n_estimators=100; total time=   1.4s
# [CV] END ....ada__learning_rate=0.001, ada__n_estimators=100; total time=   1.3s
# [CV] END ....ada__learning_rate=0.001, ada__n_estimators=100; total time=   1.1s
# [CV] END ....ada__learning_rate=0.001, ada__n_estimators=100; total time=   1.1s
# [CV] END ....ada__learning_rate=0.001, ada__n_estimators=200; total time=   2.3s
# [CV] END ....ada__learning_rate=0.001, ada__n_estimators=200; total time=   2.2s
# [CV] END ....ada__learning_rate=0.001, ada__n_estimators=200; total time=   2.3s
# [CV] END ....ada__learning_rate=0.001, ada__n_estimators=200; total time=   2.3s
# [CV] END ....ada__learning_rate=0.001, ada__n_estimators=200; total time=   2.3s
# [CV] END .....ada__learning_rate=0.01, ada__n_estimators=100; total time=   1.1s
# [CV] END .....ada__learning_rate=0.01, ada__n_estimators=100; total time=   1.1s
# [CV] END .....ada__learning_rate=0.01, ada__n_estimators=100; total time=   1.1s
# [CV] END .....ada__learning_rate=0.01, ada__n_estimators=100; total time=   1.1s
# [CV] END .....ada__learning_rate=0.01, ada__n_estimators=100; total time=   1.1s
# [CV] END .....ada__learning_rate=0.01, ada__n_estimators=200; total time=   2.3s
# [CV] END .....ada__learning_rate=0.01, ada__n_estimators=200; total time=   2.3s
# [CV] END .....ada__learning_rate=0.01, ada__n_estimators=200; total time=   2.3s
# [CV] END .....ada__learning_rate=0.01, ada__n_estimators=200; total time=   2.3s
# [CV] END .....ada__learning_rate=0.01, ada__n_estimators=200; total time=   2.3s
# [CV] END ......ada__learning_rate=0.1, ada__n_estimators=100; total time=   1.1s
# [CV] END ......ada__learning_rate=0.1, ada__n_estimators=100; total time=   1.1s
# [CV] END ......ada__learning_rate=0.1, ada__n_estimators=100; total time=   1.1s
# [CV] END ......ada__learning_rate=0.1, ada__n_estimators=100; total time=   1.1s
# [CV] END ......ada__learning_rate=0.1, ada__n_estimators=100; total time=   1.1s
# [CV] END ......ada__learning_rate=0.1, ada__n_estimators=200; total time=   2.2s
# [CV] END ......ada__learning_rate=0.1, ada__n_estimators=200; total time=   2.3s
# [CV] END ......ada__learning_rate=0.1, ada__n_estimators=200; total time=   2.3s
# [CV] END ......ada__learning_rate=0.1, ada__n_estimators=200; total time=   2.3s
# [CV] END ......ada__learning_rate=0.1, ada__n_estimators=200; total time=   2.2s
# [CV] END ......ada__learning_rate=0.2, ada__n_estimators=100; total time=   1.1s
# [CV] END ......ada__learning_rate=0.2, ada__n_estimators=100; total time=   1.1s
# [CV] END ......ada__learning_rate=0.2, ada__n_estimators=100; total time=   1.1s
# [CV] END ......ada__learning_rate=0.2, ada__n_estimators=100; total time=   1.1s
# [CV] END ......ada__learning_rate=0.2, ada__n_estimators=100; total time=   1.1s
# [CV] END ......ada__learning_rate=0.2, ada__n_estimators=200; total time=   2.2s
# [CV] END ......ada__learning_rate=0.2, ada__n_estimators=200; total time=   2.2s
# [CV] END ......ada__learning_rate=0.2, ada__n_estimators=200; total time=   2.2s
# [CV] END ......ada__learning_rate=0.2, ada__n_estimators=200; total time=   2.2s
# [CV] END ......ada__learning_rate=0.2, ada__n_estimators=200; total time=   2.2s
# [CV] END ......ada__learning_rate=0.5, ada__n_estimators=100; total time=   1.1s
# [CV] END ......ada__learning_rate=0.5, ada__n_estimators=100; total time=   1.2s
# [CV] END ......ada__learning_rate=0.5, ada__n_estimators=100; total time=   1.1s
# [CV] END ......ada__learning_rate=0.5, ada__n_estimators=100; total time=   1.1s
# [CV] END ......ada__learning_rate=0.5, ada__n_estimators=100; total time=   1.1s
# [CV] END ......ada__learning_rate=0.5, ada__n_estimators=200; total time=   2.3s
# [CV] END ......ada__learning_rate=0.5, ada__n_estimators=200; total time=   2.4s
# [CV] END ......ada__learning_rate=0.5, ada__n_estimators=200; total time=   2.3s
# [CV] END ......ada__learning_rate=0.5, ada__n_estimators=200; total time=   2.3s
# [CV] END ......ada__learning_rate=0.5, ada__n_estimators=200; total time=   2.3s

# %%
# Evaluation metrics
eva_metrics(gs4, preds4, 'ada')
# Out:
# {'model': 'ada', 'best_parameters': {'ada__learning_rate': 0.5, 'ada__n_estimators': 200}, 'train_score': 0.867093043630629, 'test_score': 0.794812233836624, 'precision': 0.1497326203208556, 'recall': 0.6131386861313869, 'specificity': 0.8049877350776778, 'accuracy': 0.794812233836624, 'f1': 0.24068767908309455, 'roc_auc': 0.802998788428598}
# Model: ada
#
# Best parameters are: {'ada__learning_rate': 0.5, 'ada__n_estimators': 200}
#
# Train Score: 0.867093043630629
# Test Score: 0.794812233836624
#
# True Negatives: 1969
# False Positives: 477
# False Negatives: 53
# True Positives: 84
#
# Precision Score: 0.1497326203208556
# Recall Score: 0.1497326203208556
# Specificity Score: 0.8049877350776778
# Accuracy Score: 0.794812233836624
# F1 Score: 0.24068767908309455
#
# ROC_AUC Score: 0.802998788428598
# -------------------------------------------------------------------------------

# %%
results3
# Out:
#    accuracy                                    best_parameters        f1  \
# 0  0.720867  {'logreg__C': 2.9000000000000017, 'logreg__max...  0.152761
# 1  0.838173                            {'knn__n_neighbors': 3}  0.211321
# 2  0.869919   {'rf__max_depth': None, 'rf__n_estimators': 140}  0.207547
# 3  0.794812  {'ada__learning_rate': 0.5, 'ada__n_estimators...  0.240688
#
#     model  precision    recall   roc_auc  specificity  test_score  train_score
# 0  logreg   0.091036  0.474453  0.699771     0.734669    0.720867     0.804714
# 1     knn   0.142494  0.408759  0.701634     0.862224    0.838173     0.946907
# 2      rf   0.153310  0.321168  0.805816     0.900654    0.869919     0.993692
# 3     ada   0.149733  0.613139  0.802999     0.804988    0.794812     0.867093

# %% [markdown]
# ### Gradient Boosting

# %%
# Create pipeline for adaboost classification model
pipe_gb = Pipeline([
    ('ss', StandardScaler()),
    ('gb', GradientBoostingClassifier())
])

# Ref: https://medium.com/swlh/the-hyperparameter-cheat-sheet-770f1fed32ff
n_estimators = [100, 200]
learning_rate = [0.001, 0.01, 0.1, 0.2, 0.5]

# Include different hyperparameters
pipe_params_gb = [{"gb__n_estimators": n_estimators,
                   "gb__learning_rate": learning_rate}]

# %%
# Instantiate GridSearchCV
gs5 = GridSearchCV(pipe_gb, pipe_params_gb, cv=5, verbose=2) 

#Fit GridSearchCV
gs5.fit(X_train, y_train)

# Find predictors
preds5 = gs5.predict(X_test)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END ......gb__learning_rate=0.001, gb__n_estimators=100; total time=   1.9s
# [CV] END ......gb__learning_rate=0.001, gb__n_estimators=100; total time=   1.7s
# [CV] END ......gb__learning_rate=0.001, gb__n_estimators=100; total time=   1.8s
# [CV] END ......gb__learning_rate=0.001, gb__n_estimators=100; total time=   1.7s
# [CV] END ......gb__learning_rate=0.001, gb__n_estimators=100; total time=   1.7s
# [CV] END ......gb__learning_rate=0.001, gb__n_estimators=200; total time=   3.5s
# [CV] END ......gb__learning_rate=0.001, gb__n_estimators=200; total time=   3.5s
# [CV] END ......gb__learning_rate=0.001, gb__n_estimators=200; total time=   3.5s
# [CV] END ......gb__learning_rate=0.001, gb__n_estimators=200; total time=   3.6s
# [CV] END ......gb__learning_rate=0.001, gb__n_estimators=200; total time=   3.5s
# [CV] END .......gb__learning_rate=0.01, gb__n_estimators=100; total time=   1.7s
# [CV] END .......gb__learning_rate=0.01, gb__n_estimators=100; total time=   1.7s
# [CV] END .......gb__learning_rate=0.01, gb__n_estimators=100; total time=   1.7s
# [CV] END .......gb__learning_rate=0.01, gb__n_estimators=100; total time=   1.7s
# [CV] END .......gb__learning_rate=0.01, gb__n_estimators=100; total time=   1.7s
# [CV] END .......gb__learning_rate=0.01, gb__n_estimators=200; total time=   3.7s
# [CV] END .......gb__learning_rate=0.01, gb__n_estimators=200; total time=   3.5s
# [CV] END .......gb__learning_rate=0.01, gb__n_estimators=200; total time=   3.6s
# [CV] END .......gb__learning_rate=0.01, gb__n_estimators=200; total time=   3.5s
# [CV] END .......gb__learning_rate=0.01, gb__n_estimators=200; total time=   3.5s
# [CV] END ........gb__learning_rate=0.1, gb__n_estimators=100; total time=   1.8s
# [CV] END ........gb__learning_rate=0.1, gb__n_estimators=100; total time=   1.7s
# [CV] END ........gb__learning_rate=0.1, gb__n_estimators=100; total time=   2.0s
# [CV] END ........gb__learning_rate=0.1, gb__n_estimators=100; total time=   1.8s
# [CV] END ........gb__learning_rate=0.1, gb__n_estimators=100; total time=   1.8s
# [CV] END ........gb__learning_rate=0.1, gb__n_estimators=200; total time=   3.8s
# [CV] END ........gb__learning_rate=0.1, gb__n_estimators=200; total time=   3.6s
# [CV] END ........gb__learning_rate=0.1, gb__n_estimators=200; total time=   3.6s
# [CV] END ........gb__learning_rate=0.1, gb__n_estimators=200; total time=   3.5s
# [CV] END ........gb__learning_rate=0.1, gb__n_estimators=200; total time=   3.6s
# [CV] END ........gb__learning_rate=0.2, gb__n_estimators=100; total time=   1.8s
# [CV] END ........gb__learning_rate=0.2, gb__n_estimators=100; total time=   1.7s
# [CV] END ........gb__learning_rate=0.2, gb__n_estimators=100; total time=   1.7s
# [CV] END ........gb__learning_rate=0.2, gb__n_estimators=100; total time=   1.7s
# [CV] END ........gb__learning_rate=0.2, gb__n_estimators=100; total time=   1.7s
# [CV] END ........gb__learning_rate=0.2, gb__n_estimators=200; total time=   3.6s
# [CV] END ........gb__learning_rate=0.2, gb__n_estimators=200; total time=   3.5s
# [CV] END ........gb__learning_rate=0.2, gb__n_estimators=200; total time=   3.5s
# [CV] END ........gb__learning_rate=0.2, gb__n_estimators=200; total time=   3.6s
# [CV] END ........gb__learning_rate=0.2, gb__n_estimators=200; total time=   3.5s
# [CV] END ........gb__learning_rate=0.5, gb__n_estimators=100; total time=   1.8s
# [CV] END ........gb__learning_rate=0.5, gb__n_estimators=100; total time=   1.7s
# [CV] END ........gb__learning_rate=0.5, gb__n_estimators=100; total time=   1.7s
# [CV] END ........gb__learning_rate=0.5, gb__n_estimators=100; total time=   1.7s
# [CV] END ........gb__learning_rate=0.5, gb__n_estimators=100; total time=   1.7s
# [CV] END ........gb__learning_rate=0.5, gb__n_estimators=200; total time=   3.6s
# [CV] END ........gb__learning_rate=0.5, gb__n_estimators=200; total time=   3.5s
# [CV] END ........gb__learning_rate=0.5, gb__n_estimators=200; total time=   3.5s
# [CV] END ........gb__learning_rate=0.5, gb__n_estimators=200; total time=   3.6s
# [CV] END ........gb__learning_rate=0.5, gb__n_estimators=200; total time=   3.5s

# %%
# Evaluation metrics
eva_metrics(gs5, preds5, 'gb')
# Out:
# {'model': 'gb', 'best_parameters': {'gb__learning_rate': 0.5, 'gb__n_estimators': 200}, 'train_score': 0.97240231294901, 'test_score': 0.9047619047619048, 'precision': 0.17365269461077845, 'recall': 0.2116788321167883, 'specificity': 0.9435813573180704, 'accuracy': 0.9047619047619048, 'f1': 0.19078947368421054, 'roc_auc': 0.8231120673705319}
# Model: gb
#
# Best parameters are: {'gb__learning_rate': 0.5, 'gb__n_estimators': 200}
#
# Train Score: 0.97240231294901
# Test Score: 0.9047619047619048
#
# True Negatives: 2308
# False Positives: 138
# False Negatives: 108
# True Positives: 29
#
# Precision Score: 0.17365269461077845
# Recall Score: 0.17365269461077845
# Specificity Score: 0.9435813573180704
# Accuracy Score: 0.9047619047619048
# F1 Score: 0.19078947368421054
#
# ROC_AUC Score: 0.8231120673705319
# -------------------------------------------------------------------------------

# %%
results3[['model', 'best_parameters', 'train_score', 'test_score', 'precision', 
          'recall','accuracy', 'roc_auc']]
# Out:
#     model                                    best_parameters  train_score  \
# 0  logreg  {'logreg__C': 2.9000000000000017, 'logreg__max...     0.804714
# 1     knn                            {'knn__n_neighbors': 3}     0.946907
# 2      rf   {'rf__max_depth': None, 'rf__n_estimators': 140}     0.993692
# 3     ada  {'ada__learning_rate': 0.5, 'ada__n_estimators...     0.867093
# 4      gb  {'gb__learning_rate': 0.5, 'gb__n_estimators':...     0.972402
#
#    test_score  precision    recall  accuracy   roc_auc
# 0    0.720867   0.091036  0.474453  0.720867  0.699771
# 1    0.838173   0.142494  0.408759  0.838173  0.701634
# 2    0.869919   0.153310  0.321168  0.869919  0.805816
# 3    0.794812   0.149733  0.613139  0.794812  0.802999
# 4    0.904762   0.173653  0.211679  0.904762  0.823112

# %%
merged_df3 = merged_df2.copy()
merged_df_test3 = merged_df_test2.copy()

# %%
results
# Out:
#     model  train_score  test_score  precision    recall  specificity  \
# 0  logreg     0.946408    0.946961   0.500000  0.007299     0.999591
# 1     knn     0.950058    0.943477   0.263158  0.036496     0.994276
# 2      rf     0.988054    0.938057   0.244444  0.080292     0.986100
# 3     ada     0.946408    0.943864   0.214286  0.021898     0.995503
# 4      gb     0.949560    0.942702   0.076923  0.007299     0.995094
#
#    accuracy        f1   roc_auc
# 0  0.946961  0.014388  0.813038
# 1  0.943477  0.064103  0.698774
# 2  0.938057  0.120879  0.800934
# 3  0.943864  0.039735  0.846123
# 4  0.942702  0.013333  0.872690

# %% [markdown]
# From the results:
# - 5 classification algorithm used: logistic regression, k nearest neighbors, random forest, adaboost and gradientboosting
# - Models performs better after smote
# - After tuning the hyperparams of each algorithm, the roc_auc score decrease but increase in recall scores
# - From results of gridsearch, adaboost is able to produce followed by random forest and gradient boosting

# %% [markdown]
#  # Best Model Evaluation

# %%
# Define X features
X2 = merged_df_test3.drop('id', axis=1)

# %%
len(X2.columns)
# Out:
# 184

# %%
columns = columns[1:]

# %%
len(columns.index)
# Out:
# 40

# %%
X2 = X2[columns.index]

# %%
'''
# Instantiate StandardScaler
ss = StandardScaler()
X_train_sc = ss.fit_transform(X_train)
'''
# Out:
# '\n# Instantiate StandardScaler\nss = StandardScaler()\nX_train_sc = ss.fit_transform(X_train)\n'

# %%
'''
# Instantiate best model with hyperparameters
gb = GradientBoostingClassifier(learning_rate=0.5, n_estimators=200)

#Fit model
gb.fit(X_train_sc, y_train)

# Predictions
preds_final = pipe.predict(X2)
preds_final2 = pipe.predict_proba(X2)
'''
# Out:
# '\n# Instantiate best model with hyperparameters\ngb = GradientBoostingClassifier(learning_rate=0.5, n_estimators=200)\n\n#Fit model\ngb.fit(X_train_sc, y_train)\n\n# Predictions\npreds_final = pipe.predict(X2)\npreds_final2 = pipe.predict_proba(X2)\n'

# %%
'''
# Instantiate best model with hyperparameters
ada = AdaBoostClassifier(learning_rate=0.5, n_estimators=200)

#Fit model
ada.fit(X_train, y_train)

# Predictions
preds_final = pipe.predict(X2)
preds_final2 = pipe.predict_proba(X2)
'''
# Out:
# '\n# Instantiate best model with hyperparameters\nada = AdaBoostClassifier(learning_rate=0.5, n_estimators=200)\n\n#Fit model\nada.fit(X_train, y_train)\n\n# Predictions\npreds_final = pipe.predict(X2)\npreds_final2 = pipe.predict_proba(X2)\n'

# %%
#feat_importances = pd.Series(gb.feature_importances_, index=X2.columns)
#feat_importances.sort_values(ascending=False).head(10)

# %%
# Create pipeline for each kneighborsclassifier classification model
pipe_gb = [('ss', StandardScaler()),
            ('gb', GradientBoostingClassifier(learning_rate=0.5, n_estimators=200))]

# %%
'''
# Create pipeline for each kneighborsclassifier classification model
pipe_ada = [('ss', StandardScaler()),
            ('ada', AdaBoostClassifier(learning_rate=0.5, n_estimators=200))]
'''
# Out:
# "\n# Create pipeline for each kneighborsclassifier classification model\npipe_ada = [('ss', StandardScaler()),\n            ('ada', AdaBoostClassifier(learning_rate=0.5, n_estimators=200))]\n"

# %%
# Instantiate Pipeline
pipe = Pipeline(pipe_gb)

# Fit model
pipe.fit(X_train, y_train)

# Predictions
preds_final = pipe.predict(X2)
preds_final2 = pipe.predict_proba(X2)

# %% [markdown]
# ### Save model

# %%
joblib.dump(pipe, 'pipe_joblib')
# Out:
# ['pipe_joblib']

# %% [markdown]
# ### For Kaggle Submission

# %%
submission = pd.DataFrame(merged_df_test['id'])
submission.columns = ['Id']

# %%
#submission['Id']

# %%
submission['WnvPresent'] = preds_final

# %%
submission.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116293 entries, 0 to 116292
# Data columns (total 2 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Id          116293 non-null  int64
#  1   WnvPresent  116293 non-null  int64
# dtypes: int64(2)
# memory usage: 1.8 MB

# %%
submission.head()
# Out:
#    Id  WnvPresent
# 0   1           0
# 1   2           0
# 2   3           0
# 3   4           0
# 4   5           0

# %%
# Export data to csv for Kaggle submission
submission.to_csv('../assets/clean_data/submission.csv', index=False)

# %% [markdown]
# ### Final Test dataset with predictions

# %%
# Create new column for predictors
merged_df_test['wnvpresent'] = preds_final

# %%
# Create new column for predictors probability
merged_df_test[['wnvpresentprob1', 'wnvpresentprob2']] = preds_final2

# %%
merged_df_test.head()
# Out:
#    id        date                                            address  \
# 0   1  2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 1   2  2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2   3  2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 3   4  2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 4   5  2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
#
#                   species  block           street  trap  \
# 0  CULEX PIPIENS/RESTUANS     41   N OAK PARK AVE  T002
# 1          CULEX RESTUANS     41   N OAK PARK AVE  T002
# 2           CULEX PIPIENS     41   N OAK PARK AVE  T002
# 3        CULEX SALINARIUS     41   N OAK PARK AVE  T002
# 4         CULEX TERRITANS     41   N OAK PARK AVE  T002
#
#               addressnumberandstreet  latitude  longitude  ...  preciptotal  \
# 0  4100  N OAK PARK AVE, Chicago, IL  41.95469 -87.800991  ...          0.0
# 1  4100  N OAK PARK AVE, Chicago, IL  41.95469 -87.800991  ...          0.0
# 2  4100  N OAK PARK AVE, Chicago, IL  41.95469 -87.800991  ...          0.0
# 3  4100  N OAK PARK AVE, Chicago, IL  41.95469 -87.800991  ...          0.0
# 4  4100  N OAK PARK AVE, Chicago, IL  41.95469 -87.800991  ...          0.0
#
#    stnpressure  sealevel  resultspeed  resultdir  avgspeed  r_humid  \
# 0        29.28     29.99          8.9         18      10.0       53
# 1        29.28     29.99          8.9         18      10.0       53
# 2        29.28     29.99          8.9         18      10.0       53
# 3        29.28     29.99          8.9         18      10.0       53
# 4        29.28     29.99          8.9         18      10.0       53
#
#    wnvpresent  wnvpresentprob1  wnvpresentprob2
# 0           0         0.966375         0.033625
# 1           0         0.992248         0.007752
# 2           0         0.987504         0.012496
# 3           0         0.993889         0.006111
# 4           0         0.983944         0.016056
#
# [5 rows x 36 columns]

# %%
merged_df_test.to_csv('../assets/clean_data/final_test5.csv', index=False)

# %% [markdown]
# ---

# %% [markdown]
# # Prediction Analysis

# %%
final_df = merged_df_test

# %%
final_df.shape
# Out:
# (116293, 36)

# %%
final_df[final_df['wnvpresent'] == 1]['wnvpresent'].sum()
# Out:
# 12144

# %%
final_df[final_df['wnvpresentprob2'] > 0.5]['wnvpresentprob2'].sort_values(ascending=False)
# Out:
# 53440    0.999297
# 53442    0.999297
# 53441    0.999297
# 53435    0.999297
# 64375    0.999079
#            ...
# 21710    0.500246
# 52328    0.500180
# 52322    0.500180
# 52327    0.500180
# 52329    0.500180
# Name: wnvpresentprob2, Length: 12144, dtype: float64

# %%
# Traps are located
alpha_cm = plt.cm.coolwarm
alpha_cm._init()
alpha_cm._lut[:-3,-1] = abs(np.logspace(0, 1, alpha_cm.N) / 10 - 1)[::-1]
mapdata = np.loadtxt("../assets/raw_data/mapdata_copyright_openstreetmap_contributors.txt")
aspect = mapdata.shape[0] * 1.0 / mapdata.shape[1]

lon_lat_box = (-88, -87.5, 41.6, 42.1)

#spray locations
X = final_df[['longitude', 'latitude']].drop_duplicates().values
kd = KernelDensity(bandwidth=0.015)
kd.fit(X)

xv,yv = np.meshgrid(np.linspace(-88, -87.5, 100), np.linspace(41.6, 42.1, 100))
gridpoints = np.array([xv.ravel(),yv.ravel()]).T
zv = np.exp(kd.score_samples(gridpoints).reshape(100,100))

#kernel density
plt.figure(figsize=(10,14))
plt.imshow(mapdata, cmap=plt.get_cmap('gray'), extent=lon_lat_box, aspect=aspect)
plt.imshow(zv, origin='lower', cmap=alpha_cm, extent=lon_lat_box, aspect=aspect)

# wnv outbreak locations
trap_locations1 = final_df[final_df['wnvpresentprob2'] > 0.5][['longitude', 'latitude']].drop_duplicates().values
plt.scatter(trap_locations1[:,0], trap_locations1[:,1], marker='x', c='b', label='>50% WNV Probability')

trap_locations2 = final_df[final_df['wnvpresentprob2'] > 0.8][['longitude', 'latitude']].drop_duplicates().values
plt.scatter(trap_locations2[:,0], trap_locations2[:,1], s=300, facecolors='none', edgecolors='red', linewidth = 1.5, label='>70% WNV Probability')

plt.title('West Nile Virus predictions in Chicago')
plt.legend()
plt.xlabel('Longitude')
plt.ylabel('Latitude')
# Out:
# Text(0, 0.5, 'Latitude')

# %%
pipe.feature_importances_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-108-e5f9cc2bdb81> in <module>
# ----> 1 pipe.feature_importances_
#
# AttributeError: 'Pipeline' object has no attribute 'feature_importances_'
